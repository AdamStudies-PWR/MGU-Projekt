# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-88031bf72da52739" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-88031bf72da52739");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
                transforms.RandomVerticalFlip(),  
                transforms.RandomRotation(10),
                transforms.ColorJitter(brightness=0.05, contrast=0.05, saturation=0.05, hue=0.05)
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .25

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        self.batchnorm5 = nn.BatchNorm2d(2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = y = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x + y)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm5(self.convtrans3(x + input)), negative_slope=0.1)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-1, momentum=0.9)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 32, 32]           2,306
#       BatchNorm2d-10            [-1, 2, 32, 32]               4
# ================================================================
# Total params: 2,662,278
# Trainable params: 2,662,278
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.78
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.94
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00235885 (0.01042341), PSNR 26.27300262 (24.30010951), SSIM 0.78276461 (0.71723842)
# Finished training epoch 0
# Validate: MSE 0.00317596 (0.00275923), PSNR 24.98125458 (25.66937914), SSIM 0.70689124 (0.77535872)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00230724 (0.00276383), PSNR 26.36907387 (25.60730027), SSIM 0.78261352 (0.76921813)
# Finished training epoch 1
# Validate: MSE 0.00324621 (0.00276963), PSNR 24.88623428 (25.64948160), SSIM 0.70645392 (0.77597161)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00314887 (0.00276381), PSNR 25.01845360 (25.60807843), SSIM 0.76137704 (0.76920068)
# Finished training epoch 2
# Validate: MSE 0.00318277 (0.00276236), PSNR 24.97194862 (25.66433061), SSIM 0.70645636 (0.77407864)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00296145 (0.00275155), PSNR 25.28495026 (25.62525479), SSIM 0.74671787 (0.76936509)
# Finished training epoch 3
# Validate: MSE 0.00320415 (0.00276012), PSNR 24.94286537 (25.66636652), SSIM 0.70685947 (0.77549277)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00253114 (0.00276111), PSNR 25.96684456 (25.61295070), SSIM 0.77972472 (0.76940850)
# Finished training epoch 4
# Validate: MSE 0.00317045 (0.00275911), PSNR 24.98879623 (25.66981254), SSIM 0.70698476 (0.77559044)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00273010 (0.00276183), PSNR 25.63821411 (25.61065035), SSIM 0.77995795 (0.76933040)
# Finished training epoch 5
# Validate: MSE 0.00317889 (0.00275696), PSNR 24.97724152 (25.67350912), SSIM 0.70654213 (0.77458911)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00306568 (0.00275851), PSNR 25.13473129 (25.61545687), SSIM 0.75306207 (0.76928728)
# Finished training epoch 6
# Validate: MSE 0.00323209 (0.00276242), PSNR 24.90516472 (25.66141296), SSIM 0.70674652 (0.77594082)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00294919 (0.00276141), PSNR 25.30296516 (25.61214108), SSIM 0.77215731 (0.76917598)
# Finished training epoch 7
# Validate: MSE 0.00328461 (0.00277252), PSNR 24.83516693 (25.64481085), SSIM 0.70700765 (0.77567315)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00277272 (0.00276690), PSNR 25.57093048 (25.60074269), SSIM 0.77351648 (0.76927228)
# Finished training epoch 8
# Validate: MSE 0.00322511 (0.00275657), PSNR 24.91455841 (25.67120084), SSIM 0.70668662 (0.77514873)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00255127 (0.00276446), PSNR 25.93244171 (25.60707367), SSIM 0.75633872 (0.76916466)
# Finished training epoch 9
# Validate: MSE 0.00320931 (0.00275593), PSNR 24.93588638 (25.67243987), SSIM 0.70718503 (0.77557520)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00305295 (0.00275966), PSNR 25.15280151 (25.61657749), SSIM 0.76792216 (0.76939092)
# Finished training epoch 10
# Validate: MSE 0.00318073 (0.00275392), PSNR 24.97473145 (25.67710762), SSIM 0.70720100 (0.77540110)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00202425 (0.00275856), PSNR 26.93734932 (25.61614367), SSIM 0.80399722 (0.76919134)
# Finished training epoch 11
# Validate: MSE 0.00323472 (0.00276024), PSNR 24.90163612 (25.66526505), SSIM 0.70705009 (0.77569225)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00246876 (0.00276032), PSNR 26.07520103 (25.61340114), SSIM 0.77733237 (0.76951978)
# Finished training epoch 12
# Validate: MSE 0.00323321 (0.00276741), PSNR 24.90366364 (25.65441576), SSIM 0.70732582 (0.77479156)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00333059 (0.00276331), PSNR 24.77478600 (25.60806070), SSIM 0.76334590 (0.76935686)
# Finished training epoch 13
# Validate: MSE 0.00325828 (0.00277417), PSNR 24.87010956 (25.64288854), SSIM 0.70677859 (0.77613940)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00269469 (0.00275484), PSNR 25.69491577 (25.62320535), SSIM 0.79629958 (0.76937647)
# Finished training epoch 14
# Validate: MSE 0.00320627 (0.00275501), PSNR 24.94000244 (25.67436086), SSIM 0.70740426 (0.77485484)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00376517 (0.00275552), PSNR 24.24214745 (25.62439580), SSIM 0.75725758 (0.76940641)
# Finished training epoch 15
# Validate: MSE 0.00321936 (0.00275438), PSNR 24.92230415 (25.67449600), SSIM 0.70728874 (0.77580225)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00247642 (0.00276050), PSNR 26.06175232 (25.61371130), SSIM 0.77288121 (0.76940054)
# Finished training epoch 16
# Validate: MSE 0.00326315 (0.00276758), PSNR 24.86363029 (25.65293349), SSIM 0.70707560 (0.77612224)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00254987 (0.00275435), PSNR 25.93481445 (25.62419647), SSIM 0.76438123 (0.76945050)
# Finished training epoch 17
# Validate: MSE 0.00318060 (0.00275433), PSNR 24.97490883 (25.67645380), SSIM 0.70748836 (0.77589031)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00280060 (0.00276176), PSNR 25.52749634 (25.61055649), SSIM 0.77403152 (0.76930206)
# Finished training epoch 18
# Validate: MSE 0.00328615 (0.00278536), PSNR 24.83312225 (25.62516088), SSIM 0.70669270 (0.77610481)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00241566 (0.00275373), PSNR 26.16963959 (25.62622214), SSIM 0.76416719 (0.76956400)
# Finished training epoch 19
# Validate: MSE 0.00314780 (0.00276167), PSNR 25.01992226 (25.66920937), SSIM 0.70758569 (0.77536300)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00184825 (0.00275097), PSNR 27.33238411 (25.62783204), SSIM 0.76682973 (0.76959013)
# Finished training epoch 20
# Validate: MSE 0.00319781 (0.00274897), PSNR 24.95147133 (25.68430338), SSIM 0.70725495 (0.77556110)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00236350 (0.00275405), PSNR 26.26444626 (25.62505911), SSIM 0.78329706 (0.76952621)
# Finished training epoch 21
# Validate: MSE 0.00316752 (0.00274787), PSNR 24.99279976 (25.68698877), SSIM 0.70752382 (0.77570828)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00382037 (0.00275159), PSNR 24.17894745 (25.62621305), SSIM 0.76286161 (0.76951322)
# Finished training epoch 22
# Validate: MSE 0.00319068 (0.00275480), PSNR 24.96116447 (25.67477634), SSIM 0.70741034 (0.77574970)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00263474 (0.00275399), PSNR 25.79261971 (25.62682485), SSIM 0.78713799 (0.76967644)
# Finished training epoch 23
# Validate: MSE 0.00316819 (0.00274965), PSNR 24.99188995 (25.68377089), SSIM 0.70731914 (0.77507693)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00276070 (0.00275351), PSNR 25.58980179 (25.62366727), SSIM 0.75267053 (0.76960966)
# Finished training epoch 24
# Validate: MSE 0.00320016 (0.00276882), PSNR 24.94827843 (25.65192586), SSIM 0.70646882 (0.77602196)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00283278 (0.00274840), PSNR 25.47787476 (25.63157883), SSIM 0.79136163 (0.76963337)
# Finished training epoch 25
# Validate: MSE 0.00321609 (0.00275121), PSNR 24.92671967 (25.67940177), SSIM 0.70754170 (0.77626357)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00264117 (0.00274837), PSNR 25.78203773 (25.63427134), SSIM 0.78255683 (0.76978407)
# Finished training epoch 26
# Validate: MSE 0.00319891 (0.00275102), PSNR 24.94997978 (25.68047307), SSIM 0.70777303 (0.77610202)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00250230 (0.00275363), PSNR 26.01659775 (25.62162100), SSIM 0.78323996 (0.76977796)
# Finished training epoch 27
# Validate: MSE 0.00318924 (0.00274592), PSNR 24.96311951 (25.68874421), SSIM 0.70783305 (0.77621204)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00264652 (0.00274399), PSNR 25.77324867 (25.64162762), SSIM 0.76611501 (0.76988877)
# Finished training epoch 28
# Validate: MSE 0.00317412 (0.00274412), PSNR 24.98376656 (25.69206018), SSIM 0.70764399 (0.77527424)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00221293 (0.00273879), PSNR 26.55031586 (25.64568529), SSIM 0.78412557 (0.76994290)
# Finished training epoch 29
# Validate: MSE 0.00316424 (0.00274232), PSNR 24.99730873 (25.69616815), SSIM 0.70816588 (0.77604598)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00324368 (0.00274652), PSNR 24.88961601 (25.63402430), SSIM 0.76585710 (0.76988708)
# Finished training epoch 30
# Validate: MSE 0.00328586 (0.00277535), PSNR 24.83351326 (25.64083206), SSIM 0.70722431 (0.77647367)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00314896 (0.00274795), PSNR 25.01832199 (25.63243118), SSIM 0.77711183 (0.76964513)
# Finished training epoch 31
# Validate: MSE 0.00324038 (0.00275333), PSNR 24.89404297 (25.67414033), SSIM 0.70806223 (0.77612548)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00257181 (0.00273832), PSNR 25.89760780 (25.64722533), SSIM 0.76115590 (0.77002095)
# Finished training epoch 32
# Validate: MSE 0.00313173 (0.00273684), PSNR 25.04215431 (25.70609523), SSIM 0.70846617 (0.77582368)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00233047 (0.00275406), PSNR 26.32556915 (25.62319534), SSIM 0.78422701 (0.76960755)
# Finished training epoch 33
# Validate: MSE 0.00317503 (0.00274919), PSNR 24.98251915 (25.68368263), SSIM 0.70765913 (0.77643874)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00242356 (0.00274002), PSNR 26.15545273 (25.64645748), SSIM 0.78278267 (0.76984866)
# Finished training epoch 34
# Validate: MSE 0.00327392 (0.00277039), PSNR 24.84932518 (25.64912418), SSIM 0.70798403 (0.77617367)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00275846 (0.00273716), PSNR 25.59333229 (25.65161694), SSIM 0.76850265 (0.77001027)
# Finished training epoch 35
# Validate: MSE 0.00310464 (0.00274109), PSNR 25.07988167 (25.70265196), SSIM 0.70822352 (0.77622763)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00274774 (0.00274196), PSNR 25.61025047 (25.64438606), SSIM 0.78271830 (0.77000001)
# Finished training epoch 36
# Validate: MSE 0.00314612 (0.00273326), PSNR 25.02224350 (25.71064360), SSIM 0.70858586 (0.77608529)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00315876 (0.00273778), PSNR 25.00483704 (25.65097863), SSIM 0.74860251 (0.76998723)
# Finished training epoch 37
# Validate: MSE 0.00315483 (0.00273355), PSNR 25.01023483 (25.70834592), SSIM 0.70793152 (0.77521705)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00232330 (0.00273472), PSNR 26.33895302 (25.65406834), SSIM 0.78276151 (0.77008982)
# Finished training epoch 38
# Validate: MSE 0.00326553 (0.00275640), PSNR 24.86046410 (25.66980172), SSIM 0.70854247 (0.77627285)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00308728 (0.00274286), PSNR 25.10424232 (25.64091270), SSIM 0.77935982 (0.76998858)
# Finished training epoch 39
# Validate: MSE 0.00308608 (0.00272354), PSNR 25.10592079 (25.72914347), SSIM 0.70859897 (0.77549041)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00305060 (0.00272980), PSNR 25.15615273 (25.66065804), SSIM 0.75734156 (0.76999346)
# Finished training epoch 40
# Validate: MSE 0.00313768 (0.00272457), PSNR 25.03391647 (25.72373217), SSIM 0.70885009 (0.77680646)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00273871 (0.00273381), PSNR 25.62453270 (25.65580969), SSIM 0.78461754 (0.77009912)
# Finished training epoch 41
# Validate: MSE 0.00316091 (0.00272210), PSNR 25.00187874 (25.72588579), SSIM 0.70902002 (0.77643616)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00312927 (0.00273050), PSNR 25.04557037 (25.65914984), SSIM 0.76208794 (0.77011110)
# Finished training epoch 42
# Validate: MSE 0.00310364 (0.00271089), PSNR 25.08128166 (25.74578664), SSIM 0.70825565 (0.77582867)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00281259 (0.00272519), PSNR 25.50894165 (25.66949089), SSIM 0.76815015 (0.77018857)
# Finished training epoch 43
# Validate: MSE 0.00311978 (0.00270880), PSNR 25.05875778 (25.74795720), SSIM 0.70894110 (0.77674478)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00259682 (0.00271317), PSNR 25.85558319 (25.68837130), SSIM 0.77456343 (0.77014681)
# Finished training epoch 44
# Validate: MSE 0.00308727 (0.00269940), PSNR 25.10424995 (25.76454170), SSIM 0.70964581 (0.77715996)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00229358 (0.00270638), PSNR 26.39486694 (25.69967912), SSIM 0.76465130 (0.77021115)
# Finished training epoch 45
# Validate: MSE 0.00314356 (0.00270445), PSNR 25.02577400 (25.75231372), SSIM 0.70958000 (0.77660666)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00295712 (0.00270191), PSNR 25.29131317 (25.70561457), SSIM 0.75397855 (0.77007084)
# Finished training epoch 46
# Validate: MSE 0.00298352 (0.00268255), PSNR 25.25271034 (25.79228388), SSIM 0.70822984 (0.77562507)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00234140 (0.00268527), PSNR 26.30524063 (25.73313540), SSIM 0.78643423 (0.76957373)
# Finished training epoch 47
# Validate: MSE 0.00298482 (0.00266215), PSNR 25.25081062 (25.82521165), SSIM 0.70852774 (0.77578271)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00247057 (0.00267940), PSNR 26.07203293 (25.74426120), SSIM 0.79121059 (0.76936982)
# Finished training epoch 48
# Validate: MSE 0.00301835 (0.00266065), PSNR 25.20230484 (25.82551534), SSIM 0.70958424 (0.77721283)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00208025 (0.00266238), PSNR 26.81885147 (25.77186939), SSIM 0.79190242 (0.76852215)
# Finished training epoch 49
# Validate: MSE 0.00292054 (0.00263938), PSNR 25.34536171 (25.86053073), SSIM 0.70612794 (0.77310896)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00201717 (0.00265386), PSNR 26.95257950 (25.78375757), SSIM 0.77846879 (0.76817756)
# Finished training epoch 50
# Validate: MSE 0.00301328 (0.00263394), PSNR 25.20960236 (25.86577728), SSIM 0.70715666 (0.77499238)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00334249 (0.00263906), PSNR 24.75929642 (25.80649714), SSIM 0.74761951 (0.76753259)
# Finished training epoch 51
# Validate: MSE 0.00294126 (0.00261407), PSNR 25.31466866 (25.90134036), SSIM 0.70617902 (0.77359138)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00230841 (0.00262382), PSNR 26.36687469 (25.83483121), SSIM 0.76917851 (0.76673250)
# Finished training epoch 52
# Validate: MSE 0.00293777 (0.00259563), PSNR 25.31981850 (25.93050761), SSIM 0.70688879 (0.77437998)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00239571 (0.00261088), PSNR 26.20565033 (25.85403590), SSIM 0.75621754 (0.76614783)
# Finished training epoch 53
# Validate: MSE 0.00297809 (0.00258992), PSNR 25.26062775 (25.93738458), SSIM 0.70655096 (0.77317284)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00284530 (0.00260037), PSNR 25.45872498 (25.87275594), SSIM 0.76239413 (0.76573537)
# Finished training epoch 54
# Validate: MSE 0.00292465 (0.00257711), PSNR 25.33925819 (25.95791337), SSIM 0.70697325 (0.77221177)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00289221 (0.00259502), PSNR 25.38770485 (25.88168173), SSIM 0.76603490 (0.76537703)
# Finished training epoch 55
# Validate: MSE 0.00295376 (0.00257116), PSNR 25.29624939 (25.96870796), SSIM 0.70750201 (0.77365744)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00203404 (0.00258787), PSNR 26.91639709 (25.89252288), SSIM 0.78480124 (0.76511165)
# Finished training epoch 56
# Validate: MSE 0.00293220 (0.00259091), PSNR 25.32805824 (25.93818656), SSIM 0.70998830 (0.77658812)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00248252 (0.00257530), PSNR 26.05106735 (25.91490551), SSIM 0.75344425 (0.76488087)
# Finished training epoch 57
# Validate: MSE 0.00299026 (0.00256045), PSNR 25.24290466 (25.98291995), SSIM 0.70602745 (0.77084553)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00199482 (0.00257143), PSNR 27.00096321 (25.92204483), SSIM 0.76714212 (0.76472930)
# Finished training epoch 58
# Validate: MSE 0.00293580 (0.00254803), PSNR 25.32273865 (26.00514675), SSIM 0.70731020 (0.77219127)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00241582 (0.00256991), PSNR 26.16934776 (25.92352528), SSIM 0.77291507 (0.76446170)
# Finished training epoch 59
# Validate: MSE 0.00292367 (0.00255346), PSNR 25.34072113 (25.99351073), SSIM 0.70317173 (0.76582611)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00227564 (0.00256009), PSNR 26.42896652 (25.94061686), SSIM 0.76620930 (0.76466864)
# Finished training epoch 60
# Validate: MSE 0.00299092 (0.00256525), PSNR 25.24195480 (25.97591328), SSIM 0.70776576 (0.77086612)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00376656 (0.00255198), PSNR 24.24054718 (25.95366472), SSIM 0.72412831 (0.76470643)
# Finished training epoch 61
# Validate: MSE 0.00295399 (0.00253800), PSNR 25.29590607 (26.01862931), SSIM 0.70388567 (0.76782698)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00354556 (0.00255298), PSNR 24.50314713 (25.95129493), SSIM 0.71935976 (0.76457838)
# Finished training epoch 62
# Validate: MSE 0.00294927 (0.00253405), PSNR 25.30286026 (26.02529485), SSIM 0.70318097 (0.76725309)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00240451 (0.00254522), PSNR 26.18973541 (25.96659975), SSIM 0.76193511 (0.76447244)
# Finished training epoch 63
# Validate: MSE 0.00287744 (0.00252400), PSNR 25.40993690 (26.04346349), SSIM 0.70714140 (0.77012695)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00281765 (0.00254598), PSNR 25.50113487 (25.96306793), SSIM 0.75989729 (0.76437189)
# Finished training epoch 64
# Validate: MSE 0.00293289 (0.00251845), PSNR 25.32703972 (26.05211377), SSIM 0.70693481 (0.77041064)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00211287 (0.00254810), PSNR 26.75127220 (25.96156936), SSIM 0.79171628 (0.76428509)
# Finished training epoch 65
# Validate: MSE 0.00294105 (0.00252180), PSNR 25.31497192 (26.04679944), SSIM 0.70738935 (0.77070482)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00283641 (0.00253806), PSNR 25.47230530 (25.97955452), SSIM 0.75343144 (0.76451978)
# Finished training epoch 66
# Validate: MSE 0.00295901 (0.00252334), PSNR 25.28853989 (26.04505742), SSIM 0.70714360 (0.77097108)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00284848 (0.00252682), PSNR 25.45387077 (25.99622764), SSIM 0.74967653 (0.76473948)
# Finished training epoch 67
# Validate: MSE 0.00292675 (0.00250420), PSNR 25.33613968 (26.07732957), SSIM 0.70803416 (0.77149893)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00255655 (0.00253211), PSNR 25.92344856 (25.98697582), SSIM 0.73736274 (0.76445909)
# Finished training epoch 68
# Validate: MSE 0.00289624 (0.00250781), PSNR 25.38165665 (26.06995145), SSIM 0.70589125 (0.77113676)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00281710 (0.00253415), PSNR 25.50197029 (25.98524598), SSIM 0.75803697 (0.76453319)
# Finished training epoch 69
# Validate: MSE 0.00294050 (0.00250127), PSNR 25.31578827 (26.08326437), SSIM 0.70661366 (0.77279111)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00247759 (0.00252547), PSNR 26.05970573 (26.00380887), SSIM 0.78417218 (0.76510994)
# Finished training epoch 70
# Validate: MSE 0.00293938 (0.00250779), PSNR 25.31744957 (26.07066041), SSIM 0.70739621 (0.77298665)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00244952 (0.00253215), PSNR 26.10919189 (25.98731691), SSIM 0.77538222 (0.76486342)
# Finished training epoch 71
# Validate: MSE 0.00302926 (0.00252054), PSNR 25.18663597 (26.04984361), SSIM 0.70856315 (0.77137288)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00274525 (0.00252026), PSNR 25.61417770 (26.01007897), SSIM 0.77111399 (0.76505042)
# Finished training epoch 72
# Validate: MSE 0.00290329 (0.00249539), PSNR 25.37109184 (26.09124668), SSIM 0.70649850 (0.76936495)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00254507 (0.00251826), PSNR 25.94300461 (26.01259007), SSIM 0.76117170 (0.76505565)
# Finished training epoch 73
# Validate: MSE 0.00288816 (0.00249516), PSNR 25.39378738 (26.09034688), SSIM 0.70361817 (0.76852620)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00241086 (0.00251819), PSNR 26.17827606 (26.01141524), SSIM 0.76743186 (0.76526229)
# Finished training epoch 74
# Validate: MSE 0.00300107 (0.00252148), PSNR 25.22723389 (26.04792419), SSIM 0.70596427 (0.77056970)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00294641 (0.00251648), PSNR 25.30706024 (26.01586440), SSIM 0.75785959 (0.76522268)
# Finished training epoch 75
# Validate: MSE 0.00289827 (0.00248629), PSNR 25.37861252 (26.10777014), SSIM 0.71042210 (0.77350149)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00279614 (0.00251345), PSNR 25.53440857 (26.02000267), SSIM 0.76567745 (0.76525267)
# Finished training epoch 76
# Validate: MSE 0.00299852 (0.00249671), PSNR 25.23093605 (26.09000407), SSIM 0.70770490 (0.77253196)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00246824 (0.00251075), PSNR 26.07612610 (26.02659250), SSIM 0.76355612 (0.76533724)
# Finished training epoch 77
# Validate: MSE 0.00295131 (0.00249682), PSNR 25.29984856 (26.08808759), SSIM 0.70823681 (0.77241879)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00303510 (0.00250719), PSNR 25.17826080 (26.02975587), SSIM 0.76658297 (0.76551913)
# Finished training epoch 78
# Validate: MSE 0.00288493 (0.00248139), PSNR 25.39864349 (26.11535245), SSIM 0.70901668 (0.77129301)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00208837 (0.00250726), PSNR 26.80193520 (26.03103049), SSIM 0.78777778 (0.76548291)
# Finished training epoch 79
# Validate: MSE 0.00291407 (0.00247418), PSNR 25.35499191 (26.12892065), SSIM 0.70910591 (0.77389948)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00221953 (0.00250899), PSNR 26.53739548 (26.02960250), SSIM 0.79078215 (0.76545651)
# Finished training epoch 80
# Validate: MSE 0.00296736 (0.00249202), PSNR 25.27629089 (26.09829102), SSIM 0.70838058 (0.77197908)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00217030 (0.00250286), PSNR 26.63480377 (26.03980096), SSIM 0.79972494 (0.76563276)
# Finished training epoch 81
# Validate: MSE 0.00291121 (0.00247111), PSNR 25.35926247 (26.13449931), SSIM 0.71059197 (0.77445056)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00315104 (0.00250467), PSNR 25.01546097 (26.03385532), SSIM 0.75163090 (0.76567632)
# Finished training epoch 82
# Validate: MSE 0.00300131 (0.00248718), PSNR 25.22689056 (26.10737596), SSIM 0.70921624 (0.77506848)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00261383 (0.00250621), PSNR 25.82722092 (26.03407902), SSIM 0.75321275 (0.76537567)
# Finished training epoch 83
# Validate: MSE 0.00285381 (0.00247191), PSNR 25.44575310 (26.12873322), SSIM 0.70733321 (0.76873462)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00247709 (0.00249684), PSNR 26.06057930 (26.04479018), SSIM 0.75289118 (0.76566326)
# Finished training epoch 84
# Validate: MSE 0.00285850 (0.00249041), PSNR 25.43862152 (26.09622848), SSIM 0.70429277 (0.76527458)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00225446 (0.00249397), PSNR 26.46957207 (26.05384976), SSIM 0.77793378 (0.76570544)
# Finished training epoch 85
# Validate: MSE 0.00292849 (0.00246574), PSNR 25.33356476 (26.14549398), SSIM 0.71236062 (0.77591140)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00257346 (0.00249181), PSNR 25.89483070 (26.05701290), SSIM 0.74977177 (0.76580040)
# Finished training epoch 86
# Validate: MSE 0.00296276 (0.00247181), PSNR 25.28303909 (26.13268519), SSIM 0.70807970 (0.77362464)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00234768 (0.00249110), PSNR 26.29361916 (26.05625522), SSIM 0.74488819 (0.76587155)
# Finished training epoch 87
# Validate: MSE 0.00285779 (0.00245960), PSNR 25.43969154 (26.15179904), SSIM 0.70744520 (0.77149213)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00288772 (0.00249478), PSNR 25.39444160 (26.05476335), SSIM 0.76519412 (0.76589969)
# Finished training epoch 88
# Validate: MSE 0.00288575 (0.00245472), PSNR 25.39741135 (26.16090099), SSIM 0.70984423 (0.77237570)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00254503 (0.00248826), PSNR 25.94307137 (26.06109518), SSIM 0.77450144 (0.76605518)
# Finished training epoch 89
# Validate: MSE 0.00294186 (0.00246888), PSNR 25.31377983 (26.13811765), SSIM 0.70618951 (0.77385943)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00270991 (0.00248591), PSNR 25.67044640 (26.06837488), SSIM 0.75659138 (0.76621256)
# Finished training epoch 90
# Validate: MSE 0.00296006 (0.00248224), PSNR 25.28698730 (26.11450776), SSIM 0.70696372 (0.77064252)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00229723 (0.00247757), PSNR 26.38795280 (26.08136859), SSIM 0.77940673 (0.76617164)
# Finished training epoch 91
# Validate: MSE 0.00295243 (0.00246942), PSNR 25.29819870 (26.13522975), SSIM 0.70928836 (0.77192303)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00224138 (0.00248699), PSNR 26.49485016 (26.06393666), SSIM 0.76761502 (0.76590773)
# Finished training epoch 92
# Validate: MSE 0.00285208 (0.00245802), PSNR 25.44838333 (26.15379327), SSIM 0.70707834 (0.76844352)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00297783 (0.00248529), PSNR 25.26100349 (26.06533263), SSIM 0.74034607 (0.76609172)
# Finished training epoch 93
# Validate: MSE 0.00286996 (0.00245578), PSNR 25.42123795 (26.16039874), SSIM 0.70974028 (0.77417257)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00242516 (0.00248079), PSNR 26.15259171 (26.07677799), SSIM 0.77290261 (0.76634601)
# Finished training epoch 94
# Validate: MSE 0.00288510 (0.00244593), PSNR 25.39838982 (26.17744160), SSIM 0.70898181 (0.77465615)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00251180 (0.00247830), PSNR 26.00014877 (26.08192235), SSIM 0.75911027 (0.76626639)
# Finished training epoch 95
# Validate: MSE 0.00290371 (0.00244800), PSNR 25.37046623 (26.17186831), SSIM 0.70715427 (0.77074381)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00216237 (0.00248153), PSNR 26.65069580 (26.07793084), SSIM 0.76745927 (0.76631182)
# Finished training epoch 96
# Validate: MSE 0.00294676 (0.00248015), PSNR 25.30655098 (26.11728748), SSIM 0.70684993 (0.76942324)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00237201 (0.00248488), PSNR 26.24884033 (26.06652630), SSIM 0.77286804 (0.76624154)
# Finished training epoch 97
# Validate: MSE 0.00287019 (0.00244045), PSNR 25.42090034 (26.18591834), SSIM 0.70833778 (0.77106927)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00197446 (0.00247958), PSNR 27.04551888 (26.07887740), SSIM 0.75403655 (0.76643976)
# Finished training epoch 98
# Validate: MSE 0.00287663 (0.00244063), PSNR 25.41115570 (26.18685883), SSIM 0.70910323 (0.77426596)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00236169 (0.00247837), PSNR 26.26777649 (26.07807953), SSIM 0.77781588 (0.76637106)
# Finished training epoch 99
# Validate: MSE 0.00283673 (0.00244561), PSNR 25.47182465 (26.17695287), SSIM 0.70810556 (0.77215708)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00270925 (0.00247527), PSNR 25.67150307 (26.08624536), SSIM 0.75784284 (0.76660439)
# Finished training epoch 100
# Validate: MSE 0.00289331 (0.00244503), PSNR 25.38604546 (26.18025000), SSIM 0.70979178 (0.77619510)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00244839 (0.00247274), PSNR 26.11120033 (26.09093781), SSIM 0.75945270 (0.76640856)
# Finished training epoch 101
# Validate: MSE 0.00289823 (0.00243852), PSNR 25.37867737 (26.19115840), SSIM 0.70990527 (0.77447412)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00251763 (0.00247028), PSNR 25.99007797 (26.09859034), SSIM 0.75761920 (0.76668604)
# Finished training epoch 102
# Validate: MSE 0.00288055 (0.00244218), PSNR 25.40524864 (26.18225499), SSIM 0.70637429 (0.77059613)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00273596 (0.00246367), PSNR 25.62889671 (26.10607699), SSIM 0.75283617 (0.76675640)
# Finished training epoch 103
# Validate: MSE 0.00286213 (0.00244645), PSNR 25.43310547 (26.17859490), SSIM 0.71181798 (0.77720784)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00242838 (0.00247327), PSNR 26.14682388 (26.08965514), SSIM 0.76840484 (0.76654902)
# Finished training epoch 104
# Validate: MSE 0.00290810 (0.00243924), PSNR 25.36389923 (26.19016012), SSIM 0.70942557 (0.77545471)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00254087 (0.00246856), PSNR 25.95017052 (26.09836682), SSIM 0.77177298 (0.76679615)
# Finished training epoch 105
# Validate: MSE 0.00289577 (0.00243392), PSNR 25.38236237 (26.19945780), SSIM 0.70984709 (0.77332863)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00278071 (0.00246404), PSNR 25.55844116 (26.10659512), SSIM 0.75421411 (0.76712174)
# Finished training epoch 106
# Validate: MSE 0.00283903 (0.00244353), PSNR 25.46829414 (26.18237928), SSIM 0.71054363 (0.77438352)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00244179 (0.00246046), PSNR 26.12291145 (26.11697617), SSIM 0.76000899 (0.76701663)
# Finished training epoch 107
# Validate: MSE 0.00283778 (0.00243332), PSNR 25.47021103 (26.19899384), SSIM 0.71172118 (0.77205458)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00242594 (0.00247182), PSNR 26.15120697 (26.09082919), SSIM 0.76542634 (0.76693581)
# Finished training epoch 108
# Validate: MSE 0.00288969 (0.00244780), PSNR 25.39149094 (26.17413229), SSIM 0.71095181 (0.77138732)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00280062 (0.00246635), PSNR 25.52745438 (26.10195561), SSIM 0.74825418 (0.76716612)
# Finished training epoch 109
# Validate: MSE 0.00287859 (0.00242794), PSNR 25.40819740 (26.20934438), SSIM 0.71025372 (0.77205845)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00236985 (0.00247135), PSNR 26.25278091 (26.09418963), SSIM 0.76429284 (0.76680554)
# Finished training epoch 110
# Validate: MSE 0.00289511 (0.00242659), PSNR 25.38334846 (26.21339954), SSIM 0.71157086 (0.77671028)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00203258 (0.00246149), PSNR 26.91951752 (26.10851671), SSIM 0.77392817 (0.76698589)
# Finished training epoch 111
# Validate: MSE 0.00293599 (0.00245454), PSNR 25.32245255 (26.16467037), SSIM 0.71126366 (0.77500193)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00205545 (0.00246120), PSNR 26.87092781 (26.11114522), SSIM 0.76713890 (0.76705363)
# Finished training epoch 112
# Validate: MSE 0.00290162 (0.00244731), PSNR 25.37359428 (26.17518969), SSIM 0.71018744 (0.77204908)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00207415 (0.00245937), PSNR 26.83159828 (26.11427878), SSIM 0.76476920 (0.76707649)
# Finished training epoch 113
# Validate: MSE 0.00284999 (0.00242873), PSNR 25.45155907 (26.20834176), SSIM 0.71136379 (0.77540505)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00206570 (0.00245733), PSNR 26.84931946 (26.11860753), SSIM 0.78401703 (0.76713625)
# Finished training epoch 114
# Validate: MSE 0.00295984 (0.00244824), PSNR 25.28731155 (26.17407322), SSIM 0.70859838 (0.77283590)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00232032 (0.00245836), PSNR 26.34451675 (26.11887401), SSIM 0.76914203 (0.76726997)
# Finished training epoch 115
# Validate: MSE 0.00286122 (0.00243964), PSNR 25.43448448 (26.18847957), SSIM 0.71086347 (0.77298489)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00274065 (0.00246232), PSNR 25.62146568 (26.10833017), SSIM 0.75773543 (0.76717383)
# Finished training epoch 116
# Validate: MSE 0.00291878 (0.00242817), PSNR 25.34799194 (26.21061096), SSIM 0.71153855 (0.77654930)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00236407 (0.00246575), PSNR 26.26339149 (26.10284694), SSIM 0.77911431 (0.76697638)
# Finished training epoch 117
# Validate: MSE 0.00285517 (0.00243031), PSNR 25.44367790 (26.20373308), SSIM 0.71113646 (0.77194949)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00229602 (0.00244878), PSNR 26.39023590 (26.13365686), SSIM 0.78490084 (0.76756271)
# Finished training epoch 118
# Validate: MSE 0.00293015 (0.00245725), PSNR 25.33109474 (26.16083756), SSIM 0.71332699 (0.77884744)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00234048 (0.00246144), PSNR 26.30695724 (26.11006819), SSIM 0.77581561 (0.76741376)
# Finished training epoch 119
# Validate: MSE 0.00287224 (0.00241730), PSNR 25.41778755 (26.23038240), SSIM 0.71215606 (0.77585650)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00294667 (0.00245304), PSNR 25.30668259 (26.12498110), SSIM 0.75871438 (0.76731975)
# Finished training epoch 120
# Validate: MSE 0.00286568 (0.00242171), PSNR 25.42772293 (26.21843194), SSIM 0.70732176 (0.77209305)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00218995 (0.00245567), PSNR 26.59565735 (26.12404433), SSIM 0.76148224 (0.76739127)
# Finished training epoch 121
# Validate: MSE 0.00282830 (0.00241426), PSNR 25.48474884 (26.23488925), SSIM 0.71313334 (0.77573179)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00242794 (0.00245520), PSNR 26.14762115 (26.12269351), SSIM 0.78043622 (0.76763264)
# Finished training epoch 122
# Validate: MSE 0.00285086 (0.00245052), PSNR 25.45023918 (26.17027351), SSIM 0.71070188 (0.77122953)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00219203 (0.00245388), PSNR 26.59153366 (26.12536056), SSIM 0.77721250 (0.76757756)
# Finished training epoch 123
# Validate: MSE 0.00284351 (0.00240926), PSNR 25.46144676 (26.24302962), SSIM 0.71154773 (0.77482889)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00219199 (0.00245402), PSNR 26.59162331 (26.12442597), SSIM 0.79161346 (0.76750873)
# Finished training epoch 124
# Validate: MSE 0.00290297 (0.00242402), PSNR 25.37157631 (26.21952873), SSIM 0.71301651 (0.77896699)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00306204 (0.00245477), PSNR 25.13988686 (26.12334682), SSIM 0.74649221 (0.76761460)
# Finished training epoch 125
# Validate: MSE 0.00277764 (0.00241217), PSNR 25.56323624 (26.23583760), SSIM 0.71130502 (0.77247934)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00267248 (0.00245093), PSNR 25.73085213 (26.12773891), SSIM 0.75106698 (0.76755221)
# Finished training epoch 126
# Validate: MSE 0.00284115 (0.00241513), PSNR 25.46505356 (26.23362236), SSIM 0.71153969 (0.77450321)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00297406 (0.00244537), PSNR 25.26649475 (26.14023966), SSIM 0.76163846 (0.76775215)
# Finished training epoch 127
# Validate: MSE 0.00287685 (0.00245603), PSNR 25.41082954 (26.16331717), SSIM 0.71221232 (0.77932825)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00278900 (0.00245215), PSNR 25.54550743 (26.12792016), SSIM 0.75642073 (0.76761344)
# Finished training epoch 128
# Validate: MSE 0.00285118 (0.00242209), PSNR 25.44974899 (26.21929697), SSIM 0.70880949 (0.77281114)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00212357 (0.00245053), PSNR 26.72933006 (26.13216089), SSIM 0.77826655 (0.76768545)
# Finished training epoch 129
# Validate: MSE 0.00282566 (0.00242030), PSNR 25.48880196 (26.22224104), SSIM 0.71028268 (0.77253742)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00298587 (0.00244425), PSNR 25.24928474 (26.14137089), SSIM 0.73455793 (0.76770553)
# Finished training epoch 130
# Validate: MSE 0.00284073 (0.00241259), PSNR 25.46569252 (26.23420695), SSIM 0.70843816 (0.77016376)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00237598 (0.00244613), PSNR 26.24156952 (26.13578512), SSIM 0.77657354 (0.76783793)
# Finished training epoch 131
# Validate: MSE 0.00276751 (0.00240870), PSNR 25.57910156 (26.24096895), SSIM 0.71097469 (0.77221038)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00308564 (0.00244808), PSNR 25.10654831 (26.13428110), SSIM 0.74482113 (0.76781330)
# Finished training epoch 132
# Validate: MSE 0.00277020 (0.00241170), PSNR 25.57488251 (26.23720101), SSIM 0.70951533 (0.77424267)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00228301 (0.00243958), PSNR 26.41492081 (26.14946818), SSIM 0.78071898 (0.76799508)
# Finished training epoch 133
# Validate: MSE 0.00279212 (0.00240600), PSNR 25.54066467 (26.24802056), SSIM 0.71215510 (0.77554007)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00297349 (0.00244315), PSNR 25.26733398 (26.14181425), SSIM 0.73384583 (0.76805386)
# Finished training epoch 134
# Validate: MSE 0.00281887 (0.00240071), PSNR 25.49925423 (26.25795952), SSIM 0.71225393 (0.77498209)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00221568 (0.00243964), PSNR 26.54493332 (26.14732137), SSIM 0.77686453 (0.76810441)
# Finished training epoch 135
# Validate: MSE 0.00282014 (0.00242426), PSNR 25.49728966 (26.21456339), SSIM 0.71041143 (0.77088513)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00248004 (0.00244353), PSNR 26.05541039 (26.14289956), SSIM 0.78769964 (0.76793825)
# Finished training epoch 136
# Validate: MSE 0.00283097 (0.00241800), PSNR 25.48065376 (26.22718658), SSIM 0.71218872 (0.77284335)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00255765 (0.00243395), PSNR 25.92157936 (26.15958019), SSIM 0.77138388 (0.76809306)
# Finished training epoch 137
# Validate: MSE 0.00278912 (0.00240577), PSNR 25.54532433 (26.24862118), SSIM 0.71059012 (0.77479219)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00215916 (0.00244274), PSNR 26.65715790 (26.14300437), SSIM 0.76925170 (0.76812902)
# Finished training epoch 138
# Validate: MSE 0.00275137 (0.00241095), PSNR 25.60450172 (26.23686378), SSIM 0.71298206 (0.77354307)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00250016 (0.00244818), PSNR 26.02031326 (26.13523617), SSIM 0.73977578 (0.76777150)
# Finished training epoch 139
# Validate: MSE 0.00282787 (0.00241386), PSNR 25.48539734 (26.23457852), SSIM 0.71028924 (0.77280581)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00249959 (0.00244270), PSNR 26.02131081 (26.14212643), SSIM 0.76290071 (0.76793028)
# Finished training epoch 140
# Validate: MSE 0.00287860 (0.00241519), PSNR 25.40818214 (26.23319679), SSIM 0.71383405 (0.77729546)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00253575 (0.00244507), PSNR 25.95893478 (26.14049961), SSIM 0.75600851 (0.76804176)
# Finished training epoch 141
# Validate: MSE 0.00280703 (0.00241263), PSNR 25.51753235 (26.23585107), SSIM 0.71267563 (0.77420523)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00192296 (0.00243066), PSNR 27.16029549 (26.16508948), SSIM 0.77723283 (0.76832966)
# Finished training epoch 142
# Validate: MSE 0.00281594 (0.00239994), PSNR 25.50376320 (26.25978551), SSIM 0.71389687 (0.77500007)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00269766 (0.00243237), PSNR 25.69012833 (26.16123086), SSIM 0.75422513 (0.76849728)
# Finished training epoch 143
# Validate: MSE 0.00286762 (0.00241802), PSNR 25.42477798 (26.22865406), SSIM 0.71181476 (0.77490971)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00188973 (0.00244026), PSNR 27.23600960 (26.14936466), SSIM 0.78453946 (0.76821506)
# Finished training epoch 144
# Validate: MSE 0.00293041 (0.00241738), PSNR 25.33071899 (26.22981216), SSIM 0.71303606 (0.77573512)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00244159 (0.00243291), PSNR 26.12326241 (26.16052028), SSIM 0.76513547 (0.76838938)
# Finished training epoch 145
# Validate: MSE 0.00282410 (0.00240401), PSNR 25.49119759 (26.25208501), SSIM 0.71301115 (0.77602366)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00268366 (0.00243946), PSNR 25.71273232 (26.14662442), SSIM 0.76231682 (0.76819516)
# Finished training epoch 146
# Validate: MSE 0.00285711 (0.00241327), PSNR 25.44072342 (26.23637859), SSIM 0.71460390 (0.77701880)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00252624 (0.00243346), PSNR 25.97524834 (26.15986922), SSIM 0.77781689 (0.76863349)
# Finished training epoch 147
# Validate: MSE 0.00281247 (0.00239547), PSNR 25.50912476 (26.26803740), SSIM 0.71341658 (0.77634225)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00266380 (0.00243130), PSNR 25.74498558 (26.16546816), SSIM 0.76952159 (0.76831890)
# Finished training epoch 148
# Validate: MSE 0.00287869 (0.00241432), PSNR 25.40804291 (26.23555560), SSIM 0.71437013 (0.77837082)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00193754 (0.00243866), PSNR 27.12749863 (26.15219047), SSIM 0.79407513 (0.76837832)
# Finished training epoch 149
# Validate: MSE 0.00285914 (0.00241355), PSNR 25.43764877 (26.23524543), SSIM 0.71198350 (0.77800937)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00233983 (0.00243131), PSNR 26.30815697 (26.16540809), SSIM 0.77309126 (0.76862504)
# Finished training epoch 150
# Validate: MSE 0.00279958 (0.00240369), PSNR 25.52907181 (26.25056988), SSIM 0.71009833 (0.77348758)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00212588 (0.00243163), PSNR 26.72460365 (26.16430801), SSIM 0.76144183 (0.76851134)
# Finished training epoch 151
# Validate: MSE 0.00289737 (0.00240358), PSNR 25.37995529 (26.25452509), SSIM 0.71323693 (0.77678447)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00267537 (0.00243354), PSNR 25.72615814 (26.16273300), SSIM 0.73397112 (0.76852986)
# Finished training epoch 152
# Validate: MSE 0.00276889 (0.00239259), PSNR 25.57693672 (26.27084095), SSIM 0.71054912 (0.77445946)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00196961 (0.00242747), PSNR 27.05618668 (26.17223301), SSIM 0.78526098 (0.76861090)
# Finished training epoch 153
# Validate: MSE 0.00278517 (0.00240147), PSNR 25.55148315 (26.25724407), SSIM 0.71473503 (0.77811633)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00188078 (0.00243522), PSNR 27.25661850 (26.15865854), SSIM 0.78897804 (0.76852804)
# Finished training epoch 154
# Validate: MSE 0.00284700 (0.00240536), PSNR 25.45612526 (26.25092602), SSIM 0.71334195 (0.77567214)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00256786 (0.00242738), PSNR 25.90427780 (26.17168433), SSIM 0.76655042 (0.76876176)
# Finished training epoch 155
# Validate: MSE 0.00284993 (0.00239295), PSNR 25.45165825 (26.27349558), SSIM 0.71212703 (0.77623053)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00260503 (0.00242914), PSNR 25.84187126 (26.17216346), SSIM 0.75544399 (0.76881082)
# Finished training epoch 156
# Validate: MSE 0.00285944 (0.00239678), PSNR 25.43718529 (26.26466685), SSIM 0.71010995 (0.77511161)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00307219 (0.00242969), PSNR 25.12552452 (26.16660007), SSIM 0.73066157 (0.76856628)
# Finished training epoch 157
# Validate: MSE 0.00274325 (0.00239199), PSNR 25.61734390 (26.27116658), SSIM 0.71217358 (0.77279215)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00209313 (0.00243078), PSNR 26.79203987 (26.17058554), SSIM 0.77603513 (0.76844738)
# Finished training epoch 158
# Validate: MSE 0.00290735 (0.00243423), PSNR 25.36501884 (26.20274467), SSIM 0.71560431 (0.77797975)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00268844 (0.00242736), PSNR 25.70499992 (26.17048972), SSIM 0.78549057 (0.76849184)
# Finished training epoch 159
# Validate: MSE 0.00280872 (0.00239695), PSNR 25.51491165 (26.26611663), SSIM 0.71392620 (0.77656940)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00255733 (0.00242432), PSNR 25.92213821 (26.18123036), SSIM 0.77054834 (0.76863953)
# Finished training epoch 160
# Validate: MSE 0.00290037 (0.00240863), PSNR 25.37546349 (26.24770606), SSIM 0.71390939 (0.77759839)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00232539 (0.00243480), PSNR 26.33503342 (26.15608960), SSIM 0.80052203 (0.76883723)
# Finished training epoch 161
# Validate: MSE 0.00281481 (0.00239743), PSNR 25.50551224 (26.26348333), SSIM 0.71210122 (0.77623973)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00213087 (0.00242696), PSNR 26.71443748 (26.17130932), SSIM 0.77518463 (0.76876232)
# Finished training epoch 162
# Validate: MSE 0.00284273 (0.00239082), PSNR 25.46264839 (26.27675298), SSIM 0.71356523 (0.77706149)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00193010 (0.00242924), PSNR 27.14420700 (26.16885057), SSIM 0.78081948 (0.76871831)
# Finished training epoch 163
# Validate: MSE 0.00279355 (0.00238569), PSNR 25.53843498 (26.28426606), SSIM 0.71098542 (0.77532144)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00219556 (0.00242810), PSNR 26.58455276 (26.17037797), SSIM 0.77335072 (0.76870564)
# Finished training epoch 164
# Validate: MSE 0.00277959 (0.00242012), PSNR 25.56019592 (26.22262778), SSIM 0.70911598 (0.77037305)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00220850 (0.00242099), PSNR 26.55902863 (26.18296878), SSIM 0.75074452 (0.76873697)
# Finished training epoch 165
# Validate: MSE 0.00286036 (0.00239582), PSNR 25.43579865 (26.26867743), SSIM 0.71233165 (0.77563342)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00279493 (0.00242350), PSNR 25.53628731 (26.17576478), SSIM 0.76900017 (0.76876254)
# Finished training epoch 166
# Validate: MSE 0.00285589 (0.00240121), PSNR 25.44258118 (26.26059172), SSIM 0.71583915 (0.77793541)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00243614 (0.00242644), PSNR 26.13298225 (26.17045109), SSIM 0.77181256 (0.76894284)
# Finished training epoch 167
# Validate: MSE 0.00288375 (0.00238982), PSNR 25.40042877 (26.28034906), SSIM 0.71455228 (0.77751891)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00314386 (0.00242509), PSNR 25.02536774 (26.17746513), SSIM 0.77261364 (0.76883911)
# Finished training epoch 168
# Validate: MSE 0.00282954 (0.00238531), PSNR 25.48284340 (26.28731725), SSIM 0.71458602 (0.77811084)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00289071 (0.00243256), PSNR 25.38994598 (26.16559347), SSIM 0.74288785 (0.76871400)
# Finished training epoch 169
# Validate: MSE 0.00281268 (0.00239847), PSNR 25.50878906 (26.26311729), SSIM 0.71383625 (0.77649774)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00245598 (0.00242373), PSNR 26.09775162 (26.17755899), SSIM 0.77988493 (0.76891596)
# Finished training epoch 170
# Validate: MSE 0.00280926 (0.00238682), PSNR 25.51408768 (26.28383463), SSIM 0.71365297 (0.77649541)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00273560 (0.00242088), PSNR 25.62947845 (26.18274447), SSIM 0.76961982 (0.76905312)
# Finished training epoch 171
# Validate: MSE 0.00282299 (0.00238905), PSNR 25.49290848 (26.28011453), SSIM 0.71216309 (0.77588615)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00239203 (0.00242309), PSNR 26.21232986 (26.17818491), SSIM 0.75214273 (0.76908441)
# Finished training epoch 172
# Validate: MSE 0.00288344 (0.00241035), PSNR 25.40089798 (26.24407984), SSIM 0.71171576 (0.77687798)
# Finished validation.
# Starting training epoch 173
# ...
# Finished validation.
# Starting training epoch 410
# Epoch: 410, MSE 0.00217431 (0.00237232), PSNR 26.62678146 (26.27236964), SSIM 0.75894147 (0.77167962)
# Finished training epoch 410
# Validate: MSE 0.00267338 (0.00233124), PSNR 25.72939110 (26.38274107), SSIM 0.71672207 (0.77710562)
# Finished validation.
# Starting training epoch 411
# Epoch: 411, MSE 0.00241115 (0.00237108), PSNR 26.17775154 (26.27436841), SSIM 0.77074564 (0.77174364)
# Finished training epoch 411
# Validate: MSE 0.00271355 (0.00233415), PSNR 25.66462517 (26.38111704), SSIM 0.71990335 (0.77976571)
# Finished validation.
# Starting training epoch 412
# Epoch: 412, MSE 0.00185153 (0.00236650), PSNR 27.32468414 (26.28236122), SSIM 0.78151560 (0.77196847)
# Finished training epoch 412
# Validate: MSE 0.00264035 (0.00234670), PSNR 25.78338623 (26.35239177), SSIM 0.71827555 (0.77776851)
# Finished validation.
# Starting training epoch 413
# Epoch: 413, MSE 0.00248650 (0.00236565), PSNR 26.04411125 (26.28163149), SSIM 0.75993884 (0.77194378)
# Finished training epoch 413
# Validate: MSE 0.00272176 (0.00232664), PSNR 25.65150452 (26.39181025), SSIM 0.71636772 (0.77815277)
# Finished validation.
# Starting training epoch 414
# Epoch: 414, MSE 0.00223014 (0.00236680), PSNR 26.51667213 (26.28342068), SSIM 0.77697003 (0.77193449)
# Finished training epoch 414
# Validate: MSE 0.00276153 (0.00233661), PSNR 25.58850670 (26.37703431), SSIM 0.71891516 (0.78155761)
# Finished validation.
# Starting training epoch 415
# Epoch: 415, MSE 0.00224790 (0.00237055), PSNR 26.48222733 (26.27507224), SSIM 0.76769346 (0.77167960)
# Finished training epoch 415
# Validate: MSE 0.00267844 (0.00232505), PSNR 25.72118378 (26.39521332), SSIM 0.72041953 (0.77837026)
# Finished validation.
# Starting training epoch 416
# Epoch: 416, MSE 0.00229014 (0.00236570), PSNR 26.40138626 (26.28284980), SSIM 0.78776920 (0.77170547)
# Finished training epoch 416
# Validate: MSE 0.00269147 (0.00232006), PSNR 25.70010757 (26.40482596), SSIM 0.71964419 (0.77847361)
# Finished validation.
# Starting training epoch 417
# Epoch: 417, MSE 0.00226103 (0.00237037), PSNR 26.45693779 (26.27437839), SSIM 0.78152728 (0.77180689)
# Finished training epoch 417
# Validate: MSE 0.00270200 (0.00234772), PSNR 25.68313789 (26.35342171), SSIM 0.71843320 (0.78115237)
# Finished validation.
# Starting training epoch 418
# Epoch: 418, MSE 0.00211440 (0.00237315), PSNR 26.74812317 (26.26764427), SSIM 0.77327776 (0.77155796)
# Finished training epoch 418
# Validate: MSE 0.00271725 (0.00232983), PSNR 25.65869904 (26.38818488), SSIM 0.71960306 (0.78161968)
# Finished validation.
# Starting training epoch 419
# Epoch: 419, MSE 0.00217612 (0.00237468), PSNR 26.62317848 (26.26714180), SSIM 0.77660763 (0.77170218)
# Finished training epoch 419
# Validate: MSE 0.00273272 (0.00235005), PSNR 25.63405228 (26.35131978), SSIM 0.71747220 (0.77828188)
# Finished validation.
# Starting training epoch 420
# Epoch: 420, MSE 0.00270992 (0.00237055), PSNR 25.67044258 (26.27551691), SSIM 0.77373743 (0.77161709)
# Finished training epoch 420
# Validate: MSE 0.00273529 (0.00233207), PSNR 25.62997055 (26.38279858), SSIM 0.71899712 (0.77953300)
# Finished validation.
# Starting training epoch 421
# Epoch: 421, MSE 0.00227042 (0.00236003), PSNR 26.43893433 (26.29365381), SSIM 0.77757037 (0.77197878)
# Finished training epoch 421
# Validate: MSE 0.00273260 (0.00232675), PSNR 25.63423538 (26.39483770), SSIM 0.71868670 (0.77982141)
# Finished validation.
# Starting training epoch 422
# Epoch: 422, MSE 0.00261399 (0.00237554), PSNR 25.82696152 (26.26489914), SSIM 0.76744902 (0.77189167)
# Finished training epoch 422
# Validate: MSE 0.00271365 (0.00234452), PSNR 25.66446686 (26.35839496), SSIM 0.71822900 (0.78034450)
# Finished validation.
# Starting training epoch 423
# Epoch: 423, MSE 0.00247131 (0.00235816), PSNR 26.07073021 (26.30065956), SSIM 0.77868050 (0.77220908)
# Finished training epoch 423
# Validate: MSE 0.00284480 (0.00239939), PSNR 25.45948792 (26.26448303), SSIM 0.71892679 (0.77760370)
# Finished validation.
# Starting training epoch 424
# Epoch: 424, MSE 0.00305871 (0.00236962), PSNR 25.14462280 (26.27557596), SSIM 0.75844991 (0.77186382)
# Finished training epoch 424
# Validate: MSE 0.00272187 (0.00234810), PSNR 25.65132141 (26.35522844), SSIM 0.71934682 (0.77877807)
# Finished validation.
# Starting training epoch 425
# Epoch: 425, MSE 0.00232769 (0.00236503), PSNR 26.33074760 (26.28261056), SSIM 0.77589083 (0.77185962)
# Finished training epoch 425
# Validate: MSE 0.00267690 (0.00233986), PSNR 25.72367287 (26.36817755), SSIM 0.71769536 (0.77724213)
# Finished validation.
# Starting training epoch 426
# Epoch: 426, MSE 0.00296788 (0.00237004), PSNR 25.27553940 (26.27850647), SSIM 0.75026226 (0.77189814)
# Finished training epoch 426
# Validate: MSE 0.00273316 (0.00235511), PSNR 25.63334274 (26.33788488), SSIM 0.71499759 (0.77797461)
# Finished validation.
# Starting training epoch 427
# Epoch: 427, MSE 0.00198400 (0.00237222), PSNR 27.02457237 (26.27253120), SSIM 0.78718436 (0.77160795)
# Finished training epoch 427
# Validate: MSE 0.00272582 (0.00232874), PSNR 25.64502525 (26.38982953), SSIM 0.71898544 (0.78085008)
# Finished validation.
# Starting training epoch 428
# Epoch: 428, MSE 0.00219521 (0.00236695), PSNR 26.58524704 (26.28246176), SSIM 0.79872060 (0.77189724)
# Finished training epoch 428
# Validate: MSE 0.00285196 (0.00237641), PSNR 25.44857025 (26.30698390), SSIM 0.71970063 (0.78146669)
# Finished validation.
# Starting training epoch 429
# Epoch: 429, MSE 0.00222572 (0.00236963), PSNR 26.52528763 (26.27452450), SSIM 0.76774836 (0.77184017)
# Finished training epoch 429
# Validate: MSE 0.00275270 (0.00236427), PSNR 25.60240746 (26.32684176), SSIM 0.71772599 (0.77746053)
# Finished validation.
# Starting training epoch 430
# Epoch: 430, MSE 0.00201398 (0.00235579), PSNR 26.95944595 (26.30044005), SSIM 0.79727757 (0.77202075)
# Finished training epoch 430
# Validate: MSE 0.00281555 (0.00238301), PSNR 25.50437164 (26.29455348), SSIM 0.71776056 (0.77996635)
# Finished validation.
# Starting training epoch 431
# Epoch: 431, MSE 0.00249086 (0.00236094), PSNR 26.03651237 (26.29423536), SSIM 0.78250206 (0.77199667)
# Finished training epoch 431
# Validate: MSE 0.00281817 (0.00236296), PSNR 25.50032997 (26.32916671), SSIM 0.71628642 (0.77988121)
# Finished validation.
# Starting training epoch 432
# Epoch: 432, MSE 0.00322237 (0.00236414), PSNR 24.91824913 (26.28547867), SSIM 0.75165027 (0.77185459)
# Finished training epoch 432
# Validate: MSE 0.00276317 (0.00233018), PSNR 25.58591652 (26.38836759), SSIM 0.71818954 (0.78193768)
# Finished validation.
# Starting training epoch 433
# Epoch: 433, MSE 0.00189322 (0.00236853), PSNR 27.22799110 (26.28342309), SSIM 0.79550463 (0.77182722)
# Finished training epoch 433
# Validate: MSE 0.00285491 (0.00237781), PSNR 25.44407082 (26.30382008), SSIM 0.71798289 (0.78070217)
# Finished validation.
# Starting training epoch 434
# Epoch: 434, MSE 0.00252153 (0.00236879), PSNR 25.98335075 (26.27764297), SSIM 0.76304084 (0.77186856)
# Finished training epoch 434
# Validate: MSE 0.00273509 (0.00237287), PSNR 25.63028908 (26.30992982), SSIM 0.71914089 (0.77715358)
# Finished validation.
# Starting training epoch 435
# Epoch: 435, MSE 0.00306455 (0.00236369), PSNR 25.13633347 (26.28643832), SSIM 0.76139599 (0.77196534)
# Finished training epoch 435
# Validate: MSE 0.00272098 (0.00233472), PSNR 25.65274429 (26.37823170), SSIM 0.71817005 (0.78075925)
# Finished validation.
# Starting training epoch 436
# Epoch: 436, MSE 0.00268413 (0.00236553), PSNR 25.71196747 (26.28331651), SSIM 0.77654088 (0.77199583)
# Finished training epoch 436
# Validate: MSE 0.00283421 (0.00234847), PSNR 25.47567368 (26.35797980), SSIM 0.71674109 (0.78011861)
# Finished validation.
# Starting training epoch 437
# Epoch: 437, MSE 0.00250881 (0.00236776), PSNR 26.00532341 (26.27922663), SSIM 0.78915095 (0.77172314)
# Finished training epoch 437
# Validate: MSE 0.00270860 (0.00232908), PSNR 25.67254448 (26.38799624), SSIM 0.71880698 (0.77696190)
# Finished validation.
# Starting training epoch 438
# Epoch: 438, MSE 0.00238227 (0.00236049), PSNR 26.23009682 (26.29382628), SSIM 0.77428901 (0.77213622)
# Finished training epoch 438
# Validate: MSE 0.00267304 (0.00233909), PSNR 25.72994804 (26.36880283), SSIM 0.71753037 (0.77650843)
# Finished validation.
# Starting training epoch 439
# Epoch: 439, MSE 0.00209419 (0.00236732), PSNR 26.78984451 (26.28159150), SSIM 0.78855979 (0.77218821)
# Finished training epoch 439
# Validate: MSE 0.00266612 (0.00233759), PSNR 25.74120712 (26.37083725), SSIM 0.71810019 (0.77737614)
# Finished validation.
# Starting training epoch 440
# Epoch: 440, MSE 0.00202533 (0.00237035), PSNR 26.93503189 (26.27582929), SSIM 0.78496629 (0.77169371)
# Finished training epoch 440
# Validate: MSE 0.00265199 (0.00233144), PSNR 25.76428032 (26.38083264), SSIM 0.71745253 (0.77447325)
# Finished validation.
# Starting training epoch 441
# Epoch: 441, MSE 0.00209051 (0.00236704), PSNR 26.79748535 (26.28516079), SSIM 0.75280124 (0.77190304)
# Finished training epoch 441
# Validate: MSE 0.00275790 (0.00232903), PSNR 25.59421158 (26.39150887), SSIM 0.71850091 (0.78093115)
# Finished validation.
# Starting training epoch 442
# Epoch: 442, MSE 0.00262914 (0.00236394), PSNR 25.80185509 (26.28862371), SSIM 0.75055486 (0.77170076)
# Finished training epoch 442
# Validate: MSE 0.00264777 (0.00232197), PSNR 25.77119637 (26.39955064), SSIM 0.71901119 (0.77861691)
# Finished validation.
# Starting training epoch 443
# Epoch: 443, MSE 0.00263110 (0.00236470), PSNR 25.79862213 (26.28517111), SSIM 0.75633121 (0.77173403)
# Finished training epoch 443
# Validate: MSE 0.00277364 (0.00233104), PSNR 25.56949234 (26.38751502), SSIM 0.71872085 (0.78187886)
# Finished validation.
# Starting training epoch 444
# Epoch: 444, MSE 0.00220924 (0.00236618), PSNR 26.55756569 (26.28334395), SSIM 0.80257034 (0.77185419)
# Finished training epoch 444
# Validate: MSE 0.00272602 (0.00233266), PSNR 25.64470863 (26.38223598), SSIM 0.71800297 (0.77946325)
# Finished validation.
# Starting training epoch 445
# Epoch: 445, MSE 0.00194329 (0.00236698), PSNR 27.11462021 (26.28211537), SSIM 0.78344303 (0.77177416)
# Finished training epoch 445
# Validate: MSE 0.00267237 (0.00232978), PSNR 25.73102570 (26.38652189), SSIM 0.71776736 (0.77704517)
# Finished validation.
# Starting training epoch 446
# Epoch: 446, MSE 0.00187975 (0.00236046), PSNR 27.25898743 (26.29392276), SSIM 0.77480423 (0.77193039)
# Finished training epoch 446
# Validate: MSE 0.00270885 (0.00233730), PSNR 25.67214584 (26.37300934), SSIM 0.71788192 (0.77703976)
# Finished validation.
# Starting training epoch 447
# Epoch: 447, MSE 0.00223501 (0.00235767), PSNR 26.50720406 (26.29606642), SSIM 0.75869632 (0.77195475)
# Finished training epoch 447
# Validate: MSE 0.00269762 (0.00232637), PSNR 25.69018364 (26.39146325), SSIM 0.71837246 (0.77766770)
# Finished validation.
# Starting training epoch 448
# Epoch: 448, MSE 0.00228920 (0.00236383), PSNR 26.40315819 (26.28855269), SSIM 0.77277744 (0.77199261)
# Finished training epoch 448
# Validate: MSE 0.00274731 (0.00234455), PSNR 25.61091995 (26.36168416), SSIM 0.71781284 (0.77793443)
# Finished validation.
# Starting training epoch 449
# Epoch: 449, MSE 0.00217415 (0.00236648), PSNR 26.62710571 (26.28249071), SSIM 0.77393162 (0.77190524)
# Finished training epoch 449
# Validate: MSE 0.00270176 (0.00232084), PSNR 25.68353462 (26.40318379), SSIM 0.71828914 (0.78040874)
# Finished validation.
# Starting training epoch 450
# Epoch: 450, MSE 0.00261969 (0.00235840), PSNR 25.81750488 (26.29727986), SSIM 0.76203233 (0.77214019)
# Finished training epoch 450
# Validate: MSE 0.00273912 (0.00233582), PSNR 25.62389183 (26.37742799), SSIM 0.72037590 (0.77769584)
# Finished validation.
# Starting training epoch 451
# Epoch: 451, MSE 0.00273065 (0.00236037), PSNR 25.63733482 (26.29397302), SSIM 0.76741457 (0.77170322)
# Finished training epoch 451
# Validate: MSE 0.00284587 (0.00237109), PSNR 25.45784569 (26.31592122), SSIM 0.71842158 (0.78227246)
# Finished validation.
# Starting training epoch 452
# Epoch: 452, MSE 0.00251029 (0.00235837), PSNR 26.00275803 (26.29826766), SSIM 0.77784520 (0.77218721)
# Finished training epoch 452
# Validate: MSE 0.00277979 (0.00236662), PSNR 25.55988312 (26.32336002), SSIM 0.71823078 (0.78053748)
# Finished validation.
# Starting training epoch 453
# Epoch: 453, MSE 0.00226415 (0.00235944), PSNR 26.45093727 (26.29347625), SSIM 0.79898208 (0.77228051)
# Finished training epoch 453
# Validate: MSE 0.00280594 (0.00235179), PSNR 25.51921082 (26.34930308), SSIM 0.71898162 (0.77983516)
# Finished validation.
# Starting training epoch 454
# Epoch: 454, MSE 0.00193415 (0.00235949), PSNR 27.13510323 (26.29503996), SSIM 0.79058683 (0.77199289)
# Finished training epoch 454
# Validate: MSE 0.00272642 (0.00232621), PSNR 25.64406586 (26.39413441), SSIM 0.71917069 (0.77942935)
# Finished validation.
# Starting training epoch 455
# Epoch: 455, MSE 0.00252087 (0.00235976), PSNR 25.98450089 (26.29440358), SSIM 0.77451456 (0.77204403)
# Finished training epoch 455
# Validate: MSE 0.00276449 (0.00232428), PSNR 25.58384705 (26.39902517), SSIM 0.71900958 (0.78088971)
# Finished validation.
# Starting training epoch 456
# Epoch: 456, MSE 0.00238190 (0.00236860), PSNR 26.23075867 (26.27762046), SSIM 0.78060383 (0.77178944)
# Finished training epoch 456
# Validate: MSE 0.00271223 (0.00233278), PSNR 25.66673660 (26.37931717), SSIM 0.71669358 (0.77685382)
# Finished validation.
# Starting training epoch 457
# Epoch: 457, MSE 0.00299070 (0.00236524), PSNR 25.24227715 (26.28605774), SSIM 0.74765587 (0.77201251)
# Finished training epoch 457
# Validate: MSE 0.00272386 (0.00232915), PSNR 25.64815140 (26.38593558), SSIM 0.71389568 (0.77756036)
# Finished validation.
# Starting training epoch 458
# Epoch: 458, MSE 0.00295238 (0.00237220), PSNR 25.29827309 (26.26999208), SSIM 0.74348772 (0.77184339)
# Finished training epoch 458
# Validate: MSE 0.00269019 (0.00234379), PSNR 25.70216560 (26.35958411), SSIM 0.71790266 (0.77688450)
# Finished validation.
# Starting training epoch 459
# Epoch: 459, MSE 0.00227542 (0.00236608), PSNR 26.42939186 (26.28321090), SSIM 0.76143968 (0.77217780)
# Finished training epoch 459
# Validate: MSE 0.00272665 (0.00232084), PSNR 25.64370155 (26.40429591), SSIM 0.71953726 (0.77957134)
# Finished validation.
# Starting training epoch 460
# Epoch: 460, MSE 0.00205759 (0.00236057), PSNR 26.86640739 (26.29217996), SSIM 0.77691108 (0.77191137)
# Finished training epoch 460
# Validate: MSE 0.00272438 (0.00233064), PSNR 25.64731979 (26.38575063), SSIM 0.71732259 (0.78080717)
# Finished validation.
# Starting training epoch 461
# Epoch: 461, MSE 0.00245731 (0.00236657), PSNR 26.09539223 (26.28068257), SSIM 0.78282893 (0.77197483)
# Finished training epoch 461
# Validate: MSE 0.00271799 (0.00233744), PSNR 25.65752029 (26.37297789), SSIM 0.71700543 (0.77577770)
# Finished validation.
# Starting training epoch 462
# Epoch: 462, MSE 0.00252632 (0.00236259), PSNR 25.97511101 (26.29249682), SSIM 0.76831228 (0.77187929)
# Finished training epoch 462
# Validate: MSE 0.00265720 (0.00232975), PSNR 25.75575638 (26.38463997), SSIM 0.71953487 (0.77868518)
# Finished validation.
# Starting training epoch 463
# Epoch: 463, MSE 0.00217367 (0.00236112), PSNR 26.62805939 (26.29107377), SSIM 0.77535552 (0.77201876)
# Finished training epoch 463
# Validate: MSE 0.00277345 (0.00232997), PSNR 25.56979370 (26.38767961), SSIM 0.71717763 (0.77868946)
# Finished validation.
# Starting training epoch 464
# Epoch: 464, MSE 0.00186138 (0.00236306), PSNR 27.30165482 (26.28894034), SSIM 0.76291639 (0.77209328)
# Finished training epoch 464
# Validate: MSE 0.00265796 (0.00233258), PSNR 25.75451279 (26.37703188), SSIM 0.71567893 (0.77474079)
# Finished validation.
# Starting training epoch 465
# Epoch: 465, MSE 0.00211458 (0.00236777), PSNR 26.74776649 (26.27659986), SSIM 0.77212799 (0.77209071)
# Finished training epoch 465
# Validate: MSE 0.00271789 (0.00234197), PSNR 25.65768623 (26.36151006), SSIM 0.71728432 (0.77996023)
# Finished validation.
# Starting training epoch 466
# Epoch: 466, MSE 0.00198501 (0.00236078), PSNR 27.02237701 (26.29083503), SSIM 0.78550202 (0.77206779)
# Finished training epoch 466
# Validate: MSE 0.00270317 (0.00232294), PSNR 25.68126678 (26.40130785), SSIM 0.71686238 (0.77777707)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00271530 (0.00232422), PSNR 25.66182137 (26.39883887), SSIM 0.71675158 (0.77777563)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
