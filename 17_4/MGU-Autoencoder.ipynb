# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-83007db48cd9300" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-83007db48cd9300");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 512

class Autoencoder(nn.Module):
    def __init__(self, input_size=128):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x)), negative_slope=0.1)
        x = F.interpolate(self.convtrans3(x), scale_factor=scale_factor)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 512, 32, 32]           5,120
#        BatchNorm2d-2          [-1, 512, 32, 32]           1,024
#             Conv2d-3         [-1, 1024, 16, 16]       4,719,616
#        BatchNorm2d-4         [-1, 1024, 16, 16]           2,048
#    ConvTranspose2d-5            [-1, 512, 8, 8]       4,719,104
#        BatchNorm2d-6            [-1, 512, 8, 8]           1,024
#    ConvTranspose2d-7          [-1, 256, 16, 16]       1,179,904
#        BatchNorm2d-8          [-1, 256, 16, 16]             512
#    ConvTranspose2d-9            [-1, 2, 16, 16]           4,610
# ================================================================
# Total params: 10,632,962
# Trainable params: 10,632,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 13.50
# Params size (MB): 40.56
# Estimated Total Size (MB): 54.07
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.02858108 (5.65832478), PSNR 15.43921280 (8.93980723), SSIM 0.10657670 (0.05411384)
# Finished training epoch 0
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 107 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 63 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 80 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 7 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 6 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 25 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 127 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 27 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.03054378 (0.02794322), PSNR 15.15077209 (15.55997611), SSIM 0.08432081 (0.10807018)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.01511877 (0.01962274), PSNR 18.20483398 (17.17206833), SSIM 0.18303493 (0.14915802)
# Finished training epoch 1
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 43 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 94 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 37 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 8 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 49 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 5 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01525505 (0.01358815), PSNR 18.16586494 (18.69094517), SSIM 0.14700198 (0.18688398)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.01009373 (0.01132364), PSNR 19.95948029 (19.49165746), SSIM 0.22849782 (0.21970849)
# Finished training epoch 2
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 17 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 64 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 16 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 42 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01094548 (0.00971033), PSNR 19.60765266 (20.14082439), SSIM 0.20095310 (0.24750442)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00813374 (0.00838369), PSNR 20.89709663 (20.78772081), SSIM 0.28138861 (0.27383651)
# Finished training epoch 3
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 11 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 40 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00884703 (0.00756665), PSNR 20.53202438 (21.23545187), SSIM 0.24012280 (0.29702682)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00739877 (0.00691792), PSNR 21.30840492 (21.61827820), SSIM 0.31824270 (0.31711515)
# Finished training epoch 4
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 10 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 19 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00727465 (0.00641527), PSNR 21.38188171 (21.94625591), SSIM 0.28134650 (0.33620821)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00720613 (0.00618423), PSNR 21.42297935 (22.11118513), SSIM 0.37092480 (0.35308502)
# Finished training epoch 5
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 31 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00664397 (0.00592414), PSNR 21.77572060 (22.31347506), SSIM 0.30788144 (0.37236849)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00881453 (0.00624644), PSNR 20.54800987 (22.11017289), SSIM 0.37585852 (0.38089309)
# Finished training epoch 6
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 26 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00922541 (0.00817986), PSNR 20.35014343 (20.91369651), SSIM 0.30634475 (0.37876525)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.01852869 (0.00785155), PSNR 17.32155228 (21.55232789), SSIM 0.33212543 (0.39939237)
# Finished training epoch 7
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.02162447 (0.02185578), PSNR 16.65054512 (16.63548684), SSIM 0.28392166 (0.34597655)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00520881 (0.01022475), PSNR 22.83261871 (20.68607933), SSIM 0.42604336 (0.40927545)
# Finished training epoch 8
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 20 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00565814 (0.00512595), PSNR 22.47325897 (22.92541998), SSIM 0.38287240 (0.44870532)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.02992703 (0.01029452), PSNR 15.23936272 (20.56874382), SSIM 0.33274189 (0.42706727)
# Finished training epoch 9
# Validate: MSE 0.02303023 (0.03116031), PSNR 16.37701607 (15.09525177), SSIM 0.32065189 (0.35144751)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.01006711 (0.01143119), PSNR 19.97095299 (20.33056709), SSIM 0.47094736 (0.44009989)
# Finished training epoch 10
# Validate: MSE 0.01114194 (0.01229014), PSNR 19.53038979 (19.18085431), SSIM 0.36960632 (0.43337671)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00647668 (0.00948027), PSNR 21.88647461 (21.19101279), SSIM 0.49951273 (0.47092323)
# Finished training epoch 11
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 15 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00712489 (0.00632582), PSNR 21.47221947 (22.01261869), SSIM 0.42079926 (0.49442928)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.01051524 (0.00862491), PSNR 19.78180504 (21.13921722), SSIM 0.44410172 (0.48539187)
# Finished training epoch 12
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 13 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00553602 (0.00515936), PSNR 22.56802177 (22.89606950), SSIM 0.45629799 (0.52414111)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00755024 (0.00747630), PSNR 21.22039223 (21.63809623), SSIM 0.50791883 (0.50836898)
# Finished training epoch 13
# Validate: MSE 0.00572443 (0.00666982), PSNR 22.42267799 (21.77717753), SSIM 0.46872473 (0.52260174)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00419644 (0.00732059), PSNR 23.77119064 (21.75501217), SSIM 0.57660496 (0.52527902)
# Finished training epoch 14
# Validate: MSE 0.00425630 (0.00413882), PSNR 23.70967865 (23.89067606), SSIM 0.49666604 (0.56870887)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00340152 (0.00634669), PSNR 24.68326759 (22.28200511), SSIM 0.58619821 (0.54530444)
# Finished training epoch 15
# Validate: MSE 0.00409028 (0.00389309), PSNR 23.88246346 (24.14419532), SSIM 0.52339089 (0.59249459)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00574567 (0.00648313), PSNR 22.40659332 (22.19116604), SSIM 0.54152334 (0.55506031)
# Finished training epoch 16
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 22 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00714262 (0.00739753), PSNR 21.46142578 (21.35645566), SSIM 0.49058458 (0.54881324)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00417274 (0.00544769), PSNR 23.79578590 (22.90163091), SSIM 0.61041558 (0.58058396)
# Finished training epoch 17
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 14 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00459054 (0.00413850), PSNR 23.38136482 (23.86509373), SSIM 0.55101973 (0.61973855)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00525288 (0.00520972), PSNR 22.79602051 (23.11833534), SSIM 0.58852690 (0.59781030)
# Finished training epoch 18
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 69 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 371 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00683356 (0.00673391), PSNR 21.65353203 (21.74952275), SSIM 0.49376842 (0.56913093)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00367970 (0.00475252), PSNR 24.34187698 (23.38855543), SSIM 0.63156486 (0.61380395)
# Finished training epoch 19
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 29 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00487777 (0.00453759), PSNR 23.11778831 (23.48589159), SSIM 0.55316019 (0.62616629)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00524301 (0.00454417), PSNR 22.80419350 (23.54960614), SSIM 0.60954583 (0.62886446)
# Finished training epoch 20
# Validate: MSE 0.00640623 (0.00582543), PSNR 21.93397331 (22.40340490), SSIM 0.53998721 (0.61213523)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00373289 (0.00384015), PSNR 24.27954865 (24.22609264), SSIM 0.66794264 (0.65326945)
# Finished training epoch 21
# Validate: MSE 0.00420914 (0.00370093), PSNR 23.75806427 (24.35240519), SSIM 0.60269821 (0.67062722)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00374454 (0.00369370), PSNR 24.26601982 (24.39388534), SSIM 0.65046918 (0.66762037)
# Finished training epoch 22
# Validate: MSE 0.00415026 (0.00360335), PSNR 23.81924629 (24.48354671), SSIM 0.59519923 (0.67620932)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00345506 (0.00322059), PSNR 24.61544800 (24.95703392), SSIM 0.69221461 (0.69075521)
# Finished training epoch 23
# Validate: MSE 0.00332398 (0.00276579), PSNR 24.78342247 (25.64143443), SSIM 0.63798368 (0.71335926)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00391431 (0.00313791), PSNR 24.07344246 (25.07112993), SSIM 0.68942606 (0.70310639)
# Finished training epoch 24
# Validate: MSE 0.00339350 (0.00324153), PSNR 24.69352341 (24.95082390), SSIM 0.62738413 (0.70374025)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00286652 (0.00297126), PSNR 25.42645454 (25.29902305), SSIM 0.73012620 (0.71709284)
# Finished training epoch 25
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 39 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 357 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00474118 (0.00406670), PSNR 23.24113655 (23.96244832), SSIM 0.62799299 (0.69984362)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00321055 (0.00301428), PSNR 24.93420219 (25.24272123), SSIM 0.73240584 (0.72261278)
# Finished training epoch 26
# Validate: MSE 0.00855194 (0.00857477), PSNR 20.67935371 (20.71905896), SSIM 0.57207763 (0.63207033)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00288238 (0.00283631), PSNR 25.40248680 (25.50615230), SSIM 0.77347010 (0.73591955)
# Finished training epoch 27
# Validate: MSE 0.00352338 (0.00379294), PSNR 24.53041077 (24.33077207), SSIM 0.65922898 (0.72887331)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00329181 (0.00279114), PSNR 24.82564545 (25.57036095), SSIM 0.73284477 (0.74316322)
# Finished training epoch 28
# Validate: MSE 0.00388295 (0.00331312), PSNR 24.10837555 (24.86218895), SSIM 0.65925181 (0.73080270)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00293455 (0.00281651), PSNR 25.32457733 (25.53934962), SSIM 0.73754841 (0.74748835)
# Finished training epoch 29
# Validate: MSE 0.00298313 (0.00330503), PSNR 25.25327492 (24.93425451), SSIM 0.67734241 (0.74396252)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00307398 (0.00289166), PSNR 25.12298393 (25.43547454), SSIM 0.74153036 (0.74997752)
# Finished training epoch 30
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 282 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01251063 (0.01655927), PSNR 19.02720833 (17.87922107), SSIM 0.55380827 (0.59211894)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00299545 (0.00285763), PSNR 25.23537827 (25.47709685), SSIM 0.76296085 (0.75425888)
# Finished training epoch 31
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 296 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00342766 (0.00289734), PSNR 24.65001488 (25.44297367), SSIM 0.69295800 (0.75989280)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00270856 (0.00283381), PSNR 25.67260933 (25.51655208), SSIM 0.76911497 (0.75695930)
# Finished training epoch 32
# Validate: MSE 0.00473454 (0.00551082), PSNR 23.24721909 (22.68098029), SSIM 0.65175390 (0.69621924)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00275826 (0.00278783), PSNR 25.59365273 (25.57955425), SSIM 0.75085068 (0.75932768)
# Finished training epoch 33
# Validate: MSE 0.00317181 (0.00265197), PSNR 24.98692894 (25.83050909), SSIM 0.69720531 (0.76536020)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00289981 (0.00275853), PSNR 25.37630272 (25.62587985), SSIM 0.76435339 (0.76158940)
# Finished training epoch 34
# Validate: MSE 0.00373870 (0.00408584), PSNR 24.27279091 (24.06547731), SSIM 0.67715883 (0.74859685)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00260058 (0.00274115), PSNR 25.84929848 (25.65556378), SSIM 0.75873756 (0.76270434)
# Finished training epoch 35
# Validate: MSE 0.00317238 (0.00299602), PSNR 24.98615265 (25.32719979), SSIM 0.69186908 (0.76231036)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00209617 (0.00266396), PSNR 26.78572464 (25.77181439), SSIM 0.77523762 (0.76684388)
# Finished training epoch 36
# Validate: MSE 0.00885009 (0.01148698), PSNR 20.53052330 (19.47309081), SSIM 0.60015887 (0.63353058)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00217637 (0.00263390), PSNR 26.62266731 (25.82029169), SSIM 0.80276221 (0.76789154)
# Finished training epoch 37
# Validate: MSE 0.00802989 (0.01071371), PSNR 20.95290565 (19.76477248), SSIM 0.61657041 (0.64984698)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00219739 (0.00258062), PSNR 26.58092117 (25.90866931), SSIM 0.78241998 (0.77051754)
# Finished training epoch 38
# Validate: MSE 0.00298797 (0.00291477), PSNR 25.24623871 (25.43396134), SSIM 0.70760548 (0.76446780)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00217592 (0.00252377), PSNR 26.62356186 (26.00373049), SSIM 0.79458547 (0.77254332)
# Finished training epoch 39
# Validate: MSE 0.00511080 (0.00510509), PSNR 22.91510963 (22.96582270), SSIM 0.66131473 (0.70314009)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00269097 (0.00249799), PSNR 25.70091438 (26.04911134), SSIM 0.76922834 (0.77379441)
# Finished training epoch 40
# Validate: MSE 0.00300178 (0.00255925), PSNR 25.22620773 (25.99087211), SSIM 0.70478827 (0.77397960)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00219531 (0.00249121), PSNR 26.58504105 (26.06184459), SSIM 0.78196532 (0.77444996)
# Finished training epoch 41
# Validate: MSE 0.00465142 (0.00431339), PSNR 23.32414627 (23.73537938), SSIM 0.68945360 (0.74994870)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00227404 (0.00247114), PSNR 26.43201065 (26.09564478), SSIM 0.78876936 (0.77521160)
# Finished training epoch 42
# Validate: MSE 0.00274714 (0.00250047), PSNR 25.61119461 (26.10181209), SSIM 0.71129256 (0.77580942)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00202275 (0.00243378), PSNR 26.94058609 (26.15970470), SSIM 0.77567607 (0.77623839)
# Finished training epoch 43
# Validate: MSE 0.00286046 (0.00254977), PSNR 25.43563461 (26.00260312), SSIM 0.71312976 (0.77250561)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00261538 (0.00242569), PSNR 25.82465553 (26.17415059), SSIM 0.76504958 (0.77675269)
# Finished training epoch 44
# Validate: MSE 0.00283902 (0.00239587), PSNR 25.46831131 (26.27400057), SSIM 0.71012962 (0.77656679)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00210556 (0.00241668), PSNR 26.76632309 (26.19083595), SSIM 0.78113127 (0.77706872)
# Finished training epoch 45
# Validate: MSE 0.00294072 (0.00249865), PSNR 25.31546021 (26.09659197), SSIM 0.71393991 (0.77860484)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00216734 (0.00239973), PSNR 26.64072037 (26.22404888), SSIM 0.79109907 (0.77737918)
# Finished training epoch 46
# Validate: MSE 0.00294221 (0.00243661), PSNR 25.31326675 (26.19907249), SSIM 0.71217209 (0.77547165)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00279541 (0.00239548), PSNR 25.53554344 (26.22959554), SSIM 0.76839608 (0.77753923)
# Finished training epoch 47
# Validate: MSE 0.00397326 (0.00468167), PSNR 24.00853157 (23.37510574), SSIM 0.70301068 (0.75226375)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00248996 (0.00238833), PSNR 26.03807640 (26.23906264), SSIM 0.79253185 (0.77767671)
# Finished training epoch 48
# Validate: MSE 0.00312401 (0.00263609), PSNR 25.05287743 (25.86111561), SSIM 0.70834672 (0.77433244)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00196792 (0.00238770), PSNR 27.05993080 (26.24610831), SSIM 0.80055606 (0.77790630)
# Finished training epoch 49
# Validate: MSE 0.00333455 (0.00321634), PSNR 24.76962471 (25.01100928), SSIM 0.71017104 (0.76762969)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00236347 (0.00239148), PSNR 26.26449394 (26.23808092), SSIM 0.78360003 (0.77786111)
# Finished training epoch 50
# Validate: MSE 0.00287976 (0.00255557), PSNR 25.40643501 (25.98975789), SSIM 0.70888335 (0.76911259)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00291519 (0.00239298), PSNR 25.35332870 (26.23325370), SSIM 0.76247466 (0.77774126)
# Finished training epoch 51
# Validate: MSE 0.00291371 (0.00343452), PSNR 25.35554314 (24.76341269), SSIM 0.70483720 (0.75534153)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00243306 (0.00237729), PSNR 26.13846970 (26.26188604), SSIM 0.74656844 (0.77818645)
# Finished training epoch 52
# Validate: MSE 0.00383158 (0.00362489), PSNR 24.16621590 (24.48445564), SSIM 0.70138544 (0.76149423)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00216511 (0.00238073), PSNR 26.64519882 (26.25650661), SSIM 0.77190602 (0.77815832)
# Finished training epoch 53
# Validate: MSE 0.00290600 (0.00266016), PSNR 25.36705017 (25.83026575), SSIM 0.70798445 (0.76996243)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00277215 (0.00237087), PSNR 25.57182693 (26.27607628), SSIM 0.77091360 (0.77856816)
# Finished training epoch 54
# Validate: MSE 0.00306065 (0.00278921), PSNR 25.14185524 (25.63058561), SSIM 0.71218526 (0.77540469)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00248248 (0.00234635), PSNR 26.05114937 (26.31885946), SSIM 0.77219337 (0.77912879)
# Finished training epoch 55
# Validate: MSE 0.00394343 (0.00641870), PSNR 24.04125214 (22.06080863), SSIM 0.68908274 (0.72691303)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00243345 (0.00235962), PSNR 26.13777542 (26.29550145), SSIM 0.79058236 (0.77878028)
# Finished training epoch 56
# Validate: MSE 0.00285432 (0.00243694), PSNR 25.44498062 (26.19398257), SSIM 0.71067274 (0.77634051)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00220592 (0.00236113), PSNR 26.56409454 (26.29349538), SSIM 0.78515595 (0.77904712)
# Finished training epoch 57
# Validate: MSE 0.00839254 (0.01106411), PSNR 20.76106834 (19.62954005), SSIM 0.66363108 (0.70615483)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00241016 (0.00234258), PSNR 26.17954254 (26.32793024), SSIM 0.76550406 (0.77953623)
# Finished training epoch 58
# Validate: MSE 0.00278177 (0.00247026), PSNR 25.55678177 (26.15310674), SSIM 0.71542633 (0.77417247)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00232451 (0.00235223), PSNR 26.33668518 (26.30924913), SSIM 0.78169918 (0.77899574)
# Finished training epoch 59
# Validate: MSE 0.00249611 (0.00243467), PSNR 26.02735710 (26.19697514), SSIM 0.71736574 (0.77699703)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00213910 (0.00235214), PSNR 26.69768143 (26.31029851), SSIM 0.77662003 (0.77940631)
# Finished training epoch 60
# Validate: MSE 0.00293416 (0.00251192), PSNR 25.32515907 (26.07881012), SSIM 0.71541107 (0.77770417)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00233833 (0.00232084), PSNR 26.31093788 (26.36764482), SSIM 0.78368002 (0.78009211)
# Finished training epoch 61
# Validate: MSE 0.00273091 (0.00264295), PSNR 25.63692665 (25.84473232), SSIM 0.71924102 (0.77896737)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00229629 (0.00235380), PSNR 26.38972664 (26.30896088), SSIM 0.77500153 (0.77967515)
# Finished training epoch 62
# Validate: MSE 0.00260248 (0.00233316), PSNR 25.84611893 (26.38419529), SSIM 0.72147036 (0.77888808)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00267059 (0.00231210), PSNR 25.73392487 (26.38212170), SSIM 0.76878154 (0.78056599)
# Finished training epoch 63
# Validate: MSE 0.00282553 (0.00247917), PSNR 25.48899460 (26.12153637), SSIM 0.71661633 (0.78193716)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00343134 (0.00230284), PSNR 24.64536285 (26.39707768), SSIM 0.75884616 (0.78064494)
# Finished training epoch 64
# Validate: MSE 0.00264254 (0.00244852), PSNR 25.77977753 (26.18405704), SSIM 0.71966052 (0.77549868)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00210406 (0.00233185), PSNR 26.76941681 (26.34631636), SSIM 0.79820377 (0.78020397)
# Finished training epoch 65
# Validate: MSE 0.00276808 (0.00243373), PSNR 25.57821846 (26.20340193), SSIM 0.71737254 (0.78109864)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00209951 (0.00230754), PSNR 26.77881622 (26.38943565), SSIM 0.77898991 (0.78079860)
# Finished training epoch 66
# Validate: MSE 0.00272997 (0.00313067), PSNR 25.63842010 (25.17653802), SSIM 0.71549261 (0.77408883)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00278743 (0.00227836), PSNR 25.54795456 (26.44961045), SSIM 0.76592970 (0.78126731)
# Finished training epoch 67
# Validate: MSE 0.00281641 (0.00245647), PSNR 25.50304604 (26.15896386), SSIM 0.71495306 (0.77683209)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00183441 (0.00228727), PSNR 27.36502266 (26.42871845), SSIM 0.78258193 (0.78106268)
# Finished training epoch 68
# Validate: MSE 0.00265871 (0.00262681), PSNR 25.75328827 (25.88483512), SSIM 0.71149778 (0.77556102)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00202156 (0.00237214), PSNR 26.94312859 (26.28105226), SSIM 0.78055984 (0.77950105)
# Finished training epoch 69
# Validate: MSE 0.00255787 (0.00257466), PSNR 25.92120934 (25.96535948), SSIM 0.72005546 (0.76988478)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00222496 (0.00225319), PSNR 26.52677917 (26.49651840), SSIM 0.78513348 (0.78186540)
# Finished training epoch 70
# Validate: MSE 0.00329646 (0.00287080), PSNR 24.81951523 (25.51416879), SSIM 0.71187395 (0.77470564)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00250046 (0.00226495), PSNR 26.01979256 (26.47436990), SSIM 0.77950686 (0.78171703)
# Finished training epoch 71
# Validate: MSE 0.00264585 (0.00240572), PSNR 25.77434158 (26.25622017), SSIM 0.72088659 (0.77974344)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00243856 (0.00226756), PSNR 26.12866974 (26.46622925), SSIM 0.77122462 (0.78170188)
# Finished training epoch 72
# Validate: MSE 0.00290396 (0.00323103), PSNR 25.37008667 (25.01831621), SSIM 0.71394897 (0.76977764)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00193740 (0.00226849), PSNR 27.12780571 (26.46541930), SSIM 0.79314107 (0.78154495)
# Finished training epoch 73
# Validate: MSE 0.00278656 (0.00238108), PSNR 25.54930687 (26.30332391), SSIM 0.70964134 (0.77365655)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00210138 (0.00225727), PSNR 26.77495956 (26.48921135), SSIM 0.78516209 (0.78187744)
# Finished training epoch 74
# Validate: MSE 0.00259567 (0.00242263), PSNR 25.85750961 (26.23329367), SSIM 0.71907145 (0.77612526)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00218004 (0.00225640), PSNR 26.61535454 (26.49104619), SSIM 0.79186928 (0.78192525)
# Finished training epoch 75
# Validate: MSE 0.00270418 (0.00239519), PSNR 25.67964172 (26.27560312), SSIM 0.72032726 (0.77933584)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00230994 (0.00223614), PSNR 26.36399841 (26.52778553), SSIM 0.79040015 (0.78219047)
# Finished training epoch 76
# Validate: MSE 0.00351011 (0.00284505), PSNR 24.54678726 (25.53783062), SSIM 0.71046138 (0.77545329)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00177689 (0.00222262), PSNR 27.50340271 (26.55541820), SSIM 0.79346526 (0.78234890)
# Finished training epoch 77
# Validate: MSE 0.00338712 (0.00380039), PSNR 24.70169640 (24.31198624), SSIM 0.70206696 (0.75622358)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00208472 (0.00224227), PSNR 26.80951500 (26.51814150), SSIM 0.78597385 (0.78204329)
# Finished training epoch 78
# Validate: MSE 0.00289331 (0.00240795), PSNR 25.38604546 (26.24010920), SSIM 0.70606244 (0.77557303)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00285428 (0.00224091), PSNR 25.44503593 (26.51759737), SSIM 0.75863636 (0.78205008)
# Finished training epoch 79
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 177 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00268941 (0.00262155), PSNR 25.70342827 (25.85559079), SSIM 0.72026145 (0.77950286)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00238644 (0.00223396), PSNR 26.22249413 (26.53277786), SSIM 0.76814330 (0.78227347)
# Finished training epoch 80
# Validate: MSE 0.00279326 (0.00236910), PSNR 25.53888130 (26.32571219), SSIM 0.71911216 (0.78197482)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00207410 (0.00223409), PSNR 26.83169746 (26.53144527), SSIM 0.78770894 (0.78203711)
# Finished training epoch 81
# Validate: MSE 0.00275550 (0.00338943), PSNR 25.59799576 (24.89286531), SSIM 0.71378767 (0.76830961)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00200070 (0.00222976), PSNR 26.98817444 (26.54227636), SSIM 0.77090919 (0.78214668)
# Finished training epoch 82
# Validate: MSE 0.00295232 (0.00253998), PSNR 25.29836273 (26.03293678), SSIM 0.71775764 (0.77621784)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00222460 (0.00221228), PSNR 26.52747726 (26.57434712), SSIM 0.78714532 (0.78259167)
# Finished training epoch 83
# Validate: MSE 0.00253937 (0.00245257), PSNR 25.95273781 (26.18512333), SSIM 0.72509897 (0.77711196)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00175202 (0.00220674), PSNR 27.56460190 (26.58582331), SSIM 0.81444263 (0.78265728)
# Finished training epoch 84
# Validate: MSE 0.00262070 (0.00248155), PSNR 25.81582451 (26.12295012), SSIM 0.72023511 (0.78136039)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00226496 (0.00219130), PSNR 26.44939232 (26.61680166), SSIM 0.79720294 (0.78292458)
# Finished training epoch 85
# Validate: MSE 0.00265572 (0.00236730), PSNR 25.75817871 (26.32643977), SSIM 0.72787583 (0.77840408)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00252706 (0.00218637), PSNR 25.97384071 (26.62636324), SSIM 0.78443497 (0.78297495)
# Finished training epoch 86
# Validate: MSE 0.00265795 (0.00232463), PSNR 25.75452805 (26.39944150), SSIM 0.71885490 (0.77992085)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00255380 (0.00223067), PSNR 25.92812347 (26.53958052), SSIM 0.79446328 (0.78213481)
# Finished training epoch 87
# Validate: MSE 0.00306881 (0.00254550), PSNR 25.13030434 (26.01584291), SSIM 0.72231829 (0.78146275)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00230501 (0.00219130), PSNR 26.37327194 (26.61560632), SSIM 0.77864838 (0.78285536)
# Finished training epoch 88
# Validate: MSE 0.00287632 (0.00280921), PSNR 25.41163063 (25.61042628), SSIM 0.71629143 (0.77356942)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00225670 (0.00218650), PSNR 26.46526146 (26.62465490), SSIM 0.79194677 (0.78286685)
# Finished training epoch 89
# Validate: MSE 0.00272885 (0.00257194), PSNR 25.64020729 (25.97021039), SSIM 0.72222269 (0.77096211)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00230175 (0.00218544), PSNR 26.37942314 (26.63024196), SSIM 0.78848201 (0.78290591)
# Finished training epoch 90
# Validate: MSE 0.00285325 (0.00232362), PSNR 25.44660187 (26.40054088), SSIM 0.71733069 (0.78121477)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00261017 (0.00217106), PSNR 25.83331490 (26.65323282), SSIM 0.75748479 (0.78301039)
# Finished training epoch 91
# Validate: MSE 0.00268574 (0.00261182), PSNR 25.70936203 (25.91925781), SSIM 0.71653485 (0.77231493)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00194814 (0.00217680), PSNR 27.10379791 (26.64676187), SSIM 0.78871739 (0.78270380)
# Finished training epoch 92
# Validate: MSE 0.00254684 (0.00253298), PSNR 25.93997765 (26.03066922), SSIM 0.71225590 (0.77071132)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00205610 (0.00218577), PSNR 26.86955452 (26.63045492), SSIM 0.76509511 (0.78265970)
# Finished training epoch 93
# Validate: MSE 0.00336237 (0.00318135), PSNR 24.73354912 (25.04454482), SSIM 0.70736802 (0.76112696)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00209221 (0.00215514), PSNR 26.79394531 (26.68802984), SSIM 0.79154480 (0.78292954)
# Finished training epoch 94
# Validate: MSE 0.00291538 (0.00250118), PSNR 25.35304070 (26.10683083), SSIM 0.71420228 (0.77556970)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00228448 (0.00216053), PSNR 26.41211891 (26.67654218), SSIM 0.77438271 (0.78307485)
# Finished training epoch 95
# Validate: MSE 0.00247697 (0.00227358), PSNR 26.06079102 (26.49957935), SSIM 0.72335434 (0.78005159)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00223914 (0.00214500), PSNR 26.49918556 (26.70611610), SSIM 0.78328514 (0.78291198)
# Finished training epoch 96
# Validate: MSE 0.00263423 (0.00238189), PSNR 25.79345894 (26.28799971), SSIM 0.72190630 (0.78202675)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00333099 (0.00507086), PSNR 24.77425957 (25.12372302), SSIM 0.74937719 (0.76325604)
# Finished training epoch 97
# Validate: MSE 0.00277414 (0.00258567), PSNR 25.56871986 (25.93187455), SSIM 0.70758462 (0.77239779)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00338312 (0.00264458), PSNR 24.70683098 (25.81346818), SSIM 0.76484376 (0.77576992)
# Finished training epoch 98
# Validate: MSE 0.00277664 (0.00262189), PSNR 25.56479836 (25.86521315), SSIM 0.71292162 (0.77713137)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00327586 (0.00250948), PSNR 24.84674263 (26.04010487), SSIM 0.75383234 (0.77736617)
# Finished training epoch 99
# Validate: MSE 0.00277249 (0.00233382), PSNR 25.57130241 (26.38138279), SSIM 0.71056306 (0.77641883)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00239667 (0.00242783), PSNR 26.20390892 (26.17715927), SSIM 0.77050710 (0.77852762)
# Finished training epoch 100
# Validate: MSE 0.00264663 (0.00260567), PSNR 25.77307129 (25.90724363), SSIM 0.71038675 (0.76999768)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00261814 (0.00241481), PSNR 25.82006836 (26.20345548), SSIM 0.76636785 (0.77939457)
# Finished training epoch 101
# Validate: MSE 0.00275365 (0.00272805), PSNR 25.60090446 (25.74539856), SSIM 0.71041334 (0.77043670)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00221166 (0.00229096), PSNR 26.55281639 (26.42491877), SSIM 0.77867830 (0.78049042)
# Finished training epoch 102
# Validate: MSE 0.00300367 (0.00259848), PSNR 25.22347641 (25.90076594), SSIM 0.71771598 (0.78085682)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00267211 (0.00229229), PSNR 25.73145676 (26.42402517), SSIM 0.78169250 (0.78064788)
# Finished training epoch 103
# Validate: MSE 0.00289840 (0.00236014), PSNR 25.37841988 (26.34537117), SSIM 0.71637160 (0.78059264)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00223552 (0.00225327), PSNR 26.50621033 (26.49272367), SSIM 0.78558075 (0.78122492)
# Finished training epoch 104
# Validate: MSE 0.00279803 (0.00233873), PSNR 25.53146744 (26.37761202), SSIM 0.71544451 (0.77982242)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00207540 (0.00219951), PSNR 26.82897568 (26.60274073), SSIM 0.77350217 (0.78211564)
# Finished training epoch 105
# Validate: MSE 0.00252693 (0.00236391), PSNR 25.97406578 (26.34703426), SSIM 0.72672755 (0.78026050)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00203356 (0.00219646), PSNR 26.91743660 (26.60963145), SSIM 0.79009449 (0.78224112)
# Finished training epoch 106
# Validate: MSE 0.00262845 (0.00259083), PSNR 25.80299950 (25.94762059), SSIM 0.71650177 (0.77661688)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00242854 (0.00217295), PSNR 26.14653969 (26.65486663), SSIM 0.76526320 (0.78277870)
# Finished training epoch 107
# Validate: MSE 0.00269255 (0.00267603), PSNR 25.69836617 (25.81156438), SSIM 0.71723515 (0.77504704)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00206009 (0.00216039), PSNR 26.86113358 (26.68022674), SSIM 0.77709067 (0.78286487)
# Finished training epoch 108
# Validate: MSE 0.00277198 (0.00248602), PSNR 25.57209969 (26.12018628), SSIM 0.72038770 (0.77958107)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00235095 (0.00215053), PSNR 26.28755951 (26.69661928), SSIM 0.76707292 (0.78318182)
# Finished training epoch 109
# Validate: MSE 0.00261688 (0.00250636), PSNR 25.82215309 (26.09728273), SSIM 0.71940905 (0.77700566)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00212661 (0.00213966), PSNR 26.72312164 (26.71709263), SSIM 0.79663438 (0.78323755)
# Finished training epoch 110
# Validate: MSE 0.00277756 (0.00231933), PSNR 25.56336212 (26.40843295), SSIM 0.72321939 (0.78204916)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00260059 (0.00213758), PSNR 25.84927750 (26.72267074), SSIM 0.78291094 (0.78337463)
# Finished training epoch 111
# Validate: MSE 0.00270230 (0.00229533), PSNR 25.68266487 (26.45063047), SSIM 0.72127885 (0.77797752)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00232605 (0.00212751), PSNR 26.33381271 (26.74349640), SSIM 0.78324199 (0.78323316)
# Finished training epoch 112
# Validate: MSE 0.00253494 (0.00221864), PSNR 25.96032333 (26.59554579), SSIM 0.71906269 (0.77901709)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00210536 (0.00214299), PSNR 26.76673317 (26.71452900), SSIM 0.78270137 (0.78314463)
# Finished training epoch 113
# Validate: MSE 0.00271814 (0.00273581), PSNR 25.65728569 (25.73961225), SSIM 0.71424061 (0.77551282)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00229642 (0.00213885), PSNR 26.38948441 (26.72372318), SSIM 0.76258051 (0.78318385)
# Finished training epoch 114
# Validate: MSE 0.00261791 (0.00226434), PSNR 25.82045555 (26.50889718), SSIM 0.71795297 (0.77376204)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00176959 (0.00210849), PSNR 27.52127838 (26.78263212), SSIM 0.78889042 (0.78342466)
# Finished training epoch 115
# Validate: MSE 0.00271902 (0.00226228), PSNR 25.65587044 (26.52122112), SSIM 0.71765608 (0.77872321)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00185455 (0.00210188), PSNR 27.31760597 (26.79679025), SSIM 0.79875571 (0.78342943)
# Finished training epoch 116
# Validate: MSE 0.00276906 (0.00236499), PSNR 25.57667923 (26.32390211), SSIM 0.71509230 (0.77605872)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00268313 (0.00211652), PSNR 25.71358299 (26.76408298), SSIM 0.75879109 (0.78334051)
# Finished training epoch 117
# Validate: MSE 0.00269084 (0.00230439), PSNR 25.70112038 (26.44149599), SSIM 0.71394902 (0.77509684)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00150130 (0.00211054), PSNR 28.23533440 (26.77983322), SSIM 0.78756040 (0.78311192)
# Finished training epoch 118
# Validate: MSE 0.00262366 (0.00239870), PSNR 25.81092834 (26.26615266), SSIM 0.72011495 (0.77646423)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00211161 (0.00209926), PSNR 26.75386620 (26.80307653), SSIM 0.78074098 (0.78330165)
# Finished training epoch 119
# Validate: MSE 0.00294715 (0.00248558), PSNR 25.30597496 (26.12982738), SSIM 0.71359009 (0.77673892)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00239155 (0.00209705), PSNR 26.21320724 (26.80636660), SSIM 0.77148306 (0.78307703)
# Finished training epoch 120
# Validate: MSE 0.00263552 (0.00233055), PSNR 25.79133224 (26.38523456), SSIM 0.71381104 (0.77534730)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00188501 (0.00208998), PSNR 27.24687386 (26.81930121), SSIM 0.80022496 (0.78314244)
# Finished training epoch 121
# Validate: MSE 0.00253543 (0.00227795), PSNR 25.95948792 (26.48835146), SSIM 0.71998131 (0.78045612)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00239307 (0.00209059), PSNR 26.21044540 (26.81602528), SSIM 0.77809751 (0.78331105)
# Finished training epoch 122
# Validate: MSE 0.00285509 (0.00226141), PSNR 25.44380569 (26.51997281), SSIM 0.72102386 (0.77762247)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00243562 (0.00210420), PSNR 26.13389397 (26.79322507), SSIM 0.77793396 (0.78303815)
# Finished training epoch 123
# Validate: MSE 0.00254570 (0.00229310), PSNR 25.94191933 (26.45111647), SSIM 0.71725011 (0.77920900)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00196224 (0.00208345), PSNR 27.07248688 (26.83386316), SSIM 0.78808761 (0.78320460)
# Finished training epoch 124
# Validate: MSE 0.00251769 (0.00230472), PSNR 25.98998451 (26.43188080), SSIM 0.72046125 (0.77357903)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00188897 (0.00207162), PSNR 27.23775482 (26.85778823), SSIM 0.78568566 (0.78319841)
# Finished training epoch 125
# Validate: MSE 0.00269544 (0.00228796), PSNR 25.69370651 (26.46917490), SSIM 0.71514857 (0.77308495)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00170744 (0.00209047), PSNR 27.67655373 (26.82098143), SSIM 0.79846126 (0.78288553)
# Finished training epoch 126
# Validate: MSE 0.00273309 (0.00230323), PSNR 25.63346291 (26.44338698), SSIM 0.72106516 (0.78099705)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00228250 (0.00205011), PSNR 26.41588974 (26.90391176), SSIM 0.78112614 (0.78319040)
# Finished training epoch 127
# Validate: MSE 0.00238649 (0.00223738), PSNR 26.22239685 (26.56091921), SSIM 0.72115982 (0.77097719)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00209754 (0.00206586), PSNR 26.78289986 (26.87215547), SSIM 0.77545208 (0.78280360)
# Finished training epoch 128
# Validate: MSE 0.00250222 (0.00230530), PSNR 26.01674080 (26.43125401), SSIM 0.72257286 (0.78023084)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00174553 (0.00205704), PSNR 27.58071518 (26.88809835), SSIM 0.79216874 (0.78303911)
# Finished training epoch 129
# Validate: MSE 0.00283186 (0.00278711), PSNR 25.47928047 (25.61955388), SSIM 0.70818603 (0.76226952)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00253601 (0.00207133), PSNR 25.95849800 (26.86098634), SSIM 0.76984417 (0.78278122)
# Finished training epoch 130
# Validate: MSE 0.00283916 (0.00246063), PSNR 25.46809578 (26.14694512), SSIM 0.71560276 (0.77176913)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00163143 (0.00204622), PSNR 27.87431526 (26.91645742), SSIM 0.79241186 (0.78293646)
# Finished training epoch 131
# Validate: MSE 0.00318686 (0.00297930), PSNR 24.96637154 (25.33903743), SSIM 0.69860220 (0.76202027)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00201198 (0.00204195), PSNR 26.96376801 (26.92342528), SSIM 0.79085100 (0.78317915)
# Finished training epoch 132
# Validate: MSE 0.00281875 (0.00247322), PSNR 25.49942780 (26.12355699), SSIM 0.71060330 (0.76926634)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00187205 (0.00202796), PSNR 27.27682686 (26.95131643), SSIM 0.77103698 (0.78323646)
# Finished training epoch 133
# Validate: MSE 0.00247576 (0.00230522), PSNR 26.06291580 (26.43075606), SSIM 0.71302193 (0.77009752)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00182536 (0.00202534), PSNR 27.38651276 (26.95675865), SSIM 0.80136508 (0.78321251)
# Finished training epoch 134
# Validate: MSE 0.00263402 (0.00247250), PSNR 25.79380035 (26.12614093), SSIM 0.72061789 (0.77538456)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00217093 (0.00203710), PSNR 26.63354683 (26.93065339), SSIM 0.78751290 (0.78281969)
# Finished training epoch 135
# Validate: MSE 0.00268511 (0.00265304), PSNR 25.71037674 (25.84646727), SSIM 0.71692783 (0.77217739)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00180010 (0.00204385), PSNR 27.44703674 (26.91885627), SSIM 0.76761067 (0.78221090)
# Finished training epoch 136
# Validate: MSE 0.00274224 (0.00301981), PSNR 25.61894035 (25.28986526), SSIM 0.71024066 (0.76430348)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00193436 (0.00203151), PSNR 27.13463020 (26.94440379), SSIM 0.77547652 (0.78275542)
# Finished training epoch 137
# Validate: MSE 0.00255775 (0.00237391), PSNR 25.92141724 (26.29228105), SSIM 0.71430349 (0.76954651)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00212550 (0.00201057), PSNR 26.72539139 (26.99046001), SSIM 0.78431290 (0.78288706)
# Finished training epoch 138
# Validate: MSE 0.00278334 (0.00239159), PSNR 25.55434036 (26.29145682), SSIM 0.71287376 (0.77302050)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00192080 (0.00201934), PSNR 27.16517639 (26.97037326), SSIM 0.77962017 (0.78283470)
# Finished training epoch 139
# Validate: MSE 0.00307084 (0.00293168), PSNR 25.12743187 (25.41668368), SSIM 0.69946277 (0.75788557)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00211451 (0.00199524), PSNR 26.74790001 (27.01794977), SSIM 0.79333884 (0.78304822)
# Finished training epoch 140
# Validate: MSE 0.00271656 (0.00228107), PSNR 25.65980911 (26.48446988), SSIM 0.71670580 (0.77287681)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00196972 (0.00200099), PSNR 27.05595779 (27.01052725), SSIM 0.78825772 (0.78286367)
# Finished training epoch 141
# Validate: MSE 0.00278885 (0.00281123), PSNR 25.54574966 (25.62039337), SSIM 0.70480776 (0.75716371)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00188972 (0.00199600), PSNR 27.23603439 (27.01895954), SSIM 0.76709533 (0.78253129)
# Finished training epoch 142
# Validate: MSE 0.00294812 (0.00241105), PSNR 25.30454636 (26.23637211), SSIM 0.70728523 (0.76827533)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00197546 (0.00199076), PSNR 27.04330826 (27.03253342), SSIM 0.78787333 (0.78270024)
# Finished training epoch 143
# Validate: MSE 0.00238347 (0.00225155), PSNR 26.22791100 (26.53109508), SSIM 0.71914262 (0.77022311)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00192425 (0.00197993), PSNR 27.15737343 (27.05459313), SSIM 0.79586130 (0.78281107)
# Finished training epoch 144
# Validate: MSE 0.00272053 (0.00231667), PSNR 25.65345764 (26.41773118), SSIM 0.71398020 (0.77408249)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00186129 (0.00199855), PSNR 27.30186272 (27.01527041), SSIM 0.78166163 (0.78228687)
# Finished training epoch 145
# Validate: MSE 0.00250315 (0.00231080), PSNR 26.01513863 (26.43756602), SSIM 0.71867335 (0.77556718)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00246530 (0.00196980), PSNR 26.08129692 (27.07882688), SSIM 0.77928543 (0.78297608)
# Finished training epoch 146
# Validate: MSE 0.00249478 (0.00271787), PSNR 26.02968025 (25.69389131), SSIM 0.71544737 (0.76601011)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00205487 (0.00313272), PSNR 26.87215233 (26.03833244), SSIM 0.77527541 (0.77469906)
# Finished training epoch 147
# Validate: MSE 0.00276708 (0.00231161), PSNR 25.57978058 (26.41870582), SSIM 0.69941378 (0.76594988)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00209210 (0.00205526), PSNR 26.79417038 (26.89754070), SSIM 0.78733671 (0.78192665)
# Finished training epoch 148
# Validate: MSE 0.00331750 (0.00269810), PSNR 24.79188919 (25.74868487), SSIM 0.70916700 (0.77031490)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00169939 (0.00198971), PSNR 27.69706535 (27.03309906), SSIM 0.80570382 (0.78243276)
# Finished training epoch 149
# Validate: MSE 0.00256579 (0.00220735), PSNR 25.90778542 (26.62429264), SSIM 0.70952654 (0.77388800)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00186068 (0.00198608), PSNR 27.30328941 (27.03855431), SSIM 0.77783382 (0.78263983)
# Finished training epoch 150
# Validate: MSE 0.00379341 (0.00312832), PSNR 24.20970535 (25.15906070), SSIM 0.68857479 (0.75592672)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00151952 (0.00197084), PSNR 28.18293762 (27.07513978), SSIM 0.80217761 (0.78282733)
# Finished training epoch 151
# Validate: MSE 0.00291789 (0.00237604), PSNR 25.34931183 (26.30775438), SSIM 0.71536672 (0.77403363)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00201325 (0.00194350), PSNR 26.96101189 (27.13477021), SSIM 0.79585755 (0.78307308)
# Finished training epoch 152
# Validate: MSE 0.00230472 (0.00253011), PSNR 26.37382507 (26.04408279), SSIM 0.71721196 (0.76342731)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00160015 (0.00194121), PSNR 27.95840454 (27.13973628), SSIM 0.81050479 (0.78300999)
# Finished training epoch 153
# Validate: MSE 0.00280744 (0.00225930), PSNR 25.51688766 (26.52108144), SSIM 0.71455336 (0.77633823)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00220314 (0.00192759), PSNR 26.56957626 (27.17045963), SSIM 0.79166299 (0.78347981)
# Finished training epoch 154
# Validate: MSE 0.00273663 (0.00250431), PSNR 25.62784386 (26.07141058), SSIM 0.70740533 (0.76436448)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00173020 (0.00192083), PSNR 27.61902428 (27.18401372), SSIM 0.79303789 (0.78334445)
# Finished training epoch 155
# Validate: MSE 0.00260129 (0.00222009), PSNR 25.84811211 (26.60090976), SSIM 0.71213883 (0.77574942)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00190186 (0.00191551), PSNR 27.20821571 (27.19826024), SSIM 0.78607070 (0.78305870)
# Finished training epoch 156
# Validate: MSE 0.00244702 (0.00234788), PSNR 26.11361885 (26.35199273), SSIM 0.71629000 (0.76896726)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00201905 (0.00190418), PSNR 26.94853210 (27.22184428), SSIM 0.79313391 (0.78323322)
# Finished training epoch 157
# Validate: MSE 0.00253585 (0.00231235), PSNR 25.95875359 (26.41804670), SSIM 0.70961839 (0.76644050)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00209598 (0.00192388), PSNR 26.78613472 (27.17802195), SSIM 0.78707802 (0.78296500)
# Finished training epoch 158
# Validate: MSE 0.00294684 (0.00258783), PSNR 25.30643272 (25.94136615), SSIM 0.70355976 (0.76761188)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00208900 (0.00189281), PSNR 26.80062485 (27.24882050), SSIM 0.77208495 (0.78298367)
# Finished training epoch 159
# Validate: MSE 0.00401795 (0.00348601), PSNR 23.95995712 (24.66575080), SSIM 0.69147050 (0.74261735)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00158768 (0.00190848), PSNR 27.99237442 (27.21276297), SSIM 0.80308187 (0.78298409)
# Finished training epoch 160
# Validate: MSE 0.00270320 (0.00226563), PSNR 25.68121529 (26.50845855), SSIM 0.71806419 (0.77176773)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00165482 (0.00188915), PSNR 27.81249428 (27.26090285), SSIM 0.81070626 (0.78284492)
# Finished training epoch 161
# Validate: MSE 0.00327240 (0.00245886), PSNR 24.85133553 (26.15990149), SSIM 0.70130897 (0.77168214)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00186126 (0.00190137), PSNR 27.30193520 (27.23007863), SSIM 0.78729093 (0.78272925)
# Finished training epoch 162
# Validate: MSE 0.00249999 (0.00229737), PSNR 26.02060890 (26.44214264), SSIM 0.70818412 (0.76476155)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00202962 (0.00188468), PSNR 26.92584801 (27.26599609), SSIM 0.77774858 (0.78286887)
# Finished training epoch 163
# Validate: MSE 0.00269561 (0.00244404), PSNR 25.69342804 (26.17927650), SSIM 0.70912671 (0.77043814)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00212124 (0.00190315), PSNR 26.73410416 (27.22552476), SSIM 0.77977967 (0.78241892)
# Finished training epoch 164
# Validate: MSE 0.00246521 (0.00239320), PSNR 26.08146667 (26.26392493), SSIM 0.71225113 (0.76809187)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00212192 (0.00187008), PSNR 26.73270416 (27.29904641), SSIM 0.76702267 (0.78274266)
# Finished training epoch 165
# Validate: MSE 0.00268176 (0.00229534), PSNR 25.71580124 (26.44871733), SSIM 0.71060151 (0.76957019)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00228904 (0.00188189), PSNR 26.40347481 (27.27207886), SSIM 0.77460331 (0.78251237)
# Finished training epoch 166
# Validate: MSE 0.00259282 (0.00265098), PSNR 25.86227798 (25.81949998), SSIM 0.70638788 (0.75964056)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00186119 (0.00189243), PSNR 27.30208969 (27.24942460), SSIM 0.76880127 (0.78238302)
# Finished training epoch 167
# Validate: MSE 0.00273081 (0.00230498), PSNR 25.63707924 (26.43424384), SSIM 0.70678771 (0.76753778)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00207731 (0.00185716), PSNR 26.82497978 (27.33089959), SSIM 0.78026831 (0.78293034)
# Finished training epoch 168
# Validate: MSE 0.00270365 (0.00233850), PSNR 25.68049049 (26.37376708), SSIM 0.70993149 (0.76736728)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00209411 (0.00186538), PSNR 26.79000282 (27.31198046), SSIM 0.78460729 (0.78258931)
# Finished training epoch 169
# Validate: MSE 0.00288977 (0.00239783), PSNR 25.39136314 (26.25794886), SSIM 0.68653071 (0.76197111)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00211194 (0.00185607), PSNR 26.75318146 (27.33417258), SSIM 0.75826633 (0.78266329)
# Finished training epoch 170
# Validate: MSE 0.00263840 (0.00309639), PSNR 25.78658295 (25.15980431), SSIM 0.70993078 (0.76032078)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00201824 (0.00188749), PSNR 26.95027542 (27.26345342), SSIM 0.77450782 (0.78175957)
# Finished training epoch 171
# Validate: MSE 0.00259488 (0.00232265), PSNR 25.85881996 (26.40144259), SSIM 0.70674664 (0.76320868)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00172270 (0.00183520), PSNR 27.63789749 (27.38479435), SSIM 0.78251940 (0.78294191)
# Finished training epoch 172
# Validate: MSE 0.00232365 (0.00234164), PSNR 26.33829880 (26.35144750), SSIM 0.70496482 (0.76184987)
# Finished validation.
# Starting training epoch 173
# Epoch: 173, MSE 0.00204526 (0.00184329), PSNR 26.89251900 (27.36323882), SSIM 0.78499568 (0.78244463)
# Finished training epoch 173
# Validate: MSE 0.00254447 (0.00244224), PSNR 25.94402122 (26.16618751), SSIM 0.69744772 (0.76183818)
# Finished validation.
# Starting training epoch 174
# Epoch: 174, MSE 0.00180466 (0.00185201), PSNR 27.43605232 (27.34369832), SSIM 0.76609361 (0.78214340)
# Finished training epoch 174
# Validate: MSE 0.00261388 (0.00248963), PSNR 25.82714462 (26.08272133), SSIM 0.69284165 (0.75128003)
# Finished validation.
# Starting training epoch 175
# Epoch: 175, MSE 0.00210684 (0.00184383), PSNR 26.76368523 (27.36156499), SSIM 0.78324997 (0.78236073)
# Finished training epoch 175
# Validate: MSE 0.00285081 (0.00287401), PSNR 25.45031929 (25.48669322), SSIM 0.68977386 (0.75171673)
# Finished validation.
# Starting training epoch 176
# Epoch: 176, MSE 0.00189479 (0.00182096), PSNR 27.22438622 (27.41422915), SSIM 0.78662342 (0.78265349)
# Finished training epoch 176
# Validate: MSE 0.00292483 (0.00234459), PSNR 25.33899498 (26.36387044), SSIM 0.69299424 (0.76641923)
# Finished validation.
# Starting training epoch 177
# Epoch: 177, MSE 0.00209514 (0.00180969), PSNR 26.78786087 (27.44129165), SSIM 0.79064858 (0.78259004)
# Finished training epoch 177
# Validate: MSE 0.00296850 (0.00234497), PSNR 25.27462387 (26.36127526), SSIM 0.70102060 (0.77004201)
# Finished validation.
# Starting training epoch 178
# Epoch: 178, MSE 0.00211100 (0.00185646), PSNR 26.75510597 (27.33455503), SSIM 0.75674593 (0.78189710)
# Finished training epoch 178
# Validate: MSE 0.00271676 (0.00260294), PSNR 25.65948677 (25.90266411), SSIM 0.68931848 (0.75610814)
# Finished validation.
# Starting training epoch 179
# Epoch: 179, MSE 0.00166700 (0.00180967), PSNR 27.78064156 (27.44500702), SSIM 0.79520816 (0.78252738)
# Finished training epoch 179
# Validate: MSE 0.00271178 (0.00233282), PSNR 25.66745567 (26.37640477), SSIM 0.71105450 (0.76067672)
# Finished validation.
# Starting training epoch 180
# Epoch: 180, MSE 0.00182709 (0.00180492), PSNR 27.38238716 (27.45499499), SSIM 0.76443368 (0.78275754)
# Finished training epoch 180
# Validate: MSE 0.00259649 (0.00260914), PSNR 25.85613823 (25.91951284), SSIM 0.70870763 (0.75952915)
# Finished validation.
# Starting training epoch 181
# Epoch: 181, MSE 0.00183861 (0.00179519), PSNR 27.35510254 (27.47653639), SSIM 0.77443421 (0.78287231)
# Finished training epoch 181
# Validate: MSE 0.00268578 (0.00231397), PSNR 25.70929909 (26.41658488), SSIM 0.70813560 (0.76535633)
# Finished validation.
# Starting training epoch 182
# Epoch: 182, MSE 0.00180818 (0.00180853), PSNR 27.42757797 (27.44763509), SSIM 0.78430814 (0.78256241)
# Finished training epoch 182
# Validate: MSE 0.00291343 (0.00263111), PSNR 25.35595894 (25.85979900), SSIM 0.69786203 (0.74774298)
# Finished validation.
# Starting training epoch 183
# Epoch: 183, MSE 0.00176067 (0.00182073), PSNR 27.54321289 (27.41750909), SSIM 0.78204238 (0.78252040)
# Finished training epoch 183
# Validate: MSE 0.00254914 (0.00237967), PSNR 25.93605804 (26.28317794), SSIM 0.69322228 (0.76383973)
# Finished validation.
# Starting training epoch 184
# Epoch: 184, MSE 0.00178765 (0.00178626), PSNR 27.47718048 (27.49829014), SSIM 0.77409053 (0.78253994)
# Finished training epoch 184
# Validate: MSE 0.00277640 (0.00237428), PSNR 25.56518555 (26.30042637), SSIM 0.70456553 (0.76405229)
# Finished validation.
# Starting training epoch 185
# Epoch: 185, MSE 0.00161726 (0.00180485), PSNR 27.91220093 (27.45719225), SSIM 0.79086959 (0.78246560)
# Finished training epoch 185
# Validate: MSE 0.00314047 (0.00296941), PSNR 25.03004837 (25.36124454), SSIM 0.69576967 (0.75599450)
# Finished validation.
# Starting training epoch 186
# Epoch: 186, MSE 0.00192222 (0.00176704), PSNR 27.16197205 (27.54127111), SSIM 0.77238894 (0.78307943)
# Finished training epoch 186
# Validate: MSE 0.00256746 (0.00238741), PSNR 25.90497017 (26.28478291), SSIM 0.70388424 (0.76261520)
# Finished validation.
# Starting training epoch 187
# Epoch: 187, MSE 0.00164704 (0.00177758), PSNR 27.83295059 (27.52037400), SSIM 0.78679860 (0.78267609)
# Finished training epoch 187
# Validate: MSE 0.00247096 (0.00230260), PSNR 26.07134819 (26.43576533), SSIM 0.71141231 (0.76265808)
# Finished validation.
# Starting training epoch 188
# Epoch: 188, MSE 0.00181980 (0.00177103), PSNR 27.39976120 (27.53629747), SSIM 0.77783173 (0.78272184)
# Finished training epoch 188
# Validate: MSE 0.00311609 (0.00248564), PSNR 25.06389236 (26.10709756), SSIM 0.68353540 (0.75937109)
# Finished validation.
# Starting training epoch 189
# Epoch: 189, MSE 0.00159922 (0.00180174), PSNR 27.96091080 (27.46190617), SSIM 0.79181987 (0.78247371)
# Finished training epoch 189
# Validate: MSE 0.00285387 (0.00238440), PSNR 25.44565582 (26.27403568), SSIM 0.69223452 (0.76136495)
# Finished validation.
# Starting training epoch 190
# Epoch: 190, MSE 0.00184648 (0.00175820), PSNR 27.33655167 (27.56691785), SSIM 0.76861650 (0.78291472)
# Finished training epoch 190
# Validate: MSE 0.00262255 (0.00237110), PSNR 25.81275368 (26.30683590), SSIM 0.70163667 (0.75853913)
# Finished validation.
# Starting training epoch 191
# Epoch: 191, MSE 0.00184801 (0.00175617), PSNR 27.33294868 (27.57335175), SSIM 0.78463697 (0.78296453)
# Finished training epoch 191
# Validate: MSE 0.00307418 (0.00234906), PSNR 25.12271309 (26.35379771), SSIM 0.68975711 (0.76291581)
# Finished validation.
# Starting training epoch 192
# Epoch: 192, MSE 0.00189823 (0.00174662), PSNR 27.21651268 (27.59545316), SSIM 0.77695423 (0.78300351)
# Finished training epoch 192
# Validate: MSE 0.00291086 (0.00242353), PSNR 25.35977936 (26.20415350), SSIM 0.69418204 (0.76486331)
# Finished validation.
# Starting training epoch 193
# Epoch: 193, MSE 0.00158398 (0.00181359), PSNR 28.00249863 (27.44239360), SSIM 0.77498692 (0.78171001)
# Finished training epoch 193
# Validate: MSE 0.00299366 (0.00235168), PSNR 25.23796844 (26.35174366), SSIM 0.69547844 (0.76874350)
# Finished validation.
# Starting training epoch 194
# Epoch: 194, MSE 0.00198044 (0.00173095), PSNR 27.03237152 (27.63729116), SSIM 0.78911835 (0.78326800)
# Finished training epoch 194
# Validate: MSE 0.00258554 (0.00240742), PSNR 25.87448883 (26.24407675), SSIM 0.70120502 (0.76253842)
# Finished validation.
# Starting training epoch 195
# Epoch: 195, MSE 0.00190449 (0.00172605), PSNR 27.20220947 (27.64742979), SSIM 0.77386111 (0.78298203)
# Finished training epoch 195
# Validate: MSE 0.00262689 (0.00233505), PSNR 25.80558014 (26.36826903), SSIM 0.70297515 (0.76776416)
# Finished validation.
# Starting training epoch 196
# Epoch: 196, MSE 0.00173982 (0.00173698), PSNR 27.59494972 (27.61955667), SSIM 0.78665859 (0.78287042)
# Finished training epoch 196
# Validate: MSE 0.00264327 (0.00235181), PSNR 25.77858162 (26.33246341), SSIM 0.70009589 (0.75955606)
# Finished validation.
# Starting training epoch 197
# Epoch: 197, MSE 0.00181705 (0.00173292), PSNR 27.40632439 (27.62806317), SSIM 0.77958190 (0.78294334)
# Finished training epoch 197
# Validate: MSE 0.00261848 (0.00283446), PSNR 25.81951523 (25.51519340), SSIM 0.70106030 (0.75958886)
# Finished validation.
# Starting training epoch 198
# Epoch: 198, MSE 0.00165182 (0.00172438), PSNR 27.82035828 (27.64940628), SSIM 0.79060400 (0.78316548)
# Finished training epoch 198
# Validate: MSE 0.00265272 (0.00240146), PSNR 25.76308250 (26.25234928), SSIM 0.69487977 (0.75721569)
# Finished validation.
# Starting training epoch 199
# Epoch: 199, MSE 0.00170829 (0.00173166), PSNR 27.67438316 (27.63229904), SSIM 0.77854097 (0.78312127)
# Finished training epoch 199
# Validate: MSE 0.00274528 (0.00235277), PSNR 25.61413574 (26.34373093), SSIM 0.69921041 (0.76140056)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00274528 (0.00235277), PSNR 25.61413574 (26.34373093), SSIM 0.69921052 (0.76140055)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
