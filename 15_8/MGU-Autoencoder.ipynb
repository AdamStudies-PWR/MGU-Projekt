# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-dca8bdcb254fbbd0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-dca8bdcb254fbbd0");
#           const url = new URL("/", window.location);
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
class Autoencoder(nn.Module):
  def __init__(self, input_size=128):
    super(Autoencoder, self).__init__()

    self.encoder = nn.Sequential(       
      nn.Conv2d(1, 16, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode),
      nn.BatchNorm2d(16),
      nn.LeakyReLU(0.1),
      nn.AvgPool2d(kernel_size=3, stride=2, padding=1),
      nn.Conv2d(16, 32, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode),
      nn.BatchNorm2d(32),
      nn.LeakyReLU(0.1),
      nn.AvgPool2d(kernel_size=3, stride=2, padding=1),
    )     
        
    self.decoder = nn.Sequential(  
      nn.ConvTranspose2d(32, 16, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
      nn.BatchNorm2d(16),
      nn.LeakyReLU(0.1),
      nn.Upsample(scale_factor=scale_factor),
      nn.ConvTranspose2d(16, 8, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
      nn.BatchNorm2d(8),
      nn.LeakyReLU(0.1),
      nn.ConvTranspose2d(8, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
      nn.Upsample(scale_factor=scale_factor)
    )

  def forward(self, input):

    encoder = self.encoder(input)
    # Upsample to get colors
    output = self.decoder(encoder)
    return output

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             160
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#          LeakyReLU-3           [-1, 16, 32, 32]               0
#          AvgPool2d-4           [-1, 16, 16, 16]               0
#             Conv2d-5           [-1, 32, 16, 16]           4,640
#        BatchNorm2d-6           [-1, 32, 16, 16]              64
#          LeakyReLU-7           [-1, 32, 16, 16]               0
#          AvgPool2d-8             [-1, 32, 8, 8]               0
#    ConvTranspose2d-9             [-1, 16, 8, 8]           4,624
#       BatchNorm2d-10             [-1, 16, 8, 8]              32
#         LeakyReLU-11             [-1, 16, 8, 8]               0
#          Upsample-12           [-1, 16, 16, 16]               0
#   ConvTranspose2d-13            [-1, 8, 16, 16]           1,160
#       BatchNorm2d-14            [-1, 8, 16, 16]              16
#         LeakyReLU-15            [-1, 8, 16, 16]               0
#   ConvTranspose2d-16            [-1, 2, 16, 16]             146
#          Upsample-17            [-1, 2, 32, 32]               0
# ================================================================
# Total params: 10,874
# Trainable params: 10,874
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.73
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.78
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00275531 (0.01428257), PSNR 25.59829712 (22.37121229), SSIM 0.69594574 (0.54040935)
# Finished training epoch 0
# Validate: MSE 0.00351311 (0.00308461), PSNR 24.54307747 (25.16439119), SSIM 0.60646254 (0.67288071)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00312446 (0.00308439), PSNR 25.05224800 (25.13583221), SSIM 0.71817482 (0.70214228)
# Finished training epoch 1
# Validate: MSE 0.00318243 (0.00287413), PSNR 24.97241211 (25.49370896), SSIM 0.65479648 (0.72248936)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00290605 (0.00288649), PSNR 25.36697006 (25.41846593), SSIM 0.75462329 (0.73352872)
# Finished training epoch 2
# Validate: MSE 0.00328390 (0.00276241), PSNR 24.83609390 (25.65244671), SSIM 0.67816436 (0.74270110)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00212826 (0.00279085), PSNR 26.71974373 (25.56373383), SSIM 0.78012627 (0.74768138)
# Finished training epoch 3
# Validate: MSE 0.00311074 (0.00272214), PSNR 25.07135582 (25.71734071), SSIM 0.68854338 (0.75421794)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00314023 (0.00267758), PSNR 25.03038216 (25.74167421), SSIM 0.73231041 (0.75475805)
# Finished training epoch 4
# Validate: MSE 0.00291176 (0.00286867), PSNR 25.35844231 (25.53305412), SSIM 0.69560903 (0.75785864)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00359820 (0.00262384), PSNR 24.43914795 (25.83241762), SSIM 0.73737943 (0.76103218)
# Finished training epoch 5
# Validate: MSE 0.00290336 (0.00319524), PSNR 25.37098885 (25.10046328), SSIM 0.69584900 (0.75622460)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00221252 (0.00258650), PSNR 26.55113029 (25.89704198), SSIM 0.76989460 (0.76526267)
# Finished training epoch 6
# Validate: MSE 0.00297228 (0.00260063), PSNR 25.26909447 (25.92578468), SSIM 0.70339167 (0.76626166)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00208395 (0.00255137), PSNR 26.81112099 (25.95483883), SSIM 0.77916443 (0.76775599)
# Finished training epoch 7
# Validate: MSE 0.00300069 (0.00274582), PSNR 25.22778702 (25.70936780), SSIM 0.70594776 (0.76829363)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00234504 (0.00253452), PSNR 26.29850388 (25.98584881), SSIM 0.75511712 (0.76991329)
# Finished training epoch 8
# Validate: MSE 0.00344764 (0.00312344), PSNR 24.62478256 (25.15679189), SSIM 0.69878346 (0.76279498)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00200510 (0.00250751), PSNR 26.97864532 (26.03068276), SSIM 0.77619368 (0.77146966)
# Finished training epoch 9
# Validate: MSE 0.00326874 (0.00292167), PSNR 24.85618973 (25.43818499), SSIM 0.70292008 (0.76602963)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00344511 (0.00248419), PSNR 24.62797165 (26.07181281), SSIM 0.74718457 (0.77227235)
# Finished training epoch 10
# Validate: MSE 0.00372209 (0.00335438), PSNR 24.29212379 (24.87246759), SSIM 0.70021105 (0.76554420)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00240748 (0.00247770), PSNR 26.18437767 (26.08297606), SSIM 0.76833397 (0.77285058)
# Finished training epoch 11
# Validate: MSE 0.00284218 (0.00261635), PSNR 25.46348381 (25.91313762), SSIM 0.70492148 (0.77112113)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00234678 (0.00245041), PSNR 26.29527664 (26.13162199), SSIM 0.76842725 (0.77325507)
# Finished training epoch 12
# Validate: MSE 0.00309530 (0.00254215), PSNR 25.09297180 (26.02094919), SSIM 0.70646346 (0.77698701)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00191608 (0.00245530), PSNR 27.17586708 (26.12336586), SSIM 0.80258417 (0.77351795)
# Finished training epoch 13
# Validate: MSE 0.00355628 (0.00306754), PSNR 24.49003601 (25.23956960), SSIM 0.69913268 (0.76791878)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00196671 (0.00244262), PSNR 27.06258583 (26.14336940), SSIM 0.77736908 (0.77369818)
# Finished training epoch 14
# Validate: MSE 0.00300044 (0.00255550), PSNR 25.22815323 (25.99937806), SSIM 0.70458949 (0.77518739)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00314735 (0.00243063), PSNR 25.02054787 (26.16550865), SSIM 0.75544226 (0.77419576)
# Finished training epoch 15
# Validate: MSE 0.00287953 (0.00246085), PSNR 25.40679169 (26.15627010), SSIM 0.70660746 (0.77266036)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00274948 (0.00243889), PSNR 25.60749626 (26.15256022), SSIM 0.76550686 (0.77448190)
# Finished training epoch 16
# Validate: MSE 0.00315075 (0.00256435), PSNR 25.01585960 (25.98090255), SSIM 0.70832193 (0.77570610)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00215719 (0.00242875), PSNR 26.66112328 (26.16967876), SSIM 0.79100931 (0.77488003)
# Finished training epoch 17
# Validate: MSE 0.00277820 (0.00268838), PSNR 25.56237030 (25.81429408), SSIM 0.70743084 (0.77211853)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00198451 (0.00243417), PSNR 27.02347374 (26.15694870), SSIM 0.77378660 (0.77521672)
# Finished training epoch 18
# Validate: MSE 0.00276326 (0.00255887), PSNR 25.58578682 (26.00610408), SSIM 0.70751429 (0.77475061)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00226261 (0.00241267), PSNR 26.45390129 (26.19663611), SSIM 0.78519499 (0.77547900)
# Finished training epoch 19
# Validate: MSE 0.00282075 (0.00243080), PSNR 25.49635315 (26.21666411), SSIM 0.70912719 (0.77552305)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00255359 (0.00240768), PSNR 25.92849350 (26.20634668), SSIM 0.76751471 (0.77595086)
# Finished training epoch 20
# Validate: MSE 0.00306483 (0.00274603), PSNR 25.13592911 (25.70142217), SSIM 0.70620239 (0.77168326)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00227444 (0.00240317), PSNR 26.43124580 (26.21534415), SSIM 0.76124656 (0.77621204)
# Finished training epoch 21
# Validate: MSE 0.00284167 (0.00258499), PSNR 25.46425819 (25.96099640), SSIM 0.71314901 (0.77146329)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00260602 (0.00240682), PSNR 25.84021950 (26.21101634), SSIM 0.76194090 (0.77616971)
# Finished training epoch 22
# Validate: MSE 0.00278963 (0.00245945), PSNR 25.54453659 (26.16578520), SSIM 0.71497798 (0.77698759)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00246141 (0.00239861), PSNR 26.08816719 (26.22244390), SSIM 0.77708703 (0.77659682)
# Finished training epoch 23
# Validate: MSE 0.00279074 (0.00267222), PSNR 25.54280090 (25.79807253), SSIM 0.71097100 (0.76746143)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00213602 (0.00238658), PSNR 26.70394897 (26.24401310), SSIM 0.80109900 (0.77686468)
# Finished training epoch 24
# Validate: MSE 0.00360860 (0.00410044), PSNR 24.42660522 (24.00221917), SSIM 0.69730794 (0.75245136)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00249503 (0.00239047), PSNR 26.02924919 (26.23984237), SSIM 0.76864058 (0.77690892)
# Finished training epoch 25
# Validate: MSE 0.00291105 (0.00251504), PSNR 25.35949898 (26.06581431), SSIM 0.71452570 (0.77669579)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00234801 (0.00239414), PSNR 26.29299927 (26.23048702), SSIM 0.80235040 (0.77695498)
# Finished training epoch 26
# Validate: MSE 0.00293478 (0.00265709), PSNR 25.32424355 (25.84301496), SSIM 0.71353495 (0.77573410)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00225807 (0.00239280), PSNR 26.46261787 (26.23277713), SSIM 0.78851140 (0.77697795)
# Finished training epoch 27
# Validate: MSE 0.00262265 (0.00263128), PSNR 25.81259918 (25.89684611), SSIM 0.71337551 (0.77283043)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00245177 (0.00238664), PSNR 26.10519409 (26.24578686), SSIM 0.78289664 (0.77705244)
# Finished training epoch 28
# Validate: MSE 0.00275545 (0.00253309), PSNR 25.59806824 (26.03671060), SSIM 0.71500820 (0.77381777)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00203444 (0.00237153), PSNR 26.91554451 (26.27174885), SSIM 0.76954478 (0.77729605)
# Finished training epoch 29
# Validate: MSE 0.00280903 (0.00264390), PSNR 25.51443672 (25.88873216), SSIM 0.71554071 (0.77504837)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00264941 (0.00237731), PSNR 25.76850700 (26.26228870), SSIM 0.77750564 (0.77727714)
# Finished training epoch 30
# Validate: MSE 0.00278147 (0.00242621), PSNR 25.55726242 (26.21737292), SSIM 0.71381801 (0.77518859)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00239643 (0.00238306), PSNR 26.20434380 (26.25170577), SSIM 0.76977074 (0.77735051)
# Finished training epoch 31
# Validate: MSE 0.00276459 (0.00247291), PSNR 25.58369637 (26.13786753), SSIM 0.71592069 (0.77480525)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00216302 (0.00236378), PSNR 26.64939690 (26.28702376), SSIM 0.79141504 (0.77756324)
# Finished training epoch 32
# Validate: MSE 0.00268935 (0.00255389), PSNR 25.70353127 (26.00566684), SSIM 0.71148860 (0.77371371)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00177633 (0.00236283), PSNR 27.50475502 (26.28848740), SSIM 0.82513797 (0.77762321)
# Finished training epoch 33
# Validate: MSE 0.00300237 (0.00248659), PSNR 25.22535324 (26.11691762), SSIM 0.71151346 (0.77939351)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00225718 (0.00236741), PSNR 26.46433067 (26.27745552), SSIM 0.78091627 (0.77753909)
# Finished training epoch 34
# Validate: MSE 0.00283297 (0.00237071), PSNR 25.47757339 (26.32108748), SSIM 0.71500075 (0.77824352)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00227724 (0.00236084), PSNR 26.42591476 (26.29491905), SSIM 0.76033461 (0.77785568)
# Finished training epoch 35
# Validate: MSE 0.00272693 (0.00239181), PSNR 25.64325333 (26.27838951), SSIM 0.71466398 (0.77614007)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00192394 (0.00235898), PSNR 27.15808105 (26.29416069), SSIM 0.81663454 (0.77774174)
# Finished training epoch 36
# Validate: MSE 0.00268709 (0.00255395), PSNR 25.70717621 (26.01363412), SSIM 0.71670032 (0.77821151)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00209457 (0.00235557), PSNR 26.78904533 (26.30065132), SSIM 0.79121304 (0.77745603)
# Finished training epoch 37
# Validate: MSE 0.00272894 (0.00240041), PSNR 25.64006042 (26.25775313), SSIM 0.71264458 (0.76927897)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00242954 (0.00237303), PSNR 26.14475441 (26.27099590), SSIM 0.77260876 (0.77764756)
# Finished training epoch 38
# Validate: MSE 0.00276258 (0.00245011), PSNR 25.58684921 (26.17569592), SSIM 0.71543109 (0.77631082)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00255393 (0.00236515), PSNR 25.92791367 (26.28367540), SSIM 0.76942044 (0.77754574)
# Finished training epoch 39
# Validate: MSE 0.00268224 (0.00243349), PSNR 25.71502495 (26.19345691), SSIM 0.71205795 (0.77397965)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00198812 (0.00234766), PSNR 27.01557732 (26.31648047), SSIM 0.77476943 (0.77790938)
# Finished training epoch 40
# Validate: MSE 0.00263690 (0.00242796), PSNR 25.78906822 (26.20521385), SSIM 0.71228051 (0.77429638)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00251917 (0.00235078), PSNR 25.98742104 (26.31161219), SSIM 0.75913733 (0.77777681)
# Finished training epoch 41
# Validate: MSE 0.00268138 (0.00237015), PSNR 25.71641731 (26.31599309), SSIM 0.71266478 (0.77587408)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00270753 (0.00234476), PSNR 25.67427254 (26.32191478), SSIM 0.77490866 (0.77767709)
# Finished training epoch 42
# Validate: MSE 0.00296574 (0.00243251), PSNR 25.27866554 (26.21055956), SSIM 0.71216428 (0.77825963)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00206102 (0.00234203), PSNR 26.85918045 (26.32647207), SSIM 0.79202491 (0.77781129)
# Finished training epoch 43
# Validate: MSE 0.00273558 (0.00302488), PSNR 25.62950516 (25.33627364), SSIM 0.71139324 (0.77100573)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00207714 (0.00233960), PSNR 26.82533646 (26.33185220), SSIM 0.78137422 (0.77773273)
# Finished training epoch 44
# Validate: MSE 0.00278652 (0.00237295), PSNR 25.54937172 (26.31299565), SSIM 0.71557933 (0.77751716)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00248926 (0.00233937), PSNR 26.03928947 (26.33057089), SSIM 0.76534319 (0.77771782)
# Finished training epoch 45
# Validate: MSE 0.00277921 (0.00242178), PSNR 25.56078720 (26.23290859), SSIM 0.71065646 (0.77850978)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00251791 (0.00234710), PSNR 25.98959160 (26.31685211), SSIM 0.77950644 (0.77792302)
# Finished training epoch 46
# Validate: MSE 0.00279075 (0.00237772), PSNR 25.54279518 (26.30939565), SSIM 0.71517628 (0.77871335)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00228072 (0.00234408), PSNR 26.41928291 (26.32053208), SSIM 0.76729834 (0.77774574)
# Finished training epoch 47
# Validate: MSE 0.00282113 (0.00245829), PSNR 25.49576569 (26.16737274), SSIM 0.71335083 (0.77708100)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00233319 (0.00233583), PSNR 26.32049751 (26.33848510), SSIM 0.77153540 (0.77783778)
# Finished training epoch 48
# Validate: MSE 0.00261946 (0.00233683), PSNR 25.81787491 (26.37137559), SSIM 0.71414733 (0.77411638)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00247799 (0.00233298), PSNR 26.05900192 (26.34583836), SSIM 0.79273903 (0.77783354)
# Finished training epoch 49
# Validate: MSE 0.00295808 (0.00301092), PSNR 25.28990173 (25.29593406), SSIM 0.70827353 (0.76236996)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00228381 (0.00233442), PSNR 26.41339111 (26.33929727), SSIM 0.78178775 (0.77782054)
# Finished training epoch 50
# Validate: MSE 0.00267531 (0.00246981), PSNR 25.72626305 (26.15068663), SSIM 0.71727794 (0.77812333)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00286899 (0.00233091), PSNR 25.42270660 (26.34971821), SSIM 0.76228040 (0.77787829)
# Finished training epoch 51
# Validate: MSE 0.00274051 (0.00261547), PSNR 25.62168884 (25.88899102), SSIM 0.71272826 (0.76983248)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00246963 (0.00233591), PSNR 26.07368088 (26.33763733), SSIM 0.76882392 (0.77782665)
# Finished training epoch 52
# Validate: MSE 0.00270706 (0.00239752), PSNR 25.67501450 (26.25792673), SSIM 0.71601808 (0.77358418)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00269314 (0.00232791), PSNR 25.69741631 (26.35352007), SSIM 0.76693153 (0.77797272)
# Finished training epoch 53
# Validate: MSE 0.00287892 (0.00243042), PSNR 25.40769768 (26.21083364), SSIM 0.71473235 (0.77678826)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00243418 (0.00233201), PSNR 26.13647270 (26.34559308), SSIM 0.77936274 (0.77783219)
# Finished training epoch 54
# Validate: MSE 0.00265501 (0.00236171), PSNR 25.75934601 (26.32771151), SSIM 0.71484959 (0.77513215)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00229694 (0.00232699), PSNR 26.38850212 (26.35485850), SSIM 0.76083475 (0.77811080)
# Finished training epoch 55
# Validate: MSE 0.00270263 (0.00242356), PSNR 25.68213463 (26.22014391), SSIM 0.71269393 (0.77818074)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00228690 (0.00232852), PSNR 26.40753555 (26.35216533), SSIM 0.80234081 (0.77795643)
# Finished training epoch 56
# Validate: MSE 0.00314121 (0.00278219), PSNR 25.02903366 (25.65052936), SSIM 0.71135014 (0.77390562)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00216031 (0.00233010), PSNR 26.65483665 (26.35031854), SSIM 0.78576767 (0.77795226)
# Finished training epoch 57
# Validate: MSE 0.00284965 (0.00271088), PSNR 25.45207977 (25.79147684), SSIM 0.71518183 (0.77490468)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00269860 (0.00233213), PSNR 25.68862152 (26.34624639), SSIM 0.79635566 (0.77809768)
# Finished training epoch 58
# Validate: MSE 0.00281019 (0.00255427), PSNR 25.51263809 (26.01389713), SSIM 0.71312654 (0.77875919)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00253953 (0.00232381), PSNR 25.95246887 (26.36446798), SSIM 0.77083838 (0.77802456)
# Finished training epoch 59
# Validate: MSE 0.00269365 (0.00248006), PSNR 25.69659233 (26.13906499), SSIM 0.71773577 (0.77613896)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00218183 (0.00232454), PSNR 26.61178207 (26.36045342), SSIM 0.76604384 (0.77805854)
# Finished training epoch 60
# Validate: MSE 0.00256013 (0.00234995), PSNR 25.91738319 (26.35014611), SSIM 0.72237551 (0.77766985)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00253571 (0.00231752), PSNR 25.95899582 (26.37484795), SSIM 0.79070348 (0.77806196)
# Finished training epoch 61
# Validate: MSE 0.00268573 (0.00233902), PSNR 25.70937920 (26.37013261), SSIM 0.71839392 (0.77795417)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00295456 (0.00232916), PSNR 25.29506493 (26.35545602), SSIM 0.76136851 (0.77792484)
# Finished training epoch 62
# Validate: MSE 0.00270151 (0.00251746), PSNR 25.68392563 (26.05290200), SSIM 0.71984708 (0.77356328)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00278532 (0.00232416), PSNR 25.55124664 (26.36008893), SSIM 0.75294715 (0.77786088)
# Finished training epoch 63
# Validate: MSE 0.00272051 (0.00265163), PSNR 25.65349197 (25.87872835), SSIM 0.71603727 (0.77416796)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00190350 (0.00232153), PSNR 27.20447350 (26.36619524), SSIM 0.80654413 (0.77786252)
# Finished training epoch 64
# Validate: MSE 0.00270945 (0.00247957), PSNR 25.67118835 (26.14221672), SSIM 0.71678746 (0.77716890)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00217240 (0.00231409), PSNR 26.63060760 (26.37820114), SSIM 0.76512474 (0.77797541)
# Finished training epoch 65
# Validate: MSE 0.00262235 (0.00230671), PSNR 25.81309509 (26.43437505), SSIM 0.71804076 (0.77634551)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00177494 (0.00231116), PSNR 27.50817490 (26.38682632), SSIM 0.81724942 (0.77793034)
# Finished training epoch 66
# Validate: MSE 0.00266533 (0.00232555), PSNR 25.74248886 (26.40244987), SSIM 0.71938550 (0.77935841)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00239257 (0.00231407), PSNR 26.21135521 (26.37748274), SSIM 0.79196030 (0.77797493)
# Finished training epoch 67
# Validate: MSE 0.00269551 (0.00242050), PSNR 25.69359207 (26.22553594), SSIM 0.71163726 (0.77504070)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00232570 (0.00231403), PSNR 26.33446884 (26.38050988), SSIM 0.78212798 (0.77797635)
# Finished training epoch 68
# Validate: MSE 0.00280768 (0.00274246), PSNR 25.51652908 (25.70559544), SSIM 0.71628439 (0.76905277)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00240161 (0.00232372), PSNR 26.19498253 (26.36208548), SSIM 0.76309997 (0.77786810)
# Finished training epoch 69
# Validate: MSE 0.00291479 (0.00259608), PSNR 25.35392570 (25.93324773), SSIM 0.71656859 (0.77291342)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00217234 (0.00232214), PSNR 26.63072205 (26.36471720), SSIM 0.77815497 (0.77789979)
# Finished training epoch 70
# Validate: MSE 0.00275655 (0.00235490), PSNR 25.59633446 (26.35118248), SSIM 0.71661025 (0.77901623)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00231737 (0.00230931), PSNR 26.35003662 (26.38765184), SSIM 0.77209449 (0.77805894)
# Finished training epoch 71
# Validate: MSE 0.00272998 (0.00244729), PSNR 25.63840485 (26.17957662), SSIM 0.71993184 (0.77255231)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00208906 (0.00231534), PSNR 26.80048943 (26.37782397), SSIM 0.78382349 (0.77790865)
# Finished training epoch 72
# Validate: MSE 0.00282221 (0.00232341), PSNR 25.49411011 (26.40682930), SSIM 0.71526027 (0.77719632)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00225172 (0.00231281), PSNR 26.47486305 (26.38269620), SSIM 0.79180706 (0.77797356)
# Finished training epoch 73
# Validate: MSE 0.00277716 (0.00231538), PSNR 25.56399536 (26.42153984), SSIM 0.71863985 (0.77838110)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00198600 (0.00230759), PSNR 27.02020264 (26.38930010), SSIM 0.79098189 (0.77811043)
# Finished training epoch 74
# Validate: MSE 0.00282276 (0.00244854), PSNR 25.49326324 (26.17730035), SSIM 0.70799673 (0.77277061)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00233232 (0.00230355), PSNR 26.32211685 (26.39866645), SSIM 0.77718163 (0.77787494)
# Finished training epoch 75
# Validate: MSE 0.00282448 (0.00238405), PSNR 25.49060822 (26.29694354), SSIM 0.71551305 (0.77823732)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00220739 (0.00231052), PSNR 26.56119919 (26.38601708), SSIM 0.78878629 (0.77776540)
# Finished training epoch 76
# Validate: MSE 0.00299893 (0.00253969), PSNR 25.23033333 (26.03145767), SSIM 0.71207291 (0.77678062)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00249735 (0.00230211), PSNR 26.02520943 (26.40188608), SSIM 0.75777376 (0.77793481)
# Finished training epoch 77
# Validate: MSE 0.00294680 (0.00235528), PSNR 25.30649757 (26.34930841), SSIM 0.71321416 (0.78027283)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00261370 (0.00231036), PSNR 25.82743835 (26.38705826), SSIM 0.76506293 (0.77788970)
# Finished training epoch 78
# Validate: MSE 0.00276164 (0.00247340), PSNR 25.58833694 (26.13381197), SSIM 0.71315002 (0.77239480)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00237986 (0.00230556), PSNR 26.23448753 (26.39422621), SSIM 0.76674330 (0.77795494)
# Finished training epoch 79
# Validate: MSE 0.00277251 (0.00233767), PSNR 25.57126236 (26.37561966), SSIM 0.71502352 (0.77930922)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00175452 (0.00230456), PSNR 27.55842590 (26.39781538), SSIM 0.82259607 (0.77789322)
# Finished training epoch 80
# Validate: MSE 0.00277299 (0.00239710), PSNR 25.57052231 (26.27129594), SSIM 0.71523649 (0.78154877)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00275825 (0.00230813), PSNR 25.59366417 (26.39001399), SSIM 0.78260583 (0.77787349)
# Finished training epoch 81
# Validate: MSE 0.00290257 (0.00239417), PSNR 25.37217903 (26.28069663), SSIM 0.71728683 (0.77955080)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00242051 (0.00230576), PSNR 26.16093254 (26.39205518), SSIM 0.77030408 (0.77804284)
# Finished training epoch 82
# Validate: MSE 0.00278409 (0.00237046), PSNR 25.55317307 (26.32141281), SSIM 0.71685129 (0.77885796)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00209123 (0.00230275), PSNR 26.79597855 (26.40104424), SSIM 0.78990793 (0.77805466)
# Finished training epoch 83
# Validate: MSE 0.00277407 (0.00232531), PSNR 25.56883240 (26.39830342), SSIM 0.71410644 (0.77883287)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00206035 (0.00230297), PSNR 26.86058807 (26.40137208), SSIM 0.77697110 (0.77798927)
# Finished training epoch 84
# Validate: MSE 0.00286130 (0.00243826), PSNR 25.43436432 (26.19474869), SSIM 0.71578443 (0.77532916)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00257320 (0.00230533), PSNR 25.89525414 (26.39663212), SSIM 0.76036310 (0.77797672)
# Finished training epoch 85
# Validate: MSE 0.00266970 (0.00244262), PSNR 25.73537254 (26.18401873), SSIM 0.70707709 (0.77201222)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00246685 (0.00230392), PSNR 26.07857895 (26.39972301), SSIM 0.78097057 (0.77790582)
# Finished training epoch 86
# Validate: MSE 0.00272666 (0.00234889), PSNR 25.64368248 (26.35805213), SSIM 0.71609294 (0.77771948)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00219707 (0.00229855), PSNR 26.58156586 (26.40960839), SSIM 0.78927362 (0.77812491)
# Finished training epoch 87
# Validate: MSE 0.00289376 (0.00255330), PSNR 25.38536835 (26.00281544), SSIM 0.71104968 (0.77294301)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00238524 (0.00229775), PSNR 26.22467613 (26.41015635), SSIM 0.81093997 (0.77804852)
# Finished training epoch 88
# Validate: MSE 0.00317262 (0.00260966), PSNR 24.98581505 (25.91723097), SSIM 0.71556234 (0.77988994)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00234727 (0.00230528), PSNR 26.29436684 (26.39482575), SSIM 0.76459533 (0.77796347)
# Finished training epoch 89
# Validate: MSE 0.00280183 (0.00270433), PSNR 25.52558327 (25.79533339), SSIM 0.71457577 (0.76751843)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00212640 (0.00229453), PSNR 26.72354126 (26.41547134), SSIM 0.77401680 (0.77805931)
# Finished training epoch 90
# Validate: MSE 0.00263600 (0.00275397), PSNR 25.79054070 (25.71588247), SSIM 0.71618813 (0.77222972)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00199332 (0.00230083), PSNR 27.00422287 (26.40349048), SSIM 0.80901796 (0.77807990)
# Finished training epoch 91
# Validate: MSE 0.00282215 (0.00238239), PSNR 25.49419785 (26.29954123), SSIM 0.71380514 (0.77517268)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00225153 (0.00229870), PSNR 26.47522926 (26.41091398), SSIM 0.78429496 (0.77824277)
# Finished training epoch 92
# Validate: MSE 0.00278278 (0.00237856), PSNR 25.55520630 (26.30435222), SSIM 0.71764469 (0.77743809)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00248996 (0.00230158), PSNR 26.03806686 (26.40313168), SSIM 0.77881849 (0.77802400)
# Finished training epoch 93
# Validate: MSE 0.00291461 (0.00271610), PSNR 25.35419655 (25.75185878), SSIM 0.70916027 (0.76932866)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00261442 (0.00230030), PSNR 25.82624054 (26.40643689), SSIM 0.73532057 (0.77800859)
# Finished training epoch 94
# Validate: MSE 0.00265014 (0.00246188), PSNR 25.76731873 (26.15178564), SSIM 0.71010339 (0.77714752)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00184185 (0.00229957), PSNR 27.34746361 (26.40670748), SSIM 0.78573859 (0.77808906)
# Finished training epoch 95
# Validate: MSE 0.00290714 (0.00239728), PSNR 25.36533737 (26.27436472), SSIM 0.71321076 (0.77776437)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00240634 (0.00229738), PSNR 26.18642616 (26.41045570), SSIM 0.77356070 (0.77799731)
# Finished training epoch 96
# Validate: MSE 0.00265365 (0.00231876), PSNR 25.76156807 (26.40834070), SSIM 0.71239358 (0.77758062)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00247465 (0.00229874), PSNR 26.06485939 (26.40802887), SSIM 0.76222622 (0.77790618)
# Finished training epoch 97
# Validate: MSE 0.00283609 (0.00237356), PSNR 25.47279167 (26.31335173), SSIM 0.71702123 (0.77944690)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00192651 (0.00229909), PSNR 27.15228081 (26.40814134), SSIM 0.79203004 (0.77809660)
# Finished training epoch 98
# Validate: MSE 0.00259776 (0.00261822), PSNR 25.85401535 (25.91471081), SSIM 0.71078885 (0.77102889)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00213819 (0.00229018), PSNR 26.69954109 (26.42792075), SSIM 0.79208010 (0.77809485)
# Finished training epoch 99
# Validate: MSE 0.00266676 (0.00232495), PSNR 25.74016571 (26.39929576), SSIM 0.71679473 (0.78104517)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00236728 (0.00229612), PSNR 26.25749779 (26.41148544), SSIM 0.77554762 (0.77810212)
# Finished training epoch 100
# Validate: MSE 0.00276222 (0.00248270), PSNR 25.58741760 (26.12694856), SSIM 0.70595443 (0.76934755)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00233511 (0.00229530), PSNR 26.31693077 (26.41534264), SSIM 0.77766961 (0.77811563)
# Finished training epoch 101
# Validate: MSE 0.00262607 (0.00229165), PSNR 25.80694008 (26.45736879), SSIM 0.71719790 (0.77721475)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00230563 (0.00229885), PSNR 26.37209892 (26.40736589), SSIM 0.75773078 (0.77808966)
# Finished training epoch 102
# Validate: MSE 0.00276816 (0.00243225), PSNR 25.57808304 (26.20074000), SSIM 0.71385467 (0.77638623)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00216605 (0.00229003), PSNR 26.64332390 (26.42714233), SSIM 0.77476174 (0.77811623)
# Finished training epoch 103
# Validate: MSE 0.00265474 (0.00234095), PSNR 25.75977707 (26.36688000), SSIM 0.71850479 (0.77225147)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00254220 (0.00229722), PSNR 25.94789696 (26.41186585), SSIM 0.78952926 (0.77805569)
# Finished training epoch 104
# Validate: MSE 0.00257396 (0.00245861), PSNR 25.89397430 (26.15335597), SSIM 0.71933395 (0.77134385)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00256812 (0.00229866), PSNR 25.90385246 (26.40821210), SSIM 0.75382531 (0.77802044)
# Finished training epoch 105
# Validate: MSE 0.00270742 (0.00243545), PSNR 25.67443657 (26.20095940), SSIM 0.71249294 (0.77641373)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00255230 (0.00229119), PSNR 25.93068695 (26.42012108), SSIM 0.77507591 (0.77814088)
# Finished training epoch 106
# Validate: MSE 0.00274676 (0.00237068), PSNR 25.61179924 (26.31348730), SSIM 0.71441412 (0.77177901)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00263915 (0.00228943), PSNR 25.78536415 (26.42731835), SSIM 0.76584268 (0.77809141)
# Finished training epoch 107
# Validate: MSE 0.00285100 (0.00241898), PSNR 25.45002556 (26.23502331), SSIM 0.71597004 (0.77579808)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00191951 (0.00230064), PSNR 27.16810417 (26.40379332), SSIM 0.80287665 (0.77795716)
# Finished training epoch 108
# Validate: MSE 0.00280277 (0.00232030), PSNR 25.52412415 (26.40847771), SSIM 0.71151364 (0.77641930)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00212865 (0.00229451), PSNR 26.71894646 (26.41570370), SSIM 0.77769816 (0.77804313)
# Finished training epoch 109
# Validate: MSE 0.00267331 (0.00260386), PSNR 25.72951317 (25.93466170), SSIM 0.71078497 (0.77239379)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00229080 (0.00228470), PSNR 26.40013123 (26.43726685), SSIM 0.76630437 (0.77811355)
# Finished training epoch 110
# Validate: MSE 0.00253150 (0.00251231), PSNR 25.96622658 (26.08004296), SSIM 0.71721137 (0.77450507)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00189194 (0.00229260), PSNR 27.23093414 (26.42043600), SSIM 0.78015387 (0.77803409)
# Finished training epoch 111
# Validate: MSE 0.00268289 (0.00243366), PSNR 25.71397209 (26.21532129), SSIM 0.71854615 (0.77882676)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00222777 (0.00228515), PSNR 26.52129555 (26.43050809), SSIM 0.76675093 (0.77804764)
# Finished training epoch 112
# Validate: MSE 0.00267829 (0.00229674), PSNR 25.72141647 (26.45143132), SSIM 0.71539748 (0.77792531)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00223304 (0.00228381), PSNR 26.51103783 (26.43708143), SSIM 0.77945739 (0.77806576)
# Finished training epoch 113
# Validate: MSE 0.00267055 (0.00269289), PSNR 25.73398972 (25.81140930), SSIM 0.71423459 (0.77323376)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00266771 (0.00228729), PSNR 25.73861313 (26.43064775), SSIM 0.77406037 (0.77823648)
# Finished training epoch 114
# Validate: MSE 0.00253742 (0.00258150), PSNR 25.95607376 (25.97378729), SSIM 0.71879953 (0.77298982)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00249365 (0.00229372), PSNR 26.03164291 (26.41771598), SSIM 0.77131975 (0.77811063)
# Finished training epoch 115
# Validate: MSE 0.00271085 (0.00233755), PSNR 25.66894150 (26.37824001), SSIM 0.71487558 (0.77745502)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00196935 (0.00228468), PSNR 27.05677986 (26.43640402), SSIM 0.78079188 (0.77824921)
# Finished training epoch 116
# Validate: MSE 0.00261787 (0.00232483), PSNR 25.82051468 (26.40401605), SSIM 0.71582794 (0.77618702)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00234316 (0.00228974), PSNR 26.30198288 (26.42349111), SSIM 0.78625429 (0.77822897)
# Finished training epoch 117
# Validate: MSE 0.00272845 (0.00231107), PSNR 25.64083862 (26.42190928), SSIM 0.71396714 (0.77500228)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00218012 (0.00228493), PSNR 26.61518669 (26.43205732), SSIM 0.77299190 (0.77809915)
# Finished training epoch 118
# Validate: MSE 0.00255417 (0.00239388), PSNR 25.92750359 (26.27220219), SSIM 0.71935624 (0.77275970)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00208920 (0.00228739), PSNR 26.80020714 (26.42838183), SSIM 0.77659070 (0.77825317)
# Finished training epoch 119
# Validate: MSE 0.00277768 (0.00266773), PSNR 25.56318283 (25.81835051), SSIM 0.71072239 (0.77509210)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00265448 (0.00228152), PSNR 25.76020050 (26.44267100), SSIM 0.76314890 (0.77829878)
# Finished training epoch 120
# Validate: MSE 0.00276342 (0.00287293), PSNR 25.58553505 (25.49825871), SSIM 0.71391785 (0.76529599)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00189115 (0.00229410), PSNR 27.23273277 (26.41864620), SSIM 0.78723425 (0.77810560)
# Finished training epoch 121
# Validate: MSE 0.00263303 (0.00228733), PSNR 25.79544449 (26.46628900), SSIM 0.71797013 (0.77774479)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00201793 (0.00228853), PSNR 26.95093155 (26.42872373), SSIM 0.80165005 (0.77821343)
# Finished training epoch 122
# Validate: MSE 0.00270254 (0.00255842), PSNR 25.68228149 (26.00425457), SSIM 0.71220112 (0.77318449)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00203919 (0.00228419), PSNR 26.90542984 (26.43501401), SSIM 0.77943587 (0.77820106)
# Finished training epoch 123
# Validate: MSE 0.00267325 (0.00231125), PSNR 25.72960472 (26.42825504), SSIM 0.71377194 (0.77739112)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00213975 (0.00228863), PSNR 26.69636917 (26.42746072), SSIM 0.77823019 (0.77808789)
# Finished training epoch 124
# Validate: MSE 0.00261230 (0.00241715), PSNR 25.82976532 (26.23448883), SSIM 0.71669352 (0.77063705)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00237611 (0.00228505), PSNR 26.24132919 (26.43899692), SSIM 0.76722217 (0.77820088)
# Finished training epoch 125
# Validate: MSE 0.00265285 (0.00230040), PSNR 25.76287460 (26.44359370), SSIM 0.71368593 (0.77867411)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00223479 (0.00228755), PSNR 26.50763512 (26.42888069), SSIM 0.77811444 (0.77820572)
# Finished training epoch 126
# Validate: MSE 0.00273075 (0.00250724), PSNR 25.63717651 (26.09215671), SSIM 0.71647358 (0.77381663)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00193149 (0.00228767), PSNR 27.14106941 (26.42829993), SSIM 0.78919107 (0.77828389)
# Finished training epoch 127
# Validate: MSE 0.00293877 (0.00241955), PSNR 25.31834602 (26.23832149), SSIM 0.71328032 (0.77807825)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00205337 (0.00228062), PSNR 26.87532425 (26.44409188), SSIM 0.77623618 (0.77811813)
# Finished training epoch 128
# Validate: MSE 0.00281768 (0.00237504), PSNR 25.50108910 (26.31105555), SSIM 0.71594512 (0.77874115)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00226086 (0.00228119), PSNR 26.45726776 (26.44147090), SSIM 0.78546786 (0.77832446)
# Finished training epoch 129
# Validate: MSE 0.00263847 (0.00240938), PSNR 25.78648376 (26.26013540), SSIM 0.71563113 (0.77927904)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00210733 (0.00228838), PSNR 26.76267433 (26.42964674), SSIM 0.78271550 (0.77812442)
# Finished training epoch 130
# Validate: MSE 0.00262598 (0.00237953), PSNR 25.80707741 (26.29633678), SSIM 0.71386766 (0.77421606)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00219491 (0.00228118), PSNR 26.58584023 (26.44321816), SSIM 0.77878934 (0.77829200)
# Finished training epoch 131
# Validate: MSE 0.00265609 (0.00231280), PSNR 25.75757408 (26.42528751), SSIM 0.71697068 (0.77974832)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00200806 (0.00227853), PSNR 26.97222900 (26.44626934), SSIM 0.80704290 (0.77828610)
# Finished training epoch 132
# Validate: MSE 0.00279966 (0.00246369), PSNR 25.52894783 (26.16228326), SSIM 0.71399057 (0.77723669)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00185086 (0.00228402), PSNR 27.32626534 (26.43751090), SSIM 0.78924018 (0.77808099)
# Finished training epoch 133
# Validate: MSE 0.00260867 (0.00228795), PSNR 25.83580780 (26.46604965), SSIM 0.71608782 (0.77433914)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00210577 (0.00229331), PSNR 26.76589203 (26.41763464), SSIM 0.78119040 (0.77804028)
# Finished training epoch 134
# Validate: MSE 0.00275696 (0.00236458), PSNR 25.59569359 (26.33070548), SSIM 0.71616292 (0.77519811)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00220164 (0.00228581), PSNR 26.57253838 (26.43534720), SSIM 0.77575338 (0.77826801)
# Finished training epoch 135
# Validate: MSE 0.00283121 (0.00231743), PSNR 25.48027420 (26.40955040), SSIM 0.70821023 (0.77499561)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00219856 (0.00228583), PSNR 26.57861900 (26.43112774), SSIM 0.78833151 (0.77810254)
# Finished training epoch 136
# Validate: MSE 0.00283634 (0.00254381), PSNR 25.47241592 (26.02137100), SSIM 0.71901315 (0.77445069)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00188185 (0.00228044), PSNR 27.25415611 (26.44201983), SSIM 0.79068261 (0.77824893)
# Finished training epoch 137
# Validate: MSE 0.00272671 (0.00232661), PSNR 25.64361572 (26.39602019), SSIM 0.71114069 (0.77407618)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00199989 (0.00228502), PSNR 26.98994446 (26.43285587), SSIM 0.79721159 (0.77816787)
# Finished training epoch 138
# Validate: MSE 0.00261464 (0.00279458), PSNR 25.82587814 (25.65789448), SSIM 0.71412969 (0.77433523)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00221322 (0.00227906), PSNR 26.54976273 (26.44262479), SSIM 0.77216935 (0.77826179)
# Finished training epoch 139
# Validate: MSE 0.00267778 (0.00233363), PSNR 25.72225189 (26.38605880), SSIM 0.71236229 (0.77935741)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00211923 (0.00227482), PSNR 26.73822021 (26.45293239), SSIM 0.79446179 (0.77829540)
# Finished training epoch 140
# Validate: MSE 0.00265671 (0.00254629), PSNR 25.75655174 (26.03629102), SSIM 0.71334052 (0.77517051)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00197920 (0.00228616), PSNR 27.03510475 (26.42951083), SSIM 0.79317176 (0.77819910)
# Finished training epoch 141
# Validate: MSE 0.00273357 (0.00271262), PSNR 25.63269615 (25.74416324), SSIM 0.71197140 (0.77286987)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00239069 (0.00228792), PSNR 26.21476936 (26.42786958), SSIM 0.78202522 (0.77820903)
# Finished training epoch 142
# Validate: MSE 0.00257578 (0.00228301), PSNR 25.89091682 (26.47780972), SSIM 0.71726120 (0.77645359)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00213148 (0.00228047), PSNR 26.71319389 (26.44085905), SSIM 0.77111036 (0.77817032)
# Finished training epoch 143
# Validate: MSE 0.00254783 (0.00236750), PSNR 25.93830109 (26.31506427), SSIM 0.71339989 (0.77346775)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00185944 (0.00228110), PSNR 27.30618286 (26.44121781), SSIM 0.78314477 (0.77815441)
# Finished training epoch 144
# Validate: MSE 0.00271330 (0.00234067), PSNR 25.66501808 (26.36150177), SSIM 0.71220762 (0.77435335)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00203076 (0.00227481), PSNR 26.92341614 (26.45548051), SSIM 0.77393347 (0.77817693)
# Finished training epoch 145
# Validate: MSE 0.00269916 (0.00233326), PSNR 25.68770981 (26.38830568), SSIM 0.71545684 (0.77937897)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00244505 (0.00227594), PSNR 26.11711502 (26.45334841), SSIM 0.77733749 (0.77820177)
# Finished training epoch 146
# Validate: MSE 0.00292390 (0.00245789), PSNR 25.34037399 (26.17301035), SSIM 0.71300685 (0.77846861)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00187536 (0.00227902), PSNR 27.26915741 (26.44827990), SSIM 0.78568739 (0.77836547)
# Finished training epoch 147
# Validate: MSE 0.00286915 (0.00240245), PSNR 25.42246819 (26.26918049), SSIM 0.71252793 (0.77812936)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00179342 (0.00227928), PSNR 27.46318817 (26.44449806), SSIM 0.78912783 (0.77819764)
# Finished training epoch 148
# Validate: MSE 0.00265074 (0.00240249), PSNR 25.76632881 (26.26912434), SSIM 0.71462566 (0.77932820)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00220216 (0.00227954), PSNR 26.57151413 (26.44656637), SSIM 0.76515281 (0.77804767)
# Finished training epoch 149
# Validate: MSE 0.00266671 (0.00229012), PSNR 25.74024773 (26.46317942), SSIM 0.71882051 (0.77960042)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00218347 (0.00229016), PSNR 26.60852432 (26.42503107), SSIM 0.78637570 (0.77832947)
# Finished training epoch 150
# Validate: MSE 0.00260264 (0.00231827), PSNR 25.84585571 (26.41220139), SSIM 0.71380830 (0.77480909)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00215557 (0.00227291), PSNR 26.66438293 (26.45849032), SSIM 0.78160381 (0.77842036)
# Finished training epoch 151
# Validate: MSE 0.00257532 (0.00236882), PSNR 25.89169312 (26.32354333), SSIM 0.71589643 (0.77712780)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00257274 (0.00227585), PSNR 25.89604568 (26.45298545), SSIM 0.78741992 (0.77831222)
# Finished training epoch 152
# Validate: MSE 0.00268112 (0.00226414), PSNR 25.71683311 (26.51280970), SSIM 0.71403021 (0.78174572)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00223211 (0.00227754), PSNR 26.51284981 (26.44509937), SSIM 0.77072960 (0.77819593)
# Finished training epoch 153
# Validate: MSE 0.00274656 (0.00235736), PSNR 25.61211014 (26.34854219), SSIM 0.71556664 (0.77964326)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00248734 (0.00228214), PSNR 26.04263878 (26.43767815), SSIM 0.75561351 (0.77828609)
# Finished training epoch 154
# Validate: MSE 0.00266994 (0.00229166), PSNR 25.73499107 (26.46203939), SSIM 0.71807152 (0.77697272)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00225501 (0.00227583), PSNR 26.46851158 (26.45082209), SSIM 0.76679122 (0.77822963)
# Finished training epoch 155
# Validate: MSE 0.00277610 (0.00287402), PSNR 25.56564331 (25.51671003), SSIM 0.70837009 (0.77101216)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00264663 (0.00227757), PSNR 25.77306366 (26.44744042), SSIM 0.76243716 (0.77833473)
# Finished training epoch 156
# Validate: MSE 0.00259798 (0.00225907), PSNR 25.85364532 (26.52204459), SSIM 0.71662271 (0.77981102)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00201959 (0.00227380), PSNR 26.94736099 (26.45594276), SSIM 0.78850466 (0.77826528)
# Finished training epoch 157
# Validate: MSE 0.00288378 (0.00244626), PSNR 25.40037346 (26.19617722), SSIM 0.71535051 (0.77983924)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00233525 (0.00227562), PSNR 26.31666565 (26.45117602), SSIM 0.78756118 (0.77822166)
# Finished training epoch 158
# Validate: MSE 0.00306492 (0.00253049), PSNR 25.13580894 (26.05274522), SSIM 0.71136928 (0.77856660)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00255866 (0.00227374), PSNR 25.91987038 (26.45591220), SSIM 0.76520914 (0.77828538)
# Finished training epoch 159
# Validate: MSE 0.00261717 (0.00228192), PSNR 25.82167435 (26.47599000), SSIM 0.71400112 (0.77916082)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00203907 (0.00227051), PSNR 26.90568352 (26.46205661), SSIM 0.78538311 (0.77847209)
# Finished training epoch 160
# Validate: MSE 0.00260283 (0.00230751), PSNR 25.84553909 (26.42949832), SSIM 0.71629572 (0.77794607)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00193254 (0.00228557), PSNR 27.13871193 (26.43565330), SSIM 0.77619946 (0.77806065)
# Finished training epoch 161
# Validate: MSE 0.00312105 (0.00300536), PSNR 25.05698586 (25.30826095), SSIM 0.71256399 (0.76485519)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00194070 (0.00228130), PSNR 27.12042427 (26.44175716), SSIM 0.79014999 (0.77848518)
# Finished training epoch 162
# Validate: MSE 0.00280717 (0.00237712), PSNR 25.51731491 (26.31213381), SSIM 0.71562684 (0.77760292)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00228134 (0.00227381), PSNR 26.41810226 (26.45402811), SSIM 0.77999324 (0.77827909)
# Finished training epoch 163
# Validate: MSE 0.00262435 (0.00239194), PSNR 25.80978203 (26.27361985), SSIM 0.71270818 (0.77576852)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00241154 (0.00227662), PSNR 26.17705536 (26.44986346), SSIM 0.77142602 (0.77823957)
# Finished training epoch 164
# Validate: MSE 0.00280686 (0.00229609), PSNR 25.51778603 (26.45477729), SSIM 0.71110266 (0.77845599)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00210730 (0.00227591), PSNR 26.76272774 (26.45244672), SSIM 0.78135604 (0.77824936)
# Finished training epoch 165
# Validate: MSE 0.00271640 (0.00236152), PSNR 25.66005898 (26.33930434), SSIM 0.71551174 (0.77686528)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00203788 (0.00226532), PSNR 26.90821266 (26.47270437), SSIM 0.79204881 (0.77840894)
# Finished training epoch 166
# Validate: MSE 0.00265271 (0.00252019), PSNR 25.76309967 (26.05868556), SSIM 0.71097958 (0.77254795)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00241258 (0.00227275), PSNR 26.17518425 (26.45696569), SSIM 0.78243130 (0.77840305)
# Finished training epoch 167
# Validate: MSE 0.00260785 (0.00230884), PSNR 25.83717155 (26.41969323), SSIM 0.71104348 (0.77434512)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00250376 (0.00227542), PSNR 26.01406860 (26.45080166), SSIM 0.76037204 (0.77835695)
# Finished training epoch 168
# Validate: MSE 0.00260821 (0.00235623), PSNR 25.83657265 (26.34094069), SSIM 0.71685493 (0.77814758)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00203944 (0.00227576), PSNR 26.90488052 (26.45194921), SSIM 0.78496045 (0.77815995)
# Finished training epoch 169
# Validate: MSE 0.00273133 (0.00239675), PSNR 25.63626099 (26.27873010), SSIM 0.71505922 (0.77711768)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00257689 (0.00227199), PSNR 25.88903427 (26.46020436), SSIM 0.77669448 (0.77835087)
# Finished training epoch 170
# Validate: MSE 0.00264397 (0.00232388), PSNR 25.77742958 (26.39567218), SSIM 0.71380365 (0.77685173)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00255647 (0.00227207), PSNR 25.92359543 (26.46011798), SSIM 0.76599246 (0.77840225)
# Finished training epoch 171
# Validate: MSE 0.00268233 (0.00228933), PSNR 25.71487427 (26.46850144), SSIM 0.71399796 (0.77809556)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00247084 (0.00227928), PSNR 26.07154465 (26.44648236), SSIM 0.78080714 (0.77821701)
# Finished training epoch 172
# Validate: MSE 0.00263222 (0.00235157), PSNR 25.79677391 (26.35325174), SSIM 0.71630961 (0.77830134)
# Finished validation.
# Starting training epoch 173
# Epoch: 173, MSE 0.00236568 (0.00227248), PSNR 26.26043892 (26.45764937), SSIM 0.77017784 (0.77834509)
# Finished training epoch 173
# Validate: MSE 0.00273974 (0.00234029), PSNR 25.62290764 (26.37982492), SSIM 0.71354413 (0.77784178)
# Finished validation.
# Starting training epoch 174
# Epoch: 174, MSE 0.00193318 (0.00227359), PSNR 27.13727760 (26.45716470), SSIM 0.79574281 (0.77841317)
# Finished training epoch 174
# Validate: MSE 0.00270958 (0.00230909), PSNR 25.67098618 (26.43190148), SSIM 0.71572489 (0.77841772)
# Finished validation.
# Starting training epoch 175
# Epoch: 175, MSE 0.00211278 (0.00227410), PSNR 26.75144768 (26.45501174), SSIM 0.77769595 (0.77843401)
# Finished training epoch 175
# Validate: MSE 0.00264178 (0.00240751), PSNR 25.78104019 (26.24397991), SSIM 0.71309745 (0.76907337)
# Finished validation.
# Starting training epoch 176
# Epoch: 176, MSE 0.00220959 (0.00228136), PSNR 26.55688667 (26.44193443), SSIM 0.80016690 (0.77818506)
# Finished training epoch 176
# Validate: MSE 0.00264620 (0.00242460), PSNR 25.77376747 (26.20951261), SSIM 0.70913565 (0.77272054)
# Finished validation.
# Starting training epoch 177
# Epoch: 177, MSE 0.00255842 (0.00227845), PSNR 25.92027283 (26.44538157), SSIM 0.76384783 (0.77825935)
# Finished training epoch 177
# Validate: MSE 0.00268920 (0.00248159), PSNR 25.70377159 (26.13265438), SSIM 0.71213305 (0.77214713)
# Finished validation.
# Starting training epoch 178
# Epoch: 178, MSE 0.00217947 (0.00227319), PSNR 26.61648560 (26.45547201), SSIM 0.77741718 (0.77833726)
# Finished training epoch 178
# Validate: MSE 0.00268963 (0.00242161), PSNR 25.70307159 (26.22846630), SSIM 0.71494335 (0.77847899)
# Finished validation.
# Starting training epoch 179
# Epoch: 179, MSE 0.00235812 (0.00226820), PSNR 26.27433968 (26.46635241), SSIM 0.79146117 (0.77833637)
# Finished training epoch 179
# Validate: MSE 0.00272220 (0.00238588), PSNR 25.65079880 (26.29727607), SSIM 0.71752083 (0.77764395)
# Finished validation.
# Starting training epoch 180
# Epoch: 180, MSE 0.00204486 (0.00227596), PSNR 26.89335442 (26.45395973), SSIM 0.78803331 (0.77833049)
# Finished training epoch 180
# Validate: MSE 0.00271491 (0.00226918), PSNR 25.66244888 (26.50541561), SSIM 0.71093667 (0.77841737)
# Finished validation.
# Starting training epoch 181
# Epoch: 181, MSE 0.00248726 (0.00227220), PSNR 26.04278183 (26.46172541), SSIM 0.77085179 (0.77846440)
# Finished training epoch 181
# Validate: MSE 0.00261044 (0.00272858), PSNR 25.83286476 (25.74062907), SSIM 0.71290344 (0.77127018)
# Finished validation.
# Starting training epoch 182
# Epoch: 182, MSE 0.00264240 (0.00226593), PSNR 25.78001022 (26.46915170), SSIM 0.77494466 (0.77844059)
# Finished training epoch 182
# Validate: MSE 0.00294378 (0.00242710), PSNR 25.31095314 (26.22506527), SSIM 0.71309549 (0.77829417)
# Finished validation.
# Starting training epoch 183
# Epoch: 183, MSE 0.00219128 (0.00226852), PSNR 26.59301186 (26.46581950), SSIM 0.79137748 (0.77844274)
# Finished training epoch 183
# Validate: MSE 0.00271238 (0.00231843), PSNR 25.66648674 (26.41572910), SSIM 0.71541160 (0.77966459)
# Finished validation.
# Starting training epoch 184
# Epoch: 184, MSE 0.00219269 (0.00226948), PSNR 26.59022903 (26.46285300), SSIM 0.79381168 (0.77841554)
# Finished training epoch 184
# Validate: MSE 0.00268054 (0.00229705), PSNR 25.71776772 (26.45268476), SSIM 0.71450704 (0.77723779)
# Finished validation.
# Starting training epoch 185
# Epoch: 185, MSE 0.00244368 (0.00226961), PSNR 26.11954689 (26.46431337), SSIM 0.77215630 (0.77828307)
# Finished training epoch 185
# Validate: MSE 0.00248333 (0.00229857), PSNR 26.04965401 (26.44257168), SSIM 0.71530551 (0.77289898)
# Finished validation.
# Starting training epoch 186
# Epoch: 186, MSE 0.00225214 (0.00228165), PSNR 26.47405243 (26.44030801), SSIM 0.78608918 (0.77822969)
# Finished training epoch 186
# Validate: MSE 0.00268223 (0.00238693), PSNR 25.71503067 (26.29295757), SSIM 0.71337199 (0.77950371)
# Finished validation.
# Starting training epoch 187
# Epoch: 187, MSE 0.00230633 (0.00226765), PSNR 26.37078285 (26.46500704), SSIM 0.78276223 (0.77828745)
# Finished training epoch 187
# Validate: MSE 0.00267971 (0.00226880), PSNR 25.71912766 (26.50562844), SSIM 0.71499294 (0.77753077)
# Finished validation.
# Starting training epoch 188
# Epoch: 188, MSE 0.00237105 (0.00227424), PSNR 26.25059128 (26.45004599), SSIM 0.78498858 (0.77838832)
# Finished training epoch 188
# Validate: MSE 0.00257105 (0.00229073), PSNR 25.89889717 (26.45666013), SSIM 0.71604002 (0.77649020)
# Finished validation.
# Starting training epoch 189
# Epoch: 189, MSE 0.00248999 (0.00226652), PSNR 26.03801727 (26.46989518), SSIM 0.76341516 (0.77851388)
# Finished training epoch 189
# Validate: MSE 0.00260514 (0.00232500), PSNR 25.84168816 (26.39717050), SSIM 0.71267712 (0.77366034)
# Finished validation.
# Starting training epoch 190
# Epoch: 190, MSE 0.00215237 (0.00226548), PSNR 26.67083740 (26.47192474), SSIM 0.76746792 (0.77855156)
# Finished training epoch 190
# Validate: MSE 0.00271526 (0.00232492), PSNR 25.66189194 (26.39884482), SSIM 0.71682143 (0.77775407)
# Finished validation.
# Starting training epoch 191
# Epoch: 191, MSE 0.00181657 (0.00227318), PSNR 27.40746689 (26.45688631), SSIM 0.78048885 (0.77824837)
# Finished training epoch 191
# Validate: MSE 0.00276296 (0.00232567), PSNR 25.58624840 (26.38926075), SSIM 0.70962012 (0.77504449)
# Finished validation.
# Starting training epoch 192
# Epoch: 192, MSE 0.00257216 (0.00227106), PSNR 25.89701653 (26.45813524), SSIM 0.77066147 (0.77850071)
# Finished training epoch 192
# Validate: MSE 0.00260064 (0.00229560), PSNR 25.84918976 (26.45556927), SSIM 0.71421814 (0.77624039)
# Finished validation.
# Starting training epoch 193
# Epoch: 193, MSE 0.00204809 (0.00227414), PSNR 26.88649750 (26.45276236), SSIM 0.78048331 (0.77838355)
# Finished training epoch 193
# Validate: MSE 0.00277806 (0.00229766), PSNR 25.56257820 (26.45440215), SSIM 0.71080625 (0.77717545)
# Finished validation.
# Starting training epoch 194
# Epoch: 194, MSE 0.00179286 (0.00226678), PSNR 27.46453476 (26.46997972), SSIM 0.77507961 (0.77847044)
# Finished training epoch 194
# Validate: MSE 0.00268105 (0.00233145), PSNR 25.71695709 (26.38277733), SSIM 0.71323740 (0.77801270)
# Finished validation.
# Starting training epoch 195
# Epoch: 195, MSE 0.00253699 (0.00226981), PSNR 25.95680618 (26.46240089), SSIM 0.76572251 (0.77854612)
# Finished training epoch 195
# Validate: MSE 0.00269864 (0.00226926), PSNR 25.68854904 (26.50613747), SSIM 0.71463710 (0.77835179)
# Finished validation.
# Starting training epoch 196
# Epoch: 196, MSE 0.00237753 (0.00226562), PSNR 26.23873329 (26.47240362), SSIM 0.77570820 (0.77852132)
# Finished training epoch 196
# Validate: MSE 0.00283564 (0.00258098), PSNR 25.47349358 (25.96485781), SSIM 0.72021353 (0.77614498)
# Finished validation.
# Starting training epoch 197
# Epoch: 197, MSE 0.00244427 (0.00226316), PSNR 26.11851311 (26.47410245), SSIM 0.77539694 (0.77867354)
# Finished training epoch 197
# Validate: MSE 0.00300029 (0.00251764), PSNR 25.22836685 (26.06440128), SSIM 0.71441925 (0.77677188)
# Finished validation.
# Starting training epoch 198
# Epoch: 198, MSE 0.00211804 (0.00226983), PSNR 26.74065208 (26.46321075), SSIM 0.79300863 (0.77839572)
# Finished training epoch 198
# Validate: MSE 0.00265740 (0.00241596), PSNR 25.75543594 (26.24649317), SSIM 0.71492535 (0.77819978)
# Finished validation.
# Starting training epoch 199
# Epoch: 199, MSE 0.00238009 (0.00227198), PSNR 26.23406982 (26.45868214), SSIM 0.78258377 (0.77843654)
# Finished training epoch 199
# Validate: MSE 0.00267556 (0.00232843), PSNR 25.72585869 (26.39607546), SSIM 0.72167516 (0.77716349)
# Finished validation.
# Starting training epoch 200
# Epoch: 200, MSE 0.00243624 (0.00227025), PSNR 26.13279724 (26.46290883), SSIM 0.77516067 (0.77837118)
# Finished training epoch 200
# Validate: MSE 0.00276470 (0.00234426), PSNR 25.58351326 (26.36785244), SSIM 0.71660620 (0.77853963)
# Finished validation.
# Starting training epoch 201
# Epoch: 201, MSE 0.00272113 (0.00226870), PSNR 25.65250015 (26.46601303), SSIM 0.77408946 (0.77844409)
# Finished training epoch 201
# Validate: MSE 0.00269674 (0.00227964), PSNR 25.69161034 (26.48668866), SSIM 0.71659529 (0.78046172)
# Finished validation.
# Starting training epoch 202
# Epoch: 202, MSE 0.00222043 (0.00226452), PSNR 26.53562546 (26.47513740), SSIM 0.78150380 (0.77848709)
# Finished training epoch 202
# Validate: MSE 0.00274918 (0.00251262), PSNR 25.60795975 (26.08595320), SSIM 0.70924187 (0.77355325)
# Finished validation.
# Starting training epoch 203
# Epoch: 203, MSE 0.00239835 (0.00226497), PSNR 26.20087242 (26.47407880), SSIM 0.76209533 (0.77846112)
# Finished training epoch 203
# Validate: MSE 0.00258645 (0.00230844), PSNR 25.87296295 (26.42916862), SSIM 0.71933186 (0.77609834)
# Finished validation.
# Starting training epoch 204
# Epoch: 204, MSE 0.00216818 (0.00227302), PSNR 26.63903809 (26.45584272), SSIM 0.79014957 (0.77855173)
# Finished training epoch 204
# Validate: MSE 0.00268963 (0.00231017), PSNR 25.70307350 (26.43054721), SSIM 0.71710587 (0.77773665)
# Finished validation.
# Starting training epoch 205
# Epoch: 205, MSE 0.00231250 (0.00226839), PSNR 26.35917282 (26.46835101), SSIM 0.78616565 (0.77840746)
# Finished training epoch 205
# Validate: MSE 0.00271470 (0.00262023), PSNR 25.66278267 (25.91968394), SSIM 0.70636290 (0.76845764)
# Finished validation.
# Starting training epoch 206
# Epoch: 206, MSE 0.00241744 (0.00226417), PSNR 26.16643906 (26.47413180), SSIM 0.77419806 (0.77855153)
# Finished training epoch 206
# Validate: MSE 0.00275259 (0.00238058), PSNR 25.60258675 (26.30027454), SSIM 0.71490979 (0.77529448)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00275259 (0.00238058), PSNR 25.60258675 (26.30027454), SSIM 0.71490979 (0.77529448)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
