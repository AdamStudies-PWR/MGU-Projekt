# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
# Reusing TensorBoard on port 6007 (pid 10547), started 0:22:32 ago. (Use '!kill 10547' to kill it.)
#       <iframe id="tensorboard-frame-dce27593e698dee8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-dce27593e698dee8");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .25

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        self.batchnorm5 = nn.BatchNorm2d(2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = y = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x + y)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm5(self.convtrans3(x + input)), negative_slope=0.1)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 32, 32]           2,306
#       BatchNorm2d-10            [-1, 2, 32, 32]               4
# ================================================================
# Total params: 2,662,278
# Trainable params: 2,662,278
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.78
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.94
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00276749 (0.02233743), PSNR 25.57914162 (20.60365704), SSIM 0.76572740 (0.57800312)
# Finished training epoch 0
# Validate: MSE 0.00304379 (0.00265734), PSNR 25.16584778 (25.82802576), SSIM 0.70006156 (0.76879131)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00258880 (0.00258917), PSNR 25.86901474 (25.89233583), SSIM 0.76562709 (0.76931771)
# Finished training epoch 1
# Validate: MSE 0.00284875 (0.00253460), PSNR 25.45344925 (26.03093304), SSIM 0.70651501 (0.77097976)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00285740 (0.00250008), PSNR 25.44029236 (26.04542067), SSIM 0.74858654 (0.77318103)
# Finished training epoch 2
# Validate: MSE 0.00286435 (0.00244598), PSNR 25.42973328 (26.18049180), SSIM 0.70965672 (0.77649953)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00199158 (0.00246240), PSNR 27.00802994 (26.10672399), SSIM 0.77754200 (0.77578614)
# Finished training epoch 3
# Validate: MSE 0.00282714 (0.00246979), PSNR 25.48651886 (26.13698561), SSIM 0.71260887 (0.77404055)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00259436 (0.00244292), PSNR 25.85969925 (26.14411718), SSIM 0.76001120 (0.77676487)
# Finished training epoch 4
# Validate: MSE 0.00291147 (0.00246537), PSNR 25.35887909 (26.15372162), SSIM 0.71512860 (0.77967742)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00257264 (0.00242334), PSNR 25.89620590 (26.17984735), SSIM 0.79237139 (0.77774194)
# Finished training epoch 5
# Validate: MSE 0.00315923 (0.00301768), PSNR 25.00418282 (25.30198892), SSIM 0.70657152 (0.76910642)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00197750 (0.00241627), PSNR 27.03884125 (26.19142336), SSIM 0.76897383 (0.77819250)
# Finished training epoch 6
# Validate: MSE 0.00267133 (0.00248399), PSNR 25.73271942 (26.11355929), SSIM 0.71202886 (0.77554463)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00259329 (0.00238762), PSNR 25.86149597 (26.24433574), SSIM 0.77385807 (0.77878178)
# Finished training epoch 7
# Validate: MSE 0.00306761 (0.00256266), PSNR 25.13199806 (25.98528537), SSIM 0.70763797 (0.77522685)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00201105 (0.00238426), PSNR 26.96578026 (26.25225769), SSIM 0.77930075 (0.77904002)
# Finished training epoch 8
# Validate: MSE 0.00281302 (0.00235105), PSNR 25.50827599 (26.35334903), SSIM 0.71512181 (0.78203169)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00273441 (0.00236860), PSNR 25.63136864 (26.27789935), SSIM 0.75653756 (0.77960739)
# Finished training epoch 9
# Validate: MSE 0.00303123 (0.00246379), PSNR 25.18380928 (26.15176575), SSIM 0.70932949 (0.77702480)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00270717 (0.00235811), PSNR 25.67483902 (26.29584265), SSIM 0.77013701 (0.78010908)
# Finished training epoch 10
# Validate: MSE 0.00278828 (0.00237638), PSNR 25.54663658 (26.30010523), SSIM 0.70743519 (0.77421726)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00220448 (0.00234560), PSNR 26.56692886 (26.32245347), SSIM 0.76065004 (0.78047177)
# Finished training epoch 11
# Validate: MSE 0.00266410 (0.00314316), PSNR 25.74449921 (25.14977880), SSIM 0.71405357 (0.76442545)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00203754 (0.00233847), PSNR 26.90892792 (26.33338158), SSIM 0.81071484 (0.78082328)
# Finished training epoch 12
# Validate: MSE 0.00278614 (0.00240569), PSNR 25.54996681 (26.25485121), SSIM 0.71390235 (0.78113155)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00234759 (0.00233075), PSNR 26.29377937 (26.34634632), SSIM 0.77596033 (0.78087588)
# Finished training epoch 13
# Validate: MSE 0.00295338 (0.00239436), PSNR 25.29680824 (26.27753156), SSIM 0.71477729 (0.78328923)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00225867 (0.00231423), PSNR 26.46147346 (26.37802041), SSIM 0.80166614 (0.78162723)
# Finished training epoch 14
# Validate: MSE 0.00272312 (0.00237561), PSNR 25.64933777 (26.29937231), SSIM 0.71452665 (0.77647826)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00266358 (0.00230933), PSNR 25.74534988 (26.38841657), SSIM 0.77166504 (0.78194664)
# Finished training epoch 15
# Validate: MSE 0.00259097 (0.00263274), PSNR 25.86536980 (25.87504555), SSIM 0.71732211 (0.77420680)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00252354 (0.00230842), PSNR 25.97990227 (26.38890915), SSIM 0.79166830 (0.78220908)
# Finished training epoch 16
# Validate: MSE 0.00271674 (0.00248434), PSNR 25.65951347 (26.10215263), SSIM 0.71543491 (0.77568990)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00233465 (0.00230472), PSNR 26.31777763 (26.39702891), SSIM 0.78037322 (0.78255318)
# Finished training epoch 17
# Validate: MSE 0.00253569 (0.00252119), PSNR 25.95903778 (26.04736932), SSIM 0.71806985 (0.77326143)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00278844 (0.00229173), PSNR 25.54638481 (26.41929527), SSIM 0.79156303 (0.78283903)
# Finished training epoch 18
# Validate: MSE 0.00293288 (0.00360581), PSNR 25.32706261 (24.58119891), SSIM 0.70832789 (0.75789938)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00211838 (0.00228729), PSNR 26.73995781 (26.42943305), SSIM 0.78438914 (0.78308744)
# Finished training epoch 19
# Validate: MSE 0.00280873 (0.00299437), PSNR 25.51490021 (25.32817762), SSIM 0.71038520 (0.76850661)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00218116 (0.00227992), PSNR 26.61311913 (26.44490719), SSIM 0.78063023 (0.78329147)
# Finished training epoch 20
# Validate: MSE 0.00288207 (0.00250695), PSNR 25.40295601 (26.07982029), SSIM 0.71709102 (0.78071830)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00246382 (0.00227363), PSNR 26.08390617 (26.45505817), SSIM 0.76112241 (0.78349499)
# Finished training epoch 21
# Validate: MSE 0.00266243 (0.00232343), PSNR 25.74721146 (26.40253284), SSIM 0.72020555 (0.78124140)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00177751 (0.00227197), PSNR 27.50187302 (26.46149853), SSIM 0.80995524 (0.78371799)
# Finished training epoch 22
# Validate: MSE 0.00272509 (0.00229321), PSNR 25.64619064 (26.45948986), SSIM 0.71760947 (0.78547884)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00247459 (0.00227043), PSNR 26.06495857 (26.46025946), SSIM 0.80086505 (0.78393421)
# Finished training epoch 23
# Validate: MSE 0.00328264 (0.00303606), PSNR 24.83775902 (25.27799278), SSIM 0.70806915 (0.77167953)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00233114 (0.00226473), PSNR 26.32431412 (26.47125817), SSIM 0.77030313 (0.78427197)
# Finished training epoch 24
# Validate: MSE 0.00262055 (0.00256582), PSNR 25.81606865 (25.99042744), SSIM 0.71456981 (0.77428252)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00245451 (0.00225410), PSNR 26.10035896 (26.49556770), SSIM 0.77365142 (0.78442868)
# Finished training epoch 25
# Validate: MSE 0.00254420 (0.00230137), PSNR 25.94449425 (26.43485216), SSIM 0.71969056 (0.77605201)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00226365 (0.00224664), PSNR 26.45189667 (26.50767971), SSIM 0.78687406 (0.78469730)
# Finished training epoch 26
# Validate: MSE 0.00278417 (0.00233709), PSNR 25.55304527 (26.37899684), SSIM 0.71839345 (0.78065937)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00262049 (0.00224566), PSNR 25.81617928 (26.51194349), SSIM 0.77335227 (0.78455741)
# Finished training epoch 27
# Validate: MSE 0.00261621 (0.00223347), PSNR 25.82328033 (26.57484452), SSIM 0.72405034 (0.78593153)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00298764 (0.00223234), PSNR 25.24671555 (26.53652021), SSIM 0.77401865 (0.78492797)
# Finished training epoch 28
# Validate: MSE 0.00260267 (0.00234346), PSNR 25.84580040 (26.35621336), SSIM 0.71905410 (0.78135169)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00251704 (0.00223700), PSNR 25.99109077 (26.52728890), SSIM 0.77096164 (0.78482355)
# Finished training epoch 29
# Validate: MSE 0.00252118 (0.00232577), PSNR 25.98395920 (26.39420397), SSIM 0.72434640 (0.78064629)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00251313 (0.00222310), PSNR 25.99784851 (26.55422979), SSIM 0.77877533 (0.78517687)
# Finished training epoch 30
# Validate: MSE 0.00272681 (0.00244414), PSNR 25.64344406 (26.18886769), SSIM 0.72135592 (0.77852404)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00252430 (0.00221947), PSNR 25.97858047 (26.56081241), SSIM 0.74740815 (0.78523640)
# Finished training epoch 31
# Validate: MSE 0.00269333 (0.00261735), PSNR 25.69710922 (25.90387192), SSIM 0.72349507 (0.77812388)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00213553 (0.00221542), PSNR 26.70493507 (26.56835709), SSIM 0.76873404 (0.78534678)
# Finished training epoch 32
# Validate: MSE 0.00276570 (0.00265127), PSNR 25.58194542 (25.84090958), SSIM 0.72196817 (0.77638179)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00143665 (0.00221490), PSNR 28.42649651 (26.57267299), SSIM 0.84062564 (0.78535553)
# Finished training epoch 33
# Validate: MSE 0.00267167 (0.00255545), PSNR 25.73216629 (26.00653204), SSIM 0.72558200 (0.78408436)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00211989 (0.00221056), PSNR 26.73686790 (26.57958479), SSIM 0.78144193 (0.78530279)
# Finished training epoch 34
# Validate: MSE 0.00281143 (0.00259725), PSNR 25.51071930 (25.92897506), SSIM 0.71281075 (0.77575428)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00178169 (0.00220855), PSNR 27.49167252 (26.58272763), SSIM 0.79766786 (0.78559075)
# Finished training epoch 35
# Validate: MSE 0.00269172 (0.00239785), PSNR 25.69970322 (26.27804951), SSIM 0.72391427 (0.78544247)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00210451 (0.00220304), PSNR 26.76848030 (26.59342222), SSIM 0.78728712 (0.78535022)
# Finished training epoch 36
# Validate: MSE 0.00272566 (0.00222819), PSNR 25.64528275 (26.58238734), SSIM 0.72031546 (0.78665033)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00247064 (0.00219081), PSNR 26.07189751 (26.61478914), SSIM 0.77801430 (0.78572493)
# Finished training epoch 37
# Validate: MSE 0.00246085 (0.00224633), PSNR 26.08915329 (26.54488605), SSIM 0.72700441 (0.78190310)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00259020 (0.00218847), PSNR 25.86666489 (26.62230029), SSIM 0.76199049 (0.78569390)
# Finished training epoch 38
# Validate: MSE 0.00265027 (0.00231756), PSNR 25.76709938 (26.40035461), SSIM 0.71754324 (0.77699088)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00211887 (0.00218362), PSNR 26.73894882 (26.63145051), SSIM 0.78342283 (0.78566167)
# Finished training epoch 39
# Validate: MSE 0.00254729 (0.00224621), PSNR 25.93920708 (26.54671631), SSIM 0.72807479 (0.78533239)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00247316 (0.00218762), PSNR 26.06748390 (26.62470470), SSIM 0.79176486 (0.78570784)
# Finished training epoch 40
# Validate: MSE 0.00274516 (0.00239210), PSNR 25.61432648 (26.28426561), SSIM 0.71660602 (0.77881384)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00195853 (0.00217613), PSNR 27.08069801 (26.64606475), SSIM 0.79541391 (0.78576736)
# Finished training epoch 41
# Validate: MSE 0.00260656 (0.00226818), PSNR 25.83931923 (26.49753852), SSIM 0.71999848 (0.78465190)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00194002 (0.00216859), PSNR 27.12194252 (26.66181128), SSIM 0.79094827 (0.78581655)
# Finished training epoch 42
# Validate: MSE 0.00274219 (0.00224952), PSNR 25.61902809 (26.54705331), SSIM 0.72058415 (0.78325653)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00228780 (0.00216413), PSNR 26.40581894 (26.67066827), SSIM 0.77496326 (0.78592313)
# Finished training epoch 43
# Validate: MSE 0.00249963 (0.00224010), PSNR 26.02124023 (26.55740000), SSIM 0.72541797 (0.78166944)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00205069 (0.00215998), PSNR 26.88100243 (26.68030424), SSIM 0.78870451 (0.78578732)
# Finished training epoch 44
# Validate: MSE 0.00279585 (0.00229528), PSNR 25.53486443 (26.46248916), SSIM 0.72106111 (0.78328554)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00179283 (0.00215797), PSNR 27.46461678 (26.68512208), SSIM 0.79261035 (0.78592136)
# Finished training epoch 45
# Validate: MSE 0.00287265 (0.00226288), PSNR 25.41717911 (26.51347147), SSIM 0.71856761 (0.78143700)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00233009 (0.00215389), PSNR 26.32626915 (26.68962242), SSIM 0.79005784 (0.78600045)
# Finished training epoch 46
# Validate: MSE 0.00275987 (0.00224907), PSNR 25.59111023 (26.54278242), SSIM 0.72275686 (0.78281504)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00206418 (0.00215338), PSNR 26.85252762 (26.69155373), SSIM 0.78815293 (0.78569649)
# Finished training epoch 47
# Validate: MSE 0.00261765 (0.00241559), PSNR 25.82088089 (26.24094820), SSIM 0.71844435 (0.77821577)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00245638 (0.00213900), PSNR 26.09704971 (26.71861763), SSIM 0.77264565 (0.78593248)
# Finished training epoch 48
# Validate: MSE 0.00240420 (0.00224653), PSNR 26.19028473 (26.54642196), SSIM 0.72711104 (0.77983835)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00190701 (0.00213307), PSNR 27.19647598 (26.73171091), SSIM 0.80136764 (0.78580627)
# Finished training epoch 49
# Validate: MSE 0.00229305 (0.00226665), PSNR 26.39585876 (26.50404224), SSIM 0.73459506 (0.77889902)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00175634 (0.00213695), PSNR 27.55390167 (26.72275020), SSIM 0.78656346 (0.78553564)
# Finished training epoch 50
# Validate: MSE 0.00255799 (0.00217657), PSNR 25.92101288 (26.68475182), SSIM 0.72519088 (0.78481352)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00246714 (0.00213504), PSNR 26.07806206 (26.72533808), SSIM 0.76871812 (0.78591259)
# Finished training epoch 51
# Validate: MSE 0.00252045 (0.00227948), PSNR 25.98522377 (26.47769689), SSIM 0.71992612 (0.77961720)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00195265 (0.00213405), PSNR 27.09375191 (26.73245079), SSIM 0.79112625 (0.78568368)
# Finished training epoch 52
# Validate: MSE 0.00252274 (0.00224431), PSNR 25.98126411 (26.53835957), SSIM 0.72222209 (0.77889185)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00214803 (0.00212913), PSNR 26.67959404 (26.74133798), SSIM 0.77746713 (0.78527934)
# Finished training epoch 53
# Validate: MSE 0.00243298 (0.00228240), PSNR 26.13862038 (26.46852309), SSIM 0.72641772 (0.77469558)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00224469 (0.00211887), PSNR 26.48843575 (26.76126246), SSIM 0.77525234 (0.78583922)
# Finished training epoch 54
# Validate: MSE 0.00257124 (0.00226708), PSNR 25.89856911 (26.50046584), SSIM 0.72086090 (0.77824016)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00199967 (0.00211734), PSNR 26.99042130 (26.76416211), SSIM 0.79164296 (0.78541441)
# Finished training epoch 55
# Validate: MSE 0.00258816 (0.00222728), PSNR 25.87008858 (26.58788958), SSIM 0.73116314 (0.78380992)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00229034 (0.00211213), PSNR 26.40100098 (26.77503573), SSIM 0.76951098 (0.78536058)
# Finished training epoch 56
# Validate: MSE 0.00239680 (0.00245610), PSNR 26.20368767 (26.17134529), SSIM 0.72640574 (0.77545478)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00211810 (0.00211206), PSNR 26.74053955 (26.77397663), SSIM 0.79266024 (0.78564412)
# Finished training epoch 57
# Validate: MSE 0.00274723 (0.00220380), PSNR 25.61104965 (26.63245302), SSIM 0.71761477 (0.78114919)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00179619 (0.00210897), PSNR 27.45646667 (26.78184740), SSIM 0.79723150 (0.78564091)
# Finished training epoch 58
# Validate: MSE 0.00252656 (0.00237117), PSNR 25.97470474 (26.32240145), SSIM 0.72396070 (0.77874140)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00190351 (0.00210004), PSNR 27.20444489 (26.79983123), SSIM 0.79667467 (0.78550448)
# Finished training epoch 59
# Validate: MSE 0.00279291 (0.00276541), PSNR 25.53943253 (25.69531185), SSIM 0.71898472 (0.77120600)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00202061 (0.00209970), PSNR 26.94517326 (26.80037666), SSIM 0.77389175 (0.78535623)
# Finished training epoch 60
# Validate: MSE 0.00262606 (0.00222714), PSNR 25.80695152 (26.58707713), SSIM 0.72477686 (0.78341146)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00227574 (0.00209377), PSNR 26.42878151 (26.81217153), SSIM 0.77816594 (0.78549058)
# Finished training epoch 61
# Validate: MSE 0.00254520 (0.00234297), PSNR 25.94277382 (26.36523258), SSIM 0.72926754 (0.77709535)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00167186 (0.00209601), PSNR 27.76799965 (26.80634821), SSIM 0.80488443 (0.78508839)
# Finished training epoch 62
# Validate: MSE 0.00251234 (0.00223906), PSNR 25.99921036 (26.55808384), SSIM 0.71871030 (0.77884136)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00258872 (0.00208935), PSNR 25.86915207 (26.81983531), SSIM 0.78279179 (0.78523998)
# Finished training epoch 63
# Validate: MSE 0.00284421 (0.00243818), PSNR 25.46037865 (26.20862557), SSIM 0.72182477 (0.77851292)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00194720 (0.00208700), PSNR 27.10589600 (26.82597449), SSIM 0.78582907 (0.78519165)
# Finished training epoch 64
# Validate: MSE 0.00253440 (0.00217852), PSNR 25.96125221 (26.67701691), SSIM 0.71598065 (0.78084377)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00233308 (0.00208144), PSNR 26.32069778 (26.83561171), SSIM 0.77980959 (0.78512711)
# Finished training epoch 65
# Validate: MSE 0.00255064 (0.00218698), PSNR 25.93350029 (26.66236963), SSIM 0.72378165 (0.78072143)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00236348 (0.00207535), PSNR 26.26447678 (26.84964776), SSIM 0.78558660 (0.78507063)
# Finished training epoch 66
# Validate: MSE 0.00232221 (0.00219630), PSNR 26.34099007 (26.64009251), SSIM 0.72079432 (0.77677742)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00248191 (0.00207902), PSNR 26.05213547 (26.84367371), SSIM 0.76114577 (0.78483759)
# Finished training epoch 67
# Validate: MSE 0.00249957 (0.00225890), PSNR 26.02133751 (26.50939564), SSIM 0.71405506 (0.76955222)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00195469 (0.00206864), PSNR 27.08922005 (26.86524653), SSIM 0.78670961 (0.78497747)
# Finished training epoch 68
# Validate: MSE 0.00233945 (0.00230061), PSNR 26.30886650 (26.43058174), SSIM 0.72209239 (0.77485447)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00182784 (0.00206775), PSNR 27.38062668 (26.86821935), SSIM 0.80299842 (0.78498371)
# Finished training epoch 69
# Validate: MSE 0.00254691 (0.00247018), PSNR 25.93986511 (26.13425154), SSIM 0.72053683 (0.76765273)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00198111 (0.00206432), PSNR 27.03091812 (26.87325533), SSIM 0.77775174 (0.78491199)
# Finished training epoch 70
# Validate: MSE 0.00266457 (0.00239226), PSNR 25.74373055 (26.28463799), SSIM 0.71792495 (0.77898667)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00221330 (0.00206076), PSNR 26.54958725 (26.87852598), SSIM 0.77837968 (0.78495814)
# Finished training epoch 71
# Validate: MSE 0.00265785 (0.00218705), PSNR 25.75469589 (26.66285788), SSIM 0.71954143 (0.78244499)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00136147 (0.00206009), PSNR 28.65992165 (26.88551692), SSIM 0.80025786 (0.78467660)
# Finished training epoch 72
# Validate: MSE 0.00259227 (0.00220891), PSNR 25.86319542 (26.62338751), SSIM 0.72405189 (0.78317870)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00222825 (0.00205418), PSNR 26.52035713 (26.89484752), SSIM 0.77789098 (0.78443125)
# Finished training epoch 73
# Validate: MSE 0.00245497 (0.00221064), PSNR 26.09953308 (26.61698855), SSIM 0.72668445 (0.78028686)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00199411 (0.00206026), PSNR 27.00251770 (26.88341282), SSIM 0.78437495 (0.78452088)
# Finished training epoch 74
# Validate: MSE 0.00260669 (0.00224619), PSNR 25.83910561 (26.53832738), SSIM 0.72086799 (0.77445758)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00224904 (0.00204799), PSNR 26.48002052 (26.91020192), SSIM 0.79054248 (0.78454446)
# Finished training epoch 75
# Validate: MSE 0.00254913 (0.00221272), PSNR 25.93608475 (26.61045748), SSIM 0.71748382 (0.77444363)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00188876 (0.00204331), PSNR 27.23824120 (26.91893039), SSIM 0.79264438 (0.78435419)
# Finished training epoch 76
# Validate: MSE 0.00250260 (0.00220712), PSNR 26.01608849 (26.61941842), SSIM 0.72152787 (0.77857337)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00209381 (0.00204216), PSNR 26.79063606 (26.92272288), SSIM 0.76978415 (0.78454161)
# Finished training epoch 77
# Validate: MSE 0.00240234 (0.00232468), PSNR 26.19365311 (26.40422720), SSIM 0.72332680 (0.77303197)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00220132 (0.00204083), PSNR 26.57317352 (26.92312811), SSIM 0.77226388 (0.78451418)
# Finished training epoch 78
# Validate: MSE 0.00262084 (0.00228088), PSNR 25.81558990 (26.47852457), SSIM 0.71753532 (0.77347611)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00198103 (0.00203474), PSNR 27.03108025 (26.93630304), SSIM 0.80143785 (0.78470740)
# Finished training epoch 79
# Validate: MSE 0.00249337 (0.00227000), PSNR 26.03212547 (26.50468687), SSIM 0.72636044 (0.78093958)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00239736 (0.00203339), PSNR 26.20267487 (26.94172375), SSIM 0.77531040 (0.78430666)
# Finished training epoch 80
# Validate: MSE 0.00262502 (0.00225735), PSNR 25.80866814 (26.52370529), SSIM 0.71467030 (0.77913925)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00199058 (0.00202824), PSNR 27.01020432 (26.95238251), SSIM 0.77165663 (0.78416867)
# Finished training epoch 81
# Validate: MSE 0.00246069 (0.00224728), PSNR 26.08942795 (26.54391752), SSIM 0.72735727 (0.77788812)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00204514 (0.00202958), PSNR 26.89277840 (26.94932196), SSIM 0.78040260 (0.78428827)
# Finished training epoch 82
# Validate: MSE 0.00254820 (0.00224285), PSNR 25.93766785 (26.54696882), SSIM 0.71823287 (0.76896351)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00195354 (0.00202957), PSNR 27.09178162 (26.94550010), SSIM 0.80348510 (0.78414083)
# Finished training epoch 83
# Validate: MSE 0.00262256 (0.00226906), PSNR 25.81274223 (26.50830403), SSIM 0.72104049 (0.77827414)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00175275 (0.00201871), PSNR 27.56281090 (26.97147108), SSIM 0.78099883 (0.78401554)
# Finished training epoch 84
# Validate: MSE 0.00263749 (0.00224328), PSNR 25.78808975 (26.55339776), SSIM 0.71038556 (0.77722174)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00195170 (0.00201725), PSNR 27.09586334 (26.97355487), SSIM 0.79421932 (0.78400453)
# Finished training epoch 85
# Validate: MSE 0.00254425 (0.00225634), PSNR 25.94439507 (26.52836049), SSIM 0.72395134 (0.77436264)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00219711 (0.00201608), PSNR 26.58147621 (26.97667125), SSIM 0.79826707 (0.78390971)
# Finished training epoch 86
# Validate: MSE 0.00252368 (0.00220668), PSNR 25.97965622 (26.62098666), SSIM 0.72086811 (0.78144455)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00204706 (0.00202016), PSNR 26.88869667 (26.96759965), SSIM 0.79593128 (0.78401327)
# Finished training epoch 87
# Validate: MSE 0.00232396 (0.00222280), PSNR 26.33771133 (26.58831844), SSIM 0.72208846 (0.77681171)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00195014 (0.00200959), PSNR 27.09934616 (26.99006876), SSIM 0.77495468 (0.78397944)
# Finished training epoch 88
# Validate: MSE 0.00242702 (0.00224871), PSNR 26.14926529 (26.53205877), SSIM 0.72275555 (0.77161028)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00166604 (0.00201395), PSNR 27.78314972 (26.98232946), SSIM 0.79534495 (0.78369081)
# Finished training epoch 89
# Validate: MSE 0.00261336 (0.00222685), PSNR 25.82801437 (26.58357001), SSIM 0.72466922 (0.78069679)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00182534 (0.00201278), PSNR 27.38655853 (26.98495409), SSIM 0.78931797 (0.78404583)
# Finished training epoch 90
# Validate: MSE 0.00280543 (0.00233920), PSNR 25.52000237 (26.37340805), SSIM 0.72007799 (0.77240774)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00202031 (0.00200370), PSNR 26.94582176 (27.00190900), SSIM 0.78975326 (0.78396324)
# Finished training epoch 91
# Validate: MSE 0.00257800 (0.00222923), PSNR 25.88716316 (26.57337534), SSIM 0.71892118 (0.77445346)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00188449 (0.00200306), PSNR 27.24806976 (27.00448561), SSIM 0.78106511 (0.78385868)
# Finished training epoch 92
# Validate: MSE 0.00257098 (0.00222023), PSNR 25.89901161 (26.59522336), SSIM 0.71203923 (0.77462102)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00215863 (0.00199410), PSNR 26.65821266 (27.02236021), SSIM 0.76972330 (0.78375946)
# Finished training epoch 93
# Validate: MSE 0.00264793 (0.00218582), PSNR 25.77093887 (26.66064205), SSIM 0.71524262 (0.77554577)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00177914 (0.00200236), PSNR 27.49788666 (27.00334794), SSIM 0.78837287 (0.78359392)
# Finished training epoch 94
# Validate: MSE 0.00261773 (0.00227340), PSNR 25.82074738 (26.48846327), SSIM 0.71871257 (0.77374938)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00161226 (0.00199669), PSNR 27.92564392 (27.01872971), SSIM 0.79350817 (0.78367566)
# Finished training epoch 95
# Validate: MSE 0.00258785 (0.00221595), PSNR 25.87060356 (26.60396670), SSIM 0.72315258 (0.77775911)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00214719 (0.00199185), PSNR 26.68128777 (27.02689187), SSIM 0.78253925 (0.78338106)
# Finished training epoch 96
# Validate: MSE 0.00250902 (0.00220601), PSNR 26.00496674 (26.62561261), SSIM 0.71842825 (0.77873608)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00198851 (0.00199430), PSNR 27.01471329 (27.02474984), SSIM 0.79194504 (0.78326756)
# Finished training epoch 97
# Validate: MSE 0.00274764 (0.00247792), PSNR 25.61040878 (26.13080114), SSIM 0.70909607 (0.76535948)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00228136 (0.00198785), PSNR 26.41806030 (27.03850047), SSIM 0.76644307 (0.78339997)
# Finished training epoch 98
# Validate: MSE 0.00254253 (0.00228538), PSNR 25.94734573 (26.47127093), SSIM 0.70324790 (0.76593210)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00193372 (0.00199137), PSNR 27.13606453 (27.02904243), SSIM 0.78174973 (0.78328145)
# Finished training epoch 99
# Validate: MSE 0.00253205 (0.00225640), PSNR 25.96528435 (26.52740359), SSIM 0.72343373 (0.77303634)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00241519 (0.00199091), PSNR 26.17048454 (27.02869383), SSIM 0.76609629 (0.78318923)
# Finished training epoch 100
# Validate: MSE 0.00236792 (0.00218091), PSNR 26.25633621 (26.67046519), SSIM 0.72603405 (0.77524749)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00240964 (0.00217801), PSNR 26.18048096 (26.67498579), SSIM 0.72326326 (0.77538827)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
