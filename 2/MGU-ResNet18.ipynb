# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-ffb33d69db4de3e4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ffb33d69db4de3e4");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
SIZE = 64
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(), 
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE),
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
batch_size = 128
train_imagefolder = LabImageFolder('../../datasets/dataset/train/colour')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder('../../datasets/dataset/test/colour' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=2
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
class ColorizationNet(nn.Module):
  def __init__(self, input_size=128):
    super(ColorizationNet, self).__init__()
    
    self.encoder = nn.Sequential(       
      nn.Conv2d(1, 16, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode),
#       nn.BatchNorm2d(16),
      nn.ReLU(),
      nn.Conv2d(16, 32, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode),
#       nn.BatchNorm2d(32),
      nn.ReLU(),
      nn.Conv2d(32, 64, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode),
#       nn.BatchNorm2d(64),
      nn.ReLU(),   
    )     
        
    self.decoder = nn.Sequential(  
      nn.ConvTranspose2d(64, 32, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
#       nn.BatchNorm2d(32),
      nn.ReLU(),
      nn.Upsample(scale_factor=scale_factor),   
      nn.ConvTranspose2d(32, 16, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
#       nn.BatchNorm2d(16),
      nn.ReLU(),
      nn.Upsample(scale_factor=scale_factor),
      nn.ConvTranspose2d(16, 8, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
#       nn.BatchNorm2d(8),
      nn.ReLU(),
      nn.ConvTranspose2d(8, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
      nn.Upsample(scale_factor=scale_factor)
    )

  def forward(self, input):

    encoder = self.encoder(input)
    # Upsample to get colors
    output = self.decoder(encoder)
    return output

# %%
model = ColorizationNet()

# %%
criterion = nn.MSELoss()

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = criterion.cuda()
    model = model.cuda()

# %%
from torchsummary import summary

summary(model, (1, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             160
#               ReLU-2           [-1, 16, 32, 32]               0
#             Conv2d-3           [-1, 32, 16, 16]           4,640
#               ReLU-4           [-1, 32, 16, 16]               0
#             Conv2d-5             [-1, 64, 8, 8]          18,496
#               ReLU-6             [-1, 64, 8, 8]               0
#    ConvTranspose2d-7             [-1, 32, 8, 8]          18,464
#               ReLU-8             [-1, 32, 8, 8]               0
#           Upsample-9           [-1, 32, 16, 16]               0
#   ConvTranspose2d-10           [-1, 16, 16, 16]           4,624
#              ReLU-11           [-1, 16, 16, 16]               0
#          Upsample-12           [-1, 16, 32, 32]               0
#   ConvTranspose2d-13            [-1, 8, 32, 32]           1,160
#              ReLU-14            [-1, 8, 32, 32]               0
#   ConvTranspose2d-15            [-1, 2, 32, 32]             146
#          Upsample-16            [-1, 2, 64, 64]               0
# ================================================================
# Total params: 47,690
# Trainable params: 47,690
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.92
# Params size (MB): 0.18
# Estimated Total Size (MB): 1.12
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
  '''A handy class from the PyTorch ImageNet tutorial''' 
  def __init__(self):
    self.reset()
  def reset(self):
    self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
  def update(self, val, n=1):
    self.val = val
    self.sum += val * n
    self.count += n
    self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
  '''Show/save rgb image from grayscale and ab channels
     Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
  plt.clf() # clear matplotlib 
  color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
  color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
  color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
  color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
  color_image = lab2rgb(color_image.astype(np.float64))
  grayscale_input = grayscale_input.squeeze().numpy()
  if save_path is not None and save_name is not None: 
    plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
    plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = AverageMeter()

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = criterion(output_ab, ab)
        
        _loss.update(loss.item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print('Validate: Loss {loss.val:.4f} ({loss.avg:.4f})\t'.format(
         loss=_loss))

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("Loss/test", _loss.avg, epoch)
    return _loss.avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = AverageMeter()
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = criterion(output_ab, ab) 
        loss.backward()
        optimizer.step()
        
        _loss.update(loss.item(), gray.size(0))
        
    print(f'Epoch: {epoch}, Loss {_loss.val:.4f} ({_loss.avg:.4f})')
    
    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("Loss/train", _loss.avg, epoch)

# %%
# Make folders and set parameters
checkpoints = 'checkpoints'
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = 1e10
epochs = 250

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses < best_losses:
        best_losses = losses
        torch.save(model.state_dict(), '{}/model-epoch-{}-losses-{:.3f}.pth'.format(checkpoints,epoch+1,losses))


    if epoch == epochs - 1:
        torch.save(model.state_dict(), '{}/model-epoch-{}-last-losses-{:.3f}.pth'.format(checkpoints,epoch+1,losses))
# Out:
# Starting training epoch 0
# Epoch: 0, Loss 0.0112 (0.2320)
# Finished training epoch 0
# Validate: Loss 0.0108 (0.0108)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, Loss 0.0076 (0.0100)
# Finished training epoch 1
# Validate: Loss 0.0082 (0.0083)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, Loss 0.0070 (0.0078)
# Finished training epoch 2
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, Loss 0.0071 (0.0076)
# Finished training epoch 3
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, Loss 0.0071 (0.0076)
# Finished training epoch 4
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, Loss 0.0072 (0.0076)
# Finished training epoch 5
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, Loss 0.0074 (0.0076)
# Finished training epoch 6
# Validate: Loss 0.0072 (0.0074)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, Loss 0.0077 (0.0076)
# Finished training epoch 7
# Validate: Loss 0.0071 (0.0074)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, Loss 0.0069 (0.0076)
# Finished training epoch 8
# Validate: Loss 0.0071 (0.0074)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, Loss 0.0082 (0.0076)
# Finished training epoch 9
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, Loss 0.0075 (0.0076)
# Finished training epoch 10
# Validate: Loss 0.0074 (0.0075)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, Loss 0.0080 (0.0076)
# Finished training epoch 11
# Validate: Loss 0.0075 (0.0076)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, Loss 0.0075 (0.0076)
# Finished training epoch 12
# Validate: Loss 0.0074 (0.0075)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, Loss 0.0081 (0.0076)
# Finished training epoch 13
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, Loss 0.0072 (0.0076)
# Finished training epoch 14
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, Loss 0.0082 (0.0076)
# Finished training epoch 15
# Validate: Loss 0.0072 (0.0074)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, Loss 0.0069 (0.0076)
# Finished training epoch 16
# Validate: Loss 0.0074 (0.0074)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, Loss 0.0079 (0.0076)
# Finished training epoch 17
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, Loss 0.0090 (0.0076)
# Finished training epoch 18
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, Loss 0.0069 (0.0076)
# Finished training epoch 19
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, Loss 0.0083 (0.0076)
# Finished training epoch 20
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, Loss 0.0081 (0.0076)
# Finished training epoch 21
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, Loss 0.0072 (0.0076)
# Finished training epoch 22
# Validate: Loss 0.0075 (0.0075)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, Loss 0.0070 (0.0076)
# Finished training epoch 23
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, Loss 0.0069 (0.0076)
# Finished training epoch 24
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, Loss 0.0081 (0.0076)
# Finished training epoch 25
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, Loss 0.0075 (0.0076)
# Finished training epoch 26
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, Loss 0.0079 (0.0076)
# Finished training epoch 27
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, Loss 0.0078 (0.0076)
# Finished training epoch 28
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, Loss 0.0071 (0.0076)
# Finished training epoch 29
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, Loss 0.0077 (0.0076)
# Finished training epoch 30
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, Loss 0.0074 (0.0076)
# Finished training epoch 31
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, Loss 0.0075 (0.0076)
# Finished training epoch 32
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, Loss 0.0069 (0.0076)
# Finished training epoch 33
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, Loss 0.0084 (0.0076)
# Finished training epoch 34
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, Loss 0.0067 (0.0076)
# Finished training epoch 35
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, Loss 0.0073 (0.0076)
# Finished training epoch 36
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, Loss 0.0073 (0.0076)
# Finished training epoch 37
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, Loss 0.0075 (0.0076)
# Finished training epoch 38
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, Loss 0.0077 (0.0076)
# Finished training epoch 39
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, Loss 0.0081 (0.0076)
# Finished training epoch 40
# Validate: Loss 0.0074 (0.0075)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, Loss 0.0085 (0.0076)
# Finished training epoch 41
# Validate: Loss 0.0075 (0.0075)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, Loss 0.0076 (0.0076)
# Finished training epoch 42
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, Loss 0.0077 (0.0076)
# Finished training epoch 43
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, Loss 0.0077 (0.0076)
# Finished training epoch 44
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, Loss 0.0071 (0.0076)
# Finished training epoch 45
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, Loss 0.0071 (0.0076)
# Finished training epoch 46
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, Loss 0.0079 (0.0076)
# Finished training epoch 47
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, Loss 0.0081 (0.0076)
# Finished training epoch 48
# Validate: Loss 0.0079 (0.0078)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, Loss 0.0085 (0.0076)
# Finished training epoch 49
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, Loss 0.0071 (0.0076)
# Finished training epoch 50
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, Loss 0.0081 (0.0076)
# Finished training epoch 51
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, Loss 0.0071 (0.0076)
# Finished training epoch 52
# Validate: Loss 0.0071 (0.0074)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, Loss 0.0080 (0.0076)
# Finished training epoch 53
# Validate: Loss 0.0076 (0.0076)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, Loss 0.0065 (0.0076)
# Finished training epoch 54
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, Loss 0.0075 (0.0076)
# Finished training epoch 55
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, Loss 0.0081 (0.0076)
# Finished training epoch 56
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, Loss 0.0075 (0.0076)
# Finished training epoch 57
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, Loss 0.0080 (0.0076)
# Finished training epoch 58
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, Loss 0.0076 (0.0076)
# Finished training epoch 59
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, Loss 0.0076 (0.0076)
# Finished training epoch 60
# Validate: Loss 0.0072 (0.0074)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, Loss 0.0077 (0.0076)
# Finished training epoch 61
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, Loss 0.0062 (0.0076)
# Finished training epoch 62
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, Loss 0.0079 (0.0076)
# Finished training epoch 63
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, Loss 0.0064 (0.0076)
# Finished training epoch 64
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, Loss 0.0077 (0.0076)
# Finished training epoch 65
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, Loss 0.0083 (0.0076)
# Finished training epoch 66
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, Loss 0.0081 (0.0076)
# Finished training epoch 67
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, Loss 0.0072 (0.0076)
# Finished training epoch 68
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, Loss 0.0080 (0.0076)
# Finished training epoch 69
# Validate: Loss 0.0074 (0.0074)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, Loss 0.0078 (0.0076)
# Finished training epoch 70
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, Loss 0.0076 (0.0076)
# Finished training epoch 71
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, Loss 0.0071 (0.0076)
# Finished training epoch 72
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, Loss 0.0074 (0.0076)
# Finished training epoch 73
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, Loss 0.0069 (0.0076)
# Finished training epoch 74
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, Loss 0.0080 (0.0076)
# Finished training epoch 75
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, Loss 0.0075 (0.0076)
# Finished training epoch 76
# Validate: Loss 0.0071 (0.0074)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, Loss 0.0070 (0.0076)
# Finished training epoch 77
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, Loss 0.0078 (0.0076)
# Finished training epoch 78
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, Loss 0.0076 (0.0076)
# Finished training epoch 79
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, Loss 0.0059 (0.0076)
# Finished training epoch 80
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, Loss 0.0079 (0.0076)
# Finished training epoch 81
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, Loss 0.0073 (0.0076)
# Finished training epoch 82
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, Loss 0.0084 (0.0076)
# Finished training epoch 83
# Validate: Loss 0.0075 (0.0075)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, Loss 0.0084 (0.0076)
# Finished training epoch 84
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, Loss 0.0072 (0.0076)
# Finished training epoch 85
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, Loss 0.0078 (0.0076)
# Finished training epoch 86
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, Loss 0.0073 (0.0076)
# Finished training epoch 87
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, Loss 0.0073 (0.0076)
# Finished training epoch 88
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, Loss 0.0077 (0.0076)
# Finished training epoch 89
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, Loss 0.0074 (0.0076)
# Finished training epoch 90
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, Loss 0.0073 (0.0076)
# Finished training epoch 91
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, Loss 0.0070 (0.0076)
# Finished training epoch 92
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, Loss 0.0077 (0.0076)
# Finished training epoch 93
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, Loss 0.0085 (0.0076)
# Finished training epoch 94
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, Loss 0.0070 (0.0076)
# Finished training epoch 95
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, Loss 0.0083 (0.0076)
# Finished training epoch 96
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, Loss 0.0083 (0.0076)
# Finished training epoch 97
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, Loss 0.0072 (0.0076)
# Finished training epoch 98
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, Loss 0.0076 (0.0076)
# Finished training epoch 99
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, Loss 0.0078 (0.0076)
# Finished training epoch 100
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, Loss 0.0089 (0.0076)
# Finished training epoch 101
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, Loss 0.0086 (0.0076)
# Finished training epoch 102
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, Loss 0.0082 (0.0076)
# Finished training epoch 103
# Validate: Loss 0.0074 (0.0074)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, Loss 0.0078 (0.0076)
# Finished training epoch 104
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, Loss 0.0085 (0.0076)
# Finished training epoch 105
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, Loss 0.0088 (0.0076)
# Finished training epoch 106
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, Loss 0.0071 (0.0075)
# Finished training epoch 107
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, Loss 0.0074 (0.0076)
# Finished training epoch 108
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, Loss 0.0071 (0.0076)
# Finished training epoch 109
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, Loss 0.0070 (0.0076)
# Finished training epoch 110
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, Loss 0.0069 (0.0076)
# Finished training epoch 111
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, Loss 0.0079 (0.0076)
# Finished training epoch 112
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, Loss 0.0087 (0.0076)
# Finished training epoch 113
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, Loss 0.0078 (0.0076)
# Finished training epoch 114
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, Loss 0.0077 (0.0076)
# Finished training epoch 115
# Validate: Loss 0.0074 (0.0074)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, Loss 0.0075 (0.0076)
# Finished training epoch 116
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, Loss 0.0072 (0.0076)
# Finished training epoch 117
# Validate: Loss 0.0070 (0.0073)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, Loss 0.0062 (0.0076)
# Finished training epoch 118
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, Loss 0.0087 (0.0076)
# Finished training epoch 119
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, Loss 0.0074 (0.0076)
# Finished training epoch 120
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, Loss 0.0075 (0.0076)
# Finished training epoch 121
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, Loss 0.0078 (0.0076)
# Finished training epoch 122
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, Loss 0.0085 (0.0076)
# Finished training epoch 123
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, Loss 0.0068 (0.0076)
# Finished training epoch 124
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, Loss 0.0074 (0.0076)
# Finished training epoch 125
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, Loss 0.0072 (0.0076)
# Finished training epoch 126
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, Loss 0.0082 (0.0076)
# Finished training epoch 127
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, Loss 0.0079 (0.0076)
# Finished training epoch 128
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, Loss 0.0074 (0.0076)
# Finished training epoch 129
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, Loss 0.0071 (0.0076)
# Finished training epoch 130
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, Loss 0.0081 (0.0076)
# Finished training epoch 131
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, Loss 0.0076 (0.0076)
# Finished training epoch 132
# Validate: Loss 0.0073 (0.0075)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, Loss 0.0068 (0.0076)
# Finished training epoch 133
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, Loss 0.0078 (0.0076)
# Finished training epoch 134
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, Loss 0.0081 (0.0076)
# Finished training epoch 135
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, Loss 0.0082 (0.0076)
# Finished training epoch 136
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, Loss 0.0076 (0.0076)
# Finished training epoch 137
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, Loss 0.0082 (0.0076)
# Finished training epoch 138
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, Loss 0.0079 (0.0076)
# Finished training epoch 139
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, Loss 0.0077 (0.0076)
# Finished training epoch 140
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, Loss 0.0070 (0.0076)
# Finished training epoch 141
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, Loss 0.0070 (0.0076)
# Finished training epoch 142
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, Loss 0.0074 (0.0076)
# Finished training epoch 143
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, Loss 0.0082 (0.0076)
# Finished training epoch 144
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, Loss 0.0091 (0.0076)
# Finished training epoch 145
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, Loss 0.0069 (0.0076)
# Finished training epoch 146
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, Loss 0.0076 (0.0076)
# Finished training epoch 147
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, Loss 0.0083 (0.0076)
# Finished training epoch 148
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, Loss 0.0080 (0.0076)
# Finished training epoch 149
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, Loss 0.0089 (0.0076)
# Finished training epoch 150
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, Loss 0.0080 (0.0076)
# Finished training epoch 151
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, Loss 0.0068 (0.0076)
# Finished training epoch 152
# Validate: Loss 0.0074 (0.0074)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, Loss 0.0072 (0.0076)
# Finished training epoch 153
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, Loss 0.0080 (0.0076)
# Finished training epoch 154
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, Loss 0.0074 (0.0076)
# Finished training epoch 155
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, Loss 0.0070 (0.0076)
# Finished training epoch 156
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, Loss 0.0074 (0.0076)
# Finished training epoch 157
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, Loss 0.0077 (0.0076)
# Finished training epoch 158
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, Loss 0.0067 (0.0076)
# Finished training epoch 159
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, Loss 0.0071 (0.0076)
# Finished training epoch 160
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, Loss 0.0073 (0.0076)
# Finished training epoch 161
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, Loss 0.0074 (0.0076)
# Finished training epoch 162
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, Loss 0.0073 (0.0076)
# Finished training epoch 163
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, Loss 0.0081 (0.0076)
# Finished training epoch 164
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, Loss 0.0077 (0.0076)
# Finished training epoch 165
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, Loss 0.0080 (0.0076)
# Finished training epoch 166
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, Loss 0.0074 (0.0076)
# Finished training epoch 167
# Validate: Loss 0.0074 (0.0074)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, Loss 0.0075 (0.0076)
# Finished training epoch 168
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, Loss 0.0080 (0.0076)
# Finished training epoch 169
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, Loss 0.0079 (0.0076)
# Finished training epoch 170
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, Loss 0.0073 (0.0076)
# Finished training epoch 171
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, Loss 0.0074 (0.0076)
# Finished training epoch 172
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 173
# Epoch: 173, Loss 0.0069 (0.0075)
# Finished training epoch 173
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 174
# Epoch: 174, Loss 0.0080 (0.0076)
# Finished training epoch 174
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 175
# Epoch: 175, Loss 0.0080 (0.0076)
# Finished training epoch 175
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 176
# Epoch: 176, Loss 0.0085 (0.0076)
# Finished training epoch 176
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 177
# Epoch: 177, Loss 0.0076 (0.0076)
# Finished training epoch 177
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 178
# Epoch: 178, Loss 0.0067 (0.0076)
# Finished training epoch 178
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 179
# Epoch: 179, Loss 0.0078 (0.0076)
# Finished training epoch 179
# Validate: Loss 0.0072 (0.0074)
# Finished validation.
# Starting training epoch 180
# Epoch: 180, Loss 0.0071 (0.0076)
# Finished training epoch 180
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 181
# Epoch: 181, Loss 0.0078 (0.0076)
# Finished training epoch 181
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 182
# Epoch: 182, Loss 0.0073 (0.0076)
# Finished training epoch 182
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 183
# Epoch: 183, Loss 0.0080 (0.0075)
# Finished training epoch 183
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 184
# Epoch: 184, Loss 0.0073 (0.0076)
# Finished training epoch 184
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 185
# Epoch: 185, Loss 0.0084 (0.0076)
# Finished training epoch 185
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 186
# Epoch: 186, Loss 0.0070 (0.0076)
# Finished training epoch 186
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 187
# Epoch: 187, Loss 0.0076 (0.0076)
# Finished training epoch 187
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 188
# Epoch: 188, Loss 0.0087 (0.0076)
# Finished training epoch 188
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 189
# Epoch: 189, Loss 0.0077 (0.0075)
# Finished training epoch 189
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 190
# Epoch: 190, Loss 0.0080 (0.0075)
# Finished training epoch 190
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 191
# Epoch: 191, Loss 0.0077 (0.0076)
# Finished training epoch 191
# Validate: Loss 0.0073 (0.0074)
# Finished validation.
# Starting training epoch 192
# Epoch: 192, Loss 0.0076 (0.0076)
# Finished training epoch 192
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 193
# Epoch: 193, Loss 0.0067 (0.0076)
# Finished training epoch 193
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 194
# Epoch: 194, Loss 0.0068 (0.0076)
# Finished training epoch 194
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 195
# Epoch: 195, Loss 0.0081 (0.0075)
# Finished training epoch 195
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 196
# Epoch: 196, Loss 0.0083 (0.0076)
# Finished training epoch 196
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 197
# Epoch: 197, Loss 0.0071 (0.0076)
# Finished training epoch 197
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 198
# Epoch: 198, Loss 0.0076 (0.0076)
# Finished training epoch 198
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 199
# Epoch: 199, Loss 0.0077 (0.0075)
# Finished training epoch 199
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 200
# Epoch: 200, Loss 0.0079 (0.0076)
# Finished training epoch 200
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 201
# Epoch: 201, Loss 0.0078 (0.0076)
# Finished training epoch 201
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 202
# Epoch: 202, Loss 0.0071 (0.0076)
# Finished training epoch 202
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 203
# Epoch: 203, Loss 0.0080 (0.0076)
# Finished training epoch 203
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 204
# Epoch: 204, Loss 0.0077 (0.0076)
# Finished training epoch 204
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 205
# Epoch: 205, Loss 0.0070 (0.0075)
# Finished training epoch 205
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 206
# Epoch: 206, Loss 0.0075 (0.0076)
# Finished training epoch 206
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 207
# Epoch: 207, Loss 0.0076 (0.0076)
# Finished training epoch 207
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 208
# Epoch: 208, Loss 0.0069 (0.0076)
# Finished training epoch 208
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 209
# Epoch: 209, Loss 0.0074 (0.0076)
# Finished training epoch 209
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 210
# Epoch: 210, Loss 0.0081 (0.0076)
# Finished training epoch 210
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 211
# Epoch: 211, Loss 0.0081 (0.0076)
# Finished training epoch 211
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 212
# Epoch: 212, Loss 0.0073 (0.0076)
# Finished training epoch 212
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 213
# Epoch: 213, Loss 0.0075 (0.0076)
# Finished training epoch 213
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 214
# Epoch: 214, Loss 0.0077 (0.0076)
# Finished training epoch 214
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 215
# Epoch: 215, Loss 0.0072 (0.0076)
# Finished training epoch 215
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 216
# Epoch: 216, Loss 0.0070 (0.0076)
# Finished training epoch 216
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 217
# Epoch: 217, Loss 0.0072 (0.0076)
# Finished training epoch 217
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 218
# Epoch: 218, Loss 0.0073 (0.0075)
# Finished training epoch 218
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 219
# Epoch: 219, Loss 0.0063 (0.0076)
# Finished training epoch 219
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 220
# Epoch: 220, Loss 0.0079 (0.0076)
# Finished training epoch 220
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 221
# Epoch: 221, Loss 0.0078 (0.0076)
# Finished training epoch 221
# Validate: Loss 0.0074 (0.0074)
# Finished validation.
# Starting training epoch 222
# Epoch: 222, Loss 0.0077 (0.0076)
# Finished training epoch 222
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 223
# Epoch: 223, Loss 0.0073 (0.0076)
# Finished training epoch 223
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 224
# Epoch: 224, Loss 0.0072 (0.0076)
# Finished training epoch 224
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 225
# Epoch: 225, Loss 0.0078 (0.0076)
# Finished training epoch 225
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 226
# Epoch: 226, Loss 0.0075 (0.0076)
# Finished training epoch 226
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 227
# Epoch: 227, Loss 0.0075 (0.0076)
# Finished training epoch 227
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 228
# Epoch: 228, Loss 0.0075 (0.0076)
# Finished training epoch 228
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 229
# Epoch: 229, Loss 0.0071 (0.0075)
# Finished training epoch 229
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 230
# Epoch: 230, Loss 0.0078 (0.0076)
# Finished training epoch 230
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 231
# Epoch: 231, Loss 0.0076 (0.0076)
# Finished training epoch 231
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 232
# Epoch: 232, Loss 0.0085 (0.0076)
# Finished training epoch 232
# Validate: Loss 0.0072 (0.0074)
# Finished validation.
# Starting training epoch 233
# Epoch: 233, Loss 0.0072 (0.0076)
# Finished training epoch 233
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 234
# Epoch: 234, Loss 0.0077 (0.0076)
# Finished training epoch 234
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 235
# Epoch: 235, Loss 0.0080 (0.0076)
# Finished training epoch 235
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 236
# Epoch: 236, Loss 0.0076 (0.0076)
# Finished training epoch 236
# Validate: Loss 0.0074 (0.0074)
# Finished validation.
# Starting training epoch 237
# Epoch: 237, Loss 0.0070 (0.0076)
# Finished training epoch 237
# Validate: Loss 0.0073 (0.0073)
# Finished validation.
# Starting training epoch 238
# Epoch: 238, Loss 0.0078 (0.0076)
# Finished training epoch 238
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 239
# Epoch: 239, Loss 0.0069 (0.0076)
# Finished training epoch 239
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 240
# Epoch: 240, Loss 0.0073 (0.0076)
# Finished training epoch 240
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 241
# Epoch: 241, Loss 0.0067 (0.0076)
# Finished training epoch 241
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 242
# Epoch: 242, Loss 0.0071 (0.0076)
# Finished training epoch 242
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 243
# Epoch: 243, Loss 0.0074 (0.0076)
# Finished training epoch 243
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 244
# Epoch: 244, Loss 0.0074 (0.0076)
# Finished training epoch 244
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 245
# Epoch: 245, Loss 0.0086 (0.0076)
# Finished training epoch 245
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 246
# Epoch: 246, Loss 0.0083 (0.0076)
# Finished training epoch 246
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 247
# Epoch: 247, Loss 0.0081 (0.0076)
# Finished training epoch 247
# Validate: Loss 0.0071 (0.0073)
# Finished validation.
# Starting training epoch 248
# Epoch: 248, Loss 0.0070 (0.0076)
# Finished training epoch 248
# Validate: Loss 0.0072 (0.0073)
# Finished validation.
# Starting training epoch 249
# Epoch: 249, Loss 0.0077 (0.0076)
# Finished training epoch 249
# Validate: Loss 0.0072 (0.0073)
# Finished validation.

# %%
torch.save(model.state_dict(), '{}/model-epoch-{}-last-losses-{:.3f}.pth'.format(checkpoints,"last",losses))

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
