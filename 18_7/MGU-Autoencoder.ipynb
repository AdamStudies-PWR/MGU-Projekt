# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
# Reusing TensorBoard on port 6007 (pid 16107), started 0:58:03 ago. (Use '!kill 16107' to kill it.)
#       <iframe id="tensorboard-frame-fd30c555de91d656" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-fd30c555de91d656");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .5

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(self.convtrans3(x), scale_factor=scale_factor)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 16, 16]           2,306
# ================================================================
# Total params: 2,662,274
# Trainable params: 2,662,274
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.75
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.91
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.10759954 (1.94897345), PSNR 9.68189526 (4.60876074), SSIM 0.04124395 (0.01382493)
# Finished training epoch 0
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 37 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 74 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 266 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 99 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 24 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 53 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 210 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 23 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 217 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 62 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.08022149 (0.10228657), PSNR 10.95709229 (10.25020947), SSIM 0.04317306 (0.04190793)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.05792886 (0.07710596), PSNR 12.37104988 (11.19899808), SSIM 0.22418387 (0.10879513)
# Finished training epoch 1
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 6 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 38 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 191 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 44 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 205 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 142 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.04575937 (0.05302155), PSNR 13.39519882 (13.33253447), SSIM 0.17119032 (0.19321194)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.03758120 (0.04658081), PSNR 14.25029278 (13.35549822), SSIM 0.26839513 (0.24917847)
# Finished training epoch 2
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 5 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 147 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 31 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 140 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 77 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.02889898 (0.03515750), PSNR 15.39117336 (15.13252701), SSIM 0.26680142 (0.31588141)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.02387550 (0.03008388), PSNR 16.22047615 (15.25247860), SSIM 0.37600407 (0.35217189)
# Finished training epoch 3
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 19 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 152 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 30 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 127 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 45 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.02044395 (0.02583954), PSNR 16.89435196 (16.44143798), SSIM 0.32853615 (0.39421866)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.01617739 (0.01966981), PSNR 17.91091537 (17.09455260), SSIM 0.44457665 (0.42424622)
# Finished training epoch 4
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 78 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 8 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 102 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 12 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01329490 (0.01622793), PSNR 18.76314926 (18.37991976), SSIM 0.37941021 (0.45821365)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.01018897 (0.01316150), PSNR 19.91869736 (18.83759282), SSIM 0.51549351 (0.48363659)
# Finished training epoch 5
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 103 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 79 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01043332 (0.01172813), PSNR 19.81577492 (19.72911078), SSIM 0.42386913 (0.51201537)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00719334 (0.00902564), PSNR 21.43069077 (20.47273463), SSIM 0.56424636 (0.53341954)
# Finished training epoch 6
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 51 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 36 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00666613 (0.00745771), PSNR 21.76125908 (21.57483108), SSIM 0.48077494 (0.56020327)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00561851 (0.00644206), PSNR 22.50378990 (21.93128272), SSIM 0.61309904 (0.57453763)
# Finished training epoch 7
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 18 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 16 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00538449 (0.00558908), PSNR 22.68855095 (22.74398469), SSIM 0.51247001 (0.59357520)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00456383 (0.00486607), PSNR 23.40670204 (23.14674838), SSIM 0.60853499 (0.60982206)
# Finished training epoch 8
# Validate: MSE 0.00421030 (0.00427802), PSNR 23.75687027 (23.82043450), SSIM 0.55014777 (0.62997597)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00364085 (0.00391332), PSNR 24.38796806 (24.09305133), SSIM 0.64753616 (0.63998219)
# Finished training epoch 9
# Validate: MSE 0.00367949 (0.00353233), PSNR 24.34212112 (24.60717479), SSIM 0.58982980 (0.65993816)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00304835 (0.00336919), PSNR 25.15934753 (24.74219407), SSIM 0.68892640 (0.66651481)
# Finished training epoch 10
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00340592 (0.00318801), PSNR 24.67765999 (25.03963680), SSIM 0.61779535 (0.67845076)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00362838 (0.00305677), PSNR 24.40287590 (25.16863363), SSIM 0.68508917 (0.68931587)
# Finished training epoch 11
# Validate: MSE 0.00323373 (0.00296695), PSNR 24.90295601 (25.35515921), SSIM 0.62923193 (0.69834541)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00240246 (0.00287992), PSNR 26.19342995 (25.42750319), SSIM 0.72012317 (0.70880786)
# Finished training epoch 12
# Validate: MSE 0.00328374 (0.00280938), PSNR 24.83631325 (25.58000973), SSIM 0.66949695 (0.72753991)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00304349 (0.00277911), PSNR 25.16628075 (25.58328638), SSIM 0.70826352 (0.72402055)
# Finished training epoch 13
# Validate: MSE 0.00310060 (0.00272669), PSNR 25.08554268 (25.71196626), SSIM 0.67489541 (0.73570372)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00277765 (0.00272080), PSNR 25.56322479 (25.67630638), SSIM 0.75493157 (0.73737022)
# Finished training epoch 14
# Validate: MSE 0.00297391 (0.00268200), PSNR 25.26672173 (25.78702927), SSIM 0.68531883 (0.74646387)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00253470 (0.00268352), PSNR 25.96072578 (25.73683882), SSIM 0.76098090 (0.74729922)
# Finished training epoch 15
# Validate: MSE 0.00298282 (0.00265344), PSNR 25.25373268 (25.83243896), SSIM 0.69540507 (0.75538293)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00317517 (0.00266220), PSNR 24.98233032 (25.77026813), SSIM 0.74288070 (0.75432402)
# Finished training epoch 16
# Validate: MSE 0.00289251 (0.00263839), PSNR 25.38725281 (25.86063220), SSIM 0.69254601 (0.75628092)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00203913 (0.00264529), PSNR 26.90555954 (25.79701807), SSIM 0.78504527 (0.75900221)
# Finished training epoch 17
# Validate: MSE 0.00290355 (0.00263273), PSNR 25.37070465 (25.86355416), SSIM 0.69900930 (0.76094850)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00309201 (0.00263517), PSNR 25.09758377 (25.81377672), SSIM 0.76008558 (0.76193724)
# Finished training epoch 18
# Validate: MSE 0.00305897 (0.00271645), PSNR 25.14425087 (25.73392106), SSIM 0.69970560 (0.76190989)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00256780 (0.00262500), PSNR 25.90437889 (25.82905488), SSIM 0.76812685 (0.76344898)
# Finished training epoch 19
# Validate: MSE 0.00302087 (0.00261845), PSNR 25.19867325 (25.89061458), SSIM 0.69796383 (0.76455138)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00221648 (0.00261065), PSNR 26.54336548 (25.85491260), SSIM 0.77068818 (0.76422335)
# Finished training epoch 20
# Validate: MSE 0.00291996 (0.00277998), PSNR 25.34622383 (25.65836382), SSIM 0.69819021 (0.76234197)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00201967 (0.00260388), PSNR 26.94718552 (25.86481221), SSIM 0.79129040 (0.76470616)
# Finished training epoch 21
# Validate: MSE 0.00311544 (0.00268924), PSNR 25.06480980 (25.76578800), SSIM 0.69914103 (0.76448720)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00270609 (0.00260640), PSNR 25.67657852 (25.86175608), SSIM 0.74718004 (0.76459134)
# Finished training epoch 22
# Validate: MSE 0.00295944 (0.00276288), PSNR 25.28789902 (25.65894384), SSIM 0.69866538 (0.76144089)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00299371 (0.00259218), PSNR 25.23790169 (25.88779112), SSIM 0.75555086 (0.76459750)
# Finished training epoch 23
# Validate: MSE 0.00291551 (0.00283960), PSNR 25.35286140 (25.57398794), SSIM 0.69571495 (0.75952883)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00230183 (0.00259405), PSNR 26.37926102 (25.88341747), SSIM 0.79134238 (0.76471117)
# Finished training epoch 24
# Validate: MSE 0.00279453 (0.00263522), PSNR 25.53691673 (25.85991939), SSIM 0.70013714 (0.76548381)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00198987 (0.00257970), PSNR 27.01175880 (25.90759971), SSIM 0.75628173 (0.76531859)
# Finished training epoch 25
# Validate: MSE 0.00300643 (0.00261469), PSNR 25.21948051 (25.89437937), SSIM 0.69949275 (0.76330091)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00281527 (0.00259274), PSNR 25.50480270 (25.88353248), SSIM 0.75954026 (0.76466538)
# Finished training epoch 26
# Validate: MSE 0.00290579 (0.00275786), PSNR 25.36735344 (25.68506782), SSIM 0.70075721 (0.76506779)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00268248 (0.00260005), PSNR 25.71464157 (25.87361138), SSIM 0.76900315 (0.76422946)
# Finished training epoch 27
# Validate: MSE 0.00299381 (0.00277692), PSNR 25.23775482 (25.64032416), SSIM 0.69424403 (0.75900379)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00219077 (0.00257479), PSNR 26.59403038 (25.91594256), SSIM 0.78758740 (0.76529763)
# Finished training epoch 28
# Validate: MSE 0.00281676 (0.00258209), PSNR 25.50250626 (25.95403099), SSIM 0.70478928 (0.76728439)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00290720 (0.00260498), PSNR 25.36524963 (25.86399121), SSIM 0.75432515 (0.76433440)
# Finished training epoch 29
# Validate: MSE 0.00298598 (0.00290916), PSNR 25.24913597 (25.47246759), SSIM 0.69525099 (0.75694694)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00276237 (0.00257087), PSNR 25.58718109 (25.92211059), SSIM 0.76415157 (0.76581114)
# Finished training epoch 30
# Validate: MSE 0.00309407 (0.00278050), PSNR 25.09469414 (25.62923818), SSIM 0.69934225 (0.76063025)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00202611 (0.00255491), PSNR 26.93336105 (25.95379943), SSIM 0.78484207 (0.76686493)
# Finished training epoch 31
# Validate: MSE 0.00453362 (0.00431609), PSNR 23.43555260 (23.77135809), SSIM 0.68109721 (0.74204245)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00215051 (0.00253399), PSNR 26.67457390 (25.98457260), SSIM 0.77427405 (0.76794794)
# Finished training epoch 32
# Validate: MSE 0.00292480 (0.00256870), PSNR 25.33904457 (25.98018329), SSIM 0.70466268 (0.77023152)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00233018 (0.00253613), PSNR 26.32610703 (25.98023121), SSIM 0.76190531 (0.76789567)
# Finished training epoch 33
# Validate: MSE 0.00310021 (0.00267268), PSNR 25.08609009 (25.79119104), SSIM 0.69421178 (0.76112494)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00313853 (0.00249095), PSNR 25.03273010 (26.05731753), SSIM 0.75524920 (0.76950636)
# Finished training epoch 34
# Validate: MSE 0.00295277 (0.00304447), PSNR 25.29770470 (25.27237179), SSIM 0.69714546 (0.75766318)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00283367 (0.00249180), PSNR 25.47650719 (26.05695178), SSIM 0.77168626 (0.76950171)
# Finished training epoch 35
# Validate: MSE 0.00270151 (0.00276352), PSNR 25.68392754 (25.68333420), SSIM 0.70648456 (0.76420295)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00247440 (0.00246767), PSNR 26.06530380 (26.10203634), SSIM 0.76012081 (0.77027067)
# Finished training epoch 36
# Validate: MSE 0.00293242 (0.00261267), PSNR 25.32774353 (25.89710195), SSIM 0.70436507 (0.76467118)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00269245 (0.00247278), PSNR 25.69851685 (26.09068256), SSIM 0.75618136 (0.77032257)
# Finished training epoch 37
# Validate: MSE 0.00315050 (0.00281142), PSNR 25.01620865 (25.59967449), SSIM 0.70389217 (0.76503915)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00260441 (0.00245921), PSNR 25.84290504 (26.11529101), SSIM 0.73449910 (0.77087980)
# Finished training epoch 38
# Validate: MSE 0.00299417 (0.00260588), PSNR 25.23723984 (25.90537856), SSIM 0.70089507 (0.76452547)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00249813 (0.00244167), PSNR 26.02383995 (26.14655184), SSIM 0.75080156 (0.77161409)
# Finished training epoch 39
# Validate: MSE 0.00366085 (0.00335006), PSNR 24.36418343 (24.85704825), SSIM 0.69831103 (0.75722030)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00251795 (0.00243637), PSNR 25.98952484 (26.15479186), SSIM 0.76594907 (0.77142974)
# Finished training epoch 40
# Validate: MSE 0.00278861 (0.00254577), PSNR 25.54611397 (25.99720335), SSIM 0.70798618 (0.76874453)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00254789 (0.00242760), PSNR 25.93819618 (26.17405444), SSIM 0.80405998 (0.77241193)
# Finished training epoch 41
# Validate: MSE 0.00333477 (0.00283557), PSNR 24.76933479 (25.56643369), SSIM 0.70461470 (0.77075737)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00240373 (0.00243386), PSNR 26.19114685 (26.15970129), SSIM 0.76522654 (0.77203588)
# Finished training epoch 42
# Validate: MSE 0.00267361 (0.00270297), PSNR 25.72901726 (25.78658418), SSIM 0.71007848 (0.76876568)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00206798 (0.00242114), PSNR 26.84453392 (26.18248067), SSIM 0.79171526 (0.77258563)
# Finished training epoch 43
# Validate: MSE 0.00283778 (0.00243823), PSNR 25.47021866 (26.19715743), SSIM 0.70848644 (0.77144750)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00198757 (0.00242073), PSNR 27.01677513 (26.18036883), SSIM 0.78998679 (0.77200747)
# Finished training epoch 44
# Validate: MSE 0.00301328 (0.00279237), PSNR 25.20960236 (25.62578429), SSIM 0.70715511 (0.77008664)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00218305 (0.00242205), PSNR 26.60935593 (26.18366264), SSIM 0.77689588 (0.77230691)
# Finished training epoch 45
# Validate: MSE 0.00332510 (0.00319638), PSNR 24.78195000 (25.05024704), SSIM 0.70491791 (0.76334729)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00236028 (0.00240945), PSNR 26.27035904 (26.20233201), SSIM 0.76680076 (0.77226685)
# Finished training epoch 46
# Validate: MSE 0.00284605 (0.00252478), PSNR 25.45757675 (26.04540861), SSIM 0.70217961 (0.76428099)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00229190 (0.00241149), PSNR 26.39804268 (26.20103754), SSIM 0.79716241 (0.77267099)
# Finished training epoch 47
# Validate: MSE 0.00265745 (0.00256912), PSNR 25.75534058 (25.98338782), SSIM 0.71081793 (0.77199233)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00251657 (0.00240352), PSNR 25.99191666 (26.21311418), SSIM 0.77765286 (0.77251294)
# Finished training epoch 48
# Validate: MSE 0.00276965 (0.00242956), PSNR 25.57574844 (26.21023443), SSIM 0.70928550 (0.77144909)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00282853 (0.00240824), PSNR 25.48439598 (26.20499827), SSIM 0.77575254 (0.77214363)
# Finished training epoch 49
# Validate: MSE 0.00309550 (0.00254819), PSNR 25.09268570 (26.00679603), SSIM 0.70511001 (0.77290579)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00241220 (0.00240387), PSNR 26.17586327 (26.21249730), SSIM 0.76949531 (0.77200587)
# Finished training epoch 50
# Validate: MSE 0.00277395 (0.00244885), PSNR 25.56900787 (26.17277262), SSIM 0.70897520 (0.77138092)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00290997 (0.00240013), PSNR 25.36111641 (26.22084827), SSIM 0.77073652 (0.77256243)
# Finished training epoch 51
# Validate: MSE 0.00290805 (0.00251648), PSNR 25.36398506 (26.06292366), SSIM 0.71047115 (0.77113539)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00206375 (0.00241261), PSNR 26.85342026 (26.20033736), SSIM 0.78975260 (0.77153381)
# Finished training epoch 52
# Validate: MSE 0.00275224 (0.00239434), PSNR 25.60314369 (26.26572563), SSIM 0.70856822 (0.77128873)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00256813 (0.00238984), PSNR 25.90383530 (26.23845780), SSIM 0.74880773 (0.77250099)
# Finished training epoch 53
# Validate: MSE 0.00269962 (0.00249356), PSNR 25.68697929 (26.09274287), SSIM 0.71176851 (0.77021710)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00252059 (0.00238884), PSNR 25.98497581 (26.24278661), SSIM 0.77699149 (0.77250913)
# Finished training epoch 54
# Validate: MSE 0.00272199 (0.00239271), PSNR 25.65112877 (26.27199010), SSIM 0.70849168 (0.77007531)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00268023 (0.00238764), PSNR 25.71827316 (26.24329925), SSIM 0.75976908 (0.77166944)
# Finished training epoch 55
# Validate: MSE 0.00288060 (0.00260556), PSNR 25.40517235 (25.91779974), SSIM 0.70689815 (0.76947634)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00241709 (0.00238245), PSNR 26.16707039 (26.25174449), SSIM 0.77527487 (0.77213934)
# Finished training epoch 56
# Validate: MSE 0.00270777 (0.00285521), PSNR 25.67388535 (25.58293444), SSIM 0.71056509 (0.76862760)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00277243 (0.00238088), PSNR 25.57138634 (26.25629888), SSIM 0.75494045 (0.77246869)
# Finished training epoch 57
# Validate: MSE 0.00271290 (0.00250277), PSNR 25.66566467 (26.08567100), SSIM 0.71410573 (0.77381071)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00230278 (0.00238364), PSNR 26.37747765 (26.25138604), SSIM 0.76292956 (0.77185483)
# Finished training epoch 58
# Validate: MSE 0.00280116 (0.00241158), PSNR 25.52661514 (26.23609083), SSIM 0.70304990 (0.76726397)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00268745 (0.00236865), PSNR 25.70659065 (26.27721978), SSIM 0.75996959 (0.77227066)
# Finished training epoch 59
# Validate: MSE 0.00266642 (0.00240350), PSNR 25.74070930 (26.24830948), SSIM 0.70785069 (0.76477003)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00251395 (0.00238222), PSNR 25.99642754 (26.25640250), SSIM 0.75987393 (0.77199307)
# Finished training epoch 60
# Validate: MSE 0.00285382 (0.00276896), PSNR 25.44573021 (25.69006307), SSIM 0.70854908 (0.76724981)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00240214 (0.00237096), PSNR 26.19400978 (26.27381168), SSIM 0.76700562 (0.77256054)
# Finished training epoch 61
# Validate: MSE 0.00273306 (0.00245368), PSNR 25.63351250 (26.17710932), SSIM 0.71030498 (0.77335969)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00188190 (0.00236342), PSNR 27.25403023 (26.28905740), SSIM 0.76627433 (0.77261745)
# Finished training epoch 62
# Validate: MSE 0.00259070 (0.00246718), PSNR 25.86582947 (26.12714443), SSIM 0.70790946 (0.76587123)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00186710 (0.00235989), PSNR 27.28832436 (26.28983837), SSIM 0.78228372 (0.77259785)
# Finished training epoch 63
# Validate: MSE 0.00251810 (0.00262771), PSNR 25.98927689 (25.90626075), SSIM 0.71767271 (0.76941774)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00237923 (0.00236170), PSNR 26.23562813 (26.28866486), SSIM 0.77530086 (0.77230385)
# Finished training epoch 64
# Validate: MSE 0.00261082 (0.00258712), PSNR 25.83222771 (25.96217839), SSIM 0.70561051 (0.76783130)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00202449 (0.00233821), PSNR 26.93684196 (26.33723044), SSIM 0.77641743 (0.77341124)
# Finished training epoch 65
# Validate: MSE 0.00287503 (0.00264154), PSNR 25.41358185 (25.86283641), SSIM 0.71271539 (0.76828050)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00207754 (0.00234481), PSNR 26.82451439 (26.32284322), SSIM 0.77772355 (0.77311152)
# Finished training epoch 66
# Validate: MSE 0.00298171 (0.00253229), PSNR 25.25534058 (26.03683083), SSIM 0.70804191 (0.77612193)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00275040 (0.00235991), PSNR 25.60603905 (26.29527354), SSIM 0.76872241 (0.77196945)
# Finished training epoch 67
# Validate: MSE 0.00277141 (0.00233366), PSNR 25.57299805 (26.38482520), SSIM 0.70824677 (0.77056470)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00180225 (0.00235840), PSNR 27.44183922 (26.29822195), SSIM 0.79882348 (0.77221475)
# Finished training epoch 68
# Validate: MSE 0.00268683 (0.00258331), PSNR 25.70759201 (25.96964245), SSIM 0.71226174 (0.76893529)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00253360 (0.00234448), PSNR 25.96262741 (26.32197369), SSIM 0.75780690 (0.77263947)
# Finished training epoch 69
# Validate: MSE 0.00261044 (0.00254107), PSNR 25.83286285 (26.04009100), SSIM 0.71061832 (0.77067582)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00208311 (0.00236011), PSNR 26.81288528 (26.29155673), SSIM 0.77626276 (0.77224357)
# Finished training epoch 70
# Validate: MSE 0.00300668 (0.00257494), PSNR 25.21912766 (25.96698466), SSIM 0.69902563 (0.76141212)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00265454 (0.00233879), PSNR 25.76011467 (26.33114209), SSIM 0.77537072 (0.77330700)
# Finished training epoch 71
# Validate: MSE 0.00267297 (0.00258390), PSNR 25.73005295 (25.95570375), SSIM 0.71061313 (0.76378130)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00239365 (0.00235506), PSNR 26.20940018 (26.30525733), SSIM 0.77584523 (0.77237587)
# Finished training epoch 72
# Validate: MSE 0.00291660 (0.00239632), PSNR 25.35122681 (26.27226289), SSIM 0.71134913 (0.77619179)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00260398 (0.00234046), PSNR 25.84362984 (26.32930080), SSIM 0.75710428 (0.77323523)
# Finished training epoch 73
# Validate: MSE 0.00264735 (0.00255414), PSNR 25.77189255 (26.00217802), SSIM 0.70595753 (0.76343972)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00217744 (0.00233900), PSNR 26.62054443 (26.33148368), SSIM 0.78056806 (0.77306018)
# Finished training epoch 74
# Validate: MSE 0.00253004 (0.00250476), PSNR 25.96872711 (26.07681556), SSIM 0.71142149 (0.77159627)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00226849 (0.00235058), PSNR 26.44263840 (26.31131054), SSIM 0.75167555 (0.77254665)
# Finished training epoch 75
# Validate: MSE 0.00265150 (0.00239148), PSNR 25.76508713 (26.27591020), SSIM 0.71500516 (0.77216622)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00264599 (0.00233745), PSNR 25.77411842 (26.33542893), SSIM 0.75757152 (0.77290120)
# Finished training epoch 76
# Validate: MSE 0.00259268 (0.00241385), PSNR 25.86251450 (26.23521474), SSIM 0.71363437 (0.77154177)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00229399 (0.00236167), PSNR 26.39409065 (26.29269657), SSIM 0.76003605 (0.77145198)
# Finished training epoch 77
# Validate: MSE 0.00260656 (0.00241605), PSNR 25.83932495 (26.23827512), SSIM 0.71901751 (0.77549438)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00227517 (0.00233376), PSNR 26.42986870 (26.34301393), SSIM 0.78351563 (0.77305885)
# Finished training epoch 78
# Validate: MSE 0.00284799 (0.00272725), PSNR 25.45462227 (25.76627305), SSIM 0.70592481 (0.76386506)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00254011 (0.00232326), PSNR 25.95148087 (26.36178422), SSIM 0.74914807 (0.77370333)
# Finished training epoch 79
# Validate: MSE 0.00269021 (0.00240875), PSNR 25.70213127 (26.24735874), SSIM 0.71048927 (0.77446083)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00210809 (0.00233022), PSNR 26.76111031 (26.34896578), SSIM 0.77564418 (0.77350246)
# Finished training epoch 80
# Validate: MSE 0.00271103 (0.00310415), PSNR 25.66865158 (25.24157199), SSIM 0.70364225 (0.75832718)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00339823 (0.00233084), PSNR 24.68747139 (26.34682576), SSIM 0.75205213 (0.77278205)
# Finished training epoch 81
# Validate: MSE 0.00266136 (0.00243205), PSNR 25.74895859 (26.20831484), SSIM 0.71242249 (0.77432150)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00228250 (0.00233127), PSNR 26.41588974 (26.34914417), SSIM 0.77911240 (0.77284654)
# Finished training epoch 82
# Validate: MSE 0.00274044 (0.00236656), PSNR 25.62178993 (26.32511833), SSIM 0.70904052 (0.77208530)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00180674 (0.00232098), PSNR 27.43103027 (26.36679974), SSIM 0.77572632 (0.77297546)
# Finished training epoch 83
# Validate: MSE 0.00250637 (0.00238354), PSNR 26.00954819 (26.28854062), SSIM 0.71389794 (0.77074105)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00199610 (0.00231540), PSNR 26.99817657 (26.37809412), SSIM 0.76109213 (0.77352179)
# Finished training epoch 84
# Validate: MSE 0.00270890 (0.00234465), PSNR 25.67206573 (26.36305629), SSIM 0.71141744 (0.77383291)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00229406 (0.00232848), PSNR 26.39395523 (26.35332115), SSIM 0.76187748 (0.77302649)
# Finished training epoch 85
# Validate: MSE 0.00266440 (0.00237751), PSNR 25.74401093 (26.31026578), SSIM 0.70999265 (0.77447603)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00259213 (0.00231427), PSNR 25.86343765 (26.38000509), SSIM 0.75962126 (0.77353402)
# Finished training epoch 86
# Validate: MSE 0.00259594 (0.00259066), PSNR 25.85704994 (25.95554770), SSIM 0.71543097 (0.77216131)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00227988 (0.00232058), PSNR 26.42088699 (26.36300112), SSIM 0.77070844 (0.77281270)
# Finished training epoch 87
# Validate: MSE 0.00271704 (0.00243218), PSNR 25.65904427 (26.21724663), SSIM 0.71807492 (0.77659046)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00216715 (0.00231076), PSNR 26.64111328 (26.38704293), SSIM 0.78797746 (0.77351579)
# Finished training epoch 88
# Validate: MSE 0.00269698 (0.00242628), PSNR 25.69121933 (26.21869062), SSIM 0.71748996 (0.77397033)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00232256 (0.00230912), PSNR 26.34033394 (26.38616390), SSIM 0.76359385 (0.77322755)
# Finished training epoch 89
# Validate: MSE 0.00243169 (0.00246236), PSNR 26.14091682 (26.15693897), SSIM 0.71675301 (0.77192958)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00239551 (0.00231103), PSNR 26.20602036 (26.38456555), SSIM 0.77972716 (0.77275588)
# Finished training epoch 90
# Validate: MSE 0.00259302 (0.00231416), PSNR 25.86194038 (26.41805335), SSIM 0.71376067 (0.77424202)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00235394 (0.00230746), PSNR 26.28204918 (26.38965361), SSIM 0.76744157 (0.77343731)
# Finished training epoch 91
# Validate: MSE 0.00256492 (0.00243431), PSNR 25.90925980 (26.18962964), SSIM 0.71748400 (0.76731679)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00240495 (0.00230270), PSNR 26.18893051 (26.40366083), SSIM 0.76646042 (0.77339501)
# Finished training epoch 92
# Validate: MSE 0.00250565 (0.00260335), PSNR 26.01078796 (25.93148052), SSIM 0.71278048 (0.76703863)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00265827 (0.00229922), PSNR 25.75400543 (26.40563625), SSIM 0.76526916 (0.77349817)
# Finished training epoch 93
# Validate: MSE 0.00280642 (0.00241848), PSNR 25.51847839 (26.22708721), SSIM 0.70703185 (0.76904498)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00197481 (0.00230737), PSNR 27.04474640 (26.39246295), SSIM 0.77515316 (0.77296131)
# Finished training epoch 94
# Validate: MSE 0.00266476 (0.00261716), PSNR 25.74341202 (25.89204009), SSIM 0.71301413 (0.76449226)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00245455 (0.00229856), PSNR 26.10027313 (26.40874671), SSIM 0.77736932 (0.77378757)
# Finished training epoch 95
# Validate: MSE 0.00306430 (0.00250439), PSNR 25.13668823 (26.08586355), SSIM 0.71399319 (0.77705546)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00244744 (0.00231261), PSNR 26.11288071 (26.38424309), SSIM 0.77917957 (0.77240746)
# Finished training epoch 96
# Validate: MSE 0.00260620 (0.00236265), PSNR 25.83992767 (26.32673683), SSIM 0.70928323 (0.77015919)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00216461 (0.00230203), PSNR 26.64620781 (26.40164427), SSIM 0.79467493 (0.77308842)
# Finished training epoch 97
# Validate: MSE 0.00290422 (0.00254182), PSNR 25.36970901 (26.01692833), SSIM 0.70011282 (0.76524380)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00263515 (0.00232286), PSNR 25.79194641 (26.36382376), SSIM 0.75523782 (0.77228095)
# Finished training epoch 98
# Validate: MSE 0.00258087 (0.00298549), PSNR 25.88233566 (25.39406501), SSIM 0.70705414 (0.75921189)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00217048 (0.00229341), PSNR 26.63443375 (26.41747541), SSIM 0.78211081 (0.77351171)
# Finished training epoch 99
# Validate: MSE 0.00275418 (0.00248917), PSNR 25.60007858 (26.12109062), SSIM 0.70804930 (0.77330845)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00175830 (0.00231491), PSNR 27.54905891 (26.37630335), SSIM 0.79016715 (0.77194405)
# Finished training epoch 100
# Validate: MSE 0.00255395 (0.00241746), PSNR 25.92787933 (26.23929469), SSIM 0.71099412 (0.76879286)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00274619 (0.00230085), PSNR 25.61269951 (26.40474591), SSIM 0.75528467 (0.77301441)
# Finished training epoch 101
# Validate: MSE 0.00271367 (0.00248174), PSNR 25.66442108 (26.11692482), SSIM 0.70568693 (0.76712684)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00225968 (0.00230365), PSNR 26.45953178 (26.40064864), SSIM 0.77655977 (0.77280927)
# Finished training epoch 102
# Validate: MSE 0.00269833 (0.00239623), PSNR 25.68904495 (26.26849534), SSIM 0.70918393 (0.76994517)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00194333 (0.00229672), PSNR 27.11454010 (26.41176201), SSIM 0.77936059 (0.77295697)
# Finished training epoch 103
# Validate: MSE 0.00275627 (0.00233881), PSNR 25.59679031 (26.36933755), SSIM 0.70214462 (0.76732682)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00220350 (0.00229604), PSNR 26.56887436 (26.41113599), SSIM 0.76492321 (0.77297769)
# Finished training epoch 104
# Validate: MSE 0.00274811 (0.00242289), PSNR 25.60966492 (26.22658550), SSIM 0.71103525 (0.77006654)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00219634 (0.00229165), PSNR 26.58301163 (26.42259504), SSIM 0.77198446 (0.77330149)
# Finished training epoch 105
# Validate: MSE 0.00253325 (0.00240041), PSNR 25.96322632 (26.25474182), SSIM 0.71289313 (0.76406430)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00218485 (0.00231052), PSNR 26.60578918 (26.38736704), SSIM 0.77882302 (0.77189005)
# Finished training epoch 106
# Validate: MSE 0.00248429 (0.00236602), PSNR 26.04797554 (26.33042451), SSIM 0.71220452 (0.76930543)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00219291 (0.00229070), PSNR 26.58978081 (26.42185237), SSIM 0.77035487 (0.77311479)
# Finished training epoch 107
# Validate: MSE 0.00255022 (0.00259619), PSNR 25.93421745 (25.94457724), SSIM 0.71588695 (0.76275158)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00217904 (0.00229862), PSNR 26.61734390 (26.40914241), SSIM 0.77240849 (0.77288519)
# Finished training epoch 108
# Validate: MSE 0.00281071 (0.00254302), PSNR 25.51183128 (26.03425018), SSIM 0.70969981 (0.76451429)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00306028 (0.00229973), PSNR 25.14238739 (26.40390029), SSIM 0.78619343 (0.77253415)
# Finished training epoch 109
# Validate: MSE 0.00280833 (0.00270819), PSNR 25.51551437 (25.78268605), SSIM 0.70572257 (0.76364969)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00201327 (0.00228603), PSNR 26.96097946 (26.43129959), SSIM 0.78723347 (0.77370371)
# Finished training epoch 110
# Validate: MSE 0.00277259 (0.00236284), PSNR 25.57114220 (26.33148080), SSIM 0.71791458 (0.77371565)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00269899 (0.00228045), PSNR 25.68798637 (26.44464545), SSIM 0.78081739 (0.77320028)
# Finished training epoch 111
# Validate: MSE 0.00263926 (0.00263135), PSNR 25.78518677 (25.89489185), SSIM 0.71411610 (0.76752793)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00225397 (0.00228823), PSNR 26.47052002 (26.42779109), SSIM 0.76257002 (0.77290360)
# Finished training epoch 112
# Validate: MSE 0.00265625 (0.00246606), PSNR 25.75730515 (26.14506960), SSIM 0.70646799 (0.76777961)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00198682 (0.00228133), PSNR 27.01840782 (26.43959489), SSIM 0.78780240 (0.77339758)
# Finished training epoch 113
# Validate: MSE 0.00276070 (0.00242881), PSNR 25.58980560 (26.21630643), SSIM 0.71000099 (0.77096786)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00203993 (0.00228738), PSNR 26.90384102 (26.42670387), SSIM 0.76820856 (0.77293004)
# Finished training epoch 114
# Validate: MSE 0.00269683 (0.00242554), PSNR 25.69145584 (26.22916473), SSIM 0.70919853 (0.76949732)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00221357 (0.00228541), PSNR 26.54906273 (26.43197879), SSIM 0.76763999 (0.77325976)
# Finished training epoch 115
# Validate: MSE 0.00260579 (0.00237640), PSNR 25.84061050 (26.31021155), SSIM 0.70708168 (0.76675897)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00244699 (0.00229162), PSNR 26.11368370 (26.42010660), SSIM 0.75803792 (0.77287079)
# Finished training epoch 116
# Validate: MSE 0.00319765 (0.00269764), PSNR 24.95168686 (25.77320375), SSIM 0.69871688 (0.76227873)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00242546 (0.00228115), PSNR 26.15206528 (26.44124559), SSIM 0.77813941 (0.77328408)
# Finished training epoch 117
# Validate: MSE 0.00271319 (0.00236146), PSNR 25.66520119 (26.32945666), SSIM 0.70978904 (0.76738237)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00204922 (0.00228430), PSNR 26.88412094 (26.43387469), SSIM 0.77945650 (0.77275672)
# Finished training epoch 118
# Validate: MSE 0.00263028 (0.00234193), PSNR 25.79997253 (26.36908362), SSIM 0.71236879 (0.77194394)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00244605 (0.00228394), PSNR 26.11534882 (26.43897433), SSIM 0.75290561 (0.77265183)
# Finished training epoch 119
# Validate: MSE 0.00266932 (0.00236179), PSNR 25.73600006 (26.32338182), SSIM 0.70691425 (0.76939782)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00236937 (0.00228654), PSNR 26.25366592 (26.43042430), SSIM 0.78052193 (0.77278025)
# Finished training epoch 120
# Validate: MSE 0.00249605 (0.00231789), PSNR 26.02747154 (26.40752513), SSIM 0.71433043 (0.77323532)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00234691 (0.00228095), PSNR 26.29503250 (26.43944849), SSIM 0.76363456 (0.77295236)
# Finished training epoch 121
# Validate: MSE 0.00255629 (0.00236146), PSNR 25.92389679 (26.32890602), SSIM 0.71416253 (0.77377855)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00232520 (0.00230204), PSNR 26.33538818 (26.40212405), SSIM 0.77078724 (0.77186471)
# Finished training epoch 122
# Validate: MSE 0.00254950 (0.00252685), PSNR 25.93544960 (26.05546210), SSIM 0.71476799 (0.77071362)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00221714 (0.00227472), PSNR 26.54207420 (26.45380562), SSIM 0.76838315 (0.77324548)
# Finished training epoch 123
# Validate: MSE 0.00246576 (0.00249864), PSNR 26.08049202 (26.09613704), SSIM 0.71681702 (0.77469150)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00229966 (0.00227085), PSNR 26.38336372 (26.46329191), SSIM 0.76537609 (0.77320095)
# Finished training epoch 124
# Validate: MSE 0.00268196 (0.00236505), PSNR 25.71547127 (26.32450201), SSIM 0.71662515 (0.76666535)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00306091 (0.00227076), PSNR 25.14149475 (26.46035914), SSIM 0.76753837 (0.77341101)
# Finished training epoch 125
# Validate: MSE 0.00262603 (0.00243533), PSNR 25.80700493 (26.20052519), SSIM 0.70979667 (0.76518472)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00212743 (0.00228956), PSNR 26.72144127 (26.42779705), SSIM 0.77865684 (0.77181321)
# Finished training epoch 126
# Validate: MSE 0.00249481 (0.00256824), PSNR 26.02962112 (25.98522288), SSIM 0.71180379 (0.77137756)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00190604 (0.00228131), PSNR 27.19867706 (26.44199324), SSIM 0.79443026 (0.77269750)
# Finished training epoch 127
# Validate: MSE 0.00273935 (0.00238912), PSNR 25.62351799 (26.28611369), SSIM 0.70768785 (0.76704111)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00247201 (0.00228449), PSNR 26.06950569 (26.43491220), SSIM 0.77026749 (0.77301663)
# Finished training epoch 128
# Validate: MSE 0.00272629 (0.00254985), PSNR 25.64427376 (26.00639102), SSIM 0.71357745 (0.76592134)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00225783 (0.00226675), PSNR 26.46308899 (26.47066518), SSIM 0.76521617 (0.77331405)
# Finished training epoch 129
# Validate: MSE 0.00273041 (0.00239092), PSNR 25.63771439 (26.28341744), SSIM 0.71116358 (0.77190330)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00183569 (0.00227259), PSNR 27.36200333 (26.45867663), SSIM 0.78263104 (0.77298757)
# Finished training epoch 130
# Validate: MSE 0.00259608 (0.00228766), PSNR 25.85682297 (26.46456035), SSIM 0.71547490 (0.77169670)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00213751 (0.00227256), PSNR 26.70091057 (26.45722573), SSIM 0.77699649 (0.77304531)
# Finished training epoch 131
# Validate: MSE 0.00268329 (0.00242876), PSNR 25.71331596 (26.21590881), SSIM 0.71229267 (0.77003959)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00315544 (0.00227572), PSNR 25.00940704 (26.45517661), SSIM 0.73487478 (0.77250011)
# Finished training epoch 132
# Validate: MSE 0.00276524 (0.00232408), PSNR 25.58267593 (26.40059693), SSIM 0.70592988 (0.76668060)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00210512 (0.00227346), PSNR 26.76723480 (26.45624802), SSIM 0.78432941 (0.77254835)
# Finished training epoch 133
# Validate: MSE 0.00273858 (0.00263148), PSNR 25.62474823 (25.90886674), SSIM 0.71088696 (0.76644960)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00169514 (0.00226833), PSNR 27.70794296 (26.46439755), SSIM 0.78372097 (0.77348894)
# Finished training epoch 134
# Validate: MSE 0.00285656 (0.00237432), PSNR 25.44156647 (26.31469828), SSIM 0.71254694 (0.77373704)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00220168 (0.00228732), PSNR 26.57244873 (26.42851387), SSIM 0.76942658 (0.77161448)
# Finished training epoch 135
# Validate: MSE 0.00282664 (0.00257091), PSNR 25.48728943 (25.96457720), SSIM 0.70632678 (0.76339943)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00202894 (0.00227728), PSNR 26.92731285 (26.44792925), SSIM 0.78165537 (0.77283121)
# Finished training epoch 136
# Validate: MSE 0.00272486 (0.00232814), PSNR 25.64655495 (26.39380544), SSIM 0.71111858 (0.77086746)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00281646 (0.00226191), PSNR 25.50295830 (26.48030663), SSIM 0.76202887 (0.77309382)
# Finished training epoch 137
# Validate: MSE 0.00272782 (0.00345770), PSNR 25.64184761 (24.77662610), SSIM 0.71367508 (0.75267203)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00210170 (0.00226224), PSNR 26.77428246 (26.47682397), SSIM 0.77421963 (0.77289113)
# Finished training epoch 138
# Validate: MSE 0.00271632 (0.00255594), PSNR 25.66018486 (25.99818598), SSIM 0.71211743 (0.77258057)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00171481 (0.00225666), PSNR 27.65784073 (26.48841807), SSIM 0.78021944 (0.77324113)
# Finished training epoch 139
# Validate: MSE 0.00277192 (0.00271410), PSNR 25.57218742 (25.73500993), SSIM 0.70368159 (0.75872687)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00276539 (0.00226094), PSNR 25.58244324 (26.47968049), SSIM 0.75669348 (0.77286881)
# Finished training epoch 140
# Validate: MSE 0.00277152 (0.00241671), PSNR 25.57281685 (26.22550337), SSIM 0.70690644 (0.76390994)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00244064 (0.00229804), PSNR 26.12495422 (26.41091326), SSIM 0.75643623 (0.77168738)
# Finished training epoch 141
# Validate: MSE 0.00301466 (0.00252958), PSNR 25.20761681 (26.03826209), SSIM 0.70457739 (0.76500737)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00197158 (0.00227054), PSNR 27.05184555 (26.45988185), SSIM 0.79923326 (0.77286727)
# Finished training epoch 142
# Validate: MSE 0.00274334 (0.00238315), PSNR 25.61719704 (26.29926940), SSIM 0.71759295 (0.77566966)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00246442 (0.00226114), PSNR 26.08284378 (26.47906630), SSIM 0.78336042 (0.77326727)
# Finished training epoch 143
# Validate: MSE 0.00288950 (0.00241542), PSNR 25.39177895 (26.22511989), SSIM 0.71240652 (0.76745450)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00290625 (0.00226194), PSNR 25.36667061 (26.47803587), SSIM 0.74856913 (0.77316569)
# Finished training epoch 144
# Validate: MSE 0.00277325 (0.00242083), PSNR 25.57010269 (26.23014520), SSIM 0.70810986 (0.76815640)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00203901 (0.00226997), PSNR 26.90581512 (26.46371120), SSIM 0.78527975 (0.77288526)
# Finished training epoch 145
# Validate: MSE 0.00326498 (0.00258128), PSNR 24.86119461 (25.96306480), SSIM 0.71061563 (0.77397476)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00219052 (0.00226200), PSNR 26.59453201 (26.48115142), SSIM 0.78579628 (0.77282403)
# Finished training epoch 146
# Validate: MSE 0.00266273 (0.00236502), PSNR 25.74672318 (26.32767632), SSIM 0.71260333 (0.76846055)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00229346 (0.00226836), PSNR 26.39508057 (26.46367244), SSIM 0.78318799 (0.77305946)
# Finished training epoch 147
# Validate: MSE 0.00255282 (0.00237648), PSNR 25.92980194 (26.30094188), SSIM 0.71276605 (0.76753333)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00300916 (0.00226386), PSNR 25.21554375 (26.47403611), SSIM 0.73689175 (0.77291550)
# Finished training epoch 148
# Validate: MSE 0.00272920 (0.00235412), PSNR 25.63964272 (26.34768478), SSIM 0.71381807 (0.76995910)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00211088 (0.00226166), PSNR 26.75536156 (26.48073864), SSIM 0.78452957 (0.77292594)
# Finished training epoch 149
# ...
# Finished validation.
# Starting training epoch 179
# Epoch: 179, MSE 0.00201995 (0.00225381), PSNR 26.94659042 (26.49302177), SSIM 0.76349014 (0.77257117)
# Finished training epoch 179
# Validate: MSE 0.00274158 (0.00245638), PSNR 25.61998367 (26.16554671), SSIM 0.71504450 (0.76912618)
# Finished validation.
# Starting training epoch 180
# Epoch: 180, MSE 0.00233667 (0.00224536), PSNR 26.31403351 (26.50848355), SSIM 0.75993997 (0.77276431)
# Finished training epoch 180
# Validate: MSE 0.00260886 (0.00230783), PSNR 25.83548737 (26.43245599), SSIM 0.70693612 (0.76947067)
# Finished validation.
# Starting training epoch 181
# Epoch: 181, MSE 0.00229247 (0.00224783), PSNR 26.39696312 (26.50575062), SSIM 0.75369042 (0.77248392)
# Finished training epoch 181
# Validate: MSE 0.00255427 (0.00284938), PSNR 25.92732620 (25.58589998), SSIM 0.71107233 (0.76016283)
# Finished validation.
# Starting training epoch 182
# Epoch: 182, MSE 0.00196964 (0.00224105), PSNR 27.05613327 (26.51805820), SSIM 0.77274001 (0.77231549)
# Finished training epoch 182
# Validate: MSE 0.00256498 (0.00225061), PSNR 25.90915108 (26.53409229), SSIM 0.70310652 (0.76827568)
# Finished validation.
# Starting training epoch 183
# Epoch: 183, MSE 0.00234471 (0.00226702), PSNR 26.29909897 (26.46950059), SSIM 0.77898312 (0.77146368)
# Finished training epoch 183
# Validate: MSE 0.00269719 (0.00235114), PSNR 25.69087982 (26.35913807), SSIM 0.71169174 (0.77546220)
# Finished validation.
# Starting training epoch 184
# Epoch: 184, MSE 0.00243235 (0.00224736), PSNR 26.13973999 (26.50461788), SSIM 0.75562942 (0.77290600)
# Finished training epoch 184
# Validate: MSE 0.00273065 (0.00241732), PSNR 25.63734245 (26.24107724), SSIM 0.70912206 (0.76741663)
# Finished validation.
# Starting training epoch 185
# Epoch: 185, MSE 0.00201445 (0.00224173), PSNR 26.95843887 (26.51662259), SSIM 0.78175950 (0.77263739)
# Finished training epoch 185
# Validate: MSE 0.00259001 (0.00224787), PSNR 25.86697769 (26.54227305), SSIM 0.71624887 (0.77235198)
# Finished validation.
# Starting training epoch 186
# Epoch: 186, MSE 0.00243828 (0.00223522), PSNR 26.12916565 (26.53031153), SSIM 0.78521180 (0.77310000)
# Finished training epoch 186
# Validate: MSE 0.00272412 (0.00286333), PSNR 25.64773560 (25.57574880), SSIM 0.71290284 (0.76230639)
# Finished validation.
# Starting training epoch 187
# Epoch: 187, MSE 0.00204201 (0.00225126), PSNR 26.89941406 (26.50035801), SSIM 0.78887761 (0.77195281)
# Finished training epoch 187
# Validate: MSE 0.00280126 (0.00231061), PSNR 25.52645874 (26.43046003), SSIM 0.71723223 (0.77511553)
# Finished validation.
# Starting training epoch 188
# Epoch: 188, MSE 0.00246643 (0.00224239), PSNR 26.07931900 (26.51623511), SSIM 0.77176678 (0.77252764)
# Finished training epoch 188
# Validate: MSE 0.00263745 (0.00249975), PSNR 25.78816032 (26.07026848), SSIM 0.69957721 (0.75326843)
# Finished validation.
# Starting training epoch 189
# Epoch: 189, MSE 0.00227174 (0.00225248), PSNR 26.43641472 (26.49398932), SSIM 0.76299202 (0.77198486)
# Finished training epoch 189
# Validate: MSE 0.00274842 (0.00241191), PSNR 25.60916901 (26.24144894), SSIM 0.71416330 (0.76960252)
# Finished validation.
# Starting training epoch 190
# Epoch: 190, MSE 0.00165684 (0.00223800), PSNR 27.80718231 (26.52918338), SSIM 0.79032528 (0.77277008)
# Finished training epoch 190
# Validate: MSE 0.00281543 (0.00234308), PSNR 25.50454521 (26.36440344), SSIM 0.70740211 (0.76784636)
# Finished validation.
# Starting training epoch 191
# Epoch: 191, MSE 0.00240871 (0.00223832), PSNR 26.18214417 (26.52393309), SSIM 0.76111209 (0.77275803)
# Finished training epoch 191
# Validate: MSE 0.00266307 (0.00227190), PSNR 25.74617386 (26.49549029), SSIM 0.71146810 (0.77067641)
# Finished validation.
# Starting training epoch 192
# Epoch: 192, MSE 0.00211682 (0.00227563), PSNR 26.74315834 (26.45190016), SSIM 0.79146200 (0.77095285)
# Finished training epoch 192
# Validate: MSE 0.00272696 (0.00260907), PSNR 25.64320374 (25.90529158), SSIM 0.70548600 (0.76078963)
# Finished validation.
# Starting training epoch 193
# Epoch: 193, MSE 0.00167438 (0.00223924), PSNR 27.76145935 (26.52400200), SSIM 0.78237903 (0.77272304)
# Finished training epoch 193
# Validate: MSE 0.00278237 (0.00231891), PSNR 25.55584717 (26.41420332), SSIM 0.71279919 (0.77235245)
# Finished validation.
# Starting training epoch 194
# Epoch: 194, MSE 0.00209553 (0.00223304), PSNR 26.78706932 (26.53500180), SSIM 0.79441679 (0.77308557)
# Finished training epoch 194
# Validate: MSE 0.00260882 (0.00241707), PSNR 25.83555412 (26.22600674), SSIM 0.70888770 (0.76420385)
# Finished validation.
# Starting training epoch 195
# Epoch: 195, MSE 0.00190337 (0.00224885), PSNR 27.20476151 (26.50429822), SSIM 0.79989177 (0.77241086)
# Finished training epoch 195
# Validate: MSE 0.00261625 (0.00252726), PSNR 25.82320213 (26.06761375), SSIM 0.71306658 (0.77077995)
# Finished validation.
# Starting training epoch 196
# Epoch: 196, MSE 0.00236188 (0.00224102), PSNR 26.26742935 (26.51903835), SSIM 0.76097572 (0.77271755)
# Finished training epoch 196
# Validate: MSE 0.00272393 (0.00235086), PSNR 25.64803505 (26.35129784), SSIM 0.71163166 (0.76640036)
# Finished validation.
# Starting training epoch 197
# Epoch: 197, MSE 0.00226903 (0.00224050), PSNR 26.44159889 (26.51965328), SSIM 0.77298963 (0.77264888)
# Finished training epoch 197
# Validate: MSE 0.00263362 (0.00231959), PSNR 25.79446983 (26.40024425), SSIM 0.70582092 (0.76795910)
# Finished validation.
# Starting training epoch 198
# Epoch: 198, MSE 0.00234131 (0.00224400), PSNR 26.30540657 (26.50936932), SSIM 0.76933444 (0.77220952)
# Finished training epoch 198
# Validate: MSE 0.00301670 (0.00234996), PSNR 25.20467186 (26.36213482), SSIM 0.70516479 (0.77546473)
# Finished validation.
# Starting training epoch 199
# Epoch: 199, MSE 0.00280715 (0.00223430), PSNR 25.51734352 (26.53298707), SSIM 0.76641804 (0.77249225)
# Finished training epoch 199
# Validate: MSE 0.00265836 (0.00228082), PSNR 25.75386429 (26.47522025), SSIM 0.70782793 (0.77122117)
# Finished validation.
# Starting training epoch 200
# Epoch: 200, MSE 0.00197708 (0.00223523), PSNR 27.03975105 (26.53230258), SSIM 0.77558458 (0.77252073)
# Finished training epoch 200
# Validate: MSE 0.00272746 (0.00243944), PSNR 25.64240646 (26.20845124), SSIM 0.71104586 (0.77110337)
# Finished validation.
# Starting training epoch 201
# Epoch: 201, MSE 0.00211917 (0.00224594), PSNR 26.73833275 (26.50687848), SSIM 0.75405109 (0.77210180)
# Finished training epoch 201
# Validate: MSE 0.00268459 (0.00228197), PSNR 25.71122360 (26.48101677), SSIM 0.71273148 (0.77239576)
# Finished validation.
# Starting training epoch 202
# Epoch: 202, MSE 0.00203951 (0.00223938), PSNR 26.90473938 (26.51763659), SSIM 0.77487433 (0.77246907)
# Finished training epoch 202
# Validate: MSE 0.00270147 (0.00228797), PSNR 25.68400192 (26.46807487), SSIM 0.70958972 (0.77568926)
# Finished validation.
# Starting training epoch 203
# Epoch: 203, MSE 0.00187175 (0.00223117), PSNR 27.27752495 (26.53829927), SSIM 0.78970611 (0.77288109)
# Finished training epoch 203
# Validate: MSE 0.00248593 (0.00233777), PSNR 26.04510880 (26.37915389), SSIM 0.71597481 (0.77273366)
# Finished validation.
# Starting training epoch 204
# Epoch: 204, MSE 0.00212860 (0.00225156), PSNR 26.71905327 (26.49778362), SSIM 0.76743633 (0.77190786)
# Finished training epoch 204
# Validate: MSE 0.00262744 (0.00225739), PSNR 25.80466461 (26.52573300), SSIM 0.71591157 (0.77266013)
# Finished validation.
# Starting training epoch 205
# Epoch: 205, MSE 0.00237126 (0.00223250), PSNR 26.25020981 (26.53707821), SSIM 0.76625615 (0.77271611)
# Finished training epoch 205
# Validate: MSE 0.00280469 (0.00244754), PSNR 25.52115631 (26.18118724), SSIM 0.71176279 (0.76509443)
# Finished validation.
# Starting training epoch 206
# Epoch: 206, MSE 0.00208856 (0.00224579), PSNR 26.80153656 (26.51143125), SSIM 0.77012396 (0.77227599)
# Finished training epoch 206
# Validate: MSE 0.00289168 (0.00231889), PSNR 25.38849640 (26.41685021), SSIM 0.70749938 (0.77178324)
# Finished validation.
# Starting training epoch 207
# Epoch: 207, MSE 0.00230309 (0.00226384), PSNR 26.37688255 (26.47654400), SSIM 0.77347529 (0.77048378)
# Finished training epoch 207
# Validate: MSE 0.00279350 (0.00238310), PSNR 25.53850746 (26.29047204), SSIM 0.71342409 (0.77079250)
# Finished validation.
# Starting training epoch 208
# Epoch: 208, MSE 0.00207417 (0.00223661), PSNR 26.83156013 (26.52653247), SSIM 0.76347268 (0.77293077)
# Finished training epoch 208
# Validate: MSE 0.00270871 (0.00242435), PSNR 25.67237854 (26.21025774), SSIM 0.70880359 (0.76699569)
# Finished validation.
# Starting training epoch 209
# Epoch: 209, MSE 0.00275894 (0.00223835), PSNR 25.59258270 (26.52204823), SSIM 0.74111569 (0.77281176)
# Finished training epoch 209
# Validate: MSE 0.00266428 (0.00265132), PSNR 25.74420547 (25.84391348), SSIM 0.70427716 (0.75826118)
# Finished validation.
# Starting training epoch 210
# Epoch: 210, MSE 0.00223278 (0.00222337), PSNR 26.51154900 (26.55438633), SSIM 0.78260392 (0.77321479)
# Finished training epoch 210
# Validate: MSE 0.00286977 (0.00233644), PSNR 25.42153358 (26.38470187), SSIM 0.70658302 (0.77232805)
# Finished validation.
# Starting training epoch 211
# Epoch: 211, MSE 0.00220902 (0.00222765), PSNR 26.55799675 (26.54376325), SSIM 0.77044737 (0.77296847)
# Finished training epoch 211
# Validate: MSE 0.00289496 (0.00244315), PSNR 25.38358116 (26.19065064), SSIM 0.70920622 (0.77117290)
# Finished validation.
# Starting training epoch 212
# Epoch: 212, MSE 0.00230071 (0.00223105), PSNR 26.38137436 (26.53409207), SSIM 0.76240915 (0.77257480)
# Finished training epoch 212
# Validate: MSE 0.00255434 (0.00277104), PSNR 25.92720604 (25.68976519), SSIM 0.71308911 (0.75919753)
# Finished validation.
# Starting training epoch 213
# Epoch: 213, MSE 0.00229890 (0.00225793), PSNR 26.38479996 (26.48611157), SSIM 0.77165174 (0.77093709)
# Finished training epoch 213
# Validate: MSE 0.00271709 (0.00241677), PSNR 25.65895271 (26.22425640), SSIM 0.71143514 (0.75854847)
# Finished validation.
# Starting training epoch 214
# Epoch: 214, MSE 0.00230246 (0.00222668), PSNR 26.37806892 (26.54519090), SSIM 0.76939142 (0.77287133)
# Finished training epoch 214
# Validate: MSE 0.00260191 (0.00227523), PSNR 25.84708023 (26.48590333), SSIM 0.70869523 (0.76924052)
# Finished validation.
# Starting training epoch 215
# Epoch: 215, MSE 0.00232410 (0.00224042), PSNR 26.33745193 (26.51869412), SSIM 0.75916433 (0.77237570)
# Finished training epoch 215
# Validate: MSE 0.00242564 (0.00255960), PSNR 26.15173340 (25.97639158), SSIM 0.71121085 (0.75941135)
# Finished validation.
# Starting training epoch 216
# Epoch: 216, MSE 0.00180474 (0.00221753), PSNR 27.43585777 (26.56099649), SSIM 0.78311485 (0.77319891)
# Finished training epoch 216
# Validate: MSE 0.00267007 (0.00310340), PSNR 25.73477364 (25.17794129), SSIM 0.71160352 (0.74889711)
# Finished validation.
# Starting training epoch 217
# Epoch: 217, MSE 0.00207592 (0.00223000), PSNR 26.82788658 (26.53851657), SSIM 0.78114045 (0.77249992)
# Finished training epoch 217
# Validate: MSE 0.00269599 (0.00255473), PSNR 25.69281769 (26.01266505), SSIM 0.71422285 (0.77071819)
# Finished validation.
# Starting training epoch 218
# Epoch: 218, MSE 0.00228864 (0.00225136), PSNR 26.40421677 (26.49869657), SSIM 0.76074344 (0.77188824)
# Finished training epoch 218
# Validate: MSE 0.00275222 (0.00229225), PSNR 25.60316658 (26.46227076), SSIM 0.71000719 (0.77269068)
# Finished validation.
# Starting training epoch 219
# Epoch: 219, MSE 0.00177084 (0.00223724), PSNR 27.51820183 (26.52278425), SSIM 0.79855841 (0.77227858)
# Finished training epoch 219
# Validate: MSE 0.00268945 (0.00225620), PSNR 25.70336151 (26.52258314), SSIM 0.71451342 (0.77451330)
# Finished validation.
# Starting training epoch 220
# Epoch: 220, MSE 0.00179367 (0.00223387), PSNR 27.46256828 (26.53068815), SSIM 0.77320325 (0.77259651)
# Finished training epoch 220
# Validate: MSE 0.00310258 (0.00268066), PSNR 25.08276939 (25.79052833), SSIM 0.70907271 (0.76562541)
# Finished validation.
# Starting training epoch 221
# Epoch: 221, MSE 0.00259240 (0.00222718), PSNR 25.86297226 (26.54471552), SSIM 0.75821054 (0.77262895)
# Finished training epoch 221
# Validate: MSE 0.00259271 (0.00230671), PSNR 25.86245346 (26.42641298), SSIM 0.70894837 (0.77258932)
# Finished validation.
# Starting training epoch 222
# Epoch: 222, MSE 0.00280487 (0.00223077), PSNR 25.52087975 (26.53801860), SSIM 0.74788147 (0.77244395)
# Finished training epoch 222
# Validate: MSE 0.00295554 (0.00348106), PSNR 25.29363251 (24.73159203), SSIM 0.68579853 (0.73404438)
# Finished validation.
# Starting training epoch 223
# Epoch: 223, MSE 0.00213235 (0.00222731), PSNR 26.71142387 (26.54450234), SSIM 0.76954758 (0.77227419)
# Finished training epoch 223
# Validate: MSE 0.00302602 (0.00246413), PSNR 25.19127846 (26.15069860), SSIM 0.70956188 (0.77179567)
# Finished validation.
# Starting training epoch 224
# Epoch: 224, MSE 0.00183511 (0.00224156), PSNR 27.36338425 (26.52171665), SSIM 0.76674968 (0.77158538)
# Finished training epoch 224
# Validate: MSE 0.00268936 (0.00230093), PSNR 25.70351028 (26.44415789), SSIM 0.71027398 (0.76717283)
# Finished validation.
# Starting training epoch 225
# Epoch: 225, MSE 0.00289419 (0.00222223), PSNR 25.38472939 (26.55421312), SSIM 0.75989759 (0.77299833)
# Finished training epoch 225
# Validate: MSE 0.00265287 (0.00237601), PSNR 25.76284409 (26.31238932), SSIM 0.71166277 (0.76758013)
# Finished validation.
# Starting training epoch 226
# Epoch: 226, MSE 0.00207816 (0.00222644), PSNR 26.82321167 (26.54549463), SSIM 0.75961637 (0.77289862)
# Finished training epoch 226
# Validate: MSE 0.00246890 (0.00234920), PSNR 26.07495689 (26.34362337), SSIM 0.71365470 (0.76470726)
# Finished validation.
# Starting training epoch 227
# Epoch: 227, MSE 0.00208059 (0.00223400), PSNR 26.81813049 (26.53238244), SSIM 0.78462487 (0.77234839)
# Finished training epoch 227
# Validate: MSE 0.00258770 (0.00244497), PSNR 25.87085724 (26.17233500), SSIM 0.70304048 (0.75580097)
# Finished validation.
# Starting training epoch 228
# Epoch: 228, MSE 0.00210996 (0.00223440), PSNR 26.75724792 (26.53088030), SSIM 0.76902902 (0.77181099)
# Finished training epoch 228
# Validate: MSE 0.00259246 (0.00266566), PSNR 25.86287498 (25.83064542), SSIM 0.71013558 (0.76038376)
# Finished validation.
# Starting training epoch 229
# Epoch: 229, MSE 0.00217186 (0.00223191), PSNR 26.63168144 (26.53672611), SSIM 0.78426933 (0.77209084)
# Finished training epoch 229
# Validate: MSE 0.00263505 (0.00231972), PSNR 25.79210281 (26.41296705), SSIM 0.70957494 (0.77074154)
# Finished validation.
# Starting training epoch 230
# Epoch: 230, MSE 0.00203067 (0.00221770), PSNR 26.92360687 (26.56368808), SSIM 0.78234053 (0.77273489)
# Finished training epoch 230
# Validate: MSE 0.00270799 (0.00231249), PSNR 25.67352486 (26.42521682), SSIM 0.71175134 (0.77519359)
# Finished validation.
# Starting training epoch 231
# Epoch: 231, MSE 0.00226983 (0.00221639), PSNR 26.44006157 (26.56407949), SSIM 0.77590311 (0.77318054)
# Finished training epoch 231
# Validate: MSE 0.00264566 (0.00236910), PSNR 25.77466393 (26.30884566), SSIM 0.71533036 (0.77169061)
# Finished validation.
# Starting training epoch 232
# Epoch: 232, MSE 0.00225526 (0.00223152), PSNR 26.46802330 (26.53601265), SSIM 0.77144063 (0.77232925)
# Finished training epoch 232
# Validate: MSE 0.00260160 (0.00229514), PSNR 25.84760094 (26.45452149), SSIM 0.71040964 (0.76879511)
# Finished validation.
# Starting training epoch 233
# Epoch: 233, MSE 0.00191072 (0.00222632), PSNR 27.18803596 (26.54650534), SSIM 0.77654856 (0.77251159)
# Finished training epoch 233
# Validate: MSE 0.00267173 (0.00226945), PSNR 25.73207664 (26.50537726), SSIM 0.71483588 (0.77319241)
# Finished validation.
# Starting training epoch 234
# Epoch: 234, MSE 0.00214567 (0.00221823), PSNR 26.68437386 (26.56100533), SSIM 0.78782034 (0.77296812)
# Finished training epoch 234
# Validate: MSE 0.00292667 (0.00239854), PSNR 25.33626175 (26.27093057), SSIM 0.71341419 (0.77258973)
# Finished validation.
# Starting training epoch 235
# Epoch: 235, MSE 0.00214694 (0.00221499), PSNR 26.68179131 (26.56657458), SSIM 0.78442466 (0.77293358)
# Finished training epoch 235
# Validate: MSE 0.00279471 (0.00239776), PSNR 25.53663063 (26.27485912), SSIM 0.71071243 (0.77261739)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00278930 (0.00239648), PSNR 25.54504013 (26.27838015), SSIM 0.71262717 (0.77283016)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
