# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-a4044e636a5485f2" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a4044e636a5485f2");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
                transforms.RandomVerticalFlip(),  
                transforms.RandomRotation(10),
                transforms.ColorJitter(brightness=0.05, contrast=0.05, saturation=0.05, hue=0.05)
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .25

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        self.batchnorm5 = nn.BatchNorm2d(2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = y = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x + y)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm5(self.convtrans3(x + input)), negative_slope=0.1)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9, weight_decay=1e-5)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 32, 32]           2,306
#       BatchNorm2d-10            [-1, 2, 32, 32]               4
# ================================================================
# Total params: 2,662,278
# Trainable params: 2,662,278
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.78
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.94
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00254552 (0.04366420), PSNR 25.94223404 (18.91462367), SSIM 0.78552955 (0.46850461)
# Finished training epoch 0
# Validate: MSE 0.00319207 (0.00275314), PSNR 24.95927620 (25.67761057), SSIM 0.70460057 (0.77466265)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00291384 (0.00274353), PSNR 25.35534668 (25.63784571), SSIM 0.76775277 (0.76886805)
# Finished training epoch 1
# Validate: MSE 0.00321687 (0.00275669), PSNR 24.92565918 (25.67070935), SSIM 0.70384294 (0.77446084)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00273689 (0.00275175), PSNR 25.62742424 (25.62521241), SSIM 0.75058353 (0.76887820)
# Finished training epoch 2
# Validate: MSE 0.00317916 (0.00275237), PSNR 24.97687340 (25.67922664), SSIM 0.70412993 (0.77444272)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00240915 (0.00275450), PSNR 26.18136215 (25.62277028), SSIM 0.78932685 (0.76849084)
# Finished training epoch 3
# Validate: MSE 0.00322224 (0.00275471), PSNR 24.91842079 (25.67353017), SSIM 0.70426607 (0.77473396)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00265484 (0.00275996), PSNR 25.75960541 (25.61305365), SSIM 0.77067995 (0.76860902)
# Finished training epoch 4
# Validate: MSE 0.00317885 (0.00275101), PSNR 24.97729492 (25.68157742), SSIM 0.70422012 (0.77444906)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00251809 (0.00274989), PSNR 25.98928261 (25.63016860), SSIM 0.76339281 (0.76883779)
# Finished training epoch 5
# Validate: MSE 0.00320762 (0.00275352), PSNR 24.93816757 (25.67604008), SSIM 0.70465136 (0.77505532)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00229158 (0.00275221), PSNR 26.39864731 (25.62489035), SSIM 0.79364932 (0.76870514)
# Finished training epoch 6
# Validate: MSE 0.00319146 (0.00275160), PSNR 24.96010017 (25.67965481), SSIM 0.70425165 (0.77470638)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00301863 (0.00274844), PSNR 25.20189476 (25.63287108), SSIM 0.74699533 (0.76883583)
# Finished training epoch 7
# Validate: MSE 0.00319897 (0.00275054), PSNR 24.94989204 (25.68097417), SSIM 0.70436287 (0.77486703)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00222269 (0.00275313), PSNR 26.53120232 (25.62586604), SSIM 0.80737746 (0.76876167)
# Finished training epoch 8
# Validate: MSE 0.00319477 (0.00275101), PSNR 24.95560837 (25.68031235), SSIM 0.70461792 (0.77490139)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00313956 (0.00274806), PSNR 25.03131485 (25.63345652), SSIM 0.78959739 (0.76871101)
# Finished training epoch 9
# Validate: MSE 0.00318729 (0.00274977), PSNR 24.96578789 (25.68275031), SSIM 0.70420671 (0.77483119)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00224709 (0.00274824), PSNR 26.48379707 (25.63209704), SSIM 0.78223956 (0.76862218)
# Finished training epoch 10
# Validate: MSE 0.00321255 (0.00275176), PSNR 24.93150330 (25.67840842), SSIM 0.70429641 (0.77463630)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00268628 (0.00274773), PSNR 25.70848846 (25.63554505), SSIM 0.77206427 (0.76874999)
# Finished training epoch 11
# Validate: MSE 0.00318081 (0.00274810), PSNR 24.97462654 (25.68545520), SSIM 0.70433605 (0.77458251)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00271247 (0.00275425), PSNR 25.66635513 (25.62053931), SSIM 0.77741367 (0.76851942)
# Finished training epoch 12
# Validate: MSE 0.00318483 (0.00274869), PSNR 24.96913910 (25.68431595), SSIM 0.70401442 (0.77473898)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00286339 (0.00275453), PSNR 25.43119240 (25.62493542), SSIM 0.77268529 (0.76850552)
# Finished training epoch 13
# Validate: MSE 0.00318183 (0.00274826), PSNR 24.97323418 (25.68539275), SSIM 0.70446444 (0.77511140)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00210219 (0.00274188), PSNR 26.77327728 (25.64321540), SSIM 0.78113747 (0.76872313)
# Finished training epoch 14
# Validate: MSE 0.00319218 (0.00274758), PSNR 24.95912361 (25.68588284), SSIM 0.70378792 (0.77472180)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00286466 (0.00275189), PSNR 25.42926788 (25.62414320), SSIM 0.77125651 (0.76862402)
# Finished training epoch 15
# Validate: MSE 0.00318284 (0.00274654), PSNR 24.97184372 (25.68778710), SSIM 0.70426136 (0.77487737)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00327504 (0.00274265), PSNR 24.84782982 (25.63838762), SSIM 0.74454165 (0.76883034)
# Finished training epoch 16
# Validate: MSE 0.00319771 (0.00274732), PSNR 24.95160866 (25.68568041), SSIM 0.70468712 (0.77482244)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00257320 (0.00275195), PSNR 25.89526939 (25.62829832), SSIM 0.74907047 (0.76841278)
# Finished training epoch 17
# Validate: MSE 0.00317286 (0.00274459), PSNR 24.98549461 (25.69129796), SSIM 0.70490086 (0.77489266)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00256264 (0.00275063), PSNR 25.91311646 (25.62755336), SSIM 0.76438576 (0.76865753)
# Finished training epoch 18
# Validate: MSE 0.00317266 (0.00274513), PSNR 24.98576927 (25.69012608), SSIM 0.70457006 (0.77484344)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00302145 (0.00274244), PSNR 25.19784546 (25.64073636), SSIM 0.76997650 (0.76869954)
# Finished training epoch 19
# Validate: MSE 0.00317991 (0.00274381), PSNR 24.97585678 (25.69203327), SSIM 0.70416284 (0.77474676)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00301748 (0.00274460), PSNR 25.20355034 (25.63789425), SSIM 0.74435294 (0.76881587)
# Finished training epoch 20
# Validate: MSE 0.00317784 (0.00274245), PSNR 24.97868347 (25.69435889), SSIM 0.70416546 (0.77473774)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00328702 (0.00273389), PSNR 24.83197975 (25.65763728), SSIM 0.75648147 (0.76880608)
# Finished training epoch 21
# Validate: MSE 0.00315170 (0.00274125), PSNR 25.01455307 (25.69745712), SSIM 0.70409513 (0.77463168)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00268196 (0.00274003), PSNR 25.71546745 (25.64270488), SSIM 0.80007190 (0.76877060)
# Finished training epoch 22
# Validate: MSE 0.00317990 (0.00274143), PSNR 24.97586441 (25.69590399), SSIM 0.70386040 (0.77507368)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00256819 (0.00274468), PSNR 25.90372276 (25.63667029), SSIM 0.76860511 (0.76851422)
# Finished training epoch 23
# Validate: MSE 0.00318113 (0.00274110), PSNR 24.97418594 (25.69607029), SSIM 0.70371473 (0.77471245)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00294472 (0.00274306), PSNR 25.30955887 (25.64416691), SSIM 0.78221691 (0.76868756)
# Finished training epoch 24
# Validate: MSE 0.00313869 (0.00273864), PSNR 25.03251076 (25.70191732), SSIM 0.70162582 (0.77355344)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00340428 (0.00273813), PSNR 24.67974663 (25.64992470), SSIM 0.75055146 (0.76852611)
# Finished training epoch 25
# Validate: MSE 0.00314784 (0.00273673), PSNR 25.01986885 (25.70450201), SSIM 0.70336318 (0.77421053)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00249623 (0.00273633), PSNR 26.02715874 (25.65124511), SSIM 0.77887636 (0.76860492)
# Finished training epoch 26
# Validate: MSE 0.00315865 (0.00273836), PSNR 25.00498962 (25.70128945), SSIM 0.70276380 (0.77441789)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00281691 (0.00273723), PSNR 25.50227356 (25.65126841), SSIM 0.75492889 (0.76856946)
# Finished training epoch 27
# Validate: MSE 0.00314213 (0.00273562), PSNR 25.02775192 (25.70644965), SSIM 0.70293307 (0.77441318)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00243765 (0.00273876), PSNR 26.13028336 (25.64785189), SSIM 0.78047615 (0.76838016)
# Finished training epoch 28
# Validate: MSE 0.00314354 (0.00273428), PSNR 25.02581406 (25.70865134), SSIM 0.70329332 (0.77431260)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00205292 (0.00273832), PSNR 26.87628746 (25.64703122), SSIM 0.79561502 (0.76837977)
# Finished training epoch 29
# Validate: MSE 0.00314373 (0.00273442), PSNR 25.02554703 (25.70824075), SSIM 0.70327789 (0.77445530)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00232596 (0.00273517), PSNR 26.33396912 (25.65342195), SSIM 0.77255279 (0.76821394)
# Finished training epoch 30
# Validate: MSE 0.00316906 (0.00273501), PSNR 24.99069023 (25.70598969), SSIM 0.70357949 (0.77500509)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00250596 (0.00273811), PSNR 26.01025772 (25.64927463), SSIM 0.77789319 (0.76821278)
# Finished training epoch 31
# Validate: MSE 0.00315135 (0.00273325), PSNR 25.01503563 (25.70938372), SSIM 0.70393384 (0.77457994)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00296845 (0.00273159), PSNR 25.27470589 (25.66031618), SSIM 0.78289354 (0.76839941)
# Finished training epoch 32
# Validate: MSE 0.00313891 (0.00273133), PSNR 25.03220367 (25.71308536), SSIM 0.70293272 (0.77430256)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00307220 (0.00272982), PSNR 25.12549973 (25.65985842), SSIM 0.76594192 (0.76842229)
# Finished training epoch 33
# Validate: MSE 0.00311887 (0.00272970), PSNR 25.06002426 (25.71659035), SSIM 0.70246655 (0.77384297)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00248871 (0.00273434), PSNR 26.04026031 (25.65087388), SSIM 0.77389401 (0.76815423)
# Finished training epoch 34
# Validate: MSE 0.00312180 (0.00272834), PSNR 25.05594444 (25.71873541), SSIM 0.70281100 (0.77413354)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00213898 (0.00273127), PSNR 26.69793701 (25.66063091), SSIM 0.79651302 (0.76810240)
# Finished training epoch 35
# Validate: MSE 0.00313898 (0.00272806), PSNR 25.03211212 (25.71794183), SSIM 0.70147687 (0.77404164)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00249580 (0.00273120), PSNR 26.02790451 (25.66158065), SSIM 0.76751029 (0.76801281)
# Finished training epoch 36
# Validate: MSE 0.00312490 (0.00272702), PSNR 25.05163383 (25.72066450), SSIM 0.70361376 (0.77461435)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00302721 (0.00271933), PSNR 25.18957329 (25.67784778), SSIM 0.75379783 (0.76816880)
# Finished training epoch 37
# Validate: MSE 0.00311761 (0.00272620), PSNR 25.06178665 (25.72236793), SSIM 0.70284051 (0.77437372)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00260723 (0.00272528), PSNR 25.83821106 (25.66905173), SSIM 0.78500539 (0.76809816)
# Finished training epoch 38
# Validate: MSE 0.00315085 (0.00272752), PSNR 25.01571846 (25.71778999), SSIM 0.70350587 (0.77443267)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00257621 (0.00272621), PSNR 25.89018059 (25.66769922), SSIM 0.76079941 (0.76785598)
# Finished training epoch 39
# Validate: MSE 0.00313087 (0.00272432), PSNR 25.04335403 (25.72421910), SSIM 0.70208883 (0.77402994)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00267550 (0.00272274), PSNR 25.72594261 (25.67450756), SSIM 0.76427859 (0.76814616)
# Finished training epoch 40
# Validate: MSE 0.00310445 (0.00272246), PSNR 25.08014488 (25.72914820), SSIM 0.70116407 (0.77351548)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00268712 (0.00271985), PSNR 25.70712662 (25.67494001), SSIM 0.75603926 (0.76797385)
# Finished training epoch 41
# Validate: MSE 0.00313140 (0.00272186), PSNR 25.04261971 (25.72811819), SSIM 0.70227605 (0.77435178)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00272417 (0.00272169), PSNR 25.64765930 (25.67727383), SSIM 0.76627165 (0.76769060)
# Finished training epoch 42
# Validate: MSE 0.00313992 (0.00272249), PSNR 25.03081894 (25.72636523), SSIM 0.70266181 (0.77449823)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00328906 (0.00271410), PSNR 24.82927895 (25.68573575), SSIM 0.76594782 (0.76799212)
# Finished training epoch 43
# Validate: MSE 0.00312553 (0.00271900), PSNR 25.05076218 (25.73251345), SSIM 0.70291489 (0.77391057)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00234917 (0.00271678), PSNR 26.29085732 (25.68261720), SSIM 0.79384243 (0.76795317)
# Finished training epoch 44
# Validate: MSE 0.00311513 (0.00271921), PSNR 25.06524277 (25.73336494), SSIM 0.70211434 (0.77423379)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00238277 (0.00271445), PSNR 26.22918701 (25.68461840), SSIM 0.77673721 (0.76795735)
# Finished training epoch 45
# Validate: MSE 0.00310992 (0.00271640), PSNR 25.07250977 (25.73769932), SSIM 0.70130509 (0.77379545)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00306189 (0.00271774), PSNR 25.14010620 (25.68262588), SSIM 0.74787295 (0.76788695)
# Finished training epoch 46
# Validate: MSE 0.00313644 (0.00271704), PSNR 25.03563309 (25.73485147), SSIM 0.70133805 (0.77339364)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00247331 (0.00271673), PSNR 26.06721687 (25.68238434), SSIM 0.76323181 (0.76783395)
# Finished training epoch 47
# Validate: MSE 0.00313027 (0.00271520), PSNR 25.04418373 (25.73821427), SSIM 0.70327067 (0.77453043)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00217571 (0.00271542), PSNR 26.62398148 (25.68374240), SSIM 0.78143543 (0.76763843)
# Finished training epoch 48
# Validate: MSE 0.00311354 (0.00271278), PSNR 25.06745338 (25.74295512), SSIM 0.70239043 (0.77428875)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00313505 (0.00271308), PSNR 25.03755951 (25.68673067), SSIM 0.75894558 (0.76769395)
# Finished training epoch 49
# Validate: MSE 0.00308189 (0.00271160), PSNR 25.11182785 (25.74658896), SSIM 0.69845068 (0.77255680)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00257399 (0.00271549), PSNR 25.89392471 (25.68572488), SSIM 0.77762580 (0.76748574)
# Finished training epoch 50
# Validate: MSE 0.00309326 (0.00270937), PSNR 25.09584045 (25.74924258), SSIM 0.70115888 (0.77364828)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00296452 (0.00271316), PSNR 25.28045082 (25.68750202), SSIM 0.76472777 (0.76725423)
# Finished training epoch 51
# Validate: MSE 0.00307320 (0.00270800), PSNR 25.12409210 (25.75245597), SSIM 0.70090073 (0.77329826)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00226969 (0.00271425), PSNR 26.44033813 (25.68763743), SSIM 0.76254672 (0.76725975)
# Finished training epoch 52
# Validate: MSE 0.00311255 (0.00270777), PSNR 25.06883621 (25.75008318), SSIM 0.70113641 (0.77348632)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00252090 (0.00270375), PSNR 25.98443604 (25.70370143), SSIM 0.76774520 (0.76734943)
# Finished training epoch 53
# Validate: MSE 0.00310626 (0.00270628), PSNR 25.07761383 (25.75252069), SSIM 0.70117092 (0.77296609)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00282145 (0.00270608), PSNR 25.49527740 (25.70174237), SSIM 0.74169928 (0.76719455)
# Finished training epoch 54
# Validate: MSE 0.00312071 (0.00270642), PSNR 25.05746269 (25.75186162), SSIM 0.70143807 (0.77353718)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00295046 (0.00271074), PSNR 25.30110550 (25.69649995), SSIM 0.77353156 (0.76699311)
# Finished training epoch 55
# Validate: MSE 0.00310634 (0.00270127), PSNR 25.07751465 (25.76110168), SSIM 0.69977838 (0.77339869)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00301548 (0.00270293), PSNR 25.20644188 (25.70296666), SSIM 0.75235218 (0.76709233)
# Finished training epoch 56
# Validate: MSE 0.00310356 (0.00270186), PSNR 25.08140373 (25.75970942), SSIM 0.70001066 (0.77349811)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00268710 (0.00269824), PSNR 25.70716095 (25.71109369), SSIM 0.75543994 (0.76698931)
# Finished training epoch 57
# Validate: MSE 0.00311938 (0.00270190), PSNR 25.05931091 (25.75872878), SSIM 0.70173746 (0.77352531)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00305405 (0.00269987), PSNR 25.15123940 (25.70842144), SSIM 0.76312256 (0.76686823)
# Finished training epoch 58
# Validate: MSE 0.00310536 (0.00269762), PSNR 25.07888031 (25.76640585), SSIM 0.70015794 (0.77324924)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00294208 (0.00270012), PSNR 25.31345367 (25.71087586), SSIM 0.74828565 (0.76677274)
# Finished training epoch 59
# Validate: MSE 0.00308197 (0.00269479), PSNR 25.11171341 (25.77156893), SSIM 0.69979310 (0.77254701)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00203395 (0.00269952), PSNR 26.91658974 (25.70982668), SSIM 0.79973352 (0.76667648)
# Finished training epoch 60
# Validate: MSE 0.00309020 (0.00269324), PSNR 25.10013962 (25.77363981), SSIM 0.69947982 (0.77301683)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00227584 (0.00269235), PSNR 26.42858124 (25.72049097), SSIM 0.77728498 (0.76648800)
# Finished training epoch 61
# Validate: MSE 0.00307892 (0.00269037), PSNR 25.11601448 (25.77894646), SSIM 0.69939977 (0.77250473)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00195015 (0.00269769), PSNR 27.09931374 (25.71755284), SSIM 0.77675807 (0.76621500)
# Finished training epoch 62
# Validate: MSE 0.00310593 (0.00269331), PSNR 25.07808876 (25.77181024), SSIM 0.70174289 (0.77314427)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00245834 (0.00268905), PSNR 26.09357071 (25.72761003), SSIM 0.78640336 (0.76634945)
# Finished training epoch 63
# Validate: MSE 0.00307353 (0.00268816), PSNR 25.12362862 (25.78159009), SSIM 0.70166630 (0.77259031)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00262433 (0.00268537), PSNR 25.80980873 (25.73319835), SSIM 0.77065325 (0.76622825)
# Finished training epoch 64
# Validate: MSE 0.00307404 (0.00268542), PSNR 25.12290192 (25.78614769), SSIM 0.69937438 (0.77245037)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00266567 (0.00269190), PSNR 25.74192810 (25.72240728), SSIM 0.75845408 (0.76587984)
# Finished training epoch 65
# Validate: MSE 0.00305011 (0.00268233), PSNR 25.15683937 (25.79154430), SSIM 0.69948292 (0.77187136)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00269554 (0.00268747), PSNR 25.69353294 (25.73084742), SSIM 0.76108575 (0.76571825)
# Finished training epoch 66
# Validate: MSE 0.00307995 (0.00268173), PSNR 25.11456680 (25.79156194), SSIM 0.69901764 (0.77261894)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00292950 (0.00268931), PSNR 25.33206367 (25.72844087), SSIM 0.74465865 (0.76550774)
# Finished training epoch 67
# Validate: MSE 0.00305641 (0.00267892), PSNR 25.14788437 (25.79641476), SSIM 0.69843131 (0.77144796)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00271144 (0.00268101), PSNR 25.66799736 (25.74050389), SSIM 0.75779277 (0.76537626)
# Finished training epoch 68
# Validate: MSE 0.00306049 (0.00267586), PSNR 25.14208984 (25.80119607), SSIM 0.69918054 (0.77156940)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00239287 (0.00267931), PSNR 26.21080017 (25.74299667), SSIM 0.76410568 (0.76531774)
# Finished training epoch 69
# Validate: MSE 0.00305675 (0.00267382), PSNR 25.14739609 (25.80437468), SSIM 0.69937468 (0.77215027)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00214711 (0.00267615), PSNR 26.68146324 (25.74656395), SSIM 0.77465999 (0.76500812)
# Finished training epoch 70
# Validate: MSE 0.00303350 (0.00267014), PSNR 25.18055534 (25.81136413), SSIM 0.69538593 (0.76985324)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00309482 (0.00267997), PSNR 25.09363937 (25.74330831), SSIM 0.73474085 (0.76492508)
# Finished training epoch 71
# Validate: MSE 0.00306634 (0.00266942), PSNR 25.13379288 (25.81057950), SSIM 0.69641387 (0.77155180)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00233467 (0.00267149), PSNR 26.31774521 (25.75523405), SSIM 0.76893383 (0.76480673)
# Finished training epoch 72
# Validate: MSE 0.00304167 (0.00266513), PSNR 25.16888428 (25.81814351), SSIM 0.69635034 (0.77014298)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00216977 (0.00267116), PSNR 26.63586998 (25.75684666), SSIM 0.78163850 (0.76456678)
# Finished training epoch 73
# Validate: MSE 0.00305228 (0.00266275), PSNR 25.15375710 (25.82164472), SSIM 0.69815421 (0.77054407)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00303322 (0.00266589), PSNR 25.18095779 (25.76611519), SSIM 0.76120311 (0.76427134)
# Finished training epoch 74
# Validate: MSE 0.00303633 (0.00265949), PSNR 25.17650986 (25.82700200), SSIM 0.69736356 (0.77074872)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00211017 (0.00267339), PSNR 26.75682831 (25.75204895), SSIM 0.78018802 (0.76375510)
# Finished training epoch 75
# Validate: MSE 0.00303368 (0.00265757), PSNR 25.18029976 (25.82959781), SSIM 0.69602787 (0.77050295)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00281098 (0.00266648), PSNR 25.51142502 (25.76308869), SSIM 0.75317657 (0.76355356)
# Finished training epoch 76
# Validate: MSE 0.00305181 (0.00265558), PSNR 25.15442467 (25.83176300), SSIM 0.69878155 (0.77058540)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00250332 (0.00266065), PSNR 26.01482773 (25.77276613), SSIM 0.76375771 (0.76386481)
# Finished training epoch 77
# Validate: MSE 0.00305447 (0.00265288), PSNR 25.15064049 (25.83596068), SSIM 0.69729650 (0.76964812)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00221591 (0.00265757), PSNR 26.54447937 (25.77722243), SSIM 0.77608359 (0.76350240)
# Finished training epoch 78
# Validate: MSE 0.00302506 (0.00264747), PSNR 25.19265366 (25.84528322), SSIM 0.69542301 (0.76935529)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00300979 (0.00265737), PSNR 25.21463394 (25.77790794), SSIM 0.76411909 (0.76315511)
# Finished training epoch 79
# Validate: MSE 0.00303011 (0.00264616), PSNR 25.18541718 (25.84690719), SSIM 0.69701016 (0.76938221)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00268828 (0.00265718), PSNR 25.70524979 (25.77601297), SSIM 0.75235844 (0.76309311)
# Finished training epoch 80
# Validate: MSE 0.00302128 (0.00264307), PSNR 25.19808578 (25.85246469), SSIM 0.69693363 (0.76938320)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00249049 (0.00264931), PSNR 26.03714943 (25.79081709), SSIM 0.77188981 (0.76287057)
# Finished training epoch 81
# Validate: MSE 0.00300880 (0.00263956), PSNR 25.21605873 (25.85758363), SSIM 0.69442487 (0.76809550)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00287849 (0.00264346), PSNR 25.40835571 (25.80244829), SSIM 0.75240964 (0.76266875)
# Finished training epoch 82
# Validate: MSE 0.00301826 (0.00263735), PSNR 25.20243263 (25.86085766), SSIM 0.69867885 (0.76916082)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00232869 (0.00265667), PSNR 26.32887840 (25.77988778), SSIM 0.76921427 (0.76227515)
# Finished training epoch 83
# Validate: MSE 0.00301774 (0.00263442), PSNR 25.20318604 (25.86541902), SSIM 0.69685596 (0.76818265)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00293307 (0.00263659), PSNR 25.32677650 (25.81089953), SSIM 0.75149137 (0.76254187)
# Finished training epoch 84
# Validate: MSE 0.00299550 (0.00262989), PSNR 25.23530960 (25.87358248), SSIM 0.69441670 (0.76747532)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00284581 (0.00264731), PSNR 25.45794106 (25.79425906), SSIM 0.77181756 (0.76217844)
# Finished training epoch 85
# Validate: MSE 0.00303783 (0.00263128), PSNR 25.17436218 (25.86974824), SSIM 0.69668269 (0.76875894)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00251820 (0.00263474), PSNR 25.98910332 (25.81809780), SSIM 0.76848066 (0.76215795)
# Finished training epoch 86
# Validate: MSE 0.00299486 (0.00262584), PSNR 25.23623848 (25.87960623), SSIM 0.69718778 (0.76833074)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00220679 (0.00263910), PSNR 26.56238365 (25.80968082), SSIM 0.76670045 (0.76191837)
# Finished training epoch 87
# Validate: MSE 0.00303361 (0.00262782), PSNR 25.18040657 (25.87552398), SSIM 0.69788283 (0.76944564)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00282168 (0.00262512), PSNR 25.49491501 (25.83136790), SSIM 0.74072307 (0.76218317)
# Finished training epoch 88
# Validate: MSE 0.00301566 (0.00262299), PSNR 25.20616913 (25.88319154), SSIM 0.69808447 (0.76893865)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00218651 (0.00263807), PSNR 26.60248566 (25.81257095), SSIM 0.75812131 (0.76155492)
# Finished training epoch 89
# Validate: MSE 0.00299323 (0.00261718), PSNR 25.23859406 (25.89366229), SSIM 0.69743741 (0.76841166)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00258042 (0.00263047), PSNR 25.88309669 (25.82637076), SSIM 0.74952334 (0.76154685)
# Finished training epoch 90
# Validate: MSE 0.00297898 (0.00261390), PSNR 25.25932503 (25.89830391), SSIM 0.69641924 (0.76723042)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00285359 (0.00262461), PSNR 25.44608498 (25.83062753), SSIM 0.75158221 (0.76150084)
# Finished training epoch 91
# Validate: MSE 0.00300965 (0.00261727), PSNR 25.21484184 (25.89276594), SSIM 0.69929779 (0.76948350)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00239645 (0.00261810), PSNR 26.20431328 (25.84475394), SSIM 0.77296448 (0.76156290)
# Finished training epoch 92
# Validate: MSE 0.00298928 (0.00261204), PSNR 25.24432945 (25.90135770), SSIM 0.69748318 (0.76910329)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00260970 (0.00261867), PSNR 25.83408928 (25.84495314), SSIM 0.74619567 (0.76152398)
# Finished training epoch 93
# Validate: MSE 0.00298342 (0.00260817), PSNR 25.25285721 (25.90750323), SSIM 0.69882619 (0.76727643)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00271101 (0.00261723), PSNR 25.66868401 (25.84253131), SSIM 0.76174510 (0.76140067)
# Finished training epoch 94
# Validate: MSE 0.00299777 (0.00260879), PSNR 25.23202324 (25.90580146), SSIM 0.69615149 (0.76815991)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00223247 (0.00262292), PSNR 26.51213837 (25.83587601), SSIM 0.75511223 (0.76114579)
# Finished training epoch 95
# Validate: MSE 0.00295713 (0.00260321), PSNR 25.29129982 (25.91617875), SSIM 0.69530523 (0.76675522)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00303827 (0.00262010), PSNR 25.17373657 (25.84245007), SSIM 0.74812454 (0.76110831)
# Finished training epoch 96
# Validate: MSE 0.00298957 (0.00260209), PSNR 25.24391174 (25.91715889), SSIM 0.69783115 (0.76880363)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00268170 (0.00261943), PSNR 25.71589851 (25.84297848), SSIM 0.76954287 (0.76102114)
# Finished training epoch 97
# Validate: MSE 0.00295940 (0.00259844), PSNR 25.28795624 (25.92375331), SSIM 0.69823647 (0.76822257)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00269908 (0.00260683), PSNR 25.68784714 (25.86269740), SSIM 0.76071817 (0.76107915)
# Finished training epoch 98
# Validate: MSE 0.00295653 (0.00259577), PSNR 25.29218292 (25.92733331), SSIM 0.69670379 (0.76702330)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00271737 (0.00261062), PSNR 25.65851784 (25.85710255), SSIM 0.73941690 (0.76072885)
# Finished training epoch 99
# Validate: MSE 0.00296702 (0.00259567), PSNR 25.27679443 (25.92720857), SSIM 0.69687605 (0.76661193)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00274118 (0.00261325), PSNR 25.62062645 (25.85080594), SSIM 0.74414259 (0.76052146)
# Finished training epoch 100
# Validate: MSE 0.00298913 (0.00259502), PSNR 25.24454689 (25.92792907), SSIM 0.69771075 (0.76655972)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00303559 (0.00260391), PSNR 25.17756462 (25.86654962), SSIM 0.76078898 (0.76076763)
# Finished training epoch 101
# Validate: MSE 0.00297435 (0.00259112), PSNR 25.26607704 (25.93426349), SSIM 0.69845676 (0.76714905)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00229972 (0.00261213), PSNR 26.38324356 (25.85162610), SSIM 0.76973176 (0.76041494)
# Finished training epoch 102
# Validate: MSE 0.00297643 (0.00258964), PSNR 25.26303673 (25.93623512), SSIM 0.69752407 (0.76583893)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00261737 (0.00260996), PSNR 25.82134628 (25.85940789), SSIM 0.77582657 (0.76062283)
# Finished training epoch 103
# Validate: MSE 0.00296419 (0.00258837), PSNR 25.28093529 (25.93924576), SSIM 0.69948906 (0.76860023)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00288211 (0.00260231), PSNR 25.40288734 (25.86883401), SSIM 0.74672985 (0.76041813)
# Finished training epoch 104
# Validate: MSE 0.00297193 (0.00258663), PSNR 25.26960945 (25.94157268), SSIM 0.69770920 (0.76716046)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00282844 (0.00260018), PSNR 25.48452950 (25.87441569), SSIM 0.76028049 (0.76040082)
# Finished training epoch 105
# Validate: MSE 0.00295448 (0.00258182), PSNR 25.29518509 (25.95025333), SSIM 0.69784749 (0.76797287)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00313411 (0.00259149), PSNR 25.03885651 (25.89055663), SSIM 0.73832124 (0.76068136)
# Finished training epoch 106
# Validate: MSE 0.00297015 (0.00258141), PSNR 25.27220917 (25.95028898), SSIM 0.69801629 (0.76722885)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00251051 (0.00260020), PSNR 26.00237274 (25.87372605), SSIM 0.75736648 (0.76044238)
# Finished training epoch 107
# Validate: MSE 0.00295443 (0.00257987), PSNR 25.29526329 (25.95315455), SSIM 0.70088971 (0.76847792)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00192625 (0.00259005), PSNR 27.15286827 (25.89019591), SSIM 0.79404861 (0.76054219)
# Finished training epoch 108
# Validate: MSE 0.00296475 (0.00257448), PSNR 25.28011131 (25.96102254), SSIM 0.69438010 (0.76570616)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00253939 (0.00258727), PSNR 25.95271111 (25.89409862), SSIM 0.75078285 (0.76045217)
# Finished training epoch 109
# Validate: MSE 0.00294575 (0.00257283), PSNR 25.30803680 (25.96432303), SSIM 0.69813991 (0.76700747)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00237164 (0.00259023), PSNR 26.24950790 (25.89013232), SSIM 0.76024866 (0.76057655)
# Finished training epoch 110
# Validate: MSE 0.00296304 (0.00257229), PSNR 25.28262901 (25.96501222), SSIM 0.69971746 (0.76746478)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00294579 (0.00258377), PSNR 25.30797577 (25.89880184), SSIM 0.76499176 (0.76077245)
# Finished training epoch 111
# Validate: MSE 0.00296688 (0.00257312), PSNR 25.27700233 (25.96364286), SSIM 0.69927162 (0.76813246)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00282002 (0.00259306), PSNR 25.49748230 (25.88330123), SSIM 0.74128681 (0.76034442)
# Finished training epoch 112
# Validate: MSE 0.00296140 (0.00257241), PSNR 25.28503036 (25.96402057), SSIM 0.69929123 (0.76638573)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00330944 (0.00258005), PSNR 24.80245590 (25.90804963), SSIM 0.73152792 (0.76048526)
# Finished training epoch 113
# Validate: MSE 0.00295125 (0.00256626), PSNR 25.29993439 (25.97472386), SSIM 0.69687748 (0.76670629)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00281714 (0.00257917), PSNR 25.50191307 (25.90988622), SSIM 0.75050843 (0.76058137)
# Finished training epoch 114
# Validate: MSE 0.00295072 (0.00256650), PSNR 25.30071831 (25.97399194), SSIM 0.69857466 (0.76697108)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00309858 (0.00258321), PSNR 25.08837700 (25.89990501), SSIM 0.73494327 (0.76051268)
# Finished training epoch 115
# Validate: MSE 0.00295404 (0.00256531), PSNR 25.29584122 (25.97603040), SSIM 0.69851935 (0.76755835)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00230278 (0.00258158), PSNR 26.37747002 (25.90416772), SSIM 0.76338166 (0.76041145)
# Finished training epoch 116
# Validate: MSE 0.00294561 (0.00256175), PSNR 25.30824661 (25.98256480), SSIM 0.69733155 (0.76729589)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00278429 (0.00257174), PSNR 25.55284882 (25.91980044), SSIM 0.75235701 (0.76058221)
# Finished training epoch 117
# Validate: MSE 0.00298101 (0.00256383), PSNR 25.25637054 (25.97823641), SSIM 0.69883806 (0.76675493)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00272062 (0.00258001), PSNR 25.65332413 (25.90908610), SSIM 0.75218093 (0.76033210)
# Finished training epoch 118
# Validate: MSE 0.00296830 (0.00256112), PSNR 25.27492142 (25.98250753), SSIM 0.69633639 (0.76691343)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00313551 (0.00258203), PSNR 25.03692055 (25.90567593), SSIM 0.74373466 (0.76037462)
# Finished training epoch 119
# Validate: MSE 0.00294558 (0.00255717), PSNR 25.30828857 (25.98894639), SSIM 0.70128465 (0.76606924)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00307103 (0.00257245), PSNR 25.12716293 (25.91995555), SSIM 0.74247932 (0.76025683)
# Finished training epoch 120
# Validate: MSE 0.00294263 (0.00255738), PSNR 25.31264305 (25.98947494), SSIM 0.70139301 (0.76783691)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00271214 (0.00257253), PSNR 25.66687775 (25.91722702), SSIM 0.76107168 (0.76028338)
# Finished training epoch 121
# Validate: MSE 0.00295486 (0.00255560), PSNR 25.29462433 (25.99182457), SSIM 0.69866121 (0.76745541)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00260640 (0.00256894), PSNR 25.83959579 (25.92695142), SSIM 0.74596161 (0.76057339)
# Finished training epoch 122
# Validate: MSE 0.00295444 (0.00255673), PSNR 25.29524994 (25.98982423), SSIM 0.69804561 (0.76675130)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00244788 (0.00256741), PSNR 26.11209488 (25.92518943), SSIM 0.75107962 (0.76060984)
# Finished training epoch 123
# Validate: MSE 0.00293520 (0.00255360), PSNR 25.32361984 (25.99459387), SSIM 0.69692516 (0.76590781)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00285548 (0.00257403), PSNR 25.44320488 (25.91695321), SSIM 0.74886906 (0.76052738)
# Finished training epoch 124
# Validate: MSE 0.00293376 (0.00255102), PSNR 25.32575417 (25.99895507), SSIM 0.69910204 (0.76610887)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00267865 (0.00256594), PSNR 25.72084045 (25.92889756), SSIM 0.75851369 (0.76047723)
# Finished training epoch 125
# Validate: MSE 0.00295770 (0.00255218), PSNR 25.29046059 (25.99756457), SSIM 0.69945526 (0.76716370)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00274836 (0.00256659), PSNR 25.60925674 (25.92944755), SSIM 0.75065672 (0.76057121)
# Finished training epoch 126
# Validate: MSE 0.00293097 (0.00254722), PSNR 25.32988548 (26.00573226), SSIM 0.69917619 (0.76658001)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00239931 (0.00256041), PSNR 26.19914436 (25.93819226), SSIM 0.76737601 (0.76060669)
# Finished training epoch 127
# Validate: MSE 0.00292484 (0.00254505), PSNR 25.33897209 (26.00934421), SSIM 0.69945669 (0.76679389)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00238415 (0.00257027), PSNR 26.22666168 (25.92375242), SSIM 0.75136334 (0.76061039)
# Finished training epoch 128
# Validate: MSE 0.00291021 (0.00254561), PSNR 25.36075592 (26.00803932), SSIM 0.70145226 (0.76605820)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00247944 (0.00256248), PSNR 26.05646706 (25.93711545), SSIM 0.78205746 (0.76068210)
# Finished training epoch 129
# Validate: MSE 0.00293691 (0.00254510), PSNR 25.32108498 (26.00915773), SSIM 0.69967479 (0.76765803)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00309450 (0.00256541), PSNR 25.09409904 (25.93559080), SSIM 0.71506697 (0.76077765)
# Finished training epoch 130
# Validate: MSE 0.00292190 (0.00254378), PSNR 25.34335136 (26.01069494), SSIM 0.69811839 (0.76601921)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00271194 (0.00255799), PSNR 25.66720581 (25.94339228), SSIM 0.76508981 (0.76059693)
# Finished training epoch 131
# Validate: MSE 0.00291953 (0.00254146), PSNR 25.34687233 (26.01475143), SSIM 0.70100844 (0.76653811)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00288198 (0.00256102), PSNR 25.40308952 (25.94092694), SSIM 0.75748515 (0.76054807)
# Finished training epoch 132
# Validate: MSE 0.00292307 (0.00253973), PSNR 25.34160042 (26.01760450), SSIM 0.70125854 (0.76717548)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00223605 (0.00256269), PSNR 26.50518227 (25.93473471), SSIM 0.77758580 (0.76048782)
# Finished training epoch 133
# Validate: MSE 0.00293665 (0.00253955), PSNR 25.32147980 (26.01836202), SSIM 0.70267797 (0.76839473)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00202506 (0.00256713), PSNR 26.93561745 (25.93262938), SSIM 0.77308905 (0.76058776)
# Finished training epoch 134
# Validate: MSE 0.00292401 (0.00253920), PSNR 25.34020805 (26.01861736), SSIM 0.70181775 (0.76760286)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00225038 (0.00255030), PSNR 26.47743225 (25.95628398), SSIM 0.76760346 (0.76098244)
# Finished training epoch 135
# Validate: MSE 0.00292816 (0.00253765), PSNR 25.33405495 (26.02105343), SSIM 0.70100486 (0.76696896)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00254436 (0.00255519), PSNR 25.94420624 (25.94798674), SSIM 0.77591574 (0.76066336)
# Finished training epoch 136
# Validate: MSE 0.00293264 (0.00253613), PSNR 25.32740402 (26.02401804), SSIM 0.70038259 (0.76756878)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00192802 (0.00255413), PSNR 27.14888954 (25.95082694), SSIM 0.77374262 (0.76063517)
# Finished training epoch 137
# Validate: MSE 0.00294615 (0.00253788), PSNR 25.30744553 (26.02083495), SSIM 0.70144027 (0.76806246)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00306618 (0.00255732), PSNR 25.13401985 (25.94408510), SSIM 0.75929916 (0.76068642)
# Finished training epoch 138
# Validate: MSE 0.00294990 (0.00253600), PSNR 25.30192947 (26.02435164), SSIM 0.70131058 (0.76868862)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00296273 (0.00255351), PSNR 25.28307533 (25.95016921), SSIM 0.75360769 (0.76076529)
# Finished training epoch 139
# Validate: MSE 0.00293499 (0.00253444), PSNR 25.32392883 (26.02576882), SSIM 0.69994795 (0.76673053)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00236957 (0.00254953), PSNR 26.25330734 (25.96059209), SSIM 0.76036692 (0.76087667)
# Finished training epoch 140
# Validate: MSE 0.00293485 (0.00253140), PSNR 25.32414246 (26.03183247), SSIM 0.69922912 (0.76730553)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00253195 (0.00255156), PSNR 25.96543884 (25.95278276), SSIM 0.76021802 (0.76075450)
# Finished training epoch 141
# Validate: MSE 0.00293363 (0.00253199), PSNR 25.32594299 (26.03106116), SSIM 0.70177162 (0.76797742)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00201290 (0.00255605), PSNR 26.96176720 (25.94737151), SSIM 0.77345842 (0.76069313)
# Finished training epoch 142
# Validate: MSE 0.00292811 (0.00252975), PSNR 25.33412933 (26.03376757), SSIM 0.70171118 (0.76599669)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00195736 (0.00254588), PSNR 27.08329391 (25.96490391), SSIM 0.77727538 (0.76077593)
# Finished training epoch 143
# Validate: MSE 0.00293751 (0.00252960), PSNR 25.32020760 (26.03504817), SSIM 0.70078188 (0.76838273)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00256073 (0.00254843), PSNR 25.91636848 (25.96366889), SSIM 0.77301806 (0.76106096)
# Finished training epoch 144
# Validate: MSE 0.00291321 (0.00252681), PSNR 25.35627937 (26.03875747), SSIM 0.70073706 (0.76690663)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00270245 (0.00254618), PSNR 25.68242455 (25.96448938), SSIM 0.78176898 (0.76096323)
# Finished training epoch 145
# Validate: MSE 0.00290311 (0.00252640), PSNR 25.37136650 (26.03914421), SSIM 0.70161796 (0.76718267)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00270480 (0.00254867), PSNR 25.67864418 (25.96014880), SSIM 0.76599532 (0.76075690)
# Finished training epoch 146
# Validate: MSE 0.00291665 (0.00252666), PSNR 25.35115623 (26.03907933), SSIM 0.70319790 (0.76738282)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00232742 (0.00254232), PSNR 26.33125687 (25.96911026), SSIM 0.76784277 (0.76106201)
# Finished training epoch 147
# Validate: MSE 0.00289954 (0.00252586), PSNR 25.37671280 (26.04023516), SSIM 0.70211917 (0.76657554)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00281362 (0.00254607), PSNR 25.50735092 (25.96296603), SSIM 0.77199805 (0.76077253)
# Finished training epoch 148
# Validate: MSE 0.00292685 (0.00252632), PSNR 25.33598709 (26.04059376), SSIM 0.70176697 (0.76854125)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00268806 (0.00255835), PSNR 25.70560837 (25.94703097), SSIM 0.75983155 (0.76053890)
# Finished training epoch 149
# Validate: MSE 0.00293355 (0.00252489), PSNR 25.32606316 (26.04266894), SSIM 0.70283937 (0.76821961)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00227956 (0.00254371), PSNR 26.42148018 (25.96757582), SSIM 0.77820688 (0.76123010)
# Finished training epoch 150
# Validate: MSE 0.00293119 (0.00252646), PSNR 25.32955170 (26.03927274), SSIM 0.70078802 (0.76693448)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00269966 (0.00254569), PSNR 25.68690491 (25.96458373), SSIM 0.73520964 (0.76094424)
# Finished training epoch 151
# Validate: MSE 0.00290624 (0.00252220), PSNR 25.36668205 (26.04658725), SSIM 0.70196819 (0.76686428)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00228986 (0.00254995), PSNR 26.40191269 (25.95887526), SSIM 0.75857460 (0.76063928)
# Finished training epoch 152
# Validate: MSE 0.00294212 (0.00252389), PSNR 25.31339264 (26.04381774), SSIM 0.70369154 (0.76831503)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00192875 (0.00254042), PSNR 27.14723015 (25.97619256), SSIM 0.76968932 (0.76111503)
# Finished training epoch 153
# Validate: MSE 0.00294384 (0.00252078), PSNR 25.31085777 (26.04910677), SSIM 0.70212716 (0.76715464)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00267094 (0.00254070), PSNR 25.73335266 (25.97434841), SSIM 0.75080222 (0.76105298)
# Finished training epoch 154
# Validate: MSE 0.00291116 (0.00251867), PSNR 25.35933876 (26.05232863), SSIM 0.70235193 (0.76761097)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00231865 (0.00253929), PSNR 26.34764671 (25.97534117), SSIM 0.77165508 (0.76110461)
# Finished training epoch 155
# Validate: MSE 0.00291265 (0.00251863), PSNR 25.35712051 (26.05291617), SSIM 0.70300961 (0.76837856)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00257022 (0.00253489), PSNR 25.90029526 (25.98368734), SSIM 0.75563920 (0.76117961)
# Finished training epoch 156
# Validate: MSE 0.00293074 (0.00252043), PSNR 25.33022690 (26.04983647), SSIM 0.70137262 (0.76734252)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00265033 (0.00254097), PSNR 25.76700401 (25.97253108), SSIM 0.75582969 (0.76116248)
# Finished training epoch 157
# Validate: MSE 0.00292198 (0.00251726), PSNR 25.34322548 (26.05517777), SSIM 0.70354104 (0.76802613)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00329547 (0.00253081), PSNR 24.82082939 (25.99029903), SSIM 0.73325694 (0.76132012)
# Finished training epoch 158
# Validate: MSE 0.00293312 (0.00251829), PSNR 25.32669449 (26.05374925), SSIM 0.70341963 (0.76898225)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00231383 (0.00253090), PSNR 26.35668564 (25.98898696), SSIM 0.77505475 (0.76140728)
# Finished training epoch 159
# Validate: MSE 0.00290900 (0.00251521), PSNR 25.36255455 (26.05889002), SSIM 0.70205510 (0.76844801)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00231226 (0.00253581), PSNR 26.35964012 (25.97917513), SSIM 0.76410961 (0.76118169)
# Finished training epoch 160
# Validate: MSE 0.00290695 (0.00251525), PSNR 25.36562347 (26.05860841), SSIM 0.70296359 (0.76793977)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00255576 (0.00254261), PSNR 25.92479897 (25.97124017), SSIM 0.76945597 (0.76121408)
# Finished training epoch 161
# Validate: MSE 0.00290979 (0.00251265), PSNR 25.36138153 (26.06302240), SSIM 0.70282459 (0.76829909)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00289327 (0.00253593), PSNR 25.38610268 (25.98216836), SSIM 0.77207875 (0.76120443)
# Finished training epoch 162
# Validate: MSE 0.00291440 (0.00251334), PSNR 25.35449982 (26.06170924), SSIM 0.70302165 (0.76772663)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00267437 (0.00253774), PSNR 25.72778511 (25.97756768), SSIM 0.74439114 (0.76118457)
# Finished training epoch 163
# Validate: MSE 0.00289555 (0.00251286), PSNR 25.38269234 (26.06183977), SSIM 0.70263988 (0.76664222)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00303675 (0.00253113), PSNR 25.17590714 (25.99163298), SSIM 0.75175989 (0.76128163)
# Finished training epoch 164
# Validate: MSE 0.00292363 (0.00251077), PSNR 25.34077835 (26.06637564), SSIM 0.70219904 (0.76829580)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00285472 (0.00253119), PSNR 25.44435883 (25.99089498), SSIM 0.74472362 (0.76144489)
# Finished training epoch 165
# Validate: MSE 0.00291741 (0.00251141), PSNR 25.35002327 (26.06500874), SSIM 0.70467496 (0.76899228)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00312317 (0.00253180), PSNR 25.05403900 (25.98781476), SSIM 0.74638367 (0.76138084)
# Finished training epoch 166
# Validate: MSE 0.00290581 (0.00250995), PSNR 25.36733246 (26.06690570), SSIM 0.70199454 (0.76741262)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00254289 (0.00252822), PSNR 25.94673157 (25.99425206), SSIM 0.76694906 (0.76146557)
# Finished training epoch 167
# Validate: MSE 0.00291542 (0.00251320), PSNR 25.35298920 (26.06168199), SSIM 0.70213979 (0.76699259)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00277021 (0.00252811), PSNR 25.57487869 (25.99613596), SSIM 0.75636119 (0.76152128)
# Finished training epoch 168
# Validate: MSE 0.00290216 (0.00250710), PSNR 25.37279129 (26.07207249), SSIM 0.70369828 (0.76756954)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00221125 (0.00252858), PSNR 26.55362892 (25.99333703), SSIM 0.77108854 (0.76154203)
# Finished training epoch 169
# Validate: MSE 0.00292077 (0.00250701), PSNR 25.34502411 (26.07270135), SSIM 0.70286274 (0.76895423)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00324039 (0.00252915), PSNR 24.89403152 (25.99298016), SSIM 0.74631578 (0.76165696)
# Finished training epoch 170
# Validate: MSE 0.00289101 (0.00250670), PSNR 25.38949966 (26.07274232), SSIM 0.70502412 (0.76740729)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00302515 (0.00253163), PSNR 25.19252777 (25.98861764), SSIM 0.73906684 (0.76140908)
# Finished training epoch 171
# Validate: MSE 0.00290737 (0.00250555), PSNR 25.36499596 (26.07499005), SSIM 0.70238423 (0.76744130)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00197475 (0.00252324), PSNR 27.04488564 (26.00436711), SSIM 0.77945769 (0.76136032)
# Finished training epoch 172
# Validate: MSE 0.00291438 (0.00250687), PSNR 25.35453987 (26.07191580), SSIM 0.70178902 (0.76755141)
# Finished validation.
# Starting training epoch 173
# ...
# Finished validation.
# Starting training epoch 276
# Epoch: 276, MSE 0.00230888 (0.00248377), PSNR 26.36598396 (26.07314768), SSIM 0.79207003 (0.76411895)
# Finished training epoch 276
# Validate: MSE 0.00287712 (0.00245566), PSNR 25.41041374 (26.16066147), SSIM 0.70653820 (0.77055236)
# Finished validation.
# Starting training epoch 277
# Epoch: 277, MSE 0.00244439 (0.00248210), PSNR 26.11829185 (26.07726971), SSIM 0.76365429 (0.76427858)
# Finished training epoch 277
# Validate: MSE 0.00288849 (0.00245720), PSNR 25.39328957 (26.15799806), SSIM 0.70611858 (0.77067189)
# Finished validation.
# Starting training epoch 278
# Epoch: 278, MSE 0.00258263 (0.00247793), PSNR 25.87937927 (26.08186364), SSIM 0.77823961 (0.76421574)
# Finished training epoch 278
# Validate: MSE 0.00289922 (0.00246281), PSNR 25.37718773 (26.14856375), SSIM 0.70650911 (0.77181206)
# Finished validation.
# Starting training epoch 279
# Epoch: 279, MSE 0.00287600 (0.00248127), PSNR 25.41211510 (26.07653438), SSIM 0.75304115 (0.76414560)
# Finished training epoch 279
# Validate: MSE 0.00286639 (0.00245295), PSNR 25.42664909 (26.16550271), SSIM 0.70703804 (0.77074641)
# Finished validation.
# Starting training epoch 280
# Epoch: 280, MSE 0.00263226 (0.00248259), PSNR 25.79670906 (26.07394319), SSIM 0.75432700 (0.76432774)
# Finished training epoch 280
# Validate: MSE 0.00289962 (0.00245477), PSNR 25.37658501 (26.16238803), SSIM 0.70566267 (0.77037902)
# Finished validation.
# Starting training epoch 281
# Epoch: 281, MSE 0.00180477 (0.00247576), PSNR 27.43577385 (26.08883221), SSIM 0.78005773 (0.76447203)
# Finished training epoch 281
# Validate: MSE 0.00287382 (0.00245441), PSNR 25.41540718 (26.16303684), SSIM 0.70776123 (0.77041521)
# Finished validation.
# Starting training epoch 282
# Epoch: 282, MSE 0.00236398 (0.00247843), PSNR 26.26356506 (26.08213276), SSIM 0.76986575 (0.76431425)
# Finished training epoch 282
# Validate: MSE 0.00287427 (0.00245435), PSNR 25.41472244 (26.16242044), SSIM 0.70670664 (0.77072099)
# Finished validation.
# Starting training epoch 283
# Epoch: 283, MSE 0.00252293 (0.00248444), PSNR 25.98093987 (26.06971491), SSIM 0.77765232 (0.76424106)
# Finished training epoch 283
# Validate: MSE 0.00285520 (0.00245719), PSNR 25.44363022 (26.15775768), SSIM 0.70796853 (0.77118155)
# Finished validation.
# Starting training epoch 284
# Epoch: 284, MSE 0.00275878 (0.00247587), PSNR 25.59282875 (26.08482385), SSIM 0.76425624 (0.76419921)
# Finished training epoch 284
# Validate: MSE 0.00288065 (0.00245634), PSNR 25.40509224 (26.16058423), SSIM 0.70968360 (0.77239249)
# Finished validation.
# Starting training epoch 285
# Epoch: 285, MSE 0.00237482 (0.00247628), PSNR 26.24368477 (26.08693170), SSIM 0.77097207 (0.76470291)
# Finished training epoch 285
# Validate: MSE 0.00286320 (0.00245175), PSNR 25.43148232 (26.16708061), SSIM 0.70636940 (0.77057632)
# Finished validation.
# Starting training epoch 286
# Epoch: 286, MSE 0.00249922 (0.00247398), PSNR 26.02194977 (26.08671783), SSIM 0.77832592 (0.76435960)
# Finished training epoch 286
# Validate: MSE 0.00285804 (0.00245379), PSNR 25.43931389 (26.16408061), SSIM 0.70885348 (0.77107053)
# Finished validation.
# Starting training epoch 287
# Epoch: 287, MSE 0.00254735 (0.00248088), PSNR 25.93912125 (26.07694599), SSIM 0.77303159 (0.76427609)
# Finished training epoch 287
# Validate: MSE 0.00290739 (0.00245559), PSNR 25.36497307 (26.16157158), SSIM 0.70625663 (0.77111721)
# Finished validation.
# Starting training epoch 288
# Epoch: 288, MSE 0.00327732 (0.00247913), PSNR 24.84480476 (26.08257572), SSIM 0.76885468 (0.76454871)
# Finished training epoch 288
# Validate: MSE 0.00287775 (0.00245550), PSNR 25.40947151 (26.16092300), SSIM 0.70707107 (0.77052283)
# Finished validation.
# Starting training epoch 289
# Epoch: 289, MSE 0.00269252 (0.00247860), PSNR 25.69840240 (26.08068311), SSIM 0.75141019 (0.76447991)
# Finished training epoch 289
# Validate: MSE 0.00287122 (0.00244764), PSNR 25.41932869 (26.17404790), SSIM 0.70768642 (0.77060849)
# Finished validation.
# Starting training epoch 290
# Epoch: 290, MSE 0.00285735 (0.00247666), PSNR 25.44037247 (26.08266192), SSIM 0.74766743 (0.76431142)
# Finished training epoch 290
# Validate: MSE 0.00287823 (0.00245223), PSNR 25.40874672 (26.16649162), SSIM 0.70700222 (0.77206941)
# Finished validation.
# Starting training epoch 291
# Epoch: 291, MSE 0.00206370 (0.00247704), PSNR 26.85353851 (26.08085704), SSIM 0.78738773 (0.76468656)
# Finished training epoch 291
# Validate: MSE 0.00287458 (0.00245253), PSNR 25.41425323 (26.16613676), SSIM 0.70520580 (0.77115749)
# Finished validation.
# Starting training epoch 292
# Epoch: 292, MSE 0.00201655 (0.00247072), PSNR 26.95390701 (26.09359011), SSIM 0.78305912 (0.76470878)
# Finished training epoch 292
# Validate: MSE 0.00286854 (0.00245315), PSNR 25.42338371 (26.16509433), SSIM 0.70806825 (0.77117182)
# Finished validation.
# Starting training epoch 293
# Epoch: 293, MSE 0.00283061 (0.00247872), PSNR 25.48120499 (26.08158632), SSIM 0.75016057 (0.76454343)
# Finished training epoch 293
# Validate: MSE 0.00289994 (0.00244998), PSNR 25.37610626 (26.17072477), SSIM 0.70651019 (0.77148306)
# Finished validation.
# Starting training epoch 294
# Epoch: 294, MSE 0.00265979 (0.00248015), PSNR 25.75152397 (26.07846310), SSIM 0.74305642 (0.76447176)
# Finished training epoch 294
# Validate: MSE 0.00286751 (0.00245294), PSNR 25.42494583 (26.16544593), SSIM 0.70747769 (0.77034977)
# Finished validation.
# Starting training epoch 295
# Epoch: 295, MSE 0.00270746 (0.00248097), PSNR 25.67437363 (26.07910268), SSIM 0.77982748 (0.76439863)
# Finished training epoch 295
# Validate: MSE 0.00288356 (0.00244949), PSNR 25.40071487 (26.17213463), SSIM 0.70852411 (0.77197483)
# Finished validation.
# Starting training epoch 296
# Epoch: 296, MSE 0.00266310 (0.00247956), PSNR 25.74612427 (26.07974425), SSIM 0.74218261 (0.76442620)
# Finished training epoch 296
# Validate: MSE 0.00287353 (0.00245061), PSNR 25.41583633 (26.16960555), SSIM 0.70774490 (0.77158235)
# Finished validation.
# Starting training epoch 297
# Epoch: 297, MSE 0.00252581 (0.00247403), PSNR 25.97598839 (26.09007082), SSIM 0.75672156 (0.76494134)
# Finished training epoch 297
# Validate: MSE 0.00286795 (0.00245347), PSNR 25.42428207 (26.16439536), SSIM 0.70564663 (0.77023634)
# Finished validation.
# Starting training epoch 298
# Epoch: 298, MSE 0.00228543 (0.00247437), PSNR 26.41032982 (26.08591477), SSIM 0.76530421 (0.76461310)
# Finished training epoch 298
# Validate: MSE 0.00287646 (0.00245105), PSNR 25.41141891 (26.16882997), SSIM 0.70676994 (0.77224801)
# Finished validation.
# Starting training epoch 299
# Epoch: 299, MSE 0.00263599 (0.00248689), PSNR 25.79056358 (26.06823887), SSIM 0.73591292 (0.76451866)
# Finished training epoch 299
# Validate: MSE 0.00285993 (0.00245079), PSNR 25.43643761 (26.16883299), SSIM 0.70709682 (0.77096675)
# Finished validation.
# Starting training epoch 300
# Epoch: 300, MSE 0.00287806 (0.00247936), PSNR 25.40900040 (26.07724472), SSIM 0.76300895 (0.76450635)
# Finished training epoch 300
# Validate: MSE 0.00287801 (0.00245009), PSNR 25.40906906 (26.17088317), SSIM 0.70889348 (0.77190187)
# Finished validation.
# Starting training epoch 301
# Epoch: 301, MSE 0.00232506 (0.00247926), PSNR 26.33566475 (26.08248912), SSIM 0.77210361 (0.76453083)
# Finished training epoch 301
# Validate: MSE 0.00282158 (0.00244701), PSNR 25.49507332 (26.17524112), SSIM 0.70830733 (0.76997907)
# Finished validation.
# Starting training epoch 302
# Epoch: 302, MSE 0.00277928 (0.00247649), PSNR 25.56066895 (26.08860125), SSIM 0.75266331 (0.76454052)
# Finished training epoch 302
# Validate: MSE 0.00286955 (0.00244673), PSNR 25.42185402 (26.17699232), SSIM 0.70889246 (0.77253453)
# Finished validation.
# Starting training epoch 303
# Epoch: 303, MSE 0.00258071 (0.00247716), PSNR 25.88261414 (26.08691622), SSIM 0.73727924 (0.76478171)
# Finished training epoch 303
# Validate: MSE 0.00285942 (0.00244434), PSNR 25.43721199 (26.18035076), SSIM 0.70943224 (0.77178369)
# Finished validation.
# Starting training epoch 304
# Epoch: 304, MSE 0.00261538 (0.00247003), PSNR 25.82464981 (26.09847048), SSIM 0.74610925 (0.76473509)
# Finished training epoch 304
# Validate: MSE 0.00291359 (0.00245255), PSNR 25.35571098 (26.16724985), SSIM 0.70723504 (0.77199570)
# Finished validation.
# Starting training epoch 305
# Epoch: 305, MSE 0.00241828 (0.00246532), PSNR 26.16493416 (26.10223682), SSIM 0.76160121 (0.76502270)
# Finished training epoch 305
# Validate: MSE 0.00286022 (0.00244375), PSNR 25.43600464 (26.18122583), SSIM 0.70717150 (0.77158136)
# Finished validation.
# Starting training epoch 306
# Epoch: 306, MSE 0.00265155 (0.00246602), PSNR 25.76500511 (26.10353819), SSIM 0.77525216 (0.76501751)
# Finished training epoch 306
# Validate: MSE 0.00286344 (0.00244677), PSNR 25.43112373 (26.17642752), SSIM 0.70754284 (0.77154915)
# Finished validation.
# Starting training epoch 307
# Epoch: 307, MSE 0.00280374 (0.00247238), PSNR 25.52262688 (26.09517480), SSIM 0.74467784 (0.76488358)
# Finished training epoch 307
# Validate: MSE 0.00285339 (0.00244525), PSNR 25.44638824 (26.17895345), SSIM 0.70968509 (0.77151279)
# Finished validation.
# Starting training epoch 308
# Epoch: 308, MSE 0.00271833 (0.00247105), PSNR 25.65697479 (26.09684045), SSIM 0.75012738 (0.76463615)
# Finished training epoch 308
# Validate: MSE 0.00286568 (0.00244870), PSNR 25.42771530 (26.17352604), SSIM 0.70697880 (0.77152600)
# Finished validation.
# Starting training epoch 309
# Epoch: 309, MSE 0.00222747 (0.00247344), PSNR 26.52188110 (26.08779152), SSIM 0.77909213 (0.76485642)
# Finished training epoch 309
# Validate: MSE 0.00288584 (0.00244469), PSNR 25.39727402 (26.17961196), SSIM 0.70791352 (0.77089447)
# Finished validation.
# Starting training epoch 310
# Epoch: 310, MSE 0.00286328 (0.00246879), PSNR 25.43136406 (26.09942743), SSIM 0.74377167 (0.76504872)
# Finished training epoch 310
# Validate: MSE 0.00288155 (0.00244898), PSNR 25.40373611 (26.17194717), SSIM 0.70693791 (0.77049794)
# Finished validation.
# Starting training epoch 311
# Epoch: 311, MSE 0.00282934 (0.00247484), PSNR 25.48315048 (26.08893822), SSIM 0.76135051 (0.76464628)
# Finished training epoch 311
# Validate: MSE 0.00287637 (0.00244916), PSNR 25.41155624 (26.17262719), SSIM 0.70572889 (0.77172356)
# Finished validation.
# Starting training epoch 312
# Epoch: 312, MSE 0.00267630 (0.00247133), PSNR 25.72465897 (26.09500221), SSIM 0.76128781 (0.76493637)
# Finished training epoch 312
# Validate: MSE 0.00285166 (0.00244428), PSNR 25.44901848 (26.18075190), SSIM 0.70741093 (0.77156452)
# Finished validation.
# Starting training epoch 313
# Epoch: 313, MSE 0.00267422 (0.00247257), PSNR 25.72801971 (26.09158361), SSIM 0.75102645 (0.76471334)
# Finished training epoch 313
# Validate: MSE 0.00287513 (0.00244310), PSNR 25.41343307 (26.18294438), SSIM 0.70835745 (0.77229974)
# Finished validation.
# Starting training epoch 314
# Epoch: 314, MSE 0.00223244 (0.00247616), PSNR 26.51219559 (26.08546123), SSIM 0.76856732 (0.76477891)
# Finished training epoch 314
# Validate: MSE 0.00287261 (0.00244552), PSNR 25.41723251 (26.17897260), SSIM 0.70754111 (0.77191601)
# Finished validation.
# Starting training epoch 315
# Epoch: 315, MSE 0.00212281 (0.00246115), PSNR 26.73088837 (26.11267412), SSIM 0.78573638 (0.76534149)
# Finished training epoch 315
# Validate: MSE 0.00286277 (0.00244224), PSNR 25.43213081 (26.18443909), SSIM 0.70589364 (0.77127937)
# Finished validation.
# Starting training epoch 316
# Epoch: 316, MSE 0.00275475 (0.00246754), PSNR 25.59917068 (26.10108313), SSIM 0.74694836 (0.76500722)
# Finished training epoch 316
# Validate: MSE 0.00287879 (0.00244626), PSNR 25.40790367 (26.17710255), SSIM 0.70772743 (0.77088730)
# Finished validation.
# Starting training epoch 317
# Epoch: 317, MSE 0.00189213 (0.00247337), PSNR 27.23049164 (26.08948258), SSIM 0.77007776 (0.76482413)
# Finished training epoch 317
# Validate: MSE 0.00286552 (0.00244664), PSNR 25.42796898 (26.17666729), SSIM 0.70506608 (0.77171306)
# Finished validation.
# Starting training epoch 318
# Epoch: 318, MSE 0.00296489 (0.00247113), PSNR 25.27991486 (26.09240198), SSIM 0.74633598 (0.76475150)
# Finished training epoch 318
# Validate: MSE 0.00286673 (0.00244305), PSNR 25.42613411 (26.18391587), SSIM 0.71002150 (0.77335605)
# Finished validation.
# Starting training epoch 319
# Epoch: 319, MSE 0.00271175 (0.00247400), PSNR 25.66750145 (26.08810765), SSIM 0.75327653 (0.76485931)
# Finished training epoch 319
# Validate: MSE 0.00286540 (0.00244208), PSNR 25.42814445 (26.18456941), SSIM 0.70785415 (0.77148359)
# Finished validation.
# Starting training epoch 320
# Epoch: 320, MSE 0.00244187 (0.00246637), PSNR 26.12277985 (26.10177847), SSIM 0.76399088 (0.76497512)
# Finished training epoch 320
# Validate: MSE 0.00289767 (0.00244942), PSNR 25.37950897 (26.17247623), SSIM 0.70851582 (0.77132520)
# Finished validation.
# Starting training epoch 321
# Epoch: 321, MSE 0.00281792 (0.00247025), PSNR 25.50071526 (26.09430632), SSIM 0.74071538 (0.76491854)
# Finished training epoch 321
# Validate: MSE 0.00287750 (0.00244373), PSNR 25.40984535 (26.18109772), SSIM 0.70794642 (0.77145065)
# Finished validation.
# Starting training epoch 322
# Epoch: 322, MSE 0.00242455 (0.00247347), PSNR 26.15369225 (26.09049528), SSIM 0.75787956 (0.76495792)
# Finished training epoch 322
# Validate: MSE 0.00285957 (0.00244033), PSNR 25.43699455 (26.18760605), SSIM 0.70682663 (0.77143477)
# Finished validation.
# Starting training epoch 323
# Epoch: 323, MSE 0.00265831 (0.00246086), PSNR 25.75394440 (26.11052790), SSIM 0.77502924 (0.76514875)
# Finished training epoch 323
# Validate: MSE 0.00287720 (0.00243943), PSNR 25.41029358 (26.18941548), SSIM 0.70633572 (0.77240975)
# Finished validation.
# Starting training epoch 324
# Epoch: 324, MSE 0.00263181 (0.00247366), PSNR 25.79745483 (26.08874863), SSIM 0.75846887 (0.76484857)
# Finished training epoch 324
# Validate: MSE 0.00285801 (0.00244344), PSNR 25.43936157 (26.18306921), SSIM 0.70940846 (0.77307420)
# Finished validation.
# Starting training epoch 325
# Epoch: 325, MSE 0.00249868 (0.00247471), PSNR 26.02288437 (26.08995890), SSIM 0.77859765 (0.76492523)
# Finished training epoch 325
# Validate: MSE 0.00286483 (0.00244232), PSNR 25.42900848 (26.18372606), SSIM 0.70757759 (0.77151298)
# Finished validation.
# Starting training epoch 326
# Epoch: 326, MSE 0.00267827 (0.00246562), PSNR 25.72146225 (26.10516289), SSIM 0.75603139 (0.76532675)
# Finished training epoch 326
# Validate: MSE 0.00286913 (0.00243947), PSNR 25.42250252 (26.18922840), SSIM 0.70813078 (0.77167055)
# Finished validation.
# Starting training epoch 327
# Epoch: 327, MSE 0.00240725 (0.00246189), PSNR 26.18478394 (26.11224693), SSIM 0.77298033 (0.76527864)
# Finished training epoch 327
# Validate: MSE 0.00283404 (0.00243727), PSNR 25.47594643 (26.19262316), SSIM 0.70950848 (0.77212022)
# Finished validation.
# Starting training epoch 328
# Epoch: 328, MSE 0.00252476 (0.00247469), PSNR 25.97778893 (26.08994542), SSIM 0.74957085 (0.76485805)
# Finished training epoch 328
# Validate: MSE 0.00287016 (0.00244297), PSNR 25.42093849 (26.18313095), SSIM 0.70654476 (0.77162945)
# Finished validation.
# Starting training epoch 329
# Epoch: 329, MSE 0.00254389 (0.00247517), PSNR 25.94500732 (26.08831097), SSIM 0.77260065 (0.76494762)
# Finished training epoch 329
# Validate: MSE 0.00286892 (0.00243800), PSNR 25.42280960 (26.19263970), SSIM 0.70814735 (0.77320516)
# Finished validation.
# Starting training epoch 330
# Epoch: 330, MSE 0.00324239 (0.00246488), PSNR 24.89134789 (26.10752366), SSIM 0.74200922 (0.76518842)
# Finished training epoch 330
# Validate: MSE 0.00286822 (0.00244126), PSNR 25.42387772 (26.18702681), SSIM 0.70821428 (0.77291961)
# Finished validation.
# Starting training epoch 331
# Epoch: 331, MSE 0.00285189 (0.00246353), PSNR 25.44867897 (26.10624794), SSIM 0.74196482 (0.76524036)
# Finished training epoch 331
# Validate: MSE 0.00285893 (0.00244271), PSNR 25.43796730 (26.18336628), SSIM 0.70664990 (0.77116234)
# Finished validation.
# Starting training epoch 332
# Epoch: 332, MSE 0.00229741 (0.00246831), PSNR 26.38761520 (26.10043944), SSIM 0.78571355 (0.76485256)
# Finished training epoch 332
# Validate: MSE 0.00283187 (0.00243793), PSNR 25.47926140 (26.19196513), SSIM 0.70688462 (0.77185252)
# Finished validation.
# Starting training epoch 333

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
