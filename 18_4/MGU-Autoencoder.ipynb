# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-91765923f25bc50b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-91765923f25bc50b");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 16
p1 = .5

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(self.convtrans3(x), scale_factor=scale_factor)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             160
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#             Conv2d-3           [-1, 32, 16, 16]           4,640
#        BatchNorm2d-4           [-1, 32, 16, 16]              64
#    ConvTranspose2d-5             [-1, 16, 8, 8]           4,624
#        BatchNorm2d-6             [-1, 16, 8, 8]              32
#    ConvTranspose2d-7            [-1, 8, 16, 16]           1,160
#        BatchNorm2d-8            [-1, 8, 16, 16]              16
#    ConvTranspose2d-9            [-1, 2, 16, 16]             146
# ================================================================
# Total params: 10,874
# Trainable params: 10,874
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.43
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.47
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00324499 (0.02247040), PSNR 24.88785934 (22.00917702), SSIM 0.76118404 (0.48987466)
# Finished training epoch 0
# Validate: MSE 0.00315523 (0.00281371), PSNR 25.00968361 (25.59363546), SSIM 0.68125319 (0.75447644)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00286631 (0.00275769), PSNR 25.42676544 (25.61855511), SSIM 0.75725430 (0.76679320)
# Finished training epoch 1
# Validate: MSE 0.00325461 (0.00274212), PSNR 24.87501335 (25.69207182), SSIM 0.70379198 (0.77233774)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00283083 (0.00275308), PSNR 25.48086166 (25.62235686), SSIM 0.75429595 (0.77038410)
# Finished training epoch 2
# Validate: MSE 0.00296922 (0.00275512), PSNR 25.27357101 (25.69056369), SSIM 0.69919163 (0.76793322)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00328439 (0.00274455), PSNR 24.83545303 (25.64275133), SSIM 0.74957931 (0.76993772)
# Finished training epoch 3
# Validate: MSE 0.00308958 (0.00269565), PSNR 25.10100937 (25.77000632), SSIM 0.70233846 (0.76984407)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00231454 (0.00273001), PSNR 26.35534668 (25.65988458), SSIM 0.78625095 (0.76970427)
# Finished training epoch 4
# Validate: MSE 0.00322658 (0.00272975), PSNR 24.91258049 (25.71341377), SSIM 0.70407212 (0.77287535)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00267564 (0.00271738), PSNR 25.72571373 (25.67968964), SSIM 0.75605005 (0.76944585)
# Finished training epoch 5
# Validate: MSE 0.00327208 (0.00274226), PSNR 24.85176086 (25.69122622), SSIM 0.70304483 (0.77246894)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00226893 (0.00269475), PSNR 26.44178581 (25.71588871), SSIM 0.78630143 (0.76849944)
# Finished training epoch 6
# Validate: MSE 0.00312033 (0.00267780), PSNR 25.05798912 (25.79286676), SSIM 0.69781351 (0.76946636)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00267156 (0.00266417), PSNR 25.73234558 (25.76533881), SSIM 0.75023156 (0.76666800)
# Finished training epoch 7
# Validate: MSE 0.00290962 (0.00266512), PSNR 25.36163330 (25.81956433), SSIM 0.69392639 (0.76212648)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00269373 (0.00262590), PSNR 25.69646454 (25.82902263), SSIM 0.74546069 (0.76566995)
# Finished training epoch 8
# Validate: MSE 0.00318962 (0.00271041), PSNR 24.96261406 (25.73651674), SSIM 0.68571079 (0.75576654)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00266450 (0.00260905), PSNR 25.74384880 (25.85813753), SSIM 0.77113044 (0.76525925)
# Finished training epoch 9
# Validate: MSE 0.00293000 (0.00271559), PSNR 25.33131599 (25.75867117), SSIM 0.69964224 (0.76652307)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00228796 (0.00257955), PSNR 26.40552330 (25.90524138), SSIM 0.77824169 (0.76565428)
# Finished training epoch 10
# Validate: MSE 0.00310981 (0.00263513), PSNR 25.07265663 (25.85822011), SSIM 0.70225829 (0.77014001)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00229156 (0.00257745), PSNR 26.39868736 (25.90924891), SSIM 0.76863986 (0.76562907)
# Finished training epoch 11
# Validate: MSE 0.00294487 (0.00280765), PSNR 25.30933189 (25.62461300), SSIM 0.69654858 (0.76034232)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00240284 (0.00257098), PSNR 26.19275665 (25.92037642), SSIM 0.77775890 (0.76577783)
# Finished training epoch 12
# Validate: MSE 0.00293904 (0.00251573), PSNR 25.31793785 (26.06031410), SSIM 0.70314062 (0.76832963)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00251142 (0.00254952), PSNR 26.00079727 (25.95551901), SSIM 0.77494669 (0.76652168)
# Finished training epoch 13
# Validate: MSE 0.00294954 (0.00271092), PSNR 25.30245781 (25.76887854), SSIM 0.70601875 (0.76999165)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00265252 (0.00253956), PSNR 25.76341057 (25.97506419), SSIM 0.75062543 (0.76657488)
# Finished training epoch 14
# Validate: MSE 0.00295132 (0.00254208), PSNR 25.29982758 (26.01297291), SSIM 0.69365972 (0.76259100)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00226373 (0.00253618), PSNR 26.45174980 (25.98050846), SSIM 0.76822257 (0.76685557)
# Finished training epoch 15
# Validate: MSE 0.00306556 (0.00261440), PSNR 25.13490295 (25.89828689), SSIM 0.69575512 (0.76540101)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00261217 (0.00252591), PSNR 25.82998085 (25.99759630), SSIM 0.74698603 (0.76718891)
# Finished training epoch 16
# Validate: MSE 0.00283126 (0.00284626), PSNR 25.48019600 (25.57161624), SSIM 0.69504607 (0.75718549)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00293549 (0.00252278), PSNR 25.32319260 (26.00184635), SSIM 0.74672854 (0.76769667)
# Finished training epoch 17
# Validate: MSE 0.00304054 (0.00270332), PSNR 25.17049408 (25.77216483), SSIM 0.70234072 (0.76539855)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00282604 (0.00251215), PSNR 25.48821449 (26.02043349), SSIM 0.76711082 (0.76814709)
# Finished training epoch 18
# Validate: MSE 0.00281030 (0.00282906), PSNR 25.51247597 (25.59176554), SSIM 0.70124924 (0.76046280)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00280827 (0.00250907), PSNR 25.51561546 (26.02518905), SSIM 0.77278852 (0.76844624)
# Finished training epoch 19
# Validate: MSE 0.00320106 (0.00277123), PSNR 24.94705391 (25.65163516), SSIM 0.70219195 (0.76498162)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00212407 (0.00250811), PSNR 26.72831535 (26.02862378), SSIM 0.77907526 (0.76873065)
# Finished training epoch 20
# Validate: MSE 0.00289891 (0.00259706), PSNR 25.37764931 (25.93769311), SSIM 0.70112646 (0.76570993)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00219591 (0.00249605), PSNR 26.58385468 (26.04662750), SSIM 0.76772267 (0.76905674)
# Finished training epoch 21
# Validate: MSE 0.00288268 (0.00248404), PSNR 25.40204048 (26.10848777), SSIM 0.70521402 (0.76666593)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00255007 (0.00250134), PSNR 25.93447495 (26.04080440), SSIM 0.75239027 (0.76931459)
# Finished training epoch 22
# Validate: MSE 0.00304898 (0.00253761), PSNR 25.15844917 (26.02458460), SSIM 0.70643026 (0.77445400)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00339051 (0.00249914), PSNR 24.69734764 (26.04674232), SSIM 0.73674631 (0.76916150)
# Finished training epoch 23
# Validate: MSE 0.00290639 (0.00262072), PSNR 25.36646461 (25.90249347), SSIM 0.70605516 (0.77063402)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00236162 (0.00249727), PSNR 26.26790047 (26.04820969), SSIM 0.76745325 (0.76934567)
# Finished training epoch 24
# Validate: MSE 0.00291034 (0.00253718), PSNR 25.36055565 (26.03279608), SSIM 0.70645922 (0.77109501)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00231433 (0.00248735), PSNR 26.35574532 (26.06280916), SSIM 0.76739657 (0.76937195)
# Finished training epoch 25
# Validate: MSE 0.00289315 (0.00263596), PSNR 25.38628960 (25.87688071), SSIM 0.70100558 (0.76866666)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00228701 (0.00248727), PSNR 26.40731239 (26.06454681), SSIM 0.79147518 (0.76929025)
# Finished training epoch 26
# Validate: MSE 0.00328076 (0.00320933), PSNR 24.84025002 (25.02582514), SSIM 0.69887030 (0.75274830)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00235085 (0.00248707), PSNR 26.28775024 (26.06487476), SSIM 0.75739092 (0.76938631)
# Finished training epoch 27
# Validate: MSE 0.00292340 (0.00258549), PSNR 25.34111404 (25.95278450), SSIM 0.70301437 (0.76855295)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00233009 (0.00248604), PSNR 26.32627106 (26.06525998), SSIM 0.77268916 (0.76939785)
# Finished training epoch 28
# Validate: MSE 0.00306972 (0.00276169), PSNR 25.12900734 (25.66571186), SSIM 0.70492464 (0.76206613)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00227442 (0.00247988), PSNR 26.43128395 (26.07595924), SSIM 0.80062258 (0.76948353)
# Finished training epoch 29
# Validate: MSE 0.00285195 (0.00253488), PSNR 25.44858170 (26.02623055), SSIM 0.69981086 (0.76431646)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00294697 (0.00248508), PSNR 25.30624390 (26.07054819), SSIM 0.73658335 (0.76945938)
# Finished training epoch 30
# Validate: MSE 0.00281049 (0.00259950), PSNR 25.51217079 (25.93610497), SSIM 0.70365548 (0.76659014)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00251723 (0.00248915), PSNR 25.99076271 (26.06050119), SSIM 0.75417423 (0.76909924)
# Finished training epoch 31
# Validate: MSE 0.00295342 (0.00266221), PSNR 25.29673958 (25.84074959), SSIM 0.70152110 (0.76592611)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00200542 (0.00247742), PSNR 26.97794151 (26.08186983), SSIM 0.79134166 (0.76899952)
# Finished training epoch 32
# Validate: MSE 0.00282077 (0.00255173), PSNR 25.49631500 (26.00336532), SSIM 0.70364809 (0.76932644)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00214818 (0.00247885), PSNR 26.67929077 (26.07904555), SSIM 0.78088796 (0.76933719)
# Finished training epoch 33
# Validate: MSE 0.00313887 (0.00267479), PSNR 25.03226280 (25.79798436), SSIM 0.70512396 (0.76518802)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00252206 (0.00248203), PSNR 25.98244286 (26.07424239), SSIM 0.77589089 (0.76902877)
# Finished training epoch 34
# Validate: MSE 0.00285558 (0.00280881), PSNR 25.44305801 (25.63336732), SSIM 0.70686519 (0.76494498)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00239486 (0.00248094), PSNR 26.20720291 (26.07642804), SSIM 0.76119626 (0.76892876)
# Finished training epoch 35
# Validate: MSE 0.00289349 (0.00247538), PSNR 25.38577271 (26.13452095), SSIM 0.70521247 (0.77191649)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00212104 (0.00247526), PSNR 26.73450279 (26.08953405), SSIM 0.76693642 (0.76935544)
# Finished training epoch 36
# Validate: MSE 0.00293895 (0.00247797), PSNR 25.31807327 (26.12690511), SSIM 0.70494783 (0.77211021)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00229617 (0.00247243), PSNR 26.38996696 (26.09120948), SSIM 0.77505296 (0.76931063)
# Finished training epoch 37
# Validate: MSE 0.00292550 (0.00260111), PSNR 25.33799934 (25.91531158), SSIM 0.70163500 (0.76547656)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00238833 (0.00247277), PSNR 26.21904755 (26.08958468), SSIM 0.75980091 (0.76915499)
# Finished training epoch 38
# Validate: MSE 0.00304255 (0.00257028), PSNR 25.16762352 (25.97005321), SSIM 0.70657098 (0.77330621)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00239655 (0.00247266), PSNR 26.20413589 (26.09182602), SSIM 0.77182579 (0.76920056)
# Finished training epoch 39
# Validate: MSE 0.00276921 (0.00261251), PSNR 25.57643509 (25.91403814), SSIM 0.69831824 (0.76618695)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00258861 (0.00247880), PSNR 25.86932564 (26.08003693), SSIM 0.77004349 (0.76900299)
# Finished training epoch 40
# Validate: MSE 0.00295838 (0.00247218), PSNR 25.28945732 (26.13194531), SSIM 0.69938695 (0.76681346)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00180803 (0.00248074), PSNR 27.42794037 (26.07696871), SSIM 0.78249639 (0.76901218)
# Finished training epoch 41
# Validate: MSE 0.00290710 (0.00250491), PSNR 25.36539459 (26.07729037), SSIM 0.70422626 (0.76783735)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00280739 (0.00246908), PSNR 25.51697159 (26.09732091), SSIM 0.75621164 (0.76876472)
# Finished training epoch 42
# Validate: MSE 0.00275553 (0.00249035), PSNR 25.59794617 (26.10496345), SSIM 0.70520604 (0.76554254)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00209625 (0.00246586), PSNR 26.78557205 (26.10095275), SSIM 0.77921671 (0.76908203)
# Finished training epoch 43
# Validate: MSE 0.00305804 (0.00300174), PSNR 25.14557076 (25.30312583), SSIM 0.70097256 (0.75503587)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00208269 (0.00247036), PSNR 26.81375313 (26.09437309), SSIM 0.80082625 (0.76915110)
# Finished training epoch 44
# Validate: MSE 0.00292557 (0.00247406), PSNR 25.33790207 (26.13218386), SSIM 0.70484304 (0.77280538)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00238023 (0.00246903), PSNR 26.23381805 (26.10007378), SSIM 0.77946597 (0.76899987)
# Finished training epoch 45
# Validate: MSE 0.00289025 (0.00253720), PSNR 25.39063835 (26.03193210), SSIM 0.70386380 (0.76765232)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00256984 (0.00247308), PSNR 25.90093994 (26.08776655), SSIM 0.76459128 (0.76895307)
# Finished training epoch 46
# Validate: MSE 0.00295509 (0.00258643), PSNR 25.29429054 (25.94099171), SSIM 0.70574701 (0.76704047)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00277418 (0.00246731), PSNR 25.56865120 (26.09911411), SSIM 0.74633425 (0.76906315)
# Finished training epoch 47
# Validate: MSE 0.00283335 (0.00249833), PSNR 25.47698975 (26.08133779), SSIM 0.70543104 (0.76266460)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00214774 (0.00247137), PSNR 26.68018532 (26.09508632), SSIM 0.75276357 (0.76896351)
# Finished training epoch 48
# Validate: MSE 0.00312165 (0.00270590), PSNR 25.05615807 (25.75872306), SSIM 0.70195544 (0.76638344)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00255119 (0.00246659), PSNR 25.93256950 (26.10007409), SSIM 0.74541849 (0.76898344)
# Finished training epoch 49
# Validate: MSE 0.00332859 (0.00330401), PSNR 24.77739716 (24.90308065), SSIM 0.69588190 (0.74725153)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00240776 (0.00246785), PSNR 26.18386459 (26.09852994), SSIM 0.80166167 (0.76905061)
# Finished training epoch 50
# Validate: MSE 0.00290256 (0.00271556), PSNR 25.37218094 (25.75671260), SSIM 0.70298201 (0.76857435)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00242642 (0.00246159), PSNR 26.15033913 (26.10891595), SSIM 0.76770639 (0.76922461)
# Finished training epoch 51
# Validate: MSE 0.00315246 (0.00273978), PSNR 25.01350212 (25.70468205), SSIM 0.70639437 (0.76669292)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00166643 (0.00246081), PSNR 27.78212929 (26.11140532), SSIM 0.80820835 (0.76903877)
# Finished training epoch 52
# Validate: MSE 0.00283407 (0.00248509), PSNR 25.47589684 (26.11253539), SSIM 0.70397794 (0.76856370)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00277922 (0.00246438), PSNR 25.56077194 (26.10395700), SSIM 0.77001870 (0.76905431)
# Finished training epoch 53
# Validate: MSE 0.00290168 (0.00250479), PSNR 25.37349892 (26.07776530), SSIM 0.70327842 (0.76712036)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00294857 (0.00246625), PSNR 25.30389023 (26.10167208), SSIM 0.74512637 (0.76893881)
# Finished training epoch 54
# Validate: MSE 0.00293593 (0.00247111), PSNR 25.32253647 (26.13637490), SSIM 0.70012438 (0.76678284)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00246417 (0.00246318), PSNR 26.08329010 (26.10718401), SSIM 0.76712042 (0.76887683)
# Finished training epoch 55
# Validate: MSE 0.00295791 (0.00263993), PSNR 25.29014397 (25.85782522), SSIM 0.70354718 (0.76403791)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00198326 (0.00246336), PSNR 27.02620888 (26.10916660), SSIM 0.77412063 (0.76888045)
# Finished training epoch 56
# Validate: MSE 0.00282890 (0.00243846), PSNR 25.48382568 (26.19366079), SSIM 0.70737141 (0.77009751)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00214615 (0.00246401), PSNR 26.68338966 (26.10510186), SSIM 0.77182400 (0.76870674)
# Finished training epoch 57
# Validate: MSE 0.00306848 (0.00270843), PSNR 25.13076210 (25.75192816), SSIM 0.70241845 (0.76464824)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00224576 (0.00246827), PSNR 26.48635674 (26.09784438), SSIM 0.79588234 (0.76903588)
# Finished training epoch 58
# Validate: MSE 0.00289275 (0.00255225), PSNR 25.38688850 (26.00822405), SSIM 0.70722544 (0.77198578)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00237241 (0.00246122), PSNR 26.24810600 (26.11318288), SSIM 0.77370155 (0.76901467)
# Finished training epoch 59
# Validate: MSE 0.00281883 (0.00307013), PSNR 25.49931526 (25.27296526), SSIM 0.70355594 (0.75437154)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00246093 (0.00245765), PSNR 26.08901024 (26.11895586), SSIM 0.76849401 (0.76881814)
# Finished training epoch 60
# Validate: MSE 0.00291449 (0.00264189), PSNR 25.35436821 (25.85310144), SSIM 0.70038819 (0.76319774)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00268208 (0.00246221), PSNR 25.71527481 (26.10850824), SSIM 0.76608425 (0.76874647)
# Finished training epoch 61
# Validate: MSE 0.00288888 (0.00252016), PSNR 25.39271164 (26.06325070), SSIM 0.70755333 (0.77127566)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00234440 (0.00246169), PSNR 26.29968834 (26.10998519), SSIM 0.78040391 (0.76897149)
# Finished training epoch 62
# Validate: MSE 0.00280666 (0.00248771), PSNR 25.51810074 (26.10070135), SSIM 0.70790541 (0.76717481)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00301629 (0.00246043), PSNR 25.20526314 (26.11102209), SSIM 0.73968869 (0.76913993)
# Finished training epoch 63
# Validate: MSE 0.00300014 (0.00250918), PSNR 25.22859001 (26.07663271), SSIM 0.70505589 (0.76961558)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00240248 (0.00246497), PSNR 26.19340324 (26.10336800), SSIM 0.76651335 (0.76895399)
# Finished training epoch 64
# Validate: MSE 0.00278623 (0.00244009), PSNR 25.54983711 (26.18432217), SSIM 0.70340103 (0.76326574)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00257388 (0.00245704), PSNR 25.89411354 (26.11936256), SSIM 0.76157278 (0.76894584)
# Finished training epoch 65
# Validate: MSE 0.00300412 (0.00260815), PSNR 25.22282219 (25.91136142), SSIM 0.70880485 (0.76857982)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00261785 (0.00245882), PSNR 25.82054329 (26.11228391), SSIM 0.77820206 (0.76922139)
# Finished training epoch 66
# Validate: MSE 0.00283257 (0.00242690), PSNR 25.47819328 (26.21371604), SSIM 0.70252299 (0.76927912)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00237175 (0.00245826), PSNR 26.24931908 (26.11875339), SSIM 0.76192582 (0.76892824)
# Finished training epoch 67
# Validate: MSE 0.00291511 (0.00246583), PSNR 25.35344315 (26.14223494), SSIM 0.70368403 (0.76502930)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00256788 (0.00246133), PSNR 25.90424538 (26.11063258), SSIM 0.75718510 (0.76895637)
# Finished training epoch 68
# Validate: MSE 0.00290379 (0.00251881), PSNR 25.37034607 (26.06047441), SSIM 0.70606983 (0.76494916)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00218432 (0.00245905), PSNR 26.60682869 (26.11621867), SSIM 0.76740056 (0.76912432)
# Finished training epoch 69
# Validate: MSE 0.00275903 (0.00282698), PSNR 25.59244156 (25.59529166), SSIM 0.70449913 (0.76399724)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00240704 (0.00246096), PSNR 26.18515968 (26.11293423), SSIM 0.76525170 (0.76896635)
# Finished training epoch 70
# Validate: MSE 0.00279558 (0.00248690), PSNR 25.53528023 (26.11556177), SSIM 0.70688343 (0.76618563)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00188121 (0.00245387), PSNR 27.25562477 (26.12439816), SSIM 0.79438591 (0.76902953)
# Finished training epoch 71
# Validate: MSE 0.00294422 (0.00248623), PSNR 25.31028938 (26.11193242), SSIM 0.70634389 (0.77374914)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00257096 (0.00245834), PSNR 25.89904022 (26.11713027), SSIM 0.77320111 (0.76878478)
# Finished training epoch 72
# Validate: MSE 0.00278878 (0.00282398), PSNR 25.54585648 (25.58709290), SSIM 0.69847029 (0.75814868)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00288768 (0.00246182), PSNR 25.39451218 (26.10982669), SSIM 0.78361923 (0.76889539)
# Finished training epoch 73
# Validate: MSE 0.00299075 (0.00264557), PSNR 25.24219513 (25.84928053), SSIM 0.70188445 (0.76347833)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00217509 (0.00245696), PSNR 26.62522316 (26.11868486), SSIM 0.76694769 (0.76888025)
# Finished training epoch 74
# Validate: MSE 0.00289557 (0.00243413), PSNR 25.38266182 (26.20273889), SSIM 0.70359915 (0.77213934)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00241902 (0.00245591), PSNR 26.16360474 (26.12153469), SSIM 0.75661659 (0.76875716)
# Finished training epoch 75
# Validate: MSE 0.00289695 (0.00245528), PSNR 25.38058281 (26.16554702), SSIM 0.69950461 (0.76620198)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00221916 (0.00245473), PSNR 26.53810310 (26.12171365), SSIM 0.77150023 (0.76871437)
# Finished training epoch 76
# Validate: MSE 0.00281144 (0.00245536), PSNR 25.51070976 (26.15562280), SSIM 0.70470351 (0.76480044)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00263974 (0.00245717), PSNR 25.78437996 (26.11712874), SSIM 0.78468454 (0.76867321)
# Finished training epoch 77
# Validate: MSE 0.00288742 (0.00252941), PSNR 25.39490509 (26.03928759), SSIM 0.70503050 (0.76694662)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00226318 (0.00245246), PSNR 26.45280266 (26.12753853), SSIM 0.76245832 (0.76896948)
# Finished training epoch 78
# Validate: MSE 0.00286586 (0.00259913), PSNR 25.42745209 (25.93255746), SSIM 0.70175552 (0.76261440)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00274248 (0.00245787), PSNR 25.61856270 (26.11560209), SSIM 0.75652528 (0.76887008)
# Finished training epoch 79
# Validate: MSE 0.00286607 (0.00243750), PSNR 25.42712402 (26.19784065), SSIM 0.70785952 (0.77070700)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00245407 (0.00245503), PSNR 26.10112572 (26.12325866), SSIM 0.75136602 (0.76893034)
# Finished training epoch 80
# Validate: MSE 0.00307899 (0.00250053), PSNR 25.11592102 (26.08906340), SSIM 0.70195591 (0.76922481)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00225527 (0.00244956), PSNR 26.46802330 (26.12865506), SSIM 0.77936900 (0.76896944)
# Finished training epoch 81
# Validate: MSE 0.00271353 (0.00270138), PSNR 25.66465950 (25.78092998), SSIM 0.70681173 (0.76146950)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00263477 (0.00244820), PSNR 25.79257965 (26.13285717), SSIM 0.73957390 (0.76908439)
# Finished training epoch 82
# Validate: MSE 0.00279845 (0.00254807), PSNR 25.53081703 (26.00235470), SSIM 0.70161128 (0.76363297)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00249165 (0.00244922), PSNR 26.03513336 (26.13269343), SSIM 0.73668993 (0.76886195)
# Finished training epoch 83
# Validate: MSE 0.00286523 (0.00242426), PSNR 25.42839622 (26.21634737), SSIM 0.70479381 (0.76846708)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00267468 (0.00244885), PSNR 25.72728157 (26.13496070), SSIM 0.75509465 (0.76894545)
# Finished training epoch 84
# Validate: MSE 0.00273414 (0.00246103), PSNR 25.63179016 (26.14933716), SSIM 0.70695633 (0.76653815)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00269644 (0.00245353), PSNR 25.69209480 (26.12303555), SSIM 0.75521642 (0.76887022)
# Finished training epoch 85
# Validate: MSE 0.00270097 (0.00287570), PSNR 25.68480682 (25.53854760), SSIM 0.70740211 (0.75727789)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00252129 (0.00244657), PSNR 25.98376465 (26.13670563), SSIM 0.77857983 (0.76894627)
# Finished training epoch 86
# Validate: MSE 0.00299214 (0.00247345), PSNR 25.24017906 (26.13536297), SSIM 0.70599484 (0.77056590)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00238674 (0.00244775), PSNR 26.22194862 (26.13413298), SSIM 0.76756489 (0.76879239)
# Finished training epoch 87
# Validate: MSE 0.00275471 (0.00256613), PSNR 25.59923553 (25.98669908), SSIM 0.70489097 (0.76988750)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00288290 (0.00244851), PSNR 25.40169716 (26.13527059), SSIM 0.74597216 (0.76906299)
# Finished training epoch 88
# Validate: MSE 0.00286407 (0.00250784), PSNR 25.43017006 (26.07585038), SSIM 0.70907700 (0.76751295)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00183823 (0.00244786), PSNR 27.35600662 (26.13229378), SSIM 0.78696454 (0.76870494)
# Finished training epoch 89
# Validate: MSE 0.00287669 (0.00244667), PSNR 25.41106987 (26.17999292), SSIM 0.70431417 (0.76739057)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00218453 (0.00245310), PSNR 26.60640907 (26.12506835), SSIM 0.77657664 (0.76872848)
# Finished training epoch 90
# Validate: MSE 0.00282903 (0.00241733), PSNR 25.48362923 (26.22676790), SSIM 0.70401442 (0.76712889)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00197978 (0.00244775), PSNR 27.03383636 (26.13396134), SSIM 0.77837789 (0.76863425)
# Finished training epoch 91
# Validate: MSE 0.00275537 (0.00246953), PSNR 25.59819794 (26.14224845), SSIM 0.70585197 (0.76817628)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00220914 (0.00245201), PSNR 26.55777168 (26.12683108), SSIM 0.77758282 (0.76878739)
# Finished training epoch 92
# Validate: MSE 0.00274028 (0.00245954), PSNR 25.62205505 (26.15487900), SSIM 0.70295894 (0.76468492)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00203704 (0.00244794), PSNR 26.90999794 (26.13437261), SSIM 0.77927911 (0.76859682)
# Finished training epoch 93
# Validate: MSE 0.00291213 (0.00248313), PSNR 25.35788536 (26.11771090), SSIM 0.70599055 (0.76902676)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00199499 (0.00244433), PSNR 27.00058746 (26.14247946), SSIM 0.76543820 (0.76909818)
# Finished training epoch 94
# Validate: MSE 0.00306841 (0.00253241), PSNR 25.13087082 (26.03518957), SSIM 0.70357120 (0.76691209)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00218699 (0.00245170), PSNR 26.60153198 (26.12537420), SSIM 0.78507966 (0.76877811)
# Finished training epoch 95
# Validate: MSE 0.00278678 (0.00255690), PSNR 25.54897881 (25.98208332), SSIM 0.70052838 (0.75843881)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00236517 (0.00246297), PSNR 26.26137733 (26.10860524), SSIM 0.79048622 (0.76859536)
# Finished training epoch 96
# Validate: MSE 0.00279510 (0.00243460), PSNR 25.53602982 (26.19713719), SSIM 0.70677739 (0.76914804)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00227691 (0.00244301), PSNR 26.42653084 (26.13993003), SSIM 0.77319813 (0.76878047)
# Finished training epoch 97
# Validate: MSE 0.00282519 (0.00278186), PSNR 25.48951721 (25.66221345), SSIM 0.70316857 (0.76276342)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00225913 (0.00244499), PSNR 26.46058083 (26.13753367), SSIM 0.77522397 (0.76877488)
# Finished training epoch 98
# Validate: MSE 0.00313605 (0.00263410), PSNR 25.03616524 (25.86815125), SSIM 0.70232344 (0.76590571)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00207970 (0.00244820), PSNR 26.81999779 (26.13412661), SSIM 0.76457399 (0.76868057)
# Finished training epoch 99
# Validate: MSE 0.00284611 (0.00285674), PSNR 25.45748520 (25.55665046), SSIM 0.70125246 (0.76187603)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00255656 (0.00245194), PSNR 25.92344475 (26.12680253), SSIM 0.77528721 (0.76850416)
# Finished training epoch 100
# Validate: MSE 0.00284177 (0.00244735), PSNR 25.46411324 (26.17318096), SSIM 0.70151246 (0.77012255)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00251352 (0.00244645), PSNR 25.99717331 (26.13618055), SSIM 0.74938995 (0.76884787)
# Finished training epoch 101
# Validate: MSE 0.00280335 (0.00254806), PSNR 25.52322578 (26.00278714), SSIM 0.70572859 (0.76176518)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00286127 (0.00245020), PSNR 25.43441772 (26.12671209), SSIM 0.76582253 (0.76908607)
# Finished training epoch 102
# Validate: MSE 0.00279421 (0.00261709), PSNR 25.53740120 (25.91010186), SSIM 0.70701683 (0.76567342)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00226166 (0.00244828), PSNR 26.45572090 (26.13189738), SSIM 0.77216113 (0.76868609)
# Finished training epoch 103
# Validate: MSE 0.00290579 (0.00247473), PSNR 25.36736298 (26.13186656), SSIM 0.70217091 (0.76840903)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00242221 (0.00244100), PSNR 26.15788078 (26.14738921), SSIM 0.77901721 (0.76862995)
# Finished training epoch 104
# Validate: MSE 0.00277475 (0.00245662), PSNR 25.56775856 (26.16209811), SSIM 0.70673239 (0.76934496)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00264403 (0.00244409), PSNR 25.77733994 (26.14209916), SSIM 0.77593803 (0.76903294)
# Finished training epoch 105
# Validate: MSE 0.00292509 (0.00246602), PSNR 25.33860779 (26.14730352), SSIM 0.70227045 (0.77242893)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00184935 (0.00245803), PSNR 27.32980156 (26.11598968), SSIM 0.76966798 (0.76871907)
# Finished training epoch 106
# Validate: MSE 0.00279032 (0.00248592), PSNR 25.54345703 (26.11479133), SSIM 0.71127456 (0.76946313)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00247010 (0.00244230), PSNR 26.07284546 (26.14408392), SSIM 0.75218344 (0.76904600)
# Finished training epoch 107
# Validate: MSE 0.00281348 (0.00293350), PSNR 25.50755310 (25.46077122), SSIM 0.70338601 (0.76199756)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00230507 (0.00243955), PSNR 26.37316132 (26.15101408), SSIM 0.80364358 (0.76906929)
# Finished training epoch 108
# Validate: MSE 0.00292729 (0.00248667), PSNR 25.33534241 (26.11112468), SSIM 0.70783949 (0.77497681)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00321298 (0.00244588), PSNR 24.93092346 (26.13811613), SSIM 0.75918496 (0.76894210)
# Finished training epoch 109
# Validate: MSE 0.00294946 (0.00257498), PSNR 25.30257225 (25.96753582), SSIM 0.71045178 (0.76967601)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00215637 (0.00244600), PSNR 26.66276360 (26.13402271), SSIM 0.76906478 (0.76881555)
# Finished training epoch 110
# Validate: MSE 0.00287642 (0.00248738), PSNR 25.41147232 (26.10866307), SSIM 0.70882422 (0.76811508)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00215394 (0.00244418), PSNR 26.66766548 (26.14160012), SSIM 0.77225876 (0.76888598)
# Finished training epoch 111
# Validate: MSE 0.00281443 (0.00243263), PSNR 25.50609779 (26.20192973), SSIM 0.71026564 (0.77105066)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00238523 (0.00244294), PSNR 26.22469139 (26.14231497), SSIM 0.76091224 (0.76895528)
# Finished training epoch 112
# Validate: MSE 0.00301570 (0.00251226), PSNR 25.20612526 (26.06644472), SSIM 0.70503241 (0.76726193)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00292227 (0.00244439), PSNR 25.34279060 (26.14097762), SSIM 0.74149561 (0.76891762)
# Finished training epoch 113
# Validate: MSE 0.00272875 (0.00245167), PSNR 25.64036751 (26.16620872), SSIM 0.70128310 (0.76436738)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00239938 (0.00245344), PSNR 26.19900894 (26.12159771), SSIM 0.76444167 (0.76864671)
# Finished training epoch 114
# Validate: MSE 0.00289093 (0.00253271), PSNR 25.38962746 (26.03391454), SSIM 0.70596808 (0.76626758)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00215305 (0.00245451), PSNR 26.66945076 (26.12105944), SSIM 0.76921976 (0.76860153)
# Finished training epoch 115
# Validate: MSE 0.00271158 (0.00255769), PSNR 25.66778183 (25.99736530), SSIM 0.70983815 (0.76756915)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00331196 (0.00244541), PSNR 24.79914665 (26.13870197), SSIM 0.75902897 (0.76875901)
# Finished training epoch 116
# Validate: MSE 0.00292294 (0.00249635), PSNR 25.34180641 (26.09390880), SSIM 0.70321149 (0.76853428)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00239836 (0.00244540), PSNR 26.20085907 (26.13589939), SSIM 0.78816128 (0.76876970)
# Finished training epoch 117
# Validate: MSE 0.00288909 (0.00264974), PSNR 25.39238548 (25.86432245), SSIM 0.70473516 (0.76902948)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00279401 (0.00244555), PSNR 25.53771591 (26.13816133), SSIM 0.76193076 (0.76876260)
# Finished training epoch 118
# Validate: MSE 0.00273547 (0.00256930), PSNR 25.62968445 (25.97288054), SSIM 0.70966423 (0.76929451)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00208266 (0.00244744), PSNR 26.81381416 (26.13702935), SSIM 0.78132617 (0.76875200)
# Finished training epoch 119
# Validate: MSE 0.00272762 (0.00250069), PSNR 25.64216232 (26.08504911), SSIM 0.70638168 (0.76791786)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00255856 (0.00245102), PSNR 25.92004395 (26.12869942), SSIM 0.77776784 (0.76878599)
# Finished training epoch 120
# Validate: MSE 0.00293536 (0.00260310), PSNR 25.32339096 (25.93602870), SSIM 0.70439088 (0.76756528)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00253300 (0.00244774), PSNR 25.96365166 (26.13455743), SSIM 0.78635013 (0.76838002)
# Finished training epoch 121
# Validate: MSE 0.00289182 (0.00243359), PSNR 25.38828468 (26.20300126), SSIM 0.70578587 (0.77266114)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00260665 (0.00244695), PSNR 25.83916855 (26.13369521), SSIM 0.78541934 (0.76877755)
# Finished training epoch 122
# Validate: MSE 0.00302040 (0.00244943), PSNR 25.19935036 (26.17399901), SSIM 0.70456052 (0.77193059)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00239985 (0.00244813), PSNR 26.19816399 (26.13311751), SSIM 0.77352053 (0.76867654)
# Finished training epoch 123
# Validate: MSE 0.00276181 (0.00250756), PSNR 25.58806610 (26.07512452), SSIM 0.69832909 (0.76593054)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00252349 (0.00244300), PSNR 25.97998238 (26.14280836), SSIM 0.76089656 (0.76855576)
# Finished training epoch 124
# Validate: MSE 0.00281301 (0.00254526), PSNR 25.50829315 (26.02130670), SSIM 0.70594943 (0.77157650)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00231031 (0.00245434), PSNR 26.36330414 (26.12450595), SSIM 0.77961600 (0.76842702)
# Finished training epoch 125
# Validate: MSE 0.00276856 (0.00246431), PSNR 25.57746506 (26.14336769), SSIM 0.70330203 (0.76455315)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00255696 (0.00244715), PSNR 25.92275620 (26.13534563), SSIM 0.75356615 (0.76853933)
# Finished training epoch 126
# Validate: MSE 0.00290455 (0.00244486), PSNR 25.36920929 (26.17917391), SSIM 0.70494992 (0.76640593)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00216418 (0.00244144), PSNR 26.64706993 (26.14794208), SSIM 0.75672483 (0.76873350)
# Finished training epoch 127
# Validate: MSE 0.00273803 (0.00248246), PSNR 25.62562180 (26.11541767), SSIM 0.70720661 (0.76522642)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00279289 (0.00244862), PSNR 25.53945923 (26.13290809), SSIM 0.76255667 (0.76870872)
# Finished training epoch 128
# Validate: MSE 0.00298413 (0.00252267), PSNR 25.25182533 (26.05093944), SSIM 0.70580161 (0.76690670)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00205220 (0.00243931), PSNR 26.87780571 (26.15117582), SSIM 0.78082025 (0.76864459)
# Finished training epoch 129
# Validate: MSE 0.00277885 (0.00247553), PSNR 25.56135559 (26.12888044), SSIM 0.70347124 (0.76631882)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00276844 (0.00244389), PSNR 25.57764626 (26.14029224), SSIM 0.75043952 (0.76868077)
# Finished training epoch 130
# Validate: MSE 0.00285491 (0.00279548), PSNR 25.44407082 (25.64122343), SSIM 0.70086193 (0.76053493)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00293287 (0.00244170), PSNR 25.32706833 (26.14645701), SSIM 0.74070537 (0.76891479)
# Finished training epoch 131
# Validate: MSE 0.00294365 (0.00247361), PSNR 25.31114006 (26.13002082), SSIM 0.69949961 (0.76357621)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00226434 (0.00244883), PSNR 26.45057678 (26.13468607), SSIM 0.78830117 (0.76871479)
# Finished training epoch 132
# Validate: MSE 0.00295344 (0.00245554), PSNR 25.29672241 (26.16458809), SSIM 0.70632792 (0.77323417)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00248582 (0.00244179), PSNR 26.04529953 (26.14414440), SSIM 0.76503772 (0.76881288)
# Finished training epoch 133
# Validate: MSE 0.00289770 (0.00243151), PSNR 25.37946510 (26.20205573), SSIM 0.70849252 (0.76763454)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00262826 (0.00243410), PSNR 25.80331612 (26.15854482), SSIM 0.76753080 (0.76870064)
# Finished training epoch 134
# Validate: MSE 0.00279474 (0.00242388), PSNR 25.53658676 (26.21582985), SSIM 0.70428205 (0.76899089)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00199535 (0.00243637), PSNR 26.99981308 (26.15404064), SSIM 0.77849036 (0.76855443)
# Finished training epoch 135
# Validate: MSE 0.00282280 (0.00257319), PSNR 25.49319267 (25.97683264), SSIM 0.71067154 (0.76846642)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00183718 (0.00244637), PSNR 27.35847282 (26.13722683), SSIM 0.77139699 (0.76865717)
# Finished training epoch 136
# Validate: MSE 0.00278469 (0.00252374), PSNR 25.55222511 (26.05554960), SSIM 0.71075571 (0.76985933)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00309765 (0.00245150), PSNR 25.08967781 (26.12749720), SSIM 0.74629444 (0.76864262)
# Finished training epoch 137
# Validate: MSE 0.00283837 (0.00244421), PSNR 25.46930885 (26.17801173), SSIM 0.70473719 (0.76639851)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00248687 (0.00244867), PSNR 26.04346275 (26.13238445), SSIM 0.77360648 (0.76865546)
# Finished training epoch 138
# Validate: MSE 0.00280664 (0.00247970), PSNR 25.51813507 (26.11644010), SSIM 0.70312530 (0.76851726)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00210121 (0.00244730), PSNR 26.77531242 (26.13270580), SSIM 0.76860535 (0.76858614)
# Finished training epoch 139
# Validate: MSE 0.00276105 (0.00254195), PSNR 25.58925056 (26.02096284), SSIM 0.70408499 (0.76910451)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00226941 (0.00244056), PSNR 26.44087601 (26.14896530), SSIM 0.76829541 (0.76892091)
# Finished training epoch 140
# Validate: MSE 0.00276068 (0.00241389), PSNR 25.58983803 (26.23329999), SSIM 0.70361018 (0.76922753)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00240402 (0.00243627), PSNR 26.19062424 (26.15521077), SSIM 0.78484029 (0.76895391)
# Finished training epoch 141
# Validate: MSE 0.00279248 (0.00247837), PSNR 25.54009628 (26.13213754), SSIM 0.70675164 (0.77023043)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00255038 (0.00243791), PSNR 25.93394852 (26.15214208), SSIM 0.74951136 (0.76910006)
# Finished training epoch 142
# Validate: MSE 0.00293324 (0.00256441), PSNR 25.32652664 (25.97466605), SSIM 0.70509660 (0.76349764)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00280536 (0.00245394), PSNR 25.52011490 (26.12189931), SSIM 0.74694699 (0.76862775)
# Finished training epoch 143
# Validate: MSE 0.00277605 (0.00245308), PSNR 25.56573105 (26.17057968), SSIM 0.70723546 (0.76951212)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00207384 (0.00243842), PSNR 26.83225060 (26.14845863), SSIM 0.79543138 (0.76867259)
# Finished training epoch 144
# Validate: MSE 0.00289988 (0.00242497), PSNR 25.37619400 (26.21417176), SSIM 0.70719111 (0.77041033)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00246049 (0.00244640), PSNR 26.08978653 (26.13906713), SSIM 0.77849919 (0.76851760)
# Finished training epoch 145
# Validate: MSE 0.00280592 (0.00247706), PSNR 25.51924133 (26.12431487), SSIM 0.70327163 (0.76659302)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00270158 (0.00244145), PSNR 25.68382454 (26.14648610), SSIM 0.74775058 (0.76903253)
# Finished training epoch 146
# Validate: MSE 0.00289505 (0.00243581), PSNR 25.38343620 (26.19291982), SSIM 0.69982463 (0.76576939)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00221770 (0.00243666), PSNR 26.54097939 (26.15722401), SSIM 0.78491598 (0.76862425)
# Finished training epoch 147
# Validate: MSE 0.00272565 (0.00242412), PSNR 25.64529037 (26.21488110), SSIM 0.70823079 (0.76912281)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00203194 (0.00244169), PSNR 26.92088127 (26.14504239), SSIM 0.77612853 (0.76907866)
# Finished training epoch 148
# Validate: MSE 0.00280008 (0.00244111), PSNR 25.52828789 (26.19126391), SSIM 0.70801139 (0.77098278)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00246632 (0.00244527), PSNR 26.07950974 (26.13846156), SSIM 0.75940925 (0.76882023)
# Finished training epoch 149
# Validate: MSE 0.00286043 (0.00245960), PSNR 25.43569183 (26.16065558), SSIM 0.70900834 (0.77164004)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00276591 (0.00243194), PSNR 25.58161354 (26.16060867), SSIM 0.75677860 (0.76870017)
# Finished training epoch 150
# Validate: MSE 0.00277903 (0.00241138), PSNR 25.56105804 (26.24061654), SSIM 0.70715606 (0.76916878)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00250124 (0.00243511), PSNR 26.01845169 (26.15516075), SSIM 0.74552947 (0.76884046)
# Finished training epoch 151
# Validate: MSE 0.00294347 (0.00277314), PSNR 25.31140709 (25.64384225), SSIM 0.69928336 (0.75666065)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00205741 (0.00245173), PSNR 26.86679077 (26.12751512), SSIM 0.79393715 (0.76851652)
# Finished training epoch 152
# Validate: MSE 0.00283367 (0.00244590), PSNR 25.47650146 (26.18518845), SSIM 0.70716244 (0.77239047)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00231003 (0.00244459), PSNR 26.36381721 (26.14064414), SSIM 0.77113742 (0.76875575)
# Finished training epoch 153
# Validate: MSE 0.00287022 (0.00250031), PSNR 25.42084694 (26.08372323), SSIM 0.70170748 (0.76789297)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00220065 (0.00244031), PSNR 26.57448196 (26.14463605), SSIM 0.77880400 (0.76863169)
# Finished training epoch 154
# Validate: MSE 0.00311334 (0.00279758), PSNR 25.06774139 (25.61305917), SSIM 0.70285487 (0.76238996)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00200213 (0.00244001), PSNR 26.98507118 (26.15028450), SSIM 0.76452041 (0.76914578)
# Finished training epoch 155
# Validate: MSE 0.00298532 (0.00256216), PSNR 25.25008965 (25.98655505), SSIM 0.70559591 (0.76605862)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00264842 (0.00244497), PSNR 25.77013588 (26.13934542), SSIM 0.76917893 (0.76859028)
# Finished training epoch 156
# Validate: MSE 0.00294611 (0.00253392), PSNR 25.30750275 (26.02864276), SSIM 0.70514512 (0.76469231)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00254772 (0.00244807), PSNR 25.93848228 (26.13274530), SSIM 0.78711247 (0.76863469)
# Finished training epoch 157
# Validate: MSE 0.00283097 (0.00242668), PSNR 25.48063850 (26.21517762), SSIM 0.70552874 (0.77006061)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00263125 (0.00243914), PSNR 25.79838181 (26.14976877), SSIM 0.77638090 (0.76882501)
# Finished training epoch 158
# Validate: MSE 0.00282284 (0.00249702), PSNR 25.49314308 (26.10129208), SSIM 0.70982063 (0.77177434)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00272650 (0.00243989), PSNR 25.64394379 (26.14817162), SSIM 0.76173353 (0.76870013)
# Finished training epoch 159
# Validate: MSE 0.00285570 (0.00242586), PSNR 25.44287300 (26.21590159), SSIM 0.70323312 (0.77055007)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00261972 (0.00243574), PSNR 25.81744576 (26.15409031), SSIM 0.75972253 (0.76892007)
# Finished training epoch 160
# Validate: MSE 0.00279454 (0.00276707), PSNR 25.53689194 (25.69475983), SSIM 0.70192045 (0.76253054)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00279396 (0.00243978), PSNR 25.53780365 (26.15037823), SSIM 0.75032347 (0.76887771)
# Finished training epoch 161
# Validate: MSE 0.00292471 (0.00240164), PSNR 25.33917236 (26.25670173), SSIM 0.70510143 (0.77079094)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00205896 (0.00243723), PSNR 26.86351204 (26.15639557), SSIM 0.77789062 (0.76907589)
# Finished training epoch 162
# Validate: MSE 0.00292756 (0.00243854), PSNR 25.33493805 (26.19260177), SSIM 0.70731980 (0.77234917)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00204760 (0.00244120), PSNR 26.88753891 (26.14709281), SSIM 0.78260803 (0.76882323)
# Finished training epoch 163
# Validate: MSE 0.00280866 (0.00243099), PSNR 25.51500130 (26.20693526), SSIM 0.70819151 (0.77240036)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00253286 (0.00243726), PSNR 25.96389198 (26.15451183), SSIM 0.75861704 (0.76884408)
# Finished training epoch 164
# Validate: MSE 0.00279859 (0.00244339), PSNR 25.53060913 (26.18484324), SSIM 0.70462394 (0.76667424)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00222718 (0.00243592), PSNR 26.52244377 (26.15292003), SSIM 0.77565610 (0.76872816)
# Finished training epoch 165
# Validate: MSE 0.00278705 (0.00242930), PSNR 25.54855537 (26.20488977), SSIM 0.70448494 (0.76430816)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00192660 (0.00243370), PSNR 27.15207863 (26.15853484), SSIM 0.78998369 (0.76882104)
# Finished training epoch 166
# Validate: MSE 0.00282800 (0.00244686), PSNR 25.48519897 (26.18126235), SSIM 0.70915484 (0.77120090)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00258718 (0.00243548), PSNR 25.87174034 (26.16020372), SSIM 0.75995743 (0.76877516)
# Finished training epoch 167
# Validate: MSE 0.00294245 (0.00241959), PSNR 25.31291199 (26.22600532), SSIM 0.70591235 (0.77198741)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00190911 (0.00243782), PSNR 27.19168091 (26.15239531), SSIM 0.79846865 (0.76885508)
# Finished training epoch 168
# Validate: MSE 0.00289318 (0.00241209), PSNR 25.38624573 (26.23748032), SSIM 0.70467782 (0.76962039)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00237260 (0.00243966), PSNR 26.24775124 (26.14905376), SSIM 0.78197861 (0.76884574)
# Finished training epoch 169
# Validate: MSE 0.00291185 (0.00240567), PSNR 25.35831451 (26.25202555), SSIM 0.70426822 (0.76975734)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00214942 (0.00243812), PSNR 26.67679024 (26.15511362), SSIM 0.76763868 (0.76894757)
# Finished training epoch 170
# Validate: MSE 0.00284201 (0.00260131), PSNR 25.46374512 (25.91275964), SSIM 0.70501304 (0.75927725)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00221662 (0.00244047), PSNR 26.54307747 (26.14975140), SSIM 0.77137506 (0.76877157)
# Finished training epoch 171
# Validate: MSE 0.00281044 (0.00242933), PSNR 25.51225471 (26.21017559), SSIM 0.70667750 (0.77004291)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00237936 (0.00244135), PSNR 26.23539543 (26.14731670), SSIM 0.75912714 (0.76880427)
# Finished training epoch 172
# Validate: MSE 0.00293525 (0.00249509), PSNR 25.32354355 (26.09411994), SSIM 0.70917583 (0.76661691)
# Finished validation.
# Starting training epoch 173
# ...
# Finished validation.
# Starting training epoch 240
# Epoch: 240, MSE 0.00283637 (0.00243616), PSNR 25.47237015 (26.15379358), SSIM 0.75195009 (0.76847712)
# Finished training epoch 240
# Validate: MSE 0.00296092 (0.00256271), PSNR 25.28573799 (25.98633313), SSIM 0.71023345 (0.77017344)
# Finished validation.
# Starting training epoch 241
# Epoch: 241, MSE 0.00201565 (0.00243766), PSNR 26.95585060 (26.15121816), SSIM 0.78930008 (0.76878849)
# Finished training epoch 241
# Validate: MSE 0.00287826 (0.00241701), PSNR 25.40869713 (26.23190301), SSIM 0.70459914 (0.76829858)
# Finished validation.
# Starting training epoch 242
# Epoch: 242, MSE 0.00230195 (0.00243000), PSNR 26.37903595 (26.16643412), SSIM 0.77522266 (0.76885443)
# Finished training epoch 242
# Validate: MSE 0.00281774 (0.00246426), PSNR 25.50098228 (26.15318148), SSIM 0.70817685 (0.77373506)
# Finished validation.
# Starting training epoch 243
# Epoch: 243, MSE 0.00242446 (0.00244116), PSNR 26.15384674 (26.14660914), SSIM 0.77502006 (0.76856087)
# Finished training epoch 243
# Validate: MSE 0.00301489 (0.00249481), PSNR 25.20728111 (26.09805958), SSIM 0.70476913 (0.77327173)
# Finished validation.
# Starting training epoch 244
# Epoch: 244, MSE 0.00246653 (0.00244201), PSNR 26.07912636 (26.14403933), SSIM 0.77559471 (0.76827210)
# Finished training epoch 244
# Validate: MSE 0.00284934 (0.00243395), PSNR 25.45255280 (26.20237753), SSIM 0.70806289 (0.77170216)
# Finished validation.
# Starting training epoch 245
# Epoch: 245, MSE 0.00222339 (0.00243589), PSNR 26.52984619 (26.15711051), SSIM 0.77745509 (0.76860841)
# Finished training epoch 245
# Validate: MSE 0.00306861 (0.00254886), PSNR 25.13057899 (26.00636647), SSIM 0.70499575 (0.76786008)
# Finished validation.
# Starting training epoch 246
# Epoch: 246, MSE 0.00272284 (0.00243380), PSNR 25.64976883 (26.15933611), SSIM 0.75412643 (0.76882011)
# Finished training epoch 246
# Validate: MSE 0.00280317 (0.00238787), PSNR 25.52350426 (26.28059554), SSIM 0.70751315 (0.76870408)
# Finished validation.
# Starting training epoch 247
# Epoch: 247, MSE 0.00229869 (0.00243620), PSNR 26.38519287 (26.15584814), SSIM 0.75631958 (0.76878811)
# Finished training epoch 247
# Validate: MSE 0.00297124 (0.00247937), PSNR 25.27061844 (26.12144427), SSIM 0.70433950 (0.77027323)
# Finished validation.
# Starting training epoch 248
# Epoch: 248, MSE 0.00290832 (0.00243369), PSNR 25.36357498 (26.16029893), SSIM 0.76011419 (0.76867316)
# Finished training epoch 248
# Validate: MSE 0.00294480 (0.00252825), PSNR 25.30943680 (26.04097173), SSIM 0.70141673 (0.76570032)
# Finished validation.
# Starting training epoch 249
# Epoch: 249, MSE 0.00234603 (0.00243971), PSNR 26.29666710 (26.14927598), SSIM 0.77815974 (0.76823496)
# Finished training epoch 249
# Validate: MSE 0.00285788 (0.00241210), PSNR 25.43956375 (26.23999881), SSIM 0.70679903 (0.76859956)
# Finished validation.
# Starting training epoch 250
# Epoch: 250, MSE 0.00265117 (0.00243159), PSNR 25.76562881 (26.16338861), SSIM 0.75630587 (0.76869581)
# Finished training epoch 250
# Validate: MSE 0.00288472 (0.00239811), PSNR 25.39895630 (26.26574658), SSIM 0.70751929 (0.76938106)
# Finished validation.
# Starting training epoch 251
# Epoch: 251, MSE 0.00300038 (0.00242662), PSNR 25.22824287 (26.17053140), SSIM 0.74747765 (0.76878550)
# Finished training epoch 251
# Validate: MSE 0.00294315 (0.00248785), PSNR 25.31187439 (26.10065745), SSIM 0.69978249 (0.76540379)
# Finished validation.
# Starting training epoch 252
# Epoch: 252, MSE 0.00221371 (0.00243875), PSNR 26.54879379 (26.14760584), SSIM 0.76267588 (0.76856401)
# Finished training epoch 252
# Validate: MSE 0.00283357 (0.00251788), PSNR 25.47665405 (26.05816802), SSIM 0.70498812 (0.76825620)
# Finished validation.
# Starting training epoch 253
# Epoch: 253, MSE 0.00222832 (0.00243452), PSNR 26.52022934 (26.16031502), SSIM 0.78404903 (0.76880611)
# Finished training epoch 253
# Validate: MSE 0.00294643 (0.00247561), PSNR 25.30703735 (26.12748596), SSIM 0.70407844 (0.76874315)
# Finished validation.
# Starting training epoch 254
# Epoch: 254, MSE 0.00198827 (0.00243640), PSNR 27.01523972 (26.15505839), SSIM 0.77560282 (0.76887312)
# Finished training epoch 254
# Validate: MSE 0.00276050 (0.00244221), PSNR 25.59011841 (26.18255439), SSIM 0.69921136 (0.76183726)
# Finished validation.
# Starting training epoch 255
# Epoch: 255, MSE 0.00233386 (0.00243009), PSNR 26.31925011 (26.16519150), SSIM 0.76611221 (0.76855828)
# Finished training epoch 255
# Validate: MSE 0.00295070 (0.00245236), PSNR 25.30074883 (26.17154106), SSIM 0.70868790 (0.77422891)
# Finished validation.
# Starting training epoch 256
# Epoch: 256, MSE 0.00232226 (0.00243191), PSNR 26.34088326 (26.16031019), SSIM 0.78398591 (0.76887432)
# Finished training epoch 256
# Validate: MSE 0.00315145 (0.00263366), PSNR 25.01489639 (25.87053885), SSIM 0.70881617 (0.76954572)
# Finished validation.
# Starting training epoch 257
# Epoch: 257, MSE 0.00211352 (0.00243301), PSNR 26.74993515 (26.16035055), SSIM 0.78649276 (0.76850517)
# Finished training epoch 257
# Validate: MSE 0.00305650 (0.00251676), PSNR 25.14775276 (26.06313531), SSIM 0.70211011 (0.76725865)
# Finished validation.
# Starting training epoch 258
# Epoch: 258, MSE 0.00260120 (0.00243205), PSNR 25.84826088 (26.16335589), SSIM 0.76519156 (0.76866884)
# Finished training epoch 258
# Validate: MSE 0.00285825 (0.00248664), PSNR 25.43899155 (26.10885734), SSIM 0.70115960 (0.76287485)
# Finished validation.
# Starting training epoch 259
# Epoch: 259, MSE 0.00298119 (0.00244177), PSNR 25.25610161 (26.14564906), SSIM 0.74498993 (0.76861777)
# Finished training epoch 259
# Validate: MSE 0.00282103 (0.00251303), PSNR 25.49592018 (26.06835194), SSIM 0.70870876 (0.77299106)
# Finished validation.
# Starting training epoch 260
# Epoch: 260, MSE 0.00241976 (0.00243443), PSNR 26.16227341 (26.15822800), SSIM 0.77112901 (0.76868011)
# Finished training epoch 260
# Validate: MSE 0.00283888 (0.00239563), PSNR 25.46852875 (26.26925560), SSIM 0.70683295 (0.77065136)
# Finished validation.
# Starting training epoch 261
# Epoch: 261, MSE 0.00219068 (0.00243357), PSNR 26.59420776 (26.15761403), SSIM 0.77482820 (0.76892577)
# Finished training epoch 261
# Validate: MSE 0.00274462 (0.00244050), PSNR 25.61517715 (26.18822427), SSIM 0.70344555 (0.76704475)
# Finished validation.
# Starting training epoch 262
# Epoch: 262, MSE 0.00229948 (0.00244072), PSNR 26.38369370 (26.14891073), SSIM 0.78182107 (0.76845427)
# Finished training epoch 262
# Validate: MSE 0.00295087 (0.00244063), PSNR 25.30049324 (26.18964431), SSIM 0.70484102 (0.77392813)
# Finished validation.
# Starting training epoch 263
# Epoch: 263, MSE 0.00236685 (0.00243931), PSNR 26.25828743 (26.15044210), SSIM 0.76022166 (0.76873212)
# Finished training epoch 263
# Validate: MSE 0.00274516 (0.00243438), PSNR 25.61432457 (26.19972752), SSIM 0.70557082 (0.76895781)
# Finished validation.
# Starting training epoch 264
# Epoch: 264, MSE 0.00297233 (0.00243601), PSNR 25.26902962 (26.15338194), SSIM 0.76513612 (0.76866782)
# Finished training epoch 264
# Validate: MSE 0.00286323 (0.00264250), PSNR 25.43144035 (25.85325544), SSIM 0.70412380 (0.76158358)
# Finished validation.
# Starting training epoch 265
# Epoch: 265, MSE 0.00231691 (0.00243891), PSNR 26.35090637 (26.14873131), SSIM 0.76322281 (0.76863024)
# Finished training epoch 265
# Validate: MSE 0.00271242 (0.00240859), PSNR 25.66642380 (26.24552421), SSIM 0.70829314 (0.76840690)
# Finished validation.
# Starting training epoch 266
# Epoch: 266, MSE 0.00211009 (0.00244123), PSNR 26.75697899 (26.14825018), SSIM 0.76619381 (0.76855149)
# Finished training epoch 266
# Validate: MSE 0.00312001 (0.00255457), PSNR 25.05843544 (25.99918534), SSIM 0.70074433 (0.76655619)
# Finished validation.
# Starting training epoch 267
# Epoch: 267, MSE 0.00224993 (0.00243384), PSNR 26.47830391 (26.16078991), SSIM 0.77667701 (0.76886716)
# Finished training epoch 267
# Validate: MSE 0.00301592 (0.00257921), PSNR 25.20579720 (25.96093135), SSIM 0.70349485 (0.76855830)
# Finished validation.
# Starting training epoch 268
# Epoch: 268, MSE 0.00265591 (0.00243668), PSNR 25.75786400 (26.15549118), SSIM 0.76224339 (0.76855256)
# Finished training epoch 268
# Validate: MSE 0.00282994 (0.00240117), PSNR 25.48222351 (26.25976042), SSIM 0.70657468 (0.77059285)
# Finished validation.
# Starting training epoch 269
# Epoch: 269, MSE 0.00244787 (0.00243362), PSNR 26.11211586 (26.15851236), SSIM 0.75780243 (0.76880588)
# Finished training epoch 269
# Validate: MSE 0.00285192 (0.00241844), PSNR 25.44862938 (26.22616546), SSIM 0.70921946 (0.77025976)
# Finished validation.
# Starting training epoch 270
# Epoch: 270, MSE 0.00240466 (0.00243580), PSNR 26.18946648 (26.15655807), SSIM 0.78336340 (0.76863637)
# Finished training epoch 270
# Validate: MSE 0.00281780 (0.00240444), PSNR 25.50089645 (26.25049680), SSIM 0.70388758 (0.76734242)
# Finished validation.
# Starting training epoch 271
# Epoch: 271, MSE 0.00271287 (0.00243248), PSNR 25.66571045 (26.16012606), SSIM 0.74610889 (0.76857937)
# Finished training epoch 271
# Validate: MSE 0.00271452 (0.00245953), PSNR 25.66307449 (26.15843931), SSIM 0.70717388 (0.76786817)
# Finished validation.
# Starting training epoch 272
# Epoch: 272, MSE 0.00218117 (0.00243566), PSNR 26.61310577 (26.15461149), SSIM 0.75804895 (0.76869079)
# Finished training epoch 272
# Validate: MSE 0.00279199 (0.00261631), PSNR 25.54085922 (25.90530544), SSIM 0.70104414 (0.76428337)
# Finished validation.
# Starting training epoch 273
# Epoch: 273, MSE 0.00253927 (0.00243190), PSNR 25.95290565 (26.16436071), SSIM 0.75994045 (0.76882726)
# Finished training epoch 273
# Validate: MSE 0.00290550 (0.00247143), PSNR 25.36778450 (26.14248379), SSIM 0.70656407 (0.76996513)
# Finished validation.
# Starting training epoch 274
# Epoch: 274, MSE 0.00244157 (0.00243780), PSNR 26.12330818 (26.15444854), SSIM 0.75642580 (0.76853700)
# Finished training epoch 274
# Validate: MSE 0.00288876 (0.00243072), PSNR 25.39288521 (26.20495354), SSIM 0.70263642 (0.76911258)
# Finished validation.
# Starting training epoch 275
# Epoch: 275, MSE 0.00231897 (0.00243107), PSNR 26.34704399 (26.16331362), SSIM 0.77182513 (0.76869733)
# Finished training epoch 275
# Validate: MSE 0.00297305 (0.00241102), PSNR 25.26797295 (26.24101452), SSIM 0.70611423 (0.77170904)
# Finished validation.
# Starting training epoch 276
# Epoch: 276, MSE 0.00251214 (0.00243663), PSNR 25.99956512 (26.15498325), SSIM 0.77351677 (0.76848519)
# Finished training epoch 276
# Validate: MSE 0.00295984 (0.00240834), PSNR 25.28732300 (26.24365491), SSIM 0.70412052 (0.76668636)
# Finished validation.
# Starting training epoch 277
# Epoch: 277, MSE 0.00258283 (0.00243556), PSNR 25.87903595 (26.15497863), SSIM 0.74973726 (0.76851199)
# Finished training epoch 277
# Validate: MSE 0.00278366 (0.00241839), PSNR 25.55384445 (26.22737697), SSIM 0.71083397 (0.76598713)
# Finished validation.
# Starting training epoch 278
# Epoch: 278, MSE 0.00260770 (0.00243341), PSNR 25.83742142 (26.15943822), SSIM 0.76082253 (0.76871772)
# Finished training epoch 278
# Validate: MSE 0.00285636 (0.00242326), PSNR 25.44186401 (26.21984666), SSIM 0.70373160 (0.76603083)
# Finished validation.
# Starting training epoch 279
# Epoch: 279, MSE 0.00235135 (0.00243149), PSNR 26.28682899 (26.16113726), SSIM 0.74099386 (0.76847424)
# Finished training epoch 279
# Validate: MSE 0.00287201 (0.00250138), PSNR 25.41813278 (26.07817170), SSIM 0.70225513 (0.76613097)
# Finished validation.
# Starting training epoch 280
# Epoch: 280, MSE 0.00295018 (0.00242817), PSNR 25.30151176 (26.16778128), SSIM 0.75649351 (0.76874109)
# Finished training epoch 280
# Validate: MSE 0.00271151 (0.00259085), PSNR 25.66789055 (25.94955222), SSIM 0.70296466 (0.76678575)
# Finished validation.
# Starting training epoch 281
# Epoch: 281, MSE 0.00297350 (0.00243743), PSNR 25.26731682 (26.15704172), SSIM 0.72705179 (0.76856247)
# Finished training epoch 281
# Validate: MSE 0.00279108 (0.00256684), PSNR 25.54227448 (25.98503392), SSIM 0.70299721 (0.76123988)
# Finished validation.
# Starting training epoch 282
# Epoch: 282, MSE 0.00245567 (0.00243654), PSNR 26.09828949 (26.15699485), SSIM 0.78314483 (0.76872502)
# Finished training epoch 282
# Validate: MSE 0.00288511 (0.00241166), PSNR 25.39837837 (26.24086072), SSIM 0.70446837 (0.77061546)
# Finished validation.
# Starting training epoch 283
# Epoch: 283, MSE 0.00268487 (0.00244352), PSNR 25.71077156 (26.14302735), SSIM 0.76776880 (0.76851718)
# Finished training epoch 283
# Validate: MSE 0.00275705 (0.00249172), PSNR 25.59554482 (26.10437628), SSIM 0.70493788 (0.76731438)
# Finished validation.
# Starting training epoch 284
# Epoch: 284, MSE 0.00274866 (0.00243345), PSNR 25.60879517 (26.16050842), SSIM 0.75745803 (0.76856338)
# Finished training epoch 284
# Validate: MSE 0.00281480 (0.00244683), PSNR 25.50551987 (26.16615595), SSIM 0.70064151 (0.76136483)
# Finished validation.
# Starting training epoch 285
# Epoch: 285, MSE 0.00204162 (0.00243208), PSNR 26.90024757 (26.16371712), SSIM 0.79845846 (0.76886098)
# Finished training epoch 285
# Validate: MSE 0.00284542 (0.00250893), PSNR 25.45853806 (26.07073998), SSIM 0.70728469 (0.76754523)
# Finished validation.
# Starting training epoch 286
# Epoch: 286, MSE 0.00267910 (0.00243460), PSNR 25.72010803 (26.15672168), SSIM 0.75983489 (0.76888907)
# Finished training epoch 286
# Validate: MSE 0.00294981 (0.00246878), PSNR 25.30206299 (26.14085344), SSIM 0.70286369 (0.76679033)
# Finished validation.
# Starting training epoch 287
# Epoch: 287, MSE 0.00232490 (0.00244001), PSNR 26.33595657 (26.14711832), SSIM 0.77097863 (0.76831155)
# Finished training epoch 287
# Validate: MSE 0.00285555 (0.00239467), PSNR 25.44310570 (26.27212020), SSIM 0.70822233 (0.77228488)
# Finished validation.
# Starting training epoch 288
# Epoch: 288, MSE 0.00253505 (0.00243513), PSNR 25.96013260 (26.15501249), SSIM 0.75485957 (0.76869009)
# Finished training epoch 288
# Validate: MSE 0.00283821 (0.00274171), PSNR 25.46954918 (25.72674425), SSIM 0.70466137 (0.76495604)
# Finished validation.
# Starting training epoch 289
# Epoch: 289, MSE 0.00207854 (0.00243149), PSNR 26.82241249 (26.16352151), SSIM 0.77984113 (0.76843895)
# Finished training epoch 289
# Validate: MSE 0.00303544 (0.00254657), PSNR 25.17777634 (26.01203193), SSIM 0.70736921 (0.77277203)
# Finished validation.
# Starting training epoch 290
# Epoch: 290, MSE 0.00227066 (0.00245204), PSNR 26.43846893 (26.12905280), SSIM 0.76108199 (0.76845377)
# Finished training epoch 290
# Validate: MSE 0.00280841 (0.00241786), PSNR 25.51539230 (26.22501635), SSIM 0.70928323 (0.76408970)
# Finished validation.
# Starting training epoch 291
# Epoch: 291, MSE 0.00228741 (0.00243290), PSNR 26.40656090 (26.16333223), SSIM 0.77422374 (0.76830314)
# Finished training epoch 291
# Validate: MSE 0.00280309 (0.00240303), PSNR 25.52362442 (26.25255389), SSIM 0.70631325 (0.76927298)
# Finished validation.
# Starting training epoch 292
# Epoch: 292, MSE 0.00244473 (0.00243362), PSNR 26.11768913 (26.16026675), SSIM 0.75732225 (0.76864430)
# Finished training epoch 292
# Validate: MSE 0.00277153 (0.00244383), PSNR 25.57280922 (26.18412685), SSIM 0.70494926 (0.76510674)
# Finished validation.
# Starting training epoch 293
# Epoch: 293, MSE 0.00253908 (0.00242907), PSNR 25.95323372 (26.17066449), SSIM 0.78496397 (0.76874890)
# Finished training epoch 293
# Validate: MSE 0.00281337 (0.00240189), PSNR 25.50772667 (26.25411864), SSIM 0.70356685 (0.76881123)
# Finished validation.
# Starting training epoch 294
# Epoch: 294, MSE 0.00270344 (0.00243112), PSNR 25.68083000 (26.16426846), SSIM 0.76763821 (0.76857037)
# Finished training epoch 294
# Validate: MSE 0.00300231 (0.00249566), PSNR 25.22544861 (26.09847009), SSIM 0.70419204 (0.76929620)
# Finished validation.
# Starting training epoch 295
# Epoch: 295, MSE 0.00222586 (0.00243031), PSNR 26.52502251 (26.16594354), SSIM 0.77684057 (0.76889574)
# Finished training epoch 295
# Validate: MSE 0.00286320 (0.00242804), PSNR 25.43148804 (26.21292715), SSIM 0.70738697 (0.77347083)
# Finished validation.
# Starting training epoch 296
# Epoch: 296, MSE 0.00210818 (0.00243107), PSNR 26.76092911 (26.16385895), SSIM 0.79558069 (0.76875578)
# Finished training epoch 296
# Validate: MSE 0.00275495 (0.00241324), PSNR 25.59885788 (26.23438867), SSIM 0.70789611 (0.76580782)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00276967 (0.00241368), PSNR 25.57571602 (26.23340635), SSIM 0.70624006 (0.76591180)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
