# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-12f33536393ba760" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-12f33536393ba760");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
                transforms.RandomVerticalFlip(),  
                transforms.RandomRotation(10),
                transforms.ColorJitter(brightness=0.05, contrast=0.05, saturation=0.05, hue=0.05)
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .25

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        self.batchnorm5 = nn.BatchNorm2d(2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = y = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x + y)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm5(self.convtrans3(x + input)), negative_slope=0.1)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-1, momentum=0.9, weight_decay=1e-5)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 32, 32]           2,306
#       BatchNorm2d-10            [-1, 2, 32, 32]               4
# ================================================================
# Total params: 2,662,278
# Trainable params: 2,662,278
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.78
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.94
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00275440 (0.01035134), PSNR 25.59972191 (24.33031112), SSIM 0.74054354 (0.71809805)
# Finished training epoch 0
# Validate: MSE 0.00312409 (0.00276836), PSNR 25.05276871 (25.65877745), SSIM 0.70640135 (0.77491635)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00262224 (0.00275835), PSNR 25.81326675 (25.61635816), SSIM 0.78478986 (0.76902870)
# Finished training epoch 1
# Validate: MSE 0.00336505 (0.00280434), PSNR 24.73008919 (25.59472744), SSIM 0.70571125 (0.77598963)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00345118 (0.00275448), PSNR 24.62032700 (25.62154764), SSIM 0.73684347 (0.76923741)
# Finished training epoch 2
# Validate: MSE 0.00317125 (0.00275612), PSNR 24.98769760 (25.67471057), SSIM 0.70474565 (0.77375406)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00291546 (0.00276316), PSNR 25.35293579 (25.61190337), SSIM 0.76530474 (0.76895246)
# Finished training epoch 3
# Validate: MSE 0.00319668 (0.00275308), PSNR 24.95300674 (25.67785159), SSIM 0.70590925 (0.77480988)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00321037 (0.00276012), PSNR 24.93445015 (25.61545173), SSIM 0.75900990 (0.76920601)
# Finished training epoch 4
# Validate: MSE 0.00319261 (0.00275232), PSNR 24.95854187 (25.67985046), SSIM 0.70567226 (0.77490889)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00304091 (0.00275847), PSNR 25.16996384 (25.61748789), SSIM 0.77027643 (0.76916846)
# Finished training epoch 5
# Validate: MSE 0.00325207 (0.00276190), PSNR 24.87839890 (25.66120170), SSIM 0.70664632 (0.77598055)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00314405 (0.00275344), PSNR 25.02509689 (25.62564455), SSIM 0.74393153 (0.76922035)
# Finished training epoch 6
# Validate: MSE 0.00318639 (0.00275786), PSNR 24.96700287 (25.67061229), SSIM 0.70671493 (0.77599006)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00285022 (0.00276744), PSNR 25.45121956 (25.59990975), SSIM 0.79045117 (0.76908714)
# Finished training epoch 7
# Validate: MSE 0.00326244 (0.00275881), PSNR 24.86457443 (25.66610661), SSIM 0.70590812 (0.77572469)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00249285 (0.00276018), PSNR 26.03303528 (25.61341139), SSIM 0.76764089 (0.76912678)
# Finished training epoch 8
# Validate: MSE 0.00318621 (0.00274724), PSNR 24.96726227 (25.68769845), SSIM 0.70615262 (0.77529909)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00233683 (0.00275989), PSNR 26.31372261 (25.61284501), SSIM 0.78243983 (0.76923370)
# Finished training epoch 9
# Validate: MSE 0.00319229 (0.00274798), PSNR 24.95897865 (25.68650583), SSIM 0.70623386 (0.77551747)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00273329 (0.00274637), PSNR 25.63314056 (25.63464849), SSIM 0.77569306 (0.76930361)
# Finished training epoch 10
# Validate: MSE 0.00315110 (0.00275366), PSNR 25.01538277 (25.68207408), SSIM 0.70502722 (0.77466622)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00283476 (0.00275415), PSNR 25.47482681 (25.62419045), SSIM 0.75893480 (0.76932784)
# Finished training epoch 11
# Validate: MSE 0.00319541 (0.00275702), PSNR 24.95473480 (25.67180177), SSIM 0.70681268 (0.77552686)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00282860 (0.00274672), PSNR 25.48427773 (25.63253178), SSIM 0.73990792 (0.76933609)
# Finished training epoch 12
# Validate: MSE 0.00317542 (0.00274211), PSNR 24.98198128 (25.69615059), SSIM 0.70587975 (0.77519327)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00232580 (0.00274648), PSNR 26.33428574 (25.63636015), SSIM 0.76024997 (0.76953137)
# Finished training epoch 13
# Validate: MSE 0.00316532 (0.00274121), PSNR 24.99582863 (25.69784894), SSIM 0.70661646 (0.77553283)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00260884 (0.00274325), PSNR 25.83552742 (25.64350776), SSIM 0.76687437 (0.76953851)
# Finished training epoch 14
# Validate: MSE 0.00324136 (0.00274648), PSNR 24.89273071 (25.68600176), SSIM 0.70610505 (0.77570273)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00287747 (0.00274752), PSNR 25.40989685 (25.63237567), SSIM 0.76479381 (0.76956283)
# Finished training epoch 15
# Validate: MSE 0.00328383 (0.00277141), PSNR 24.83619881 (25.64758767), SSIM 0.70656514 (0.77600461)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00293072 (0.00274077), PSNR 25.33025169 (25.64496759), SSIM 0.77928132 (0.76961898)
# Finished training epoch 16
# Validate: MSE 0.00319735 (0.00273899), PSNR 24.95209694 (25.69970360), SSIM 0.70702749 (0.77633077)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00221960 (0.00274356), PSNR 26.53725624 (25.63790083), SSIM 0.79318792 (0.76945125)
# Finished training epoch 17
# Validate: MSE 0.00313497 (0.00272653), PSNR 25.03766251 (25.72275579), SSIM 0.70687789 (0.77589618)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00265217 (0.00273362), PSNR 25.76399040 (25.65636192), SSIM 0.77191937 (0.76944878)
# Finished training epoch 18
# Validate: MSE 0.00321190 (0.00273300), PSNR 24.93238068 (25.70818895), SSIM 0.70569235 (0.77603035)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00254410 (0.00273003), PSNR 25.94466209 (25.65987464), SSIM 0.75677216 (0.76937746)
# Finished training epoch 19
# Validate: MSE 0.00312191 (0.00271340), PSNR 25.05579567 (25.74291139), SSIM 0.70660800 (0.77598209)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00325900 (0.00272454), PSNR 24.86915970 (25.67027363), SSIM 0.74867046 (0.76898836)
# Finished training epoch 20
# Validate: MSE 0.00312090 (0.00270560), PSNR 25.05720711 (25.75520828), SSIM 0.70387357 (0.77542037)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00298071 (0.00270940), PSNR 25.25679970 (25.69541130), SSIM 0.74894363 (0.76825410)
# Finished training epoch 21
# Validate: MSE 0.00310975 (0.00270254), PSNR 25.07274437 (25.75888927), SSIM 0.70577472 (0.77624486)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00247028 (0.00269712), PSNR 26.07253838 (25.71226923), SSIM 0.77112269 (0.76737726)
# Finished training epoch 22
# Validate: MSE 0.00318328 (0.00270098), PSNR 24.97125244 (25.75747656), SSIM 0.70429671 (0.77548460)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00287815 (0.00267441), PSNR 25.40886688 (25.75068484), SSIM 0.73684496 (0.76651872)
# Finished training epoch 23
# Validate: MSE 0.00307427 (0.00266496), PSNR 25.12258148 (25.81798065), SSIM 0.70181417 (0.77368521)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00277542 (0.00267014), PSNR 25.56670570 (25.75683969), SSIM 0.75515932 (0.76522124)
# Finished training epoch 24
# Validate: MSE 0.00306254 (0.00265198), PSNR 25.13917923 (25.83776624), SSIM 0.69818801 (0.77166693)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00308996 (0.00265428), PSNR 25.10047531 (25.78367290), SSIM 0.75036204 (0.76418364)
# Finished training epoch 25
# Validate: MSE 0.00300432 (0.00263396), PSNR 25.22253418 (25.86791772), SSIM 0.69959843 (0.77093954)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00202979 (0.00264479), PSNR 26.92549324 (25.79986659), SSIM 0.78633642 (0.76312547)
# Finished training epoch 26
# Validate: MSE 0.00302811 (0.00262261), PSNR 25.18828011 (25.88561426), SSIM 0.69968110 (0.77181027)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00227254 (0.00262465), PSNR 26.43488312 (25.83490200), SSIM 0.80089152 (0.76219434)
# Finished training epoch 27
# Validate: MSE 0.00300903 (0.00260380), PSNR 25.21573257 (25.91533162), SSIM 0.69922602 (0.76962633)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00208070 (0.00261001), PSNR 26.81790161 (25.85951488), SSIM 0.76161355 (0.76164129)
# Finished training epoch 28
# Validate: MSE 0.00293002 (0.00258894), PSNR 25.33128929 (25.93919544), SSIM 0.69630945 (0.76661614)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00235479 (0.00261092), PSNR 26.28048325 (25.85707962), SSIM 0.76754308 (0.76102461)
# Finished training epoch 29
# Validate: MSE 0.00297563 (0.00258199), PSNR 25.26420212 (25.95068456), SSIM 0.70162892 (0.77110525)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00251411 (0.00259489), PSNR 25.99615288 (25.88563211), SSIM 0.77301586 (0.76105055)
# Finished training epoch 30
# Validate: MSE 0.00296504 (0.00257298), PSNR 25.27969933 (25.96163705), SSIM 0.69369513 (0.76271602)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00264458 (0.00258991), PSNR 25.77643776 (25.88849471), SSIM 0.73080635 (0.76073460)
# Finished training epoch 31
# Validate: MSE 0.00299515 (0.00256120), PSNR 25.23580742 (25.98319536), SSIM 0.70114613 (0.76908816)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00243794 (0.00258028), PSNR 26.12976646 (25.90443763), SSIM 0.77313149 (0.76082935)
# Finished training epoch 32
# Validate: MSE 0.00293109 (0.00255268), PSNR 25.32970047 (25.99655147), SSIM 0.69934225 (0.76620150)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00252816 (0.00257238), PSNR 25.97195816 (25.91900755), SSIM 0.76952839 (0.76106461)
# Finished training epoch 33
# Validate: MSE 0.00296172 (0.00256323), PSNR 25.28456116 (25.97890100), SSIM 0.70409781 (0.76909404)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00217807 (0.00256635), PSNR 26.61928940 (25.92993835), SSIM 0.76139194 (0.76123651)
# Finished training epoch 34
# Validate: MSE 0.00294891 (0.00254031), PSNR 25.30338860 (26.01652153), SSIM 0.70073724 (0.76675261)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00281297 (0.00256784), PSNR 25.50834846 (25.92878011), SSIM 0.76704490 (0.76123923)
# Finished training epoch 35
# Validate: MSE 0.00293143 (0.00252978), PSNR 25.32920074 (26.03432745), SSIM 0.70120746 (0.76768314)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00310311 (0.00255283), PSNR 25.08202171 (25.95468823), SSIM 0.73458976 (0.76173759)
# Finished training epoch 36
# Validate: MSE 0.00295892 (0.00253297), PSNR 25.28867149 (26.02843641), SSIM 0.70169806 (0.76607287)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00255276 (0.00254868), PSNR 25.92990494 (25.95911066), SSIM 0.76468748 (0.76207772)
# Finished training epoch 37
# Validate: MSE 0.00297893 (0.00252010), PSNR 25.25938988 (26.05163834), SSIM 0.70386624 (0.76966078)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00274429 (0.00254644), PSNR 25.61569977 (25.96331221), SSIM 0.73850101 (0.76201064)
# Finished training epoch 38
# Validate: MSE 0.00295692 (0.00253887), PSNR 25.29159546 (26.02202378), SSIM 0.70777333 (0.77468615)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00303948 (0.00254331), PSNR 25.17200851 (25.96731208), SSIM 0.76056021 (0.76237634)
# Finished training epoch 39
# Validate: MSE 0.00299434 (0.00251668), PSNR 25.23698235 (26.05724214), SSIM 0.70360124 (0.77027316)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00248314 (0.00253712), PSNR 26.04999542 (25.97944742), SSIM 0.74889117 (0.76279639)
# Finished training epoch 40
# Validate: MSE 0.00298581 (0.00252028), PSNR 25.24937057 (26.05096818), SSIM 0.70709592 (0.77109920)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00225492 (0.00253365), PSNR 26.46869087 (25.98621795), SSIM 0.75947988 (0.76278730)
# Finished training epoch 41
# Validate: MSE 0.00296390 (0.00253369), PSNR 25.28136635 (26.03027140), SSIM 0.70753741 (0.77535035)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00223055 (0.00253226), PSNR 26.51587868 (25.98606681), SSIM 0.77602804 (0.76359416)
# Finished training epoch 42
# Validate: MSE 0.00291745 (0.00252174), PSNR 25.34997177 (26.04450363), SSIM 0.70081079 (0.76555850)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00259115 (0.00252833), PSNR 25.86506844 (25.99720711), SSIM 0.76388150 (0.76369966)
# Finished training epoch 43
# Validate: MSE 0.00302387 (0.00253715), PSNR 25.19436836 (26.02373421), SSIM 0.70658731 (0.77075154)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00226227 (0.00252497), PSNR 26.45454788 (26.00025948), SSIM 0.75862455 (0.76380317)
# Finished training epoch 44
# Validate: MSE 0.00305762 (0.00252273), PSNR 25.14615822 (26.04866208), SSIM 0.70731592 (0.77590262)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00327912 (0.00252694), PSNR 24.84243202 (25.99773681), SSIM 0.72875333 (0.76387267)
# Finished training epoch 45
# Validate: MSE 0.00294179 (0.00249536), PSNR 25.31388855 (26.09081497), SSIM 0.70428157 (0.76677351)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00266312 (0.00252599), PSNR 25.74609375 (25.99635680), SSIM 0.74341863 (0.76424755)
# Finished training epoch 46
# Validate: MSE 0.00294230 (0.00249412), PSNR 25.31312561 (26.09659336), SSIM 0.70819634 (0.77409420)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00210222 (0.00251550), PSNR 26.77322006 (26.01761420), SSIM 0.76965415 (0.76470097)
# Finished training epoch 47
# Validate: MSE 0.00294381 (0.00248709), PSNR 25.31090164 (26.10805469), SSIM 0.70634991 (0.77182270)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00294814 (0.00251934), PSNR 25.30452347 (26.01463555), SSIM 0.75315505 (0.76457846)
# Finished training epoch 48
# Validate: MSE 0.00296314 (0.00249162), PSNR 25.28247833 (26.10022245), SSIM 0.70904523 (0.77425086)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00230594 (0.00252228), PSNR 26.37151909 (26.00583328), SSIM 0.75978142 (0.76477836)
# Finished training epoch 49
# Validate: MSE 0.00296726 (0.00250965), PSNR 25.27643967 (26.06972607), SSIM 0.70586789 (0.76950740)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00271091 (0.00250818), PSNR 25.66885185 (26.03142064), SSIM 0.75586140 (0.76501365)
# Finished training epoch 50
# Validate: MSE 0.00294105 (0.00249206), PSNR 25.31497002 (26.09737290), SSIM 0.70246416 (0.76726137)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00229350 (0.00250810), PSNR 26.39500618 (26.02465001), SSIM 0.76671207 (0.76506822)
# Finished training epoch 51
# Validate: MSE 0.00291638 (0.00249980), PSNR 25.35155296 (26.08684581), SSIM 0.71209848 (0.77363511)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00252298 (0.00251203), PSNR 25.98085976 (26.02392409), SSIM 0.74703854 (0.76538495)
# Finished training epoch 52
# Validate: MSE 0.00301282 (0.00252228), PSNR 25.21026039 (26.04920863), SSIM 0.70930928 (0.77163763)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00279541 (0.00250698), PSNR 25.53554535 (26.03152477), SSIM 0.73944753 (0.76568736)
# Finished training epoch 53
# Validate: MSE 0.00292808 (0.00247745), PSNR 25.33416748 (26.12399395), SSIM 0.70431149 (0.76991871)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00242722 (0.00251248), PSNR 26.14890099 (26.02554256), SSIM 0.76689309 (0.76567821)
# Finished training epoch 54
# Validate: MSE 0.00291667 (0.00246594), PSNR 25.35112572 (26.14328831), SSIM 0.70701283 (0.77188447)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00209292 (0.00250818), PSNR 26.79247665 (26.02743184), SSIM 0.77881646 (0.76603479)
# Finished training epoch 55
# Validate: MSE 0.00290181 (0.00247083), PSNR 25.37331390 (26.13404093), SSIM 0.70635855 (0.77110040)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00237612 (0.00250172), PSNR 26.24131393 (26.04025216), SSIM 0.78093940 (0.76596000)
# Finished training epoch 56
# Validate: MSE 0.00295478 (0.00247532), PSNR 25.29474449 (26.12803768), SSIM 0.70806116 (0.77379282)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00216367 (0.00250910), PSNR 26.64809608 (26.02586101), SSIM 0.78475010 (0.76590704)
# Finished training epoch 57
# Validate: MSE 0.00294729 (0.00246770), PSNR 25.30577660 (26.14062201), SSIM 0.70709771 (0.77247336)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00293101 (0.00250245), PSNR 25.32982826 (26.04193677), SSIM 0.76087582 (0.76634043)
# Finished training epoch 58
# Validate: MSE 0.00292594 (0.00247282), PSNR 25.33734703 (26.12986488), SSIM 0.70379996 (0.76864941)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00248214 (0.00249985), PSNR 26.05174446 (26.04687547), SSIM 0.75692177 (0.76658092)
# Finished training epoch 59
# Validate: MSE 0.00290819 (0.00246239), PSNR 25.36377335 (26.15068216), SSIM 0.70984173 (0.77416811)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00247877 (0.00250058), PSNR 26.05764198 (26.04142398), SSIM 0.75156569 (0.76649267)
# Finished training epoch 60
# Validate: MSE 0.00297794 (0.00248840), PSNR 25.26083565 (26.10671004), SSIM 0.70794088 (0.77222864)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00257135 (0.00249839), PSNR 25.89838600 (26.04962130), SSIM 0.77389413 (0.76678761)
# Finished training epoch 61
# Validate: MSE 0.00293927 (0.00246244), PSNR 25.31759834 (26.14923147), SSIM 0.70795870 (0.77400538)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00275591 (0.00249341), PSNR 25.59735489 (26.05542146), SSIM 0.74002081 (0.76670928)
# Finished training epoch 62
# Validate: MSE 0.00292141 (0.00246730), PSNR 25.34406662 (26.14020285), SSIM 0.70753974 (0.77213911)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00216505 (0.00248946), PSNR 26.64532852 (26.06447421), SSIM 0.74936843 (0.76703904)
# Finished training epoch 63
# Validate: MSE 0.00288601 (0.00245102), PSNR 25.39701462 (26.16937311), SSIM 0.71108043 (0.77355892)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00287397 (0.00249060), PSNR 25.41517258 (26.05930689), SSIM 0.77738893 (0.76725172)
# Finished training epoch 64
# Validate: MSE 0.00298136 (0.00246895), PSNR 25.25585556 (26.13983942), SSIM 0.71060991 (0.77593159)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00192943 (0.00249490), PSNR 27.14571762 (26.05256255), SSIM 0.81090480 (0.76707319)
# Finished training epoch 65
# Validate: MSE 0.00289765 (0.00245095), PSNR 25.37953377 (26.17117332), SSIM 0.70966071 (0.77506695)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00254712 (0.00248838), PSNR 25.93950272 (26.06214902), SSIM 0.75776100 (0.76716672)
# Finished training epoch 66
# Validate: MSE 0.00298280 (0.00246283), PSNR 25.25375366 (26.15022009), SSIM 0.70829940 (0.77474979)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00245105 (0.00248584), PSNR 26.10647964 (26.06744065), SSIM 0.77192748 (0.76753319)
# Finished training epoch 67
# Validate: MSE 0.00290073 (0.00245784), PSNR 25.37492371 (26.15787617), SSIM 0.70971203 (0.77238915)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00227211 (0.00248359), PSNR 26.43571472 (26.07142016), SSIM 0.76779610 (0.76749609)
# Finished training epoch 68
# Validate: MSE 0.00285355 (0.00246389), PSNR 25.44614029 (26.14320684), SSIM 0.70939016 (0.77245941)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00227809 (0.00249424), PSNR 26.42428207 (26.05299437), SSIM 0.75525057 (0.76760195)
# Finished training epoch 69
# Validate: MSE 0.00292819 (0.00244643), PSNR 25.33400726 (26.17761881), SSIM 0.70931208 (0.77539502)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00232126 (0.00248644), PSNR 26.34276199 (26.06915150), SSIM 0.77681673 (0.76775851)
# Finished training epoch 70
# Validate: MSE 0.00292817 (0.00246578), PSNR 25.33403206 (26.14695335), SSIM 0.71283191 (0.77591580)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00244595 (0.00248001), PSNR 26.11551476 (26.07837200), SSIM 0.76736653 (0.76799638)
# Finished training epoch 71
# Validate: MSE 0.00293691 (0.00244773), PSNR 25.32109833 (26.17725133), SSIM 0.71230459 (0.77619290)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00239758 (0.00249163), PSNR 26.20226860 (26.05677882), SSIM 0.75599796 (0.76806252)
# Finished training epoch 72
# Validate: MSE 0.00296917 (0.00244737), PSNR 25.27364922 (26.17954719), SSIM 0.70933783 (0.77661827)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00290302 (0.00247999), PSNR 25.37150383 (26.07804471), SSIM 0.74586594 (0.76811937)
# Finished training epoch 73
# Validate: MSE 0.00295444 (0.00246203), PSNR 25.29525375 (26.15200649), SSIM 0.71154630 (0.77817038)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00211373 (0.00248345), PSNR 26.74950981 (26.07276892), SSIM 0.76176906 (0.76824833)
# Finished training epoch 74
# Validate: MSE 0.00292901 (0.00244195), PSNR 25.33278847 (26.18765810), SSIM 0.71133548 (0.77669437)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00216403 (0.00247330), PSNR 26.64737129 (26.09142168), SSIM 0.77578205 (0.76842976)
# Finished training epoch 75
# Validate: MSE 0.00285291 (0.00243727), PSNR 25.44711494 (26.19253780), SSIM 0.71074170 (0.77459761)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00266527 (0.00247408), PSNR 25.74258041 (26.08877585), SSIM 0.74991173 (0.76850549)
# Finished training epoch 76
# Validate: MSE 0.00289719 (0.00243803), PSNR 25.38022232 (26.19146461), SSIM 0.71035945 (0.77362077)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00291351 (0.00247460), PSNR 25.35583878 (26.08822024), SSIM 0.76294649 (0.76844721)
# Finished training epoch 77
# Validate: MSE 0.00295980 (0.00246709), PSNR 25.28738022 (26.14464247), SSIM 0.71437967 (0.77598558)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00237825 (0.00247258), PSNR 26.23741913 (26.08912934), SSIM 0.75844830 (0.76878217)
# Finished training epoch 78
# Validate: MSE 0.00285244 (0.00244466), PSNR 25.44782829 (26.17857136), SSIM 0.71001226 (0.77340817)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00261242 (0.00247759), PSNR 25.82957649 (26.08385043), SSIM 0.78301924 (0.76850076)
# Finished training epoch 79
# Validate: MSE 0.00288461 (0.00243817), PSNR 25.39913368 (26.19189167), SSIM 0.71016014 (0.77451869)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00269118 (0.00246664), PSNR 25.70057106 (26.10027786), SSIM 0.74833524 (0.76885337)
# Finished training epoch 80
# Validate: MSE 0.00292706 (0.00245605), PSNR 25.33567429 (26.16134702), SSIM 0.70970774 (0.77319873)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00211045 (0.00247194), PSNR 26.75624084 (26.09251949), SSIM 0.75963974 (0.76849301)
# Finished training epoch 81
# Validate: MSE 0.00292042 (0.00245306), PSNR 25.34554100 (26.16857083), SSIM 0.71408844 (0.77956902)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00265148 (0.00246728), PSNR 25.76512146 (26.10101345), SSIM 0.75491858 (0.76881491)
# Finished training epoch 82
# Validate: MSE 0.00285521 (0.00245453), PSNR 25.44361687 (26.16374070), SSIM 0.71013951 (0.77371355)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00193687 (0.00247489), PSNR 27.12900162 (26.08581301), SSIM 0.77370489 (0.76885420)
# Finished training epoch 83
# Validate: MSE 0.00290086 (0.00243497), PSNR 25.37472725 (26.19883601), SSIM 0.71139610 (0.77524130)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00236208 (0.00247107), PSNR 26.26705360 (26.09302141), SSIM 0.77374589 (0.76907157)
# Finished training epoch 84
# Validate: MSE 0.00292585 (0.00244459), PSNR 25.33747482 (26.18415866), SSIM 0.71246839 (0.77513013)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00207336 (0.00246998), PSNR 26.83326149 (26.09663625), SSIM 0.79401964 (0.76906199)
# Finished training epoch 85
# Validate: MSE 0.00287049 (0.00242746), PSNR 25.42043304 (26.21098661), SSIM 0.71220058 (0.77451868)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00219273 (0.00247205), PSNR 26.59013748 (26.09463443), SSIM 0.76350814 (0.76917182)
# Finished training epoch 86
# Validate: MSE 0.00297315 (0.00245165), PSNR 25.26782608 (26.17196680), SSIM 0.71256572 (0.77817948)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00251077 (0.00247203), PSNR 26.00192261 (26.09179899), SSIM 0.76188534 (0.76912616)
# Finished training epoch 87
# Validate: MSE 0.00294468 (0.00246761), PSNR 25.30962181 (26.14195809), SSIM 0.71163797 (0.77370014)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00231295 (0.00245684), PSNR 26.35833359 (26.12092346), SSIM 0.75998068 (0.76941339)
# Finished training epoch 88
# Validate: MSE 0.00288095 (0.00243129), PSNR 25.40463638 (26.20329153), SSIM 0.71094990 (0.77314008)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00179939 (0.00246004), PSNR 27.44874001 (26.11220286), SSIM 0.79007471 (0.76947320)
# Finished training epoch 89
# Validate: MSE 0.00290204 (0.00242709), PSNR 25.37296104 (26.21268546), SSIM 0.71189320 (0.77680728)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00281569 (0.00245994), PSNR 25.50415802 (26.11239053), SSIM 0.77916187 (0.76941890)
# Finished training epoch 90
# Validate: MSE 0.00290468 (0.00243963), PSNR 25.36901665 (26.19075820), SSIM 0.71115947 (0.77648558)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00270411 (0.00245590), PSNR 25.67976189 (26.11709267), SSIM 0.75850546 (0.76954720)
# Finished training epoch 91
# Validate: MSE 0.00284246 (0.00242745), PSNR 25.46305847 (26.20960449), SSIM 0.71127319 (0.77458825)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00303261 (0.00245523), PSNR 25.18183327 (26.12172284), SSIM 0.75962603 (0.76943968)
# Finished training epoch 92
# Validate: MSE 0.00297725 (0.00245891), PSNR 25.26185226 (26.15804457), SSIM 0.71192408 (0.77474099)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00273277 (0.00245810), PSNR 25.63396835 (26.11831312), SSIM 0.77956378 (0.76960699)
# Finished training epoch 93
# Validate: MSE 0.00298599 (0.00245613), PSNR 25.24910736 (26.16355131), SSIM 0.71268600 (0.77865789)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00245849 (0.00245956), PSNR 26.09331512 (26.11301804), SSIM 0.76707667 (0.76959182)
# Finished training epoch 94
# Validate: MSE 0.00287838 (0.00243780), PSNR 25.40852356 (26.19227417), SSIM 0.71268684 (0.77862618)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00272857 (0.00245662), PSNR 25.64064026 (26.12160884), SSIM 0.76090962 (0.76971970)
# Finished training epoch 95
# Validate: MSE 0.00287766 (0.00242170), PSNR 25.40960693 (26.22049321), SSIM 0.71312839 (0.77491517)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00257237 (0.00245897), PSNR 25.89666176 (26.11485134), SSIM 0.75570560 (0.76974721)
# Finished training epoch 96
# Validate: MSE 0.00299332 (0.00246207), PSNR 25.23846054 (26.15217543), SSIM 0.70847493 (0.77441379)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00249865 (0.00245359), PSNR 26.02295303 (26.12414712), SSIM 0.76118839 (0.76998970)
# Finished training epoch 97
# Validate: MSE 0.00295161 (0.00242528), PSNR 25.29940796 (26.21837236), SSIM 0.71280068 (0.77975438)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00230378 (0.00245784), PSNR 26.37559319 (26.11913910), SSIM 0.78784090 (0.76987308)
# Finished training epoch 98
# Validate: MSE 0.00293162 (0.00242242), PSNR 25.32892227 (26.22177156), SSIM 0.71234906 (0.77836830)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00249680 (0.00245300), PSNR 26.02615547 (26.12785320), SSIM 0.77546859 (0.76996585)
# Finished training epoch 99
# Validate: MSE 0.00283450 (0.00242007), PSNR 25.47523689 (26.22225428), SSIM 0.71100825 (0.77610217)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00298102 (0.00245818), PSNR 25.25634766 (26.11688760), SSIM 0.74918485 (0.76996115)
# Finished training epoch 100
# Validate: MSE 0.00301331 (0.00245781), PSNR 25.20956612 (26.16242473), SSIM 0.71556985 (0.77894984)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00273622 (0.00245229), PSNR 25.62848663 (26.12846017), SSIM 0.75626922 (0.77008161)
# Finished training epoch 101
# Validate: MSE 0.00295766 (0.00242789), PSNR 25.29051590 (26.21359576), SSIM 0.71255887 (0.77812503)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00219315 (0.00245185), PSNR 26.58930779 (26.12894683), SSIM 0.77489072 (0.77008050)
# Finished training epoch 102
# Validate: MSE 0.00291021 (0.00243170), PSNR 25.36076164 (26.20454323), SSIM 0.71196467 (0.77704806)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00226987 (0.00244683), PSNR 26.43998718 (26.13610032), SSIM 0.78784490 (0.77006587)
# Finished training epoch 103
# Validate: MSE 0.00289604 (0.00240833), PSNR 25.38195610 (26.24574848), SSIM 0.71128988 (0.77697390)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00309146 (0.00245547), PSNR 25.09835625 (26.12018811), SSIM 0.74761230 (0.77019266)
# Finished training epoch 104
# Validate: MSE 0.00300738 (0.00245386), PSNR 25.21811676 (26.16927457), SSIM 0.71285963 (0.77759095)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00223304 (0.00244616), PSNR 26.51103210 (26.13917969), SSIM 0.74871767 (0.77013522)
# Finished training epoch 105
# Validate: MSE 0.00283445 (0.00242230), PSNR 25.47530746 (26.21895139), SSIM 0.71027744 (0.77689245)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00253488 (0.00244570), PSNR 25.96042633 (26.13903253), SSIM 0.77995789 (0.77011008)
# Finished training epoch 106
# Validate: MSE 0.00288984 (0.00240639), PSNR 25.39126015 (26.25054955), SSIM 0.71399337 (0.77707492)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00215774 (0.00245115), PSNR 26.66001129 (26.12714957), SSIM 0.77579117 (0.77036646)
# Finished training epoch 107
# Validate: MSE 0.00293184 (0.00243634), PSNR 25.32859993 (26.19651792), SSIM 0.71244562 (0.77658218)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00277698 (0.00244746), PSNR 25.56427002 (26.13648287), SSIM 0.75673532 (0.77047445)
# Finished training epoch 108
# Validate: MSE 0.00286028 (0.00241173), PSNR 25.43591499 (26.23888643), SSIM 0.71299028 (0.77832437)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00234159 (0.00244729), PSNR 26.30488777 (26.13519515), SSIM 0.78503072 (0.77028862)
# Finished training epoch 109
# Validate: MSE 0.00294228 (0.00242155), PSNR 25.31316185 (26.22292547), SSIM 0.70899463 (0.77668887)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00225755 (0.00243817), PSNR 26.46363449 (26.15278170), SSIM 0.77984703 (0.77034438)
# Finished training epoch 110
# Validate: MSE 0.00288280 (0.00241490), PSNR 25.40184975 (26.23301020), SSIM 0.71104169 (0.77477123)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00223203 (0.00243836), PSNR 26.51300049 (26.15052349), SSIM 0.77272087 (0.77039618)
# Finished training epoch 111
# Validate: MSE 0.00292429 (0.00240227), PSNR 25.33979034 (26.25688995), SSIM 0.71219605 (0.77669167)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00268085 (0.00244150), PSNR 25.71727562 (26.14799408), SSIM 0.76851618 (0.77033602)
# Finished training epoch 112
# Validate: MSE 0.00291026 (0.00240580), PSNR 25.36067581 (26.25178672), SSIM 0.71344995 (0.77736692)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00275899 (0.00243678), PSNR 25.59249878 (26.15569145), SSIM 0.76294613 (0.77046498)
# Finished training epoch 113
# Validate: MSE 0.00290734 (0.00240711), PSNR 25.36503410 (26.24881631), SSIM 0.71480685 (0.77896486)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00258205 (0.00243016), PSNR 25.88035774 (26.16669505), SSIM 0.76033509 (0.77045448)
# Finished training epoch 114
# Validate: MSE 0.00293698 (0.00240822), PSNR 25.32099533 (26.24630275), SSIM 0.71180898 (0.77699022)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00269176 (0.00243702), PSNR 25.69963074 (26.15212082), SSIM 0.75453436 (0.77044470)
# Finished training epoch 115
# Validate: MSE 0.00291156 (0.00241788), PSNR 25.35874367 (26.22976425), SSIM 0.71236134 (0.77864796)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00233924 (0.00242926), PSNR 26.30925941 (26.16704690), SSIM 0.76891267 (0.77038922)
# Finished training epoch 116
# Validate: MSE 0.00292321 (0.00240555), PSNR 25.34139633 (26.25051779), SSIM 0.71105933 (0.77563350)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00227676 (0.00243507), PSNR 26.42682838 (26.15635522), SSIM 0.75329715 (0.77031136)
# Finished training epoch 117
# Validate: MSE 0.00297550 (0.00245997), PSNR 25.26439667 (26.15909264), SSIM 0.71476471 (0.77902366)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00243179 (0.00243453), PSNR 26.14073753 (26.16086911), SSIM 0.78862965 (0.77043829)
# Finished training epoch 118
# Validate: MSE 0.00286592 (0.00238657), PSNR 25.42735672 (26.28429390), SSIM 0.71175510 (0.77811383)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00304435 (0.00243246), PSNR 25.16505814 (26.16531407), SSIM 0.75767303 (0.77036950)
# Finished training epoch 119
# Validate: MSE 0.00285003 (0.00239158), PSNR 25.45149994 (26.27296735), SSIM 0.71196795 (0.77607493)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00260208 (0.00242921), PSNR 25.84679031 (26.16959542), SSIM 0.77088511 (0.77040175)
# Finished training epoch 120
# Validate: MSE 0.00295202 (0.00241572), PSNR 25.29880524 (26.23338646), SSIM 0.71251589 (0.77845382)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00237271 (0.00243396), PSNR 26.24754715 (26.16027393), SSIM 0.80134982 (0.77002338)
# Finished training epoch 121
# Validate: MSE 0.00286982 (0.00240221), PSNR 25.42145920 (26.25604960), SSIM 0.71142673 (0.77781731)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00314168 (0.00242910), PSNR 25.02837944 (26.16906267), SSIM 0.75275654 (0.77029811)
# Finished training epoch 122
# Validate: MSE 0.00289909 (0.00239615), PSNR 25.37738609 (26.26904369), SSIM 0.71178544 (0.77708331)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00260053 (0.00242776), PSNR 25.84937668 (26.17122047), SSIM 0.76228726 (0.77037025)
# Finished training epoch 123
# Validate: MSE 0.00284258 (0.00238262), PSNR 25.46286774 (26.29081918), SSIM 0.71203923 (0.77795585)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00201771 (0.00242554), PSNR 26.95141792 (26.17354483), SSIM 0.76814115 (0.77035931)
# Finished training epoch 124
# Validate: MSE 0.00283054 (0.00240478), PSNR 25.48131180 (26.24991038), SSIM 0.71050072 (0.77725810)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00254226 (0.00241806), PSNR 25.94780159 (26.18826624), SSIM 0.78212833 (0.77026542)
# Finished training epoch 125
# Validate: MSE 0.00280109 (0.00240072), PSNR 25.52672195 (26.25607750), SSIM 0.71112019 (0.77730114)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00264199 (0.00241987), PSNR 25.78068542 (26.18504071), SSIM 0.77784222 (0.77018520)
# Finished training epoch 126
# Validate: MSE 0.00277596 (0.00242858), PSNR 25.56587410 (26.20329624), SSIM 0.70866227 (0.77417797)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00239391 (0.00242775), PSNR 26.20891762 (26.17022277), SSIM 0.75632852 (0.77031199)
# Finished training epoch 127
# Validate: MSE 0.00286299 (0.00238773), PSNR 25.43180084 (26.28182142), SSIM 0.71035051 (0.77670683)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00234330 (0.00242097), PSNR 26.30172539 (26.18290406), SSIM 0.74331951 (0.77039199)
# Finished training epoch 128
# Validate: MSE 0.00279174 (0.00239300), PSNR 25.54124260 (26.26851169), SSIM 0.70964098 (0.77557490)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00217354 (0.00242326), PSNR 26.62831497 (26.18376977), SSIM 0.78904855 (0.77022993)
# Finished training epoch 129
# Validate: MSE 0.00285225 (0.00238848), PSNR 25.44811821 (26.28106318), SSIM 0.71439481 (0.77994084)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00256204 (0.00241977), PSNR 25.91414070 (26.18758703), SSIM 0.76955545 (0.77008626)
# Finished training epoch 130
# Validate: MSE 0.00280812 (0.00238128), PSNR 25.51584625 (26.29203995), SSIM 0.71434546 (0.77780624)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00259141 (0.00241470), PSNR 25.86463737 (26.19488398), SSIM 0.76190060 (0.77034107)
# Finished training epoch 131
# Validate: MSE 0.00295294 (0.00242127), PSNR 25.29745483 (26.22505183), SSIM 0.71126890 (0.77701790)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00234715 (0.00242403), PSNR 26.29458618 (26.17645478), SSIM 0.75978005 (0.77020702)
# Finished training epoch 132
# Validate: MSE 0.00284333 (0.00238319), PSNR 25.46172714 (26.29084948), SSIM 0.71229088 (0.77609762)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00181796 (0.00241321), PSNR 27.40415382 (26.19564459), SSIM 0.78683215 (0.77027404)
# Finished training epoch 133
# Validate: MSE 0.00297123 (0.00240881), PSNR 25.27064323 (26.24878471), SSIM 0.71296704 (0.77984543)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00229828 (0.00241564), PSNR 26.38596725 (26.19209434), SSIM 0.77635485 (0.77044588)
# Finished training epoch 134
# Validate: MSE 0.00293120 (0.00238852), PSNR 25.32954788 (26.28274905), SSIM 0.71384287 (0.77852343)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00262636 (0.00241217), PSNR 25.80645180 (26.19968705), SSIM 0.75996214 (0.77051492)
# Finished training epoch 135
# Validate: MSE 0.00283852 (0.00238217), PSNR 25.46907806 (26.29054437), SSIM 0.71105540 (0.77345575)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00209164 (0.00240573), PSNR 26.79513741 (26.21041195), SSIM 0.77883744 (0.77052445)
# Finished training epoch 136
# Validate: MSE 0.00284281 (0.00237501), PSNR 25.46251678 (26.30564186), SSIM 0.71441859 (0.77878270)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00239317 (0.00240901), PSNR 26.21025658 (26.20484576), SSIM 0.79147524 (0.77026452)
# Finished training epoch 137
# Validate: MSE 0.00280692 (0.00236805), PSNR 25.51769066 (26.31784991), SSIM 0.71144009 (0.77802397)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00251755 (0.00241422), PSNR 25.99021912 (26.19530764), SSIM 0.77831918 (0.77035950)
# Finished training epoch 138
# Validate: MSE 0.00293379 (0.00243422), PSNR 25.32571602 (26.20345594), SSIM 0.71266389 (0.77594717)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00194115 (0.00240977), PSNR 27.11941528 (26.20245196), SSIM 0.78450817 (0.77063311)
# Finished training epoch 139
# Validate: MSE 0.00289448 (0.00241865), PSNR 25.38428688 (26.23070304), SSIM 0.71285880 (0.77866170)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00331465 (0.00241003), PSNR 24.79562569 (26.20184660), SSIM 0.76375800 (0.77076339)
# Finished training epoch 140
# Validate: MSE 0.00282977 (0.00238316), PSNR 25.48248863 (26.29123949), SSIM 0.71324527 (0.77930371)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00324113 (0.00240124), PSNR 24.89303970 (26.21737283), SSIM 0.75118297 (0.77066919)
# Finished training epoch 141
# Validate: MSE 0.00293031 (0.00243929), PSNR 25.33086967 (26.19481601), SSIM 0.71269512 (0.77649212)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00266886 (0.00239892), PSNR 25.73674202 (26.22487150), SSIM 0.78464502 (0.77074857)
# Finished training epoch 142
# Validate: MSE 0.00277277 (0.00237330), PSNR 25.57085228 (26.30799557), SSIM 0.71136296 (0.77691250)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00171129 (0.00240838), PSNR 27.66676712 (26.20573625), SSIM 0.80065137 (0.77053800)
# Finished training epoch 143
# Validate: MSE 0.00286466 (0.00238578), PSNR 25.42926979 (26.28849657), SSIM 0.71432161 (0.77938710)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00235966 (0.00240828), PSNR 26.27149773 (26.20574072), SSIM 0.77146757 (0.77073237)
# Finished training epoch 144
# Validate: MSE 0.00287081 (0.00243905), PSNR 25.41995811 (26.19226751), SSIM 0.71305931 (0.77478111)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00205222 (0.00240241), PSNR 26.87775612 (26.21467188), SSIM 0.77531087 (0.77068622)
# Finished training epoch 145
# Validate: MSE 0.00281311 (0.00236121), PSNR 25.50812912 (26.33046638), SSIM 0.71313739 (0.77893608)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00218750 (0.00240530), PSNR 26.60051537 (26.21063860), SSIM 0.76571000 (0.77081760)
# Finished training epoch 146
# Validate: MSE 0.00283543 (0.00239060), PSNR 25.47380829 (26.27897770), SSIM 0.71313614 (0.77731077)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00240632 (0.00240120), PSNR 26.18646431 (26.21710564), SSIM 0.77501762 (0.77094607)
# Finished training epoch 147
# Validate: MSE 0.00285389 (0.00235906), PSNR 25.44563293 (26.33480186), SSIM 0.71344662 (0.77893562)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00192470 (0.00240106), PSNR 27.15637589 (26.21929375), SSIM 0.80581397 (0.77093605)
# Finished training epoch 148
# Validate: MSE 0.00278482 (0.00235976), PSNR 25.55203056 (26.33394704), SSIM 0.71292013 (0.77953881)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00246467 (0.00240534), PSNR 26.08240891 (26.21055364), SSIM 0.76323354 (0.77071627)
# Finished training epoch 149
# Validate: MSE 0.00280102 (0.00236476), PSNR 25.52683640 (26.32185410), SSIM 0.71056688 (0.77699758)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00203706 (0.00239579), PSNR 26.90997124 (26.23212643), SSIM 0.79697168 (0.77107326)
# Finished training epoch 150
# Validate: MSE 0.00279885 (0.00236293), PSNR 25.53020859 (26.32818906), SSIM 0.71572793 (0.77919368)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00231057 (0.00239898), PSNR 26.36281586 (26.22264719), SSIM 0.76535094 (0.77086303)
# Finished training epoch 151
# Validate: MSE 0.00279761 (0.00237219), PSNR 25.53212547 (26.30887533), SSIM 0.70963526 (0.77756897)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00219778 (0.00239840), PSNR 26.58015251 (26.22674203), SSIM 0.76975423 (0.77107627)
# Finished training epoch 152
# Validate: MSE 0.00287661 (0.00236993), PSNR 25.41118813 (26.31706415), SSIM 0.71469045 (0.77928361)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00238998 (0.00240721), PSNR 26.21605873 (26.20917529), SSIM 0.78493583 (0.77095154)
# Finished training epoch 153
# Validate: MSE 0.00275420 (0.00235954), PSNR 25.60004997 (26.33082341), SSIM 0.71167064 (0.77668812)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00255505 (0.00240450), PSNR 25.92600060 (26.21468781), SSIM 0.76956534 (0.77082323)
# Finished training epoch 154
# Validate: MSE 0.00281476 (0.00236191), PSNR 25.50558472 (26.32851836), SSIM 0.71303439 (0.77914414)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00246350 (0.00240461), PSNR 26.08448219 (26.21245635), SSIM 0.76954275 (0.77095658)
# Finished training epoch 155
# Validate: MSE 0.00284437 (0.00237621), PSNR 25.46013832 (26.30589787), SSIM 0.71453249 (0.77984465)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00272359 (0.00239159), PSNR 25.64858437 (26.23517128), SSIM 0.77746540 (0.77111536)
# Finished training epoch 156
# Validate: MSE 0.00286302 (0.00236838), PSNR 25.43175316 (26.31760453), SSIM 0.71128058 (0.77721557)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00221178 (0.00239371), PSNR 26.55257988 (26.23128752), SSIM 0.78999120 (0.77105897)
# Finished training epoch 157
# Validate: MSE 0.00282128 (0.00236910), PSNR 25.49553490 (26.31614749), SSIM 0.71412504 (0.77857329)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00209540 (0.00239589), PSNR 26.78734016 (26.22767386), SSIM 0.78368515 (0.77097667)
# Finished training epoch 158
# Validate: MSE 0.00286412 (0.00237560), PSNR 25.43008614 (26.30777898), SSIM 0.71516716 (0.78022542)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00196675 (0.00239142), PSNR 27.06250954 (26.23576640), SSIM 0.77955711 (0.77137020)
# Finished training epoch 159
# Validate: MSE 0.00292526 (0.00249427), PSNR 25.33835220 (26.09989019), SSIM 0.71409237 (0.77664708)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00243361 (0.00239730), PSNR 26.13749504 (26.22479128), SSIM 0.78041786 (0.77122990)
# Finished training epoch 160
# Validate: MSE 0.00279719 (0.00235198), PSNR 25.53277206 (26.34615820), SSIM 0.71240592 (0.77849792)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00311123 (0.00239430), PSNR 25.07067299 (26.23017320), SSIM 0.77411819 (0.77128972)
# Finished training epoch 161
# Validate: MSE 0.00272992 (0.00238986), PSNR 25.63849640 (26.27291586), SSIM 0.71008694 (0.77708705)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00167329 (0.00240128), PSNR 27.76429367 (26.21720778), SSIM 0.77250922 (0.77132911)
# Finished training epoch 162
# Validate: MSE 0.00276551 (0.00234977), PSNR 25.58224869 (26.35019879), SSIM 0.71372294 (0.77872938)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00231604 (0.00239964), PSNR 26.35253906 (26.22297963), SSIM 0.77408588 (0.77115504)
# Finished training epoch 163
# Validate: MSE 0.00275752 (0.00235581), PSNR 25.59481239 (26.33725727), SSIM 0.71095031 (0.77677849)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00219599 (0.00238939), PSNR 26.58369064 (26.23833716), SSIM 0.76583505 (0.77142410)
# Finished training epoch 164
# Validate: MSE 0.00276607 (0.00236637), PSNR 25.58137512 (26.31676587), SSIM 0.70997649 (0.77451548)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00228993 (0.00238603), PSNR 26.40178299 (26.24864859), SSIM 0.77785337 (0.77129593)
# Finished training epoch 165
# Validate: MSE 0.00283301 (0.00236758), PSNR 25.47751236 (26.31803235), SSIM 0.71160799 (0.77492597)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00227970 (0.00238782), PSNR 26.42122650 (26.24403308), SSIM 0.78784937 (0.77137580)
# Finished training epoch 166
# Validate: MSE 0.00280915 (0.00235801), PSNR 25.51424789 (26.33724062), SSIM 0.71477306 (0.78001158)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00250779 (0.00238679), PSNR 26.00708199 (26.24465235), SSIM 0.76316297 (0.77156304)
# Finished training epoch 167
# Validate: MSE 0.00282842 (0.00235405), PSNR 25.48456573 (26.34369274), SSIM 0.71219528 (0.77945278)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00226723 (0.00239191), PSNR 26.44504356 (26.23338893), SSIM 0.77371615 (0.77135356)
# Finished training epoch 168
# Validate: MSE 0.00282876 (0.00236125), PSNR 25.48403740 (26.33288235), SSIM 0.71401387 (0.77875422)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00196235 (0.00238567), PSNR 27.07222939 (26.24781519), SSIM 0.76993668 (0.77161842)
# Finished training epoch 169
# Validate: MSE 0.00282866 (0.00236814), PSNR 25.48419189 (26.31960613), SSIM 0.71413678 (0.78050629)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00248659 (0.00239516), PSNR 26.04395294 (26.23210393), SSIM 0.77377319 (0.77142384)
# Finished training epoch 170
# Validate: MSE 0.00280503 (0.00237228), PSNR 25.52062225 (26.31111508), SSIM 0.71367216 (0.77877648)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00282633 (0.00238767), PSNR 25.48776436 (26.24083317), SSIM 0.75634098 (0.77144337)
# Finished training epoch 171
# Validate: MSE 0.00279037 (0.00234108), PSNR 25.54338264 (26.36731997), SSIM 0.71231252 (0.77863971)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00183642 (0.00238006), PSNR 27.36028290 (26.25516276), SSIM 0.79099381 (0.77185577)
# Finished training epoch 172
# Validate: MSE 0.00276668 (0.00234796), PSNR 25.58041573 (26.35309170), SSIM 0.71413815 (0.77974882)
# Finished validation.
# Starting training epoch 173
# ...
# Finished validation.
# Starting training epoch 343
# Epoch: 343, MSE 0.00256168 (0.00232621), PSNR 25.91474533 (26.35787676), SSIM 0.78151667 (0.77525517)
# Finished training epoch 343
# Validate: MSE 0.00290647 (0.00241721), PSNR 25.36634636 (26.23357881), SSIM 0.71310759 (0.77990130)
# Finished validation.
# Starting training epoch 344
# Epoch: 344, MSE 0.00213311 (0.00231813), PSNR 26.70987129 (26.37074964), SSIM 0.78007281 (0.77539392)
# Finished training epoch 344
# Validate: MSE 0.00263345 (0.00229081), PSNR 25.79475403 (26.45477180), SSIM 0.71647441 (0.77941780)
# Finished validation.
# Starting training epoch 345
# Epoch: 345, MSE 0.00285871 (0.00232664), PSNR 25.43830299 (26.35565378), SSIM 0.75506121 (0.77515407)
# Finished training epoch 345
# Validate: MSE 0.00274789 (0.00229820), PSNR 25.61001015 (26.44937921), SSIM 0.71721947 (0.78490703)
# Finished validation.
# Starting training epoch 346
# Epoch: 346, MSE 0.00223847 (0.00232545), PSNR 26.50047874 (26.35634715), SSIM 0.77508128 (0.77532367)
# Finished training epoch 346
# Validate: MSE 0.00279315 (0.00245079), PSNR 25.53905869 (26.17416459), SSIM 0.71700227 (0.77845123)
# Finished validation.
# Starting training epoch 347
# Epoch: 347, MSE 0.00233882 (0.00232060), PSNR 26.31003761 (26.36547781), SSIM 0.77401793 (0.77550710)
# Finished training epoch 347
# Validate: MSE 0.00273713 (0.00235168), PSNR 25.62704659 (26.35122122), SSIM 0.71882492 (0.78294258)
# Finished validation.
# Starting training epoch 348
# Epoch: 348, MSE 0.00206167 (0.00233205), PSNR 26.85780525 (26.34596174), SSIM 0.77782142 (0.77532742)
# Finished training epoch 348
# Validate: MSE 0.00276412 (0.00229749), PSNR 25.58442307 (26.45019330), SSIM 0.71837986 (0.78449402)
# Finished validation.
# Starting training epoch 349
# Epoch: 349, MSE 0.00222182 (0.00232177), PSNR 26.53290558 (26.36297060), SSIM 0.79167390 (0.77521751)
# Finished training epoch 349
# Validate: MSE 0.00262014 (0.00227403), PSNR 25.81674576 (26.49200445), SSIM 0.71697056 (0.78245041)
# Finished validation.
# Starting training epoch 350
# Epoch: 350, MSE 0.00231983 (0.00232526), PSNR 26.34544182 (26.36003513), SSIM 0.75560462 (0.77544839)
# Finished training epoch 350
# Validate: MSE 0.00273162 (0.00230312), PSNR 25.63579941 (26.43307314), SSIM 0.71256554 (0.77936977)
# Finished validation.
# Starting training epoch 351
# Epoch: 351, MSE 0.00177846 (0.00232033), PSNR 27.49956131 (26.36757683), SSIM 0.79411632 (0.77518842)
# Finished training epoch 351
# Validate: MSE 0.00278485 (0.00234726), PSNR 25.55197906 (26.36050851), SSIM 0.71830130 (0.78240663)
# Finished validation.
# Starting training epoch 352
# Epoch: 352, MSE 0.00228652 (0.00231704), PSNR 26.40824127 (26.37391968), SSIM 0.80380374 (0.77568568)
# Finished training epoch 352
# Validate: MSE 0.00269606 (0.00232260), PSNR 25.69270515 (26.39945801), SSIM 0.71924806 (0.78290763)
# Finished validation.
# Starting training epoch 353
# Epoch: 353, MSE 0.00226151 (0.00232119), PSNR 26.45602226 (26.36525698), SSIM 0.77704918 (0.77527397)
# Finished training epoch 353
# Validate: MSE 0.00265467 (0.00229230), PSNR 25.75988770 (26.45468103), SSIM 0.71636808 (0.78145261)
# Finished validation.
# Starting training epoch 354
# Epoch: 354, MSE 0.00249749 (0.00232564), PSNR 26.02495575 (26.35724568), SSIM 0.77511406 (0.77532074)
# Finished training epoch 354
# Validate: MSE 0.00276318 (0.00231721), PSNR 25.58590317 (26.41291555), SSIM 0.71953702 (0.78294147)
# Finished validation.
# Starting training epoch 355
# Epoch: 355, MSE 0.00178679 (0.00231352), PSNR 27.47925377 (26.38017198), SSIM 0.76826549 (0.77561982)
# Finished training epoch 355
# Validate: MSE 0.00264855 (0.00228602), PSNR 25.76991844 (26.46558585), SSIM 0.71458197 (0.77966639)
# Finished validation.
# Starting training epoch 356
# Epoch: 356, MSE 0.00186344 (0.00231846), PSNR 27.29683876 (26.36797190), SSIM 0.78949374 (0.77539962)
# Finished training epoch 356
# Validate: MSE 0.00270948 (0.00231556), PSNR 25.67114449 (26.41516702), SSIM 0.71337539 (0.78134290)
# Finished validation.
# Starting training epoch 357
# Epoch: 357, MSE 0.00261788 (0.00232541), PSNR 25.82050514 (26.35918398), SSIM 0.76435834 (0.77525523)
# Finished training epoch 357
# Validate: MSE 0.00287246 (0.00239536), PSNR 25.41746140 (26.27566996), SSIM 0.71743667 (0.78288187)
# Finished validation.
# Starting training epoch 358
# Epoch: 358, MSE 0.00293969 (0.00231635), PSNR 25.31698799 (26.37358156), SSIM 0.77808815 (0.77560664)
# Finished training epoch 358
# Validate: MSE 0.00266250 (0.00234527), PSNR 25.74710083 (26.35662808), SSIM 0.71702874 (0.78254452)
# Finished validation.
# Starting training epoch 359
# Epoch: 359, MSE 0.00213228 (0.00232254), PSNR 26.71155548 (26.36307474), SSIM 0.78423470 (0.77539572)
# Finished training epoch 359
# Validate: MSE 0.00276519 (0.00236951), PSNR 25.58274651 (26.31156255), SSIM 0.71530461 (0.78009796)
# Finished validation.
# Starting training epoch 360
# Epoch: 360, MSE 0.00295328 (0.00231177), PSNR 25.29695702 (26.38412864), SSIM 0.72315413 (0.77551709)
# Finished training epoch 360
# Validate: MSE 0.00311721 (0.00274843), PSNR 25.06234360 (25.68049323), SSIM 0.71164072 (0.77479930)
# Finished validation.
# Starting training epoch 361
# Epoch: 361, MSE 0.00199327 (0.00231832), PSNR 27.00433159 (26.37244363), SSIM 0.79488164 (0.77551192)
# Finished training epoch 361
# Validate: MSE 0.00270242 (0.00239079), PSNR 25.68246651 (26.28041680), SSIM 0.71640766 (0.77988744)
# Finished validation.
# Starting training epoch 362
# Epoch: 362, MSE 0.00242072 (0.00232368), PSNR 26.16055489 (26.36064015), SSIM 0.77575910 (0.77542821)
# Finished training epoch 362
# Validate: MSE 0.00267388 (0.00230393), PSNR 25.72858238 (26.43674513), SSIM 0.71583396 (0.78249482)
# Finished validation.
# Starting training epoch 363
# Epoch: 363, MSE 0.00242312 (0.00232458), PSNR 26.15625191 (26.35994288), SSIM 0.78661460 (0.77524280)
# Finished training epoch 363
# Validate: MSE 0.00265993 (0.00232575), PSNR 25.75130272 (26.39128260), SSIM 0.71726882 (0.77775599)
# Finished validation.
# Starting training epoch 364
# Epoch: 364, MSE 0.00220553 (0.00232252), PSNR 26.56486893 (26.36068471), SSIM 0.76293755 (0.77547376)
# Finished training epoch 364
# Validate: MSE 0.00265486 (0.00229854), PSNR 25.75958443 (26.44216001), SSIM 0.71815789 (0.78223730)
# Finished validation.
# Starting training epoch 365
# Epoch: 365, MSE 0.00253391 (0.00231157), PSNR 25.96209335 (26.38558145), SSIM 0.77432513 (0.77550224)
# Finished training epoch 365
# Validate: MSE 0.00271474 (0.00238055), PSNR 25.66272163 (26.29705794), SSIM 0.71964872 (0.78152986)
# Finished validation.
# Starting training epoch 366
# Epoch: 366, MSE 0.00289852 (0.00232945), PSNR 25.37822914 (26.35062836), SSIM 0.76459634 (0.77541472)
# Finished training epoch 366
# Validate: MSE 0.00259371 (0.00236593), PSNR 25.86078072 (26.31137991), SSIM 0.71580195 (0.77974198)
# Finished validation.
# Starting training epoch 367
# Epoch: 367, MSE 0.00199502 (0.00231466), PSNR 27.00053596 (26.37854902), SSIM 0.78102309 (0.77561462)
# Finished training epoch 367
# Validate: MSE 0.00288505 (0.00234967), PSNR 25.39846420 (26.35803229), SSIM 0.71758127 (0.78430943)
# Finished validation.
# Starting training epoch 368
# Epoch: 368, MSE 0.00198030 (0.00231737), PSNR 27.03269196 (26.37264353), SSIM 0.77793157 (0.77578307)
# Finished training epoch 368
# Validate: MSE 0.00266479 (0.00227941), PSNR 25.74336052 (26.47984077), SSIM 0.71920276 (0.78094554)
# Finished validation.
# Starting training epoch 369
# Epoch: 369, MSE 0.00233852 (0.00231861), PSNR 26.31058121 (26.37283497), SSIM 0.78898418 (0.77574697)
# Finished training epoch 369
# Validate: MSE 0.00265751 (0.00228446), PSNR 25.75524902 (26.47193245), SSIM 0.71392393 (0.78089216)
# Finished validation.
# Starting training epoch 370
# Epoch: 370, MSE 0.00278099 (0.00231595), PSNR 25.55800438 (26.37390997), SSIM 0.78574914 (0.77571117)
# Finished training epoch 370
# Validate: MSE 0.00260280 (0.00235075), PSNR 25.84558678 (26.34605164), SSIM 0.71666008 (0.78136175)
# Finished validation.
# Starting training epoch 371
# Epoch: 371, MSE 0.00245684 (0.00231185), PSNR 26.09622765 (26.38376518), SSIM 0.77522385 (0.77564401)
# Finished training epoch 371
# Validate: MSE 0.00274136 (0.00227565), PSNR 25.62034416 (26.48852302), SSIM 0.71699119 (0.78345444)
# Finished validation.
# Starting training epoch 372
# Epoch: 372, MSE 0.00224543 (0.00231368), PSNR 26.48700142 (26.38169606), SSIM 0.77225053 (0.77570861)
# Finished training epoch 372
# Validate: MSE 0.00275570 (0.00242789), PSNR 25.59768677 (26.21682720), SSIM 0.71667713 (0.78056137)
# Finished validation.
# Starting training epoch 373
# Epoch: 373, MSE 0.00216335 (0.00231041), PSNR 26.64872932 (26.38599330), SSIM 0.79784954 (0.77579621)
# Finished training epoch 373
# Validate: MSE 0.00277438 (0.00235659), PSNR 25.56834221 (26.34399070), SSIM 0.71971816 (0.78342202)
# Finished validation.
# Starting training epoch 374
# Epoch: 374, MSE 0.00216707 (0.00231384), PSNR 26.64126396 (26.38001157), SSIM 0.77593625 (0.77567488)
# Finished training epoch 374
# Validate: MSE 0.00290414 (0.00255889), PSNR 25.36981964 (25.98483658), SSIM 0.71326607 (0.77309984)
# Finished validation.
# Starting training epoch 375
# Epoch: 375, MSE 0.00231377 (0.00231532), PSNR 26.35680008 (26.37488256), SSIM 0.77756351 (0.77562103)
# Finished training epoch 375
# Validate: MSE 0.00273055 (0.00229461), PSNR 25.63750267 (26.45322569), SSIM 0.71538603 (0.78125945)
# Finished validation.
# Starting training epoch 376
# Epoch: 376, MSE 0.00248129 (0.00231394), PSNR 26.05321503 (26.37927052), SSIM 0.77636123 (0.77584079)
# Finished training epoch 376
# Validate: MSE 0.00281038 (0.00234309), PSNR 25.51234245 (26.36709821), SSIM 0.71254349 (0.77937345)
# Finished validation.
# Starting training epoch 377
# Epoch: 377, MSE 0.00242719 (0.00231471), PSNR 26.14896011 (26.37707249), SSIM 0.77975839 (0.77567943)
# Finished training epoch 377
# Validate: MSE 0.00264020 (0.00228274), PSNR 25.78362465 (26.47659352), SSIM 0.72099692 (0.78402414)
# Finished validation.
# Starting training epoch 378
# Epoch: 378, MSE 0.00191976 (0.00231452), PSNR 27.16753387 (26.37722678), SSIM 0.80228579 (0.77562820)
# Finished training epoch 378
# Validate: MSE 0.00264503 (0.00228741), PSNR 25.77569199 (26.46290344), SSIM 0.71866030 (0.78120147)
# Finished validation.
# Starting training epoch 379
# Epoch: 379, MSE 0.00245692 (0.00231024), PSNR 26.09608078 (26.38748373), SSIM 0.76944417 (0.77592451)
# Finished training epoch 379
# Validate: MSE 0.00295826 (0.00243732), PSNR 25.28963280 (26.19753487), SSIM 0.71609211 (0.78065225)
# Finished validation.
# Starting training epoch 380
# Epoch: 380, MSE 0.00301052 (0.00231008), PSNR 25.21358299 (26.38745431), SSIM 0.76092249 (0.77591101)
# Finished training epoch 380
# Validate: MSE 0.00281386 (0.00236131), PSNR 25.50697327 (26.33782419), SSIM 0.71990812 (0.78327467)
# Finished validation.
# Starting training epoch 381
# Epoch: 381, MSE 0.00246931 (0.00231653), PSNR 26.07423973 (26.37648602), SSIM 0.77765065 (0.77565851)
# Finished training epoch 381
# Validate: MSE 0.00275913 (0.00232254), PSNR 25.59228516 (26.39786162), SSIM 0.71852565 (0.78321313)
# Finished validation.
# Starting training epoch 382
# Epoch: 382, MSE 0.00242645 (0.00231357), PSNR 26.15028000 (26.37898746), SSIM 0.76787150 (0.77588371)
# Finished training epoch 382
# Validate: MSE 0.00267239 (0.00230384), PSNR 25.73100471 (26.43976870), SSIM 0.71633965 (0.78360338)
# Finished validation.
# Starting training epoch 383
# Epoch: 383, MSE 0.00168659 (0.00231419), PSNR 27.72989273 (26.38044900), SSIM 0.79610485 (0.77567714)
# Finished training epoch 383
# Validate: MSE 0.00273248 (0.00227814), PSNR 25.63443184 (26.48200430), SSIM 0.71502697 (0.78104231)
# Finished validation.
# Starting training epoch 384
# Epoch: 384, MSE 0.00212248 (0.00230871), PSNR 26.73156738 (26.38672696), SSIM 0.76960629 (0.77583272)
# Finished training epoch 384
# Validate: MSE 0.00264705 (0.00242823), PSNR 25.77238083 (26.19756691), SSIM 0.71642482 (0.77682286)
# Finished validation.
# Starting training epoch 385
# Epoch: 385, MSE 0.00204330 (0.00231000), PSNR 26.89668083 (26.38481015), SSIM 0.78738475 (0.77587518)
# Finished training epoch 385
# Validate: MSE 0.00272961 (0.00228576), PSNR 25.63899422 (26.47395301), SSIM 0.71827322 (0.78310487)
# Finished validation.
# Starting training epoch 386
# Epoch: 386, MSE 0.00269133 (0.00230920), PSNR 25.70032883 (26.38682605), SSIM 0.76719654 (0.77580731)
# Finished training epoch 386
# Validate: MSE 0.00280734 (0.00230097), PSNR 25.51705360 (26.44581022), SSIM 0.71731383 (0.78558876)
# Finished validation.
# Starting training epoch 387
# Epoch: 387, MSE 0.00219828 (0.00231446), PSNR 26.57916832 (26.37687164), SSIM 0.78606236 (0.77579230)
# Finished training epoch 387
# Validate: MSE 0.00292675 (0.00251430), PSNR 25.33614540 (26.06999545), SSIM 0.71698374 (0.78241991)
# Finished validation.
# Starting training epoch 388
# Epoch: 388, MSE 0.00227233 (0.00230956), PSNR 26.43528748 (26.38944634), SSIM 0.78317130 (0.77577991)
# Finished training epoch 388
# Validate: MSE 0.00271856 (0.00227761), PSNR 25.65661621 (26.48156709), SSIM 0.71435946 (0.78146040)
# Finished validation.
# Starting training epoch 389
# Epoch: 389, MSE 0.00244307 (0.00231412), PSNR 26.12064362 (26.38044572), SSIM 0.77462351 (0.77598136)
# Finished training epoch 389
# Validate: MSE 0.00258415 (0.00233414), PSNR 25.87681770 (26.37466275), SSIM 0.72050226 (0.78060551)
# Finished validation.
# Starting training epoch 390
# Epoch: 390, MSE 0.00211097 (0.00230624), PSNR 26.75518227 (26.39451437), SSIM 0.78179872 (0.77579280)
# Finished training epoch 390
# Validate: MSE 0.00272323 (0.00232221), PSNR 25.64915466 (26.40004163), SSIM 0.71502185 (0.78149132)
# Finished validation.
# Starting training epoch 391
# Epoch: 391, MSE 0.00214302 (0.00231391), PSNR 26.68974304 (26.37808781), SSIM 0.79802847 (0.77556232)
# Finished training epoch 391
# Validate: MSE 0.00298452 (0.00255118), PSNR 25.25125313 (26.01419117), SSIM 0.71399665 (0.78042113)
# Finished validation.
# Starting training epoch 392
# Epoch: 392, MSE 0.00249805 (0.00232231), PSNR 26.02398872 (26.36411852), SSIM 0.79340285 (0.77590894)
# Finished training epoch 392
# Validate: MSE 0.00267710 (0.00245287), PSNR 25.72335434 (26.16385671), SSIM 0.72074926 (0.78391274)
# Finished validation.
# Starting training epoch 393
# Epoch: 393, MSE 0.00289184 (0.00231443), PSNR 25.38825989 (26.37901759), SSIM 0.77017498 (0.77571780)
# Finished training epoch 393
# Validate: MSE 0.00286943 (0.00238265), PSNR 25.42204475 (26.29782359), SSIM 0.71761566 (0.78368348)
# Finished validation.
# Starting training epoch 394
# Epoch: 394, MSE 0.00274524 (0.00230722), PSNR 25.61420250 (26.39133848), SSIM 0.77528346 (0.77586097)
# Finished training epoch 394
# Validate: MSE 0.00269593 (0.00229362), PSNR 25.69292068 (26.45038355), SSIM 0.71573550 (0.78234010)
# Finished validation.
# Starting training epoch 395
# Epoch: 395, MSE 0.00259930 (0.00230966), PSNR 25.85144234 (26.38769119), SSIM 0.76171017 (0.77570333)
# Finished training epoch 395
# Validate: MSE 0.00270430 (0.00228802), PSNR 25.67944717 (26.46364671), SSIM 0.71948552 (0.78181746)
# Finished validation.
# Starting training epoch 396
# Epoch: 396, MSE 0.00222179 (0.00230238), PSNR 26.53296280 (26.40154477), SSIM 0.75046062 (0.77601545)
# Finished training epoch 396
# Validate: MSE 0.00255855 (0.00228536), PSNR 25.92005157 (26.46506237), SSIM 0.71827137 (0.78003790)
# Finished validation.
# Starting training epoch 397
# Epoch: 397, MSE 0.00249058 (0.00230539), PSNR 26.03699493 (26.39898126), SSIM 0.78451920 (0.77595105)
# Finished training epoch 397
# Validate: MSE 0.00269442 (0.00236032), PSNR 25.69534874 (26.33187196), SSIM 0.71751076 (0.78184368)
# Finished validation.
# Starting training epoch 398
# Epoch: 398, MSE 0.00223378 (0.00230938), PSNR 26.50959587 (26.38630974), SSIM 0.76155204 (0.77590532)
# Finished training epoch 398
# Validate: MSE 0.00276352 (0.00238015), PSNR 25.58537865 (26.29629913), SSIM 0.71389759 (0.77764315)
# Finished validation.
# Starting training epoch 399
# Epoch: 399, MSE 0.00225897 (0.00231107), PSNR 26.46089935 (26.38429205), SSIM 0.78094637 (0.77591957)
# Finished training epoch 399
# Validate: MSE 0.00274856 (0.00232511), PSNR 25.60894585 (26.39582112), SSIM 0.71816730 (0.78195265)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00272881 (0.00232502), PSNR 25.64026451 (26.39654459), SSIM 0.72002816 (0.78196699)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
