# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-3ac8d1c85753eed0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3ac8d1c85753eed0");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 128

class Autoencoder(nn.Module):
    def __init__(self, input_size=128):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x)), negative_slope=0.1)
        x = F.interpolate(self.convtrans3(x), scale_factor=scale_factor)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 32, 32]           1,280
#        BatchNorm2d-2          [-1, 128, 32, 32]             256
#             Conv2d-3          [-1, 256, 16, 16]         295,168
#        BatchNorm2d-4          [-1, 256, 16, 16]             512
#    ConvTranspose2d-5            [-1, 128, 8, 8]         295,040
#        BatchNorm2d-6            [-1, 128, 8, 8]             256
#    ConvTranspose2d-7           [-1, 64, 16, 16]          73,792
#        BatchNorm2d-8           [-1, 64, 16, 16]             128
#    ConvTranspose2d-9            [-1, 2, 16, 16]           1,154
# ================================================================
# Total params: 667,586
# Trainable params: 667,586
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 3.38
# Params size (MB): 2.55
# Estimated Total Size (MB): 5.93
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00629300 (0.32895766), PSNR 22.01142120 (17.13292887), SSIM 0.35981512 (0.22733096)
# Finished training epoch 0
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 24 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 68 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00711792 (0.00668482), PSNR 21.47646713 (21.76924555), SSIM 0.28251266 (0.34594226)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00422540 (0.00553903), PSNR 23.74131775 (22.60150604), SSIM 0.43954182 (0.40080481)
# Finished training epoch 1
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 28 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00514265 (0.00455466), PSNR 22.88812828 (23.43734610), SSIM 0.37517017 (0.45108672)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00423759 (0.00427830), PSNR 23.72881317 (23.70519824), SSIM 0.52953392 (0.48261855)
# Finished training epoch 2
# Validate: MSE 0.00439893 (0.00411593), PSNR 23.56653214 (23.89295430), SSIM 0.43119660 (0.50852199)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00378140 (0.00376994), PSNR 24.22346878 (24.25412929), SSIM 0.53469861 (0.53794718)
# Finished training epoch 3
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00441257 (0.00371417), PSNR 23.55307961 (24.33607802), SSIM 0.48082352 (0.56092571)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00324305 (0.00353890), PSNR 24.89046097 (24.53135319), SSIM 0.58112079 (0.57726259)
# Finished training epoch 4
# Validate: MSE 0.00381673 (0.00329149), PSNR 24.18308830 (24.86797097), SSIM 0.51795316 (0.59644723)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00348696 (0.00336277), PSNR 24.57552719 (24.75436299), SSIM 0.62215775 (0.60815034)
# Finished training epoch 5
# Validate: MSE 0.00397684 (0.00355392), PSNR 24.00461578 (24.53082845), SSIM 0.53698170 (0.61344580)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00281569 (0.00327284), PSNR 25.50414467 (24.87112835), SSIM 0.65401661 (0.63147016)
# Finished training epoch 6
# Validate: MSE 0.00335941 (0.00300089), PSNR 24.73737335 (25.28238046), SSIM 0.56657594 (0.64753498)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00345117 (0.00330409), PSNR 24.62034225 (24.84092270), SSIM 0.66768605 (0.64842484)
# Finished training epoch 7
# Validate: MSE 0.00347174 (0.00300743), PSNR 24.59452629 (25.27435639), SSIM 0.58576244 (0.66643788)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00315756 (0.00324726), PSNR 25.00648117 (24.91217056), SSIM 0.67546123 (0.66438959)
# Finished training epoch 8
# Validate: MSE 0.00330374 (0.00294551), PSNR 24.80993271 (25.36404909), SSIM 0.59779316 (0.67792934)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00528769 (0.00334348), PSNR 22.76733589 (24.80074085), SSIM 0.65432429 (0.67576835)
# Finished training epoch 9
# Validate: MSE 0.00331328 (0.00321589), PSNR 24.79741669 (24.98150880), SSIM 0.60039365 (0.68123645)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00278852 (0.00318404), PSNR 25.54626465 (25.00455485), SSIM 0.70376772 (0.69017929)
# Finished training epoch 10
# Validate: MSE 0.00302707 (0.00317619), PSNR 25.18977737 (25.04009063), SSIM 0.62596858 (0.70171702)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00354323 (0.00308737), PSNR 24.50601196 (25.13668927), SSIM 0.69356191 (0.70235865)
# Finished training epoch 11
# Validate: MSE 0.00309250 (0.00284295), PSNR 25.09689903 (25.52338582), SSIM 0.63547361 (0.71163900)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00352739 (0.00305596), PSNR 24.52546310 (25.18683664), SSIM 0.72431171 (0.71210696)
# Finished training epoch 12
# Validate: MSE 0.00303484 (0.00294288), PSNR 25.17864418 (25.37371728), SSIM 0.65236795 (0.72239197)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00298672 (0.00292264), PSNR 25.24805832 (25.36974177), SSIM 0.72578508 (0.72362844)
# Finished training epoch 13
# Validate: MSE 0.00304433 (0.00286502), PSNR 25.16508102 (25.49102094), SSIM 0.65016645 (0.72871935)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00242265 (0.00281716), PSNR 26.15709877 (25.52997631), SSIM 0.74205887 (0.73449967)
# Finished training epoch 14
# Validate: MSE 0.00308372 (0.00304113), PSNR 25.10925484 (25.24701375), SSIM 0.65316927 (0.72896214)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00255241 (0.00273184), PSNR 25.93050003 (25.65838791), SSIM 0.76725131 (0.74353565)
# Finished training epoch 15
# Validate: MSE 0.00307416 (0.00272979), PSNR 25.12273026 (25.71586243), SSIM 0.67283195 (0.74670205)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00207698 (0.00268476), PSNR 26.82568359 (25.73758046), SSIM 0.75741869 (0.75043835)
# Finished training epoch 16
# Validate: MSE 0.00284090 (0.00314716), PSNR 25.46543884 (25.13164370), SSIM 0.67635232 (0.74221953)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00257222 (0.00265981), PSNR 25.89692497 (25.77446948), SSIM 0.74867880 (0.75439297)
# Finished training epoch 17
# Validate: MSE 0.00354187 (0.00296790), PSNR 24.50766945 (25.34040961), SSIM 0.67963576 (0.75215311)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00282232 (0.00259630), PSNR 25.49393272 (25.87746599), SSIM 0.73864847 (0.75947101)
# Finished training epoch 18
# Validate: MSE 0.00335228 (0.00439908), PSNR 24.74659729 (23.71836665), SSIM 0.65700340 (0.73210318)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00241867 (0.00258542), PSNR 26.16423225 (25.89706650), SSIM 0.75788349 (0.76212919)
# Finished training epoch 19
# Validate: MSE 0.00298880 (0.00272531), PSNR 25.24503326 (25.73163390), SSIM 0.68952805 (0.76232381)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00285229 (0.00254381), PSNR 25.44806862 (25.97155097), SSIM 0.75774741 (0.76474599)
# Finished training epoch 20
# Validate: MSE 0.00296063 (0.00265370), PSNR 25.28615189 (25.84440526), SSIM 0.69124383 (0.76414442)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00292161 (0.00253868), PSNR 25.34377480 (25.97934286), SSIM 0.73532069 (0.76629422)
# Finished training epoch 21
# Validate: MSE 0.00517770 (0.00533274), PSNR 22.85862541 (22.83883960), SSIM 0.66280812 (0.72959905)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00252934 (0.00252962), PSNR 25.96992111 (25.99635953), SSIM 0.77973926 (0.76685996)
# Finished training epoch 22
# Validate: MSE 0.00312871 (0.00277132), PSNR 25.04634285 (25.65899878), SSIM 0.69714344 (0.76520554)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00224510 (0.00252912), PSNR 26.48763657 (25.99364582), SSIM 0.79633093 (0.76774610)
# Finished training epoch 23
# Validate: MSE 0.00275937 (0.00296768), PSNR 25.59189606 (25.41824130), SSIM 0.69613904 (0.75904416)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00235387 (0.00251307), PSNR 26.28216743 (26.02287219), SSIM 0.79931611 (0.76941021)
# Finished training epoch 24
# Validate: MSE 0.00295236 (0.00314087), PSNR 25.29830933 (25.16631909), SSIM 0.68809700 (0.75900286)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00273137 (0.00250790), PSNR 25.63619041 (26.03128660), SSIM 0.76400363 (0.77053659)
# Finished training epoch 25
# Validate: MSE 0.00279380 (0.00300684), PSNR 25.53804398 (25.35062127), SSIM 0.70260096 (0.76433507)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00272863 (0.00251548), PSNR 25.64055824 (26.01552178), SSIM 0.75287992 (0.77122605)
# Finished training epoch 26
# Validate: MSE 0.00269807 (0.00303567), PSNR 25.68946075 (25.30806273), SSIM 0.70567966 (0.76780099)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00249743 (0.00248581), PSNR 26.02506828 (26.06859679), SSIM 0.77634144 (0.77286014)
# Finished training epoch 27
# Validate: MSE 0.00307026 (0.00396652), PSNR 25.12824059 (24.12254203), SSIM 0.69760418 (0.75148002)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00254933 (0.00246108), PSNR 25.93574715 (26.10854256), SSIM 0.77444792 (0.77328486)
# Finished training epoch 28
# Validate: MSE 0.00422049 (0.00382116), PSNR 23.74636841 (24.30668179), SSIM 0.68937349 (0.75818817)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00272862 (0.00245272), PSNR 25.64057159 (26.12885792), SSIM 0.75566977 (0.77404748)
# Finished training epoch 29
# Validate: MSE 0.00374737 (0.00588748), PSNR 24.26273155 (22.45511593), SSIM 0.69497657 (0.73729683)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00233140 (0.00243962), PSNR 26.32383537 (26.15203509), SSIM 0.77883387 (0.77474431)
# Finished training epoch 30
# Validate: MSE 0.00292840 (0.00246323), PSNR 25.33369255 (26.15173088), SSIM 0.70961571 (0.77643745)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00214545 (0.00242024), PSNR 26.68481445 (26.18750681), SSIM 0.76994711 (0.77547337)
# Finished training epoch 31
# Validate: MSE 0.00272096 (0.00290268), PSNR 25.65278435 (25.48522260), SSIM 0.71016222 (0.76839257)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00325935 (0.00241460), PSNR 24.86869431 (26.19503529), SSIM 0.76494294 (0.77605169)
# Finished training epoch 32
# Validate: MSE 0.00296771 (0.00260364), PSNR 25.27579117 (25.92673130), SSIM 0.70654452 (0.77391907)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00232320 (0.00240565), PSNR 26.33912659 (26.21100923), SSIM 0.77307403 (0.77667406)
# Finished training epoch 33
# Validate: MSE 0.00308024 (0.00425120), PSNR 25.11415863 (23.86843370), SSIM 0.70933759 (0.75770408)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00279835 (0.00240524), PSNR 25.53098297 (26.21173927), SSIM 0.76764309 (0.77695859)
# Finished training epoch 34
# Validate: MSE 0.00285197 (0.00254037), PSNR 25.44854736 (26.03145391), SSIM 0.70996749 (0.77648998)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00215803 (0.00238229), PSNR 26.65943336 (26.25191722), SSIM 0.78550977 (0.77776620)
# Finished training epoch 35
# Validate: MSE 0.00291275 (0.00347177), PSNR 25.35697174 (24.75941996), SSIM 0.71057498 (0.76726979)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00262476 (0.00237115), PSNR 25.80910683 (26.27435653), SSIM 0.76548910 (0.77810791)
# Finished training epoch 36
# Validate: MSE 0.00285430 (0.00268885), PSNR 25.44500923 (25.78474737), SSIM 0.70903307 (0.76698012)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00221492 (0.00236002), PSNR 26.54641914 (26.29301289), SSIM 0.77422094 (0.77833552)
# Finished training epoch 37
# Validate: MSE 0.00288455 (0.00254121), PSNR 25.39921379 (26.01557226), SSIM 0.71695000 (0.77536117)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00229931 (0.00235958), PSNR 26.38403130 (26.29541901), SSIM 0.77460152 (0.77858085)
# Finished training epoch 38
# Validate: MSE 0.00273238 (0.00270316), PSNR 25.63458824 (25.79130892), SSIM 0.71285081 (0.77366821)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00247059 (0.00235252), PSNR 26.07198715 (26.30946560), SSIM 0.76712483 (0.77882131)
# Finished training epoch 39
# Validate: MSE 0.00280333 (0.00250641), PSNR 25.52325249 (26.08574641), SSIM 0.71401060 (0.77776422)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00256379 (0.00235696), PSNR 25.91116714 (26.29883984), SSIM 0.76242459 (0.77882187)
# Finished training epoch 40
# Validate: MSE 0.00332371 (0.00426104), PSNR 24.78376961 (23.84728706), SSIM 0.70913839 (0.75542113)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00283877 (0.00235210), PSNR 25.46869087 (26.30989204), SSIM 0.76129043 (0.77906575)
# Finished training epoch 41
# Validate: MSE 0.00288054 (0.00244916), PSNR 25.40526199 (26.18200347), SSIM 0.71533167 (0.77811136)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00238467 (0.00234687), PSNR 26.22571182 (26.31936912), SSIM 0.77251476 (0.77896050)
# Finished training epoch 42
# Validate: MSE 0.00267755 (0.00249648), PSNR 25.72263145 (26.10724974), SSIM 0.71067339 (0.77754105)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00270540 (0.00234409), PSNR 25.67767906 (26.32673290), SSIM 0.76589286 (0.77926414)
# Finished training epoch 43
# Validate: MSE 0.00265697 (0.00261460), PSNR 25.75612640 (25.89347936), SSIM 0.71300936 (0.77116613)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00290784 (0.00233232), PSNR 25.36429596 (26.34412088), SSIM 0.75008017 (0.77942982)
# Finished training epoch 44
# Validate: MSE 0.00277173 (0.00244477), PSNR 25.57248688 (26.18439772), SSIM 0.71579677 (0.77619869)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00213169 (0.00233314), PSNR 26.71275330 (26.34523972), SSIM 0.78429204 (0.77936117)
# Finished training epoch 45
# Validate: MSE 0.00281101 (0.00238914), PSNR 25.51138115 (26.27660686), SSIM 0.71509612 (0.78044932)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00270994 (0.00232443), PSNR 25.67040443 (26.35884558), SSIM 0.76170981 (0.77977402)
# Finished training epoch 46
# Validate: MSE 0.00271848 (0.00251443), PSNR 25.65673637 (26.07201394), SSIM 0.71812987 (0.77897124)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00241870 (0.00231515), PSNR 26.16417122 (26.37540401), SSIM 0.77193063 (0.77999045)
# Finished training epoch 47
# Validate: MSE 0.00324811 (0.00311625), PSNR 24.88369179 (25.14571203), SSIM 0.70513165 (0.76708555)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00241864 (0.00233179), PSNR 26.16428947 (26.34475801), SSIM 0.75309491 (0.77985055)
# Finished training epoch 48
# Validate: MSE 0.00277695 (0.00256869), PSNR 25.56431770 (25.96478247), SSIM 0.70970064 (0.77087365)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00192723 (0.00230846), PSNR 27.15065575 (26.38826043), SSIM 0.78775907 (0.78024393)
# Finished training epoch 49
# Validate: MSE 0.00269945 (0.00263371), PSNR 25.68724251 (25.90381592), SSIM 0.71918935 (0.77648008)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00188982 (0.00230459), PSNR 27.23578644 (26.39679242), SSIM 0.78152448 (0.78041328)
# Finished training epoch 50
# Validate: MSE 0.00255659 (0.00233098), PSNR 25.92338943 (26.38383214), SSIM 0.71871960 (0.78144082)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00199268 (0.00230929), PSNR 27.00563049 (26.38723051), SSIM 0.79451454 (0.78041412)
# Finished training epoch 51
# Validate: MSE 0.00270051 (0.00254428), PSNR 25.68553543 (26.02498450), SSIM 0.71790016 (0.78111345)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00223756 (0.00229351), PSNR 26.50225258 (26.41847702), SSIM 0.77899981 (0.78070254)
# Finished training epoch 52
# Validate: MSE 0.00279101 (0.00233213), PSNR 25.54237747 (26.38684554), SSIM 0.71511161 (0.77845118)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00247091 (0.00229926), PSNR 26.07143784 (26.40734177), SSIM 0.78256476 (0.78068818)
# Finished training epoch 53
# Validate: MSE 0.00316773 (0.00261841), PSNR 24.99252510 (25.89357132), SSIM 0.70883727 (0.77608580)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00258936 (0.00229104), PSNR 25.86806679 (26.42074673), SSIM 0.75919449 (0.78083557)
# Finished training epoch 54
# Validate: MSE 0.00284339 (0.00325959), PSNR 25.46163177 (25.01551495), SSIM 0.71390575 (0.77320635)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00208437 (0.00228731), PSNR 26.81025314 (26.42816972), SSIM 0.79381317 (0.78100333)
# Finished training epoch 55
# Validate: MSE 0.00258907 (0.00233438), PSNR 25.86856270 (26.38345679), SSIM 0.71822083 (0.78117931)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00203332 (0.00227568), PSNR 26.91794777 (26.45336087), SSIM 0.78643143 (0.78116905)
# Finished training epoch 56
# Validate: MSE 0.00268891 (0.00247457), PSNR 25.70423126 (26.12873368), SSIM 0.71569574 (0.77965518)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00287698 (0.00229617), PSNR 25.41063118 (26.41429507), SSIM 0.76129252 (0.78104243)
# Finished training epoch 57
# Validate: MSE 0.00284480 (0.00334708), PSNR 25.45948601 (24.91248857), SSIM 0.70664358 (0.76298227)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00227270 (0.00228068), PSNR 26.43458557 (26.44406640), SSIM 0.77710569 (0.78102914)
# Finished training epoch 58
# Validate: MSE 0.00646078 (0.00789995), PSNR 21.89714813 (21.09709452), SSIM 0.67180693 (0.72252477)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00205890 (0.00227038), PSNR 26.86363602 (26.46239091), SSIM 0.78107786 (0.78130006)
# Finished training epoch 59
# Validate: MSE 0.00271724 (0.00283715), PSNR 25.65872002 (25.52946504), SSIM 0.71587408 (0.77345349)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00209300 (0.00226819), PSNR 26.79230499 (26.46683907), SSIM 0.79057634 (0.78141979)
# Finished training epoch 60
# Validate: MSE 0.00273812 (0.00288427), PSNR 25.62547112 (25.53537404), SSIM 0.71418774 (0.76808284)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00189696 (0.00226390), PSNR 27.21941757 (26.47536455), SSIM 0.79899353 (0.78161776)
# Finished training epoch 61
# Validate: MSE 0.00269642 (0.00247348), PSNR 25.69211769 (26.12155648), SSIM 0.71268427 (0.77789931)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00164154 (0.00225422), PSNR 27.84749413 (26.49387748), SSIM 0.82437229 (0.78157184)
# Finished training epoch 62
# Validate: MSE 0.00275058 (0.00225590), PSNR 25.60575485 (26.53337590), SSIM 0.72062117 (0.78335674)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00160625 (0.00225287), PSNR 27.94186783 (26.49836437), SSIM 0.78704607 (0.78165833)
# Finished training epoch 63
# Validate: MSE 0.00268408 (0.00232315), PSNR 25.71203804 (26.39965843), SSIM 0.72065258 (0.77797019)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00206012 (0.00226053), PSNR 26.86106682 (26.48173115), SSIM 0.79828799 (0.78153459)
# Finished training epoch 64
# Validate: MSE 0.00249069 (0.00236953), PSNR 26.03680611 (26.30799915), SSIM 0.72232056 (0.78051738)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00189285 (0.00224376), PSNR 27.22883606 (26.51347824), SSIM 0.78520399 (0.78184517)
# Finished training epoch 65
# Validate: MSE 0.00301126 (0.00244878), PSNR 25.21252060 (26.18703732), SSIM 0.71587491 (0.77876337)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00186748 (0.00224098), PSNR 27.28742981 (26.51670774), SSIM 0.80128956 (0.78191633)
# Finished training epoch 66
# Validate: MSE 0.00282784 (0.00238616), PSNR 25.48545456 (26.28813764), SSIM 0.71686226 (0.77643570)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00209895 (0.00224019), PSNR 26.77997971 (26.51843061), SSIM 0.78108013 (0.78175971)
# Finished training epoch 67
# Validate: MSE 0.00265370 (0.00231997), PSNR 25.76148033 (26.41051449), SSIM 0.72126859 (0.78147357)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00262770 (0.00224779), PSNR 25.80423927 (26.50478903), SSIM 0.76864588 (0.78184034)
# Finished training epoch 68
# Validate: MSE 0.00271169 (0.00229086), PSNR 25.66759300 (26.46613348), SSIM 0.72007900 (0.78137259)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00198057 (0.00223883), PSNR 27.03209496 (26.52394367), SSIM 0.78478456 (0.78179949)
# Finished training epoch 69
# Validate: MSE 0.00258851 (0.00227348), PSNR 25.86949348 (26.49773059), SSIM 0.72448039 (0.78295052)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00214414 (0.00223442), PSNR 26.68746567 (26.53004562), SSIM 0.78982586 (0.78211330)
# Finished training epoch 70
# Validate: MSE 0.00261949 (0.00245310), PSNR 25.81783676 (26.19036061), SSIM 0.72092235 (0.78159664)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00202498 (0.00223388), PSNR 26.93579102 (26.53405949), SSIM 0.78284037 (0.78208487)
# Finished training epoch 71
# Validate: MSE 0.00297444 (0.00286753), PSNR 25.26595116 (25.51649649), SSIM 0.71244293 (0.77045646)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00217583 (0.00222351), PSNR 26.62375259 (26.55035387), SSIM 0.77114093 (0.78219653)
# Finished training epoch 72
# Validate: MSE 0.00281430 (0.00238975), PSNR 25.50629044 (26.28939046), SSIM 0.71860254 (0.78026371)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00207527 (0.00221411), PSNR 26.82925797 (26.57157409), SSIM 0.77181959 (0.78229051)
# Finished training epoch 73
# Validate: MSE 0.00256455 (0.00268088), PSNR 25.90988731 (25.82342313), SSIM 0.71643615 (0.77531658)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00219958 (0.00222519), PSNR 26.57660484 (26.55422631), SSIM 0.77721339 (0.78200483)
# Finished training epoch 74
# Validate: MSE 0.00280450 (0.00237122), PSNR 25.52144432 (26.33074034), SSIM 0.71619385 (0.77944914)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00223038 (0.00221629), PSNR 26.51621056 (26.56631532), SSIM 0.78065133 (0.78227955)
# Finished training epoch 75
# Validate: MSE 0.00311493 (0.00248784), PSNR 25.06551170 (26.11012018), SSIM 0.71565533 (0.77824861)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00223892 (0.00220811), PSNR 26.49960709 (26.58150105), SSIM 0.78480434 (0.78231670)
# Finished training epoch 76
# Validate: MSE 0.00275766 (0.00231129), PSNR 25.59459877 (26.42701933), SSIM 0.71964061 (0.77693807)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00235134 (0.00221014), PSNR 26.28684044 (26.57968688), SSIM 0.78126401 (0.78238565)
# Finished training epoch 77
# Validate: MSE 0.00286088 (0.00231308), PSNR 25.43499756 (26.43141123), SSIM 0.71672839 (0.78069575)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00203916 (0.00220829), PSNR 26.90548515 (26.58120998), SSIM 0.78956974 (0.78232851)
# Finished training epoch 78
# Validate: MSE 0.00282249 (0.00230538), PSNR 25.49366760 (26.44266494), SSIM 0.71833307 (0.78256183)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00233333 (0.00220854), PSNR 26.32024384 (26.58167448), SSIM 0.78943098 (0.78226030)
# Finished training epoch 79
# Validate: MSE 0.00270769 (0.00268582), PSNR 25.67401314 (25.83758609), SSIM 0.71601981 (0.77261083)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00248821 (0.00219742), PSNR 26.04113388 (26.60666368), SSIM 0.76456970 (0.78244518)
# Finished training epoch 80
# Validate: MSE 0.00245024 (0.00224337), PSNR 26.10791779 (26.55277006), SSIM 0.71994454 (0.77917519)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00252363 (0.00219763), PSNR 25.97974014 (26.60160969), SSIM 0.76889455 (0.78228513)
# Finished training epoch 81
# Validate: MSE 0.00308841 (0.00246765), PSNR 25.10265160 (26.14078514), SSIM 0.71568263 (0.77979952)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00211107 (0.00219174), PSNR 26.75497818 (26.61616941), SSIM 0.79414612 (0.78238720)
# Finished training epoch 82
# Validate: MSE 0.00238202 (0.00238656), PSNR 26.23055267 (26.27514125), SSIM 0.71939635 (0.77252091)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00180643 (0.00219268), PSNR 27.43178940 (26.61393663), SSIM 0.79100549 (0.78234340)
# Finished training epoch 83
# Validate: MSE 0.00260001 (0.00252642), PSNR 25.85024452 (26.05787838), SSIM 0.71966666 (0.77599929)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00221834 (0.00218715), PSNR 26.53972054 (26.62518374), SSIM 0.77330112 (0.78240996)
# Finished training epoch 84
# Validate: MSE 0.00260735 (0.00236877), PSNR 25.83801270 (26.31985095), SSIM 0.72137606 (0.77427111)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00206157 (0.00218115), PSNR 26.85800934 (26.63471646), SSIM 0.79644299 (0.78244969)
# Finished training epoch 85
# Validate: MSE 0.00271227 (0.00318569), PSNR 25.66666794 (25.14125136), SSIM 0.71605098 (0.77091052)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00211537 (0.00218173), PSNR 26.74613380 (26.63588167), SSIM 0.78800881 (0.78235584)
# Finished training epoch 86
# Validate: MSE 0.00282728 (0.00233731), PSNR 25.48631287 (26.37992549), SSIM 0.72212672 (0.78391291)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00189165 (0.00217287), PSNR 27.23158264 (26.65364304), SSIM 0.80070686 (0.78259243)
# Finished training epoch 87
# Validate: MSE 0.00300807 (0.00269469), PSNR 25.21712303 (25.78365721), SSIM 0.71266520 (0.77286594)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00294638 (0.00217384), PSNR 25.30711555 (26.65133284), SSIM 0.76677686 (0.78242213)
# Finished training epoch 88
# Validate: MSE 0.00273050 (0.00246171), PSNR 25.63757706 (26.17438914), SSIM 0.71285892 (0.77578285)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00219196 (0.00216328), PSNR 26.59167290 (26.67137078), SSIM 0.79058707 (0.78256074)
# Finished training epoch 89
# Validate: MSE 0.00258705 (0.00251717), PSNR 25.87195587 (26.07487130), SSIM 0.71870637 (0.77370623)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00153062 (0.00217575), PSNR 28.15133095 (26.64791308), SSIM 0.79595232 (0.78233463)
# Finished training epoch 90
# Validate: MSE 0.00272405 (0.00262482), PSNR 25.64784431 (25.87915159), SSIM 0.71201962 (0.76563044)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00229823 (0.00216922), PSNR 26.38605690 (26.66054769), SSIM 0.80572635 (0.78236318)
# Finished training epoch 91
# Validate: MSE 0.00260454 (0.00238679), PSNR 25.84269524 (26.27605581), SSIM 0.71832925 (0.77980047)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00240834 (0.00217545), PSNR 26.18281555 (26.64801974), SSIM 0.78500676 (0.78235662)
# Finished training epoch 92
# Validate: MSE 0.00290419 (0.00282832), PSNR 25.36975479 (25.55982300), SSIM 0.71605730 (0.77235596)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00230148 (0.00216090), PSNR 26.37992668 (26.67598175), SSIM 0.79335278 (0.78245112)
# Finished training epoch 93
# Validate: MSE 0.00277331 (0.00273711), PSNR 25.57001305 (25.74706112), SSIM 0.71356571 (0.77074434)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00181117 (0.00215518), PSNR 27.42041779 (26.68853027), SSIM 0.78958219 (0.78252324)
# Finished training epoch 94
# Validate: MSE 0.00257913 (0.00234318), PSNR 25.88527489 (26.36929081), SSIM 0.72193450 (0.77797312)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00247453 (0.00215693), PSNR 26.06507683 (26.68431836), SSIM 0.77188873 (0.78236626)
# Finished training epoch 95
# Validate: MSE 0.00261869 (0.00245953), PSNR 25.81915283 (26.18338792), SSIM 0.71861362 (0.77603534)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00201656 (0.00215825), PSNR 26.95388985 (26.68143346), SSIM 0.77983236 (0.78238489)
# Finished training epoch 96
# Validate: MSE 0.00276551 (0.00230981), PSNR 25.58224487 (26.42786558), SSIM 0.71678454 (0.77769775)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00189824 (0.00215380), PSNR 27.21648598 (26.69143346), SSIM 0.78333724 (0.78240707)
# Finished training epoch 97
# Validate: MSE 0.00257258 (0.00271477), PSNR 25.89630318 (25.75130850), SSIM 0.71786427 (0.77287666)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00179676 (0.00215124), PSNR 27.45508766 (26.69800590), SSIM 0.78422832 (0.78238235)
# Finished training epoch 98
# Validate: MSE 0.00264013 (0.00262271), PSNR 25.78374100 (25.91827979), SSIM 0.71786809 (0.77529865)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00239940 (0.00214862), PSNR 26.19897652 (26.70117340), SSIM 0.78191298 (0.78252663)
# Finished training epoch 99
# Validate: MSE 0.00298245 (0.00280704), PSNR 25.25427246 (25.60417407), SSIM 0.70820081 (0.76937264)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00223831 (0.00214755), PSNR 26.50079536 (26.70576714), SSIM 0.77338493 (0.78229640)
# Finished training epoch 100
# Validate: MSE 0.00291848 (0.00240224), PSNR 25.34842873 (26.26858468), SSIM 0.71326256 (0.77947163)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00221211 (0.00214317), PSNR 26.55193138 (26.71200277), SSIM 0.76827765 (0.78235616)
# Finished training epoch 101
# Validate: MSE 0.00268111 (0.00230730), PSNR 25.71685219 (26.42886488), SSIM 0.71719325 (0.77604424)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00179534 (0.00214585), PSNR 27.45853043 (26.70654921), SSIM 0.79487675 (0.78208563)
# Finished training epoch 102
# Validate: MSE 0.00260622 (0.00275717), PSNR 25.83988380 (25.69804543), SSIM 0.71845448 (0.77385056)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00193650 (0.00213638), PSNR 27.12982941 (26.72634851), SSIM 0.79511589 (0.78238353)
# Finished training epoch 103
# Validate: MSE 0.00264960 (0.00221505), PSNR 25.76819038 (26.60671607), SSIM 0.71600735 (0.77929463)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00215851 (0.00213100), PSNR 26.65846443 (26.73494656), SSIM 0.77845347 (0.78244472)
# Finished training epoch 104
# Validate: MSE 0.00261595 (0.00224267), PSNR 25.82370377 (26.55040599), SSIM 0.71836090 (0.77946138)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00246625 (0.00212579), PSNR 26.07963562 (26.74653616), SSIM 0.75472897 (0.78235777)
# Finished training epoch 105
# Validate: MSE 0.00241797 (0.00233480), PSNR 26.16548538 (26.37038428), SSIM 0.71573949 (0.77229429)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00195247 (0.00212798), PSNR 27.09414482 (26.74214017), SSIM 0.79861099 (0.78224863)
# Finished training epoch 106
# Validate: MSE 0.00262532 (0.00226371), PSNR 25.80818176 (26.51524788), SSIM 0.71389198 (0.77604691)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00213591 (0.00213822), PSNR 26.70416832 (26.72338680), SSIM 0.77391279 (0.78224149)
# Finished training epoch 107
# Validate: MSE 0.00272376 (0.00271457), PSNR 25.64830208 (25.77989678), SSIM 0.71465486 (0.76882633)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00197558 (0.00212297), PSNR 27.04305840 (26.75445032), SSIM 0.79710358 (0.78220611)
# Finished training epoch 108
# Validate: MSE 0.00257205 (0.00241367), PSNR 25.89720726 (26.24788348), SSIM 0.72217900 (0.77756801)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00191957 (0.00212374), PSNR 27.16795540 (26.75663984), SSIM 0.79596317 (0.78223736)
# Finished training epoch 109
# Validate: MSE 0.00277462 (0.00267419), PSNR 25.56796074 (25.81247646), SSIM 0.71417987 (0.77294654)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00207249 (0.00212799), PSNR 26.83507347 (26.74127716), SSIM 0.77977556 (0.78227773)
# Finished training epoch 110
# Validate: MSE 0.00257086 (0.00260032), PSNR 25.89922333 (25.91278370), SSIM 0.71663851 (0.77085994)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00200525 (0.00211693), PSNR 26.97831535 (26.76553042), SSIM 0.79142827 (0.78224911)
# Finished training epoch 111
# Validate: MSE 0.00269732 (0.00242399), PSNR 25.69066811 (26.23264420), SSIM 0.71744990 (0.77513586)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00192072 (0.00212010), PSNR 27.16534805 (26.75886681), SSIM 0.78376317 (0.78226432)
# Finished training epoch 112
# Validate: MSE 0.00256066 (0.00227436), PSNR 25.91647720 (26.49235797), SSIM 0.72016460 (0.77712804)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00195279 (0.00211345), PSNR 27.09345055 (26.77354771), SSIM 0.78711873 (0.78203421)
# Finished training epoch 113
# Validate: MSE 0.00252935 (0.00227336), PSNR 25.96990967 (26.49692903), SSIM 0.72137904 (0.77630309)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00216782 (0.00211447), PSNR 26.63977051 (26.77078557), SSIM 0.78901339 (0.78217750)
# Finished training epoch 114
# Validate: MSE 0.00265218 (0.00238861), PSNR 25.76397133 (26.29411498), SSIM 0.71368474 (0.77655008)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00215462 (0.00210539), PSNR 26.66628456 (26.78971882), SSIM 0.78476727 (0.78221746)
# Finished training epoch 115
# Validate: MSE 0.00262516 (0.00223774), PSNR 25.80844116 (26.56639326), SSIM 0.71808350 (0.77839903)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00205915 (0.00211978), PSNR 26.86311913 (26.75697200), SSIM 0.76917154 (0.78216157)
# Finished training epoch 116
# Validate: MSE 0.00259608 (0.00223416), PSNR 25.85681152 (26.57232180), SSIM 0.72097087 (0.77912251)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00218817 (0.00210298), PSNR 26.59919167 (26.79395506), SSIM 0.75807995 (0.78226920)
# Finished training epoch 117
# Validate: MSE 0.00259270 (0.00243353), PSNR 25.86246872 (26.20276884), SSIM 0.71512455 (0.77291018)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00221917 (0.00209606), PSNR 26.53808403 (26.81158314), SSIM 0.77085084 (0.78219819)
# Finished training epoch 118
# Validate: MSE 0.00256116 (0.00237061), PSNR 25.91563225 (26.32720710), SSIM 0.72076809 (0.77459103)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00189454 (0.00209396), PSNR 27.22496986 (26.81324083), SSIM 0.78143227 (0.78209474)
# Finished training epoch 119
# Validate: MSE 0.00275710 (0.00246586), PSNR 25.59547424 (26.14788171), SSIM 0.71290553 (0.77004956)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00188764 (0.00209967), PSNR 27.24081421 (26.80203028), SSIM 0.78062224 (0.78202590)
# Finished training epoch 120
# Validate: MSE 0.00249435 (0.00237778), PSNR 26.03042030 (26.29234240), SSIM 0.71695185 (0.77118325)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00252288 (0.00208921), PSNR 25.98102570 (26.82200701), SSIM 0.76797312 (0.78211356)
# Finished training epoch 121
# Validate: MSE 0.00256018 (0.00252336), PSNR 25.91729164 (26.04921388), SSIM 0.71171331 (0.76911774)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00274932 (0.00208888), PSNR 25.60774803 (26.82453563), SSIM 0.76395518 (0.78199239)
# Finished training epoch 122
# Validate: MSE 0.00262908 (0.00280797), PSNR 25.80195427 (25.59583842), SSIM 0.71109223 (0.76174915)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00201248 (0.00209358), PSNR 26.96268463 (26.81116706), SSIM 0.78632355 (0.78193982)
# Finished training epoch 123
# Validate: MSE 0.00264689 (0.00226452), PSNR 25.77264023 (26.50958222), SSIM 0.72124231 (0.77842296)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00175021 (0.00208927), PSNR 27.56910515 (26.82239276), SSIM 0.80813754 (0.78190461)
# Finished training epoch 124
# Validate: MSE 0.00293705 (0.00247868), PSNR 25.32088852 (26.13014233), SSIM 0.70982301 (0.77282008)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00222835 (0.00208278), PSNR 26.52016830 (26.83830782), SSIM 0.77378559 (0.78194072)
# Finished training epoch 125
# Validate: MSE 0.00257100 (0.00243026), PSNR 25.89897156 (26.21748831), SSIM 0.71580780 (0.77411732)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00222288 (0.00208455), PSNR 26.53084755 (26.83086251), SSIM 0.79426193 (0.78191160)
# Finished training epoch 126
# Validate: MSE 0.00264407 (0.00264636), PSNR 25.77727127 (25.85606334), SSIM 0.71602106 (0.76939012)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00194627 (0.00208514), PSNR 27.10797310 (26.82848196), SSIM 0.78653580 (0.78181095)
# Finished training epoch 127
# Validate: MSE 0.00255353 (0.00232427), PSNR 25.92859268 (26.40475572), SSIM 0.72451031 (0.77810047)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00205235 (0.00208113), PSNR 26.87747955 (26.84014593), SSIM 0.77875388 (0.78201476)
# Finished training epoch 128
# Validate: MSE 0.00279010 (0.00233483), PSNR 25.54379463 (26.38237659), SSIM 0.71062171 (0.77727201)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00199076 (0.00208629), PSNR 27.00981903 (26.82611705), SSIM 0.78349841 (0.78169619)
# Finished training epoch 129
# Validate: MSE 0.00300572 (0.00252146), PSNR 25.22051048 (26.07269100), SSIM 0.70978731 (0.77181876)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00255763 (0.00207462), PSNR 25.92161942 (26.84936333), SSIM 0.76387823 (0.78186362)
# Finished training epoch 130
# Validate: MSE 0.00264662 (0.00220373), PSNR 25.77308083 (26.62449777), SSIM 0.71403825 (0.77315028)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00194458 (0.00207447), PSNR 27.11173820 (26.85161224), SSIM 0.77173960 (0.78189621)
# Finished training epoch 131
# Validate: MSE 0.00265292 (0.00235923), PSNR 25.76275635 (26.34477642), SSIM 0.71541679 (0.77727213)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00196376 (0.00207388), PSNR 27.06910706 (26.85482418), SSIM 0.79085940 (0.78183436)
# Finished training epoch 132
# Validate: MSE 0.00250343 (0.00272475), PSNR 26.01463890 (25.74267496), SSIM 0.71664715 (0.76602499)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00198015 (0.00206898), PSNR 27.03301430 (26.86592374), SSIM 0.78684855 (0.78192286)
# Finished training epoch 133
# Validate: MSE 0.00262811 (0.00229262), PSNR 25.80355644 (26.46044321), SSIM 0.71519816 (0.77584625)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00145261 (0.00206782), PSNR 28.37850189 (26.86667736), SSIM 0.80286181 (0.78186278)
# Finished training epoch 134
# Validate: MSE 0.00255362 (0.00242111), PSNR 25.92843246 (26.23996284), SSIM 0.72400975 (0.77356555)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00197757 (0.00206008), PSNR 27.03867722 (26.88368450), SSIM 0.79829699 (0.78188876)
# Finished training epoch 135
# Validate: MSE 0.00285887 (0.00289429), PSNR 25.43804932 (25.50142744), SSIM 0.70972931 (0.76392813)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00204564 (0.00207315), PSNR 26.89171600 (26.85447660), SSIM 0.78564787 (0.78173390)
# Finished training epoch 136
# Validate: MSE 0.00240441 (0.00242548), PSNR 26.18990707 (26.21955837), SSIM 0.70993435 (0.76690743)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00189955 (0.00206011), PSNR 27.21349525 (26.88107158), SSIM 0.80255252 (0.78179396)
# Finished training epoch 137
# Validate: MSE 0.00258931 (0.00232746), PSNR 25.86816406 (26.39442332), SSIM 0.71769476 (0.77065236)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00202051 (0.00206101), PSNR 26.94537926 (26.87870597), SSIM 0.77949941 (0.78165109)
# Finished training epoch 138
# Validate: MSE 0.00281001 (0.00316446), PSNR 25.51291847 (25.16683241), SSIM 0.70637405 (0.75534875)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00235713 (0.00205446), PSNR 26.27616119 (26.89318473), SSIM 0.77527964 (0.78165578)
# Finished training epoch 139
# Validate: MSE 0.00263494 (0.00254148), PSNR 25.79229164 (26.05154438), SSIM 0.72143769 (0.77456633)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00222676 (0.00206180), PSNR 26.52326584 (26.87641405), SSIM 0.78720200 (0.78152461)
# Finished training epoch 140
# Validate: MSE 0.00243680 (0.00239127), PSNR 26.13179779 (26.27313702), SSIM 0.71249461 (0.76696344)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00238726 (0.00205608), PSNR 26.22100067 (26.89142752), SSIM 0.76736963 (0.78158195)
# Finished training epoch 141
# Validate: MSE 0.00313368 (0.00290665), PSNR 25.03945160 (25.46593502), SSIM 0.69308817 (0.75800334)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00172187 (0.00205182), PSNR 27.63999748 (26.90213437), SSIM 0.78080082 (0.78160986)
# Finished training epoch 142
# Validate: MSE 0.00259709 (0.00225105), PSNR 25.85513687 (26.53439319), SSIM 0.71141386 (0.77324492)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00210424 (0.00205317), PSNR 26.76904488 (26.89760174), SSIM 0.77738833 (0.78141578)
# Finished training epoch 143
# Validate: MSE 0.00264717 (0.00236389), PSNR 25.77218246 (26.32828593), SSIM 0.71362865 (0.77130546)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00281176 (0.00206019), PSNR 25.51022148 (26.88243390), SSIM 0.74744225 (0.78162507)
# Finished training epoch 144
# Validate: MSE 0.00248186 (0.00226737), PSNR 26.05221939 (26.50218201), SSIM 0.71549249 (0.77150371)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00196042 (0.00204686), PSNR 27.07651711 (26.91153920), SSIM 0.77836198 (0.78154014)
# Finished training epoch 145
# Validate: MSE 0.00242112 (0.00228350), PSNR 26.15983009 (26.47162550), SSIM 0.71499527 (0.76999366)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00193546 (0.00204222), PSNR 27.13214874 (26.91971462), SSIM 0.78637540 (0.78155821)
# Finished training epoch 146
# Validate: MSE 0.00247697 (0.00245649), PSNR 26.06078148 (26.18553458), SSIM 0.71980733 (0.77270274)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00255990 (0.00204314), PSNR 25.91776085 (26.92236676), SSIM 0.76815856 (0.78148696)
# Finished training epoch 147
# Validate: MSE 0.00264198 (0.00264701), PSNR 25.78071022 (25.87252311), SSIM 0.71444303 (0.76677909)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00227565 (0.00203682), PSNR 26.42894554 (26.93252573), SSIM 0.76301473 (0.78159927)
# Finished training epoch 148
# Validate: MSE 0.00237673 (0.00224216), PSNR 26.24020386 (26.54779954), SSIM 0.71305567 (0.77006873)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00164694 (0.00204359), PSNR 27.83320808 (26.91825876), SSIM 0.79538417 (0.78122399)
# Finished training epoch 149
# Validate: MSE 0.00283192 (0.00241661), PSNR 25.47918510 (26.23588344), SSIM 0.71018410 (0.77046176)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00208754 (0.00204579), PSNR 26.80364799 (26.91422430), SSIM 0.77030289 (0.78122794)
# Finished training epoch 150
# Validate: MSE 0.00286573 (0.00259370), PSNR 25.42764091 (25.94129145), SSIM 0.70194376 (0.76611084)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00204168 (0.00202947), PSNR 26.90012550 (26.94993414), SSIM 0.78885704 (0.78178704)
# Finished training epoch 151
# Validate: MSE 0.00255440 (0.00220491), PSNR 25.92710876 (26.62402471), SSIM 0.71582824 (0.77635121)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00203355 (0.00203688), PSNR 26.91745758 (26.92963215), SSIM 0.77618945 (0.78141874)
# Finished training epoch 152
# Validate: MSE 0.00258082 (0.00232145), PSNR 25.88242149 (26.40356624), SSIM 0.71486157 (0.76874223)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00171274 (0.00203815), PSNR 27.66308022 (26.92868858), SSIM 0.77420032 (0.78125374)
# Finished training epoch 153
# Validate: MSE 0.00253108 (0.00247696), PSNR 25.96694183 (26.11827848), SSIM 0.71029317 (0.77164082)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00193178 (0.00201829), PSNR 27.14041901 (26.97341914), SSIM 0.78534186 (0.78149168)
# Finished training epoch 154
# Validate: MSE 0.00254914 (0.00220019), PSNR 25.93606567 (26.63294536), SSIM 0.71512806 (0.77897084)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00179403 (0.00201934), PSNR 27.46171188 (26.96789029), SSIM 0.80981874 (0.78164645)
# Finished training epoch 155
# Validate: MSE 0.00270620 (0.00239811), PSNR 25.67639923 (26.27214017), SSIM 0.71081299 (0.77530670)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00210572 (0.00202587), PSNR 26.76600266 (26.95471050), SSIM 0.78062117 (0.78124749)
# Finished training epoch 156
# Validate: MSE 0.00266302 (0.00227454), PSNR 25.74625969 (26.48656911), SSIM 0.70948958 (0.77255266)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00214159 (0.00202417), PSNR 26.69262886 (26.95968837), SSIM 0.77405900 (0.78140946)
# Finished training epoch 157
# Validate: MSE 0.00250970 (0.00221121), PSNR 26.00377464 (26.61461964), SSIM 0.71137744 (0.77457974)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00213904 (0.00201598), PSNR 26.69781113 (26.97845591), SSIM 0.76664257 (0.78130732)
# Finished training epoch 158
# Validate: MSE 0.00268746 (0.00225500), PSNR 25.70657539 (26.52812820), SSIM 0.71240616 (0.77242634)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00248092 (0.00202550), PSNR 26.05388069 (26.95838512), SSIM 0.78010082 (0.78115224)
# Finished training epoch 159
# Validate: MSE 0.00280362 (0.00232310), PSNR 25.52280426 (26.40257823), SSIM 0.70240581 (0.76906203)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00190819 (0.00201784), PSNR 27.19379234 (26.97234247), SSIM 0.78343952 (0.78117160)
# Finished training epoch 160
# Validate: MSE 0.00248021 (0.00236816), PSNR 26.05511665 (26.31613208), SSIM 0.71659505 (0.77447375)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00189764 (0.00200982), PSNR 27.21785736 (26.98795950), SSIM 0.79062283 (0.78131634)
# Finished training epoch 161
# Validate: MSE 0.00304175 (0.00248564), PSNR 25.16876411 (26.11975725), SSIM 0.71259874 (0.77292347)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00183008 (0.00202469), PSNR 27.37528610 (26.95753278), SSIM 0.78457630 (0.78093544)
# Finished training epoch 162
# Validate: MSE 0.00269529 (0.00234733), PSNR 25.69394112 (26.36154326), SSIM 0.70294881 (0.77093098)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00246830 (0.00202474), PSNR 26.07601357 (26.95887396), SSIM 0.76257068 (0.78107902)
# Finished training epoch 163
# Validate: MSE 0.00243023 (0.00229670), PSNR 26.14352226 (26.44797622), SSIM 0.70646143 (0.76811223)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00142489 (0.00201237), PSNR 28.46219444 (26.98692890), SSIM 0.78854990 (0.78131844)
# Finished training epoch 164
# Validate: MSE 0.00279936 (0.00242678), PSNR 25.52941704 (26.20584697), SSIM 0.70239311 (0.76841832)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00172093 (0.00199922), PSNR 27.64236450 (27.01105231), SSIM 0.78037483 (0.78116223)
# Finished training epoch 165
# Validate: MSE 0.00262079 (0.00242580), PSNR 25.81567001 (26.22145361), SSIM 0.70602649 (0.76618485)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00249440 (0.00201183), PSNR 26.03033447 (26.98655822), SSIM 0.79125047 (0.78114582)
# Finished training epoch 166
# Validate: MSE 0.00258304 (0.00223573), PSNR 25.87868500 (26.56440502), SSIM 0.71428591 (0.77387595)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00210714 (0.00200781), PSNR 26.76306725 (26.99430840), SSIM 0.76851225 (0.78105254)
# Finished training epoch 167
# Validate: MSE 0.00254585 (0.00225042), PSNR 25.94166756 (26.53650091), SSIM 0.71592820 (0.77334724)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00220339 (0.00201399), PSNR 26.56909180 (26.98195727), SSIM 0.79001170 (0.78093543)
# Finished training epoch 168
# Validate: MSE 0.00281959 (0.00238605), PSNR 25.49814034 (26.29466358), SSIM 0.70147955 (0.76631065)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00205688 (0.00200212), PSNR 26.86790276 (27.00662296), SSIM 0.76872337 (0.78097741)
# Finished training epoch 169
# Validate: MSE 0.00260804 (0.00237517), PSNR 25.83685493 (26.31585330), SSIM 0.71088964 (0.77189697)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00200426 (0.00200449), PSNR 26.98046112 (27.00155151), SSIM 0.76991683 (0.78101589)
# Finished training epoch 170
# Validate: MSE 0.00289850 (0.00256695), PSNR 25.37825966 (25.95513874), SSIM 0.67661780 (0.76006755)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00177840 (0.00201526), PSNR 27.49969673 (26.97763224), SSIM 0.79432929 (0.78076747)
# Finished training epoch 171
# Validate: MSE 0.00254828 (0.00225972), PSNR 25.93753242 (26.52003748), SSIM 0.71183777 (0.77364899)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00168895 (0.00199710), PSNR 27.72384262 (27.01707993), SSIM 0.79420054 (0.78103356)
# Finished training epoch 172
# Validate: MSE 0.00262008 (0.00240902), PSNR 25.81686211 (26.24366274), SSIM 0.71164733 (0.77197176)
# Finished validation.
# Starting training epoch 173
# Epoch: 173, MSE 0.00204900 (0.00198425), PSNR 26.88458633 (27.04385148), SSIM 0.75925004 (0.78116135)
# Finished training epoch 173
# Validate: MSE 0.00252334 (0.00235778), PSNR 25.98023987 (26.33886230), SSIM 0.71355259 (0.77002758)
# Finished validation.
# Starting training epoch 174
# Epoch: 174, MSE 0.00186882 (0.00199846), PSNR 27.28432655 (27.01209761), SSIM 0.79568052 (0.78084652)
# Finished training epoch 174
# Validate: MSE 0.00295313 (0.00252387), PSNR 25.29717445 (26.05512792), SSIM 0.70831263 (0.76797012)
# Finished validation.
# Starting training epoch 175
# Epoch: 175, MSE 0.00176935 (0.00198338), PSNR 27.52185440 (27.04664737), SSIM 0.78433841 (0.78105146)
# Finished training epoch 175
# Validate: MSE 0.00264625 (0.00242311), PSNR 25.77368355 (26.22861836), SSIM 0.71455812 (0.76962725)
# Finished validation.
# Starting training epoch 176
# Epoch: 176, MSE 0.00196963 (0.00199307), PSNR 27.05616379 (27.02761259), SSIM 0.78831130 (0.78078625)
# Finished training epoch 176
# Validate: MSE 0.00298318 (0.00266394), PSNR 25.25320244 (25.82205371), SSIM 0.70542866 (0.76602333)
# Finished validation.
# Starting training epoch 177
# Epoch: 177, MSE 0.00154491 (0.00200668), PSNR 28.11095238 (26.99639637), SSIM 0.79560906 (0.78076682)
# Finished training epoch 177
# Validate: MSE 0.00242651 (0.00228547), PSNR 26.15017509 (26.46515476), SSIM 0.71009147 (0.76795719)
# Finished validation.
# Starting training epoch 178
# Epoch: 178, MSE 0.00195940 (0.00199037), PSNR 27.07876968 (27.03058137), SSIM 0.78145850 (0.78086840)
# Finished training epoch 178
# Validate: MSE 0.00271145 (0.00254616), PSNR 25.66797638 (26.01072308), SSIM 0.70496416 (0.76138729)
# Finished validation.
# Starting training epoch 179
# Epoch: 179, MSE 0.00152973 (0.00197996), PSNR 28.15385628 (27.05498891), SSIM 0.79813659 (0.78086104)
# Finished training epoch 179
# Validate: MSE 0.00246003 (0.00229660), PSNR 26.09059715 (26.45737906), SSIM 0.71440476 (0.77154163)
# Finished validation.
# Starting training epoch 180
# Epoch: 180, MSE 0.00175047 (0.00198356), PSNR 27.56846046 (27.04580853), SSIM 0.79074323 (0.78076655)
# Finished training epoch 180
# Validate: MSE 0.00291117 (0.00239057), PSNR 25.35932732 (26.28250351), SSIM 0.70446670 (0.77253171)
# Finished validation.
# Starting training epoch 181
# Epoch: 181, MSE 0.00170084 (0.00197790), PSNR 27.69335938 (27.05808360), SSIM 0.78202403 (0.78095469)
# Finished training epoch 181
# Validate: MSE 0.00262805 (0.00236696), PSNR 25.80367088 (26.31901768), SSIM 0.70639759 (0.76342208)
# Finished validation.
# Starting training epoch 182
# Epoch: 182, MSE 0.00178428 (0.00197998), PSNR 27.48537254 (27.05471907), SSIM 0.79232037 (0.78077842)
# Finished training epoch 182
# Validate: MSE 0.00296667 (0.00248296), PSNR 25.27730560 (26.11653107), SSIM 0.70818734 (0.76781318)
# Finished validation.
# Starting training epoch 183
# Epoch: 183, MSE 0.00198959 (0.00197613), PSNR 27.01236725 (27.06305259), SSIM 0.78366637 (0.78095038)
# Finished training epoch 183
# Validate: MSE 0.00248164 (0.00247569), PSNR 26.05261421 (26.12590862), SSIM 0.71636677 (0.76140716)
# Finished validation.
# Starting training epoch 184
# Epoch: 184, MSE 0.00222789 (0.00197794), PSNR 26.52105331 (27.05943124), SSIM 0.76788074 (0.78092214)
# Finished training epoch 184
# Validate: MSE 0.00253825 (0.00228934), PSNR 25.95465851 (26.46022106), SSIM 0.70813304 (0.76502305)
# Finished validation.
# Starting training epoch 185
# Epoch: 185, MSE 0.00195663 (0.00197502), PSNR 27.08491516 (27.06383222), SSIM 0.77925897 (0.78077506)
# Finished training epoch 185
# Validate: MSE 0.00259563 (0.00221103), PSNR 25.85757256 (26.61211562), SSIM 0.70637119 (0.77092520)
# Finished validation.
# Starting training epoch 186
# Epoch: 186, MSE 0.00172974 (0.00197412), PSNR 27.62019920 (27.06585504), SSIM 0.79611254 (0.78059848)
# Finished training epoch 186
# Validate: MSE 0.00265041 (0.00236798), PSNR 25.76687050 (26.31411620), SSIM 0.71093804 (0.76614608)
# Finished validation.
# Starting training epoch 187
# Epoch: 187, MSE 0.00211254 (0.00197119), PSNR 26.75193977 (27.07271492), SSIM 0.79474205 (0.78084173)
# Finished training epoch 187
# Validate: MSE 0.00262628 (0.00288449), PSNR 25.80657959 (25.53350122), SSIM 0.70773691 (0.76471668)
# Finished validation.
# Starting training epoch 188
# Epoch: 188, MSE 0.00206892 (0.00197160), PSNR 26.84255600 (27.07228814), SSIM 0.76431203 (0.78070718)
# Finished training epoch 188
# Validate: MSE 0.00249797 (0.00231408), PSNR 26.02412605 (26.41007202), SSIM 0.70624620 (0.76447919)
# Finished validation.
# Starting training epoch 189
# Epoch: 189, MSE 0.00190465 (0.00197344), PSNR 27.20183754 (27.06835107), SSIM 0.76572847 (0.78092069)
# Finished training epoch 189
# Validate: MSE 0.00294195 (0.00263198), PSNR 25.31365204 (25.85675099), SSIM 0.69569725 (0.75867553)
# Finished validation.
# Starting training epoch 190
# Epoch: 190, MSE 0.00184980 (0.00197328), PSNR 27.32874298 (27.06825857), SSIM 0.76233137 (0.78072753)
# Finished training epoch 190
# Validate: MSE 0.00265073 (0.00231442), PSNR 25.76633835 (26.41813625), SSIM 0.70728588 (0.76697248)
# Finished validation.
# Starting training epoch 191
# Epoch: 191, MSE 0.00176880 (0.00196753), PSNR 27.52321243 (27.07773772), SSIM 0.78542745 (0.78067309)
# Finished training epoch 191
# Validate: MSE 0.00297163 (0.00277432), PSNR 25.27004623 (25.63192194), SSIM 0.70341372 (0.75939543)
# Finished validation.
# Starting training epoch 192
# Epoch: 192, MSE 0.00146042 (0.00196808), PSNR 28.35523033 (27.08078174), SSIM 0.78851986 (0.78068833)
# Finished training epoch 192
# Validate: MSE 0.00261522 (0.00226820), PSNR 25.82490921 (26.50296666), SSIM 0.70836413 (0.76875010)
# Finished validation.
# Starting training epoch 193
# Epoch: 193, MSE 0.00195693 (0.00196750), PSNR 27.08425522 (27.08176287), SSIM 0.78083956 (0.78084149)
# Finished training epoch 193
# Validate: MSE 0.00281305 (0.00225676), PSNR 25.50822258 (26.52848852), SSIM 0.70873123 (0.77205925)
# Finished validation.
# Starting training epoch 194
# Epoch: 194, MSE 0.00205125 (0.00196330), PSNR 26.87981415 (27.08784805), SSIM 0.78244030 (0.78067200)
# Finished training epoch 194
# Validate: MSE 0.00259679 (0.00236466), PSNR 25.85562706 (26.32941732), SSIM 0.70907664 (0.76879215)
# Finished validation.
# Starting training epoch 195
# Epoch: 195, MSE 0.00199230 (0.00196172), PSNR 27.00645638 (27.09382725), SSIM 0.76670283 (0.78071163)
# Finished training epoch 195
# Validate: MSE 0.00257352 (0.00232778), PSNR 25.89472771 (26.39035119), SSIM 0.70304728 (0.76634344)
# Finished validation.
# Starting training epoch 196
# Epoch: 196, MSE 0.00208807 (0.00194974), PSNR 26.80254364 (27.12001125), SSIM 0.77694827 (0.78099183)
# Finished training epoch 196
# Validate: MSE 0.00260641 (0.00238191), PSNR 25.83957863 (26.29085148), SSIM 0.70134735 (0.76465995)
# Finished validation.
# Starting training epoch 197
# Epoch: 197, MSE 0.00186499 (0.00195510), PSNR 27.29323006 (27.10804822), SSIM 0.77387750 (0.78062986)
# Finished training epoch 197
# Validate: MSE 0.00294146 (0.00266463), PSNR 25.31436920 (25.81139713), SSIM 0.69548762 (0.76337008)
# Finished validation.
# Starting training epoch 198
# Epoch: 198, MSE 0.00183731 (0.00195750), PSNR 27.35818100 (27.10242407), SSIM 0.77972156 (0.78064611)
# Finished training epoch 198
# Validate: MSE 0.00255577 (0.00264616), PSNR 25.92478943 (25.83942483), SSIM 0.69881225 (0.75725174)
# Finished validation.
# Starting training epoch 199
# Epoch: 199, MSE 0.00224918 (0.00195446), PSNR 26.47975731 (27.11032707), SSIM 0.76506269 (0.78065470)
# Finished training epoch 199
# Validate: MSE 0.00258452 (0.00242056), PSNR 25.87620354 (26.22332634), SSIM 0.70203364 (0.76247215)
# Finished validation.
# Starting training epoch 200
# Epoch: 200, MSE 0.00168162 (0.00195071), PSNR 27.74271393 (27.12217638), SSIM 0.78512472 (0.78078937)
# Finished training epoch 200
# Validate: MSE 0.00274157 (0.00272356), PSNR 25.62001038 (25.76085459), SSIM 0.70397532 (0.76144973)
# Finished validation.
# Starting training epoch 201
# Epoch: 201, MSE 0.00182697 (0.00194746), PSNR 27.38269043 (27.12486083), SSIM 0.80489385 (0.78074293)
# Finished training epoch 201
# Validate: MSE 0.00286016 (0.00293989), PSNR 25.43609047 (25.43503283), SSIM 0.69918549 (0.75751749)
# Finished validation.
# Starting training epoch 202
# Epoch: 202, MSE 0.00177779 (0.00195351), PSNR 27.50120354 (27.11158452), SSIM 0.77472639 (0.78056883)
# Finished training epoch 202
# Validate: MSE 0.00285438 (0.00278146), PSNR 25.44488144 (25.63257651), SSIM 0.69519961 (0.75690300)
# Finished validation.
# Starting training epoch 203
# Epoch: 203, MSE 0.00204797 (0.00194451), PSNR 26.88677216 (27.13317244), SSIM 0.78066528 (0.78060233)
# Finished training epoch 203
# Validate: MSE 0.00269696 (0.00236396), PSNR 25.69125175 (26.32643283), SSIM 0.70507741 (0.76508063)
# Finished validation.
# Starting training epoch 204
# Epoch: 204, MSE 0.00182894 (0.00194946), PSNR 27.37799454 (27.12031520), SSIM 0.78592265 (0.78038258)
# Finished training epoch 204
# Validate: MSE 0.00268372 (0.00230091), PSNR 25.71261787 (26.44286734), SSIM 0.70963109 (0.77121134)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00268372 (0.00230091), PSNR 25.71261787 (26.44286734), SSIM 0.70963109 (0.77121133)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
