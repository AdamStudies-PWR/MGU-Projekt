# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-46bf494d9a01e5c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-46bf494d9a01e5c");
#           const url = new URL("/", window.location);
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
                transforms.RandomVerticalFlip(),  
                transforms.RandomRotation(10),
                transforms.ColorJitter(brightness=0.05, contrast=0.05, saturation=0.05, hue=0.05)
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .25

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        self.batchnorm5 = nn.BatchNorm2d(2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = y = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x + y)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm5(self.convtrans3(x + input)), negative_slope=0.1)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 32, 32]           2,306
#       BatchNorm2d-10            [-1, 2, 32, 32]               4
# ================================================================
# Total params: 2,662,278
# Trainable params: 2,662,278
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.78
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.94
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00240498 (0.04317634), PSNR 26.18887901 (19.05293106), SSIM 0.77045929 (0.46797675)
# Finished training epoch 0
# Validate: MSE 0.00322293 (0.00276196), PSNR 24.91748619 (25.66230228), SSIM 0.70535600 (0.77504690)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00292737 (0.00276169), PSNR 25.33522797 (25.60989477), SSIM 0.78277564 (0.76857419)
# Finished training epoch 1
# Validate: MSE 0.00321934 (0.00276010), PSNR 24.92233276 (25.66538044), SSIM 0.70484686 (0.77504291)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00301752 (0.00274890), PSNR 25.20349503 (25.63245347), SSIM 0.75473601 (0.76871359)
# Finished training epoch 2
# Validate: MSE 0.00318627 (0.00275944), PSNR 24.96717834 (25.66791514), SSIM 0.70567769 (0.77488110)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00264109 (0.00275351), PSNR 25.78217506 (25.62361488), SSIM 0.77186835 (0.76867788)
# Finished training epoch 3
# Validate: MSE 0.00321380 (0.00276088), PSNR 24.92981529 (25.66441143), SSIM 0.70503628 (0.77476047)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00298848 (0.00275067), PSNR 25.24549103 (25.62778868), SSIM 0.76662880 (0.76871379)
# Finished training epoch 4
# Validate: MSE 0.00320924 (0.00275856), PSNR 24.93597412 (25.66824338), SSIM 0.70550978 (0.77511570)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00290743 (0.00275132), PSNR 25.36490059 (25.62863897), SSIM 0.77845335 (0.76858881)
# Finished training epoch 5
# Validate: MSE 0.00320771 (0.00275866), PSNR 24.93804550 (25.66805580), SSIM 0.70555925 (0.77507529)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00289407 (0.00274629), PSNR 25.38491440 (25.63849242), SSIM 0.73631638 (0.76873267)
# Finished training epoch 6
# Validate: MSE 0.00321414 (0.00275797), PSNR 24.92934608 (25.66890839), SSIM 0.70478117 (0.77475878)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00296916 (0.00275064), PSNR 25.27365875 (25.62784387), SSIM 0.74460679 (0.76869709)
# Finished training epoch 7
# Validate: MSE 0.00317569 (0.00275652), PSNR 24.98161888 (25.67300807), SSIM 0.70551920 (0.77492435)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00327395 (0.00275506), PSNR 24.84927750 (25.62105585), SSIM 0.75715679 (0.76857672)
# Finished training epoch 8
# Validate: MSE 0.00318319 (0.00275530), PSNR 24.97137070 (25.67462285), SSIM 0.70510620 (0.77492479)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00291245 (0.00275132), PSNR 25.35741043 (25.62870903), SSIM 0.78701270 (0.76865477)
# Finished training epoch 9
# Validate: MSE 0.00320308 (0.00275611), PSNR 24.94432449 (25.67228607), SSIM 0.70603704 (0.77511678)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00220173 (0.00275295), PSNR 26.57236862 (25.62596080), SSIM 0.77245080 (0.76854426)
# Finished training epoch 10
# Validate: MSE 0.00320072 (0.00275515), PSNR 24.94751549 (25.67393619), SSIM 0.70518041 (0.77504437)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00298596 (0.00275640), PSNR 25.24915314 (25.61912745), SSIM 0.77817810 (0.76848424)
# Finished training epoch 11
# Validate: MSE 0.00319572 (0.00275396), PSNR 24.95431137 (25.67593461), SSIM 0.70534074 (0.77499139)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00257173 (0.00275477), PSNR 25.89774895 (25.62144531), SSIM 0.76555210 (0.76871409)
# Finished training epoch 12
# Validate: MSE 0.00317892 (0.00275179), PSNR 24.97720909 (25.68023851), SSIM 0.70454973 (0.77474678)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00278899 (0.00274704), PSNR 25.54553223 (25.63739611), SSIM 0.74677789 (0.76860416)
# Finished training epoch 13
# Validate: MSE 0.00319440 (0.00275170), PSNR 24.95610619 (25.67962335), SSIM 0.70512831 (0.77487681)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00221156 (0.00275077), PSNR 26.55302238 (25.62997073), SSIM 0.78552806 (0.76871362)
# Finished training epoch 14
# Validate: MSE 0.00321332 (0.00275508), PSNR 24.93046379 (25.67339743), SSIM 0.70575970 (0.77518667)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00279422 (0.00274890), PSNR 25.53739166 (25.63081400), SSIM 0.75928873 (0.76861650)
# Finished training epoch 15
# Validate: MSE 0.00317946 (0.00275024), PSNR 24.97646713 (25.68248637), SSIM 0.70567310 (0.77505912)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00275005 (0.00274483), PSNR 25.60659790 (25.63863629), SSIM 0.78054726 (0.76874626)
# Finished training epoch 16
# Validate: MSE 0.00319629 (0.00275057), PSNR 24.95353127 (25.68118998), SSIM 0.70519853 (0.77527799)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00236475 (0.00275476), PSNR 26.26214981 (25.62462635), SSIM 0.77106112 (0.76853408)
# Finished training epoch 17
# Validate: MSE 0.00317575 (0.00274787), PSNR 24.98154068 (25.68657410), SSIM 0.70490277 (0.77486956)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00265040 (0.00274888), PSNR 25.76688576 (25.63241239), SSIM 0.76299500 (0.76856688)
# Finished training epoch 18
# Validate: MSE 0.00318757 (0.00274895), PSNR 24.96539497 (25.68407691), SSIM 0.70520484 (0.77496421)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00330802 (0.00273969), PSNR 24.80431175 (25.64583464), SSIM 0.75300467 (0.76861535)
# Finished training epoch 19
# Validate: MSE 0.00317039 (0.00274610), PSNR 24.98887253 (25.68954672), SSIM 0.70486426 (0.77497250)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00295089 (0.00274058), PSNR 25.30046463 (25.64658569), SSIM 0.76203752 (0.76887048)
# Finished training epoch 20
# Validate: MSE 0.00314910 (0.00274599), PSNR 25.01813126 (25.69053831), SSIM 0.70535159 (0.77469212)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00224684 (0.00275400), PSNR 26.48427963 (25.62402403), SSIM 0.77987748 (0.76850584)
# Finished training epoch 21
# Validate: MSE 0.00314904 (0.00274453), PSNR 25.01821709 (25.69322248), SSIM 0.70531493 (0.77491092)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00276994 (0.00274856), PSNR 25.57529831 (25.63780430), SSIM 0.74852574 (0.76849328)
# Finished training epoch 22
# Validate: MSE 0.00315596 (0.00274399), PSNR 25.00867844 (25.69343015), SSIM 0.70524067 (0.77488575)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00246983 (0.00274372), PSNR 26.07332230 (25.64077300), SSIM 0.76665503 (0.76872206)
# Finished training epoch 23
# Validate: MSE 0.00315803 (0.00274142), PSNR 25.00582886 (25.69746914), SSIM 0.70513952 (0.77475115)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00254382 (0.00274387), PSNR 25.94514084 (25.63866390), SSIM 0.78803861 (0.76868422)
# Finished training epoch 24
# Validate: MSE 0.00319383 (0.00274505), PSNR 24.95687866 (25.68979204), SSIM 0.70570910 (0.77535264)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00304793 (0.00274409), PSNR 25.15995026 (25.63829844), SSIM 0.76166922 (0.76848713)
# Finished training epoch 25
# Validate: MSE 0.00319532 (0.00274525), PSNR 24.95485115 (25.68952884), SSIM 0.70553267 (0.77547891)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00302524 (0.00274042), PSNR 25.19240570 (25.64736777), SSIM 0.77093506 (0.76862218)
# Finished training epoch 26
# Validate: MSE 0.00316024 (0.00273950), PSNR 25.00279236 (25.70042437), SSIM 0.70571113 (0.77524767)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00330998 (0.00274246), PSNR 24.80175018 (25.64335487), SSIM 0.75619119 (0.76868026)
# Finished training epoch 27
# Validate: MSE 0.00314731 (0.00273752), PSNR 25.02060127 (25.70409693), SSIM 0.70543653 (0.77485127)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00237523 (0.00274225), PSNR 26.24294662 (25.64363873), SSIM 0.78005326 (0.76859202)
# Finished training epoch 28
# Validate: MSE 0.00315755 (0.00273766), PSNR 25.00649452 (25.70349010), SSIM 0.70510739 (0.77537184)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00265283 (0.00274152), PSNR 25.76289940 (25.64346971), SSIM 0.74490213 (0.76861651)
# Finished training epoch 29
# Validate: MSE 0.00314310 (0.00273869), PSNR 25.02642250 (25.70203744), SSIM 0.70547485 (0.77519819)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00281007 (0.00273936), PSNR 25.51282692 (25.64555071), SSIM 0.77044851 (0.76856964)
# Finished training epoch 30
# Validate: MSE 0.00313762 (0.00273484), PSNR 25.03398895 (25.70867198), SSIM 0.70481086 (0.77458122)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00295271 (0.00273730), PSNR 25.29778671 (25.65305305), SSIM 0.77853453 (0.76853222)
# Finished training epoch 31
# Validate: MSE 0.00315191 (0.00273315), PSNR 25.01426315 (25.71068351), SSIM 0.70510292 (0.77507565)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00270842 (0.00274213), PSNR 25.67283440 (25.64423948), SSIM 0.74247348 (0.76854827)
# Finished training epoch 32
# Validate: MSE 0.00314925 (0.00273291), PSNR 25.01792908 (25.71068530), SSIM 0.70531005 (0.77508565)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00232526 (0.00274355), PSNR 26.33528519 (25.63837784), SSIM 0.78053081 (0.76841232)
# Finished training epoch 33
# Validate: MSE 0.00317317 (0.00273289), PSNR 24.98506355 (25.70994168), SSIM 0.70501637 (0.77531135)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00278685 (0.00273002), PSNR 25.54886818 (25.66099925), SSIM 0.76615697 (0.76862475)
# Finished training epoch 34
# Validate: MSE 0.00313370 (0.00272973), PSNR 25.03942299 (25.71686737), SSIM 0.70449388 (0.77515205)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00268515 (0.00273035), PSNR 25.71031570 (25.66055907), SSIM 0.79253376 (0.76869225)
# Finished training epoch 35
# Validate: MSE 0.00312371 (0.00272838), PSNR 25.05329895 (25.71940874), SSIM 0.70488715 (0.77509853)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00231837 (0.00273351), PSNR 26.34816742 (25.65786139), SSIM 0.78646415 (0.76864052)
# Finished training epoch 36
# Validate: MSE 0.00312596 (0.00272628), PSNR 25.05016518 (25.72261215), SSIM 0.70441282 (0.77500252)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00325025 (0.00272840), PSNR 24.88083839 (25.66425417), SSIM 0.73397207 (0.76860779)
# Finished training epoch 37
# Validate: MSE 0.00311804 (0.00272487), PSNR 25.06117630 (25.72539966), SSIM 0.70480323 (0.77478164)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00231511 (0.00272700), PSNR 26.35428238 (25.66390565), SSIM 0.79231060 (0.76844211)
# Finished training epoch 38
# Validate: MSE 0.00315900 (0.00272816), PSNR 25.00449562 (25.71745666), SSIM 0.70616341 (0.77528784)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00251355 (0.00273181), PSNR 25.99712944 (25.65838210), SSIM 0.77569318 (0.76855237)
# Finished training epoch 39
# Validate: MSE 0.00313418 (0.00272342), PSNR 25.03875542 (25.72618105), SSIM 0.70526934 (0.77503160)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00172657 (0.00273204), PSNR 27.62814522 (25.65911678), SSIM 0.77717334 (0.76833410)
# Finished training epoch 40
# Validate: MSE 0.00312655 (0.00272122), PSNR 25.04934692 (25.73022991), SSIM 0.70518005 (0.77527516)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00305176 (0.00272582), PSNR 25.15449524 (25.66872278), SSIM 0.76883501 (0.76860485)
# Finished training epoch 41
# Validate: MSE 0.00314027 (0.00272235), PSNR 25.03032684 (25.72747235), SSIM 0.70551515 (0.77547248)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00302466 (0.00272176), PSNR 25.19323730 (25.67708206), SSIM 0.72101289 (0.76851504)
# Finished training epoch 42
# Validate: MSE 0.00309089 (0.00271692), PSNR 25.09915733 (25.73903985), SSIM 0.70360476 (0.77438910)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00304574 (0.00271421), PSNR 25.16306877 (25.68715417), SSIM 0.76077098 (0.76856993)
# Finished training epoch 43
# Validate: MSE 0.00312344 (0.00271672), PSNR 25.05366898 (25.73724849), SSIM 0.70483696 (0.77505619)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00254461 (0.00272639), PSNR 25.94378281 (25.66880184), SSIM 0.77467090 (0.76814219)
# Finished training epoch 44
# Validate: MSE 0.00312497 (0.00271598), PSNR 25.05153656 (25.73825553), SSIM 0.70347261 (0.77518698)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00292820 (0.00271805), PSNR 25.33399391 (25.68153483), SSIM 0.79136038 (0.76818005)
# Finished training epoch 45
# Validate: MSE 0.00311378 (0.00271463), PSNR 25.06711769 (25.74071791), SSIM 0.70397675 (0.77496363)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00253477 (0.00271942), PSNR 25.96060944 (25.68011410), SSIM 0.75858063 (0.76808180)
# Finished training epoch 46
# Validate: MSE 0.00310659 (0.00271086), PSNR 25.07715607 (25.74746178), SSIM 0.70387971 (0.77480103)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00327443 (0.00270822), PSNR 24.84864616 (25.69416823), SSIM 0.77453816 (0.76806268)
# Finished training epoch 47
# Validate: MSE 0.00308718 (0.00270875), PSNR 25.10438156 (25.75189011), SSIM 0.70335960 (0.77465079)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00268888 (0.00271089), PSNR 25.70428848 (25.69070173), SSIM 0.74210799 (0.76794132)
# Finished training epoch 48
# Validate: MSE 0.00313709 (0.00271119), PSNR 25.03473282 (25.74534090), SSIM 0.70407951 (0.77514213)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00222290 (0.00271270), PSNR 26.53079414 (25.68860020), SSIM 0.76666588 (0.76796689)
# Finished training epoch 49
# Validate: MSE 0.00309364 (0.00270435), PSNR 25.09530640 (25.75817830), SSIM 0.70278096 (0.77461467)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00256083 (0.00271502), PSNR 25.91618538 (25.68873598), SSIM 0.76485962 (0.76762192)
# Finished training epoch 50
# Validate: MSE 0.00310773 (0.00270479), PSNR 25.07557106 (25.75618393), SSIM 0.70411545 (0.77515445)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00207870 (0.00270079), PSNR 26.82207680 (25.70725711), SSIM 0.80315125 (0.76768450)
# Finished training epoch 51
# Validate: MSE 0.00308885 (0.00269994), PSNR 25.10202980 (25.76447367), SSIM 0.70252264 (0.77428970)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00276628 (0.00269993), PSNR 25.58104324 (25.71164230), SSIM 0.77321196 (0.76760729)
# Finished training epoch 52
# Validate: MSE 0.00310547 (0.00269906), PSNR 25.07872009 (25.76584878), SSIM 0.70175326 (0.77445772)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00251807 (0.00270072), PSNR 25.98932076 (25.70925506), SSIM 0.76236039 (0.76760878)
# Finished training epoch 53
# Validate: MSE 0.00312847 (0.00270075), PSNR 25.04667282 (25.76131498), SSIM 0.70183790 (0.77487566)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00215440 (0.00269950), PSNR 26.66673088 (25.70815147), SSIM 0.77567369 (0.76730804)
# Finished training epoch 54
# Validate: MSE 0.00310374 (0.00269763), PSNR 25.08115196 (25.76693470), SSIM 0.70213044 (0.77431294)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00285882 (0.00270180), PSNR 25.43813515 (25.70872469), SSIM 0.77315146 (0.76702163)
# Finished training epoch 55
# Validate: MSE 0.00305300 (0.00269214), PSNR 25.15272522 (25.77841572), SSIM 0.70167327 (0.77358796)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00264219 (0.00270658), PSNR 25.78035736 (25.69908350), SSIM 0.77222186 (0.76697837)
# Finished training epoch 56
# Validate: MSE 0.00311041 (0.00269545), PSNR 25.07182884 (25.76990228), SSIM 0.70182300 (0.77427039)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00271497 (0.00269211), PSNR 25.66235161 (25.72107979), SSIM 0.78922653 (0.76712722)
# Finished training epoch 57
# Validate: MSE 0.00307472 (0.00268995), PSNR 25.12194252 (25.78067616), SSIM 0.70242214 (0.77411860)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00216636 (0.00269192), PSNR 26.64270020 (25.72130433), SSIM 0.77678955 (0.76701465)
# Finished training epoch 58
# Validate: MSE 0.00310413 (0.00269469), PSNR 25.08060265 (25.77097723), SSIM 0.70389819 (0.77483336)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00254026 (0.00269340), PSNR 25.95122528 (25.72063182), SSIM 0.80276585 (0.76677830)
# Finished training epoch 59
# Validate: MSE 0.00307665 (0.00268670), PSNR 25.11921310 (25.78536974), SSIM 0.70314020 (0.77402857)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00297168 (0.00268989), PSNR 25.26997566 (25.72702324), SSIM 0.75224763 (0.76674578)
# Finished training epoch 60
# Validate: MSE 0.00309299 (0.00268892), PSNR 25.09621239 (25.78072227), SSIM 0.70219994 (0.77459968)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00262585 (0.00270111), PSNR 25.80729294 (25.71079910), SSIM 0.78074300 (0.76644462)
# Finished training epoch 61
# Validate: MSE 0.00308796 (0.00268344), PSNR 25.10328293 (25.78981423), SSIM 0.70282710 (0.77387372)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00283914 (0.00269144), PSNR 25.46812820 (25.72466160), SSIM 0.76002228 (0.76647216)
# Finished training epoch 62
# Validate: MSE 0.00307387 (0.00268018), PSNR 25.12314987 (25.79576835), SSIM 0.70047778 (0.77336714)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00263440 (0.00269314), PSNR 25.79317856 (25.72098754), SSIM 0.76939487 (0.76602792)
# Finished training epoch 63
# Validate: MSE 0.00305296 (0.00267742), PSNR 25.15278816 (25.80074348), SSIM 0.70065963 (0.77334805)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00309996 (0.00267946), PSNR 25.08644295 (25.74393075), SSIM 0.75206769 (0.76620497)
# Finished training epoch 64
# Validate: MSE 0.00306522 (0.00267678), PSNR 25.13537979 (25.80096439), SSIM 0.70137894 (0.77359430)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00251800 (0.00268100), PSNR 25.98943520 (25.73854094), SSIM 0.78073776 (0.76606236)
# Finished training epoch 65
# Validate: MSE 0.00307683 (0.00267495), PSNR 25.11896515 (25.80352220), SSIM 0.70097947 (0.77368842)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00248840 (0.00268850), PSNR 26.04080391 (25.72725631), SSIM 0.77168977 (0.76575960)
# Finished training epoch 66
# Validate: MSE 0.00303277 (0.00267123), PSNR 25.18160248 (25.81110970), SSIM 0.69960153 (0.77238104)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00223670 (0.00267789), PSNR 26.50392914 (25.74573878), SSIM 0.77897823 (0.76590604)
# Finished training epoch 67
# Validate: MSE 0.00304605 (0.00266939), PSNR 25.16262627 (25.81371772), SSIM 0.70174116 (0.77304290)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00268529 (0.00267644), PSNR 25.71008110 (25.75144864), SSIM 0.76756752 (0.76561714)
# Finished training epoch 68
# Validate: MSE 0.00305928 (0.00266880), PSNR 25.14380264 (25.81297735), SSIM 0.70154411 (0.77262399)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00293909 (0.00267735), PSNR 25.31786728 (25.74627358), SSIM 0.76078951 (0.76552324)
# Finished training epoch 69
# Validate: MSE 0.00307721 (0.00266998), PSNR 25.11843109 (25.80991075), SSIM 0.70146275 (0.77283839)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00322934 (0.00267342), PSNR 24.90885925 (25.75327578), SSIM 0.73865145 (0.76540861)
# Finished training epoch 70
# Validate: MSE 0.00305364 (0.00266434), PSNR 25.15181923 (25.81992155), SSIM 0.70073462 (0.77289853)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00248465 (0.00266714), PSNR 26.04735184 (25.76287227), SSIM 0.78494757 (0.76527757)
# Finished training epoch 71
# Validate: MSE 0.00304988 (0.00266160), PSNR 25.15717697 (25.82467951), SSIM 0.69916862 (0.77291187)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00223028 (0.00267338), PSNR 26.51639557 (25.75774310), SSIM 0.78752536 (0.76497857)
# Finished training epoch 72
# Validate: MSE 0.00305423 (0.00266121), PSNR 25.15098190 (25.82497026), SSIM 0.70154452 (0.77310919)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00251129 (0.00266033), PSNR 26.00103569 (25.77575750), SSIM 0.76912755 (0.76502433)
# Finished training epoch 73
# Validate: MSE 0.00302987 (0.00265582), PSNR 25.18576241 (25.83445276), SSIM 0.69850045 (0.77164251)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00242905 (0.00266414), PSNR 26.14562798 (25.76870863), SSIM 0.77975351 (0.76453639)
# Finished training epoch 74
# Validate: MSE 0.00301416 (0.00265444), PSNR 25.20833206 (25.83654222), SSIM 0.70085204 (0.77148705)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00268725 (0.00266727), PSNR 25.70691299 (25.76288067), SSIM 0.76150453 (0.76439030)
# Finished training epoch 75
# Validate: MSE 0.00305570 (0.00265285), PSNR 25.14888763 (25.83737643), SSIM 0.69915992 (0.77177428)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00280708 (0.00265246), PSNR 25.51745224 (25.78813894), SSIM 0.75557864 (0.76450085)
# Finished training epoch 76
# Validate: MSE 0.00302139 (0.00264960), PSNR 25.19792557 (25.84311566), SSIM 0.69798207 (0.77092126)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00268933 (0.00265933), PSNR 25.70355415 (25.77717654), SSIM 0.77337885 (0.76415714)
# Finished training epoch 77
# Validate: MSE 0.00304187 (0.00264794), PSNR 25.16859818 (25.84547862), SSIM 0.69887072 (0.77114195)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00246369 (0.00266471), PSNR 26.08413315 (25.76771241), SSIM 0.75555295 (0.76404126)
# Finished training epoch 78
# Validate: MSE 0.00306996 (0.00265392), PSNR 25.12867928 (25.83452061), SSIM 0.69846785 (0.77211002)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00379867 (0.00265480), PSNR 24.20368004 (25.78570698), SSIM 0.73841745 (0.76391684)
# Finished training epoch 79
# Validate: MSE 0.00300766 (0.00264031), PSNR 25.21771622 (25.85882576), SSIM 0.69972336 (0.77089370)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00297692 (0.00264391), PSNR 25.26231956 (25.79745149), SSIM 0.74479103 (0.76358364)
# Finished training epoch 80
# Validate: MSE 0.00304563 (0.00264251), PSNR 25.16323090 (25.85381993), SSIM 0.69896150 (0.77137921)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00246800 (0.00265026), PSNR 26.07654572 (25.79202973), SSIM 0.75767201 (0.76333155)
# Finished training epoch 81
# Validate: MSE 0.00302150 (0.00264051), PSNR 25.19776917 (25.85692366), SSIM 0.69587904 (0.77004778)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00220281 (0.00265420), PSNR 26.57022667 (25.78333893), SSIM 0.77794075 (0.76310381)
# Finished training epoch 82
# Validate: MSE 0.00301295 (0.00263660), PSNR 25.21008301 (25.86339150), SSIM 0.69573718 (0.76991379)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00252013 (0.00265088), PSNR 25.98576927 (25.78970644), SSIM 0.76776856 (0.76282024)
# Finished training epoch 83
# Validate: MSE 0.00303467 (0.00263755), PSNR 25.17888260 (25.86068753), SSIM 0.69969374 (0.77055127)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00227986 (0.00263579), PSNR 26.42090797 (25.81393042), SSIM 0.77934605 (0.76305125)
# Finished training epoch 84
# Validate: MSE 0.00299157 (0.00262843), PSNR 25.24100494 (25.87678795), SSIM 0.69687176 (0.76981641)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00266499 (0.00264604), PSNR 25.74304199 (25.79933590), SSIM 0.74539644 (0.76266672)
# Finished training epoch 85
# Validate: MSE 0.00300166 (0.00262969), PSNR 25.22638512 (25.87407682), SSIM 0.69984269 (0.77083786)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00252169 (0.00263998), PSNR 25.98308563 (25.80600804), SSIM 0.74972600 (0.76256390)
# Finished training epoch 86
# Validate: MSE 0.00300793 (0.00262618), PSNR 25.21732140 (25.87992093), SSIM 0.69824648 (0.77005575)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00284397 (0.00264022), PSNR 25.46075249 (25.80674289), SSIM 0.74038535 (0.76223388)
# Finished training epoch 87
# Validate: MSE 0.00298170 (0.00262528), PSNR 25.25535965 (25.88156168), SSIM 0.69962239 (0.77037179)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00243873 (0.00263765), PSNR 26.12835884 (25.81085093), SSIM 0.76098317 (0.76224482)
# Finished training epoch 88
# Validate: MSE 0.00299892 (0.00262035), PSNR 25.23035622 (25.88980375), SSIM 0.69533837 (0.76875510)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00252727 (0.00263814), PSNR 25.97347832 (25.80820720), SSIM 0.75923795 (0.76197916)
# Finished training epoch 89
# Validate: MSE 0.00299486 (0.00261882), PSNR 25.23623276 (25.89212958), SSIM 0.69934547 (0.77022470)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00212069 (0.00262792), PSNR 26.73522758 (25.83027939), SSIM 0.75244129 (0.76204711)
# Finished training epoch 90
# Validate: MSE 0.00297231 (0.00261546), PSNR 25.26905441 (25.89762883), SSIM 0.69860983 (0.76969474)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00245268 (0.00263030), PSNR 26.10359001 (25.82180445), SSIM 0.78178614 (0.76185573)
# Finished training epoch 91
# Validate: MSE 0.00300592 (0.00261670), PSNR 25.22022057 (25.89440099), SSIM 0.69902039 (0.77049925)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00248397 (0.00262669), PSNR 26.04852676 (25.82725176), SSIM 0.76913649 (0.76186753)
# Finished training epoch 92
# Validate: MSE 0.00297270 (0.00261377), PSNR 25.26848412 (25.90038548), SSIM 0.69863158 (0.77004850)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00309690 (0.00262158), PSNR 25.09072113 (25.84054596), SSIM 0.75299066 (0.76163960)
# Finished training epoch 93
# Validate: MSE 0.00298286 (0.00260854), PSNR 25.25367165 (25.90808976), SSIM 0.69614798 (0.76844044)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00339720 (0.00262421), PSNR 24.68879128 (25.83505984), SSIM 0.73731649 (0.76175395)
# Finished training epoch 94
# Validate: MSE 0.00297337 (0.00260830), PSNR 25.26750946 (25.90811232), SSIM 0.69818234 (0.76851897)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00241784 (0.00262203), PSNR 26.16572189 (25.83788701), SSIM 0.77011365 (0.76154441)
# Finished training epoch 95
# Validate: MSE 0.00297540 (0.00260507), PSNR 25.26454163 (25.91325293), SSIM 0.69604957 (0.76825331)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00258451 (0.00262633), PSNR 25.87621117 (25.82904556), SSIM 0.76220357 (0.76130705)
# Finished training epoch 96
# Validate: MSE 0.00298332 (0.00260437), PSNR 25.25299454 (25.91433665), SSIM 0.69892550 (0.76935977)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00320346 (0.00261770), PSNR 24.94381332 (25.84244872), SSIM 0.74494445 (0.76150858)
# Finished training epoch 97
# Validate: MSE 0.00298377 (0.00260141), PSNR 25.25234222 (25.91875087), SSIM 0.69615483 (0.76796465)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00275711 (0.00260981), PSNR 25.59545135 (25.85685757), SSIM 0.75905156 (0.76136270)
# Finished training epoch 98
# Validate: MSE 0.00297657 (0.00259867), PSNR 25.26284409 (25.92366957), SSIM 0.69665897 (0.76813076)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00241947 (0.00261596), PSNR 26.16279411 (25.84714370), SSIM 0.77865267 (0.76118752)
# Finished training epoch 99
# Validate: MSE 0.00299544 (0.00260138), PSNR 25.23538780 (25.91833265), SSIM 0.69836587 (0.76854334)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00236319 (0.00261359), PSNR 26.26500893 (25.85043255), SSIM 0.77309436 (0.76104839)
# Finished training epoch 100
# Validate: MSE 0.00298638 (0.00259833), PSNR 25.24854469 (25.92386779), SSIM 0.69852012 (0.76842899)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00237783 (0.00261902), PSNR 26.23818779 (25.84304590), SSIM 0.77699602 (0.76080281)
# Finished training epoch 101
# Validate: MSE 0.00296258 (0.00259376), PSNR 25.28329468 (25.93111794), SSIM 0.69953614 (0.76831546)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00280693 (0.00260543), PSNR 25.51768875 (25.86448645), SSIM 0.75034940 (0.76081476)
# Finished training epoch 102
# Validate: MSE 0.00296913 (0.00259270), PSNR 25.27370834 (25.93326044), SSIM 0.69782889 (0.76861941)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00283411 (0.00260778), PSNR 25.47583580 (25.86262463), SSIM 0.74795955 (0.76083201)
# Finished training epoch 103
# Validate: MSE 0.00299221 (0.00259249), PSNR 25.24008560 (25.93315711), SSIM 0.69971430 (0.76858205)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00227146 (0.00260571), PSNR 26.43694305 (25.86331361), SSIM 0.76668537 (0.76087327)
# Finished training epoch 104
# Validate: MSE 0.00297606 (0.00258909), PSNR 25.26357651 (25.93887773), SSIM 0.69838774 (0.76865280)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00257974 (0.00260850), PSNR 25.88424683 (25.85995064), SSIM 0.74487031 (0.76075431)
# Finished training epoch 105
# Validate: MSE 0.00296321 (0.00258619), PSNR 25.28237343 (25.94272433), SSIM 0.69845581 (0.76666689)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00258253 (0.00260076), PSNR 25.87955093 (25.86966163), SSIM 0.77564627 (0.76082647)
# Finished training epoch 106
# Validate: MSE 0.00296262 (0.00258656), PSNR 25.28324127 (25.94306398), SSIM 0.70033550 (0.76888917)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00278489 (0.00259785), PSNR 25.55191803 (25.87746333), SSIM 0.77586776 (0.76086605)
# Finished training epoch 107
# Validate: MSE 0.00296279 (0.00258318), PSNR 25.28298569 (25.94821164), SSIM 0.69609630 (0.76801511)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00241968 (0.00259321), PSNR 26.16242790 (25.88317944), SSIM 0.76679194 (0.76051011)
# Finished training epoch 108
# Validate: MSE 0.00297517 (0.00258384), PSNR 25.26488495 (25.94690519), SSIM 0.69906694 (0.76822972)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00296219 (0.00259229), PSNR 25.28387260 (25.88930292), SSIM 0.74718648 (0.76103566)
# Finished training epoch 109
# Validate: MSE 0.00296434 (0.00258021), PSNR 25.28071404 (25.95328654), SSIM 0.69932139 (0.76827849)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00238541 (0.00259608), PSNR 26.22437286 (25.87915353), SSIM 0.77762353 (0.76060156)
# Finished training epoch 110
# Validate: MSE 0.00296547 (0.00258005), PSNR 25.27906418 (25.95329841), SSIM 0.70063150 (0.76886787)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00280724 (0.00259914), PSNR 25.51719475 (25.87371121), SSIM 0.75022638 (0.76057907)
# Finished training epoch 111
# Validate: MSE 0.00293564 (0.00257742), PSNR 25.32296944 (25.95776238), SSIM 0.69984663 (0.76770578)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00230613 (0.00259490), PSNR 26.37115288 (25.88183705), SSIM 0.76463431 (0.76063653)
# Finished training epoch 112
# Validate: MSE 0.00296810 (0.00257778), PSNR 25.27521706 (25.95704660), SSIM 0.69970894 (0.76848578)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00262645 (0.00259011), PSNR 25.80631065 (25.89274739), SSIM 0.75945723 (0.76073615)
# Finished training epoch 113
# Validate: MSE 0.00298016 (0.00257549), PSNR 25.25760841 (25.96042733), SSIM 0.69868243 (0.76733786)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00288997 (0.00259641), PSNR 25.39106560 (25.87823250), SSIM 0.78217018 (0.76045754)
# Finished training epoch 114
# Validate: MSE 0.00296128 (0.00257267), PSNR 25.28520584 (25.96543035), SSIM 0.69989407 (0.76834015)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00241323 (0.00258978), PSNR 26.17400742 (25.89082123), SSIM 0.76819843 (0.76050092)
# Finished training epoch 115
# Validate: MSE 0.00296573 (0.00257396), PSNR 25.27868271 (25.96339396), SSIM 0.70237941 (0.76931995)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00258874 (0.00258496), PSNR 25.86911774 (25.89888737), SSIM 0.75049102 (0.76051370)
# Finished training epoch 116
# Validate: MSE 0.00295438 (0.00257082), PSNR 25.29533005 (25.96863078), SSIM 0.69922113 (0.76829093)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00273981 (0.00258906), PSNR 25.62279510 (25.89343490), SSIM 0.75332409 (0.76041279)
# Finished training epoch 117
# Validate: MSE 0.00295694 (0.00256900), PSNR 25.29156876 (25.97048087), SSIM 0.69891107 (0.76775598)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00215008 (0.00258152), PSNR 26.67545128 (25.90225706), SSIM 0.77302527 (0.76048683)
# Finished training epoch 118
# Validate: MSE 0.00295292 (0.00256723), PSNR 25.29747772 (25.97371969), SSIM 0.69688225 (0.76696936)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00245310 (0.00258459), PSNR 26.10284805 (25.90016674), SSIM 0.75624192 (0.76054289)
# Finished training epoch 119
# Validate: MSE 0.00292689 (0.00256653), PSNR 25.33593369 (25.97524057), SSIM 0.69802886 (0.76738583)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00250773 (0.00259029), PSNR 26.00718307 (25.89199034), SSIM 0.76238126 (0.76030551)
# Finished training epoch 120
# Validate: MSE 0.00295459 (0.00256696), PSNR 25.29502296 (25.97411193), SSIM 0.69744074 (0.76754290)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00233587 (0.00258613), PSNR 26.31550407 (25.89785608), SSIM 0.76833725 (0.76034294)
# Finished training epoch 121
# Validate: MSE 0.00294459 (0.00256314), PSNR 25.30974579 (25.97997660), SSIM 0.69513065 (0.76655879)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00214270 (0.00258154), PSNR 26.69038582 (25.90437009), SSIM 0.78162318 (0.76023808)
# Finished training epoch 122
# Validate: MSE 0.00295699 (0.00256539), PSNR 25.29149818 (25.97622902), SSIM 0.69907522 (0.76748198)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00252631 (0.00258134), PSNR 25.97512817 (25.90523213), SSIM 0.76124084 (0.76043420)
# Finished training epoch 123
# Validate: MSE 0.00297448 (0.00256282), PSNR 25.26588440 (25.98110452), SSIM 0.70044398 (0.76822517)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00248247 (0.00257311), PSNR 26.05115509 (25.91820323), SSIM 0.75178528 (0.76046840)
# Finished training epoch 124
# Validate: MSE 0.00293261 (0.00255888), PSNR 25.32745934 (25.98693770), SSIM 0.69914734 (0.76760492)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00223493 (0.00258443), PSNR 26.50737000 (25.89994421), SSIM 0.78059095 (0.76032812)
# Finished training epoch 125
# Validate: MSE 0.00296101 (0.00256249), PSNR 25.28560066 (25.98164380), SSIM 0.69924545 (0.76918618)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00294197 (0.00257583), PSNR 25.31361198 (25.91796646), SSIM 0.76669818 (0.76052874)
# Finished training epoch 126
# Validate: MSE 0.00295979 (0.00256224), PSNR 25.28738403 (25.98230686), SSIM 0.70042777 (0.76882894)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00231351 (0.00257207), PSNR 26.35727692 (25.91995667), SSIM 0.77650589 (0.76066157)
# Finished training epoch 127
# Validate: MSE 0.00293487 (0.00255493), PSNR 25.32410622 (25.99389113), SSIM 0.69865513 (0.76793929)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00317942 (0.00257700), PSNR 24.97652245 (25.91029141), SSIM 0.73978364 (0.76015538)
# Finished training epoch 128
# Validate: MSE 0.00295459 (0.00255591), PSNR 25.29501915 (25.99178683), SSIM 0.69899553 (0.76763732)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00248639 (0.00257560), PSNR 26.04430580 (25.91428114), SSIM 0.75881952 (0.76019981)
# Finished training epoch 129
# Validate: MSE 0.00291970 (0.00255171), PSNR 25.34661293 (25.99856273), SSIM 0.69639945 (0.76671375)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00233430 (0.00256909), PSNR 26.31843758 (25.92426354), SSIM 0.77435428 (0.76043440)
# Finished training epoch 130
# Validate: MSE 0.00296186 (0.00255603), PSNR 25.28435707 (25.99190697), SSIM 0.70040739 (0.76816249)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00202779 (0.00257298), PSNR 26.92976189 (25.92065334), SSIM 0.76207352 (0.76044282)
# Finished training epoch 131
# Validate: MSE 0.00295017 (0.00255379), PSNR 25.30152893 (25.99524775), SSIM 0.69785851 (0.76715967)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00374640 (0.00256497), PSNR 24.26385498 (25.93193277), SSIM 0.73508394 (0.76062178)
# Finished training epoch 132
# Validate: MSE 0.00295365 (0.00255127), PSNR 25.29640770 (25.99958456), SSIM 0.69817102 (0.76752745)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00204861 (0.00256998), PSNR 26.88540840 (25.92616165), SSIM 0.77665323 (0.76061943)
# Finished training epoch 133
# Validate: MSE 0.00293455 (0.00255120), PSNR 25.32458878 (25.99964400), SSIM 0.69779074 (0.76774215)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00349302 (0.00256942), PSNR 24.56799126 (25.92494719), SSIM 0.74254942 (0.76028740)
# Finished training epoch 134
# Validate: MSE 0.00294453 (0.00254903), PSNR 25.30983162 (26.00328186), SSIM 0.69695467 (0.76679729)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00315897 (0.00256664), PSNR 25.00453758 (25.93110513), SSIM 0.74749470 (0.76032839)
# Finished training epoch 135
# Validate: MSE 0.00292704 (0.00254862), PSNR 25.33571243 (26.00382420), SSIM 0.70086908 (0.76741421)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00230578 (0.00256915), PSNR 26.37182236 (25.92784524), SSIM 0.76246172 (0.76039200)
# Finished training epoch 136
# Validate: MSE 0.00294778 (0.00254832), PSNR 25.30505562 (26.00500049), SSIM 0.69878745 (0.76865441)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00211498 (0.00257148), PSNR 26.74693680 (25.92307805), SSIM 0.79993051 (0.76052235)
# Finished training epoch 137
# Validate: MSE 0.00295459 (0.00255150), PSNR 25.29503059 (25.99851836), SSIM 0.69972080 (0.76826340)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00227659 (0.00256625), PSNR 26.42714310 (25.92864374), SSIM 0.77335590 (0.76038776)
# Finished training epoch 138
# Validate: MSE 0.00296633 (0.00255110), PSNR 25.27779961 (25.99977900), SSIM 0.69993889 (0.76832817)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00258014 (0.00256711), PSNR 25.88357353 (25.93082287), SSIM 0.76585853 (0.76052959)
# Finished training epoch 139
# Validate: MSE 0.00290653 (0.00254366), PSNR 25.36625290 (26.01210256), SSIM 0.70132852 (0.76686820)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00259843 (0.00256880), PSNR 25.85288620 (25.92662185), SSIM 0.74917853 (0.76056877)
# Finished training epoch 140
# Validate: MSE 0.00294420 (0.00254525), PSNR 25.31032944 (26.00888666), SSIM 0.69988847 (0.76717780)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00238153 (0.00256565), PSNR 26.23144341 (25.93351104), SSIM 0.76672858 (0.76057957)
# Finished training epoch 141
# Validate: MSE 0.00290950 (0.00254225), PSNR 25.36181641 (26.01444583), SSIM 0.69969451 (0.76808153)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00258032 (0.00255974), PSNR 25.88326645 (25.94173322), SSIM 0.76676548 (0.76065382)
# Finished training epoch 142
# Validate: MSE 0.00293476 (0.00254293), PSNR 25.32427979 (26.01225569), SSIM 0.69623089 (0.76591476)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00228153 (0.00255541), PSNR 26.41773033 (25.94801089), SSIM 0.77006471 (0.76065993)
# Finished training epoch 143
# Validate: MSE 0.00293055 (0.00254155), PSNR 25.33050728 (26.01589153), SSIM 0.70288956 (0.76838617)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00228402 (0.00256359), PSNR 26.41299629 (25.93649510), SSIM 0.74948925 (0.76047550)
# Finished training epoch 144
# Validate: MSE 0.00294146 (0.00254132), PSNR 25.31437111 (26.01581906), SSIM 0.70021927 (0.76756784)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00269889 (0.00256264), PSNR 25.68814659 (25.93583568), SSIM 0.76743656 (0.76067769)
# Finished training epoch 145
# Validate: MSE 0.00295475 (0.00254023), PSNR 25.29479790 (26.01808867), SSIM 0.70274609 (0.76968256)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00371951 (0.00255646), PSNR 24.29513931 (25.94649904), SSIM 0.72185075 (0.76061838)
# Finished training epoch 146
# Validate: MSE 0.00294246 (0.00253941), PSNR 25.31289673 (26.01940911), SSIM 0.70019889 (0.76898817)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00255734 (0.00256048), PSNR 25.92210770 (25.93882355), SSIM 0.77936554 (0.76053340)
# Finished training epoch 147
# Validate: MSE 0.00294479 (0.00253705), PSNR 25.30945969 (26.02271332), SSIM 0.70121300 (0.76893454)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00265085 (0.00255875), PSNR 25.76614952 (25.94441178), SSIM 0.76358479 (0.76063693)
# Finished training epoch 148
# Validate: MSE 0.00293505 (0.00253680), PSNR 25.32384682 (26.02341505), SSIM 0.70021212 (0.76761424)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00264167 (0.00256418), PSNR 25.78121376 (25.93388451), SSIM 0.76151490 (0.76019259)
# Finished training epoch 149
# Validate: MSE 0.00292602 (0.00253606), PSNR 25.33722687 (26.02461432), SSIM 0.70032322 (0.76812091)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00231904 (0.00255509), PSNR 26.34691620 (25.94630918), SSIM 0.77941632 (0.76064570)
# Finished training epoch 150
# Validate: MSE 0.00292794 (0.00253538), PSNR 25.33438301 (26.02534868), SSIM 0.69933927 (0.76733126)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00235693 (0.00255252), PSNR 26.27652931 (25.95168586), SSIM 0.77906072 (0.76057795)
# Finished training epoch 151
# Validate: MSE 0.00294881 (0.00253732), PSNR 25.30353737 (26.02237196), SSIM 0.70091027 (0.76885811)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00314699 (0.00255791), PSNR 25.02103996 (25.94683340), SSIM 0.76118171 (0.76053213)
# Finished training epoch 152
# Validate: MSE 0.00291669 (0.00253198), PSNR 25.35110092 (26.03136782), SSIM 0.69987667 (0.76804896)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00222057 (0.00255444), PSNR 26.53534508 (25.94926227), SSIM 0.75623143 (0.76062801)
# Finished training epoch 153
# Validate: MSE 0.00295224 (0.00253491), PSNR 25.29848862 (26.02658120), SSIM 0.69950563 (0.76850006)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00259714 (0.00255494), PSNR 25.85504723 (25.94887604), SSIM 0.75641650 (0.76065391)
# Finished training epoch 154
# Validate: MSE 0.00292265 (0.00253290), PSNR 25.34222984 (26.02987337), SSIM 0.70078140 (0.76790059)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00213007 (0.00255365), PSNR 26.71605492 (25.95235313), SSIM 0.76906073 (0.76066696)
# Finished training epoch 155
# Validate: MSE 0.00292578 (0.00253186), PSNR 25.33758163 (26.03084643), SSIM 0.69973302 (0.76630097)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00216535 (0.00254889), PSNR 26.64471436 (25.95654705), SSIM 0.76724297 (0.76064034)
# Finished training epoch 156
# Validate: MSE 0.00293638 (0.00253111), PSNR 25.32187271 (26.03297125), SSIM 0.70151031 (0.76875981)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00224278 (0.00254508), PSNR 26.49213219 (25.96591564), SSIM 0.77897406 (0.76083527)
# Finished training epoch 157
# Validate: MSE 0.00291893 (0.00252903), PSNR 25.34775734 (26.03531403), SSIM 0.69958436 (0.76714444)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00255106 (0.00254776), PSNR 25.93278503 (25.96052571), SSIM 0.74287903 (0.76089661)
# Finished training epoch 158
# Validate: MSE 0.00293545 (0.00252955), PSNR 25.32324600 (26.03468577), SSIM 0.69767082 (0.76661282)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00233111 (0.00255121), PSNR 26.32437897 (25.95633698), SSIM 0.77382034 (0.76056592)
# Finished training epoch 159
# Validate: MSE 0.00293251 (0.00252992), PSNR 25.32759857 (26.03460941), SSIM 0.70076239 (0.76816144)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00294768 (0.00255073), PSNR 25.30518913 (25.96006809), SSIM 0.76235509 (0.76101775)
# Finished training epoch 160
# Validate: MSE 0.00292366 (0.00252821), PSNR 25.34073448 (26.03684146), SSIM 0.69981617 (0.76724418)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00280345 (0.00254705), PSNR 25.52306938 (25.96348777), SSIM 0.74012524 (0.76089955)
# Finished training epoch 161
# Validate: MSE 0.00292245 (0.00252611), PSNR 25.34252548 (26.04033815), SSIM 0.69789505 (0.76690422)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00266287 (0.00255036), PSNR 25.74649429 (25.95881678), SSIM 0.75151455 (0.76060689)
# Finished training epoch 162
# Validate: MSE 0.00293688 (0.00252838), PSNR 25.32113647 (26.03723518), SSIM 0.70154858 (0.76895870)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00245074 (0.00255305), PSNR 26.10702896 (25.95037817), SSIM 0.76031429 (0.76065047)
# Finished training epoch 163
# Validate: MSE 0.00292496 (0.00252661), PSNR 25.33879280 (26.04024141), SSIM 0.70353192 (0.76866172)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00275707 (0.00254981), PSNR 25.59552383 (25.96052205), SSIM 0.76914346 (0.76094688)
# Finished training epoch 164
# Validate: MSE 0.00294244 (0.00252751), PSNR 25.31292343 (26.03904003), SSIM 0.70251763 (0.76981130)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00187063 (0.00254477), PSNR 27.28012848 (25.96522676), SSIM 0.78507215 (0.76077621)
# Finished training epoch 165
# Validate: MSE 0.00292240 (0.00252541), PSNR 25.34260750 (26.04102295), SSIM 0.69914079 (0.76643101)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00220890 (0.00254688), PSNR 26.55823326 (25.96298837), SSIM 0.77739859 (0.76080881)
# Finished training epoch 166
# Validate: MSE 0.00292716 (0.00252708), PSNR 25.33552742 (26.03914961), SSIM 0.70203662 (0.76830359)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00238985 (0.00254822), PSNR 26.21629524 (25.96309072), SSIM 0.73068511 (0.76100694)
# Finished training epoch 167
# Validate: MSE 0.00291876 (0.00252382), PSNR 25.34801292 (26.04385074), SSIM 0.70055956 (0.76730300)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00325681 (0.00254191), PSNR 24.87207985 (25.97425260), SSIM 0.74010020 (0.76097249)
# Finished training epoch 168
# Validate: MSE 0.00290828 (0.00252333), PSNR 25.36363792 (26.04529149), SSIM 0.70280540 (0.76785082)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00257694 (0.00254555), PSNR 25.88894844 (25.96725248), SSIM 0.75283498 (0.76094279)
# Finished training epoch 169
# Validate: MSE 0.00294582 (0.00252275), PSNR 25.30793571 (26.04605312), SSIM 0.69924551 (0.76750934)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00230388 (0.00254356), PSNR 26.37540817 (25.96956203), SSIM 0.77163470 (0.76079684)
# Finished training epoch 170
# Validate: MSE 0.00291534 (0.00252273), PSNR 25.35310555 (26.04695616), SSIM 0.70353943 (0.77014779)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00277515 (0.00254159), PSNR 25.56713486 (25.97057667), SSIM 0.76450336 (0.76099449)
# Finished training epoch 171
# Validate: MSE 0.00293242 (0.00252164), PSNR 25.32773781 (26.04730480), SSIM 0.69972241 (0.76675705)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00393294 (0.00254534), PSNR 24.05282593 (25.96739860), SSIM 0.71888149 (0.76083613)
# Finished training epoch 172
# Validate: MSE 0.00291238 (0.00251971), PSNR 25.35751534 (26.05149873), SSIM 0.70117557 (0.76817060)
# Finished validation.
# Starting training epoch 173
# ...
# Finished validation.
# Starting training epoch 277
# Epoch: 277, MSE 0.00258874 (0.00249039), PSNR 25.86912346 (26.05713155), SSIM 0.76560688 (0.76287579)
# Finished training epoch 277
# Validate: MSE 0.00289606 (0.00247157), PSNR 25.38192177 (26.13275246), SSIM 0.70394385 (0.76983787)
# Finished validation.
# Starting training epoch 278
# Epoch: 278, MSE 0.00198627 (0.00249417), PSNR 27.01961136 (26.05346017), SSIM 0.78334397 (0.76277987)
# Finished training epoch 278
# Validate: MSE 0.00288885 (0.00247028), PSNR 25.39274406 (26.13470600), SSIM 0.70462978 (0.76871987)
# Finished validation.
# Starting training epoch 279
# Epoch: 279, MSE 0.00220358 (0.00249408), PSNR 26.56871033 (26.05259459), SSIM 0.77798164 (0.76261032)
# Finished training epoch 279
# Validate: MSE 0.00291048 (0.00246868), PSNR 25.36035538 (26.13785599), SSIM 0.70555723 (0.76978053)
# Finished validation.
# Starting training epoch 280
# Epoch: 280, MSE 0.00271833 (0.00249349), PSNR 25.65697861 (26.05456419), SSIM 0.76690120 (0.76250348)
# Finished training epoch 280
# Validate: MSE 0.00287367 (0.00246751), PSNR 25.41563034 (26.13984929), SSIM 0.70336556 (0.76942233)
# Finished validation.
# Starting training epoch 281
# Epoch: 281, MSE 0.00281286 (0.00249570), PSNR 25.50851059 (26.04865260), SSIM 0.76572627 (0.76252684)
# Finished training epoch 281
# Validate: MSE 0.00289804 (0.00246976), PSNR 25.37895775 (26.13589549), SSIM 0.70577598 (0.76997872)
# Finished validation.
# Starting training epoch 282
# Epoch: 282, MSE 0.00322109 (0.00249480), PSNR 24.91996956 (26.05244790), SSIM 0.73574293 (0.76253851)
# Finished training epoch 282
# Validate: MSE 0.00289248 (0.00246690), PSNR 25.38730049 (26.14154336), SSIM 0.70607173 (0.77067810)
# Finished validation.
# Starting training epoch 283
# Epoch: 283, MSE 0.00195771 (0.00248731), PSNR 27.08251190 (26.06529308), SSIM 0.78240061 (0.76277210)
# Finished training epoch 283
# Validate: MSE 0.00287327 (0.00246540), PSNR 25.41623497 (26.14298641), SSIM 0.70454365 (0.77016619)
# Finished validation.
# Starting training epoch 284
# Epoch: 284, MSE 0.00319037 (0.00249310), PSNR 24.96158218 (26.05331039), SSIM 0.75748277 (0.76252404)
# Finished training epoch 284
# Validate: MSE 0.00289734 (0.00246774), PSNR 25.37999725 (26.13925851), SSIM 0.70623988 (0.76955362)
# Finished validation.
# Starting training epoch 285
# Epoch: 285, MSE 0.00216650 (0.00249096), PSNR 26.64241791 (26.05955876), SSIM 0.77548724 (0.76261563)
# Finished training epoch 285
# Validate: MSE 0.00290203 (0.00246873), PSNR 25.37298203 (26.13814982), SSIM 0.70684808 (0.77066323)
# Finished validation.
# Starting training epoch 286
# Epoch: 286, MSE 0.00235267 (0.00249130), PSNR 26.28439331 (26.05860815), SSIM 0.76335114 (0.76290523)
# Finished training epoch 286
# Validate: MSE 0.00286539 (0.00246785), PSNR 25.42815781 (26.13869807), SSIM 0.70619500 (0.76973837)
# Finished validation.
# Starting training epoch 287
# Epoch: 287, MSE 0.00195561 (0.00249049), PSNR 27.08716774 (26.05926151), SSIM 0.78932965 (0.76274162)
# Finished training epoch 287
# Validate: MSE 0.00286871 (0.00246549), PSNR 25.42312622 (26.14269126), SSIM 0.70628989 (0.76975594)
# Finished validation.
# Starting training epoch 288
# Epoch: 288, MSE 0.00255170 (0.00248748), PSNR 25.93169594 (26.06377194), SSIM 0.75466341 (0.76267128)
# Finished training epoch 288
# Validate: MSE 0.00290545 (0.00246909), PSNR 25.36786270 (26.13712059), SSIM 0.70227826 (0.76938465)
# Finished validation.
# Starting training epoch 289
# Epoch: 289, MSE 0.00317916 (0.00249313), PSNR 24.97688103 (26.05877236), SSIM 0.75442231 (0.76267240)
# Finished training epoch 289
# Validate: MSE 0.00288796 (0.00246461), PSNR 25.39409256 (26.14462984), SSIM 0.70351696 (0.76968681)
# Finished validation.
# Starting training epoch 290
# Epoch: 290, MSE 0.00237363 (0.00248821), PSNR 26.24586868 (26.06594908), SSIM 0.76211292 (0.76264485)
# Finished training epoch 290
# Validate: MSE 0.00290754 (0.00247023), PSNR 25.36474609 (26.13454934), SSIM 0.70364439 (0.76890642)
# Finished validation.
# Starting training epoch 291
# Epoch: 291, MSE 0.00248825 (0.00248460), PSNR 26.04106522 (26.07188753), SSIM 0.76506925 (0.76298914)
# Finished training epoch 291
# Validate: MSE 0.00289160 (0.00246354), PSNR 25.38861275 (26.14648577), SSIM 0.70506454 (0.77067593)
# Finished validation.
# Starting training epoch 292
# Epoch: 292, MSE 0.00224377 (0.00249561), PSNR 26.49021149 (26.05098712), SSIM 0.77159739 (0.76265412)
# Finished training epoch 292
# Validate: MSE 0.00290670 (0.00246581), PSNR 25.36599541 (26.14280246), SSIM 0.70461643 (0.77072505)
# Finished validation.
# Starting training epoch 293
# Epoch: 293, MSE 0.00208385 (0.00248898), PSNR 26.81132889 (26.06170964), SSIM 0.78296328 (0.76283861)
# Finished training epoch 293
# Validate: MSE 0.00288476 (0.00246446), PSNR 25.39889717 (26.14503562), SSIM 0.70506096 (0.76968796)
# Finished validation.
# Starting training epoch 294
# Epoch: 294, MSE 0.00221383 (0.00249159), PSNR 26.54854965 (26.05686082), SSIM 0.77197707 (0.76281094)
# Finished training epoch 294
# Validate: MSE 0.00288538 (0.00246227), PSNR 25.39796257 (26.14871369), SSIM 0.70390618 (0.77001088)
# Finished validation.
# Starting training epoch 295
# Epoch: 295, MSE 0.00250852 (0.00249261), PSNR 26.00581932 (26.05625032), SSIM 0.76193422 (0.76296680)
# Finished training epoch 295
# Validate: MSE 0.00288354 (0.00246388), PSNR 25.40074348 (26.14596595), SSIM 0.70460254 (0.77011399)
# Finished validation.
# Starting training epoch 296
# Epoch: 296, MSE 0.00274951 (0.00249102), PSNR 25.60744286 (26.05762861), SSIM 0.75548089 (0.76284319)
# Finished training epoch 296
# Validate: MSE 0.00290048 (0.00246597), PSNR 25.37530327 (26.14236696), SSIM 0.70457059 (0.77093398)
# Finished validation.
# Starting training epoch 297
# Epoch: 297, MSE 0.00215233 (0.00249466), PSNR 26.67090797 (26.05448774), SSIM 0.77206212 (0.76263633)
# Finished training epoch 297
# Validate: MSE 0.00291774 (0.00246920), PSNR 25.34953117 (26.13740659), SSIM 0.70669645 (0.77091902)
# Finished validation.
# Starting training epoch 298
# Epoch: 298, MSE 0.00221712 (0.00248922), PSNR 26.54209709 (26.06280499), SSIM 0.75614941 (0.76274835)
# Finished training epoch 298
# Validate: MSE 0.00287822 (0.00246380), PSNR 25.40876389 (26.14596481), SSIM 0.70773011 (0.77111002)
# Finished validation.
# Starting training epoch 299
# Epoch: 299, MSE 0.00290461 (0.00248571), PSNR 25.36912155 (26.06991932), SSIM 0.76809132 (0.76278669)
# Finished training epoch 299
# Validate: MSE 0.00286932 (0.00246110), PSNR 25.42221260 (26.15041839), SSIM 0.70320088 (0.76985959)
# Finished validation.
# Starting training epoch 300
# Epoch: 300, MSE 0.00350054 (0.00248938), PSNR 24.55864525 (26.06313621), SSIM 0.73774517 (0.76276386)
# Finished training epoch 300
# Validate: MSE 0.00289678 (0.00246315), PSNR 25.38084412 (26.14768352), SSIM 0.70646608 (0.76987925)
# Finished validation.
# Starting training epoch 301
# Epoch: 301, MSE 0.00243725 (0.00249040), PSNR 26.13100624 (26.06079928), SSIM 0.75431538 (0.76264116)
# Finished training epoch 301
# Validate: MSE 0.00291357 (0.00246318), PSNR 25.35574532 (26.14740633), SSIM 0.70405918 (0.77058201)
# Finished validation.
# Starting training epoch 302
# Epoch: 302, MSE 0.00319132 (0.00249013), PSNR 24.96029091 (26.06367533), SSIM 0.74752313 (0.76298235)
# Finished training epoch 302
# Validate: MSE 0.00288343 (0.00245871), PSNR 25.40090942 (26.15468298), SSIM 0.70578665 (0.77007589)
# Finished validation.
# Starting training epoch 303
# Epoch: 303, MSE 0.00257916 (0.00248577), PSNR 25.88521194 (26.06573913), SSIM 0.76692986 (0.76261011)
# Finished training epoch 303
# Validate: MSE 0.00286707 (0.00245982), PSNR 25.42560959 (26.15285012), SSIM 0.70514286 (0.77051160)
# Finished validation.
# Starting training epoch 304
# Epoch: 304, MSE 0.00239201 (0.00248878), PSNR 26.21236420 (26.06205692), SSIM 0.76356822 (0.76277330)
# Finished training epoch 304
# Validate: MSE 0.00287961 (0.00245730), PSNR 25.40666962 (26.15669557), SSIM 0.70277762 (0.76871612)
# Finished validation.
# Starting training epoch 305
# Epoch: 305, MSE 0.00246369 (0.00248924), PSNR 26.08413696 (26.06241551), SSIM 0.76020288 (0.76274178)
# Finished training epoch 305
# Validate: MSE 0.00288236 (0.00246142), PSNR 25.40252113 (26.14972096), SSIM 0.70557696 (0.76981938)
# Finished validation.
# Starting training epoch 306
# Epoch: 306, MSE 0.00269329 (0.00248890), PSNR 25.69716454 (26.06263081), SSIM 0.75140792 (0.76295493)
# Finished training epoch 306
# Validate: MSE 0.00287156 (0.00245861), PSNR 25.41881561 (26.15517777), SSIM 0.70582837 (0.76930825)
# Finished validation.
# Starting training epoch 307
# Epoch: 307, MSE 0.00293230 (0.00248338), PSNR 25.32791519 (26.07258139), SSIM 0.77804977 (0.76293657)
# Finished training epoch 307
# Validate: MSE 0.00290832 (0.00246240), PSNR 25.36357307 (26.14903557), SSIM 0.70609927 (0.77140522)
# Finished validation.
# Starting training epoch 308
# Epoch: 308, MSE 0.00242562 (0.00248402), PSNR 26.15176773 (26.07294149), SSIM 0.75560045 (0.76279001)
# Finished training epoch 308
# Validate: MSE 0.00290203 (0.00246117), PSNR 25.37298012 (26.15132697), SSIM 0.70697403 (0.77102031)
# Finished validation.
# Starting training epoch 309
# Epoch: 309, MSE 0.00256810 (0.00248538), PSNR 25.90387726 (26.06698302), SSIM 0.75575221 (0.76286959)
# Finished training epoch 309
# Validate: MSE 0.00288652 (0.00245713), PSNR 25.39625359 (26.15697905), SSIM 0.70441502 (0.77023869)
# Finished validation.
# Starting training epoch 310
# Epoch: 310, MSE 0.00272697 (0.00248341), PSNR 25.64319611 (26.07738106), SSIM 0.75039184 (0.76289409)
# Finished training epoch 310
# Validate: MSE 0.00291148 (0.00246093), PSNR 25.35885620 (26.15108928), SSIM 0.70242852 (0.76951481)
# Finished validation.
# Starting training epoch 311
# Epoch: 311, MSE 0.00254151 (0.00248238), PSNR 25.94908142 (26.07241444), SSIM 0.76102173 (0.76291968)
# Finished training epoch 311
# Validate: MSE 0.00290653 (0.00245995), PSNR 25.36625481 (26.15319008), SSIM 0.70570135 (0.77157602)
# Finished validation.
# Starting training epoch 312
# Epoch: 312, MSE 0.00258793 (0.00248248), PSNR 25.87046814 (26.07200603), SSIM 0.75793445 (0.76300663)
# Finished training epoch 312
# Validate: MSE 0.00287884 (0.00245815), PSNR 25.40781593 (26.15545807), SSIM 0.70507383 (0.76942373)
# Finished validation.
# Starting training epoch 313
# Epoch: 313, MSE 0.00234476 (0.00248591), PSNR 26.29902267 (26.06727848), SSIM 0.78431761 (0.76294177)
# Finished training epoch 313
# Validate: MSE 0.00286932 (0.00245827), PSNR 25.42220497 (26.15537394), SSIM 0.70262700 (0.76890200)
# Finished validation.
# Starting training epoch 314
# Epoch: 314, MSE 0.00238539 (0.00248526), PSNR 26.22439957 (26.06850373), SSIM 0.77224648 (0.76296939)
# Finished training epoch 314
# Validate: MSE 0.00288855 (0.00246344), PSNR 25.39319420 (26.14680860), SSIM 0.70416129 (0.76994785)
# Finished validation.
# Starting training epoch 315
# Epoch: 315, MSE 0.00220226 (0.00247882), PSNR 26.57130241 (26.08020631), SSIM 0.78904110 (0.76302504)
# Finished training epoch 315
# Validate: MSE 0.00285774 (0.00245740), PSNR 25.43976784 (26.15715248), SSIM 0.70464820 (0.76998537)
# Finished validation.
# Starting training epoch 316
# Epoch: 316, MSE 0.00238287 (0.00247870), PSNR 26.22899628 (26.07973280), SSIM 0.76322877 (0.76319277)
# Finished training epoch 316
# Validate: MSE 0.00287668 (0.00245742), PSNR 25.41107750 (26.15673548), SSIM 0.70473647 (0.76953298)
# Finished validation.
# Starting training epoch 317
# Epoch: 317, MSE 0.00273128 (0.00248368), PSNR 25.63634109 (26.06912816), SSIM 0.77274871 (0.76302519)
# Finished training epoch 317
# Validate: MSE 0.00286839 (0.00245380), PSNR 25.42362022 (26.16316236), SSIM 0.70482177 (0.77004171)
# Finished validation.
# Starting training epoch 318
# Epoch: 318, MSE 0.00309059 (0.00248602), PSNR 25.09958458 (26.06799499), SSIM 0.75635117 (0.76300617)
# Finished training epoch 318
# Validate: MSE 0.00289817 (0.00246025), PSNR 25.37876129 (26.15239940), SSIM 0.70658803 (0.77051338)
# Finished validation.
# Starting training epoch 319
# Epoch: 319, MSE 0.00223918 (0.00248258), PSNR 26.49911118 (26.07396165), SSIM 0.77417457 (0.76292381)
# Finished training epoch 319
# Validate: MSE 0.00289563 (0.00245975), PSNR 25.38256645 (26.15338891), SSIM 0.70631659 (0.77134556)
# Finished validation.
# Starting training epoch 320
# Epoch: 320, MSE 0.00232685 (0.00247783), PSNR 26.33231354 (26.08296614), SSIM 0.76091307 (0.76327818)
# Finished training epoch 320
# Validate: MSE 0.00288103 (0.00245786), PSNR 25.40452194 (26.15544033), SSIM 0.70367151 (0.76869481)
# Finished validation.
# Starting training epoch 321
# Epoch: 321, MSE 0.00307440 (0.00248375), PSNR 25.12238884 (26.07052283), SSIM 0.74504578 (0.76296560)
# Finished training epoch 321
# Validate: MSE 0.00287620 (0.00245396), PSNR 25.41180801 (26.16283038), SSIM 0.70509124 (0.76969365)
# Finished validation.
# Starting training epoch 322
# Epoch: 322, MSE 0.00211776 (0.00248537), PSNR 26.74123955 (26.07135926), SSIM 0.78427136 (0.76296968)
# Finished training epoch 322
# Validate: MSE 0.00290324 (0.00245874), PSNR 25.37117577 (26.15559994), SSIM 0.70440972 (0.77205154)
# Finished validation.
# Starting training epoch 323
# Epoch: 323, MSE 0.00238572 (0.00248566), PSNR 26.22379684 (26.06891341), SSIM 0.75088930 (0.76302924)
# Finished training epoch 323
# Validate: MSE 0.00284611 (0.00245411), PSNR 25.45747757 (26.16255650), SSIM 0.70503157 (0.77023810)
# Finished validation.
# Starting training epoch 324
# Epoch: 324, MSE 0.00229985 (0.00248022), PSNR 26.38300323 (26.08251520), SSIM 0.77262104 (0.76291501)
# Finished training epoch 324
# Validate: MSE 0.00286831 (0.00245463), PSNR 25.42374229 (26.16198790), SSIM 0.70556092 (0.77023226)
# Finished validation.
# Starting training epoch 325
# Epoch: 325, MSE 0.00250936 (0.00248817), PSNR 26.00436783 (26.06485558), SSIM 0.75202191 (0.76306221)
# Finished training epoch 325
# Validate: MSE 0.00287462 (0.00245677), PSNR 25.41419601 (26.15735080), SSIM 0.70356917 (0.76864733)
# Finished validation.
# Starting training epoch 326
# Epoch: 326, MSE 0.00224529 (0.00248501), PSNR 26.48726845 (26.06930506), SSIM 0.77957886 (0.76290857)
# Finished training epoch 326
# Validate: MSE 0.00286857 (0.00245690), PSNR 25.42334366 (26.15900911), SSIM 0.70710856 (0.77213707)
# Finished validation.
# Starting training epoch 327
# Epoch: 327, MSE 0.00250591 (0.00247896), PSNR 26.01033783 (26.08040262), SSIM 0.75334972 (0.76326205)
# Finished training epoch 327
# Validate: MSE 0.00289987 (0.00245664), PSNR 25.37620544 (26.15857266), SSIM 0.70750594 (0.77084670)
# Finished validation.
# Starting training epoch 328
# Epoch: 328, MSE 0.00275046 (0.00248974), PSNR 25.60594177 (26.06482798), SSIM 0.75605041 (0.76269185)
# Finished training epoch 328
# Validate: MSE 0.00294717 (0.00245959), PSNR 25.30594635 (26.15396971), SSIM 0.70564079 (0.77162486)
# Finished validation.
# Starting training epoch 329
# Epoch: 329, MSE 0.00259999 (0.00248269), PSNR 25.85027885 (26.07542829), SSIM 0.75359190 (0.76305329)
# Finished training epoch 329
# Validate: MSE 0.00287916 (0.00245348), PSNR 25.40733528 (26.16369751), SSIM 0.70512652 (0.77033366)
# Finished validation.
# Starting training epoch 330
# Epoch: 330, MSE 0.00259396 (0.00248376), PSNR 25.86037254 (26.07494670), SSIM 0.77233446 (0.76312056)
# Finished training epoch 330
# Validate: MSE 0.00287662 (0.00245339), PSNR 25.41116905 (26.16390851), SSIM 0.70378321 (0.76953926)
# Finished validation.
# Starting training epoch 331
# Epoch: 331, MSE 0.00252385 (0.00247616), PSNR 25.97936821 (26.08551091), SSIM 0.75419313 (0.76310501)
# Finished training epoch 331
# Validate: MSE 0.00285484 (0.00245101), PSNR 25.44417381 (26.16822987), SSIM 0.70545906 (0.77095038)
# Finished validation.
# Starting training epoch 332
# Epoch: 332, MSE 0.00297140 (0.00248389), PSNR 25.27038193 (26.07371027), SSIM 0.75662839 (0.76314689)
# Finished training epoch 332
# Validate: MSE 0.00287956 (0.00245203), PSNR 25.40673828 (26.16643120), SSIM 0.70492554 (0.77051346)
# Finished validation.
# Starting training epoch 333
# Epoch: 333, MSE 0.00252157 (0.00248027), PSNR 25.98329163 (26.07909216), SSIM 0.76859510 (0.76321007)
# Finished training epoch 333
# Validate: MSE 0.00288167 (0.00245093), PSNR 25.40355682 (26.16837540), SSIM 0.70544851 (0.77048264)
# Finished validation.
# Starting training epoch 334

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
