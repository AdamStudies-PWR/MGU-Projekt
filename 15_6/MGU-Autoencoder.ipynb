# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
# Reusing TensorBoard on port 6009 (pid 22749), started 1:07:57 ago. (Use '!kill 22749' to kill it.)
#       <iframe id="tensorboard-frame-db133e3874f97cc9" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-db133e3874f97cc9");
#           const url = new URL("/", window.location);
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/dataset/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 64

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train/colour')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'test/colour' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
class Autoencoder(nn.Module):
  def __init__(self, input_size=128):
    super(Autoencoder, self).__init__()

    self.encoder = nn.Sequential(       
      nn.Conv2d(1, 16, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode),
      nn.BatchNorm2d(16),
      nn.LeakyReLU(0.1),
      nn.AvgPool2d(kernel_size=3, stride=2, padding=1),
      nn.Conv2d(16, 32, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode),
      nn.BatchNorm2d(32),
      nn.LeakyReLU(0.1),
      nn.AvgPool2d(kernel_size=3, stride=2, padding=1),
      nn.Conv2d(32, 64, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode),
      nn.BatchNorm2d(64),
      nn.LeakyReLU(0.1),
      nn.AvgPool2d(kernel_size=3, stride=2, padding=1),
    )     
        
    self.decoder = nn.Sequential(  
      nn.ConvTranspose2d(64, 32, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
      nn.BatchNorm2d(32),
      nn.LeakyReLU(0.1),
      nn.Upsample(scale_factor=scale_factor),   
      nn.ConvTranspose2d(32, 16, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
      nn.BatchNorm2d(16),
      nn.LeakyReLU(0.1),
      nn.Upsample(scale_factor=scale_factor),
      nn.ConvTranspose2d(16, 8, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
      nn.BatchNorm2d(8),
      nn.LeakyReLU(0.1),
      nn.ConvTranspose2d(8, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode),
      nn.Upsample(scale_factor=scale_factor)
    )

  def forward(self, input):

    encoder = self.encoder(input)
    # Upsample to get colors
    output = self.decoder(encoder)
    return output

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 64, 64]             160
#        BatchNorm2d-2           [-1, 16, 64, 64]              32
#          LeakyReLU-3           [-1, 16, 64, 64]               0
#          AvgPool2d-4           [-1, 16, 32, 32]               0
#             Conv2d-5           [-1, 32, 32, 32]           4,640
#        BatchNorm2d-6           [-1, 32, 32, 32]              64
#          LeakyReLU-7           [-1, 32, 32, 32]               0
#          AvgPool2d-8           [-1, 32, 16, 16]               0
#             Conv2d-9           [-1, 64, 16, 16]          18,496
#       BatchNorm2d-10           [-1, 64, 16, 16]             128
#         LeakyReLU-11           [-1, 64, 16, 16]               0
#         AvgPool2d-12             [-1, 64, 8, 8]               0
#   ConvTranspose2d-13             [-1, 32, 8, 8]          18,464
#       BatchNorm2d-14             [-1, 32, 8, 8]              64
#         LeakyReLU-15             [-1, 32, 8, 8]               0
#          Upsample-16           [-1, 32, 16, 16]               0
#   ConvTranspose2d-17           [-1, 16, 16, 16]           4,624
#       BatchNorm2d-18           [-1, 16, 16, 16]              32
#         LeakyReLU-19           [-1, 16, 16, 16]               0
#          Upsample-20           [-1, 16, 32, 32]               0
#   ConvTranspose2d-21            [-1, 8, 32, 32]           1,160
#       BatchNorm2d-22            [-1, 8, 32, 32]              16
#         LeakyReLU-23            [-1, 8, 32, 32]               0
#   ConvTranspose2d-24            [-1, 2, 32, 32]             146
#          Upsample-25            [-1, 2, 64, 64]               0
# ================================================================
# Total params: 48,026
# Trainable params: 48,026
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 3.44
# Params size (MB): 0.18
# Estimated Total Size (MB): 3.64
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00798380 (0.02834848), PSNR 20.97790337 (18.51072498), SSIM 0.62755382 (0.54083144)
# Finished training epoch 0
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 13 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 9 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 5 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 10 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00814617 (0.00813828), PSNR 20.89046478 (20.90227846), SSIM 0.63394707 (0.62463297)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00912327 (0.00836441), PSNR 20.39849472 (20.79145772), SSIM 0.64618057 (0.63137375)
# Finished training epoch 1
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.

# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00685426 (0.00688569), PSNR 21.64039230 (21.62844244), SSIM 0.67042297 (0.68862510)
# Finished training epoch 14
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 134 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 76 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00656977 (0.00664804), PSNR 21.82449913 (21.78884408), SSIM 0.70742244 (0.69482195)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00665102 (0.00685772), PSNR 21.77112007 (21.64787458), SSIM 0.69039309 (0.68921169)
# Finished training epoch 15
# Validate: MSE 0.00686973 (0.00678241), PSNR 21.63059998 (21.69989953), SSIM 0.70748633 (0.69568683)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00680219 (0.00676693), PSNR 21.67351151 (21.70645870), SSIM 0.69540912 (0.69071894)
# Finished training epoch 16
# Validate: MSE 0.00646408 (0.00654055), PSNR 21.89493370 (21.85712459), SSIM 0.70849878 (0.69613552)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00692817 (0.00676897), PSNR 21.59381485 (21.70941504), SSIM 0.69177836 (0.69098593)
# Finished training epoch 17
# Validate: MSE 0.00663943 (0.00660415), PSNR 21.77869225 (21.81465737), SSIM 0.70224446 (0.69078265)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00690902 (0.00676611), PSNR 21.60583305 (21.70757264), SSIM 0.69273323 (0.69200285)
# Finished training epoch 18
# Validate: MSE 0.00691151 (0.00702739), PSNR 21.60427094 (21.54640136), SSIM 0.70199877 (0.68992082)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00683400 (0.00670661), PSNR 21.65325165 (21.74563322), SSIM 0.70558268 (0.69366867)
# Finished training epoch 19
# Validate: MSE 0.00704986 (0.00678711), PSNR 21.51819611 (21.69568321), SSIM 0.70760143 (0.69570324)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00659488 (0.00684421), PSNR 21.80793190 (21.65768971), SSIM 0.69624138 (0.69226698)
# Finished training epoch 20
# Validate: MSE 0.00660287 (0.00649453), PSNR 21.80266953 (21.89229812), SSIM 0.71294224 (0.70168325)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00704119 (0.00661903), PSNR 21.52353477 (21.80579172), SSIM 0.69163328 (0.69517263)
# Finished training epoch 21
# Validate: MSE 0.00664410 (0.00664603), PSNR 21.77563858 (21.78807924), SSIM 0.70669973 (0.69533455)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00665039 (0.00658919), PSNR 21.77152443 (21.82009701), SSIM 0.71310371 (0.69566442)
# Finished training epoch 22
# Validate: MSE 0.00668453 (0.00680947), PSNR 21.74928856 (21.68646598), SSIM 0.71038699 (0.69755501)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00580508 (0.00659147), PSNR 22.36191368 (21.82201859), SSIM 0.68431485 (0.69624743)
# Finished training epoch 23
# Validate: MSE 0.00650081 (0.00657773), PSNR 21.87032700 (21.83703548), SSIM 0.71176225 (0.70028069)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00721352 (0.00655136), PSNR 21.41852570 (21.84867855), SSIM 0.69547689 (0.69701917)
# Finished training epoch 24
# Validate: MSE 0.00665737 (0.00661853), PSNR 21.76697540 (21.80977675), SSIM 0.71586859 (0.70469734)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00581207 (0.00655828), PSNR 22.35668945 (21.84197170), SSIM 0.70504063 (0.69721809)
# Finished training epoch 25
# Validate: MSE 0.00653015 (0.00656814), PSNR 21.85076332 (21.83654405), SSIM 0.71093559 (0.70040022)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00645071 (0.00653789), PSNR 21.90392303 (21.85573112), SSIM 0.70266318 (0.69755726)
# Finished training epoch 26
# Validate: MSE 0.00716064 (0.00687365), PSNR 21.45047951 (21.63673124), SSIM 0.69690883 (0.68786801)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00612800 (0.00654120), PSNR 22.12681198 (21.85404209), SSIM 0.70381379 (0.69805430)
# Finished training epoch 27
# Validate: MSE 0.00647787 (0.00631675), PSNR 21.88567352 (22.01203065), SSIM 0.71852952 (0.70752375)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00705677 (0.00646050), PSNR 21.51394081 (21.90461910), SSIM 0.68295634 (0.69863025)
# Finished training epoch 28
# Validate: MSE 0.00669867 (0.00676940), PSNR 21.74011612 (21.70688088), SSIM 0.70818520 (0.69677196)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00700710 (0.00648007), PSNR 21.54461670 (21.89390692), SSIM 0.69728225 (0.69869931)
# Finished training epoch 29
# Validate: MSE 0.00656554 (0.00687779), PSNR 21.82729530 (21.64007980), SSIM 0.70780343 (0.69615496)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00730825 (0.00646483), PSNR 21.36186409 (21.90324843), SSIM 0.68577057 (0.69940876)
# Finished training epoch 30
# Validate: MSE 0.00622816 (0.00634283), PSNR 22.05640411 (21.99083346), SSIM 0.71320361 (0.70086693)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00694415 (0.00643767), PSNR 21.58380890 (21.92110646), SSIM 0.68240714 (0.69950605)
# Finished training epoch 31
# Validate: MSE 0.00646684 (0.00648755), PSNR 21.89308167 (21.89401588), SSIM 0.71131551 (0.70213611)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00676511 (0.00642317), PSNR 21.69724846 (21.92875392), SSIM 0.69291550 (0.69989100)
# Finished training epoch 32
# Validate: MSE 0.00688541 (0.00701526), PSNR 21.62069893 (21.55618299), SSIM 0.70736670 (0.69618217)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00604452 (0.00638938), PSNR 22.18638229 (21.95579562), SSIM 0.69660872 (0.70030297)
# Finished training epoch 33
# Validate: MSE 0.00661358 (0.00662852), PSNR 21.79562950 (21.80492702), SSIM 0.71038610 (0.70200263)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00606185 (0.00637274), PSNR 22.17394829 (21.96804406), SSIM 0.69432896 (0.70027440)
# Finished training epoch 34
# Validate: MSE 0.00666658 (0.00683805), PSNR 21.76096916 (21.66945906), SSIM 0.71500927 (0.70384647)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00684117 (0.00634714), PSNR 21.64869308 (21.98500703), SSIM 0.68842906 (0.70060526)
# Finished training epoch 35
# Validate: MSE 0.00674997 (0.00676511), PSNR 21.70698357 (21.71112600), SSIM 0.71162909 (0.70078231)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00680633 (0.00634270), PSNR 21.67086601 (21.98842696), SSIM 0.70568854 (0.70121628)
# Finished training epoch 36
# Validate: MSE 0.00678916 (0.00685236), PSNR 21.68183899 (21.65817497), SSIM 0.70432574 (0.69512383)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00622900 (0.00630223), PSNR 22.05581665 (22.01585740), SSIM 0.70141971 (0.70142314)
# Finished training epoch 37
# Validate: MSE 0.00650377 (0.00631888), PSNR 21.86834526 (22.01010399), SSIM 0.71313894 (0.70329928)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00647797 (0.00630061), PSNR 21.88561249 (22.01380940), SSIM 0.68551368 (0.70140798)
# Finished training epoch 38
# Validate: MSE 0.00722721 (0.00721909), PSNR 21.41029167 (21.42613694), SSIM 0.71647996 (0.70562486)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00587331 (0.00631068), PSNR 22.31117058 (22.00925891), SSIM 0.70752221 (0.70167728)
# Finished training epoch 39
# Validate: MSE 0.00623668 (0.00628299), PSNR 22.05046654 (22.03700356), SSIM 0.71447116 (0.70499266)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.

# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00590503 (0.00588194), PSNR 22.28777885 (22.31830478), SSIM 0.71768117 (0.70665898)
# Finished training epoch 65
# Validate: MSE 0.00589546 (0.00641016), PSNR 22.29481888 (21.94164033), SSIM 0.71872401 (0.70382780)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00580828 (0.00586984), PSNR 22.35951996 (22.32221609), SSIM 0.71334517 (0.70712185)
# Finished training epoch 66
# Validate: MSE 0.00576710 (0.00570295), PSNR 22.39042854 (22.44695264), SSIM 0.71595573 (0.70677958)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00587161 (0.00588314), PSNR 22.31242371 (22.31462448), SSIM 0.71368343 (0.70704203)
# Finished training epoch 67
# Validate: MSE 0.00594220 (0.00620598), PSNR 22.26052284 (22.08734983), SSIM 0.71829695 (0.70671032)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00638607 (0.00586068), PSNR 21.94766617 (22.33216379), SSIM 0.70842499 (0.70702520)
# Finished training epoch 68
# Validate: MSE 0.00646300 (0.00643475), PSNR 21.89565849 (21.92511112), SSIM 0.70611310 (0.69838374)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00527757 (0.00586532), PSNR 22.77566338 (22.32765290), SSIM 0.71403468 (0.70730527)
# Finished training epoch 69
# Validate: MSE 0.00750253 (0.00720229), PSNR 21.24792290 (21.43632158), SSIM 0.70436960 (0.69710292)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00581880 (0.00579219), PSNR 22.35166740 (22.38292175), SSIM 0.69487447 (0.70777097)
# Finished training epoch 70
# Validate: MSE 0.00621667 (0.00618708), PSNR 22.06442070 (22.09788104), SSIM 0.72529787 (0.71359181)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00600527 (0.00579738), PSNR 22.21467209 (22.37670374), SSIM 0.71974587 (0.70746253)
# Finished training epoch 71
# Validate: MSE 0.00600250 (0.00590699), PSNR 22.21667480 (22.29837693), SSIM 0.72000927 (0.71145005)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00629805 (0.00576839), PSNR 22.00794029 (22.39994211), SSIM 0.69950551 (0.70790489)
# Finished training epoch 72
# Validate: MSE 0.00584414 (0.00605491), PSNR 22.33279228 (22.19533486), SSIM 0.72502506 (0.71305227)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00613067 (0.00578732), PSNR 22.12491798 (22.38709496), SSIM 0.70344245 (0.70818852)
# Finished training epoch 73
# Validate: MSE 0.00663258 (0.00632781), PSNR 21.78317261 (21.99963724), SSIM 0.71476340 (0.70399060)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00649229 (0.00574458), PSNR 21.87601662 (22.41693079), SSIM 0.69383460 (0.70849533)
# Finished training epoch 74
# Validate: MSE 0.00769660 (0.00766595), PSNR 21.13700676 (21.15939352), SSIM 0.69110388 (0.68201203)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00554331 (0.00573706), PSNR 22.56230545 (22.42437024), SSIM 0.72104353 (0.70881104)
# Finished training epoch 75
# Validate: MSE 0.00607607 (0.00583590), PSNR 22.16376877 (22.34952909), SSIM 0.71673501 (0.71001430)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00535772 (0.00573830), PSNR 22.71019936 (22.41942059), SSIM 0.71651328 (0.70889192)
# Finished training epoch 76
# Validate: MSE 0.00619832 (0.00631054), PSNR 22.07725906 (22.01256720), SSIM 0.71691620 (0.70679179)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00507956 (0.00572846), PSNR 22.94173622 (22.42887700), SSIM 0.71328014 (0.70906885)
# Finished training epoch 77
# Validate: MSE 0.00657398 (0.00643884), PSNR 21.82171440 (21.91568524), SSIM 0.71643662 (0.70806732)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.

# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00615268 (0.00531972), PSNR 22.10935593 (22.75047598), SSIM 0.70253253 (0.71273782)
# Finished training epoch 117
# Validate: MSE 0.00574578 (0.00590303), PSNR 22.40650940 (22.30520923), SSIM 0.72327274 (0.71205582)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00506742 (0.00528999), PSNR 22.95213127 (22.77179005), SSIM 0.71870458 (0.71280084)
# Finished training epoch 118
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 15 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00612889 (0.00607549), PSNR 22.12617874 (22.17293721), SSIM 0.71768391 (0.70785041)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00506423 (0.00529894), PSNR 22.95486450 (22.76774696), SSIM 0.71242589 (0.71325597)
# Finished training epoch 119
# Validate: MSE 0.00553682 (0.00549218), PSNR 22.56739616 (22.61658496), SSIM 0.72985411 (0.72011301)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00505546 (0.00529475), PSNR 22.96239281 (22.77131573), SSIM 0.71661127 (0.71283018)
# Finished training epoch 120
# Validate: MSE 0.00580177 (0.00577255), PSNR 22.36439323 (22.39733431), SSIM 0.71862072 (0.70691874)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00485288 (0.00527766), PSNR 23.13999939 (22.78618993), SSIM 0.71386212 (0.71335656)
# Finished training epoch 121
# Validate: MSE 0.00595315 (0.00575163), PSNR 22.25253296 (22.41206195), SSIM 0.72318310 (0.71428388)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00567703 (0.00524695), PSNR 22.45878601 (22.81287075), SSIM 0.69687402 (0.71320699)
# Finished training epoch 122
# Validate: MSE 0.00587044 (0.00554226), PSNR 22.31329346 (22.57158060), SSIM 0.71689850 (0.71029779)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00474346 (0.00520799), PSNR 23.23904800 (22.84706287), SSIM 0.71937960 (0.71313158)
# Finished training epoch 123
# Validate: MSE 0.00570906 (0.00553407), PSNR 22.43435287 (22.57965577), SSIM 0.72478777 (0.71518804)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00516656 (0.00529139), PSNR 22.86798286 (22.77574141), SSIM 0.73544919 (0.71291747)
# Finished training epoch 124
# Validate: MSE 0.00572422 (0.00575150), PSNR 22.42283630 (22.41916368), SSIM 0.72531295 (0.71156075)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00510784 (0.00522561), PSNR 22.91762924 (22.82864391), SSIM 0.71236509 (0.71362533)
# Finished training epoch 125
# Validate: MSE 0.00619085 (0.00588258), PSNR 22.08249664 (22.31035886), SSIM 0.71026647 (0.70333974)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00461391 (0.00524040), PSNR 23.35931015 (22.81661457), SSIM 0.72383767 (0.71321749)
# Finished training epoch 126
# Validate: MSE 0.00563106 (0.00551820), PSNR 22.49410057 (22.59218286), SSIM 0.72802299 (0.71859708)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00532060 (0.00520770), PSNR 22.74039078 (22.84220914), SSIM 0.71063626 (0.71350829)
# Finished training epoch 127
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 57 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00605411 (0.00590989), PSNR 22.17949486 (22.30588836), SSIM 0.72071481 (0.71233436)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00494395 (0.00528413), PSNR 23.05925560 (22.78043746), SSIM 0.73218852 (0.71288809)
# Finished training epoch 128
# Validate: MSE 0.00553781 (0.00562147), PSNR 22.56661987 (22.51513093), SSIM 0.72480100 (0.71124997)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00573439 (0.00521994), PSNR 22.41513062 (22.83233949), SSIM 0.70741427 (0.71357988)
# Finished training epoch 129
# Validate: MSE 0.00597614 (0.00602167), PSNR 22.23579025 (22.21478450), SSIM 0.70459980 (0.69817243)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00600562 (0.00519222), PSNR 22.21441841 (22.85816413), SSIM 0.69065100 (0.71317197)
# Finished training epoch 130
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 42 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00655714 (0.00632710), PSNR 21.83285141 (22.00241915), SSIM 0.71107703 (0.70344919)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00504999 (0.00517671), PSNR 22.96709633 (22.87083787), SSIM 0.71106124 (0.71350349)
# Finished training epoch 131
# Validate: MSE 0.00661154 (0.00629068), PSNR 21.79697418 (22.02023183), SSIM 0.70769364 (0.70124823)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00524041 (0.00520935), PSNR 22.80634880 (22.84428974), SSIM 0.71705872 (0.71325128)
# Finished training epoch 132
# Validate: MSE 0.00567947 (0.00579883), PSNR 22.45692444 (22.37596326), SSIM 0.71883357 (0.71181237)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00558606 (0.00518244), PSNR 22.52894592 (22.86690415), SSIM 0.70925742 (0.71346438)
# Finished training epoch 133
# Validate: MSE 0.00565024 (0.00575708), PSNR 22.47933197 (22.40625775), SSIM 0.72452807 (0.71403287)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00516863 (0.00518631), PSNR 22.86624908 (22.86228508), SSIM 0.72724670 (0.71324516)
# Finished training epoch 134
# Validate: MSE 0.00566696 (0.00562506), PSNR 22.46649742 (22.51658320), SSIM 0.72900367 (0.71913946)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00474894 (0.00517300), PSNR 23.23403740 (22.87185960), SSIM 0.72700030 (0.71327237)
# Finished training epoch 135
# Validate: MSE 0.00566587 (0.00543044), PSNR 22.46733665 (22.66301238), SSIM 0.72073382 (0.71261490)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00452848 (0.00512183), PSNR 23.44047546 (22.91551792), SSIM 0.72536212 (0.71308773)
# Finished training epoch 136
# Validate: MSE 0.00601018 (0.00556604), PSNR 22.21112442 (22.55562276), SSIM 0.72550511 (0.71564764)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00520732 (0.00518286), PSNR 22.83385849 (22.86497896), SSIM 0.72113746 (0.71319688)
# Finished training epoch 137
# Validate: MSE 0.00590598 (0.00614989), PSNR 22.28708076 (22.12801874), SSIM 0.71750861 (0.70565021)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00479849 (0.00512984), PSNR 23.18895340 (22.90833373), SSIM 0.72949463 (0.71338043)
# Finished training epoch 138
# Validate: MSE 0.00564414 (0.00571153), PSNR 22.48402023 (22.43989047), SSIM 0.72039616 (0.71089429)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00521010 (0.00512543), PSNR 22.83154297 (22.91447112), SSIM 0.71472383 (0.71320695)
# Finished training epoch 139
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 36 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00534135 (0.00548138), PSNR 22.72349167 (22.62083409), SSIM 0.72351646 (0.71186043)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00451643 (0.00510782), PSNR 23.45204353 (22.93022238), SSIM 0.70903462 (0.71410943)
# Finished training epoch 140
# Validate: MSE 0.00627203 (0.00593871), PSNR 22.02592087 (22.26805380), SSIM 0.71682674 (0.70855086)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00529484 (0.00514105), PSNR 22.76147270 (22.90028074), SSIM 0.71326518 (0.71313012)
# Finished training epoch 141
# Validate: MSE 0.00551110 (0.00540224), PSNR 22.58761215 (22.68600452), SSIM 0.72138566 (0.71121370)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00585177 (0.00506340), PSNR 22.32712746 (22.96524891), SSIM 0.70608586 (0.71368195)
# Finished training epoch 142
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 7 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00584672 (0.00596937), PSNR 22.33087730 (22.24628471), SSIM 0.71380574 (0.70528518)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00604661 (0.00515800), PSNR 22.18488121 (22.88623533), SSIM 0.69301337 (0.71323240)
# Finished training epoch 143
# Validate: MSE 0.00603710 (0.00589168), PSNR 22.19171715 (22.31156092), SSIM 0.71806723 (0.70842945)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00547448 (0.00511286), PSNR 22.61656952 (22.92356308), SSIM 0.72040248 (0.71327326)
# Finished training epoch 144
# Validate: MSE 0.00578987 (0.00556045), PSNR 22.37330818 (22.55822183), SSIM 0.72460747 (0.71459599)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00568978 (0.00510733), PSNR 22.44904137 (22.92837284), SSIM 0.71389711 (0.71338301)
# Finished training epoch 145
# Validate: MSE 0.00558174 (0.00565497), PSNR 22.53229904 (22.48466121), SSIM 0.72256386 (0.71107315)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00548094 (0.00509841), PSNR 22.61145020 (22.93913978), SSIM 0.70999181 (0.71349668)
# Finished training epoch 146
# Validate: MSE 0.00558952 (0.00561792), PSNR 22.52625465 (22.51066575), SSIM 0.70838827 (0.70142583)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00517009 (0.00508226), PSNR 22.86502075 (22.94899370), SSIM 0.70926327 (0.71334106)
# Finished training epoch 147
# Validate: MSE 0.00601801 (0.00586534), PSNR 22.20547104 (22.32880355), SSIM 0.72302765 (0.71465656)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00524493 (0.00509012), PSNR 22.80260277 (22.94285514), SSIM 0.70688325 (0.71372112)
# Finished training epoch 148
# Validate: MSE 0.00629445 (0.00633444), PSNR 22.01042366 (22.00556842), SSIM 0.71060002 (0.69887065)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00483711 (0.00505311), PSNR 23.15413857 (22.97369858), SSIM 0.72999531 (0.71349251)
# Finished training epoch 149
# Validate: MSE 0.00561631 (0.00548681), PSNR 22.50548553 (22.61873865), SSIM 0.72325450 (0.71348289)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00526722 (0.00506500), PSNR 22.78418541 (22.96241568), SSIM 0.70587194 (0.71343485)
# Finished training epoch 150
# Validate: MSE 0.00529402 (0.00528680), PSNR 22.76214027 (22.77933954), SSIM 0.72968978 (0.71929238)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00479206 (0.00503859), PSNR 23.19477463 (22.98572982), SSIM 0.71451950 (0.71362928)
# Finished training epoch 151
# Validate: MSE 0.00529951 (0.00524321), PSNR 22.75764275 (22.81328293), SSIM 0.72531295 (0.71694780)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00493214 (0.00504317), PSNR 23.06964874 (22.98278557), SSIM 0.70862871 (0.71360739)
# Finished training epoch 152
# Validate: MSE 0.00548401 (0.00560172), PSNR 22.60901451 (22.52596748), SSIM 0.71831733 (0.70717381)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00498787 (0.00503867), PSNR 23.02084351 (22.98593865), SSIM 0.72318470 (0.71366820)
# Finished training epoch 153
# Validate: MSE 0.00547683 (0.00543134), PSNR 22.61470795 (22.66257344), SSIM 0.72440755 (0.71343704)
# Finished validation.
# ...
# Finished training epoch 186
# Validate: MSE 0.00577209 (0.00564326), PSNR 22.38666916 (22.49769090), SSIM 0.71974617 (0.71202115)
# Finished validation.
# Starting training epoch 187
# Epoch: 187, MSE 0.00410083 (0.00487885), PSNR 23.87128258 (23.12673379), SSIM 0.73099571 (0.71393811)
# Finished training epoch 187
# Validate: MSE 0.00576545 (0.00579700), PSNR 22.39166832 (22.38441743), SSIM 0.72053039 (0.71086182)
# Finished validation.
# Starting training epoch 188
# Epoch: 188, MSE 0.00628558 (0.00483194), PSNR 22.01654434 (23.17212415), SSIM 0.70119309 (0.71466452)
# Finished training epoch 188
# Validate: MSE 0.00570187 (0.00552311), PSNR 22.43982506 (22.58762506), SSIM 0.71858335 (0.70922443)
# Finished validation.
# Starting training epoch 189
# Epoch: 189, MSE 0.00514359 (0.00487387), PSNR 22.88733673 (23.13006258), SSIM 0.70401746 (0.71403905)
# Finished training epoch 189
# Validate: MSE 0.00526833 (0.00513628), PSNR 22.78326607 (22.90192012), SSIM 0.72112817 (0.71131105)
# Finished validation.
# Starting training epoch 190
# Epoch: 190, MSE 0.00507572 (0.00485318), PSNR 22.94502068 (23.15157807), SSIM 0.71488911 (0.71407695)
# Finished training epoch 190
# Validate: MSE 0.00529684 (0.00525742), PSNR 22.75982666 (22.79924670), SSIM 0.72262639 (0.71231186)
# Finished validation.
# Starting training epoch 191
# Epoch: 191, MSE 0.00415897 (0.00485077), PSNR 23.81014061 (23.15269732), SSIM 0.71937758 (0.71412975)
# Finished training epoch 191
# Validate: MSE 0.00524384 (0.00568258), PSNR 22.80350685 (22.46491507), SSIM 0.72397637 (0.71157221)
# Finished validation.
# Starting training epoch 192
# Epoch: 192, MSE 0.00487156 (0.00487019), PSNR 23.12331581 (23.13214145), SSIM 0.72639549 (0.71422089)
# Finished training epoch 192
# Validate: MSE 0.00550911 (0.00540079), PSNR 22.58918762 (22.68681318), SSIM 0.72214550 (0.71031267)
# Finished validation.
# Starting training epoch 193
# Epoch: 193, MSE 0.00528386 (0.00480187), PSNR 22.77048874 (23.19714710), SSIM 0.71776897 (0.71418531)
# Finished training epoch 193
# Validate: MSE 0.00534826 (0.00531645), PSNR 22.71787262 (22.76154054), SSIM 0.72398537 (0.71429490)
# Finished validation.
# Starting training epoch 194
# Epoch: 194, MSE 0.00509688 (0.00483546), PSNR 22.92695427 (23.16587191), SSIM 0.70527786 (0.71449036)
# Finished training epoch 194
# Validate: MSE 0.00589457 (0.00599320), PSNR 22.29548073 (22.23817959), SSIM 0.71365994 (0.70356171)
# Finished validation.
# Starting training epoch 195
# Epoch: 195, MSE 0.00431574 (0.00481357), PSNR 23.64944458 (23.18767012), SSIM 0.71847600 (0.71436647)
# Finished training epoch 195
# Validate: MSE 0.00637120 (0.00598877), PSNR 21.95778847 (22.23614829), SSIM 0.70370078 (0.69815720)
# Finished validation.
# Starting training epoch 196
# Epoch: 196, MSE 0.00527717 (0.00482809), PSNR 22.77598953 (23.17101872), SSIM 0.71145350 (0.71385963)
# Finished training epoch 196
# Validate: MSE 0.00573754 (0.00552970), PSNR 22.41274071 (22.57903969), SSIM 0.71908176 (0.70926877)
# Finished validation.
# Starting training epoch 197
# Epoch: 197, MSE 0.00472345 (0.00483513), PSNR 23.25740051 (23.16570904), SSIM 0.72820944 (0.71404884)
# Finished training epoch 197
# Validate: MSE 0.00561418 (0.00536184), PSNR 22.50713539 (22.71536319), SSIM 0.71906102 (0.70951962)
# Finished validation.
# Starting training epoch 198
# Epoch: 198, MSE 0.00531053 (0.00479412), PSNR 22.74862099 (23.20384189), SSIM 0.70456201 (0.71446757)
# Finished training epoch 198
# Validate: MSE 0.00528089 (0.00530115), PSNR 22.77292442 (22.76571474), SSIM 0.72007066 (0.71055777)
# Finished validation.
# Starting training epoch 199
# Epoch: 199, MSE 0.00446616 (0.00481229), PSNR 23.50065804 (23.18547060), SSIM 0.71160561 (0.71419498)
# Finished training epoch 199
# Validate: MSE 0.00537547 (0.00532750), PSNR 22.69583321 (22.74233191), SSIM 0.72092235 (0.71019799)
# Finished validation.
# Starting training epoch 200
# Epoch: 200, MSE 0.00466537 (0.00477180), PSNR 23.31114006 (23.22224622), SSIM 0.71420538 (0.71444099)
# Finished training epoch 200
# Validate: MSE 0.00544483 (0.00525437), PSNR 22.64015770 (22.80733548), SSIM 0.71985114 (0.71013374)
# Finished validation.
# Starting training epoch 201
# Epoch: 201, MSE 0.00516194 (0.00479300), PSNR 22.87187386 (23.20357956), SSIM 0.71598780 (0.71396364)
# Finished training epoch 201
# Validate: MSE 0.00551250 (0.00569050), PSNR 22.58651352 (22.46352150), SSIM 0.72313911 (0.71130002)
# Finished validation.
# Starting training epoch 202
# Epoch: 202, MSE 0.00447501 (0.00480598), PSNR 23.49206352 (23.19195328), SSIM 0.72400671 (0.71415273)
# Finished training epoch 202
# Validate: MSE 0.00550434 (0.00534872), PSNR 22.59294510 (22.72996569), SSIM 0.71785444 (0.70614757)
# Finished validation.
# Starting training epoch 203
# Epoch: 203, MSE 0.00512069 (0.00479775), PSNR 22.90671158 (23.20097594), SSIM 0.70151168 (0.71398755)
# Finished training epoch 203
# Validate: MSE 0.00589543 (0.00591761), PSNR 22.29484558 (22.28805711), SSIM 0.71058875 (0.70086898)
# Finished validation.
# Starting training epoch 204
# Epoch: 204, MSE 0.00476889 (0.00473147), PSNR 23.21582413 (23.25853438), SSIM 0.72026277 (0.71436305)
# Finished training epoch 204
# Validate: MSE 0.00523235 (0.00517786), PSNR 22.81303215 (22.86679595), SSIM 0.72417426 (0.71285952)
# Finished validation.
# Starting training epoch 205
# Epoch: 205, MSE 0.00479307 (0.00476853), PSNR 23.19385910 (23.22645904), SSIM 0.71207726 (0.71417008)
# Finished training epoch 205
# Validate: MSE 0.00555007 (0.00533051), PSNR 22.55701637 (22.74427905), SSIM 0.72030020 (0.71202023)
# Finished validation.
# Starting training epoch 206
# Epoch: 206, MSE 0.00445777 (0.00475736), PSNR 23.50882149 (23.23543941), SSIM 0.70175272 (0.71440581)
# Finished training epoch 206
# Validate: MSE 0.00563629 (0.00562525), PSNR 22.49006653 (22.50140983), SSIM 0.71481895 (0.70459544)
# Finished validation.
# Starting training epoch 207
# Epoch: 207, MSE 0.00466926 (0.00477933), PSNR 23.30751610 (23.21693764), SSIM 0.72308892 (0.71404496)
# Finished training epoch 207
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 98 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00565497 (0.00562912), PSNR 22.47569466 (22.50533714), SSIM 0.71993065 (0.70831514)
# Finished validation.
# Starting training epoch 208
# Epoch: 208, MSE 0.00516202 (0.00481305), PSNR 22.87180328 (23.19028195), SSIM 0.70974356 (0.71394235)
# Finished training epoch 208
# Validate: MSE 0.00592966 (0.00589407), PSNR 22.26969910 (22.31187290), SSIM 0.71550483 (0.70658748)
# Finished validation.
# Starting training epoch 209
# Epoch: 209, MSE 0.00447156 (0.00475862), PSNR 23.49541092 (23.23407139), SSIM 0.72609085 (0.71411248)
# Finished training epoch 209
# Validate: MSE 0.00534430 (0.00523468), PSNR 22.72109032 (22.82273467), SSIM 0.71975648 (0.71029715)
# Finished validation.
# Starting training epoch 210
# Epoch: 210, MSE 0.00438355 (0.00477599), PSNR 23.58173752 (23.21929383), SSIM 0.71671814 (0.71423564)
# Finished training epoch 210
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 65 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00701593 (0.00653145), PSNR 21.53914452 (21.86178587), SSIM 0.69648242 (0.68993047)
# Finished validation.
# Starting training epoch 211
# Epoch: 211, MSE 0.00462247 (0.00476862), PSNR 23.35125542 (23.22697816), SSIM 0.73216617 (0.71417022)
# Finished training epoch 211
# Validate: MSE 0.00520974 (0.00543351), PSNR 22.83183479 (22.66260555), SSIM 0.72828287 (0.71597534)
# Finished validation.
# Starting training epoch 212
# Epoch: 212, MSE 0.00490119 (0.00474650), PSNR 23.09698868 (23.24612335), SSIM 0.73035586 (0.71461359)
# Finished training epoch 212
# Validate: MSE 0.00527669 (0.00540125), PSNR 22.77638054 (22.68302219), SSIM 0.71804452 (0.70916855)
# Finished validation.
# Starting training epoch 213
# Epoch: 213, MSE 0.00466858 (0.00472009), PSNR 23.30815315 (23.27186627), SSIM 0.71072692 (0.71434838)
# Finished training epoch 213
# Validate: MSE 0.00543653 (0.00526083), PSNR 22.64678192 (22.79852825), SSIM 0.71895242 (0.70889992)
# Finished validation.
# Starting training epoch 214
# Epoch: 214, MSE 0.00495092 (0.00472040), PSNR 23.05314064 (23.27091483), SSIM 0.71383828 (0.71382119)
# Finished training epoch 214
# Validate: MSE 0.00543763 (0.00546485), PSNR 22.64590263 (22.63004941), SSIM 0.71985012 (0.70907069)
# Finished validation.
# Starting training epoch 215
# Epoch: 215, MSE 0.00412474 (0.00472635), PSNR 23.84603882 (23.26631519), SSIM 0.71691841 (0.71448797)
# Finished training epoch 215
# Validate: MSE 0.00555126 (0.00536300), PSNR 22.55608368 (22.71442891), SSIM 0.72269434 (0.71051355)
# Finished validation.
# Starting training epoch 216
# Epoch: 216, MSE 0.00497417 (0.00473468), PSNR 23.03279114 (23.25816598), SSIM 0.72431511 (0.71397566)
# Finished training epoch 216
# Validate: MSE 0.00510240 (0.00522119), PSNR 22.92225456 (22.83013965), SSIM 0.72578323 (0.71472542)
# Finished validation.
# Starting training epoch 217
# Epoch: 217, MSE 0.00452731 (0.00475691), PSNR 23.44160080 (23.23731065), SSIM 0.73361099 (0.71408763)
# Finished training epoch 217
# Validate: MSE 0.00584145 (0.00552945), PSNR 22.33479309 (22.58138763), SSIM 0.71842539 (0.71002403)
# Finished validation.
# Starting training epoch 218
# Epoch: 218, MSE 0.00469983 (0.00476330), PSNR 23.27917480 (23.22902075), SSIM 0.72394598 (0.71384703)
# Finished training epoch 218
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 85 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00559314 (0.00529723), PSNR 22.52344131 (22.77128355), SSIM 0.71729356 (0.70799379)
# Finished validation.
# Starting training epoch 219
# Epoch: 219, MSE 0.00528982 (0.00473289), PSNR 22.76559258 (23.26004026), SSIM 0.71743798 (0.71412821)
# Finished training epoch 219
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 54 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00564162 (0.00543538), PSNR 22.48595810 (22.66040127), SSIM 0.71487141 (0.70637450)
# Finished validation.
# Starting training epoch 220
# Epoch: 220, MSE 0.00482352 (0.00472918), PSNR 23.16635895 (23.26430561), SSIM 0.71693975 (0.71430153)
# Finished training epoch 220
# Validate: MSE 0.00521626 (0.00527854), PSNR 22.82640648 (22.78202461), SSIM 0.72321945 (0.71096930)
# Finished validation.
# Starting training epoch 221
# Epoch: 221, MSE 0.00460095 (0.00470299), PSNR 23.37152481 (23.28595294), SSIM 0.71073121 (0.71467368)
# Finished training epoch 221
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 29 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00515165 (0.00527450), PSNR 22.88053322 (22.78768304), SSIM 0.72460854 (0.71214341)
# Finished validation.
# Starting training epoch 222
# Epoch: 222, MSE 0.00500656 (0.00469352), PSNR 23.00460625 (23.29215326), SSIM 0.70926422 (0.71450509)
# Finished training epoch 222
# Validate: MSE 0.00592639 (0.00561903), PSNR 22.27210045 (22.50910813), SSIM 0.71341848 (0.70359042)
# Finished validation.
# Starting training epoch 223
# Epoch: 223, MSE 0.00493817 (0.00469201), PSNR 23.06433678 (23.29811936), SSIM 0.70959127 (0.71418314)
# Finished training epoch 223
# Validate: MSE 0.00513268 (0.00514066), PSNR 22.89655685 (22.90321260), SSIM 0.72644967 (0.71619999)
# Finished validation.
# Starting training epoch 224
# Epoch: 224, MSE 0.00500126 (0.00474354), PSNR 23.00920105 (23.24994770), SSIM 0.70997345 (0.71432640)
# Finished training epoch 224
# Validate: MSE 0.00545459 (0.00528022), PSNR 22.63237381 (22.78241684), SSIM 0.72727877 (0.71852507)
# Finished validation.
# Starting training epoch 225
# Epoch: 225, MSE 0.00474195 (0.00469627), PSNR 23.24042892 (23.29361343), SSIM 0.71508217 (0.71453773)
# Finished training epoch 225
# Validate: MSE 0.00566756 (0.00537716), PSNR 22.46603394 (22.70430154), SSIM 0.71242177 (0.70403783)
# Finished validation.
# Starting training epoch 226
# Epoch: 226, MSE 0.00413369 (0.00468987), PSNR 23.83662415 (23.30160168), SSIM 0.73710757 (0.71450511)
# Finished training epoch 226
# Validate: MSE 0.00544038 (0.00555518), PSNR 22.64371109 (22.56126545), SSIM 0.72179019 (0.71031168)
# Finished validation.
# Starting training epoch 227
# Epoch: 227, MSE 0.00477100 (0.00469624), PSNR 23.21390152 (23.29124647), SSIM 0.71858788 (0.71454265)
# Finished training epoch 227
# Validate: MSE 0.00535418 (0.00543074), PSNR 22.71306801 (22.66368367), SSIM 0.72084063 (0.70926883)
# Finished validation.
# Starting training epoch 228
# Epoch: 228, MSE 0.00485143 (0.00471774), PSNR 23.14130020 (23.27196935), SSIM 0.71389085 (0.71427784)
# Finished training epoch 228
# Validate: MSE 0.00535784 (0.00524285), PSNR 22.71010208 (22.81626716), SSIM 0.72697014 (0.71607028)
# Finished validation.
# Starting training epoch 229
# Epoch: 229, MSE 0.00513292 (0.00471120), PSNR 22.89635468 (23.27789094), SSIM 0.69715524 (0.71426426)
# Finished training epoch 229
# Validate: MSE 0.00615173 (0.00596095), PSNR 22.11002541 (22.25716802), SSIM 0.70989805 (0.70066253)
# Finished validation.
# Starting training epoch 230
# Epoch: 230, MSE 0.00459077 (0.00470175), PSNR 23.38114548 (23.28648543), SSIM 0.70237678 (0.71422216)
# Finished training epoch 230
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 27 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00574282 (0.00561931), PSNR 22.40875053 (22.51677381), SSIM 0.71380949 (0.70328516)
# Finished validation.
# Starting training epoch 231
# Epoch: 231, MSE 0.00484009 (0.00470749), PSNR 23.15146255 (23.28208664), SSIM 0.70377833 (0.71420151)
# Finished training epoch 231
# Validate: MSE 0.00544581 (0.00547029), PSNR 22.63937759 (22.62887784), SSIM 0.72485352 (0.71264658)
# Finished validation.
# Starting training epoch 232
# Epoch: 232, MSE 0.00454532 (0.00466418), PSNR 23.42435074 (23.31981378), SSIM 0.71274418 (0.71443824)
# Finished training epoch 232
# Validate: MSE 0.00546440 (0.00525015), PSNR 22.62457848 (22.80958932), SSIM 0.72137433 (0.71152633)
# Finished validation.
# Starting training epoch 233
# Epoch: 233, MSE 0.00419828 (0.00465622), PSNR 23.76927948 (23.33180367), SSIM 0.73247379 (0.71452200)
# Finished training epoch 233
# Validate: MSE 0.00606890 (0.00605407), PSNR 22.16890335 (22.18377717), SSIM 0.71036094 (0.70120345)
# Finished validation.
# Starting training epoch 234
# Epoch: 234, MSE 0.00423259 (0.00466827), PSNR 23.73393631 (23.31997759), SSIM 0.71827376 (0.71434708)
# Finished training epoch 234
# Validate: MSE 0.00569625 (0.00560763), PSNR 22.44410515 (22.51663680), SSIM 0.71733767 (0.70695063)
# Finished validation.
# Starting training epoch 235
# Epoch: 235, MSE 0.00413750 (0.00467931), PSNR 23.83261299 (23.30783849), SSIM 0.73464555 (0.71416746)
# Finished training epoch 235
# Validate: MSE 0.00527075 (0.00528221), PSNR 22.78127670 (22.78507325), SSIM 0.71848977 (0.70828562)
# Finished validation.
# Starting training epoch 236
# Epoch: 236, MSE 0.00512078 (0.00464492), PSNR 22.90663528 (23.34220802), SSIM 0.70612562 (0.71436228)
# Finished training epoch 236
# Validate: MSE 0.00526573 (0.00532933), PSNR 22.78541374 (22.73708925), SSIM 0.71671110 (0.70648384)
# Finished validation.
# Starting training epoch 237
# Epoch: 237, MSE 0.00425772 (0.00466973), PSNR 23.70822334 (23.31566055), SSIM 0.72162503 (0.71455413)
# Finished training epoch 237
# Validate: MSE 0.00531060 (0.00518557), PSNR 22.74856186 (22.86052833), SSIM 0.71903521 (0.71027966)
# Finished validation.
# Starting training epoch 238
# Epoch: 238, MSE 0.00519794 (0.00465865), PSNR 22.84168434 (23.32911008), SSIM 0.68968350 (0.71428747)
# Finished training epoch 238
# Validate: MSE 0.00545366 (0.00532818), PSNR 22.63312149 (22.74657810), SSIM 0.72024268 (0.70931601)
# Finished validation.
# Starting training epoch 239
# Epoch: 239, MSE 0.00467082 (0.00465106), PSNR 23.30606461 (23.33329365), SSIM 0.72559839 (0.71473503)
# Finished training epoch 239
# Validate: MSE 0.00552353 (0.00528050), PSNR 22.57783127 (22.78507738), SSIM 0.71978343 (0.70994222)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00552353 (0.00528050), PSNR 22.57783127 (22.78507738), SSIM 0.71978343 (0.70994222)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
