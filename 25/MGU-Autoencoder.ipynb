# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-d204c71ccbc09621" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d204c71ccbc09621");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
                transforms.RandomVerticalFlip(),  
                transforms.RandomRotation(10),
                transforms.ColorJitter(brightness=0.05, contrast=0.05, saturation=0.05, hue=0.05)
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .25

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        self.batchnorm5 = nn.BatchNorm2d(2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = y = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x + y)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm5(self.convtrans3(x + input)), negative_slope=0.1)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 32, 32]           2,306
#       BatchNorm2d-10            [-1, 2, 32, 32]               4
# ================================================================
# Total params: 2,662,278
# Trainable params: 2,662,278
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.78
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.94
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[1].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 23.02385712 (8.89927898), PSNR -13.62177944 (-8.12911477), SSIM 0.00098736 (0.03303412)
# Finished training epoch 0
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1024 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1013 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1000 pixels
#   return func(*args, **kwargs)
# Validate: MSE 32.01262283 (20.82948008), PSNR -15.05321217 (-12.85713765), SSIM -0.00284308 (0.00369839)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 73.78147888 (47.21137739), PSNR -18.67947388 (-16.51441091), SSIM -0.00047635 (0.00007291)
# Finished training epoch 1
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1022 pixels
#   return func(*args, **kwargs)
# Validate: MSE 92.65051270 (72.53884810), PSNR -19.66847610 (-18.49876414), SSIM -0.00104874 (-0.00045369)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 137.39656067 (104.61431704), PSNR -21.37975883 (-20.12775042), SSIM -0.00019352 (-0.00038564)
# Finished training epoch 2
# Validate: MSE 156.00096130 (155.56190544), PSNR -21.93127251 (-21.87692229), SSIM -0.00038169 (-0.00024906)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 212.82283020 (174.14957977), PSNR -23.28018188 (-22.37492743), SSIM -0.00029718 (-0.00026355)
# Finished training epoch 3
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1019 pixels
#   return func(*args, **kwargs)
# Validate: MSE 178.52282715 (213.59309883), PSNR -22.51693726 (-23.23048958), SSIM -0.00045007 (-0.00026167)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 300.72299194 (255.83690397), PSNR -24.78166580 (-24.05815869), SSIM -0.00019486 (-0.00021512)
# Finished training epoch 4
# Validate: MSE 231.16839600 (271.76889014), PSNR -23.63928223 (-24.27796458), SSIM -0.00031805 (-0.00021835)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 402.25018311 (350.38611107), PSNR -26.04496002 (-25.43031958), SSIM -0.00013904 (-0.00017777)
# Finished training epoch 5
# Validate: MSE 333.26501465 (413.32687051), PSNR -25.22789574 (-26.09697203), SSIM -0.00028607 (-0.00016432)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 517.80297852 (458.82123953), PSNR -27.14164352 (-26.60490621), SSIM -0.00015086 (-0.00014959)
# Finished training epoch 6
# Validate: MSE 524.05371094 (666.96765820), PSNR -27.19375801 (-28.17364707), SSIM -0.00017650 (-0.00010591)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 649.44586182 (582.37339932), PSNR -28.12542915 (-27.64278146), SSIM -0.00011421 (-0.00012501)
# Finished training epoch 7
# Validate: MSE 686.71740723 (914.05081895), PSNR -28.36777878 (-29.55213779), SSIM -0.00015627 (-0.00008240)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 798.28533936 (722.43463904), PSNR -29.02157974 (-28.58031123), SSIM -0.00008885 (-0.00010813)
# Finished training epoch 8
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1021 pixels
#   return func(*args, **kwargs)
# Validate: MSE 534.92657471 (632.71387705), PSNR -27.28293991 (-27.98316064), SSIM -0.00017128 (-0.00011420)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 965.84375000 (880.54380844), PSNR -29.84906769 (-29.44094969), SSIM -0.00008200 (-0.00009230)
# Finished training epoch 9
# Validate: MSE 717.33825684 (844.76950918), PSNR -28.55723953 (-29.23741585), SSIM -0.00016288 (-0.00009324)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 1154.35083008 (1058.37622070), PSNR -30.62337685 (-30.24067707), SSIM -0.00007716 (-0.00008064)
# Finished training epoch 10
# Validate: MSE 1206.03833008 (1490.30111602), PSNR -30.81361008 (-31.68037580), SSIM -0.00010148 (-0.00005940)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 1364.62719727 (1257.76139789), PSNR -31.35013771 (-30.99090380), SSIM -0.00008247 (-0.00007008)
# Finished training epoch 11
# Validate: MSE 1071.83410645 (1400.41595645), PSNR -30.30127525 (-31.39222345), SSIM -0.00013030 (-0.00006888)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 1600.68127441 (1480.70467910), PSNR -32.04304886 (-31.70011615), SSIM -0.00005268 (-0.00006133)
# Finished training epoch 12
# Validate: MSE 1280.45788574 (1524.22346699), PSNR -31.07365227 (-31.77335644), SSIM -0.00013261 (-0.00006245)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 1862.78247070 (1729.39930320), PSNR -32.70162201 (-32.37479259), SSIM -0.00005386 (-0.00005462)
# Finished training epoch 13
# Validate: MSE 1550.95385742 (1875.17647305), PSNR -31.90598679 (-32.67879487), SSIM -0.00010342 (-0.00005268)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 2154.64746094 (2006.26860781), PSNR -33.33376312 (-33.02006521), SSIM -0.00004202 (-0.00004842)
# Finished training epoch 14
# Validate: MSE 1652.02905273 (1901.24180742), PSNR -32.18017578 (-32.76806133), SSIM -0.00008134 (-0.00004780)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 2478.41284180 (2314.00220805), PSNR -33.94173431 (-33.64009100), SSIM -0.00003603 (-0.00004289)
# Finished training epoch 15
# Validate: MSE 1704.59997559 (2095.44309746), PSNR -32.31622314 (-33.17754858), SSIM -0.00008712 (-0.00004983)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 2837.68212891 (2655.53740266), PSNR -34.52963638 (-34.23821190), SSIM -0.00003039 (-0.00003889)
# Finished training epoch 16
# Validate: MSE 2828.27685547 (4400.91839922), PSNR -34.51521683 (-36.29078499), SSIM -0.00007701 (-0.00002954)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 3236.06591797 (3034.00403984), PSNR -35.10017014 (-34.81705139), SSIM -0.00002982 (-0.00003517)
# Finished training epoch 17
# Validate: MSE 2043.54321289 (2406.67102227), PSNR -33.10383606 (-33.78852351), SSIM -0.00008405 (-0.00004124)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 3676.43286133 (3452.67217820), PSNR -35.65426636 (-35.37862023), SSIM -0.00002992 (-0.00003218)
# Finished training epoch 18
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1023 pixels
#   return func(*args, **kwargs)
# Validate: MSE 3444.14404297 (4504.80956797), PSNR -35.37081146 (-36.51287010), SSIM -0.00006079 (-0.00002723)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 4160.53613281 (3914.69595156), PSNR -36.19149017 (-35.92420878), SSIM -0.00001884 (-0.00003015)
# Finished training epoch 19
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1016 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1003 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1018 pixels
#   return func(*args, **kwargs)
# Validate: MSE 4342.49218750 (5909.21376875), PSNR -36.37738800 (-37.69034122), SSIM -0.00007977 (-0.00002861)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 4691.87402344 (4422.93607594), PSNR -36.71346283 (-36.45448860), SSIM -0.00002231 (-0.00002827)
# Finished training epoch 20
# Validate: MSE 5018.75781250 (7759.86276875), PSNR -37.00596237 (-38.78620075), SSIM -0.00004975 (-0.00001696)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 5274.23144531 (4979.76887781), PSNR -37.22158813 (-36.96962376), SSIM -0.00001804 (-0.00002680)
# Finished training epoch 21
# Validate: MSE 4119.20361328 (7215.07778828), PSNR -36.14812851 (-38.37758974), SSIM -0.00006316 (-0.00002256)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 5906.47021484 (5586.96846359), PSNR -37.71327972 (-37.46944266), SSIM -0.00003463 (-0.00002550)
# Finished training epoch 22
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1020 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1009 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1004 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 992 pixels
#   return func(*args, **kwargs)
# Validate: MSE 6170.04492188 (8531.31041562), PSNR -37.90288162 (-39.28180711), SSIM -0.00004462 (-0.00002680)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 6592.20068359 (6245.71564734), PSNR -38.19030380 (-37.95364832), SSIM -0.00002370 (-0.00002454)
# Finished training epoch 23
# Validate: MSE 4305.01269531 (5580.51118281), PSNR -36.33974457 (-37.41500643), SSIM -0.00005958 (-0.00003031)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 7328.95605469 (6956.65945719), PSNR -38.65042114 (-38.42197734), SSIM -0.00002475 (-0.00002394)
# Finished training epoch 24
# Validate: MSE 5466.69238281 (8338.88580781), PSNR -37.37724686 (-39.14953192), SSIM -0.00005598 (-0.00002646)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 8118.43066406 (7720.14445656), PSNR -39.09471893 (-38.87436150), SSIM -0.00002883 (-0.00002315)
# Finished training epoch 25
# Validate: MSE 6138.54248047 (8446.02163672), PSNR -37.88064957 (-39.21160928), SSIM -0.00006169 (-0.00002610)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 8961.49804688 (8536.30156438), PSNR -39.52380371 (-39.31093555), SSIM -0.00001695 (-0.00002235)
# Finished training epoch 26
# Validate: MSE 6657.64062500 (9530.75006875), PSNR -38.23320007 (-39.73406082), SSIM -0.00005159 (-0.00002338)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 9856.91894531 (9405.19238531), PSNR -39.93740845 (-39.73203831), SSIM -0.00002976 (-0.00002205)
# Finished training epoch 27
# Validate: MSE 7055.99609375 (11764.29048125), PSNR -38.48558426 (-40.64130506), SSIM -0.00005514 (-0.00002462)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 10804.34667969 (10326.89612719), PSNR -40.33598328 (-40.13817345), SSIM -0.00001794 (-0.00002159)
# Finished training epoch 28
# Validate: MSE 7678.32714844 (11085.70804219), PSNR -38.85266495 (-40.27917413), SSIM -0.00003228 (-0.00001886)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 11806.00000000 (11301.47150250), PSNR -40.72102356 (-40.52993083), SSIM -0.00001504 (-0.00002109)
# Finished training epoch 29
# Validate: MSE 5524.38232422 (9292.61293672), PSNR -37.42283630 (-39.46034822), SSIM -0.00006884 (-0.00002666)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 12859.57617188 (12329.16567438), PSNR -41.09226608 (-40.90801408), SSIM -0.00002280 (-0.00002094)
# Finished training epoch 30
# Validate: MSE 9908.84375000 (15516.17472500), PSNR -39.96022797 (-41.77239818), SSIM -0.00003944 (-0.00001652)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 13966.92187500 (13410.09030000), PSNR -41.45100403 (-41.27308268), SSIM -0.00001531 (-0.00002064)
# Finished training epoch 31
# Validate: MSE 11776.54980469 (17841.10245469), PSNR -40.71017838 (-42.43110225), SSIM -0.00004153 (-0.00001523)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 15129.49023438 (14544.49762438), PSNR -41.79824066 (-41.62583385), SSIM -0.00002245 (-0.00002018)
# Finished training epoch 32
# Validate: MSE 9209.84375000 (16354.71220000), PSNR -39.64252090 (-41.87459249), SSIM -0.00005136 (-0.00002031)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 16344.54492188 (15732.63847187), PSNR -42.13372803 (-41.96693603), SSIM -0.00002111 (-0.00002091)
# Finished training epoch 33
# Validate: MSE 12932.02343750 (19339.04265000), PSNR -41.11666107 (-42.67295292), SSIM -0.00004209 (-0.00001731)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 17611.58984375 (16974.75726875), PSNR -42.45798492 (-42.29702413), SSIM -0.00001978 (-0.00001995)
# Finished training epoch 34
# Validate: MSE 16724.73437500 (32873.66402500), PSNR -42.23358917 (-45.06694503), SSIM -0.00005012 (-0.00002271)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 18935.80859375 (18271.10841875), PSNR -42.77283859 (-42.61669935), SSIM -0.00001148 (-0.00001901)
# Finished training epoch 35
# Validate: MSE 15192.15136719 (28784.77476719), PSNR -41.81619263 (-44.30183516), SSIM -0.00003163 (-0.00001642)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 20313.90234375 (19621.98931875), PSNR -43.07793045 (-42.92653720), SSIM -0.00001962 (-0.00001927)
# Finished training epoch 36
# Validate: MSE 16260.48437500 (22105.54952500), PSNR -42.11133194 (-43.28974874), SSIM -0.00002359 (-0.00001298)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 21747.50390625 (21027.61030625), PSNR -43.37409210 (-43.22705822), SSIM -0.00001822 (-0.00001892)
# Finished training epoch 37
# Validate: MSE 20193.47460938 (32869.30198438), PSNR -43.05210876 (-44.94636111), SSIM -0.00002812 (-0.00001186)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 23236.18359375 (22488.18856375), PSNR -43.66164398 (-43.51875177), SSIM -0.00001301 (-0.00001761)
# Finished training epoch 38
# Validate: MSE 19027.67968750 (28808.81528750), PSNR -42.79385757 (-44.51803121), SSIM -0.00002944 (-0.00001265)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 24778.70312500 (24004.01983500), PSNR -43.94078445 (-43.80209104), SSIM -0.00001808 (-0.00001766)
# Finished training epoch 39
# Validate: MSE 13956.61523438 (20347.03953437), PSNR -41.44779968 (-42.85975750), SSIM -0.00006322 (-0.00001973)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 26376.69726562 (25575.28280563), PSNR -44.21220016 (-44.07749655), SSIM -0.00001278 (-0.00001803)
# Finished training epoch 40
# Validate: MSE 20795.17578125 (31577.15498125), PSNR -43.17962265 (-44.90995497), SSIM -0.00002800 (-0.00000977)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 28033.28125000 (27202.10204500), PSNR -44.47673798 (-44.34535420), SSIM -0.00001966 (-0.00001724)
# Finished training epoch 41
# Validate: MSE 18464.72070312 (30315.50736562), PSNR -42.66342545 (-44.60184913), SSIM -0.00003079 (-0.00002017)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 29741.81250000 (28884.76735500), PSNR -44.73367310 (-44.60605338), SSIM -0.00001244 (-0.00001618)
# Finished training epoch 42
# Validate: MSE 16074.09570312 (24079.91867812), PSNR -42.06126404 (-43.63439055), SSIM -0.00004916 (-0.00001905)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 31510.30859375 (30623.38677375), PSNR -44.98452759 (-44.85992902), SSIM -0.00001014 (-0.00001597)
# Finished training epoch 43
# Validate: MSE 44274.73046875 (71772.70931875), PSNR -46.46155930 (-48.49257209), SSIM -0.00002102 (-0.00001094)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 33333.69531250 (32418.11007750), PSNR -45.22883224 (-45.10730368), SSIM -0.00002320 (-0.00001576)
# Finished training epoch 44
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1017 pixels
#   return func(*args, **kwargs)
# Validate: MSE 25816.51171875 (42989.52081875), PSNR -44.11897278 (-46.24842898), SSIM -0.00004432 (-0.00002176)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 35211.96875000 (34269.11409000), PSNR -45.46689987 (-45.34848369), SSIM -0.00001018 (-0.00001425)
# Finished training epoch 45
# Validate: MSE 14322.63964844 (25418.39866094), PSNR -41.56023026 (-43.79505306), SSIM -0.00003328 (-0.00001698)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 37148.61328125 (36176.60624125), PSNR -45.69942474 (-45.58375894), SSIM -0.00001492 (-0.00001475)
# Finished training epoch 46
# Validate: MSE 19461.38085938 (28614.49847187), PSNR -42.89173508 (-44.37972097), SSIM -0.00005911 (-0.00001543)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 39139.80468750 (38140.65603750), PSNR -45.92618179 (-45.81338669), SSIM -0.00001336 (-0.00001530)
# Finished training epoch 47
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1007 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1014 pixels
#   return func(*args, **kwargs)
# Validate: MSE 29943.91796875 (59437.45729375), PSNR -44.76308441 (-47.60453383), SSIM -0.00002410 (-0.00001481)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 41188.75781250 (40161.31467250), PSNR -46.14778519 (-46.03760712), SSIM -0.00001622 (-0.00001426)
# Finished training epoch 48
# Validate: MSE 38207.16406250 (74231.94301250), PSNR -45.82144547 (-48.47536246), SSIM -0.00002727 (-0.00000804)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 43294.26171875 (42238.86595875), PSNR -46.36430359 (-46.25667154), SSIM -0.00000971 (-0.00001237)
# Finished training epoch 49
# Validate: MSE 40541.98437500 (63734.93152500), PSNR -46.07904816 (-47.93179406), SSIM -0.00002425 (-0.00001222)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 45457.43750000 (44373.31335000), PSNR -46.57604980 (-46.47078732), SSIM -0.00001458 (-0.00001301)
# Finished training epoch 50
# Validate: MSE 37400.67968750 (65479.85448750), PSNR -45.72879028 (-47.98238247), SSIM -0.00002989 (-0.00000828)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 47677.07031250 (46564.76107250), PSNR -46.78309631 (-46.68016084), SSIM -0.00001093 (-0.00001204)
# Finished training epoch 51
# Validate: MSE 47291.04296875 (84849.67901875), PSNR -46.74778748 (-48.97275002), SSIM -0.00000806 (-0.00000384)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 49957.46093750 (48813.33100750), PSNR -46.98600006 (-46.88498941), SSIM -0.00000706 (-0.00001250)
# Finished training epoch 52
# Validate: MSE 28388.80664062 (48967.24621562), PSNR -44.53146744 (-46.77602862), SSIM -0.00002078 (-0.00000702)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 52288.82031250 (51119.22980250), PSNR -47.18408585 (-47.08546412), SSIM -0.00000913 (-0.00001168)
# Finished training epoch 53
# Validate: MSE 29297.59570312 (48826.18842813), PSNR -44.66831970 (-46.67509470), SSIM -0.00004165 (-0.00001137)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 54683.00000000 (53482.40987000), PSNR -47.37852097 (-47.28174631), SSIM -0.00002154 (-0.00001216)
# Finished training epoch 54
# Validate: MSE 33319.11718750 (54828.59386250), PSNR -45.22693634 (-47.05730319), SSIM -0.00001227 (-0.00001011)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 57130.01953125 (55902.83891125), PSNR -47.56864166 (-47.47398999), SSIM -0.00000521 (-0.00001117)
# Finished training epoch 55
# Validate: MSE 40627.41015625 (82454.45405625), PSNR -46.08818817 (-48.82121835), SSIM -0.00000940 (-0.00000754)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 59639.47656250 (58380.94168250), PSNR -47.75533676 (-47.66237603), SSIM -0.00000570 (-0.00000989)
# Finished training epoch 56
# Validate: MSE 24859.28320312 (44526.86632812), PSNR -43.95488739 (-46.33562997), SSIM -0.00000896 (-0.00001009)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 62202.99218750 (60916.64003750), PSNR -47.93811035 (-47.84703718), SSIM -0.00000957 (-0.00001064)
# Finished training epoch 57
# Validate: MSE 36943.90625000 (52433.16435000), PSNR -45.67542267 (-47.08743375), SSIM -0.00002522 (-0.00001004)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 64825.81250000 (63509.82694000), PSNR -48.11747742 (-48.02809936), SSIM -0.00000998 (-0.00001069)
# Finished training epoch 58
# Validate: MSE 41486.27343750 (67364.20073750), PSNR -46.17904282 (-48.17019145), SSIM -0.00002097 (-0.00000697)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 67502.18750000 (66160.97826000), PSNR -48.29317474 (-48.20572068), SSIM -0.00001264 (-0.00000986)
# Finished training epoch 59
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1005 pixels
#   return func(*args, **kwargs)
# Validate: MSE 38075.66796875 (69829.28811875), PSNR -45.80647278 (-48.08181130), SSIM -0.00003188 (-0.00001105)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 70240.49218750 (68869.66236750), PSNR -48.46587372 (-48.37999189), SSIM -0.00001111 (-0.00000954)
# Finished training epoch 60
# Validate: MSE 49823.57031250 (74411.05021250), PSNR -46.97434616 (-48.60300798), SSIM -0.00001973 (-0.00000717)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 73034.96093750 (71636.47247750), PSNR -48.63530350 (-48.55106480), SSIM -0.00001001 (-0.00000959)
# Finished training epoch 61
# Validate: MSE 41361.32421875 (63198.60886875), PSNR -46.16593933 (-47.87153313), SSIM -0.00001841 (-0.00000956)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 75887.58593750 (74460.93365750), PSNR -48.80170441 (-48.71901743), SSIM -0.00000628 (-0.00000890)
# Finished training epoch 62
# Validate: MSE 52978.81640625 (95274.59885625), PSNR -47.24102020 (-49.35880878), SSIM -0.00000338 (-0.00000370)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 78798.56250000 (77343.48582000), PSNR -48.96517944 (-48.88397938), SSIM -0.00000988 (-0.00000906)
# Finished training epoch 63
# Validate: MSE 46506.97656250 (93416.82391250), PSNR -46.67517853 (-49.46440094), SSIM -0.00003711 (-0.00001279)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 81772.01562500 (80284.27040500), PSNR -49.12604523 (-49.04605520), SSIM -0.00000666 (-0.00000841)
# Finished training epoch 64
# Validate: MSE 40788.07031250 (63781.00676250), PSNR -46.10533142 (-47.90361956), SSIM -0.00002698 (-0.00001160)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 84798.27343750 (83282.82799750), PSNR -49.28386688 (-49.20531389), SSIM -0.00000993 (-0.00000770)
# Finished training epoch 65
# Validate: MSE 55959.05078125 (96227.05528125), PSNR -47.47870255 (-49.70219781), SSIM -0.00003514 (-0.00000952)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 87886.20312500 (86339.82392500), PSNR -49.43920517 (-49.36187894), SSIM -0.00000577 (-0.00000794)
# Finished training epoch 66
# Validate: MSE 48319.58984375 (73018.97289375), PSNR -46.84122849 (-48.51771203), SSIM -0.00002540 (-0.00000842)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 91026.14062500 (89455.22392500), PSNR -49.59165955 (-49.51583188), SSIM -0.00000430 (-0.00000805)
# Finished training epoch 67
# Validate: MSE 71178.76562500 (143649.37792500), PSNR -48.52350235 (-51.28287906), SSIM -0.00000819 (-0.00000433)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 94231.61718750 (92628.38546750), PSNR -49.74196625 (-49.66722261), SSIM -0.00000957 (-0.00000757)
# Finished training epoch 68
# Validate: MSE 65870.18750000 (114438.68970000), PSNR -48.18688583 (-50.45683022), SSIM -0.00002395 (-0.00000729)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 97492.39843750 (95860.39939750), PSNR -49.88970566 (-49.81618124), SSIM -0.00000987 (-0.00000709)
# Finished training epoch 69
# Validate: MSE 65492.01562500 (120148.19717500), PSNR -48.16188049 (-50.58996589), SSIM -0.00002134 (-0.00000698)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 100810.49218750 (99150.28542750), PSNR -50.03505707 (-49.96273497), SSIM -0.00001710 (-0.00000716)
# Finished training epoch 70
# Validate: MSE 67331.07812500 (121634.16552500), PSNR -48.28215408 (-50.56238885), SSIM -0.00001924 (-0.00000548)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 104191.10156250 (102499.08556250), PSNR -50.17830276 (-50.10700150), SSIM -0.00000786 (-0.00000714)
# Finished training epoch 71
# Validate: MSE 76586.70312500 (130924.41882500), PSNR -48.84152985 (-51.05036783), SSIM -0.00002099 (-0.00000707)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 107625.21093750 (105905.83779750), PSNR -50.31913757 (-50.24900680), SSIM -0.00001181 (-0.00000667)
# Finished training epoch 72
# Validate: MSE 71333.29687500 (108291.70702500), PSNR -48.53292084 (-50.11589730), SSIM -0.00001773 (-0.00000614)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 111122.16406250 (109371.33058250), PSNR -50.45800400 (-50.38884849), SSIM -0.00000634 (-0.00000641)
# Finished training epoch 73
# Validate: MSE 55400.45312500 (97008.24552500), PSNR -47.43513107 (-49.56583962), SSIM -0.00001762 (-0.00000572)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 114673.72656250 (112895.74928250), PSNR -50.59463501 (-50.52659475), SSIM -0.00000614 (-0.00000646)
# Finished training epoch 74
# Validate: MSE 58874.30468750 (95105.15363750), PSNR -47.69925690 (-49.56996359), SSIM -0.00000691 (-0.00000430)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 118287.67187500 (116477.72065500), PSNR -50.72939301 (-50.66225276), SSIM -0.00000558 (-0.00000596)
# Finished training epoch 75
# Validate: MSE 69238.80468750 (113187.71193750), PSNR -48.40349579 (-50.31045731), SSIM -0.00001385 (-0.00000598)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 121960.70312500 (120119.24630500), PSNR -50.86219788 (-50.79595523), SSIM -0.00000559 (-0.00000605)
# Finished training epoch 76
# Validate: MSE 108822.65625000 (180326.86065000), PSNR -50.36719131 (-52.45719493), SSIM -0.00001117 (-0.00000525)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 125687.57812500 (123820.05586500), PSNR -50.99291992 (-50.92774387), SSIM -0.00000537 (-0.00000535)
# Finished training epoch 77
# Validate: MSE 77966.39062500 (134993.70952500), PSNR -48.91907120 (-51.15006915), SSIM -0.00001009 (-0.00000345)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 129476.97656250 (127580.00322250), PSNR -51.12192154 (-51.05766464), SSIM -0.00000262 (-0.00000559)
# Finished training epoch 78
# Validate: MSE 62718.80859375 (116115.85084375), PSNR -47.97397232 (-50.47285596), SSIM -0.00000981 (-0.00000552)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 133319.79687500 (131397.91865500), PSNR -51.24894333 (-51.18572803), SSIM -0.00001196 (-0.00000573)
# Finished training epoch 79
# Validate: MSE 91204.50000000 (179798.07510000), PSNR -49.60015869 (-52.24470454), SSIM -0.00001542 (-0.00000432)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 137227.01562500 (135272.09434500), PSNR -51.37439346 (-51.31192964), SSIM -0.00000351 (-0.00000545)
# Finished training epoch 80
# Validate: MSE 81837.92187500 (137041.97197500), PSNR -49.12954330 (-51.15460810), SSIM -0.00001357 (-0.00000530)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 141191.95312500 (139206.01848500), PSNR -51.49809647 (-51.43643135), SSIM -0.00000489 (-0.00000548)
# Finished training epoch 81
# Validate: MSE 93642.71875000 (168828.05615000), PSNR -49.71473694 (-51.97030574), SSIM -0.00001539 (-0.00000430)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 145216.14062500 (143202.52410500), PSNR -51.62014771 (-51.55936186), SSIM -0.00000365 (-0.00000521)
# Finished training epoch 82
# Validate: MSE 112333.40625000 (167218.64215000), PSNR -50.50508881 (-52.03025658), SSIM -0.00001086 (-0.00000330)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 149296.64062500 (147256.05462500), PSNR -51.74049759 (-51.68059075), SSIM -0.00000366 (-0.00000497)
# Finished training epoch 83
# Validate: MSE 134348.29687500 (236831.95637500), PSNR -51.28232193 (-53.58571964), SSIM -0.00000894 (-0.00000212)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 153433.53125000 (151366.22861000), PSNR -51.85919952 (-51.80015281), SSIM -0.00000720 (-0.00000488)
# Finished training epoch 84
# Validate: MSE 89982.82812500 (166809.92562500), PSNR -49.54159546 (-51.97555142), SSIM -0.00002093 (-0.00000533)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 157636.03125000 (155532.94329000), PSNR -51.97655487 (-51.91809038), SSIM -0.00000409 (-0.00000418)
# Finished training epoch 85
# Validate: MSE 79850.20312500 (143084.78662500), PSNR -49.02275848 (-51.39117123), SSIM -0.00000911 (-0.00000523)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 161891.98437500 (159760.74577500), PSNR -52.09225082 (-52.03457023), SSIM -0.00000395 (-0.00000479)
# Finished training epoch 86
# Validate: MSE 88779.92187500 (133489.43427500), PSNR -49.48314667 (-51.08011044), SSIM -0.00001219 (-0.00000413)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 166214.10937500 (164053.20941500), PSNR -52.20667648 (-52.14971967), SSIM -0.00000500 (-0.00000459)
# Finished training epoch 87
# Validate: MSE 114246.01562500 (191235.81002500), PSNR -50.57840729 (-52.70042692), SSIM -0.00001147 (-0.00000400)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 170595.51562500 (168404.16410500), PSNR -52.31967163 (-52.26340379), SSIM -0.00000572 (-0.00000453)
# Finished training epoch 88
# Validate: MSE 99223.23437500 (147662.57247500), PSNR -49.96613312 (-51.52836100), SSIM -0.00001750 (-0.00000365)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 175030.93750000 (172812.26030000), PSNR -52.43114471 (-52.37562423), SSIM -0.00000315 (-0.00000422)
# Finished training epoch 89
# Validate: MSE 139464.71875000 (255275.49155000), PSNR -51.44464111 (-53.93522886), SSIM -0.00001126 (-0.00000387)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 179526.35937500 (177277.37781500), PSNR -52.54128265 (-52.48641489), SSIM -0.00000384 (-0.00000428)
# Finished training epoch 90
# Validate: MSE 104701.21875000 (137228.01155000), PSNR -50.19951630 (-51.27072606), SSIM -0.00000867 (-0.00000360)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 184079.12500000 (181799.59244000), PSNR -52.65004349 (-52.59581351), SSIM -0.00000297 (-0.00000424)
# Finished training epoch 91
# Validate: MSE 95996.91406250 (166626.70436250), PSNR -49.82257080 (-52.01265566), SSIM -0.00001857 (-0.00000505)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 188683.71875000 (186378.71503000), PSNR -52.75733948 (-52.70385066), SSIM -0.00000325 (-0.00000387)
# Finished training epoch 92
# Validate: MSE 130391.72656250 (247230.49296250), PSNR -51.15249634 (-53.79838730), SSIM -0.00001416 (-0.00000382)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 193364.21875000 (191019.78531000), PSNR -52.86375809 (-52.81067318), SSIM -0.00000642 (-0.00000363)
# Finished training epoch 93
# Validate: MSE 115295.21093750 (204018.39203750), PSNR -50.61811066 (-52.88260743), SSIM -0.00001689 (-0.00000387)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 198095.50000000 (195726.83324000), PSNR -52.96874237 (-52.91639568), SSIM -0.00000701 (-0.00000399)
# Finished training epoch 94
# Validate: MSE 146253.43750000 (215066.48400000), PSNR -51.65105820 (-53.17559218), SSIM -0.00001488 (-0.00000380)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 202890.62500000 (200492.50728000), PSNR -53.07262039 (-53.02087600), SSIM -0.00000485 (-0.00000368)
# Finished training epoch 95
# Validate: MSE 131750.35937500 (259637.51677500), PSNR -51.19751358 (-53.91858409), SSIM -0.00001464 (-0.00000331)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 207742.96875000 (205315.57231000), PSNR -53.17525864 (-53.12411596), SSIM -0.00000237 (-0.00000375)
# Finished training epoch 96
# Validate: MSE 121868.23437500 (219760.39197500), PSNR -50.85890198 (-53.12980652), SSIM -0.00001175 (-0.00000324)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 212652.04687500 (210196.11691500), PSNR -53.27669144 (-53.22614607), SSIM -0.00000669 (-0.00000363)
# Finished training epoch 97
# Validate: MSE 120503.86718750 (192374.26138750), PSNR -50.81000900 (-52.69942722), SSIM -0.00001225 (-0.00000387)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 217621.71875000 (215134.06455000), PSNR -53.37702179 (-53.32699333), SSIM -0.00000278 (-0.00000372)
# Finished training epoch 98
# Validate: MSE 128981.32812500 (254638.23952500), PSNR -51.10526657 (-53.83242551), SSIM -0.00000522 (-0.00000311)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 222637.84375000 (220129.42387000), PSNR -53.47599030 (-53.42668475), SSIM -0.00000192 (-0.00000337)
# Finished training epoch 99
# Validate: MSE 114294.26562500 (152784.78182500), PSNR -50.58024216 (-51.67702180), SSIM 0.00005453 (-0.00000138)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 227724.75000000 (225183.28544000), PSNR -53.57410049 (-53.52526700), SSIM -0.00000306 (-0.00000329)
# Finished training epoch 100
# Validate: MSE 171643.23437500 (267700.66147500), PSNR -52.34626389 (-54.12933376), SSIM -0.00000940 (-0.00000335)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 232881.67187500 (230300.85899500), PSNR -53.67135239 (-53.62286293), SSIM -0.00000217 (-0.00000329)
# Finished training epoch 101
# Validate: MSE 130567.39062500 (216761.18792500), PSNR -51.15834427 (-53.13403157), SSIM -0.00000656 (-0.00000320)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 238082.84375000 (235477.17379000), PSNR -53.76727676 (-53.71939786), SSIM -0.00000368 (-0.00000334)
# Finished training epoch 102
# Validate: MSE 154324.51562500 (265939.64482500), PSNR -51.88434601 (-54.08154156), SSIM -0.00001069 (-0.00000344)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 243353.00000000 (240715.11560000), PSNR -53.86236572 (-53.81494468), SSIM -0.00000288 (-0.00000309)
# Finished training epoch 103
# Validate: MSE 128054.47656250 (222431.62456250), PSNR -51.07394409 (-53.29005269), SSIM -0.00001141 (-0.00000363)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 248678.17187500 (246014.46931500), PSNR -53.95637512 (-53.90951964), SSIM -0.00000276 (-0.00000285)
# Finished training epoch 104
# Validate: MSE 182790.35937500 (269140.18697500), PSNR -52.61953354 (-54.05251279), SSIM -0.00001010 (-0.00000209)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 254063.50000000 (251371.86956000), PSNR -54.04941940 (-54.00308143), SSIM -0.00000478 (-0.00000311)
# Finished training epoch 105
# Validate: MSE 159752.26562500 (273297.02862500), PSNR -52.03446960 (-54.18915115), SSIM -0.00000822 (-0.00000289)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 259511.57812500 (256786.87960500), PSNR -54.14156342 (-54.09564477), SSIM -0.00000257 (-0.00000296)
# Finished training epoch 106
# Validate: MSE 156594.26562500 (225599.22492500), PSNR -51.94775772 (-53.34982789), SSIM -0.00001177 (-0.00000318)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 265012.84375000 (262259.65683000), PSNR -54.23266602 (-54.18723333), SSIM -0.00000254 (-0.00000296)
# Finished training epoch 107
# Validate: MSE 205711.42187500 (311971.94927500), PSNR -53.13258362 (-54.78028850), SSIM -0.00000616 (-0.00000268)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 270569.28125000 (267790.19917000), PSNR -54.32278442 (-54.27786656), SSIM -0.00000591 (-0.00000297)
# Finished training epoch 108
# Validate: MSE 182414.35937500 (268738.76697500), PSNR -52.61058807 (-54.12445424), SSIM -0.00000856 (-0.00000275)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 276190.40625000 (273379.03497000), PSNR -54.41208267 (-54.36757346), SSIM -0.00000168 (-0.00000261)
# Finished training epoch 109
# Validate: MSE 165342.81250000 (308075.48230000), PSNR -52.18385315 (-54.63820671), SSIM -0.00000318 (-0.00000204)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 281869.59375000 (279032.50303000), PSNR -54.50048065 (-54.45647060), SSIM -0.00000226 (-0.00000273)
# Finished training epoch 110
# Validate: MSE 186832.29687500 (352719.75147500), PSNR -52.71451950 (-55.23216389), SSIM -0.00000538 (-0.00000235)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 287619.46875000 (284745.61003000), PSNR -54.58817673 (-54.54449455), SSIM -0.00000210 (-0.00000248)
# Finished training epoch 111
# Validate: MSE 177022.43750000 (236166.86320000), PSNR -52.48028183 (-53.60286567), SSIM -0.00000535 (-0.00000244)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 293415.50000000 (290516.89592000), PSNR -54.67482758 (-54.63163961), SSIM -0.00000258 (-0.00000259)
# Finished training epoch 112
# Validate: MSE 165119.15625000 (293678.01045000), PSNR -52.17797089 (-54.39604032), SSIM -0.00000772 (-0.00000264)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 299276.81250000 (296345.97418000), PSNR -54.76072693 (-54.71791750), SSIM -0.00000231 (-0.00000241)
# Finished training epoch 113
# Validate: MSE 185412.29687500 (310966.11227500), PSNR -52.68138504 (-54.66019442), SSIM -0.00000826 (-0.00000216)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 305199.06250000 (302234.58778000), PSNR -54.84582901 (-54.80336971), SSIM -0.00000177 (-0.00000254)
# Finished training epoch 114
# Validate: MSE 169461.84375000 (291129.72795000), PSNR -52.29071808 (-54.44609093), SSIM -0.00000860 (-0.00000220)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 311185.40625000 (308187.81721000), PSNR -54.93018723 (-54.88808431), SSIM -0.00000214 (-0.00000233)
# Finished training epoch 115
# Validate: MSE 185902.53125000 (340602.47925000), PSNR -52.69284821 (-55.05494796), SSIM -0.00000473 (-0.00000200)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 317220.40625000 (314200.17561000), PSNR -55.01360703 (-54.97199508), SSIM -0.00000184 (-0.00000245)
# Finished training epoch 116
# Validate: MSE 192898.26562500 (425151.73522500), PSNR -52.85327911 (-55.94597560), SSIM -0.00000189 (-0.00000119)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 323321.00000000 (320270.60128000), PSNR -55.09634018 (-55.05510304), SSIM -0.00000233 (-0.00000240)
# Finished training epoch 117
# Validate: MSE 183667.14062500 (355590.37922500), PSNR -52.64031219 (-55.21813031), SSIM -0.00000470 (-0.00000184)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 329478.31250000 (326399.15506000), PSNR -55.17826843 (-55.13742378), SSIM -0.00000278 (-0.00000238)
# Finished training epoch 118
# Validate: MSE 194246.71875000 (347060.39035000), PSNR -52.88353729 (-55.21154095), SSIM -0.00000592 (-0.00000261)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 335686.21875000 (332585.90907000), PSNR -55.25933456 (-55.21897306), SSIM -0.00000342 (-0.00000241)
# Finished training epoch 119
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1010 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1015 pixels
#   return func(*args, **kwargs)
# Validate: MSE 248490.15625000 (412609.10525000), PSNR -53.95309067 (-55.98725346), SSIM -0.00000681 (-0.00000243)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 341966.93750000 (338830.71622000), PSNR -55.33983994 (-55.29976345), SSIM -0.00000224 (-0.00000228)
# Finished training epoch 120
# Validate: MSE 248274.15625000 (336138.91545000), PSNR -53.94931412 (-55.16320850), SSIM -0.00000675 (-0.00000192)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 348314.68750000 (345138.60230000), PSNR -55.41971588 (-55.37987198), SSIM -0.00000130 (-0.00000229)
# Finished training epoch 121
# Validate: MSE 186793.29687500 (310004.45397500), PSNR -52.71361160 (-54.59548397), SSIM -0.00000352 (-0.00000186)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 354706.03125000 (351509.93757000), PSNR -55.49868393 (-55.45931384), SSIM -0.00000331 (-0.00000219)
# Finished training epoch 122
# Validate: MSE 229636.90625000 (329263.37045000), PSNR -53.61041260 (-54.93238403), SSIM -0.00000657 (-0.00000178)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 361174.93750000 (357939.71790000), PSNR -55.57717514 (-55.53803772), SSIM -0.00000191 (-0.00000219)
# Finished training epoch 123
# Validate: MSE 175399.70312500 (309150.48332500), PSNR -52.44028473 (-54.72666740), SSIM -0.00000535 (-0.00000221)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 367684.50000000 (364427.70304000), PSNR -55.65475082 (-55.61605374), SSIM -0.00000171 (-0.00000198)
# Finished training epoch 124
# Validate: MSE 222335.28125000 (361817.21605000), PSNR -53.47008133 (-55.37554622), SSIM -0.00000367 (-0.00000163)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 374265.75000000 (370974.18640000), PSNR -55.73180008 (-55.69337776), SSIM -0.00000244 (-0.00000213)
# Finished training epoch 125
# Validate: MSE 242449.09375000 (441979.85355000), PSNR -53.84620285 (-56.21274826), SSIM -0.00000302 (-0.00000168)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 380901.68750000 (377578.83190000), PSNR -55.80812836 (-55.77001819), SSIM -0.00000375 (-0.00000198)
# Finished training epoch 126
# Validate: MSE 233580.65625000 (374598.61325000), PSNR -53.68436432 (-55.48773029), SSIM -0.00000581 (-0.00000176)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 387595.31250000 (384241.99962000), PSNR -55.88378143 (-55.84599124), SSIM -0.00000293 (-0.00000208)
# Finished training epoch 127
# Validate: MSE 167149.40625000 (358086.73165000), PSNR -52.23104858 (-55.19740933), SSIM -0.00000254 (-0.00000165)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 394340.75000000 (390963.25504000), PSNR -55.95871353 (-55.92130321), SSIM -0.00000159 (-0.00000192)
# Finished training epoch 128
# Validate: MSE 236090.73437500 (409917.26617500), PSNR -53.73078537 (-55.97471911), SSIM -0.00000460 (-0.00000125)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 401155.71875000 (397747.85299000), PSNR -56.03313065 (-55.99602301), SSIM -0.00000127 (-0.00000180)
# Finished training epoch 129
# Validate: MSE 203663.21875000 (381226.14655000), PSNR -53.08912277 (-55.59496887), SSIM -0.00000326 (-0.00000124)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 408033.84375000 (404596.46591000), PSNR -56.10696030 (-56.07016624), SSIM -0.00000258 (-0.00000193)
# Finished training epoch 130
# Validate: MSE 273532.00000000 (511827.39040000), PSNR -54.37007904 (-56.78175331), SSIM -0.00000296 (-0.00000126)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 414969.03125000 (411503.50221000), PSNR -56.18015289 (-56.14368182), SSIM -0.00000202 (-0.00000190)
# Finished training epoch 131
# Validate: MSE 305723.50000000 (566815.89240000), PSNR -54.85328293 (-57.26433073), SSIM -0.00000412 (-0.00000098)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 421964.40625000 (418468.98137000), PSNR -56.25275421 (-56.21657984), SSIM -0.00000147 (-0.00000184)
# Finished training epoch 132
# Validate: MSE 308213.12500000 (606102.23740000), PSNR -54.88850784 (-57.61605369), SSIM -0.00000430 (-0.00000115)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 429021.06250000 (425493.03394000), PSNR -56.32478333 (-56.28887268), SSIM -0.00000186 (-0.00000188)
# Finished training epoch 133
# Validate: MSE 228441.51562500 (407546.67542500), PSNR -53.58774948 (-55.81167429), SSIM -0.00000567 (-0.00000191)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 436127.09375000 (432574.95935000), PSNR -56.39612961 (-56.36056265), SSIM -0.00000107 (-0.00000149)
# Finished training epoch 134
# Validate: MSE 318671.31250000 (631556.52810000), PSNR -55.03342438 (-57.68855299), SSIM -0.00000422 (-0.00000124)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 443305.43750000 (439717.75318000), PSNR -56.46702576 (-56.43168954), SSIM -0.00000223 (-0.00000175)
# Finished training epoch 135
# Validate: MSE 290075.25000000 (421053.19980000), PSNR -54.62510681 (-56.04116931), SSIM -0.00000212 (-0.00000132)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 450552.40625000 (446927.25425000), PSNR -56.53744888 (-56.50231869), SSIM -0.00000110 (-0.00000156)
# Finished training epoch 136
# Validate: MSE 217996.95312500 (372291.19532500), PSNR -53.38450241 (-55.45677131), SSIM -0.00000262 (-0.00000158)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 457844.18750000 (454197.18638000), PSNR -56.60717773 (-56.57239531), SSIM -0.00000133 (-0.00000177)
# Finished training epoch 137
# Validate: MSE 315598.06250000 (470178.88010000), PSNR -54.99134064 (-56.53951393), SSIM -0.00000530 (-0.00000126)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 465202.00000000 (461525.55752000), PSNR -56.67641449 (-56.64190926), SSIM -0.00000090 (-0.00000175)
# Finished training epoch 138
# Validate: MSE 349174.12500000 (628166.00700000), PSNR -55.43041611 (-57.81707099), SSIM -0.00000411 (-0.00000138)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 472622.50000000 (468912.57872000), PSNR -56.74514389 (-56.71087132), SSIM -0.00000134 (-0.00000157)
# Finished training epoch 139
# Validate: MSE 310197.34375000 (483452.34115000), PSNR -54.91637802 (-56.60631801), SSIM -0.00000099 (-0.00000071)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 480089.50000000 (476358.29352000), PSNR -56.81322098 (-56.77929036), SSIM -0.00000099 (-0.00000161)
# Finished training epoch 140
# Validate: MSE 658992.50000000 (1184859.77680000), PSNR -58.18880081 (-60.41630901), SSIM -0.00000207 (-0.00000086)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 487626.34375000 (483862.53919000), PSNR -56.88086700 (-56.84717387), SSIM -0.00000076 (-0.00000140)
# Finished training epoch 141
# Validate: MSE 349225.21875000 (549064.83275000), PSNR -55.43105316 (-57.10157645), SSIM -0.00000428 (-0.00000106)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 495225.18750000 (491426.03614000), PSNR -56.94802475 (-56.91453610), SSIM -0.00000134 (-0.00000158)
# Finished training epoch 142
# Validate: MSE 336467.65625000 (535174.10545000), PSNR -55.26943207 (-57.04877064), SSIM -0.00000351 (-0.00000116)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 502863.59375000 (499046.82943000), PSNR -57.01449966 (-56.98136813), SSIM -0.00000041 (-0.00000154)
# Finished training epoch 143
# Validate: MSE 278021.06250000 (631558.95290000), PSNR -54.44077301 (-57.63437570), SSIM -0.00000056 (-0.00000047)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 510590.50000000 (506724.79736000), PSNR -57.08072281 (-57.04767728), SSIM -0.00000105 (-0.00000151)
# Finished training epoch 144
# Validate: MSE 315979.96875000 (485786.86095000), PSNR -54.99659348 (-56.68138849), SSIM -0.00000422 (-0.00000155)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 518373.59375000 (514475.51847000), PSNR -57.14642334 (-57.11360335), SSIM -0.00000168 (-0.00000153)
# Finished training epoch 145
# Validate: MSE 360266.68750000 (610901.86710000), PSNR -55.56623840 (-57.70156184), SSIM -0.00000371 (-0.00000151)
# Finished validation.
# Starting training epoch 146
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_26169/1789201418.py in <module>
#       2 for epoch in range(epochs):
#       3     # Train for one epoch, then validate
# ----> 4     train(train_loader, model, criterion, optimizer, epoch)
#       5     with torch.no_grad():
#       6         losses = validate(val_loader, model, criterion, save_images, epoch)
#
# /tmp/ipykernel_26169/1877203783.py in train(train_loader, model, criterion, optimizer, epoch)
#      17         optimizer.step()
#      18
# ---> 19         _loss[0].update(loss[0].item(), gray.size(0))
#      20         _loss[1].update(loss[1].item(), gray.size(0))
#      21         _loss[2].update(loss[2].item(), gray.size(0))
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
