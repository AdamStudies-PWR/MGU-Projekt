# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-eeb5ac15e7b873fb" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-eeb5ac15e7b873fb");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .25

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(self.convtrans3(x), scale_factor=scale_factor)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 16, 16]           2,306
# ================================================================
# Total params: 2,662,274
# Trainable params: 2,662,274
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.75
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.91
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.07072462 (1.60808911), PSNR 11.50429344 (5.11470274), SSIM 0.04266262 (0.01149934)
# Finished training epoch 0
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 79 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 15 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 85 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 143 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 50 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 6 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 112 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 13 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 248 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.07407236 (0.07573690), PSNR 11.30343819 (11.23587111), SSIM 0.02681173 (0.03313784)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.03401009 (0.04447150), PSNR 14.68392277 (13.65153554), SSIM 0.13707161 (0.10442819)
# Finished training epoch 1
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 68 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 96 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 113 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 20 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 54 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 216 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 64 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.03549461 (0.03509330), PSNR 14.49837494 (14.69999689), SSIM 0.12617514 (0.16606874)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.02347648 (0.02733863), PSNR 16.29367065 (15.64726524), SSIM 0.30162421 (0.23670072)
# Finished training epoch 2
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 60 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 121 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 10 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 33 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 189 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 29 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.02394632 (0.02349041), PSNR 16.20761108 (16.47217056), SSIM 0.21102938 (0.29320520)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.01873474 (0.02152711), PSNR 17.27352333 (16.68045031), SSIM 0.36386228 (0.32259502)
# Finished training epoch 3
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 23 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 43 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 95 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 18 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 36 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 227 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 41 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01972169 (0.01996435), PSNR 17.05055809 (17.18555763), SSIM 0.26313692 (0.36000708)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.01481940 (0.01736999), PSNR 18.29169273 (17.61093357), SSIM 0.40339822 (0.37633833)
# Finished training epoch 4
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 47 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 101 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 38 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 241 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 24 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01749817 (0.01634133), PSNR 17.57007408 (18.04652719), SSIM 0.29060411 (0.40036002)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.01174779 (0.01405777), PSNR 19.30043602 (18.52986926), SSIM 0.44111291 (0.41571487)
# Finished training epoch 5
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 34 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 8 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 190 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 22 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01377232 (0.01308868), PSNR 18.60992622 (19.00236447), SSIM 0.31990287 (0.43465957)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00978564 (0.01131359), PSNR 20.09410858 (19.47452397), SSIM 0.43538895 (0.44923264)
# Finished training epoch 6
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 21 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 57 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 12 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 183 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01113847 (0.01062896), PSNR 19.53174210 (19.89176075), SSIM 0.34918386 (0.46528717)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00862603 (0.00911827), PSNR 20.64189148 (20.41138073), SSIM 0.50171423 (0.48002992)
# Finished training epoch 7
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 7 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 5 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 52 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 169 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00877907 (0.00846988), PSNR 20.56551361 (20.86263978), SSIM 0.37640035 (0.49591719)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00627607 (0.00739454), PSNR 22.02312088 (21.32233459), SSIM 0.51387209 (0.50987789)
# Finished training epoch 8
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 134 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00719243 (0.00671812), PSNR 21.43124390 (21.84304150), SSIM 0.42010704 (0.52986460)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00565096 (0.00605290), PSNR 22.47877693 (22.19075912), SSIM 0.53359568 (0.53979124)
# Finished training epoch 9
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 30 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 131 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 11 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00635990 (0.00604529), PSNR 21.96549606 (22.29216298), SSIM 0.43488824 (0.54504077)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00401917 (0.00505727), PSNR 23.95863152 (22.97330541), SSIM 0.59099627 (0.56880311)
# Finished training epoch 10
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 123 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00514921 (0.00472895), PSNR 22.88259506 (23.33915038), SSIM 0.48183540 (0.58471767)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00407717 (0.00432377), PSNR 23.89641571 (23.65478519), SSIM 0.56781644 (0.59668831)
# Finished training epoch 11
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 124 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00445731 (0.00406229), PSNR 23.50926971 (23.98490038), SSIM 0.50819743 (0.61092756)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00353274 (0.00379324), PSNR 24.51888657 (24.22536791), SSIM 0.62378126 (0.62374339)
# Finished training epoch 12
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 55 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00391803 (0.00356458), PSNR 24.06932640 (24.54258712), SSIM 0.54748470 (0.63903980)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00333262 (0.00341675), PSNR 24.77214432 (24.68081540), SSIM 0.66663539 (0.64875606)
# Finished training epoch 13
# Validate: MSE 0.00349689 (0.00323088), PSNR 24.56318092 (24.97587624), SSIM 0.57970476 (0.66485303)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00326167 (0.00316175), PSNR 24.86560249 (25.02066247), SSIM 0.66913605 (0.67220098)
# Finished training epoch 14
# Validate: MSE 0.00345969 (0.00307252), PSNR 24.60962868 (25.18928112), SSIM 0.59620911 (0.68284313)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00284909 (0.00298544), PSNR 25.45293045 (25.26949927), SSIM 0.71679562 (0.69359905)
# Finished training epoch 15
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 19 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00317943 (0.00289506), PSNR 24.97650528 (25.45767310), SSIM 0.62808359 (0.70583982)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00289681 (0.00286967), PSNR 25.38080025 (25.44029425), SSIM 0.72761053 (0.71252149)
# Finished training epoch 16
# Validate: MSE 0.00310218 (0.00280921), PSNR 25.08332825 (25.58516345), SSIM 0.65666610 (0.72128322)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00243182 (0.00279571), PSNR 26.14069366 (25.55891651), SSIM 0.75314438 (0.72842307)
# Finished training epoch 17
# Validate: MSE 0.00307271 (0.00276232), PSNR 25.12479019 (25.65671175), SSIM 0.66912407 (0.73507667)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00287867 (0.00274622), PSNR 25.40807343 (25.63413995), SSIM 0.72968900 (0.74129820)
# Finished training epoch 18
# Validate: MSE 0.00302075 (0.00271497), PSNR 25.19885254 (25.73333123), SSIM 0.68399227 (0.74794175)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00346708 (0.00271667), PSNR 24.60036087 (25.68321891), SSIM 0.73460478 (0.75133426)
# Finished training epoch 19
# Validate: MSE 0.00302495 (0.00269151), PSNR 25.19281578 (25.77562215), SSIM 0.68742639 (0.75498722)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00249606 (0.00269644), PSNR 26.02744102 (25.71470892), SSIM 0.76806444 (0.75822965)
# Finished training epoch 20
# Validate: MSE 0.00311295 (0.00276947), PSNR 25.06827736 (25.65235419), SSIM 0.68035948 (0.74886105)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00264931 (0.00268304), PSNR 25.76867485 (25.73742858), SSIM 0.76029950 (0.76290887)
# Finished training epoch 21
# Validate: MSE 0.00288591 (0.00269293), PSNR 25.39716339 (25.78352648), SSIM 0.69601595 (0.76500722)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00251244 (0.00266098), PSNR 25.99905014 (25.77492687), SSIM 0.79448241 (0.76502960)
# Finished training epoch 22
# Validate: MSE 0.00290257 (0.00265885), PSNR 25.37217903 (25.83800945), SSIM 0.70039141 (0.76546411)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00265636 (0.00262733), PSNR 25.75712204 (25.82897265), SSIM 0.75712156 (0.76534967)
# Finished training epoch 23
# Validate: MSE 0.00291655 (0.00267750), PSNR 25.35130310 (25.79223657), SSIM 0.70740664 (0.76360045)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00237270 (0.00260169), PSNR 26.24756050 (25.86514954), SSIM 0.76760250 (0.76609314)
# Finished training epoch 24
# Validate: MSE 0.00335041 (0.00290976), PSNR 24.74901390 (25.44365833), SSIM 0.69926625 (0.76071941)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00215569 (0.00258841), PSNR 26.66413689 (25.89137729), SSIM 0.77372801 (0.76692114)
# Finished training epoch 25
# Validate: MSE 0.00288448 (0.00269493), PSNR 25.39931679 (25.76984330), SSIM 0.70227265 (0.76604219)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00244858 (0.00256764), PSNR 26.11086082 (25.92536855), SSIM 0.75927681 (0.76749323)
# Finished training epoch 26
# Validate: MSE 0.00281504 (0.00267208), PSNR 25.50515175 (25.81650710), SSIM 0.70536208 (0.76820861)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00246394 (0.00256952), PSNR 26.08369827 (25.92465454), SSIM 0.76351321 (0.76761782)
# Finished training epoch 27
# Validate: MSE 0.00276845 (0.00286120), PSNR 25.57763863 (25.54283199), SSIM 0.70597982 (0.76497688)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00299251 (0.00256517), PSNR 25.23964882 (25.93207513), SSIM 0.75915515 (0.76807806)
# Finished training epoch 28
# Validate: MSE 0.00289788 (0.00262596), PSNR 25.37918854 (25.88385482), SSIM 0.70836025 (0.77032309)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00274782 (0.00255949), PSNR 25.61011314 (25.94205674), SSIM 0.76556313 (0.76798728)
# Finished training epoch 29
# Validate: MSE 0.00283898 (0.00251525), PSNR 25.46837616 (26.05750004), SSIM 0.70372772 (0.76838611)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00224275 (0.00253470), PSNR 26.49219513 (25.98055137), SSIM 0.77121484 (0.76914405)
# Finished training epoch 30
# Validate: MSE 0.00347134 (0.00293944), PSNR 24.59502792 (25.41130434), SSIM 0.69871438 (0.76823625)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00246590 (0.00250204), PSNR 26.08023643 (26.03983226), SSIM 0.76250076 (0.76994234)
# Finished training epoch 31
# Validate: MSE 0.00346489 (0.00300744), PSNR 24.60310745 (25.29965494), SSIM 0.69830894 (0.76513261)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00244344 (0.00252237), PSNR 26.11998749 (26.00682441), SSIM 0.76124561 (0.76975440)
# Finished training epoch 32
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 105 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00297936 (0.00295007), PSNR 25.25877380 (25.42040400), SSIM 0.70095307 (0.76349159)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00202285 (0.00249170), PSNR 26.94036484 (26.05742336), SSIM 0.79184937 (0.77080289)
# Finished training epoch 33
# Validate: MSE 0.00297518 (0.00259303), PSNR 25.26486015 (25.93190522), SSIM 0.70252109 (0.76964974)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00213707 (0.00247271), PSNR 26.70180511 (26.08938129), SSIM 0.77699697 (0.77136796)
# Finished training epoch 34
# Validate: MSE 0.00387242 (0.00379146), PSNR 24.12017822 (24.34542046), SSIM 0.68652093 (0.74232696)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00228152 (0.00244629), PSNR 26.41776276 (26.13766094), SSIM 0.77306241 (0.77225883)
# Finished training epoch 35
# Validate: MSE 0.00284572 (0.00250252), PSNR 25.45807076 (26.08296546), SSIM 0.70487809 (0.76959140)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00241886 (0.00243931), PSNR 26.16388893 (26.15260098), SSIM 0.78930062 (0.77260375)
# Finished training epoch 36
# Validate: MSE 0.00283175 (0.00301265), PSNR 25.47945213 (25.33597892), SSIM 0.70271325 (0.75549027)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00232547 (0.00243564), PSNR 26.33489609 (26.15837809), SSIM 0.77626169 (0.77239310)
# Finished training epoch 37
# Validate: MSE 0.00282138 (0.00242520), PSNR 25.49538803 (26.22015192), SSIM 0.71200252 (0.77720907)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00181306 (0.00242051), PSNR 27.41586876 (26.18307167), SSIM 0.79927194 (0.77272817)
# Finished training epoch 38
# Validate: MSE 0.00295712 (0.00250488), PSNR 25.29130173 (26.08292443), SSIM 0.70826817 (0.76980610)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00281075 (0.00240315), PSNR 25.51177788 (26.21460888), SSIM 0.75713313 (0.77333650)
# Finished training epoch 39
# Validate: MSE 0.00269051 (0.00256184), PSNR 25.70165253 (25.99384166), SSIM 0.70678830 (0.76833966)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00282178 (0.00240001), PSNR 25.49476242 (26.22134854), SSIM 0.75437915 (0.77281373)
# Finished training epoch 40
# Validate: MSE 0.00287457 (0.00250978), PSNR 25.41427231 (26.07130805), SSIM 0.70242262 (0.76853820)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00220347 (0.00240426), PSNR 26.56892586 (26.21273186), SSIM 0.78401554 (0.77300228)
# Finished training epoch 41
# Validate: MSE 0.00622012 (0.00902473), PSNR 22.06201363 (20.53970044), SSIM 0.64175200 (0.67457450)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00215761 (0.00239382), PSNR 26.66027260 (26.23183567), SSIM 0.78957015 (0.77413281)
# Finished training epoch 42
# Validate: MSE 0.00299375 (0.00259376), PSNR 25.23784637 (25.93025450), SSIM 0.70840126 (0.77198216)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00222860 (0.00238478), PSNR 26.51968384 (26.24897197), SSIM 0.77185249 (0.77437024)
# Finished training epoch 43
# Validate: MSE 0.00290994 (0.00242181), PSNR 25.36115837 (26.21966682), SSIM 0.70766729 (0.77159004)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00252166 (0.00238769), PSNR 25.98313904 (26.24250455), SSIM 0.74830806 (0.77418355)
# Finished training epoch 44
# Validate: MSE 0.00293991 (0.00268839), PSNR 25.31665421 (25.77437017), SSIM 0.70468682 (0.76079955)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00259280 (0.00237812), PSNR 25.86230850 (26.26036056), SSIM 0.78187346 (0.77459572)
# Finished training epoch 45
# Validate: MSE 0.00289702 (0.00270564), PSNR 25.38048553 (25.76692574), SSIM 0.71056426 (0.76741795)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00231642 (0.00239043), PSNR 26.35183334 (26.23845345), SSIM 0.79507607 (0.77444004)
# Finished training epoch 46
# Validate: MSE 0.00265249 (0.00244977), PSNR 25.76346588 (26.18269735), SSIM 0.71100128 (0.77425389)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00263662 (0.00236717), PSNR 25.78952980 (26.28163299), SSIM 0.74392080 (0.77503359)
# Finished training epoch 47
# Validate: MSE 0.00274153 (0.00252886), PSNR 25.62006378 (26.04046603), SSIM 0.71186972 (0.77634690)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00253688 (0.00235347), PSNR 25.95700455 (26.30484259), SSIM 0.78252381 (0.77526834)
# Finished training epoch 48
# Validate: MSE 0.00293347 (0.00255915), PSNR 25.32617569 (25.99477103), SSIM 0.70918834 (0.77172151)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00343585 (0.00236751), PSNR 24.63966370 (26.28177070), SSIM 0.74281472 (0.77459482)
# Finished training epoch 49
# Validate: MSE 0.00265720 (0.00235754), PSNR 25.75576019 (26.34036874), SSIM 0.71464950 (0.77563033)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00197141 (0.00236778), PSNR 27.05222702 (26.28044228), SSIM 0.77862871 (0.77448810)
# Finished training epoch 50
# Validate: MSE 0.00273457 (0.00242940), PSNR 25.63110352 (26.20690110), SSIM 0.71216154 (0.76968967)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00212008 (0.00235103), PSNR 26.73647690 (26.31160026), SSIM 0.78338289 (0.77527788)
# Finished training epoch 51
# Validate: MSE 0.00307049 (0.00288698), PSNR 25.12791824 (25.47354341), SSIM 0.70706117 (0.76370852)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00234154 (0.00234814), PSNR 26.30499077 (26.31589097), SSIM 0.77744710 (0.77548316)
# Finished training epoch 52
# Validate: MSE 0.00281021 (0.00263003), PSNR 25.51261711 (25.91173708), SSIM 0.71265066 (0.77118260)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00228166 (0.00235811), PSNR 26.41748047 (26.29958579), SSIM 0.77714527 (0.77493329)
# Finished training epoch 53
# Validate: MSE 0.00332853 (0.00294424), PSNR 24.77746964 (25.40064297), SSIM 0.70545518 (0.76418826)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00303664 (0.00235512), PSNR 25.17607117 (26.30183703), SSIM 0.78409606 (0.77521781)
# Finished training epoch 54
# Validate: MSE 0.00303374 (0.00252642), PSNR 25.18021965 (26.04725410), SSIM 0.71380693 (0.77429422)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00247860 (0.00232760), PSNR 26.05793190 (26.35285177), SSIM 0.77093136 (0.77591484)
# Finished training epoch 55
# Validate: MSE 0.00266097 (0.00260648), PSNR 25.74959946 (25.92133132), SSIM 0.70945615 (0.76809647)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00196514 (0.00234417), PSNR 27.06606102 (26.32471024), SSIM 0.79145747 (0.77516741)
# Finished training epoch 56
# Validate: MSE 0.00276241 (0.00238694), PSNR 25.58711624 (26.29208030), SSIM 0.71321440 (0.77750405)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00217684 (0.00232492), PSNR 26.62173462 (26.35822550), SSIM 0.78489590 (0.77582501)
# Finished training epoch 57
# Validate: MSE 0.00272506 (0.00257272), PSNR 25.64624023 (26.00143062), SSIM 0.71585089 (0.77401411)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00212564 (0.00233547), PSNR 26.72509193 (26.33808058), SSIM 0.78591043 (0.77525491)
# Finished training epoch 58
# Validate: MSE 0.00300634 (0.00279648), PSNR 25.21961212 (25.60342926), SSIM 0.70173776 (0.75278149)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00187185 (0.00233388), PSNR 27.27729416 (26.34515565), SSIM 0.78930104 (0.77556857)
# Finished training epoch 59
# Validate: MSE 0.00289131 (0.00233880), PSNR 25.38904953 (26.37842658), SSIM 0.71361083 (0.77743011)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00231864 (0.00231853), PSNR 26.34766388 (26.37033280), SSIM 0.76448387 (0.77561685)
# Finished training epoch 60
# Validate: MSE 0.00286236 (0.00267011), PSNR 25.43275452 (25.84768254), SSIM 0.71083832 (0.77315185)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00251608 (0.00231214), PSNR 25.99275589 (26.38426128), SSIM 0.77843630 (0.77594617)
# Finished training epoch 61
# Validate: MSE 0.00287505 (0.00237417), PSNR 25.41353798 (26.31159181), SSIM 0.71145999 (0.77597701)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00240742 (0.00231002), PSNR 26.18447876 (26.38578230), SSIM 0.77318394 (0.77572890)
# Finished training epoch 62
# Validate: MSE 0.00274966 (0.00244929), PSNR 25.60720253 (26.19342536), SSIM 0.71149433 (0.77427861)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00231399 (0.00231162), PSNR 26.35639000 (26.38566203), SSIM 0.77253848 (0.77568401)
# Finished training epoch 63
# Validate: MSE 0.00248195 (0.00255029), PSNR 26.05207253 (26.02191525), SSIM 0.71682549 (0.76701060)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00265851 (0.00231238), PSNR 25.75361824 (26.38462674), SSIM 0.75694102 (0.77582355)
# Finished training epoch 64
# Validate: MSE 0.00285713 (0.00238966), PSNR 25.44069481 (26.28504410), SSIM 0.71203244 (0.77425201)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00254376 (0.00229875), PSNR 25.94524384 (26.40866336), SSIM 0.75440294 (0.77589314)
# Finished training epoch 65
# Validate: MSE 0.00283700 (0.00233625), PSNR 25.47140503 (26.37759109), SSIM 0.71102923 (0.76919147)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00226712 (0.00229631), PSNR 26.44525146 (26.41473854), SSIM 0.76482332 (0.77628706)
# Finished training epoch 66
# Validate: MSE 0.00301014 (0.00235672), PSNR 25.21413612 (26.34306711), SSIM 0.70432544 (0.77427325)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00215978 (0.00230989), PSNR 26.65590096 (26.38795684), SSIM 0.80305165 (0.77536841)
# Finished training epoch 67
# Validate: MSE 0.00283908 (0.00251515), PSNR 25.46822739 (26.08903012), SSIM 0.70972431 (0.77348872)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00255838 (0.00228890), PSNR 25.92034531 (26.42603990), SSIM 0.77329457 (0.77629957)
# Finished training epoch 68
# Validate: MSE 0.00276383 (0.00268620), PSNR 25.58488274 (25.81573022), SSIM 0.70944518 (0.77342995)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00221999 (0.00230377), PSNR 26.53647995 (26.39798616), SSIM 0.78961790 (0.77556111)
# Finished training epoch 69
# Validate: MSE 0.00313232 (0.00288138), PSNR 25.04133034 (25.48996889), SSIM 0.71069944 (0.76755778)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00285177 (0.00228578), PSNR 25.44885826 (26.43487583), SSIM 0.76256692 (0.77607827)
# Finished training epoch 70
# Validate: MSE 0.00274245 (0.00240483), PSNR 25.61861229 (26.26350682), SSIM 0.71425033 (0.77203178)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00206359 (0.00228798), PSNR 26.85376740 (26.43074276), SSIM 0.76285154 (0.77585348)
# Finished training epoch 71
# Validate: MSE 0.00261691 (0.00235124), PSNR 25.82210922 (26.34920168), SSIM 0.71483833 (0.77112399)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00199473 (0.00230003), PSNR 27.00115776 (26.40634538), SSIM 0.78724921 (0.77534116)
# Finished training epoch 72
# Validate: MSE 0.00311500 (0.00280758), PSNR 25.06541443 (25.58960002), SSIM 0.70368636 (0.76202624)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00207541 (0.00227422), PSNR 26.82896614 (26.45497927), SSIM 0.77780080 (0.77621771)
# Finished training epoch 73
# Validate: MSE 0.00291020 (0.00247410), PSNR 25.36077690 (26.13303056), SSIM 0.70665735 (0.77134816)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00231482 (0.00226983), PSNR 26.35481834 (26.46546849), SSIM 0.79722309 (0.77643106)
# Finished training epoch 74
# Validate: MSE 0.00255894 (0.00244041), PSNR 25.91939735 (26.21109430), SSIM 0.71919996 (0.77472958)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00234971 (0.00228062), PSNR 26.28985977 (26.44163019), SSIM 0.77746546 (0.77584820)
# Finished training epoch 75
# Validate: MSE 0.00253304 (0.00247187), PSNR 25.96358109 (26.14601175), SSIM 0.71643603 (0.77612141)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00222727 (0.00229321), PSNR 26.52227020 (26.41644129), SSIM 0.78118122 (0.77564434)
# Finished training epoch 76
# Validate: MSE 0.00264614 (0.00240305), PSNR 25.77386665 (26.26860550), SSIM 0.71368992 (0.77465768)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00218583 (0.00226363), PSNR 26.60383415 (26.47719139), SSIM 0.75834262 (0.77655336)
# Finished training epoch 77
# Validate: MSE 0.00289358 (0.00327157), PSNR 25.38563728 (24.97910144), SSIM 0.70978713 (0.76079413)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00267977 (0.00227036), PSNR 25.71902466 (26.46269762), SSIM 0.74316198 (0.77618715)
# Finished training epoch 78
# Validate: MSE 0.00272870 (0.00240943), PSNR 25.64044380 (26.24643470), SSIM 0.71397746 (0.77266938)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00272788 (0.00225541), PSNR 25.64174080 (26.49115617), SSIM 0.75181341 (0.77642094)
# Finished training epoch 79
# Validate: MSE 0.00288881 (0.00248723), PSNR 25.39280128 (26.12063476), SSIM 0.71103984 (0.76589241)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00223611 (0.00226457), PSNR 26.50507164 (26.47604271), SSIM 0.78313446 (0.77611727)
# Finished training epoch 80
# Validate: MSE 0.00282767 (0.00243105), PSNR 25.48571587 (26.21241443), SSIM 0.71749091 (0.77295576)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00259831 (0.00225165), PSNR 25.85309029 (26.49920979), SSIM 0.74806368 (0.77618988)
# Finished training epoch 81
# Validate: MSE 0.00280255 (0.00244874), PSNR 25.52446556 (26.17926273), SSIM 0.70868254 (0.77010641)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00246389 (0.00225617), PSNR 26.08378983 (26.48929487), SSIM 0.77815688 (0.77599787)
# Finished training epoch 82
# Validate: MSE 0.00272211 (0.00241130), PSNR 25.65094948 (26.26069713), SSIM 0.71224141 (0.77200571)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00254083 (0.00225262), PSNR 25.95023727 (26.49562489), SSIM 0.77155519 (0.77627879)
# Finished training epoch 83
# Validate: MSE 0.00278339 (0.00264956), PSNR 25.55426025 (25.85015557), SSIM 0.71832454 (0.76675992)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00253319 (0.00225321), PSNR 25.96331596 (26.49595899), SSIM 0.75951254 (0.77621069)
# Finished training epoch 84
# Validate: MSE 0.00278742 (0.00246920), PSNR 25.54797554 (26.14857095), SSIM 0.71980464 (0.77105860)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00233088 (0.00225709), PSNR 26.32479668 (26.48719191), SSIM 0.76900882 (0.77610985)
# Finished training epoch 85
# Validate: MSE 0.00283951 (0.00249963), PSNR 25.46755791 (26.10562568), SSIM 0.71495992 (0.77548548)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00217064 (0.00224642), PSNR 26.63411331 (26.50874933), SSIM 0.80047673 (0.77648669)
# Finished training epoch 86
# Validate: MSE 0.00272020 (0.00253256), PSNR 25.65399361 (26.05185303), SSIM 0.71161276 (0.77509314)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00274963 (0.00223853), PSNR 25.60725594 (26.52351766), SSIM 0.72858560 (0.77661946)
# Finished training epoch 87
# Validate: MSE 0.00259064 (0.00229684), PSNR 25.86593056 (26.45157372), SSIM 0.71635330 (0.77548685)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00287284 (0.00225292), PSNR 25.41688919 (26.49464469), SSIM 0.76413965 (0.77589873)
# Finished training epoch 88
# Validate: MSE 0.00271358 (0.00229779), PSNR 25.66457176 (26.45120018), SSIM 0.71402389 (0.77349721)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00226529 (0.00225405), PSNR 26.44875526 (26.49335048), SSIM 0.76462847 (0.77582166)
# Finished training epoch 89
# Validate: MSE 0.00259829 (0.00233673), PSNR 25.85311508 (26.38306293), SSIM 0.71335775 (0.77365796)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00331360 (0.00223612), PSNR 24.79699898 (26.52665392), SSIM 0.73962438 (0.77607808)
# Finished training epoch 90
# Validate: MSE 0.00313670 (0.00252747), PSNR 25.03527641 (26.02761294), SSIM 0.70302403 (0.76131567)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00268643 (0.00224484), PSNR 25.70824432 (26.50974473), SSIM 0.75385934 (0.77582777)
# Finished training epoch 91
# Validate: MSE 0.00271321 (0.00237818), PSNR 25.66515732 (26.30983566), SSIM 0.71864271 (0.77632825)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00275439 (0.00222594), PSNR 25.59973907 (26.54679552), SSIM 0.76822752 (0.77667133)
# Finished training epoch 92
# Validate: MSE 0.00250261 (0.00240180), PSNR 26.01607704 (26.24881435), SSIM 0.71860367 (0.77228563)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00196277 (0.00222461), PSNR 27.07131386 (26.55003261), SSIM 0.80478507 (0.77665337)
# Finished training epoch 93
# Validate: MSE 0.00268036 (0.00256271), PSNR 25.71807098 (25.99945399), SSIM 0.71186507 (0.77337163)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00230432 (0.00224544), PSNR 26.37456703 (26.51115161), SSIM 0.76909512 (0.77547853)
# Finished training epoch 94
# Validate: MSE 0.00272608 (0.00239366), PSNR 25.64460564 (26.26342319), SSIM 0.71098763 (0.77420170)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00189402 (0.00222652), PSNR 27.22614670 (26.54888905), SSIM 0.78793728 (0.77613750)
# Finished training epoch 95
# Validate: MSE 0.00266714 (0.00274289), PSNR 25.73953247 (25.73293042), SSIM 0.70647961 (0.76791816)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00265209 (0.00223889), PSNR 25.76411629 (26.52380799), SSIM 0.78561234 (0.77579897)
# Finished training epoch 96
# Validate: MSE 0.00283889 (0.00233693), PSNR 25.46851158 (26.38050228), SSIM 0.71403718 (0.78000043)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00212054 (0.00223840), PSNR 26.73552513 (26.52262953), SSIM 0.77640665 (0.77577668)
# Finished training epoch 97
# Validate: MSE 0.00285702 (0.00235721), PSNR 25.44085884 (26.33817874), SSIM 0.71264780 (0.77160680)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00197187 (0.00222388), PSNR 27.05121231 (26.55163928), SSIM 0.78544199 (0.77622222)
# Finished training epoch 98
# Validate: MSE 0.00265653 (0.00226875), PSNR 25.75685883 (26.50023107), SSIM 0.70765650 (0.77001656)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00203920 (0.00222827), PSNR 26.90539932 (26.54131929), SSIM 0.78278148 (0.77569032)
# Finished training epoch 99
# Validate: MSE 0.00268730 (0.00229613), PSNR 25.70684052 (26.45355519), SSIM 0.71415275 (0.77441857)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00245376 (0.00222202), PSNR 26.10167503 (26.55513642), SSIM 0.77849531 (0.77622119)
# Finished training epoch 100
# Validate: MSE 0.00341129 (0.00300550), PSNR 24.67080688 (25.29945874), SSIM 0.70730019 (0.76678086)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00241794 (0.00222122), PSNR 26.16553688 (26.55425772), SSIM 0.74354619 (0.77580805)
# Finished training epoch 101
# Validate: MSE 0.00275815 (0.00232055), PSNR 25.59382439 (26.40816430), SSIM 0.71491635 (0.77787822)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00239385 (0.00222079), PSNR 26.20903587 (26.55890334), SSIM 0.77659440 (0.77590010)
# Finished training epoch 102
# Validate: MSE 0.00262960 (0.00238144), PSNR 25.80109787 (26.29629894), SSIM 0.71594727 (0.77981485)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00254685 (0.00222552), PSNR 25.93996811 (26.54731805), SSIM 0.76007140 (0.77582968)
# Finished training epoch 103
# Validate: MSE 0.00251375 (0.00272094), PSNR 25.99677086 (25.75556258), SSIM 0.71625715 (0.77004289)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00213340 (0.00220762), PSNR 26.70926666 (26.58157243), SSIM 0.76601624 (0.77632736)
# Finished training epoch 104
# Validate: MSE 0.00255348 (0.00253812), PSNR 25.92867851 (26.04473252), SSIM 0.72203046 (0.77179350)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00191116 (0.00220567), PSNR 27.18703842 (26.58634210), SSIM 0.78413492 (0.77638937)
# Finished training epoch 105
# Validate: MSE 0.00296109 (0.00235091), PSNR 25.28547859 (26.35875198), SSIM 0.70807624 (0.77441821)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00190105 (0.00221247), PSNR 27.21006966 (26.57444019), SSIM 0.79297853 (0.77588383)
# Finished training epoch 106
# Validate: MSE 0.00251224 (0.00227859), PSNR 25.99938965 (26.48075706), SSIM 0.71411908 (0.76935639)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00217125 (0.00222010), PSNR 26.63289261 (26.55920249), SSIM 0.79580694 (0.77561022)
# Finished training epoch 107
# Validate: MSE 0.00266111 (0.00240995), PSNR 25.74936867 (26.23960014), SSIM 0.70643669 (0.76946707)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00276196 (0.00220689), PSNR 25.58782387 (26.58675592), SSIM 0.76432842 (0.77617632)
# Finished training epoch 108
# Validate: MSE 0.00250506 (0.00230537), PSNR 26.01182747 (26.43483272), SSIM 0.72338688 (0.77535837)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00245328 (0.00220088), PSNR 26.10251808 (26.59648307), SSIM 0.76847774 (0.77610098)
# Finished training epoch 109
# Validate: MSE 0.00266633 (0.00234582), PSNR 25.74085426 (26.35651706), SSIM 0.71387172 (0.77170953)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00237453 (0.00220660), PSNR 26.24422455 (26.58760370), SSIM 0.77239060 (0.77577214)
# Finished training epoch 110
# Validate: MSE 0.00262563 (0.00231504), PSNR 25.80766487 (26.42274597), SSIM 0.71342731 (0.77457462)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00265672 (0.00221497), PSNR 25.75654411 (26.56882249), SSIM 0.76450527 (0.77519106)
# Finished training epoch 111
# Validate: MSE 0.00256834 (0.00231428), PSNR 25.90347862 (26.41989625), SSIM 0.71219039 (0.77025666)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00254488 (0.00220562), PSNR 25.94332886 (26.58560135), SSIM 0.75440621 (0.77560726)
# Finished training epoch 112
# Validate: MSE 0.00258178 (0.00225195), PSNR 25.88081551 (26.53473094), SSIM 0.71287155 (0.77572648)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00236028 (0.00219335), PSNR 26.27037048 (26.61349507), SSIM 0.77222937 (0.77630919)
# Finished training epoch 113
# Validate: MSE 0.00266237 (0.00238313), PSNR 25.74732208 (26.30001400), SSIM 0.71570283 (0.77178857)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00225725 (0.00220198), PSNR 26.46421051 (26.59471394), SSIM 0.77785009 (0.77603830)
# Finished training epoch 114
# Validate: MSE 0.00275274 (0.00237681), PSNR 25.60235214 (26.30960546), SSIM 0.70857924 (0.76970724)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00213031 (0.00223008), PSNR 26.71556854 (26.54303490), SSIM 0.77511346 (0.77495438)
# Finished training epoch 115
# Validate: MSE 0.00258261 (0.00233568), PSNR 25.87940788 (26.38198801), SSIM 0.71303022 (0.77330019)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00226588 (0.00218458), PSNR 26.44763374 (26.62733752), SSIM 0.77524000 (0.77639296)
# Finished training epoch 116
# Validate: MSE 0.00251452 (0.00232433), PSNR 25.99544144 (26.40000872), SSIM 0.71984315 (0.76980270)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00207648 (0.00219487), PSNR 26.82671738 (26.61269821), SSIM 0.78277159 (0.77585028)
# Finished training epoch 117
# Validate: MSE 0.00259273 (0.00228458), PSNR 25.86242867 (26.47202722), SSIM 0.71193337 (0.76892078)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00164154 (0.00221030), PSNR 27.84749222 (26.57891480), SSIM 0.79530245 (0.77477218)
# Finished training epoch 118
# Validate: MSE 0.00277703 (0.00244019), PSNR 25.56419373 (26.19771611), SSIM 0.71586162 (0.77354017)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00228136 (0.00219386), PSNR 26.41805649 (26.60928663), SSIM 0.76638520 (0.77596728)
# Finished training epoch 119
# Validate: MSE 0.00275979 (0.00279462), PSNR 25.59124565 (25.68271989), SSIM 0.71179545 (0.76310185)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00225844 (0.00218561), PSNR 26.46190453 (26.62774216), SSIM 0.76711732 (0.77586987)
# Finished training epoch 120
# Validate: MSE 0.00328996 (0.00259954), PSNR 24.82809258 (25.91475078), SSIM 0.70234632 (0.76445027)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00219854 (0.00219272), PSNR 26.57865143 (26.61361448), SSIM 0.77660072 (0.77589888)
# Finished training epoch 121
# Validate: MSE 0.00254441 (0.00252972), PSNR 25.94412422 (26.06174136), SSIM 0.71139657 (0.76406402)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00197864 (0.00218208), PSNR 27.03633690 (26.63517798), SSIM 0.79355800 (0.77626405)
# Finished training epoch 122
# Validate: MSE 0.00267355 (0.00242367), PSNR 25.72912216 (26.23374184), SSIM 0.71754050 (0.77713594)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00236723 (0.00221898), PSNR 26.25760269 (26.56444439), SSIM 0.78969204 (0.77493167)
# Finished training epoch 123
# Validate: MSE 0.00308434 (0.00274860), PSNR 25.10836983 (25.70624048), SSIM 0.71479917 (0.77230780)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00223528 (0.00219682), PSNR 26.50668526 (26.60438000), SSIM 0.75998789 (0.77553653)
# Finished training epoch 124
# Validate: MSE 0.00266450 (0.00239990), PSNR 25.74383736 (26.26414468), SSIM 0.70446813 (0.76576996)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00188190 (0.00216333), PSNR 27.25403404 (26.67135324), SSIM 0.76904577 (0.77637950)
# Finished training epoch 125
# Validate: MSE 0.00266189 (0.00247899), PSNR 25.74810219 (26.13935959), SSIM 0.71239716 (0.77025406)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00241551 (0.00217483), PSNR 26.16990280 (26.64852550), SSIM 0.76801914 (0.77607302)
# Finished training epoch 126
# Validate: MSE 0.00266256 (0.00240030), PSNR 25.74700737 (26.26833877), SSIM 0.71149433 (0.76410975)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00209219 (0.00218992), PSNR 26.79399681 (26.61997962), SSIM 0.77542335 (0.77507755)
# Finished training epoch 127
# Validate: MSE 0.00276594 (0.00227583), PSNR 25.58157730 (26.49272342), SSIM 0.70756292 (0.77507009)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00199611 (0.00219164), PSNR 26.99814606 (26.61467028), SSIM 0.78711379 (0.77553747)
# Finished training epoch 128
# Validate: MSE 0.00258781 (0.00239854), PSNR 25.87067413 (26.25560482), SSIM 0.71521181 (0.76737431)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00248084 (0.00220384), PSNR 26.05401611 (26.59312454), SSIM 0.77105892 (0.77450782)
# Finished training epoch 129
# Validate: MSE 0.00255959 (0.00241165), PSNR 25.91829681 (26.25003917), SSIM 0.71308792 (0.76727441)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00246269 (0.00216159), PSNR 26.08589745 (26.67511714), SSIM 0.75056279 (0.77629344)
# Finished training epoch 130
# Validate: MSE 0.00279707 (0.00232534), PSNR 25.53297424 (26.40062571), SSIM 0.70969212 (0.76955419)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00259481 (0.00217945), PSNR 25.85893822 (26.63759656), SSIM 0.75237745 (0.77564463)
# Finished training epoch 131
# Validate: MSE 0.00272352 (0.00230449), PSNR 25.64868546 (26.43980474), SSIM 0.70967799 (0.77296800)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00272218 (0.00217628), PSNR 25.65082741 (26.64553315), SSIM 0.76608199 (0.77590840)
# Finished training epoch 132
# Validate: MSE 0.00253475 (0.00254210), PSNR 25.96064758 (26.00998972), SSIM 0.70896304 (0.76344044)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00206716 (0.00217429), PSNR 26.84625626 (26.65104420), SSIM 0.78106964 (0.77570718)
# Finished training epoch 133
# Validate: MSE 0.00240964 (0.00238267), PSNR 26.18048477 (26.30408152), SSIM 0.71876597 (0.77379026)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00185299 (0.00217017), PSNR 27.32125664 (26.65671567), SSIM 0.76934421 (0.77563785)
# Finished training epoch 134
# Validate: MSE 0.00283869 (0.00240403), PSNR 25.46882439 (26.26097944), SSIM 0.71692240 (0.77185442)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00204505 (0.00218753), PSNR 26.89296532 (26.62219537), SSIM 0.77159959 (0.77455670)
# Finished training epoch 135
# Validate: MSE 0.00261245 (0.00227129), PSNR 25.82952118 (26.49341234), SSIM 0.71144146 (0.76706824)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00275299 (0.00216137), PSNR 25.60194588 (26.67693079), SSIM 0.75401372 (0.77576224)
# Finished training epoch 136
# Validate: MSE 0.00252211 (0.00233850), PSNR 25.98236084 (26.37849473), SSIM 0.71573311 (0.77097871)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00188892 (0.00216352), PSNR 27.23785591 (26.67028172), SSIM 0.79142582 (0.77552918)
# Finished training epoch 137
# Validate: MSE 0.00284989 (0.00240263), PSNR 25.45172119 (26.26000840), SSIM 0.71102500 (0.77135431)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00203100 (0.00217441), PSNR 26.92289543 (26.65005840), SSIM 0.76673967 (0.77525322)
# ...
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00203463 (0.00215928), PSNR 26.91513634 (26.67906346), SSIM 0.78108162 (0.77601358)
# Finished training epoch 139
# Validate: MSE 0.00280285 (0.00232619), PSNR 25.52400398 (26.40025096), SSIM 0.71292943 (0.77177643)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00217819 (0.00215617), PSNR 26.61904144 (26.68439300), SSIM 0.75758231 (0.77596528)
# Finished training epoch 140
# Validate: MSE 0.00258803 (0.00239631), PSNR 25.87029839 (26.27452585), SSIM 0.71756393 (0.77554849)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00204858 (0.00216482), PSNR 26.88546181 (26.66679325), SSIM 0.75941551 (0.77557817)
# Finished training epoch 141
# Validate: MSE 0.00258034 (0.00230957), PSNR 25.88323021 (26.42175872), SSIM 0.71753895 (0.76846562)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00240988 (0.00216812), PSNR 26.18004036 (26.65944492), SSIM 0.78265077 (0.77512916)
# Finished training epoch 142
# Validate: MSE 0.00274668 (0.00237842), PSNR 25.61192131 (26.30997868), SSIM 0.71337163 (0.76720704)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00205837 (0.00216553), PSNR 26.86476898 (26.66927501), SSIM 0.77743286 (0.77515404)
# Finished training epoch 143
# Validate: MSE 0.00281997 (0.00240234), PSNR 25.49755478 (26.26247045), SSIM 0.71766078 (0.77366574)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00174914 (0.00218071), PSNR 27.57174683 (26.63609839), SSIM 0.78537947 (0.77456544)
# Finished training epoch 144
# Validate: MSE 0.00299849 (0.00263972), PSNR 25.23096848 (25.87012822), SSIM 0.71020991 (0.76766169)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00228928 (0.00215093), PSNR 26.40301132 (26.69656580), SSIM 0.75280571 (0.77574848)
# Finished training epoch 145
# Validate: MSE 0.00265259 (0.00222024), PSNR 25.76329231 (26.59640279), SSIM 0.71378195 (0.77523728)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00212570 (0.00215643), PSNR 26.72498131 (26.68087654), SSIM 0.77876818 (0.77558188)
# Finished training epoch 146
# Validate: MSE 0.00274421 (0.00279877), PSNR 25.61582947 (25.60574749), SSIM 0.70803177 (0.76322896)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00186792 (0.00215815), PSNR 27.28641701 (26.67968732), SSIM 0.78800350 (0.77549696)
# Finished training epoch 147
# Validate: MSE 0.00272099 (0.00228717), PSNR 25.65272141 (26.46861752), SSIM 0.71450984 (0.77532357)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00206448 (0.00215631), PSNR 26.85189438 (26.68369846), SSIM 0.77238542 (0.77571839)
# Finished training epoch 148
# Validate: MSE 0.00266002 (0.00248234), PSNR 25.75114250 (26.13799848), SSIM 0.70584857 (0.76253136)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00218298 (0.00215292), PSNR 26.60950470 (26.69262153), SSIM 0.77924722 (0.77564694)
# Finished training epoch 149
# Validate: MSE 0.00272999 (0.00259607), PSNR 25.63839149 (25.93376720), SSIM 0.71332479 (0.76522196)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00174898 (0.00214900), PSNR 27.57214737 (26.70144275), SSIM 0.79157490 (0.77557294)
# Finished training epoch 150
# Validate: MSE 0.00259508 (0.00237645), PSNR 25.85848618 (26.31528859), SSIM 0.71530569 (0.77032138)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00200651 (0.00215099), PSNR 26.97558022 (26.69695647), SSIM 0.77473527 (0.77572073)
# Finished training epoch 151
# Validate: MSE 0.00257213 (0.00228112), PSNR 25.89706421 (26.48393003), SSIM 0.71351755 (0.77225279)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00233719 (0.00215663), PSNR 26.31305122 (26.68478596), SSIM 0.77501118 (0.77510294)
# Finished training epoch 152
# Validate: MSE 0.00287257 (0.00246014), PSNR 25.41729736 (26.17273691), SSIM 0.70735025 (0.77233085)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00190559 (0.00214694), PSNR 27.19969940 (26.70277093), SSIM 0.76740164 (0.77558814)
# Finished training epoch 153
# Validate: MSE 0.00252419 (0.00230385), PSNR 25.97876930 (26.43427926), SSIM 0.71275467 (0.76641154)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00195968 (0.00215345), PSNR 27.07813644 (26.69340973), SSIM 0.78287190 (0.77511078)
# Finished training epoch 154
# Validate: MSE 0.00253113 (0.00255122), PSNR 25.96684647 (26.03572877), SSIM 0.71383709 (0.76079172)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00296954 (0.00216539), PSNR 25.27310562 (26.66811338), SSIM 0.75878239 (0.77479463)
# Finished training epoch 155
# Validate: MSE 0.00264655 (0.00271890), PSNR 25.77319717 (25.72969608), SSIM 0.70442063 (0.75242435)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00214797 (0.00214975), PSNR 26.67971420 (26.69858910), SSIM 0.76183289 (0.77485571)
# Finished training epoch 156
# Validate: MSE 0.00269303 (0.00247494), PSNR 25.69758797 (26.13928968), SSIM 0.71382642 (0.77073196)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00167366 (0.00215526), PSNR 27.76331711 (26.68784370), SSIM 0.78941494 (0.77483574)
# Finished training epoch 157
# Validate: MSE 0.00249709 (0.00226055), PSNR 26.02565193 (26.51816324), SSIM 0.71396512 (0.77519568)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00172372 (0.00213498), PSNR 27.63532829 (26.72830542), SSIM 0.77425706 (0.77575359)
# Finished training epoch 158
# Validate: MSE 0.00277962 (0.00251980), PSNR 25.56014824 (26.05504597), SSIM 0.70589870 (0.76400092)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00212433 (0.00214571), PSNR 26.72778130 (26.70609140), SSIM 0.78563088 (0.77551825)
# Finished training epoch 159
# Validate: MSE 0.00258477 (0.00223570), PSNR 25.87577248 (26.57026049), SSIM 0.71323186 (0.77495578)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00207648 (0.00213042), PSNR 26.82671165 (26.73770543), SSIM 0.77500975 (0.77591968)
# Finished training epoch 160
# Validate: MSE 0.00261073 (0.00233115), PSNR 25.83238029 (26.37545056), SSIM 0.70346785 (0.76699120)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00236801 (0.00213978), PSNR 26.25616264 (26.71767617), SSIM 0.76666290 (0.77538642)
# Finished training epoch 161
# Validate: MSE 0.00287539 (0.00263723), PSNR 25.41302681 (25.86857749), SSIM 0.70913649 (0.76746711)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00186379 (0.00220698), PSNR 27.29603767 (26.60364265), SSIM 0.81138861 (0.77179497)
# Finished training epoch 162
# Validate: MSE 0.00273156 (0.00232189), PSNR 25.63589096 (26.41072082), SSIM 0.71037334 (0.77171320)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00243990 (0.00212668), PSNR 26.12628555 (26.74698756), SSIM 0.76002151 (0.77578111)
# Finished training epoch 163
# Validate: MSE 0.00288527 (0.00240199), PSNR 25.39813042 (26.26596242), SSIM 0.70527035 (0.77419125)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00221220 (0.00214116), PSNR 26.55176163 (26.71452640), SSIM 0.78057235 (0.77526988)
# Finished training epoch 164
# Validate: MSE 0.00274768 (0.00225174), PSNR 25.61034393 (26.53898363), SSIM 0.71180356 (0.77482422)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00213822 (0.00213325), PSNR 26.69947052 (26.73130963), SSIM 0.76830018 (0.77568300)
# Finished training epoch 165
# Validate: MSE 0.00265466 (0.00225855), PSNR 25.75991058 (26.52300568), SSIM 0.71142387 (0.76877569)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00228230 (0.00213625), PSNR 26.41627312 (26.72536897), SSIM 0.77738011 (0.77524443)
# Finished training epoch 166
# Validate: MSE 0.00267004 (0.00235405), PSNR 25.73481941 (26.35254993), SSIM 0.71443999 (0.77254126)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00230307 (0.00212432), PSNR 26.37692261 (26.75085742), SSIM 0.78366530 (0.77564492)
# Finished training epoch 167
# Validate: MSE 0.00295082 (0.00245957), PSNR 25.30057526 (26.16214935), SSIM 0.71442920 (0.77414336)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00182764 (0.00213292), PSNR 27.38109970 (26.73075007), SSIM 0.79495579 (0.77530614)
# Finished training epoch 168
# Validate: MSE 0.00272185 (0.00230855), PSNR 25.65135384 (26.42706460), SSIM 0.70898992 (0.76579793)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00204025 (0.00213069), PSNR 26.90316963 (26.73690061), SSIM 0.77037305 (0.77541507)
# Finished training epoch 169
# Validate: MSE 0.00289995 (0.00227861), PSNR 25.37609100 (26.48286376), SSIM 0.71094084 (0.77057473)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00197328 (0.00213219), PSNR 27.04810715 (26.73513976), SSIM 0.78473234 (0.77541152)
# Finished training epoch 170
# Validate: MSE 0.00267346 (0.00223722), PSNR 25.72926140 (26.55857312), SSIM 0.71473014 (0.76965163)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00275908 (0.00212847), PSNR 25.59235573 (26.73922962), SSIM 0.77361786 (0.77496367)
# Finished training epoch 171
# Validate: MSE 0.00266356 (0.00230038), PSNR 25.74536896 (26.44801913), SSIM 0.71322370 (0.76675998)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00184174 (0.00213962), PSNR 27.34770966 (26.71681026), SSIM 0.79609287 (0.77479522)
# Finished training epoch 172
# Validate: MSE 0.00263018 (0.00227522), PSNR 25.80014420 (26.48859285), SSIM 0.70561475 (0.76713909)
# Finished validation.
# Starting training epoch 173
# Epoch: 173, MSE 0.00262978 (0.00212486), PSNR 25.80080414 (26.74775896), SSIM 0.74830043 (0.77517602)
# Finished training epoch 173
# Validate: MSE 0.00277173 (0.00237244), PSNR 25.57248306 (26.30512269), SSIM 0.70519638 (0.76828033)
# Finished validation.
# Starting training epoch 174
# Epoch: 174, MSE 0.00280292 (0.00212306), PSNR 25.52389145 (26.75280883), SSIM 0.76644653 (0.77520723)
# Finished training epoch 174
# Validate: MSE 0.00276935 (0.00237529), PSNR 25.57622147 (26.30654991), SSIM 0.70574594 (0.76604428)
# Finished validation.
# Starting training epoch 175
# Epoch: 175, MSE 0.00220153 (0.00214111), PSNR 26.57276154 (26.71364905), SSIM 0.77070987 (0.77475500)
# Finished training epoch 175
# Validate: MSE 0.00258782 (0.00260025), PSNR 25.87066269 (25.95154592), SSIM 0.71274292 (0.76220458)
# Finished validation.
# Starting training epoch 176
# Epoch: 176, MSE 0.00208391 (0.00213592), PSNR 26.81121063 (26.72422107), SSIM 0.77216244 (0.77479639)
# Finished training epoch 176
# Validate: MSE 0.00264637 (0.00230328), PSNR 25.77349663 (26.44031960), SSIM 0.70774728 (0.77175554)
# Finished validation.
# Starting training epoch 177
# Epoch: 177, MSE 0.00219061 (0.00211689), PSNR 26.59434319 (26.76539955), SSIM 0.76910764 (0.77538735)
# Finished training epoch 177
# Validate: MSE 0.00269189 (0.00280508), PSNR 25.69942474 (25.61398099), SSIM 0.71819443 (0.76933306)
# Finished validation.
# Starting training epoch 178
# Epoch: 178, MSE 0.00208105 (0.00213782), PSNR 26.81718063 (26.72283298), SSIM 0.78494948 (0.77459028)
# Finished training epoch 178
# Validate: MSE 0.00283670 (0.00238437), PSNR 25.47186661 (26.28918699), SSIM 0.71191466 (0.76161735)
# Finished validation.
# Starting training epoch 179
# Epoch: 179, MSE 0.00205323 (0.00212825), PSNR 26.87562943 (26.74003578), SSIM 0.77140427 (0.77468140)
# Finished training epoch 179
# Validate: MSE 0.00275277 (0.00253410), PSNR 25.60229301 (26.04858679), SSIM 0.70107681 (0.76139426)
# Finished validation.
# Starting training epoch 180
# Epoch: 180, MSE 0.00291932 (0.00212291), PSNR 25.34718704 (26.75440558), SSIM 0.73602754 (0.77470937)
# Finished training epoch 180
# Validate: MSE 0.00282286 (0.00237623), PSNR 25.49309921 (26.31245551), SSIM 0.70134807 (0.76352429)
# Finished validation.
# Starting training epoch 181
# Epoch: 181, MSE 0.00217152 (0.00213857), PSNR 26.63235664 (26.71989969), SSIM 0.76209247 (0.77434780)
# Finished training epoch 181
# Validate: MSE 0.00277754 (0.00257184), PSNR 25.56338882 (25.96881353), SSIM 0.71663028 (0.76503933)
# Finished validation.
# Starting training epoch 182
# Epoch: 182, MSE 0.00310277 (0.00211523), PSNR 25.08250427 (26.76886502), SSIM 0.77135164 (0.77510127)
# Finished training epoch 182
# Validate: MSE 0.00257863 (0.00225230), PSNR 25.88611412 (26.52870741), SSIM 0.70902109 (0.77042543)
# Finished validation.
# Starting training epoch 183
# Epoch: 183, MSE 0.00237804 (0.00212069), PSNR 26.23781586 (26.75729332), SSIM 0.77891171 (0.77510679)
# Finished training epoch 183
# Validate: MSE 0.00268771 (0.00229510), PSNR 25.70618057 (26.45280059), SSIM 0.72100818 (0.77189879)
# Finished validation.
# Starting training epoch 184
# Epoch: 184, MSE 0.00227655 (0.00210788), PSNR 26.42722130 (26.78127018), SSIM 0.74932027 (0.77510258)
# Finished training epoch 184
# Validate: MSE 0.00276604 (0.00225443), PSNR 25.58140755 (26.53457285), SSIM 0.71472007 (0.77182010)
# Finished validation.
# Starting training epoch 185
# Epoch: 185, MSE 0.00223859 (0.00212127), PSNR 26.50026131 (26.75893432), SSIM 0.78674400 (0.77474378)
# Finished training epoch 185
# Validate: MSE 0.00278842 (0.00277686), PSNR 25.54641914 (25.65908719), SSIM 0.70805764 (0.76580882)
# Finished validation.
# Starting training epoch 186
# Epoch: 186, MSE 0.00245823 (0.00210784), PSNR 26.09377480 (26.78197676), SSIM 0.78900242 (0.77516564)
# Finished training epoch 186
# Validate: MSE 0.00263632 (0.00222703), PSNR 25.79002571 (26.58420779), SSIM 0.71672106 (0.77094202)
# Finished validation.
# Starting training epoch 187
# Epoch: 187, MSE 0.00256697 (0.00211896), PSNR 25.90579414 (26.76256973), SSIM 0.75940669 (0.77486173)
# Finished training epoch 187
# Validate: MSE 0.00295689 (0.00238439), PSNR 25.29164886 (26.29556654), SSIM 0.70097947 (0.76724076)
# Finished validation.
# Starting training epoch 188
# Epoch: 188, MSE 0.00215286 (0.00210678), PSNR 26.66983986 (26.78443319), SSIM 0.77905792 (0.77504951)
# Finished training epoch 188
# Validate: MSE 0.00272486 (0.00248894), PSNR 25.64655304 (26.12380941), SSIM 0.70956087 (0.76204798)
# Finished validation.
# Starting training epoch 189
# Epoch: 189, MSE 0.00180478 (0.00212313), PSNR 27.43576241 (26.75456893), SSIM 0.79345983 (0.77449156)
# Finished training epoch 189
# Validate: MSE 0.00253834 (0.00226242), PSNR 25.95449638 (26.50933161), SSIM 0.70872873 (0.77234640)
# Finished validation.
# Starting training epoch 190
# Epoch: 190, MSE 0.00244895 (0.00210831), PSNR 26.11020660 (26.78435813), SSIM 0.77241182 (0.77484306)
# Finished training epoch 190
# Validate: MSE 0.00270041 (0.00227888), PSNR 25.68570900 (26.48639599), SSIM 0.70995593 (0.77497133)
# Finished validation.
# Starting training epoch 191
# Epoch: 191, MSE 0.00243963 (0.00211182), PSNR 26.12675667 (26.77563294), SSIM 0.76899719 (0.77459827)
# Finished training epoch 191
# Validate: MSE 0.00263545 (0.00250099), PSNR 25.79145813 (26.10802104), SSIM 0.71645492 (0.77345523)
# Finished validation.
# Starting training epoch 192
# Epoch: 192, MSE 0.00264849 (0.00211548), PSNR 25.77001953 (26.76916038), SSIM 0.76188034 (0.77429239)
# Finished training epoch 192
# Validate: MSE 0.00283090 (0.00226770), PSNR 25.48075104 (26.50279301), SSIM 0.70803863 (0.77138984)
# Finished validation.
# Starting training epoch 193
# Epoch: 193, MSE 0.00249424 (0.00209933), PSNR 26.03060913 (26.79868517), SSIM 0.76123255 (0.77505392)
# Finished training epoch 193
# Validate: MSE 0.00295743 (0.00292581), PSNR 25.29085159 (25.41215997), SSIM 0.68833017 (0.74831946)
# Finished validation.
# Starting training epoch 194
# Epoch: 194, MSE 0.00216554 (0.00210355), PSNR 26.64434433 (26.79142197), SSIM 0.76995432 (0.77467493)
# Finished training epoch 194
# Validate: MSE 0.00317503 (0.00312735), PSNR 24.98251534 (25.14312368), SSIM 0.69935578 (0.74900499)
# Finished validation.
# Starting training epoch 195
# Epoch: 195, MSE 0.00215949 (0.00211416), PSNR 26.65649796 (26.76924178), SSIM 0.77357388 (0.77436805)
# Finished training epoch 195
# Validate: MSE 0.00262351 (0.00246371), PSNR 25.81116867 (26.17639335), SSIM 0.71418273 (0.76760882)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00257613 (0.00246471), PSNR 25.89031792 (26.17519067), SSIM 0.70988852 (0.76764289)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
