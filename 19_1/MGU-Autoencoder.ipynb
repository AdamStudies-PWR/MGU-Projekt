# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-403e2c19546c0885" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-403e2c19546c0885");
#           const url = new URL("/", window.location);
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .5

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(self.convtrans3(x), scale_factor=scale_factor)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 16, 16]           2,306
# ================================================================
# Total params: 2,662,274
# Trainable params: 2,662,274
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.75
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.91
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.05675825 (1.00301149), PSNR 12.45970917 (6.74976383), SSIM 0.09060211 (0.03589147)
# Finished training epoch 0
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 12 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 71 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 154 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 24 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 9 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 49 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 213 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 91 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 6 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.05483253 (0.05225776), PSNR 12.60961723 (13.08420031), SSIM 0.09811215 (0.11079417)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.02652887 (0.03688454), PSNR 15.76281166 (14.43590253), SSIM 0.23030713 (0.21386879)
# Finished training epoch 1
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 10 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 45 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 150 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 8 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 84 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.02643820 (0.02509392), PSNR 15.77768040 (16.31297426), SSIM 0.25158435 (0.30609975)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.01379932 (0.01880001), PSNR 18.60142326 (17.32543476), SSIM 0.43525547 (0.36884350)
# Finished training epoch 2
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 11 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 47 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01649961 (0.01397742), PSNR 17.82526398 (18.80790520), SSIM 0.33753020 (0.42684442)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00791664 (0.01072990), PSNR 21.01459312 (19.74350535), SSIM 0.50914496 (0.46477444)
# Finished training epoch 3
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 64 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 34 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00863572 (0.00812210), PSNR 20.63701630 (21.09883583), SSIM 0.41971225 (0.50821948)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00605220 (0.00679374), PSNR 22.18087006 (21.71056166), SSIM 0.57183427 (0.53613522)
# Finished training epoch 4
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 26 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00620105 (0.00542437), PSNR 22.07534599 (22.77328869), SSIM 0.48311591 (0.57481653)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00347606 (0.00479096), PSNR 24.58913040 (23.21969713), SSIM 0.62304890 (0.59582549)
# Finished training epoch 5
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 19 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00491850 (0.00423600), PSNR 23.08166695 (23.81183794), SSIM 0.52991074 (0.61844974)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00347048 (0.00377302), PSNR 24.59609985 (24.24992032), SSIM 0.68088698 (0.64471634)
# Finished training epoch 6
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 15 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00394245 (0.00345360), PSNR 24.04233742 (24.68487995), SSIM 0.58294851 (0.66440150)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00266156 (0.00325686), PSNR 25.74864197 (24.89071874), SSIM 0.69991845 (0.68103303)
# Finished training epoch 7
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 5 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00361849 (0.00306340), PSNR 24.41472435 (25.19629222), SSIM 0.61546385 (0.69841643)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00292058 (0.00299408), PSNR 25.34531021 (25.25815550), SSIM 0.71094257 (0.70732131)
# Finished training epoch 8
# Validate: MSE 0.00338600 (0.00291742), PSNR 24.70313263 (25.41549366), SSIM 0.64021641 (0.71733366)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00310421 (0.00287091), PSNR 25.08049583 (25.44062768), SSIM 0.72396213 (0.72664850)
# Finished training epoch 9
# Validate: MSE 0.00323184 (0.00282706), PSNR 24.90550613 (25.55651500), SSIM 0.66317689 (0.73470078)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00216200 (0.00282097), PSNR 26.65143967 (25.51439193), SSIM 0.75441432 (0.74107134)
# Finished training epoch 10
# Validate: MSE 0.00329384 (0.00276413), PSNR 24.82297325 (25.65084862), SSIM 0.67692071 (0.74869692)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00269127 (0.00279745), PSNR 25.70042610 (25.55504702), SSIM 0.75807172 (0.75115988)
# Finished training epoch 11
# Validate: MSE 0.00328798 (0.00280525), PSNR 24.83070374 (25.58396589), SSIM 0.68148100 (0.75207358)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00246841 (0.00282905), PSNR 26.07582855 (25.50795905), SSIM 0.78112143 (0.75597031)
# Finished training epoch 12
# Validate: MSE 0.00329204 (0.00290729), PSNR 24.82534790 (25.43294495), SSIM 0.67863309 (0.75284185)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00237848 (0.00282541), PSNR 26.23701286 (25.51040163), SSIM 0.78169334 (0.75953077)
# Finished training epoch 13
# Validate: MSE 0.00331515 (0.00285252), PSNR 24.79496765 (25.51011726), SSIM 0.68310815 (0.75849325)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00306671 (0.00286348), PSNR 25.13327217 (25.45863966), SSIM 0.75892144 (0.75973624)
# Finished training epoch 14
# Validate: MSE 0.00329407 (0.00279662), PSNR 24.82267761 (25.59651577), SSIM 0.69387746 (0.76494191)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00252083 (0.00278037), PSNR 25.98455811 (25.58164542), SSIM 0.75683701 (0.76348333)
# Finished training epoch 15
# Validate: MSE 0.00320702 (0.00277776), PSNR 24.93897820 (25.62553791), SSIM 0.69268954 (0.76433505)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00237624 (0.00277840), PSNR 26.24108696 (25.58584836), SSIM 0.77152032 (0.76305090)
# Finished training epoch 16
# Validate: MSE 0.00314167 (0.00270592), PSNR 25.02838707 (25.74195511), SSIM 0.69572973 (0.76548106)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00245066 (0.00276999), PSNR 26.10717201 (25.59958545), SSIM 0.78699660 (0.76226120)
# Finished training epoch 17
# Validate: MSE 0.00318186 (0.00276800), PSNR 24.97318649 (25.63969096), SSIM 0.68782759 (0.76088583)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00294479 (0.00276829), PSNR 25.30945396 (25.60596094), SSIM 0.76930046 (0.76168378)
# Finished training epoch 18
# Validate: MSE 0.00303678 (0.00262142), PSNR 25.17586327 (25.88251754), SSIM 0.69773948 (0.76619608)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00277013 (0.00272940), PSNR 25.57500076 (25.65971361), SSIM 0.74311364 (0.76229457)
# Finished training epoch 19
# Validate: MSE 0.00306507 (0.00278821), PSNR 25.13559341 (25.62613560), SSIM 0.69045532 (0.76317359)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00226881 (0.00273387), PSNR 26.44200897 (25.65689025), SSIM 0.77588713 (0.76102813)
# Finished training epoch 20
# Validate: MSE 0.00321970 (0.00278825), PSNR 24.92184067 (25.60409575), SSIM 0.69134271 (0.75803608)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00281841 (0.00271664), PSNR 25.49996376 (25.68537312), SSIM 0.75396538 (0.76075050)
# Finished training epoch 21
# Validate: MSE 0.00296798 (0.00259766), PSNR 25.27538681 (25.91659623), SSIM 0.69595176 (0.76338313)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00309292 (0.00265516), PSNR 25.09631729 (25.78077930), SSIM 0.74200702 (0.76203985)
# Finished training epoch 22
# Validate: MSE 0.00329388 (0.00294930), PSNR 24.82292366 (25.35368311), SSIM 0.68413055 (0.74885287)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00266385 (0.00265964), PSNR 25.74490166 (25.77498621), SSIM 0.76849163 (0.76173505)
# Finished training epoch 23
# Validate: MSE 0.00304196 (0.00272159), PSNR 25.16847038 (25.71979328), SSIM 0.69703591 (0.75735739)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00256892 (0.00263920), PSNR 25.90248871 (25.81057987), SSIM 0.77890891 (0.76257557)
# Finished training epoch 24
# Validate: MSE 0.00308960 (0.00262355), PSNR 25.10097122 (25.86900989), SSIM 0.69452626 (0.76238727)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00228305 (0.00260290), PSNR 26.41484642 (25.86950016), SSIM 0.76585877 (0.76410590)
# Finished training epoch 25
# Validate: MSE 0.00296873 (0.00259773), PSNR 25.27428818 (25.92606953), SSIM 0.69764036 (0.76663315)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00229257 (0.00256963), PSNR 26.39676857 (25.92418739), SSIM 0.76945221 (0.76541248)
# Finished training epoch 26
# Validate: MSE 0.00325754 (0.00326454), PSNR 24.87110329 (24.94670385), SSIM 0.69462776 (0.74613428)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00258545 (0.00255902), PSNR 25.87464523 (25.94044725), SSIM 0.76163399 (0.76607130)
# Finished training epoch 27
# Validate: MSE 0.00304257 (0.00256672), PSNR 25.16758728 (25.96657000), SSIM 0.69500172 (0.76691987)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00276418 (0.00253853), PSNR 25.58433151 (25.97673523), SSIM 0.75183636 (0.76728866)
# Finished training epoch 28
# Validate: MSE 0.00284061 (0.00273704), PSNR 25.46588135 (25.71589250), SSIM 0.69983929 (0.76629458)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00289270 (0.00252372), PSNR 25.38696289 (25.99819382), SSIM 0.75475490 (0.76811649)
# Finished training epoch 29
# Validate: MSE 0.00318006 (0.00279758), PSNR 24.97565079 (25.60962137), SSIM 0.69670850 (0.76074633)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00260681 (0.00248902), PSNR 25.83890724 (26.05918706), SSIM 0.77015406 (0.76910456)
# Finished training epoch 30
# Validate: MSE 0.00284257 (0.00305442), PSNR 25.46288872 (25.27140144), SSIM 0.69958031 (0.75808597)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00266691 (0.00248305), PSNR 25.73990822 (26.06910823), SSIM 0.76263034 (0.76980275)
# Finished training epoch 31
# Validate: MSE 0.00296948 (0.00244434), PSNR 25.27319908 (26.18310018), SSIM 0.70161164 (0.77075409)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00208191 (0.00245197), PSNR 26.81538582 (26.12711145), SSIM 0.77887887 (0.77066622)
# Finished training epoch 32
# Validate: MSE 0.00334592 (0.00272287), PSNR 24.75484085 (25.72488084), SSIM 0.70125341 (0.77129878)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00236784 (0.00244447), PSNR 26.25647736 (26.13781286), SSIM 0.77558100 (0.77120112)
# Finished training epoch 33
# Validate: MSE 0.00277241 (0.00281699), PSNR 25.57143211 (25.62571485), SSIM 0.70733738 (0.76804081)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00241976 (0.00244491), PSNR 26.16227150 (26.14097404), SSIM 0.77501947 (0.77108557)
# Finished training epoch 34
# Validate: MSE 0.00300475 (0.00254512), PSNR 25.22191048 (26.01043711), SSIM 0.70337009 (0.77022576)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00306753 (0.00242895), PSNR 25.13210297 (26.16886377), SSIM 0.75250226 (0.77160802)
# Finished training epoch 35
# Validate: MSE 0.00303495 (0.00245370), PSNR 25.17848015 (26.16908540), SSIM 0.70144773 (0.77271491)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00209518 (0.00241795), PSNR 26.78779221 (26.19024330), SSIM 0.76926225 (0.77179007)
# Finished training epoch 36
# Validate: MSE 0.00275690 (0.00248460), PSNR 25.59579086 (26.10923332), SSIM 0.70620477 (0.77079720)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00209870 (0.00242694), PSNR 26.78050041 (26.17182229), SSIM 0.77487433 (0.77144029)
# Finished training epoch 37
# Validate: MSE 0.00294451 (0.00255697), PSNR 25.30986977 (25.98901967), SSIM 0.70500422 (0.77157472)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00282857 (0.00241859), PSNR 25.48432541 (26.18962403), SSIM 0.72720915 (0.77122363)
# Finished training epoch 38
# Validate: MSE 0.00264978 (0.00241442), PSNR 25.76789474 (26.22721105), SSIM 0.70210218 (0.76376586)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00246529 (0.00240192), PSNR 26.08131981 (26.21715522), SSIM 0.78466046 (0.77082598)
# Finished training epoch 39
# Validate: MSE 0.00324685 (0.00316224), PSNR 24.88537788 (25.08667813), SSIM 0.69731665 (0.75420414)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00214257 (0.00240515), PSNR 26.69065666 (26.20792957), SSIM 0.76975441 (0.77165527)
# Finished training epoch 40
# Validate: MSE 0.00276210 (0.00240247), PSNR 25.58760834 (26.25829703), SSIM 0.70831436 (0.77330469)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00219132 (0.00239292), PSNR 26.59293365 (26.23370054), SSIM 0.78868884 (0.77188758)
# Finished training epoch 41
# Validate: MSE 0.00310678 (0.00315750), PSNR 25.07689667 (25.09931049), SSIM 0.70207882 (0.75453898)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00269787 (0.00240057), PSNR 25.68978882 (26.21919345), SSIM 0.76270586 (0.77137331)
# Finished training epoch 42
# Validate: MSE 0.00292597 (0.00246916), PSNR 25.33729362 (26.14732226), SSIM 0.70894241 (0.77441664)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00239287 (0.00239608), PSNR 26.21080017 (26.22866222), SSIM 0.75714630 (0.77168060)
# Finished training epoch 43
# Validate: MSE 0.00273584 (0.00254872), PSNR 25.62908554 (26.01157209), SSIM 0.71020085 (0.77113688)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00264896 (0.00238133), PSNR 25.76925087 (26.25472762), SSIM 0.78773355 (0.77233422)
# Finished training epoch 44
# Validate: MSE 0.00328681 (0.00267968), PSNR 24.83224678 (25.79249273), SSIM 0.70732701 (0.76843629)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00296270 (0.00240268), PSNR 25.28312302 (26.21498492), SSIM 0.76132309 (0.77072700)
# Finished training epoch 45
# Validate: MSE 0.00281300 (0.00243829), PSNR 25.50830269 (26.19672395), SSIM 0.70626402 (0.76694186)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00223895 (0.00238677), PSNR 26.49954987 (26.24480373), SSIM 0.78331184 (0.77195400)
# Finished training epoch 46
# Validate: MSE 0.00271216 (0.00245300), PSNR 25.66683960 (26.16057075), SSIM 0.70338821 (0.76576005)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00291967 (0.00236907), PSNR 25.34666252 (26.27819984), SSIM 0.74009717 (0.77240276)
# Finished training epoch 47
# Validate: MSE 0.00253377 (0.00249383), PSNR 25.96232414 (26.09325158), SSIM 0.70905399 (0.76788815)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00255453 (0.00236907), PSNR 25.92688370 (26.27817564), SSIM 0.75684029 (0.77203034)
# Finished training epoch 48
# Validate: MSE 0.00289063 (0.00238740), PSNR 25.39007950 (26.28535184), SSIM 0.70536977 (0.77341119)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00241317 (0.00238470), PSNR 26.17411232 (26.24840292), SSIM 0.77701724 (0.77200138)
# Finished training epoch 49
# Validate: MSE 0.00298577 (0.00248223), PSNR 25.24943924 (26.12434317), SSIM 0.70951760 (0.77189451)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00327897 (0.00236830), PSNR 24.84262848 (26.27824235), SSIM 0.76415986 (0.77215810)
# Finished training epoch 50
# Validate: MSE 0.00272863 (0.00249735), PSNR 25.64054871 (26.08999573), SSIM 0.71093726 (0.76620743)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00151179 (0.00235064), PSNR 28.20508003 (26.31332624), SSIM 0.81259078 (0.77310589)
# Finished training epoch 51
# Validate: MSE 0.00281899 (0.00240837), PSNR 25.49907112 (26.25150096), SSIM 0.71231622 (0.77578591)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00260363 (0.00235475), PSNR 25.84420013 (26.30546319), SSIM 0.74623054 (0.77251024)
# Finished training epoch 52
# Validate: MSE 0.00306349 (0.00270093), PSNR 25.13783646 (25.75289312), SSIM 0.70063305 (0.76077043)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00233692 (0.00234274), PSNR 26.31357002 (26.32692291), SSIM 0.77687597 (0.77298160)
# Finished training epoch 53
# Validate: MSE 0.00287843 (0.00234824), PSNR 25.40844536 (26.35763242), SSIM 0.70834982 (0.77396349)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00272557 (0.00233930), PSNR 25.64542007 (26.33435261), SSIM 0.75950670 (0.77272518)
# Finished training epoch 54
# Validate: MSE 0.00277891 (0.00265244), PSNR 25.56124878 (25.83189534), SSIM 0.70610660 (0.76002149)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00202490 (0.00234460), PSNR 26.93595505 (26.32809219), SSIM 0.78336799 (0.77273986)
# Finished training epoch 55
# Validate: MSE 0.00265225 (0.00239810), PSNR 25.76385498 (26.25621780), SSIM 0.70658123 (0.76946092)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00226487 (0.00234074), PSNR 26.44957161 (26.33065998), SSIM 0.77593535 (0.77243741)
# Finished training epoch 56
# Validate: MSE 0.00261908 (0.00239839), PSNR 25.81850624 (26.26283273), SSIM 0.71345913 (0.76875161)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00199465 (0.00233303), PSNR 27.00132751 (26.34341006), SSIM 0.76433969 (0.77279057)
# Finished training epoch 57
# Validate: MSE 0.00292151 (0.00234087), PSNR 25.34393120 (26.37556079), SSIM 0.71300507 (0.77502388)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00275936 (0.00233935), PSNR 25.59192085 (26.33145451), SSIM 0.75731027 (0.77244999)
# Finished training epoch 58
# Validate: MSE 0.00278955 (0.00264951), PSNR 25.54465485 (25.84374467), SSIM 0.70807356 (0.76488596)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00252543 (0.00232631), PSNR 25.97664642 (26.35627618), SSIM 0.77158260 (0.77277012)
# Finished training epoch 59
# Validate: MSE 0.00255018 (0.00253640), PSNR 25.93428993 (26.04832021), SSIM 0.71555424 (0.77038241)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00232311 (0.00232372), PSNR 26.33930969 (26.36398532), SSIM 0.77450055 (0.77282964)
# Finished training epoch 60
# Validate: MSE 0.00266051 (0.00243357), PSNR 25.75035667 (26.20577970), SSIM 0.71051419 (0.77545162)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00264093 (0.00232621), PSNR 25.78242493 (26.35512402), SSIM 0.75815326 (0.77273660)
# Finished training epoch 61
# Validate: MSE 0.00256718 (0.00235136), PSNR 25.90543365 (26.35193883), SSIM 0.72172993 (0.77672427)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00256012 (0.00230677), PSNR 25.91740036 (26.39368933), SSIM 0.78807127 (0.77332939)
# Finished training epoch 62
# Validate: MSE 0.00264465 (0.00252172), PSNR 25.77631569 (26.05443315), SSIM 0.71576685 (0.77447066)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00207325 (0.00231349), PSNR 26.83348083 (26.37926351), SSIM 0.77790344 (0.77290681)
# Finished training epoch 63
# Validate: MSE 0.00281425 (0.00231268), PSNR 25.50637627 (26.42356882), SSIM 0.71075565 (0.77390438)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00227421 (0.00232577), PSNR 26.43169022 (26.35667734), SSIM 0.75847381 (0.77217434)
# Finished training epoch 64
# Validate: MSE 0.00266513 (0.00229694), PSNR 25.74282074 (26.44770975), SSIM 0.71783477 (0.77327998)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00210248 (0.00229797), PSNR 26.77268219 (26.40983450), SSIM 0.76673150 (0.77358197)
# Finished training epoch 65
# Validate: MSE 0.00259381 (0.00231851), PSNR 25.86062622 (26.40589673), SSIM 0.71163911 (0.77156512)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00225678 (0.00230388), PSNR 26.46510124 (26.39890791), SSIM 0.77829772 (0.77340065)
# Finished training epoch 66
# Validate: MSE 0.00274399 (0.00231988), PSNR 25.61617279 (26.40611693), SSIM 0.69996560 (0.76646006)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00217003 (0.00230155), PSNR 26.63534546 (26.40065718), SSIM 0.77053821 (0.77266041)
# Finished training epoch 67
# Validate: MSE 0.00274575 (0.00228862), PSNR 25.61339378 (26.46991375), SSIM 0.71503603 (0.77678566)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00254398 (0.00229974), PSNR 25.94485855 (26.40662061), SSIM 0.76680851 (0.77313820)
# Finished training epoch 68
# Validate: MSE 0.00257482 (0.00246991), PSNR 25.89253235 (26.14188271), SSIM 0.70697486 (0.76959016)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00277970 (0.00229146), PSNR 25.56001091 (26.42380879), SSIM 0.75622970 (0.77336237)
# Finished training epoch 69
# Validate: MSE 0.00268577 (0.00241185), PSNR 25.70931435 (26.22360109), SSIM 0.70400232 (0.76762572)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00264675 (0.00228140), PSNR 25.77287102 (26.43967831), SSIM 0.76105064 (0.77349316)
# Finished training epoch 70
# Validate: MSE 0.00262487 (0.00233661), PSNR 25.80892372 (26.37624176), SSIM 0.70936513 (0.77279798)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00277325 (0.00229668), PSNR 25.57011604 (26.41212332), SSIM 0.77502739 (0.77309011)
# Finished training epoch 71
# Validate: MSE 0.00276185 (0.00255265), PSNR 25.58799934 (25.98386939), SSIM 0.70561939 (0.76547378)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00232295 (0.00227776), PSNR 26.33959770 (26.44712233), SSIM 0.77128112 (0.77325818)
# Finished training epoch 72
# Validate: MSE 0.00268032 (0.00225982), PSNR 25.71813965 (26.51856077), SSIM 0.71277118 (0.77535800)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00259116 (0.00228172), PSNR 25.86506653 (26.44003354), SSIM 0.74985260 (0.77327777)
# Finished training epoch 73
# Validate: MSE 0.00306468 (0.00268229), PSNR 25.13615227 (25.79020388), SSIM 0.68985552 (0.76099306)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00180449 (0.00226786), PSNR 27.43644905 (26.46603756), SSIM 0.78726310 (0.77373905)
# Finished training epoch 74
# Validate: MSE 0.00266116 (0.00233089), PSNR 25.74928665 (26.37924676), SSIM 0.70483720 (0.76941818)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00226827 (0.00227197), PSNR 26.44304466 (26.45955271), SSIM 0.76558149 (0.77350837)
# Finished training epoch 75
# Validate: MSE 0.00267839 (0.00246637), PSNR 25.72126198 (26.15537992), SSIM 0.71337163 (0.77045298)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00233309 (0.00226530), PSNR 26.32069206 (26.47084902), SSIM 0.77867854 (0.77299054)
# Finished training epoch 76
# Validate: MSE 0.00278087 (0.00242371), PSNR 25.55818939 (26.21720677), SSIM 0.70416045 (0.76192584)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00202923 (0.00227656), PSNR 26.92669106 (26.44983890), SSIM 0.78777939 (0.77308433)
# Finished training epoch 77
# Validate: MSE 0.00276501 (0.00240529), PSNR 25.58302498 (26.25715393), SSIM 0.71655411 (0.77489179)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00215951 (0.00225721), PSNR 26.65644264 (26.48718271), SSIM 0.77613890 (0.77368183)
# Finished training epoch 78
# Validate: MSE 0.00260875 (0.00227218), PSNR 25.83567810 (26.49437891), SSIM 0.71462452 (0.77488106)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00210643 (0.00227370), PSNR 26.76453781 (26.45384737), SSIM 0.76782572 (0.77245623)
# Finished training epoch 79
# Validate: MSE 0.00302420 (0.00244320), PSNR 25.19390106 (26.19529926), SSIM 0.70868921 (0.77180848)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00257914 (0.00226043), PSNR 25.88524818 (26.47978016), SSIM 0.79110050 (0.77346837)
# Finished training epoch 80
# Validate: MSE 0.00281957 (0.00228381), PSNR 25.49817467 (26.47431578), SSIM 0.71377975 (0.77431042)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00188331 (0.00225205), PSNR 27.25078011 (26.49589893), SSIM 0.77821696 (0.77319814)
# Finished training epoch 81
# Validate: MSE 0.00276927 (0.00235549), PSNR 25.57634163 (26.33098411), SSIM 0.70559204 (0.76891211)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00226064 (0.00226686), PSNR 26.45767784 (26.47094657), SSIM 0.77402580 (0.77287419)
# Finished training epoch 82
# Validate: MSE 0.00267516 (0.00235566), PSNR 25.72650146 (26.34178223), SSIM 0.70884097 (0.76724998)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00213877 (0.00225413), PSNR 26.69834900 (26.49024337), SSIM 0.76157194 (0.77277370)
# Finished training epoch 83
# Validate: MSE 0.00286395 (0.00248073), PSNR 25.43033981 (26.12231589), SSIM 0.70248199 (0.76352584)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00237585 (0.00224458), PSNR 26.24181175 (26.50933677), SSIM 0.77354372 (0.77382577)
# Finished training epoch 84
# Validate: MSE 0.00278835 (0.00245307), PSNR 25.54653168 (26.14943446), SSIM 0.70690566 (0.77162759)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00172520 (0.00225065), PSNR 27.63159370 (26.50219415), SSIM 0.78972572 (0.77348045)
# Finished training epoch 85
# Validate: MSE 0.00256412 (0.00226403), PSNR 25.91062164 (26.50830831), SSIM 0.71363401 (0.77016938)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00226092 (0.00225538), PSNR 26.45713806 (26.49008236), SSIM 0.78409165 (0.77254489)
# Finished training epoch 86
# Validate: MSE 0.00261805 (0.00230470), PSNR 25.82021713 (26.43218989), SSIM 0.71986079 (0.77291373)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00235895 (0.00224055), PSNR 26.27280617 (26.52067242), SSIM 0.78035814 (0.77343799)
# Finished training epoch 87
# Validate: MSE 0.00259989 (0.00229093), PSNR 25.85044670 (26.45825771), SSIM 0.71288645 (0.77336783)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00198245 (0.00226858), PSNR 27.02797318 (26.46580241), SSIM 0.79252118 (0.77174018)
# Finished training epoch 88
# Validate: MSE 0.00272621 (0.00229331), PSNR 25.64439964 (26.45919786), SSIM 0.71089679 (0.77429605)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00228020 (0.00224478), PSNR 26.42027855 (26.50985872), SSIM 0.76026833 (0.77332124)
# Finished training epoch 89
# Validate: MSE 0.00278401 (0.00227488), PSNR 25.55329514 (26.48840637), SSIM 0.70744687 (0.77011823)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00214654 (0.00224388), PSNR 26.68260765 (26.51151228), SSIM 0.77291608 (0.77293744)
# Finished training epoch 90
# Validate: MSE 0.00254814 (0.00234555), PSNR 25.93775940 (26.35214531), SSIM 0.70894408 (0.76408767)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00234898 (0.00224156), PSNR 26.29121208 (26.51861803), SSIM 0.77074200 (0.77312427)
# Finished training epoch 91
# Validate: MSE 0.00259898 (0.00231683), PSNR 25.85196304 (26.41074478), SSIM 0.70726478 (0.76746717)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00215306 (0.00223654), PSNR 26.66943932 (26.52850696), SSIM 0.76276052 (0.77307729)
# Finished training epoch 92
# Validate: MSE 0.00267612 (0.00226755), PSNR 25.72494698 (26.50144453), SSIM 0.70791155 (0.76738699)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00216555 (0.00225065), PSNR 26.64432526 (26.50053785), SSIM 0.78606987 (0.77187976)
# Finished training epoch 93
# Validate: MSE 0.00277512 (0.00239230), PSNR 25.56718445 (26.27872319), SSIM 0.71095920 (0.77311653)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00210674 (0.00222351), PSNR 26.76387978 (26.55114998), SSIM 0.77765709 (0.77357833)
# Finished training epoch 94
# Validate: MSE 0.00264867 (0.00230560), PSNR 25.76971626 (26.43012073), SSIM 0.71087533 (0.77574367)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00221229 (0.00223422), PSNR 26.55157661 (26.53160106), SSIM 0.77394074 (0.77260420)
# Finished training epoch 95
# Validate: MSE 0.00289205 (0.00231489), PSNR 25.38793373 (26.42316581), SSIM 0.71120155 (0.77408208)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00241927 (0.00224640), PSNR 26.16315842 (26.50772827), SSIM 0.77889752 (0.77288717)
# Finished training epoch 96
# Validate: MSE 0.00275665 (0.00230401), PSNR 25.59618187 (26.43520265), SSIM 0.70554125 (0.76763530)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00191366 (0.00221880), PSNR 27.18135834 (26.56325071), SSIM 0.76533496 (0.77310578)
# Finished training epoch 97
# Validate: MSE 0.00249736 (0.00230403), PSNR 26.02517891 (26.43149627), SSIM 0.70929170 (0.76967903)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00245353 (0.00222658), PSNR 26.10209084 (26.54602585), SSIM 0.76282179 (0.77296989)
# Finished training epoch 98
# Validate: MSE 0.00275845 (0.00233269), PSNR 25.59334946 (26.38448173), SSIM 0.70867395 (0.76542351)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00291647 (0.00222799), PSNR 25.35142899 (26.54163703), SSIM 0.74186009 (0.77273536)
# Finished training epoch 99
# Validate: MSE 0.00284717 (0.00234745), PSNR 25.45586205 (26.35658797), SSIM 0.70455039 (0.76915674)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00190735 (0.00222088), PSNR 27.19570541 (26.55793535), SSIM 0.80439556 (0.77295436)
# Finished training epoch 100
# Validate: MSE 0.00278541 (0.00228254), PSNR 25.55111313 (26.47845856), SSIM 0.70910442 (0.77424890)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00215578 (0.00221494), PSNR 26.66394997 (26.56757513), SSIM 0.75238806 (0.77305402)
# Finished training epoch 101
# Validate: MSE 0.00258284 (0.00225178), PSNR 25.87902069 (26.53385199), SSIM 0.70998585 (0.76920310)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00205070 (0.00222700), PSNR 26.88097572 (26.54356272), SSIM 0.77272189 (0.77224440)
# Finished training epoch 102
# Validate: MSE 0.00256622 (0.00242618), PSNR 25.90705681 (26.21744934), SSIM 0.71811283 (0.77157454)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00212846 (0.00221839), PSNR 26.71934891 (26.56385266), SSIM 0.78976858 (0.77224157)
# Finished training epoch 103
# Validate: MSE 0.00245646 (0.00242176), PSNR 26.09690475 (26.21674472), SSIM 0.71860838 (0.77075519)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00315532 (0.00226011), PSNR 25.00956726 (26.48714430), SSIM 0.75208318 (0.77003545)
# Finished training epoch 104
# Validate: MSE 0.00272418 (0.00231137), PSNR 25.64764404 (26.41537300), SSIM 0.70995855 (0.76473158)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00170981 (0.00221832), PSNR 27.67052078 (26.56202762), SSIM 0.79166687 (0.77264405)
# Finished training epoch 105
# Validate: MSE 0.00286361 (0.00247956), PSNR 25.43086243 (26.12616401), SSIM 0.70828933 (0.76880166)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00233321 (0.00221383), PSNR 26.32046700 (26.56885830), SSIM 0.77246273 (0.77302285)
# Finished training epoch 106
# Validate: MSE 0.00282280 (0.00267593), PSNR 25.49319458 (25.79878796), SSIM 0.70892316 (0.76402457)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00170978 (0.00220469), PSNR 27.67060280 (26.58874469), SSIM 0.79461563 (0.77364157)
# Finished training epoch 107
# Validate: MSE 0.00271930 (0.00258018), PSNR 25.65543365 (25.96529911), SSIM 0.71276480 (0.77305643)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00202805 (0.00221519), PSNR 26.92922211 (26.56904080), SSIM 0.79058760 (0.77289497)
# Finished training epoch 108
# Validate: MSE 0.00283077 (0.00234353), PSNR 25.48095512 (26.36806264), SSIM 0.71006554 (0.77122342)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00237105 (0.00222299), PSNR 26.25059319 (26.55445548), SSIM 0.77328348 (0.77205149)
# Finished training epoch 109
# Validate: MSE 0.00272111 (0.00225447), PSNR 25.65253639 (26.53752138), SSIM 0.70812625 (0.77248971)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00276146 (0.00221102), PSNR 25.58860779 (26.57823112), SSIM 0.75909632 (0.77263844)
# Finished training epoch 110
# Validate: MSE 0.00272556 (0.00242521), PSNR 25.64544868 (26.19967703), SSIM 0.70523828 (0.76262399)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00240752 (0.00220997), PSNR 26.18430519 (26.57877812), SSIM 0.78503382 (0.77281577)
# Finished training epoch 111
# Validate: MSE 0.00267540 (0.00225015), PSNR 25.72611237 (26.53618114), SSIM 0.71009183 (0.77376113)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00241563 (0.00220015), PSNR 26.16969681 (26.59686852), SSIM 0.76746416 (0.77303055)
# Finished training epoch 112
# Validate: MSE 0.00268401 (0.00224648), PSNR 25.71216393 (26.54469828), SSIM 0.70991069 (0.76993063)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00198550 (0.00220831), PSNR 27.02129936 (26.57900474), SSIM 0.80175650 (0.77255970)
# Finished training epoch 113
# Validate: MSE 0.00267524 (0.00257179), PSNR 25.72637177 (25.99058175), SSIM 0.71217161 (0.76258444)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00215522 (0.00218952), PSNR 26.66507912 (26.61852679), SSIM 0.75785965 (0.77317923)
# Finished training epoch 114
# Validate: MSE 0.00274156 (0.00226651), PSNR 25.62002945 (26.50840047), SSIM 0.70203835 (0.76749064)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00231402 (0.00220291), PSNR 26.35632706 (26.59092640), SSIM 0.75570643 (0.77267477)
# Finished training epoch 115
# Validate: MSE 0.00284924 (0.00227669), PSNR 25.45270729 (26.49317599), SSIM 0.70572180 (0.77002975)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00192862 (0.00219154), PSNR 27.14752579 (26.61467169), SSIM 0.79988438 (0.77328477)
# Finished training epoch 116
# Validate: MSE 0.00273816 (0.00229510), PSNR 25.62541580 (26.45795457), SSIM 0.71351016 (0.77429490)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00191482 (0.00220935), PSNR 27.17871094 (26.58067297), SSIM 0.79336083 (0.77164997)
# Finished training epoch 117
# Validate: MSE 0.00263981 (0.00230877), PSNR 25.78427315 (26.42833211), SSIM 0.70890498 (0.76968050)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00227318 (0.00219676), PSNR 26.43365860 (26.60473782), SSIM 0.75884664 (0.77253026)
# Finished training epoch 118
# Validate: MSE 0.00257805 (0.00239328), PSNR 25.88708305 (26.26185207), SSIM 0.71292305 (0.76519066)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00213632 (0.00220898), PSNR 26.70333481 (26.58006524), SSIM 0.76152164 (0.77158879)
# Finished training epoch 119
# Validate: MSE 0.00296800 (0.00243933), PSNR 25.27536774 (26.19379323), SSIM 0.71477115 (0.76789904)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00214554 (0.00220873), PSNR 26.68462753 (26.57822047), SSIM 0.76982844 (0.77172496)
# Finished training epoch 120
# Validate: MSE 0.00286189 (0.00228915), PSNR 25.43347168 (26.46308135), SSIM 0.70138443 (0.76689029)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00212127 (0.00221269), PSNR 26.73403549 (26.57553941), SSIM 0.77116323 (0.77141683)
# Finished training epoch 121
# Validate: MSE 0.00261891 (0.00233343), PSNR 25.81879807 (26.38509267), SSIM 0.71251327 (0.76766283)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00233594 (0.00219088), PSNR 26.31538391 (26.61442330), SSIM 0.77455062 (0.77242249)
# Finished training epoch 122
# Validate: MSE 0.00287386 (0.00240090), PSNR 25.41534424 (26.26242188), SSIM 0.71352887 (0.76828674)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00208960 (0.00219024), PSNR 26.79936218 (26.61646688), SSIM 0.78019983 (0.77238436)
# Finished training epoch 123
# Validate: MSE 0.00305775 (0.00238912), PSNR 25.14597511 (26.28672782), SSIM 0.70866454 (0.77284561)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00244306 (0.00220141), PSNR 26.12065697 (26.59485432), SSIM 0.75593704 (0.77183192)
# Finished training epoch 124
# Validate: MSE 0.00279051 (0.00230118), PSNR 25.54316330 (26.44140021), SSIM 0.70626146 (0.76742820)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00221210 (0.00219140), PSNR 26.55194855 (26.61376515), SSIM 0.76774138 (0.77214229)
# Finished training epoch 125
# Validate: MSE 0.00263023 (0.00223470), PSNR 25.80006790 (26.56651951), SSIM 0.71099019 (0.77212872)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00202928 (0.00220370), PSNR 26.92657089 (26.59014917), SSIM 0.76523578 (0.77144931)
# Finished training epoch 126
# Validate: MSE 0.00265348 (0.00230523), PSNR 25.76183319 (26.42806603), SSIM 0.71334171 (0.76800791)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00176092 (0.00219398), PSNR 27.54260826 (26.61037206), SSIM 0.76388234 (0.77144336)
# Finished training epoch 127
# Validate: MSE 0.00269751 (0.00246539), PSNR 25.69037247 (26.16015206), SSIM 0.70959318 (0.76879728)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00192404 (0.00218510), PSNR 27.15785789 (26.62858299), SSIM 0.77897203 (0.77241944)
# Finished training epoch 128
# Validate: MSE 0.00283169 (0.00227104), PSNR 25.47954178 (26.50123633), SSIM 0.70613742 (0.77365964)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00155138 (0.00218903), PSNR 28.09282112 (26.62126862), SSIM 0.79892522 (0.77187222)
# Finished training epoch 129
# Validate: MSE 0.00282737 (0.00225376), PSNR 25.48617554 (26.53649307), SSIM 0.70528078 (0.77274943)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00199436 (0.00218511), PSNR 27.00197411 (26.62970444), SSIM 0.76464164 (0.77218095)
# Finished training epoch 130
# Validate: MSE 0.00286253 (0.00259717), PSNR 25.43250275 (25.92983510), SSIM 0.70941311 (0.76662207)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00232651 (0.00219297), PSNR 26.33295441 (26.60912861), SSIM 0.76847535 (0.77160026)
# Finished training epoch 131
# Validate: MSE 0.00257770 (0.00227837), PSNR 25.88768005 (26.48120046), SSIM 0.71224648 (0.76501688)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00233666 (0.00217922), PSNR 26.31405258 (26.63915284), SSIM 0.78598964 (0.77230552)
# Finished training epoch 132
# Validate: MSE 0.00276314 (0.00225223), PSNR 25.58596420 (26.53442656), SSIM 0.70493311 (0.77251253)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00216806 (0.00216947), PSNR 26.63927650 (26.66014683), SSIM 0.78457308 (0.77291432)
# Finished training epoch 133
# Validate: MSE 0.00252035 (0.00236976), PSNR 25.98538399 (26.30262593), SSIM 0.71688664 (0.76696351)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00224350 (0.00218272), PSNR 26.49073792 (26.63363725), SSIM 0.75431097 (0.77168848)
# Finished training epoch 134
# Validate: MSE 0.00262493 (0.00230093), PSNR 25.80881691 (26.44046422), SSIM 0.71185458 (0.76855683)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00223902 (0.00217603), PSNR 26.49942970 (26.64570834), SSIM 0.77581978 (0.77225761)
# Finished training epoch 135
# Validate: MSE 0.00283650 (0.00232645), PSNR 25.47216606 (26.39513816), SSIM 0.71042991 (0.77323322)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00170590 (0.00220281), PSNR 27.68046379 (26.59222417), SSIM 0.78865117 (0.77094218)
# Finished training epoch 136
# Validate: MSE 0.00265251 (0.00226459), PSNR 25.76342010 (26.50479838), SSIM 0.71011961 (0.76638863)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00279528 (0.00217196), PSNR 25.53573799 (26.65585255), SSIM 0.76522779 (0.77270344)
# Finished training epoch 137
# Validate: MSE 0.00274253 (0.00227921), PSNR 25.61848259 (26.48681648), SSIM 0.71282887 (0.77208226)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00224003 (0.00216514), PSNR 26.49746323 (26.66731044), SSIM 0.78437614 (0.77257581)
# Finished training epoch 138
# Validate: MSE 0.00268595 (0.00229272), PSNR 25.70901489 (26.45866985), SSIM 0.71359682 (0.77544172)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00246811 (0.00217144), PSNR 26.07635117 (26.65414620), SSIM 0.76168573 (0.77233230)
# Finished training epoch 139
# Validate: MSE 0.00274560 (0.00229627), PSNR 25.61362076 (26.45716942), SSIM 0.71126163 (0.77498509)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00176057 (0.00217072), PSNR 27.54345894 (26.65559513), SSIM 0.78351545 (0.77198834)
# Finished training epoch 140
# Validate: MSE 0.00263761 (0.00227309), PSNR 25.78788757 (26.49703330), SSIM 0.71266222 (0.77269181)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00235457 (0.00219575), PSNR 26.28089142 (26.61060928), SSIM 0.77653062 (0.77113761)
# Finished training epoch 141
# Validate: MSE 0.00280616 (0.00237182), PSNR 25.51887131 (26.29736061), SSIM 0.70317912 (0.76625138)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00197574 (0.00217407), PSNR 27.04270935 (26.65419487), SSIM 0.79028857 (0.77195427)
# Finished training epoch 142
# Validate: MSE 0.00294431 (0.00229198), PSNR 25.31016922 (26.46280933), SSIM 0.70797461 (0.77077537)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00235069 (0.00215862), PSNR 26.28804016 (26.68124656), SSIM 0.75387919 (0.77275495)
# Finished training epoch 143
# Validate: MSE 0.00260891 (0.00226759), PSNR 25.83540726 (26.50060208), SSIM 0.71539795 (0.76930172)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00245289 (0.00215797), PSNR 26.10322571 (26.68242862), SSIM 0.77864856 (0.77254163)
# Finished training epoch 144
# Validate: MSE 0.00267580 (0.00228327), PSNR 25.72545624 (26.47388192), SSIM 0.71248734 (0.76621815)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00250846 (0.00216058), PSNR 26.00592041 (26.67741887), SSIM 0.78694391 (0.77265997)
# Finished training epoch 145
# Validate: MSE 0.00262317 (0.00238756), PSNR 25.81173325 (26.29075297), SSIM 0.71917129 (0.77256312)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00189160 (0.00216727), PSNR 27.23170662 (26.66156795), SSIM 0.75619733 (0.77143006)
# Finished training epoch 146
# Validate: MSE 0.00265957 (0.00228363), PSNR 25.75188446 (26.47590590), SSIM 0.70759928 (0.76741792)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00210850 (0.00218359), PSNR 26.76026726 (26.63240814), SSIM 0.76410139 (0.77110198)
# Finished training epoch 147
# Validate: MSE 0.00273604 (0.00234161), PSNR 25.62878036 (26.37255161), SSIM 0.70605874 (0.76850043)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00287697 (0.00215470), PSNR 25.41064262 (26.68650941), SSIM 0.74095964 (0.77227648)
# Finished training epoch 148
# Validate: MSE 0.00273418 (0.00227677), PSNR 25.63172340 (26.48317619), SSIM 0.70173973 (0.77112062)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00248522 (0.00216164), PSNR 26.04635620 (26.67373725), SSIM 0.75588930 (0.77196603)
# Finished training epoch 149
# Validate: MSE 0.00253653 (0.00233939), PSNR 25.95760727 (26.35631245), SSIM 0.70632899 (0.75862250)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00215455 (0.00217292), PSNR 26.66642952 (26.65247776), SSIM 0.77796978 (0.77094845)
# Finished training epoch 150
# Validate: MSE 0.00281094 (0.00234814), PSNR 25.51148605 (26.35287512), SSIM 0.71223933 (0.76171240)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00233828 (0.00217323), PSNR 26.31103325 (26.65579031), SSIM 0.74172795 (0.77102954)
# Finished training epoch 151
# Validate: MSE 0.00316252 (0.00262287), PSNR 24.99966431 (25.88577217), SSIM 0.70792317 (0.76199414)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00210774 (0.00215919), PSNR 26.76183319 (26.67792862), SSIM 0.76888704 (0.77198635)
# Finished training epoch 152
# Validate: MSE 0.00288962 (0.00245561), PSNR 25.39159775 (26.16728954), SSIM 0.69879770 (0.76299999)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00259666 (0.00215658), PSNR 25.85584259 (26.68469694), SSIM 0.74635142 (0.77209470)
# Finished training epoch 153
# Validate: MSE 0.00264923 (0.00227528), PSNR 25.76879501 (26.48776266), SSIM 0.70791352 (0.76663177)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00200931 (0.00215993), PSNR 26.96952629 (26.67721183), SSIM 0.77860105 (0.77159016)
# Finished training epoch 154
# Validate: MSE 0.00270977 (0.00234007), PSNR 25.67067528 (26.36733573), SSIM 0.71563280 (0.76701178)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00192039 (0.00215283), PSNR 27.16610909 (26.69256497), SSIM 0.78925115 (0.77176183)
# Finished training epoch 155
# Validate: MSE 0.00271363 (0.00225077), PSNR 25.66449547 (26.53561593), SSIM 0.70977342 (0.77228145)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00205411 (0.00216145), PSNR 26.87375450 (26.67447557), SSIM 0.76805335 (0.77133914)
# Finished training epoch 156
# Validate: MSE 0.00287328 (0.00228979), PSNR 25.41622543 (26.45999716), SSIM 0.70298207 (0.76677933)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00221350 (0.00218099), PSNR 26.54920197 (26.63688230), SSIM 0.77699471 (0.77052610)
# Finished training epoch 157
# Validate: MSE 0.00256952 (0.00230184), PSNR 25.90147209 (26.44361135), SSIM 0.71090388 (0.77210734)
# Finished validation.
# Starting training epoch 158
# ...
# Finished validation.
# Starting training epoch 208
# Epoch: 208, MSE 0.00186642 (0.00210547), PSNR 27.28991318 (26.78656479), SSIM 0.78111666 (0.77173817)
# Finished training epoch 208
# Validate: MSE 0.00283272 (0.00225832), PSNR 25.47796631 (26.52507949), SSIM 0.70459813 (0.77205080)
# Finished validation.
# Starting training epoch 209
# Epoch: 209, MSE 0.00193346 (0.00212359), PSNR 27.13664246 (26.75048334), SSIM 0.77307236 (0.77052704)
# Finished training epoch 209
# Validate: MSE 0.00242870 (0.00225903), PSNR 26.14626312 (26.51791764), SSIM 0.71293306 (0.76669367)
# Finished validation.
# Starting training epoch 210
# Epoch: 210, MSE 0.00261238 (0.00211461), PSNR 25.82963371 (26.76987871), SSIM 0.75871897 (0.77102337)
# Finished training epoch 210
# Validate: MSE 0.00264708 (0.00234540), PSNR 25.77232361 (26.36396494), SSIM 0.70716834 (0.76704354)
# Finished validation.
# Starting training epoch 211
# Epoch: 211, MSE 0.00264062 (0.00210713), PSNR 25.78293800 (26.78444028), SSIM 0.74894649 (0.77142363)
# Finished training epoch 211
# Validate: MSE 0.00278291 (0.00232000), PSNR 25.55500221 (26.40202148), SSIM 0.70374227 (0.76712778)
# Finished validation.
# Starting training epoch 212
# Epoch: 212, MSE 0.00201736 (0.00210420), PSNR 26.95215797 (26.78956015), SSIM 0.78075314 (0.77154057)
# Finished training epoch 212
# Validate: MSE 0.00264847 (0.00236469), PSNR 25.77004433 (26.32531593), SSIM 0.70871121 (0.77144953)
# Finished validation.
# Starting training epoch 213
# Epoch: 213, MSE 0.00175747 (0.00212954), PSNR 27.55112267 (26.74076018), SSIM 0.77537572 (0.77020136)
# Finished training epoch 213
# Validate: MSE 0.00272817 (0.00250619), PSNR 25.64127922 (26.08583091), SSIM 0.69499218 (0.75420687)
# Finished validation.
# Starting training epoch 214
# Epoch: 214, MSE 0.00243132 (0.00209780), PSNR 26.14158249 (26.80070786), SSIM 0.75924146 (0.77148498)
# Finished training epoch 214
# Validate: MSE 0.00269944 (0.00222119), PSNR 25.68726730 (26.59139145), SSIM 0.70962334 (0.76932229)
# Finished validation.
# Starting training epoch 215
# Epoch: 215, MSE 0.00188523 (0.00211246), PSNR 27.24634552 (26.77369810), SSIM 0.78904814 (0.77072469)
# Finished training epoch 215
# Validate: MSE 0.00298354 (0.00237302), PSNR 25.25267410 (26.30967276), SSIM 0.69955480 (0.76153605)
# Finished validation.
# Starting training epoch 216
# Epoch: 216, MSE 0.00233150 (0.00213406), PSNR 26.32364655 (26.72971761), SSIM 0.76050842 (0.77050710)
# Finished training epoch 216
# Validate: MSE 0.00250968 (0.00230820), PSNR 26.00381470 (26.42193132), SSIM 0.71296608 (0.76467439)
# Finished validation.
# Starting training epoch 217
# Epoch: 217, MSE 0.00210929 (0.00210402), PSNR 26.75864601 (26.79077559), SSIM 0.77030408 (0.77141125)
# Finished training epoch 217
# Validate: MSE 0.00268900 (0.00230076), PSNR 25.70408249 (26.43819660), SSIM 0.69935924 (0.76229114)
# Finished validation.
# Starting training epoch 218
# Epoch: 218, MSE 0.00182187 (0.00211443), PSNR 27.39482498 (26.76800657), SSIM 0.78586859 (0.77102332)
# Finished training epoch 218
# Validate: MSE 0.00287287 (0.00229548), PSNR 25.41684532 (26.45741310), SSIM 0.70295972 (0.76661336)
# Finished validation.
# Starting training epoch 219
# Epoch: 219, MSE 0.00206851 (0.00211107), PSNR 26.84341812 (26.77598399), SSIM 0.77575248 (0.77087549)
# Finished training epoch 219
# Validate: MSE 0.00262606 (0.00228942), PSNR 25.80695152 (26.46669127), SSIM 0.71870160 (0.77520941)
# Finished validation.
# Starting training epoch 220
# Epoch: 220, MSE 0.00255548 (0.00211437), PSNR 25.92527199 (26.76888585), SSIM 0.79736775 (0.77103157)
# Finished training epoch 220
# Validate: MSE 0.00288615 (0.00228408), PSNR 25.39681435 (26.47392511), SSIM 0.70493537 (0.77157568)
# Finished validation.
# Starting training epoch 221
# Epoch: 221, MSE 0.00179970 (0.00211405), PSNR 27.44799232 (26.76958398), SSIM 0.79300815 (0.77075186)
# Finished training epoch 221
# Validate: MSE 0.00290312 (0.00227986), PSNR 25.37134361 (26.48231546), SSIM 0.71421909 (0.77382316)
# Finished validation.
# Starting training epoch 222
# Epoch: 222, MSE 0.00185716 (0.00210779), PSNR 27.31151199 (26.78465954), SSIM 0.76843375 (0.77113615)
# Finished training epoch 222
# Validate: MSE 0.00239723 (0.00238491), PSNR 26.20291138 (26.27127112), SSIM 0.70960569 (0.75761969)
# Finished validation.
# Starting training epoch 223
# Epoch: 223, MSE 0.00180961 (0.00209513), PSNR 27.42414665 (26.80958089), SSIM 0.77504969 (0.77153048)
# Finished training epoch 223
# Validate: MSE 0.00264577 (0.00229975), PSNR 25.77447701 (26.44422596), SSIM 0.71239042 (0.77044217)
# Finished validation.
# Starting training epoch 224
# Epoch: 224, MSE 0.00239504 (0.00210879), PSNR 26.20686531 (26.78193015), SSIM 0.76146305 (0.77121901)
# Finished training epoch 224
# Validate: MSE 0.00265052 (0.00239806), PSNR 25.76668739 (26.25365871), SSIM 0.70332235 (0.75651219)
# Finished validation.
# Starting training epoch 225
# Epoch: 225, MSE 0.00302858 (0.00210732), PSNR 25.18761253 (26.78433107), SSIM 0.75873613 (0.77074373)
# Finished training epoch 225
# Validate: MSE 0.00270862 (0.00227797), PSNR 25.67252541 (26.48277196), SSIM 0.71527433 (0.77297246)
# Finished validation.
# Starting training epoch 226
# Epoch: 226, MSE 0.00184738 (0.00211194), PSNR 27.33443260 (26.77367843), SSIM 0.78164941 (0.77074794)
# Finished training epoch 226
# Validate: MSE 0.00279539 (0.00224343), PSNR 25.53557968 (26.54990600), SSIM 0.70596123 (0.76990380)
# Finished validation.
# Starting training epoch 227
# Epoch: 227, MSE 0.00209311 (0.00210085), PSNR 26.79207039 (26.79458739), SSIM 0.78347945 (0.77136435)
# Finished training epoch 227
# Validate: MSE 0.00275381 (0.00233781), PSNR 25.60065460 (26.37057882), SSIM 0.70621657 (0.76133940)
# Finished validation.
# Starting training epoch 228
# Epoch: 228, MSE 0.00223083 (0.00209941), PSNR 26.51533699 (26.80193330), SSIM 0.76881671 (0.77074124)
# Finished training epoch 228
# Validate: MSE 0.00255180 (0.00226087), PSNR 25.93153381 (26.51732595), SSIM 0.71235567 (0.76861910)
# Finished validation.
# Starting training epoch 229
# Epoch: 229, MSE 0.00211715 (0.00209973), PSNR 26.74247360 (26.79872601), SSIM 0.77439606 (0.77096721)
# Finished training epoch 229
# Validate: MSE 0.00291066 (0.00233378), PSNR 25.36008453 (26.38250590), SSIM 0.70474482 (0.76794446)
# Finished validation.
# Starting training epoch 230
# Epoch: 230, MSE 0.00204474 (0.00209470), PSNR 26.89361191 (26.80975077), SSIM 0.76335573 (0.77082622)
# Finished training epoch 230
# Validate: MSE 0.00258494 (0.00228112), PSNR 25.87549019 (26.47452847), SSIM 0.70352507 (0.76240570)
# Finished validation.
# Starting training epoch 231
# Epoch: 231, MSE 0.00198341 (0.00210077), PSNR 27.02588081 (26.79785362), SSIM 0.77278912 (0.77056236)
# Finished training epoch 231
# Validate: MSE 0.00282236 (0.00234534), PSNR 25.49387169 (26.36611439), SSIM 0.70785928 (0.76701087)
# Finished validation.
# Starting training epoch 232
# Epoch: 232, MSE 0.00214581 (0.00209327), PSNR 26.68407822 (26.81281579), SSIM 0.78610909 (0.77098146)
# Finished training epoch 232
# Validate: MSE 0.00298077 (0.00228389), PSNR 25.25671005 (26.47237892), SSIM 0.70434457 (0.76582953)
# Finished validation.
# Starting training epoch 233
# Epoch: 233, MSE 0.00193808 (0.00211065), PSNR 27.12627792 (26.77906691), SSIM 0.77657574 (0.77058745)
# Finished training epoch 233
# Validate: MSE 0.00272610 (0.00237269), PSNR 25.64458847 (26.31209213), SSIM 0.70558453 (0.76641720)
# Finished validation.
# Starting training epoch 234
# Epoch: 234, MSE 0.00285658 (0.00209281), PSNR 25.44152832 (26.81688732), SSIM 0.76715648 (0.77112009)
# Finished training epoch 234
# Validate: MSE 0.00260270 (0.00228697), PSNR 25.84576225 (26.46808989), SSIM 0.71595460 (0.77475916)
# Finished validation.
# Starting training epoch 235
# Epoch: 235, MSE 0.00193537 (0.00210191), PSNR 27.13235283 (26.79458102), SSIM 0.77100521 (0.77051014)
# Finished training epoch 235
# Validate: MSE 0.00287927 (0.00227895), PSNR 25.40716934 (26.48473155), SSIM 0.70325023 (0.76816597)
# Finished validation.
# Starting training epoch 236
# Epoch: 236, MSE 0.00210764 (0.00211222), PSNR 26.76203156 (26.77732931), SSIM 0.75812411 (0.77026558)
# Finished training epoch 236
# Validate: MSE 0.00269546 (0.00230733), PSNR 25.69367599 (26.42264147), SSIM 0.69359672 (0.75906061)
# Finished validation.
# Starting training epoch 237
# Epoch: 237, MSE 0.00188470 (0.00210216), PSNR 27.24756432 (26.79419183), SSIM 0.76551962 (0.77095505)
# Finished training epoch 237
# Validate: MSE 0.00272910 (0.00228092), PSNR 25.63980484 (26.47950789), SSIM 0.71243227 (0.76408382)
# Finished validation.
# Starting training epoch 238
# Epoch: 238, MSE 0.00184129 (0.00209184), PSNR 27.34877205 (26.81511345), SSIM 0.76651978 (0.77076300)
# Finished training epoch 238
# Validate: MSE 0.00258327 (0.00224942), PSNR 25.87829399 (26.53869975), SSIM 0.71379495 (0.76281526)
# Finished validation.
# Starting training epoch 239
# Epoch: 239, MSE 0.00221577 (0.00210545), PSNR 26.54475403 (26.78613049), SSIM 0.77504122 (0.76983495)
# Finished training epoch 239
# Validate: MSE 0.00265884 (0.00232301), PSNR 25.75307846 (26.39724338), SSIM 0.70062423 (0.75648459)
# Finished validation.
# Starting training epoch 240
# Epoch: 240, MSE 0.00207701 (0.00209945), PSNR 26.82561302 (26.79910866), SSIM 0.75333619 (0.77070120)
# Finished training epoch 240
# Validate: MSE 0.00266996 (0.00237454), PSNR 25.73494720 (26.30952389), SSIM 0.71216685 (0.75979663)
# Finished validation.
# Starting training epoch 241
# Epoch: 241, MSE 0.00193316 (0.00209089), PSNR 27.13731194 (26.81938200), SSIM 0.77243268 (0.77117917)
# Finished training epoch 241
# Validate: MSE 0.00254455 (0.00233099), PSNR 25.94388962 (26.38248010), SSIM 0.71581930 (0.75897938)
# Finished validation.
# Starting training epoch 242
# Epoch: 242, MSE 0.00225113 (0.00209774), PSNR 26.47599792 (26.80426554), SSIM 0.76365060 (0.77095411)
# Finished training epoch 242
# Validate: MSE 0.00255305 (0.00227022), PSNR 25.92940140 (26.49928663), SSIM 0.71385485 (0.76431774)
# Finished validation.
# Starting training epoch 243
# Epoch: 243, MSE 0.00212393 (0.00210236), PSNR 26.72859955 (26.79223199), SSIM 0.75905782 (0.77066154)
# Finished training epoch 243
# Validate: MSE 0.00253471 (0.00229763), PSNR 25.96072006 (26.44256494), SSIM 0.71197420 (0.76648181)
# Finished validation.
# Starting training epoch 244
# Epoch: 244, MSE 0.00194485 (0.00209816), PSNR 27.11112785 (26.80187551), SSIM 0.75870150 (0.77019667)
# Finished training epoch 244
# Validate: MSE 0.00268574 (0.00224165), PSNR 25.70936203 (26.55572646), SSIM 0.71069413 (0.77039182)
# Finished validation.
# Starting training epoch 245
# Epoch: 245, MSE 0.00213501 (0.00208735), PSNR 26.70600510 (26.82418721), SSIM 0.78760028 (0.77137382)
# Finished training epoch 245
# Validate: MSE 0.00255289 (0.00227327), PSNR 25.92967415 (26.48781636), SSIM 0.71030551 (0.76517601)
# Finished validation.
# Starting training epoch 246
# Epoch: 246, MSE 0.00215516 (0.00209440), PSNR 26.66519928 (26.81026450), SSIM 0.77577055 (0.77099874)
# Finished training epoch 246
# Validate: MSE 0.00265945 (0.00225468), PSNR 25.75208282 (26.52954000), SSIM 0.71195328 (0.76794630)
# Finished validation.
# Starting training epoch 247
# Epoch: 247, MSE 0.00182766 (0.00208472), PSNR 27.38103294 (26.82869618), SSIM 0.79321748 (0.77098961)
# Finished training epoch 247
# Validate: MSE 0.00285371 (0.00232407), PSNR 25.44589615 (26.40463817), SSIM 0.71223575 (0.77300377)
# Finished validation.
# Starting training epoch 248
# Epoch: 248, MSE 0.00199330 (0.00211045), PSNR 27.00426292 (26.77958617), SSIM 0.76950204 (0.76962815)
# Finished training epoch 248
# Validate: MSE 0.00260772 (0.00228766), PSNR 25.83738899 (26.45868972), SSIM 0.71056682 (0.76761932)
# Finished validation.
# Starting training epoch 249
# Epoch: 249, MSE 0.00251308 (0.00207009), PSNR 25.99794388 (26.86101787), SSIM 0.75419384 (0.77152740)
# Finished training epoch 249
# Validate: MSE 0.00294433 (0.00235817), PSNR 25.31013680 (26.33922427), SSIM 0.71128631 (0.76470228)
# Finished validation.
# Starting training epoch 250
# Epoch: 250, MSE 0.00179252 (0.00209296), PSNR 27.46536827 (26.81450684), SSIM 0.78570849 (0.77005429)
# Finished training epoch 250
# Validate: MSE 0.00257108 (0.00233552), PSNR 25.89883614 (26.36498155), SSIM 0.70434463 (0.76521554)
# Finished validation.
# Starting training epoch 251
# Epoch: 251, MSE 0.00266989 (0.00209673), PSNR 25.73507118 (26.80567962), SSIM 0.75868523 (0.77049503)
# Finished training epoch 251
# Validate: MSE 0.00273442 (0.00226563), PSNR 25.63134384 (26.50387380), SSIM 0.70407343 (0.76567313)
# Finished validation.
# Starting training epoch 252
# Epoch: 252, MSE 0.00255135 (0.00210095), PSNR 25.93229485 (26.79676654), SSIM 0.75401843 (0.77001874)
# Finished training epoch 252
# Validate: MSE 0.00235537 (0.00235288), PSNR 26.27940941 (26.34229708), SSIM 0.72012931 (0.76171049)
# Finished validation.
# Starting training epoch 253
# Epoch: 253, MSE 0.00197933 (0.00208500), PSNR 27.03480721 (26.82814044), SSIM 0.77556574 (0.77116183)
# Finished training epoch 253
# Validate: MSE 0.00265708 (0.00237020), PSNR 25.75594902 (26.31318059), SSIM 0.70427704 (0.76628434)
# Finished validation.
# Starting training epoch 254
# Epoch: 254, MSE 0.00227603 (0.00207713), PSNR 26.42821121 (26.84833525), SSIM 0.77245367 (0.77096366)
# Finished training epoch 254
# Validate: MSE 0.00264770 (0.00245819), PSNR 25.77131653 (26.14133159), SSIM 0.70786893 (0.75750458)
# Finished validation.
# Starting training epoch 255
# Epoch: 255, MSE 0.00202868 (0.00210527), PSNR 26.92786407 (26.78874048), SSIM 0.75756150 (0.77008736)
# Finished training epoch 255
# Validate: MSE 0.00286444 (0.00228967), PSNR 25.42959785 (26.46808106), SSIM 0.71005815 (0.76714524)
# Finished validation.
# Starting training epoch 256
# Epoch: 256, MSE 0.00181995 (0.00208391), PSNR 27.39940643 (26.83416532), SSIM 0.78473961 (0.77060061)
# Finished training epoch 256
# Validate: MSE 0.00285779 (0.00227214), PSNR 25.43969536 (26.49772495), SSIM 0.70247269 (0.76960823)
# Finished validation.
# Starting training epoch 257
# Epoch: 257, MSE 0.00189855 (0.00209436), PSNR 27.21576881 (26.81146742), SSIM 0.77432501 (0.77043899)
# Finished training epoch 257
# Validate: MSE 0.00270110 (0.00227863), PSNR 25.68458939 (26.48436631), SSIM 0.70733047 (0.76963313)
# Finished validation.
# Starting training epoch 258
# Epoch: 258, MSE 0.00181630 (0.00208999), PSNR 27.40812683 (26.81914250), SSIM 0.75438184 (0.77037212)
# Finished training epoch 258
# Validate: MSE 0.00266661 (0.00230933), PSNR 25.74039650 (26.42315016), SSIM 0.70605075 (0.76111995)
# Finished validation.
# Starting training epoch 259
# Epoch: 259, MSE 0.00218064 (0.00209247), PSNR 26.61415482 (26.81238953), SSIM 0.76379502 (0.76990168)
# Finished training epoch 259
# Validate: MSE 0.00263603 (0.00222700), PSNR 25.79048729 (26.57843665), SSIM 0.70842576 (0.76541056)
# Finished validation.
# Starting training epoch 260
# Epoch: 260, MSE 0.00200879 (0.00207680), PSNR 26.97065544 (26.84605365), SSIM 0.78176773 (0.77105327)
# Finished training epoch 260
# Validate: MSE 0.00279469 (0.00225805), PSNR 25.53666878 (26.52627349), SSIM 0.70654619 (0.77013817)
# Finished validation.
# Starting training epoch 261
# Epoch: 261, MSE 0.00238537 (0.00209381), PSNR 26.22443390 (26.81147557), SSIM 0.76729882 (0.77018472)
# Finished training epoch 261
# Validate: MSE 0.00249139 (0.00227939), PSNR 26.03558159 (26.47471433), SSIM 0.71128702 (0.76253350)
# Finished validation.
# Starting training epoch 262
# Epoch: 262, MSE 0.00237294 (0.00208995), PSNR 26.24712944 (26.81850556), SSIM 0.75407779 (0.77024414)
# Finished training epoch 262
# Validate: MSE 0.00265852 (0.00259120), PSNR 25.75360298 (25.91429407), SSIM 0.69990754 (0.75514692)
# Finished validation.
# Starting training epoch 263
# Epoch: 263, MSE 0.00226491 (0.00209463), PSNR 26.44949150 (26.80857190), SSIM 0.76064122 (0.76995660)
# Finished training epoch 263
# Validate: MSE 0.00279996 (0.00229060), PSNR 25.52847862 (26.45617054), SSIM 0.69989300 (0.76072090)
# Finished validation.
# Starting training epoch 264
# Epoch: 264, MSE 0.00221502 (0.00209046), PSNR 26.54622459 (26.82103864), SSIM 0.78290272 (0.76996054)
# Finished training epoch 264
# Validate: MSE 0.00267014 (0.00230341), PSNR 25.73466110 (26.42786213), SSIM 0.70630556 (0.75961856)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00265156 (0.00230324), PSNR 25.76498795 (26.42936661), SSIM 0.70446002 (0.75928113)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
