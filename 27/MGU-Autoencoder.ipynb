# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-4bcdc5e7c08a5432" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4bcdc5e7c08a5432");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
                transforms.RandomVerticalFlip(),  
                transforms.RandomRotation(10),
                transforms.ColorJitter(brightness=0.05, contrast=0.05, saturation=0.05, hue=0.05)
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .25

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base * 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base * 4, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base * 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm4 = nn.BatchNorm2d(channels_base)
        self.batchnorm5 = nn.BatchNorm2d(2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = y = F.dropout(x, p=p1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = y1 = F.dropout(x, p=p1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(torch.cat((x, y1), 1))), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm5(self.convtrans3(torch.cat((x, y), 1))), negative_slope=0.1)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 512, 8, 8]       2,359,808
#        BatchNorm2d-6            [-1, 512, 8, 8]           1,024
#    ConvTranspose2d-7          [-1, 256, 16, 16]       2,359,552
#        BatchNorm2d-8          [-1, 256, 16, 16]             512
#    ConvTranspose2d-9            [-1, 2, 32, 32]           9,218
#       BatchNorm2d-10            [-1, 2, 32, 32]               4
# ================================================================
# Total params: 5,914,374
# Trainable params: 5,914,374
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 7.53
# Params size (MB): 22.56
# Estimated Total Size (MB): 30.10
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00260683 (0.02539646), PSNR 25.83887672 (19.67075554), SSIM 0.78443354 (0.56356671)
# Finished training epoch 0
# Validate: MSE 0.00323098 (0.00276707), PSNR 24.90665627 (25.65438153), SSIM 0.70478636 (0.77540276)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00246911 (0.00276762), PSNR 26.07458878 (25.60189381), SSIM 0.78921789 (0.76919917)
# Finished training epoch 1
# Validate: MSE 0.00318588 (0.00277101), PSNR 24.96770096 (25.65076536), SSIM 0.70452988 (0.77523164)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00322645 (0.00276198), PSNR 24.91275024 (25.61069731), SSIM 0.72757071 (0.76927202)
# Finished training epoch 2
# Validate: MSE 0.00318999 (0.00276560), PSNR 24.96210098 (25.65894791), SSIM 0.70469582 (0.77527850)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00249500 (0.00276814), PSNR 26.02929306 (25.60197807), SSIM 0.77563041 (0.76946240)
# Finished training epoch 3
# Validate: MSE 0.00322156 (0.00276038), PSNR 24.91934013 (25.66500215), SSIM 0.70467556 (0.77533952)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00248339 (0.00275712), PSNR 26.04954529 (25.62201112), SSIM 0.77592337 (0.76958338)
# Finished training epoch 4
# Validate: MSE 0.00316074 (0.00275918), PSNR 25.00211716 (25.67021247), SSIM 0.70521724 (0.77592112)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00272664 (0.00274078), PSNR 25.64372063 (25.64484266), SSIM 0.75819457 (0.77066324)
# Finished training epoch 5
# Validate: MSE 0.00316577 (0.00272354), PSNR 24.99520493 (25.72470947), SSIM 0.70619059 (0.77720207)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00243146 (0.00267568), PSNR 26.14133072 (25.74819528), SSIM 0.77835453 (0.77125760)
# Finished training epoch 6
# Validate: MSE 0.00295386 (0.00260450), PSNR 25.29609680 (25.91344751), SSIM 0.70413578 (0.77440078)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00260517 (0.00257038), PSNR 25.84164047 (25.92264641), SSIM 0.76487571 (0.77033956)
# Finished training epoch 7
# Validate: MSE 0.00289565 (0.00272033), PSNR 25.38253403 (25.75218144), SSIM 0.71189690 (0.77990613)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00306184 (0.00252337), PSNR 25.14017677 (26.00509724), SSIM 0.76377922 (0.77094095)
# Finished training epoch 8
# Validate: MSE 0.00296458 (0.00252147), PSNR 25.28036880 (26.04510020), SSIM 0.71003097 (0.77568976)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00239487 (0.00249850), PSNR 26.20717621 (26.04499010), SSIM 0.75704002 (0.77221599)
# Finished training epoch 9
# Validate: MSE 0.00287201 (0.00243302), PSNR 25.41813850 (26.20191646), SSIM 0.71307200 (0.78003685)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00307981 (0.00247450), PSNR 25.11476135 (26.08965515), SSIM 0.76226550 (0.77330440)
# Finished training epoch 10
# Validate: MSE 0.00276422 (0.00256429), PSNR 25.58426857 (25.98636017), SSIM 0.71351802 (0.77878547)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00242388 (0.00246519), PSNR 26.15489006 (26.10398512), SSIM 0.79238605 (0.77376005)
# Finished training epoch 11
# Validate: MSE 0.00275167 (0.00282281), PSNR 25.60403633 (25.58179329), SSIM 0.71278697 (0.77385912)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00205948 (0.00245702), PSNR 26.86241722 (26.11722270), SSIM 0.77304131 (0.77397878)
# Finished training epoch 12
# Validate: MSE 0.00332840 (0.00318699), PSNR 24.77764320 (25.05827870), SSIM 0.70896697 (0.76995531)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00186226 (0.00243112), PSNR 27.29959106 (26.16703093), SSIM 0.80086362 (0.77455531)
# Finished training epoch 13
# Validate: MSE 0.00278048 (0.00241272), PSNR 25.55879974 (26.23286952), SSIM 0.71640658 (0.78268963)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00284950 (0.00242762), PSNR 25.45231056 (26.17217047), SSIM 0.75542831 (0.77471352)
# Finished training epoch 14
# Validate: MSE 0.00293641 (0.00248457), PSNR 25.32183266 (26.11342182), SSIM 0.71612138 (0.78145585)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00302979 (0.00241737), PSNR 25.18587685 (26.18971298), SSIM 0.77081031 (0.77510214)
# Finished training epoch 15
# Validate: MSE 0.00302150 (0.00258928), PSNR 25.19777298 (25.94698675), SSIM 0.71398455 (0.78218895)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00209489 (0.00241574), PSNR 26.78837967 (26.19328329), SSIM 0.80182952 (0.77545490)
# Finished training epoch 16
# Validate: MSE 0.00320624 (0.00279240), PSNR 24.94004250 (25.62393371), SSIM 0.71122110 (0.77669943)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00260767 (0.00240840), PSNR 25.83746719 (26.20543722), SSIM 0.75898087 (0.77551217)
# Finished training epoch 17
# Validate: MSE 0.00305260 (0.00268504), PSNR 25.15329933 (25.78791588), SSIM 0.71121740 (0.77543839)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00282077 (0.00241112), PSNR 25.49631882 (26.20127024), SSIM 0.75894278 (0.77553337)
# Finished training epoch 18
# Validate: MSE 0.00302215 (0.00248196), PSNR 25.19683647 (26.12444619), SSIM 0.71438098 (0.78377907)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00205425 (0.00240599), PSNR 26.87345695 (26.21121411), SSIM 0.79522866 (0.77574871)
# Finished training epoch 19
# Validate: MSE 0.00277463 (0.00239570), PSNR 25.56794739 (26.27014282), SSIM 0.71733958 (0.78348327)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00227448 (0.00238580), PSNR 26.43117332 (26.24636960), SSIM 0.78182638 (0.77597402)
# Finished training epoch 20
# Validate: MSE 0.00284407 (0.00242240), PSNR 25.46059418 (26.21834271), SSIM 0.72092086 (0.78387729)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00334881 (0.00237878), PSNR 24.75108910 (26.25706473), SSIM 0.76616484 (0.77618939)
# Finished training epoch 21
# Validate: MSE 0.00315129 (0.00272447), PSNR 25.01511955 (25.73626611), SSIM 0.71685374 (0.77988149)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00223826 (0.00237620), PSNR 26.50089836 (26.26186053), SSIM 0.76809376 (0.77649866)
# Finished training epoch 22
# Validate: MSE 0.00292139 (0.00297487), PSNR 25.34410095 (25.34088503), SSIM 0.72031373 (0.77138339)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00264290 (0.00237266), PSNR 25.77919197 (26.27145993), SSIM 0.77430803 (0.77626548)
# Finished training epoch 23
# Validate: MSE 0.00269320 (0.00235142), PSNR 25.69731140 (26.34558044), SSIM 0.72372717 (0.78317063)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00190163 (0.00236185), PSNR 27.20873833 (26.29038285), SSIM 0.79499215 (0.77706492)
# Finished training epoch 24
# Validate: MSE 0.00266697 (0.00246191), PSNR 25.73981476 (26.16564962), SSIM 0.72259068 (0.78377515)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00169298 (0.00235358), PSNR 27.71348381 (26.30505416), SSIM 0.80431116 (0.77702571)
# Finished training epoch 25
# Validate: MSE 0.00260513 (0.00254635), PSNR 25.84169960 (25.99852780), SSIM 0.72020233 (0.77974552)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00236553 (0.00235105), PSNR 26.26071739 (26.31138773), SSIM 0.76687747 (0.77732957)
# Finished training epoch 26
# Validate: MSE 0.00266420 (0.00234889), PSNR 25.74433517 (26.35326889), SSIM 0.72523022 (0.78404181)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00198097 (0.00236379), PSNR 27.03122330 (26.28966897), SSIM 0.76823449 (0.77694136)
# Finished training epoch 27
# Validate: MSE 0.00270608 (0.00238660), PSNR 25.67659378 (26.27606153), SSIM 0.71382797 (0.77632677)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00221393 (0.00235785), PSNR 26.54835129 (26.29996648), SSIM 0.78039140 (0.77738566)
# Finished training epoch 28
# Validate: MSE 0.00272397 (0.00240542), PSNR 25.64797020 (26.25314115), SSIM 0.72327745 (0.78492555)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00293260 (0.00235215), PSNR 25.32746315 (26.30559228), SSIM 0.76684022 (0.77740225)
# Finished training epoch 29
# Validate: MSE 0.00280226 (0.00271480), PSNR 25.52490997 (25.77701576), SSIM 0.72202384 (0.77921181)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00291339 (0.00235073), PSNR 25.35600471 (26.31438294), SSIM 0.76715982 (0.77743220)
# Finished training epoch 30
# Validate: MSE 0.00265491 (0.00231735), PSNR 25.75950050 (26.41041068), SSIM 0.71889114 (0.78483069)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00269248 (0.00233820), PSNR 25.69847870 (26.33595785), SSIM 0.76613688 (0.77770094)
# Finished training epoch 31
# Validate: MSE 0.00281381 (0.00238107), PSNR 25.50705528 (26.29763209), SSIM 0.72004682 (0.78410021)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00251219 (0.00233814), PSNR 25.99946594 (26.33598994), SSIM 0.76145953 (0.77750429)
# Finished training epoch 32
# Validate: MSE 0.00280579 (0.00285976), PSNR 25.51945114 (25.51620258), SSIM 0.71812296 (0.77358646)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00199560 (0.00232942), PSNR 26.99925232 (26.35170484), SSIM 0.79133844 (0.77796140)
# Finished training epoch 33
# Validate: MSE 0.00285687 (0.00242639), PSNR 25.44109726 (26.21839416), SSIM 0.71479809 (0.77967799)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00282323 (0.00233963), PSNR 25.49253273 (26.32798842), SSIM 0.75596225 (0.77791775)
# Finished training epoch 34
# Validate: MSE 0.00272848 (0.00230341), PSNR 25.64079857 (26.43797777), SSIM 0.71978855 (0.78218845)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00193478 (0.00232155), PSNR 27.13368607 (26.36475840), SSIM 0.78819132 (0.77819443)
# Finished training epoch 35
# Validate: MSE 0.00284282 (0.00249097), PSNR 25.46250534 (26.10825681), SSIM 0.72081476 (0.78171589)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00249611 (0.00232474), PSNR 26.02735329 (26.35798437), SSIM 0.76117975 (0.77827683)
# Finished training epoch 36
# Validate: MSE 0.00260845 (0.00231010), PSNR 25.83617783 (26.41782507), SSIM 0.72417992 (0.78102553)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00214880 (0.00231784), PSNR 26.67803001 (26.37314560), SSIM 0.76833868 (0.77858803)
# Finished training epoch 37
# Validate: MSE 0.00248903 (0.00241050), PSNR 26.03970528 (26.23964744), SSIM 0.71918339 (0.77876932)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00249503 (0.00231357), PSNR 26.02924538 (26.38055332), SSIM 0.76882589 (0.77837368)
# Finished training epoch 38
# Validate: MSE 0.00279529 (0.00246256), PSNR 25.53572464 (26.15459075), SSIM 0.72141600 (0.78002318)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00249174 (0.00231657), PSNR 26.03497505 (26.37512873), SSIM 0.77109414 (0.77812797)
# Finished training epoch 39
# Validate: MSE 0.00259437 (0.00233793), PSNR 25.85968208 (26.36754920), SSIM 0.72508502 (0.78139471)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00210366 (0.00231502), PSNR 26.77024651 (26.37559601), SSIM 0.78290588 (0.77809501)
# Finished training epoch 40
# Validate: MSE 0.00260811 (0.00230573), PSNR 25.83673859 (26.43358229), SSIM 0.72511292 (0.78606533)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00250434 (0.00230918), PSNR 26.01306725 (26.38870199), SSIM 0.77984631 (0.77860135)
# Finished training epoch 41
# Validate: MSE 0.00266194 (0.00227130), PSNR 25.74801826 (26.49958023), SSIM 0.72206646 (0.78663678)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00193966 (0.00231227), PSNR 27.12274742 (26.38468849), SSIM 0.79418862 (0.77854350)
# Finished training epoch 42
# Validate: MSE 0.00265762 (0.00230260), PSNR 25.75506973 (26.43448350), SSIM 0.72085536 (0.78315908)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00274421 (0.00230406), PSNR 25.61581993 (26.39903656), SSIM 0.77257621 (0.77861130)
# Finished training epoch 43
# Validate: MSE 0.00274114 (0.00335409), PSNR 25.62067986 (24.89944509), SSIM 0.71635604 (0.76777348)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00265550 (0.00229339), PSNR 25.75853729 (26.41792659), SSIM 0.77409488 (0.77869629)
# Finished training epoch 44
# Validate: MSE 0.00282409 (0.00287400), PSNR 25.49121284 (25.50085667), SSIM 0.71888697 (0.77296965)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00236195 (0.00230299), PSNR 26.26729774 (26.39873403), SSIM 0.79219902 (0.77829423)
# Finished training epoch 45
# Validate: MSE 0.00272329 (0.00228995), PSNR 25.64905930 (26.46249916), SSIM 0.71787071 (0.78334512)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00255966 (0.00229861), PSNR 25.91817665 (26.41001437), SSIM 0.78432071 (0.77848437)
# Finished training epoch 46
# Validate: MSE 0.00268458 (0.00315964), PSNR 25.71123123 (25.11338983), SSIM 0.71059871 (0.75818582)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00235225 (0.00229251), PSNR 26.28516579 (26.42273415), SSIM 0.77706420 (0.77876257)
# Finished training epoch 47
# Validate: MSE 0.00255955 (0.00230483), PSNR 25.91835976 (26.44009652), SSIM 0.72665131 (0.78593113)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00267816 (0.00229136), PSNR 25.72163200 (26.42277816), SSIM 0.77561343 (0.77879686)
# Finished training epoch 48
# Validate: MSE 0.00279340 (0.00232524), PSNR 25.53866386 (26.39936489), SSIM 0.71713316 (0.78504999)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00209393 (0.00228361), PSNR 26.79037666 (26.43861110), SSIM 0.77853739 (0.77874136)
# Finished training epoch 49
# Validate: MSE 0.00254797 (0.00232844), PSNR 25.93806267 (26.38271745), SSIM 0.72284508 (0.78180445)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00203264 (0.00228623), PSNR 26.91940308 (26.43317445), SSIM 0.77389914 (0.77881277)
# Finished training epoch 50
# Validate: MSE 0.00252362 (0.00232994), PSNR 25.97976685 (26.38109141), SSIM 0.72514760 (0.78379277)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00203774 (0.00227872), PSNR 26.90850449 (26.44623698), SSIM 0.78251874 (0.77873929)
# Finished training epoch 51
# Validate: MSE 0.00239144 (0.00235692), PSNR 26.21340370 (26.34259062), SSIM 0.72679234 (0.78247048)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00194173 (0.00227919), PSNR 27.11810875 (26.44450953), SSIM 0.81505311 (0.77880882)
# Finished training epoch 52
# Validate: MSE 0.00269735 (0.00223850), PSNR 25.69062614 (26.56277243), SSIM 0.71993423 (0.78739054)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00230755 (0.00227900), PSNR 26.36849022 (26.44470732), SSIM 0.76989502 (0.77868081)
# Finished training epoch 53
# Validate: MSE 0.00242001 (0.00233453), PSNR 26.16182327 (26.37560137), SSIM 0.72646463 (0.77819820)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00249199 (0.00227922), PSNR 26.03453636 (26.44459292), SSIM 0.79387271 (0.77869160)
# Finished training epoch 54
# Validate: MSE 0.00253825 (0.00243049), PSNR 25.95465851 (26.20675165), SSIM 0.72090673 (0.77937166)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00220766 (0.00228282), PSNR 26.56068420 (26.43982523), SSIM 0.78147221 (0.77891633)
# Finished training epoch 55
# Validate: MSE 0.00283281 (0.00238421), PSNR 25.47782326 (26.29819237), SSIM 0.72177476 (0.78527900)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00246127 (0.00226676), PSNR 26.08841324 (26.46777292), SSIM 0.77482688 (0.77921510)
# Finished training epoch 56
# Validate: MSE 0.00264993 (0.00226983), PSNR 25.76765442 (26.50844207), SSIM 0.72032750 (0.78602277)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00217328 (0.00226173), PSNR 26.62884140 (26.47888948), SSIM 0.78646296 (0.77933586)
# Finished training epoch 57
# Validate: MSE 0.00261625 (0.00232250), PSNR 25.82321167 (26.40504939), SSIM 0.72935909 (0.78700541)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00259444 (0.00226283), PSNR 25.85956001 (26.47821114), SSIM 0.76321697 (0.77915971)
# Finished training epoch 58
# Validate: MSE 0.00267194 (0.00239240), PSNR 25.73172760 (26.28619257), SSIM 0.72157490 (0.78455345)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00210314 (0.00226819), PSNR 26.77131844 (26.46845489), SSIM 0.78137457 (0.77886022)
# Finished training epoch 59
# Validate: MSE 0.00274475 (0.00236947), PSNR 25.61496353 (26.32489153), SSIM 0.72331464 (0.78600725)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00227186 (0.00226223), PSNR 26.43619156 (26.47839053), SSIM 0.77077407 (0.77906271)
# Finished training epoch 60
# Validate: MSE 0.00263477 (0.00223266), PSNR 25.79256439 (26.57757120), SSIM 0.72594863 (0.78770677)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00215007 (0.00226652), PSNR 26.67547226 (26.47266222), SSIM 0.78251797 (0.77885184)
# Finished training epoch 61
# Validate: MSE 0.00251097 (0.00261924), PSNR 26.00157928 (25.86266407), SSIM 0.71897894 (0.77231281)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00247680 (0.00226528), PSNR 26.06108284 (26.47257541), SSIM 0.74821430 (0.77882617)
# Finished training epoch 62
# Validate: MSE 0.00268737 (0.00226434), PSNR 25.70672798 (26.51079151), SSIM 0.72894073 (0.78669783)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00217201 (0.00226138), PSNR 26.63138962 (26.48122088), SSIM 0.78294593 (0.77905771)
# Finished training epoch 63
# Validate: MSE 0.00274635 (0.00226255), PSNR 25.61243248 (26.52169002), SSIM 0.72316408 (0.78676156)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00193669 (0.00226625), PSNR 27.12938881 (26.46831716), SSIM 0.77315104 (0.77897534)
# Finished training epoch 64
# Validate: MSE 0.00272934 (0.00233329), PSNR 25.63941956 (26.38078538), SSIM 0.72052842 (0.78588723)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00206037 (0.00225850), PSNR 26.86054420 (26.48444964), SSIM 0.78998572 (0.77900250)
# Finished training epoch 65
# Validate: MSE 0.00240675 (0.00239391), PSNR 26.18568611 (26.26924842), SSIM 0.72238648 (0.77386024)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00243609 (0.00224675), PSNR 26.13307190 (26.50698714), SSIM 0.77063292 (0.77909633)
# Finished training epoch 66
# Validate: MSE 0.00268988 (0.00255800), PSNR 25.70267296 (26.00947679), SSIM 0.72061372 (0.78119395)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00215201 (0.00226041), PSNR 26.67155075 (26.48198247), SSIM 0.78843760 (0.77864342)
# Finished training epoch 67
# Validate: MSE 0.00245258 (0.00238125), PSNR 26.10377502 (26.29289714), SSIM 0.72571945 (0.77805605)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00202130 (0.00224851), PSNR 26.94370079 (26.50130889), SSIM 0.78575170 (0.77926947)
# Finished training epoch 68
# Validate: MSE 0.00256145 (0.00227387), PSNR 25.91513824 (26.48833390), SSIM 0.72485864 (0.78365447)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00268546 (0.00225632), PSNR 25.70981789 (26.48617711), SSIM 0.77560949 (0.77885837)
# Finished training epoch 69
# Validate: MSE 0.00289853 (0.00243441), PSNR 25.37822151 (26.20278191), SSIM 0.71689886 (0.78570583)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00263944 (0.00224509), PSNR 25.78487587 (26.51244011), SSIM 0.74905539 (0.77924728)
# Finished training epoch 70
# Validate: MSE 0.00287758 (0.00241779), PSNR 25.40972137 (26.24032330), SSIM 0.71772563 (0.78243083)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00270278 (0.00224277), PSNR 25.68189430 (26.51624657), SSIM 0.77509385 (0.77906918)
# Finished training epoch 71
# Validate: MSE 0.00249538 (0.00258755), PSNR 26.02863693 (25.96230441), SSIM 0.72485316 (0.77495535)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00271875 (0.00224020), PSNR 25.65631294 (26.51856930), SSIM 0.75155485 (0.77915667)
# Finished training epoch 72
# Validate: MSE 0.00263659 (0.00278672), PSNR 25.78956604 (25.66147249), SSIM 0.72478580 (0.77772295)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00223807 (0.00224162), PSNR 26.50126266 (26.51692534), SSIM 0.78996366 (0.77912469)
# Finished training epoch 73
# Validate: MSE 0.00289071 (0.00244618), PSNR 25.38994789 (26.18431979), SSIM 0.72632098 (0.78496440)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00217341 (0.00224427), PSNR 26.62857819 (26.51159283), SSIM 0.78953958 (0.77892195)
# Finished training epoch 74
# Validate: MSE 0.00239180 (0.00224356), PSNR 26.21275520 (26.54646619), SSIM 0.72811377 (0.77899211)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00179176 (0.00223754), PSNR 27.46720695 (26.52832157), SSIM 0.79550922 (0.77904568)
# Finished training epoch 75
# Validate: MSE 0.00268638 (0.00224085), PSNR 25.70832634 (26.55378606), SSIM 0.72335076 (0.78798445)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00216693 (0.00224490), PSNR 26.64155197 (26.50978144), SSIM 0.77971351 (0.77894092)
# Finished training epoch 76
# Validate: MSE 0.00258558 (0.00231701), PSNR 25.87441254 (26.41434078), SSIM 0.72498608 (0.78524275)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00205159 (0.00223997), PSNR 26.87908745 (26.52049752), SSIM 0.78627408 (0.77947272)
# Finished training epoch 77
# Validate: MSE 0.00270164 (0.00240470), PSNR 25.68371773 (26.25278784), SSIM 0.71650517 (0.77571319)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00241966 (0.00223678), PSNR 26.16245461 (26.52761895), SSIM 0.78207749 (0.77913577)
# Finished training epoch 78
# Validate: MSE 0.00256432 (0.00231885), PSNR 25.91027069 (26.41025782), SSIM 0.72231603 (0.78057147)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00236750 (0.00223102), PSNR 26.25709534 (26.53797441), SSIM 0.77329367 (0.77935098)
# Finished training epoch 79
# Validate: MSE 0.00255073 (0.00231523), PSNR 25.93335915 (26.41840277), SSIM 0.72162187 (0.78219181)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00237096 (0.00225171), PSNR 26.25075150 (26.49953014), SSIM 0.75105220 (0.77874329)
# Finished training epoch 80
# Validate: MSE 0.00240554 (0.00307000), PSNR 26.18787193 (25.24082254), SSIM 0.72447747 (0.76290714)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00236921 (0.00223514), PSNR 26.25396538 (26.53196334), SSIM 0.77652264 (0.77908416)
# Finished training epoch 81
# Validate: MSE 0.00263462 (0.00234921), PSNR 25.79282761 (26.36005468), SSIM 0.72621298 (0.78716517)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00205849 (0.00222404), PSNR 26.86452103 (26.55096385), SSIM 0.78181636 (0.77944681)
# Finished training epoch 82
# Validate: MSE 0.00268395 (0.00258088), PSNR 25.71226120 (25.98551516), SSIM 0.72569788 (0.77736308)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00198815 (0.00223714), PSNR 27.01551056 (26.52745755), SSIM 0.78258002 (0.77908173)
# Finished training epoch 83
# Validate: MSE 0.00249476 (0.00220343), PSNR 26.02971268 (26.62994324), SSIM 0.73013473 (0.78462492)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00233607 (0.00223383), PSNR 26.31514359 (26.53319553), SSIM 0.77067316 (0.77926417)
# Finished training epoch 84
# Validate: MSE 0.00261815 (0.00228708), PSNR 25.82004738 (26.47274140), SSIM 0.73203176 (0.78649241)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00203361 (0.00222278), PSNR 26.91732025 (26.55476670), SSIM 0.79836005 (0.77935376)
# Finished training epoch 85
# Validate: MSE 0.00268123 (0.00229543), PSNR 25.71666336 (26.45572283), SSIM 0.72517860 (0.78716727)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00243179 (0.00222328), PSNR 26.14074516 (26.55209734), SSIM 0.78039485 (0.77934674)
# Finished training epoch 86
# Validate: MSE 0.00262500 (0.00239791), PSNR 25.80870628 (26.27244000), SSIM 0.72719759 (0.77998950)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00215570 (0.00222351), PSNR 26.66411781 (26.55482446), SSIM 0.78808987 (0.77921892)
# Finished training epoch 87
# Validate: MSE 0.00264779 (0.00228421), PSNR 25.77116013 (26.47901931), SSIM 0.72190845 (0.78445715)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00293567 (0.00222803), PSNR 25.32292938 (26.54382115), SSIM 0.78223497 (0.77904605)
# Finished training epoch 88
# Validate: MSE 0.00268191 (0.00227877), PSNR 25.71554756 (26.48887161), SSIM 0.72326422 (0.78869339)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00214177 (0.00222109), PSNR 26.69227219 (26.55585489), SSIM 0.76891816 (0.77906415)
# Finished training epoch 89
# Validate: MSE 0.00259454 (0.00232240), PSNR 25.85939789 (26.40277421), SSIM 0.72251511 (0.78212209)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00236379 (0.00222946), PSNR 26.26390839 (26.54121924), SSIM 0.77005738 (0.77904119)
# Finished training epoch 90
# Validate: MSE 0.00251160 (0.00225987), PSNR 26.00049019 (26.51596912), SSIM 0.72208494 (0.78030426)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00231877 (0.00222728), PSNR 26.34742928 (26.54578114), SSIM 0.77724272 (0.77912835)
# Finished training epoch 91
# Validate: MSE 0.00275025 (0.00237574), PSNR 25.60627937 (26.30776241), SSIM 0.72151434 (0.77918742)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00190106 (0.00222543), PSNR 27.21003723 (26.54906991), SSIM 0.79190999 (0.77928280)
# Finished training epoch 92
# Validate: MSE 0.00225696 (0.00230527), PSNR 26.46475410 (26.43200174), SSIM 0.73808908 (0.77862561)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00271729 (0.00221786), PSNR 25.65864563 (26.56225859), SSIM 0.77278721 (0.77896081)
# Finished training epoch 93
# Validate: MSE 0.00287160 (0.00241320), PSNR 25.41876411 (26.25124239), SSIM 0.72366697 (0.78417348)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00194727 (0.00221754), PSNR 27.10573006 (26.56329213), SSIM 0.80408001 (0.77915252)
# Finished training epoch 94
# Validate: MSE 0.00257385 (0.00234594), PSNR 25.89416504 (26.35127285), SSIM 0.72021115 (0.77639468)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00227847 (0.00221670), PSNR 26.42357254 (26.56368822), SSIM 0.78460616 (0.77915340)
# Finished training epoch 95
# Validate: MSE 0.00256435 (0.00237798), PSNR 25.91022682 (26.29969884), SSIM 0.72291088 (0.77968147)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00328590 (0.00221805), PSNR 24.83345795 (26.56323573), SSIM 0.78398389 (0.77902751)
# Finished training epoch 96
# Validate: MSE 0.00271565 (0.00228821), PSNR 25.66126251 (26.47298229), SSIM 0.72818565 (0.78807648)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00194164 (0.00221512), PSNR 27.11831093 (26.57175542), SSIM 0.78326857 (0.77937765)
# Finished training epoch 97
# Validate: MSE 0.00250844 (0.00221596), PSNR 26.00596046 (26.60246293), SSIM 0.72686768 (0.78434539)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00183740 (0.00221443), PSNR 27.35796165 (26.57103925), SSIM 0.78026086 (0.77908976)
# Finished training epoch 98
# Validate: MSE 0.00255492 (0.00222728), PSNR 25.92621994 (26.57745495), SSIM 0.72514975 (0.78527622)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00196755 (0.00221039), PSNR 27.06074524 (26.57737048), SSIM 0.79374146 (0.77956777)
# Finished training epoch 99
# Validate: MSE 0.00248397 (0.00220701), PSNR 26.04853249 (26.61880727), SSIM 0.72912395 (0.78582575)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00225668 (0.00221388), PSNR 26.46529007 (26.57000588), SSIM 0.79004633 (0.77920175)
# Finished training epoch 100
# Validate: MSE 0.00254393 (0.00230462), PSNR 25.94495392 (26.43342360), SSIM 0.72399122 (0.78331723)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00216591 (0.00222483), PSNR 26.64360046 (26.55137445), SSIM 0.79429990 (0.77894297)
# Finished training epoch 101
# Validate: MSE 0.00250399 (0.00222980), PSNR 26.01367760 (26.57391820), SSIM 0.72943527 (0.78482938)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00219065 (0.00221859), PSNR 26.59427643 (26.56092712), SSIM 0.76983041 (0.77923970)
# Finished training epoch 102
# Validate: MSE 0.00288924 (0.00234237), PSNR 25.39216995 (26.37323936), SSIM 0.72129965 (0.78580538)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00193883 (0.00220620), PSNR 27.12460327 (26.58795737), SSIM 0.78427052 (0.77889653)
# Finished training epoch 103
# Validate: MSE 0.00235111 (0.00225570), PSNR 26.28727150 (26.51960729), SSIM 0.72397035 (0.77735532)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00217317 (0.00221220), PSNR 26.62906647 (26.57396228), SSIM 0.77785468 (0.77881520)
# Finished training epoch 104
# Validate: MSE 0.00271879 (0.00226133), PSNR 25.65623856 (26.51976126), SSIM 0.72117555 (0.78403386)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00246636 (0.00220947), PSNR 26.07943344 (26.58066408), SSIM 0.77367508 (0.77910115)
# Finished training epoch 105
# Validate: MSE 0.00269377 (0.00221719), PSNR 25.69638824 (26.60624237), SSIM 0.72345805 (0.78659026)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00186842 (0.00220546), PSNR 27.28524590 (26.58577769), SSIM 0.77828306 (0.77891082)
# Finished training epoch 106
# Validate: MSE 0.00243337 (0.00223597), PSNR 26.13792038 (26.56608683), SSIM 0.73331714 (0.78438937)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00216874 (0.00220529), PSNR 26.63792229 (26.58993402), SSIM 0.77852499 (0.77907669)
# Finished training epoch 107
# Validate: MSE 0.00263359 (0.00230524), PSNR 25.79451942 (26.44400338), SSIM 0.72587121 (0.78553226)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00223220 (0.00220618), PSNR 26.51267052 (26.58430036), SSIM 0.77952254 (0.77905480)
# Finished training epoch 108
# Validate: MSE 0.00244283 (0.00219292), PSNR 26.12106514 (26.64711778), SSIM 0.73059273 (0.78352452)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00198951 (0.00219540), PSNR 27.01254463 (26.60708124), SSIM 0.78466737 (0.77913712)
# Finished training epoch 109
# Validate: MSE 0.00279129 (0.00226851), PSNR 25.54195595 (26.50884401), SSIM 0.71944451 (0.78736718)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00279664 (0.00220732), PSNR 25.53363419 (26.58443083), SSIM 0.76274627 (0.77906321)
# Finished training epoch 110
# Validate: MSE 0.00261101 (0.00223945), PSNR 25.83191299 (26.56033406), SSIM 0.72323358 (0.78538843)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00251196 (0.00220055), PSNR 25.99987221 (26.59482091), SSIM 0.77712262 (0.77913886)
# Finished training epoch 111
# Validate: MSE 0.00263247 (0.00246177), PSNR 25.79636002 (26.14321902), SSIM 0.72300053 (0.77832599)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00204984 (0.00219088), PSNR 26.88278961 (26.61561033), SSIM 0.79871887 (0.77915552)
# Finished training epoch 112
# Validate: MSE 0.00260262 (0.00228128), PSNR 25.84589005 (26.47140843), SSIM 0.72697949 (0.78433940)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00201414 (0.00220152), PSNR 26.95910072 (26.59648054), SSIM 0.79078269 (0.77903288)
# Finished training epoch 113
# Validate: MSE 0.00257449 (0.00223948), PSNR 25.89309502 (26.55277795), SSIM 0.71903074 (0.77841164)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00209673 (0.00220758), PSNR 26.78457832 (26.58501134), SSIM 0.78386086 (0.77862641)
# Finished training epoch 114
# Validate: MSE 0.00253851 (0.00225247), PSNR 25.95421219 (26.53362440), SSIM 0.72557402 (0.78329563)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00213670 (0.00220145), PSNR 26.70256615 (26.59650068), SSIM 0.77264845 (0.77913293)
# Finished training epoch 115
# Validate: MSE 0.00272964 (0.00223157), PSNR 25.63894463 (26.57719177), SSIM 0.72265977 (0.78918182)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00196420 (0.00219498), PSNR 27.06814766 (26.60896162), SSIM 0.77527523 (0.77888822)
# Finished training epoch 116
# Validate: MSE 0.00252291 (0.00220940), PSNR 25.98098755 (26.62067144), SSIM 0.72633678 (0.78532520)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00205425 (0.00219141), PSNR 26.87345695 (26.61613446), SSIM 0.79172939 (0.77901612)
# Finished training epoch 117
# Validate: MSE 0.00273210 (0.00228337), PSNR 25.63503265 (26.47885004), SSIM 0.72755420 (0.78989050)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00218076 (0.00218956), PSNR 26.61392403 (26.61883598), SSIM 0.78449142 (0.77926384)
# Finished training epoch 118
# Validate: MSE 0.00259530 (0.00219147), PSNR 25.85811806 (26.65365617), SSIM 0.72610116 (0.78815628)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00195475 (0.00220179), PSNR 27.08908653 (26.59651374), SSIM 0.79298556 (0.77878980)
# Finished training epoch 119
# Validate: MSE 0.00254682 (0.00228677), PSNR 25.94001198 (26.46190446), SSIM 0.72612804 (0.78517757)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00266992 (0.00219696), PSNR 25.73502159 (26.60226550), SSIM 0.74893963 (0.77876291)
# Finished training epoch 120
# Validate: MSE 0.00255529 (0.00222316), PSNR 25.92560196 (26.59212418), SSIM 0.72610056 (0.78559034)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00209582 (0.00219016), PSNR 26.78645134 (26.61720786), SSIM 0.77067530 (0.77929994)
# Finished training epoch 121
# Validate: MSE 0.00264993 (0.00227790), PSNR 25.76766205 (26.48370021), SSIM 0.71984506 (0.77940638)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00233113 (0.00219981), PSNR 26.32432556 (26.60267062), SSIM 0.77415669 (0.77859267)
# Finished training epoch 122
# Validate: MSE 0.00270606 (0.00244583), PSNR 25.67662621 (26.18677269), SSIM 0.72205788 (0.78363660)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00204272 (0.00219628), PSNR 26.89790344 (26.60370996), SSIM 0.78705156 (0.77868940)
# Finished training epoch 123
# Validate: MSE 0.00250812 (0.00219811), PSNR 26.00651360 (26.64029585), SSIM 0.72894788 (0.78810148)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00206633 (0.00219420), PSNR 26.84800911 (26.60937821), SSIM 0.77529359 (0.77899005)
# Finished training epoch 124
# Validate: MSE 0.00260223 (0.00273617), PSNR 25.84654999 (25.69294930), SSIM 0.72130036 (0.77079644)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00192278 (0.00218955), PSNR 27.16069794 (26.61709993), SSIM 0.79538804 (0.77923967)
# Finished training epoch 125
# Validate: MSE 0.00261855 (0.00228885), PSNR 25.81939316 (26.47010825), SSIM 0.72998047 (0.78597498)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00210985 (0.00218690), PSNR 26.75747490 (26.62478536), SSIM 0.77943683 (0.77903268)
# Finished training epoch 126
# Validate: MSE 0.00258613 (0.00223538), PSNR 25.87348938 (26.56722842), SSIM 0.72552156 (0.78291056)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00208700 (0.00220107), PSNR 26.80476761 (26.59761731), SSIM 0.78092176 (0.77856708)
# Finished training epoch 127
# Validate: MSE 0.00257478 (0.00222480), PSNR 25.89259338 (26.58809204), SSIM 0.72588730 (0.78313595)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00201590 (0.00218868), PSNR 26.95531464 (26.62254375), SSIM 0.77472365 (0.77871604)
# Finished training epoch 128
# Validate: MSE 0.00254182 (0.00232951), PSNR 25.94855118 (26.38584070), SSIM 0.72533035 (0.77781082)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00205361 (0.00218525), PSNR 26.87481689 (26.62780082), SSIM 0.78444171 (0.77894608)
# Finished training epoch 129
# Validate: MSE 0.00270024 (0.00223766), PSNR 25.68596840 (26.56449894), SSIM 0.72285998 (0.78968192)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00223150 (0.00219347), PSNR 26.51403809 (26.61150229), SSIM 0.75799018 (0.77865847)
# Finished training epoch 130
# Validate: MSE 0.00258080 (0.00219752), PSNR 25.88244820 (26.63838015), SSIM 0.71719372 (0.78173115)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00229343 (0.00218134), PSNR 26.39513588 (26.63542661), SSIM 0.77103060 (0.77873686)
# Finished training epoch 131
# Validate: MSE 0.00259921 (0.00221853), PSNR 25.85159111 (26.60218569), SSIM 0.72315848 (0.78325311)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00255711 (0.00218791), PSNR 25.92250443 (26.62448168), SSIM 0.77810812 (0.77870296)
# Finished training epoch 132
# Validate: MSE 0.00252757 (0.00218303), PSNR 25.97296143 (26.66614431), SSIM 0.72364759 (0.78480780)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00272002 (0.00218451), PSNR 25.65427780 (26.62771965), SSIM 0.77237839 (0.77878066)
# Finished training epoch 133
# Validate: MSE 0.00253460 (0.00224558), PSNR 25.96090317 (26.54859138), SSIM 0.72383213 (0.78312767)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00247532 (0.00218896), PSNR 26.06367683 (26.62498621), SSIM 0.77862370 (0.77857703)
# Finished training epoch 134
# Validate: MSE 0.00261792 (0.00237649), PSNR 25.82042885 (26.30535285), SSIM 0.72187269 (0.78025114)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00214326 (0.00217664), PSNR 26.68925858 (26.64575694), SSIM 0.76474822 (0.77897277)
# Finished training epoch 135
# Validate: MSE 0.00258133 (0.00225604), PSNR 25.88157082 (26.52684491), SSIM 0.72604680 (0.78195597)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00258625 (0.00219058), PSNR 25.87330246 (26.61877264), SSIM 0.75341201 (0.77885795)
# Finished training epoch 136
# Validate: MSE 0.00260843 (0.00221247), PSNR 25.83620453 (26.60881957), SSIM 0.72123849 (0.78273009)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00173846 (0.00217373), PSNR 27.59836388 (26.64992271), SSIM 0.79603910 (0.77919043)
# Finished training epoch 137
# Validate: MSE 0.00287943 (0.00235026), PSNR 25.40693092 (26.35889901), SSIM 0.72032237 (0.78362769)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00210924 (0.00218892), PSNR 26.75873566 (26.61928709), SSIM 0.77189261 (0.77870162)
# Finished training epoch 138
# Validate: MSE 0.00262331 (0.00238054), PSNR 25.81150246 (26.31114272), SSIM 0.72700381 (0.78434820)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00213165 (0.00218223), PSNR 26.71284294 (26.63005783), SSIM 0.76266605 (0.77864894)
# Finished training epoch 139
# Validate: MSE 0.00264137 (0.00230658), PSNR 25.78171349 (26.43746634), SSIM 0.72606027 (0.77943210)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00221470 (0.00217677), PSNR 26.54685593 (26.64464430), SSIM 0.77972567 (0.77903650)
# Finished training epoch 140
# Validate: MSE 0.00254281 (0.00223087), PSNR 25.94685364 (26.57386140), SSIM 0.72378582 (0.78615416)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00209512 (0.00218549), PSNR 26.78791237 (26.62509906), SSIM 0.78639185 (0.77859158)
# Finished training epoch 141
# Validate: MSE 0.00257222 (0.00221711), PSNR 25.89691925 (26.60331969), SSIM 0.72215569 (0.78655827)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00201723 (0.00217784), PSNR 26.95245361 (26.64424199), SSIM 0.77017641 (0.77860975)
# Finished training epoch 142
# Validate: MSE 0.00248335 (0.00219971), PSNR 26.04962540 (26.63847725), SSIM 0.72307169 (0.78010146)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00186779 (0.00218021), PSNR 27.28671265 (26.63909114), SSIM 0.80150384 (0.77866215)
# Finished training epoch 143
# Validate: MSE 0.00275606 (0.00226640), PSNR 25.59710884 (26.50934168), SSIM 0.72116292 (0.78194882)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00211623 (0.00218665), PSNR 26.74437714 (26.62460480), SSIM 0.78104436 (0.77809229)
# Finished training epoch 144
# Validate: MSE 0.00265832 (0.00227138), PSNR 25.75392532 (26.49816761), SSIM 0.72411549 (0.78348364)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00157159 (0.00217357), PSNR 28.03661919 (26.65470074), SSIM 0.80039197 (0.77876807)
# Finished training epoch 145
# Validate: MSE 0.00232136 (0.00220239), PSNR 26.34257317 (26.62760923), SSIM 0.72866070 (0.78234029)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00254156 (0.00218108), PSNR 25.94898796 (26.63720200), SSIM 0.76812971 (0.77857633)
# Finished training epoch 146
# Validate: MSE 0.00255730 (0.00225053), PSNR 25.92217827 (26.53950066), SSIM 0.71995306 (0.78159734)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00270423 (0.00217313), PSNR 25.67956734 (26.65116763), SSIM 0.77218831 (0.77884085)
# Finished training epoch 147
# Validate: MSE 0.00247791 (0.00226768), PSNR 26.05914307 (26.50160220), SSIM 0.72638321 (0.77671914)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00182842 (0.00217436), PSNR 27.37924576 (26.64842899), SSIM 0.77828920 (0.77828868)
# Finished training epoch 148
# Validate: MSE 0.00253178 (0.00225429), PSNR 25.96573830 (26.53686015), SSIM 0.72583497 (0.78500733)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00246508 (0.00218027), PSNR 26.08168411 (26.63926972), SSIM 0.76580083 (0.77861742)
# Finished training epoch 149
# Validate: MSE 0.00265179 (0.00223887), PSNR 25.76461601 (26.56657846), SSIM 0.71579581 (0.77997964)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00277798 (0.00217459), PSNR 25.56270027 (26.65338241), SSIM 0.75293970 (0.77850740)
# Finished training epoch 150
# Validate: MSE 0.00269075 (0.00230807), PSNR 25.70125961 (26.43260402), SSIM 0.72476077 (0.78353999)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00256003 (0.00217234), PSNR 25.91755295 (26.65235800), SSIM 0.77262890 (0.77875551)
# Finished training epoch 151
# Validate: MSE 0.00244085 (0.00224250), PSNR 26.12459373 (26.55196451), SSIM 0.72691911 (0.77952711)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00190379 (0.00217208), PSNR 27.20381737 (26.65291182), SSIM 0.78639758 (0.77861806)
# Finished training epoch 152
# Validate: MSE 0.00234894 (0.00229746), PSNR 26.29127693 (26.43908638), SSIM 0.72912186 (0.77479057)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00202828 (0.00217593), PSNR 26.92872047 (26.64906962), SSIM 0.79301476 (0.77884871)
# Finished training epoch 153
# Validate: MSE 0.00243726 (0.00223985), PSNR 26.13098145 (26.54936033), SSIM 0.72789723 (0.78430078)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00179217 (0.00217233), PSNR 27.46621132 (26.65273502), SSIM 0.76902705 (0.77855964)
# Finished training epoch 154
# Validate: MSE 0.00260199 (0.00220071), PSNR 25.84694099 (26.63430398), SSIM 0.72141343 (0.78264166)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00216994 (0.00217534), PSNR 26.63551331 (26.64819006), SSIM 0.78387004 (0.77845077)
# Finished training epoch 155
# Validate: MSE 0.00286129 (0.00245904), PSNR 25.43437767 (26.16207498), SSIM 0.71590096 (0.77748959)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00191489 (0.00216583), PSNR 27.17856026 (26.66933609), SSIM 0.76947367 (0.77859283)
# Finished training epoch 156
# Validate: MSE 0.00261544 (0.00233282), PSNR 25.82455444 (26.38244517), SSIM 0.72874606 (0.77991651)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00228795 (0.00216815), PSNR 26.40552521 (26.66332615), SSIM 0.78585070 (0.77869168)
# Finished training epoch 157
# Validate: MSE 0.00248254 (0.00219411), PSNR 26.05104065 (26.64274873), SSIM 0.72486699 (0.78475822)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00241666 (0.00216988), PSNR 26.16784286 (26.66007025), SSIM 0.75571042 (0.77850561)
# Finished training epoch 158
# Validate: MSE 0.00233574 (0.00223287), PSNR 26.31575775 (26.56133622), SSIM 0.73247397 (0.77961530)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00234758 (0.00216970), PSNR 26.29379272 (26.65759557), SSIM 0.79280758 (0.77838431)
# Finished training epoch 159
# Validate: MSE 0.00232248 (0.00231175), PSNR 26.34047699 (26.41444213), SSIM 0.72729504 (0.77850159)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00214472 (0.00216112), PSNR 26.68629646 (26.67500337), SSIM 0.76445073 (0.77863393)
# Finished training epoch 160
# Validate: MSE 0.00267430 (0.00225701), PSNR 25.72790146 (26.52468554), SSIM 0.71978533 (0.78058373)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00200899 (0.00216056), PSNR 26.97023010 (26.67790698), SSIM 0.78119355 (0.77830759)
# Finished training epoch 161
# Validate: MSE 0.00253922 (0.00221723), PSNR 25.95300293 (26.60364548), SSIM 0.73057908 (0.78417871)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00178515 (0.00215441), PSNR 27.48325157 (26.68914772), SSIM 0.79183084 (0.77884084)
# Finished training epoch 162
# Validate: MSE 0.00252329 (0.00220338), PSNR 25.98033333 (26.62625789), SSIM 0.72502661 (0.78191257)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00218794 (0.00216675), PSNR 26.59964752 (26.66505101), SSIM 0.78093064 (0.77807014)
# Finished training epoch 163
# Validate: MSE 0.00253162 (0.00223157), PSNR 25.96601486 (26.57104394), SSIM 0.72218466 (0.78001403)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00251971 (0.00216870), PSNR 25.98649216 (26.65964757), SSIM 0.74923426 (0.77860384)
# Finished training epoch 164
# Validate: MSE 0.00232584 (0.00232054), PSNR 26.33419991 (26.39291824), SSIM 0.73040885 (0.77285626)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00246225 (0.00216201), PSNR 26.08668327 (26.67512704), SSIM 0.77064031 (0.77845965)
# Finished training epoch 165
# Validate: MSE 0.00239600 (0.00230646), PSNR 26.20513916 (26.41959470), SSIM 0.72752035 (0.77486417)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00236164 (0.00216473), PSNR 26.26785851 (26.66847105), SSIM 0.78257048 (0.77816432)
# Finished training epoch 166
# Validate: MSE 0.00255485 (0.00218048), PSNR 25.92634964 (26.67228143), SSIM 0.72564518 (0.78307113)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00224334 (0.00215922), PSNR 26.49105263 (26.67865618), SSIM 0.77289551 (0.77857135)
# Finished training epoch 167
# Validate: MSE 0.00264936 (0.00223064), PSNR 25.76859283 (26.57944520), SSIM 0.72503591 (0.78711438)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00257354 (0.00215592), PSNR 25.89468956 (26.68494248), SSIM 0.77235568 (0.77875789)
# Finished training epoch 168
# Validate: MSE 0.00263012 (0.00228283), PSNR 25.80024147 (26.47936276), SSIM 0.72230649 (0.78117119)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00210529 (0.00215380), PSNR 26.76688576 (26.68895019), SSIM 0.78074855 (0.77834253)
# Finished training epoch 169
# Validate: MSE 0.00267171 (0.00224256), PSNR 25.73211098 (26.56036957), SSIM 0.72605634 (0.78476696)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00186103 (0.00216215), PSNR 27.30247498 (26.67325062), SSIM 0.78024375 (0.77811326)
# Finished training epoch 170
# Validate: MSE 0.00241229 (0.00226008), PSNR 26.17570305 (26.50741140), SSIM 0.72511536 (0.78032643)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00203663 (0.00216316), PSNR 26.91087723 (26.67472660), SSIM 0.77263993 (0.77832118)
# Finished training epoch 171
# Validate: MSE 0.00231665 (0.00224458), PSNR 26.35139656 (26.54460425), SSIM 0.72803593 (0.77488899)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00236931 (0.00215513), PSNR 26.25377274 (26.68857918), SSIM 0.75281835 (0.77844575)
# Finished training epoch 172
# Validate: MSE 0.00230474 (0.00229899), PSNR 26.37378883 (26.44318744), SSIM 0.72998101 (0.77601973)
# Finished validation.
# Starting training epoch 173
# ...
# Finished validation.
# Starting training epoch 250
# Epoch: 250, MSE 0.00217471 (0.00211443), PSNR 26.62599182 (26.76939258), SSIM 0.76022279 (0.77736019)
# Finished training epoch 250
# Validate: MSE 0.00260643 (0.00223329), PSNR 25.83953667 (26.57091819), SSIM 0.72377330 (0.77685779)
# Finished validation.
# Starting training epoch 251
# Epoch: 251, MSE 0.00212868 (0.00211243), PSNR 26.71889877 (26.77587237), SSIM 0.77957124 (0.77729293)
# Finished training epoch 251
# Validate: MSE 0.00256609 (0.00227001), PSNR 25.90727615 (26.50004910), SSIM 0.72536099 (0.78221176)
# Finished validation.
# Starting training epoch 252
# Epoch: 252, MSE 0.00257880 (0.00211078), PSNR 25.88582993 (26.77805243), SSIM 0.76544368 (0.77739565)
# Finished training epoch 252
# Validate: MSE 0.00251067 (0.00222484), PSNR 26.00209427 (26.57965091), SSIM 0.71244371 (0.77309406)
# Finished validation.
# Starting training epoch 253
# Epoch: 253, MSE 0.00196678 (0.00212637), PSNR 27.06244278 (26.74634437), SSIM 0.77317464 (0.77693814)
# Finished training epoch 253
# Validate: MSE 0.00244481 (0.00223441), PSNR 26.11754799 (26.56290990), SSIM 0.71457630 (0.76951762)
# Finished validation.
# Starting training epoch 254
# Epoch: 254, MSE 0.00198580 (0.00211189), PSNR 27.02064705 (26.77521075), SSIM 0.79564250 (0.77705177)
# Finished training epoch 254
# Validate: MSE 0.00243050 (0.00228080), PSNR 26.14303780 (26.46845523), SSIM 0.72366691 (0.77798137)
# Finished validation.
# Starting training epoch 255
# Epoch: 255, MSE 0.00204682 (0.00211397), PSNR 26.88919830 (26.77005374), SSIM 0.75620687 (0.77742423)
# Finished training epoch 255
# Validate: MSE 0.00240919 (0.00223167), PSNR 26.18129158 (26.57495589), SSIM 0.72464675 (0.77731414)
# Finished validation.
# Starting training epoch 256
# Epoch: 256, MSE 0.00205876 (0.00211727), PSNR 26.86394501 (26.76289576), SSIM 0.77599800 (0.77712754)
# Finished training epoch 256
# Validate: MSE 0.00243144 (0.00216075), PSNR 26.14136314 (26.71346747), SSIM 0.72341478 (0.78313552)
# Finished validation.
# Starting training epoch 257
# Epoch: 257, MSE 0.00181936 (0.00211428), PSNR 27.40080452 (26.77473171), SSIM 0.78241235 (0.77703411)
# Finished training epoch 257
# Validate: MSE 0.00248005 (0.00221340), PSNR 26.05538750 (26.60261477), SSIM 0.71614581 (0.77203578)
# Finished validation.
# Starting training epoch 258
# Epoch: 258, MSE 0.00233557 (0.00211595), PSNR 26.31606102 (26.76667818), SSIM 0.76104134 (0.77731681)
# Finished training epoch 258
# Validate: MSE 0.00242945 (0.00221017), PSNR 26.14491653 (26.61343155), SSIM 0.73084664 (0.78276957)
# Finished validation.
# Starting training epoch 259
# Epoch: 259, MSE 0.00222030 (0.00211630), PSNR 26.53587532 (26.76928251), SSIM 0.77232897 (0.77683308)
# Finished training epoch 259
# Validate: MSE 0.00245584 (0.00224584), PSNR 26.09799194 (26.54215149), SSIM 0.72550267 (0.77495692)
# Finished validation.
# Starting training epoch 260
# Epoch: 260, MSE 0.00201460 (0.00211199), PSNR 26.95811272 (26.77387383), SSIM 0.77599400 (0.77737391)
# Finished training epoch 260
# Validate: MSE 0.00247008 (0.00217036), PSNR 26.07288170 (26.69081717), SSIM 0.72988331 (0.78505144)
# Finished validation.
# Starting training epoch 261
# Epoch: 261, MSE 0.00222121 (0.00210831), PSNR 26.53409386 (26.78217183), SSIM 0.77649099 (0.77725156)
# Finished training epoch 261
# Validate: MSE 0.00263683 (0.00228512), PSNR 25.78917503 (26.47444530), SSIM 0.72282618 (0.77972955)
# Finished validation.
# Starting training epoch 262
# Epoch: 262, MSE 0.00209443 (0.00210599), PSNR 26.78933716 (26.78634299), SSIM 0.77407402 (0.77739901)
# Finished training epoch 262
# Validate: MSE 0.00247832 (0.00225317), PSNR 26.05843163 (26.53234676), SSIM 0.71746510 (0.77289434)
# Finished validation.
# Starting training epoch 263
# Epoch: 263, MSE 0.00180892 (0.00211033), PSNR 27.42579842 (26.78133313), SSIM 0.79286635 (0.77710351)
# Finished training epoch 263
# Validate: MSE 0.00250748 (0.00220039), PSNR 26.00762558 (26.63529482), SSIM 0.71918285 (0.78080766)
# Finished validation.
# Starting training epoch 264
# Epoch: 264, MSE 0.00208147 (0.00210673), PSNR 26.81630135 (26.78723320), SSIM 0.77244031 (0.77711704)
# Finished training epoch 264
# Validate: MSE 0.00251276 (0.00238484), PSNR 25.99848557 (26.28281596), SSIM 0.72560030 (0.77059802)
# Finished validation.
# Starting training epoch 265
# Epoch: 265, MSE 0.00226749 (0.00211402), PSNR 26.44454956 (26.77130885), SSIM 0.75765884 (0.77724832)
# Finished training epoch 265
# Validate: MSE 0.00270667 (0.00225987), PSNR 25.67565346 (26.52052748), SSIM 0.70759869 (0.77237685)
# Finished validation.
# Starting training epoch 266
# Epoch: 266, MSE 0.00221141 (0.00211125), PSNR 26.55331230 (26.77762333), SSIM 0.76954383 (0.77720751)
# Finished training epoch 266
# Validate: MSE 0.00233261 (0.00222933), PSNR 26.32157135 (26.57987177), SSIM 0.72102571 (0.77448690)
# Finished validation.
# Starting training epoch 267
# Epoch: 267, MSE 0.00191084 (0.00211647), PSNR 27.18774605 (26.76433356), SSIM 0.77422523 (0.77663343)
# Finished training epoch 267
# Validate: MSE 0.00255931 (0.00218538), PSNR 25.91876602 (26.66841800), SSIM 0.72487253 (0.78353888)
# Finished validation.
# Starting training epoch 268
# Epoch: 268, MSE 0.00186136 (0.00210879), PSNR 27.30170631 (26.78304815), SSIM 0.77797461 (0.77708134)
# Finished training epoch 268
# Validate: MSE 0.00259397 (0.00219928), PSNR 25.86034393 (26.63882216), SSIM 0.71231198 (0.77763079)
# Finished validation.
# Starting training epoch 269
# Epoch: 269, MSE 0.00172643 (0.00211276), PSNR 27.62851715 (26.77569776), SSIM 0.78803045 (0.77683141)
# Finished training epoch 269
# Validate: MSE 0.00247587 (0.00219005), PSNR 26.06271744 (26.65697925), SSIM 0.72803897 (0.78375342)
# Finished validation.
# Starting training epoch 270
# Epoch: 270, MSE 0.00199054 (0.00210899), PSNR 27.01029015 (26.77857440), SSIM 0.80169928 (0.77714838)
# Finished training epoch 270
# Validate: MSE 0.00251557 (0.00219505), PSNR 25.99362946 (26.64769247), SSIM 0.72438687 (0.78235997)
# Finished validation.
# Starting training epoch 271
# Epoch: 271, MSE 0.00239687 (0.00210988), PSNR 26.20355606 (26.77841139), SSIM 0.76194125 (0.77689633)
# Finished training epoch 271
# Validate: MSE 0.00231208 (0.00221716), PSNR 26.35997581 (26.59772997), SSIM 0.72393942 (0.77588181)
# Finished validation.
# Starting training epoch 272
# Epoch: 272, MSE 0.00222233 (0.00210442), PSNR 26.53191757 (26.78931011), SSIM 0.75247043 (0.77701410)
# Finished training epoch 272
# Validate: MSE 0.00258163 (0.00225228), PSNR 25.88106155 (26.53749822), SSIM 0.72826397 (0.78168941)
# Finished validation.
# Starting training epoch 273
# Epoch: 273, MSE 0.00198071 (0.00211907), PSNR 27.03178596 (26.76158510), SSIM 0.77326238 (0.77677990)
# Finished training epoch 273
# Validate: MSE 0.00272482 (0.00228158), PSNR 25.64662552 (26.48195999), SSIM 0.72288066 (0.78313432)
# Finished validation.
# Starting training epoch 274
# Epoch: 274, MSE 0.00267113 (0.00210464), PSNR 25.73304939 (26.78887316), SSIM 0.78764993 (0.77698798)
# Finished training epoch 274
# Validate: MSE 0.00256321 (0.00224558), PSNR 25.91215706 (26.54963660), SSIM 0.72282088 (0.78171542)
# Finished validation.
# Starting training epoch 275
# Epoch: 275, MSE 0.00186235 (0.00210355), PSNR 27.29938507 (26.78968996), SSIM 0.79570258 (0.77693855)
# Finished training epoch 275
# Validate: MSE 0.00258290 (0.00219111), PSNR 25.87891388 (26.64779825), SSIM 0.71757662 (0.77787179)
# Finished validation.
# Starting training epoch 276
# Epoch: 276, MSE 0.00173154 (0.00211350), PSNR 27.61567688 (26.77333667), SSIM 0.79573661 (0.77692224)
# Finished training epoch 276
# Validate: MSE 0.00262631 (0.00228315), PSNR 25.80653572 (26.48345415), SSIM 0.71805751 (0.77646442)
# Finished validation.
# Starting training epoch 277
# Epoch: 277, MSE 0.00225773 (0.00210898), PSNR 26.46327782 (26.78185602), SSIM 0.76431906 (0.77672706)
# Finished training epoch 277
# Validate: MSE 0.00249320 (0.00221657), PSNR 26.03242302 (26.60361347), SSIM 0.72406471 (0.77556955)
# Finished validation.
# Starting training epoch 278
# Epoch: 278, MSE 0.00188723 (0.00210714), PSNR 27.24174500 (26.78683399), SSIM 0.79633212 (0.77698855)
# Finished training epoch 278
# Validate: MSE 0.00259673 (0.00223122), PSNR 25.85572815 (26.57997751), SSIM 0.71152794 (0.77990724)
# Finished validation.
# Starting training epoch 279
# Epoch: 279, MSE 0.00178978 (0.00210114), PSNR 27.47200203 (26.79888218), SSIM 0.77721202 (0.77701465)
# Finished training epoch 279
# Validate: MSE 0.00269621 (0.00221030), PSNR 25.69245338 (26.61323566), SSIM 0.71645105 (0.78339837)
# Finished validation.
# Starting training epoch 280
# Epoch: 280, MSE 0.00221945 (0.00209370), PSNR 26.53754425 (26.81652969), SSIM 0.77578700 (0.77724993)
# Finished training epoch 280
# Validate: MSE 0.00247366 (0.00223119), PSNR 26.06659698 (26.56726434), SSIM 0.72088361 (0.77386396)
# Finished validation.
# Starting training epoch 281
# Epoch: 281, MSE 0.00213397 (0.00209734), PSNR 26.70812225 (26.80282550), SSIM 0.77746326 (0.77724150)
# Finished training epoch 281
# Validate: MSE 0.00254974 (0.00218056), PSNR 25.93504333 (26.67403840), SSIM 0.71779895 (0.78157374)
# Finished validation.
# Starting training epoch 282
# Epoch: 282, MSE 0.00160863 (0.00210390), PSNR 27.93543816 (26.79095087), SSIM 0.79685229 (0.77700674)
# Finished training epoch 282
# Validate: MSE 0.00253656 (0.00220395), PSNR 25.95755577 (26.63076903), SSIM 0.72411567 (0.78491607)
# Finished validation.
# Starting training epoch 283
# Epoch: 283, MSE 0.00223908 (0.00209601), PSNR 26.49930382 (26.80715186), SSIM 0.77014804 (0.77676939)
# Finished training epoch 283
# Validate: MSE 0.00244706 (0.00226866), PSNR 26.11356163 (26.49500453), SSIM 0.71763092 (0.77173847)
# Finished validation.
# Starting training epoch 284
# Epoch: 284, MSE 0.00171813 (0.00209801), PSNR 27.64944077 (26.80233974), SSIM 0.78717411 (0.77725358)
# Finished training epoch 284
# Validate: MSE 0.00234939 (0.00218719), PSNR 26.29044151 (26.65837647), SSIM 0.72701651 (0.77663219)
# Finished validation.
# Starting training epoch 285
# Epoch: 285, MSE 0.00246717 (0.00210698), PSNR 26.07801247 (26.78640435), SSIM 0.75076371 (0.77699571)
# Finished training epoch 285
# Validate: MSE 0.00257439 (0.00222081), PSNR 25.89326096 (26.59463356), SSIM 0.72347939 (0.77604195)
# Finished validation.
# Starting training epoch 286
# Epoch: 286, MSE 0.00220867 (0.00210014), PSNR 26.55868721 (26.79886750), SSIM 0.76937950 (0.77675503)
# Finished training epoch 286
# Validate: MSE 0.00256946 (0.00231359), PSNR 25.90157509 (26.41504355), SSIM 0.71079087 (0.76795318)
# Finished validation.
# Starting training epoch 287
# Epoch: 287, MSE 0.00164865 (0.00210221), PSNR 27.82872009 (26.79708323), SSIM 0.78635252 (0.77676078)
# Finished training epoch 287
# Validate: MSE 0.00237678 (0.00226360), PSNR 26.24010468 (26.50458229), SSIM 0.71907139 (0.77099800)
# Finished validation.
# Starting training epoch 288
# Epoch: 288, MSE 0.00204456 (0.00209863), PSNR 26.89399529 (26.80005197), SSIM 0.77713490 (0.77689261)
# Finished training epoch 288
# Validate: MSE 0.00254916 (0.00227770), PSNR 25.93602562 (26.48202518), SSIM 0.71788824 (0.77326085)
# Finished validation.
# Starting training epoch 289
# Epoch: 289, MSE 0.00241341 (0.00209236), PSNR 26.17369461 (26.81636620), SSIM 0.77236331 (0.77693240)
# Finished training epoch 289
# Validate: MSE 0.00241903 (0.00222665), PSNR 26.16358948 (26.57638994), SSIM 0.71594548 (0.77177593)
# Finished validation.
# Starting training epoch 290
# Epoch: 290, MSE 0.00211398 (0.00210494), PSNR 26.74898720 (26.78931002), SSIM 0.77365267 (0.77675033)
# Finished training epoch 290
# Validate: MSE 0.00263381 (0.00219883), PSNR 25.79415512 (26.63725900), SSIM 0.72294760 (0.78577517)
# Finished validation.
# Starting training epoch 291
# Epoch: 291, MSE 0.00195502 (0.00210942), PSNR 27.08848572 (26.78184118), SSIM 0.77197033 (0.77648251)
# Finished training epoch 291
# Validate: MSE 0.00253774 (0.00225166), PSNR 25.95552635 (26.52846913), SSIM 0.71291000 (0.77233372)
# Finished validation.
# Starting training epoch 292
# Epoch: 292, MSE 0.00181173 (0.00210649), PSNR 27.41906738 (26.78428093), SSIM 0.79113293 (0.77681245)
# Finished training epoch 292
# Validate: MSE 0.00246770 (0.00219225), PSNR 26.07707787 (26.64989757), SSIM 0.72031277 (0.77875673)
# Finished validation.
# Starting training epoch 293
# Epoch: 293, MSE 0.00204098 (0.00210157), PSNR 26.90161324 (26.79547671), SSIM 0.79002464 (0.77688965)
# Finished training epoch 293
# Validate: MSE 0.00241416 (0.00224572), PSNR 26.17234612 (26.54970017), SSIM 0.72197604 (0.78078132)
# Finished validation.
# Starting training epoch 294
# Epoch: 294, MSE 0.00176820 (0.00210268), PSNR 27.52469444 (26.79343233), SSIM 0.79684913 (0.77626341)
# Finished training epoch 294
# Validate: MSE 0.00253879 (0.00219600), PSNR 25.95372772 (26.64426051), SSIM 0.72445655 (0.78226657)
# Finished validation.
# Starting training epoch 295
# Epoch: 295, MSE 0.00175159 (0.00210011), PSNR 27.56566620 (26.79892021), SSIM 0.78492385 (0.77668417)
# Finished training epoch 295
# Validate: MSE 0.00271126 (0.00237196), PSNR 25.66829300 (26.31580867), SSIM 0.70999694 (0.77489392)
# Finished validation.
# Starting training epoch 296
# Epoch: 296, MSE 0.00196278 (0.00211102), PSNR 27.07128525 (26.77413282), SSIM 0.78280020 (0.77616545)
# Finished training epoch 296
# Validate: MSE 0.00262286 (0.00224332), PSNR 25.81224823 (26.55287787), SSIM 0.72032297 (0.77718473)
# Finished validation.
# Starting training epoch 297
# Epoch: 297, MSE 0.00218292 (0.00210352), PSNR 26.60961723 (26.79186693), SSIM 0.77275425 (0.77666949)
# Finished training epoch 297
# Validate: MSE 0.00239932 (0.00219881), PSNR 26.19911194 (26.63474717), SSIM 0.71276999 (0.77329984)
# Finished validation.
# Starting training epoch 298
# Epoch: 298, MSE 0.00211611 (0.00209938), PSNR 26.74461555 (26.80270651), SSIM 0.77366745 (0.77694511)
# Finished training epoch 298
# Validate: MSE 0.00237789 (0.00220027), PSNR 26.23807335 (26.63078490), SSIM 0.72039121 (0.77355696)
# Finished validation.
# Starting training epoch 299
# Epoch: 299, MSE 0.00184186 (0.00209117), PSNR 27.34742165 (26.82013418), SSIM 0.77214319 (0.77663967)
# Finished training epoch 299
# Validate: MSE 0.00232623 (0.00226132), PSNR 26.33346367 (26.51147663), SSIM 0.72266424 (0.77251262)
# Finished validation.
# Starting training epoch 300
# Epoch: 300, MSE 0.00216203 (0.00209328), PSNR 26.65137863 (26.81540815), SSIM 0.76259506 (0.77675773)
# Finished training epoch 300
# Validate: MSE 0.00239420 (0.00218629), PSNR 26.20839500 (26.65749596), SSIM 0.72051096 (0.77748099)
# Finished validation.
# Starting training epoch 301
# Epoch: 301, MSE 0.00187773 (0.00209188), PSNR 27.26365852 (26.81739536), SSIM 0.77755558 (0.77718270)
# Finished training epoch 301
# Validate: MSE 0.00252903 (0.00226195), PSNR 25.97046471 (26.50665440), SSIM 0.71355861 (0.76809055)
# Finished validation.
# Starting training epoch 302
# Epoch: 302, MSE 0.00253991 (0.00209779), PSNR 25.95181465 (26.80364367), SSIM 0.77107477 (0.77647001)
# Finished training epoch 302
# Validate: MSE 0.00246067 (0.00228534), PSNR 26.08947372 (26.46691237), SSIM 0.72280675 (0.76489928)
# Finished validation.
# Starting training epoch 303
# Epoch: 303, MSE 0.00170305 (0.00209874), PSNR 27.68772697 (26.80067311), SSIM 0.78341961 (0.77672454)
# Finished training epoch 303
# Validate: MSE 0.00262963 (0.00219560), PSNR 25.80106163 (26.64639615), SSIM 0.72171837 (0.78448776)
# Finished validation.
# Starting training epoch 304
# Epoch: 304, MSE 0.00221943 (0.00209116), PSNR 26.53759003 (26.81590526), SSIM 0.77571338 (0.77691803)
# Finished training epoch 304
# Validate: MSE 0.00267221 (0.00236252), PSNR 25.73129082 (26.32353891), SSIM 0.71209121 (0.76900886)
# Finished validation.
# Starting training epoch 305
# Epoch: 305, MSE 0.00212219 (0.00208540), PSNR 26.73215103 (26.83162186), SSIM 0.77064520 (0.77706298)
# Finished training epoch 305
# Validate: MSE 0.00259128 (0.00230299), PSNR 25.86485672 (26.44265184), SSIM 0.71687031 (0.76980468)
# Finished validation.
# Starting training epoch 306
# Epoch: 306, MSE 0.00202814 (0.00209071), PSNR 26.92902184 (26.81781743), SSIM 0.78232169 (0.77674238)
# Finished training epoch 306
# Validate: MSE 0.00255536 (0.00222635), PSNR 25.92548370 (26.58402491), SSIM 0.72536290 (0.78011015)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00240837 (0.00222493), PSNR 26.18276405 (26.58702870), SSIM 0.72831553 (0.78031262)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
