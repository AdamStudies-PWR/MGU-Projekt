# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-f803807fc6935c0" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f803807fc6935c0");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256
p1 = .75

class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.dropout(x, p=p1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.max_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.dropout(x, p=p1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x)), negative_slope=0.1)
        x = F.dropout(x, p=p1)
        x = F.interpolate(self.convtrans3(x), scale_factor=scale_factor)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 16, 16]           2,306
# ================================================================
# Total params: 2,662,274
# Trainable params: 2,662,274
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.75
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.91
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.03388810 (0.93333788), PSNR 14.69952679 (8.53339034), SSIM 0.25305301 (0.08514557)
# Finished training epoch 0
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 6 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 14 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 116 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 10 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 97 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.03650992 (0.03360692), PSNR 14.37588978 (15.08183875), SSIM 0.21280637 (0.23963901)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00709825 (0.01570231), PSNR 21.48848343 (18.54908478), SSIM 0.53417128 (0.39284576)
# Finished training epoch 1
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 15 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00720866 (0.00652036), PSNR 21.42145157 (22.01351016), SSIM 0.45609725 (0.52920665)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00326057 (0.00417200), PSNR 24.86706161 (23.90178636), SSIM 0.67344320 (0.61018161)
# Finished training epoch 2
# Validate: MSE 0.00353590 (0.00309852), PSNR 24.51499367 (25.15258752), SSIM 0.59476095 (0.67398117)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00262501 (0.00288258), PSNR 25.80868530 (25.42565603), SSIM 0.76429427 (0.71448121)
# Finished training epoch 3
# Validate: MSE 0.00318152 (0.00275678), PSNR 24.97365570 (25.66723143), SSIM 0.67360258 (0.74554738)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00207683 (0.00275217), PSNR 26.82598305 (25.62253094), SSIM 0.79283869 (0.75709660)
# Finished training epoch 4
# Validate: MSE 0.00305720 (0.00273137), PSNR 25.14675903 (25.71452241), SSIM 0.69638532 (0.76404811)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00312848 (0.00273908), PSNR 25.04667091 (25.64536256), SSIM 0.74863517 (0.76718314)
# Finished training epoch 5
# Validate: MSE 0.00313866 (0.00271082), PSNR 25.03255653 (25.74383441), SSIM 0.69989598 (0.76898583)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00283468 (0.00274227), PSNR 25.47495461 (25.64121517), SSIM 0.76714277 (0.76809974)
# Finished training epoch 6
# Validate: MSE 0.00308834 (0.00273408), PSNR 25.10275459 (25.70969292), SSIM 0.69748569 (0.76617205)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00333632 (0.00274244), PSNR 24.76731682 (25.64110771), SSIM 0.74483955 (0.76800365)
# Finished training epoch 7
# Validate: MSE 0.00328442 (0.00277038), PSNR 24.83541298 (25.64633217), SSIM 0.70072114 (0.76888459)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00295617 (0.00273718), PSNR 25.29270172 (25.64467703), SSIM 0.76854956 (0.76773515)
# Finished training epoch 8
# Validate: MSE 0.00316493 (0.00272562), PSNR 24.99636459 (25.71733198), SSIM 0.69820005 (0.76721448)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00262804 (0.00275150), PSNR 25.80367851 (25.62443325), SSIM 0.78011149 (0.76659380)
# Finished training epoch 9
# Validate: MSE 0.00323214 (0.00271610), PSNR 24.90509796 (25.72992367), SSIM 0.70148468 (0.76861950)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00232922 (0.00276989), PSNR 26.32789421 (25.59734415), SSIM 0.76796424 (0.76509883)
# Finished training epoch 10
# Validate: MSE 0.00305980 (0.00270455), PSNR 25.14306450 (25.75462055), SSIM 0.69713223 (0.76530927)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00298457 (0.00277080), PSNR 25.25118446 (25.59699961), SSIM 0.75609910 (0.76378968)
# Finished training epoch 11
# Validate: MSE 0.00327259 (0.00301266), PSNR 24.85108566 (25.28761235), SSIM 0.68461001 (0.75491844)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00250280 (0.00275809), PSNR 26.01572800 (25.61679258), SSIM 0.75228804 (0.76302028)
# Finished training epoch 12
# Validate: MSE 0.00316377 (0.00277154), PSNR 24.99795723 (25.63800367), SSIM 0.68923581 (0.75930534)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00249953 (0.00283944), PSNR 26.02140999 (25.49575680), SSIM 0.77550447 (0.75874722)
# Finished training epoch 13
# Validate: MSE 0.00300571 (0.00266055), PSNR 25.22052574 (25.81724635), SSIM 0.69848561 (0.76295358)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00247058 (0.00282818), PSNR 26.07201385 (25.51416994), SSIM 0.78340846 (0.75761762)
# Finished training epoch 14
# Validate: MSE 0.00300369 (0.00264553), PSNR 25.22344589 (25.84719216), SSIM 0.69808447 (0.76546787)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00248556 (0.00294071), PSNR 26.04576492 (25.35744308), SSIM 0.77045041 (0.75257865)
# Finished training epoch 15
# Validate: MSE 0.00330809 (0.00285905), PSNR 24.80423164 (25.49532483), SSIM 0.68226671 (0.74570652)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00286692 (0.00294296), PSNR 25.42584801 (25.35249763), SSIM 0.73957169 (0.74972105)
# Finished training epoch 16
# Validate: MSE 0.00314481 (0.00271209), PSNR 25.02405930 (25.72767231), SSIM 0.68819988 (0.75381568)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00285458 (0.00292094), PSNR 25.44457436 (25.38131939), SSIM 0.73398751 (0.74977727)
# Finished training epoch 17
# Validate: MSE 0.00305044 (0.00266185), PSNR 25.15637589 (25.80813633), SSIM 0.69185913 (0.75345698)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00305520 (0.00294242), PSNR 25.14960861 (25.36138892), SSIM 0.75553697 (0.74931578)
# Finished training epoch 18
# Validate: MSE 0.00313593 (0.00277575), PSNR 25.03633499 (25.63603326), SSIM 0.69097137 (0.75964806)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00254164 (0.00281147), PSNR 25.94886017 (25.54838075), SSIM 0.74579543 (0.75436402)
# Finished training epoch 19
# Validate: MSE 0.00329280 (0.00296548), PSNR 24.82434654 (25.36980860), SSIM 0.68768156 (0.75807151)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00229801 (0.00276813), PSNR 26.38647079 (25.60710716), SSIM 0.77175891 (0.75480750)
# Finished training epoch 20
# Validate: MSE 0.00296943 (0.00255064), PSNR 25.27327156 (25.99918152), SSIM 0.69661355 (0.76505984)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00256182 (0.00277588), PSNR 25.91451073 (25.59898073), SSIM 0.75387561 (0.75577670)
# Finished training epoch 21
# Validate: MSE 0.00327202 (0.00277718), PSNR 24.85184097 (25.61777015), SSIM 0.68734288 (0.75472903)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00245179 (0.00267601), PSNR 26.10516357 (25.75097744), SSIM 0.78539258 (0.75937744)
# Finished training epoch 22
# Validate: MSE 0.00349652 (0.00283136), PSNR 24.56363297 (25.53667264), SSIM 0.68046099 (0.75358764)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00199533 (0.00270168), PSNR 26.99985695 (25.71089495), SSIM 0.77453959 (0.75930751)
# Finished training epoch 23
# Validate: MSE 0.00309210 (0.00277479), PSNR 25.09746170 (25.65824363), SSIM 0.69468296 (0.76381978)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00287205 (0.00261253), PSNR 25.41808510 (25.85188615), SSIM 0.75502038 (0.76225751)
# Finished training epoch 24
# Validate: MSE 0.00341602 (0.00291416), PSNR 24.66480064 (25.41283600), SSIM 0.68578148 (0.75649317)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00239349 (0.00256714), PSNR 26.20967484 (25.93091418), SSIM 0.76424277 (0.76370358)
# Finished training epoch 25
# Validate: MSE 0.00294536 (0.00248340), PSNR 25.30861473 (26.10833275), SSIM 0.69956660 (0.76391968)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00327165 (0.00255630), PSNR 24.85233498 (25.94832780), SSIM 0.75866193 (0.76437770)
# Finished training epoch 26
# Validate: MSE 0.00304550 (0.00261988), PSNR 25.16341400 (25.87859308), SSIM 0.69563907 (0.76487344)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00292208 (0.00253145), PSNR 25.34308434 (25.98771290), SSIM 0.75259554 (0.76580353)
# Finished training epoch 27
# Validate: MSE 0.00285185 (0.00265800), PSNR 25.44872665 (25.83399057), SSIM 0.70068562 (0.76648297)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00246145 (0.00251268), PSNR 26.08808517 (26.01912561), SSIM 0.76982945 (0.76682844)
# Finished training epoch 28
# Validate: MSE 0.00286017 (0.00248078), PSNR 25.43607521 (26.11395023), SSIM 0.70168942 (0.76835239)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00204234 (0.00250325), PSNR 26.89871407 (26.03818433), SSIM 0.77351290 (0.76710346)
# Finished training epoch 29
# Validate: MSE 0.00294789 (0.00254027), PSNR 25.30489159 (26.00765973), SSIM 0.69608152 (0.76420868)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00224679 (0.00250513), PSNR 26.48437119 (26.03538982), SSIM 0.77770847 (0.76744290)
# Finished training epoch 30
# Validate: MSE 0.00313667 (0.00264688), PSNR 25.03531647 (25.83585497), SSIM 0.69808346 (0.76499604)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00240081 (0.00248425), PSNR 26.19642067 (26.07378951), SSIM 0.75308079 (0.76865664)
# Finished training epoch 31
# Validate: MSE 0.00316934 (0.00272543), PSNR 24.99031448 (25.72342664), SSIM 0.69513196 (0.75996570)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00245844 (0.00246387), PSNR 26.09340858 (26.10775116), SSIM 0.79304922 (0.76969094)
# Finished training epoch 32
# Validate: MSE 0.00288801 (0.00258393), PSNR 25.39401245 (25.95718291), SSIM 0.70519888 (0.77379118)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00245213 (0.00246685), PSNR 26.10457039 (26.10031175), SSIM 0.78593928 (0.77004434)
# Finished training epoch 33
# Validate: MSE 0.00282798 (0.00242419), PSNR 25.48523521 (26.21557606), SSIM 0.70143533 (0.77073457)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00271499 (0.00245824), PSNR 25.66231728 (26.11555544), SSIM 0.78743827 (0.77000911)
# Finished training epoch 34
# Validate: MSE 0.00297100 (0.00249345), PSNR 25.27096558 (26.10166116), SSIM 0.70618582 (0.77379351)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00232571 (0.00245056), PSNR 26.33444786 (26.12769247), SSIM 0.76127928 (0.76999564)
# Finished training epoch 35
# Validate: MSE 0.00301172 (0.00243093), PSNR 25.21185493 (26.20478011), SSIM 0.70303386 (0.76945352)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00230372 (0.00244777), PSNR 26.37570953 (26.13459250), SSIM 0.75915533 (0.76985130)
# Finished training epoch 36
# Validate: MSE 0.00283313 (0.00244212), PSNR 25.47733307 (26.18557401), SSIM 0.70392281 (0.76797110)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00228868 (0.00244652), PSNR 26.40415001 (26.13682172), SSIM 0.75876081 (0.76984921)
# Finished training epoch 37
# Validate: MSE 0.00282279 (0.00247442), PSNR 25.49321938 (26.13144452), SSIM 0.70791245 (0.77372387)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00235600 (0.00243727), PSNR 26.27824974 (26.15471408), SSIM 0.77247524 (0.77044214)
# Finished training epoch 38
# Validate: MSE 0.00277047 (0.00247753), PSNR 25.57446861 (26.11888080), SSIM 0.70737731 (0.76658431)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00233480 (0.00244654), PSNR 26.31750679 (26.13825383), SSIM 0.76627260 (0.76938450)
# Finished training epoch 39
# Validate: MSE 0.00301834 (0.00246547), PSNR 25.20231438 (26.14937241), SSIM 0.70564038 (0.77399872)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00252105 (0.00244667), PSNR 25.98418617 (26.13593522), SSIM 0.74771595 (0.76894298)
# Finished training epoch 40
# Validate: MSE 0.00292804 (0.00271766), PSNR 25.33423424 (25.73001314), SSIM 0.69728756 (0.76128264)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00294932 (0.00244445), PSNR 25.30278587 (26.13979312), SSIM 0.75440985 (0.76896615)
# Finished training epoch 41
# Validate: MSE 0.00302449 (0.00278328), PSNR 25.19347954 (25.63460158), SSIM 0.68964398 (0.75330518)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00217562 (0.00245053), PSNR 26.62417030 (26.13106836), SSIM 0.78672785 (0.76853484)
# Finished training epoch 42
# Validate: MSE 0.00294790 (0.00246172), PSNR 25.30487633 (26.15910660), SSIM 0.70780581 (0.77620219)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00267391 (0.00243510), PSNR 25.72852898 (26.15783761), SSIM 0.74773395 (0.76941520)
# Finished training epoch 43
# Validate: MSE 0.00301554 (0.00247873), PSNR 25.20635223 (26.12683077), SSIM 0.70661688 (0.77318043)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00255233 (0.00244694), PSNR 25.93063545 (26.13707456), SSIM 0.76205331 (0.76733458)
# Finished training epoch 44
# Validate: MSE 0.00276322 (0.00243017), PSNR 25.58584404 (26.20631960), SSIM 0.70349598 (0.77097281)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00316983 (0.00242581), PSNR 24.98963547 (26.17578764), SSIM 0.75940484 (0.76934642)
# Finished training epoch 45
# Validate: MSE 0.00281530 (0.00288767), PSNR 25.50474930 (25.50738504), SSIM 0.70331842 (0.75826999)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00228654 (0.00243504), PSNR 26.40820312 (26.15789365), SSIM 0.75926673 (0.76909274)
# Finished training epoch 46
# Validate: MSE 0.00322120 (0.00261013), PSNR 24.91982841 (25.90755957), SSIM 0.69934094 (0.76506944)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00249191 (0.00243581), PSNR 26.03467178 (26.15681506), SSIM 0.78470504 (0.76867195)
# Finished training epoch 47
# Validate: MSE 0.00304253 (0.00251223), PSNR 25.16764832 (26.06857856), SSIM 0.70177776 (0.77262946)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00219758 (0.00243096), PSNR 26.58055878 (26.16024326), SSIM 0.78864318 (0.76849438)
# Finished training epoch 48
# Validate: MSE 0.00273130 (0.00241752), PSNR 25.63630295 (26.21938781), SSIM 0.70429128 (0.76782321)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00251472 (0.00244426), PSNR 25.99509811 (26.14363658), SSIM 0.78552163 (0.76781261)
# Finished training epoch 49
# Validate: MSE 0.00291200 (0.00237834), PSNR 25.35808754 (26.29735190), SSIM 0.70363230 (0.76838614)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00295950 (0.00242837), PSNR 25.28782082 (26.16788182), SSIM 0.76840508 (0.76896664)
# Finished training epoch 50
# Validate: MSE 0.00291515 (0.00240983), PSNR 25.35338211 (26.23657991), SSIM 0.69242191 (0.76455106)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00249422 (0.00243203), PSNR 26.03065872 (26.16358268), SSIM 0.77124882 (0.76904161)
# Finished training epoch 51
# Validate: MSE 0.00350233 (0.00298293), PSNR 24.55642700 (25.32898374), SSIM 0.70539612 (0.76647950)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00218012 (0.00241299), PSNR 26.61518860 (26.19939197), SSIM 0.79799998 (0.76968068)
# Finished training epoch 52
# Validate: MSE 0.00297933 (0.00240212), PSNR 25.25880814 (26.26083519), SSIM 0.70852590 (0.77510487)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00257115 (0.00243960), PSNR 25.89872932 (26.15091675), SSIM 0.75893182 (0.76808812)
# Finished training epoch 53
# Validate: MSE 0.00282154 (0.00248844), PSNR 25.49513626 (26.09911585), SSIM 0.70321918 (0.76370324)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00259710 (0.00241318), PSNR 25.85510254 (26.19512096), SSIM 0.75020695 (0.76978623)
# Finished training epoch 54
# Validate: MSE 0.00276047 (0.00239796), PSNR 25.59016800 (26.25947215), SSIM 0.70149875 (0.76612022)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00166229 (0.00240922), PSNR 27.79291916 (26.20232903), SSIM 0.80303210 (0.76913192)
# Finished training epoch 55
# Validate: MSE 0.00308101 (0.00245819), PSNR 25.11306190 (26.16643092), SSIM 0.70482123 (0.77268212)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00259040 (0.00240464), PSNR 25.86633110 (26.21175908), SSIM 0.75713092 (0.76983611)
# Finished training epoch 56
# Validate: MSE 0.00288349 (0.00251161), PSNR 25.40081978 (26.06848225), SSIM 0.70629537 (0.76519192)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00221175 (0.00241611), PSNR 26.55264282 (26.19161014), SSIM 0.76576376 (0.76876869)
# Finished training epoch 57
# Validate: MSE 0.00266128 (0.00238950), PSNR 25.74908638 (26.28065872), SSIM 0.71127796 (0.77062176)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00232462 (0.00239752), PSNR 26.33647919 (26.22350143), SSIM 0.78478283 (0.77006432)
# Finished training epoch 58
# Validate: MSE 0.00277174 (0.00242656), PSNR 25.57246780 (26.21461854), SSIM 0.70888937 (0.77292527)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00208500 (0.00240702), PSNR 26.80893326 (26.20704373), SSIM 0.78444725 (0.76949071)
# Finished training epoch 59
# Validate: MSE 0.00266212 (0.00242836), PSNR 25.74771690 (26.20922450), SSIM 0.70749187 (0.76729158)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00200210 (0.00240756), PSNR 26.98514748 (26.20681821), SSIM 0.79611945 (0.76916787)
# Finished training epoch 60
# Validate: MSE 0.00274944 (0.00241030), PSNR 25.60755539 (26.24616147), SSIM 0.70600319 (0.77028827)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00224847 (0.00239246), PSNR 26.48113060 (26.23520052), SSIM 0.76130116 (0.76998026)
# Finished training epoch 61
# Validate: MSE 0.00276311 (0.00236539), PSNR 25.58600807 (26.32372177), SSIM 0.71140313 (0.77498749)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00220364 (0.00239462), PSNR 26.56859207 (26.22994659), SSIM 0.78424919 (0.76956548)
# Finished training epoch 62
# Validate: MSE 0.00294680 (0.00252757), PSNR 25.30648804 (26.04531189), SSIM 0.70130837 (0.76537809)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00234563 (0.00238729), PSNR 26.29741096 (26.24375493), SSIM 0.78331870 (0.77008149)
# Finished training epoch 63
# Validate: MSE 0.00269222 (0.00257215), PSNR 25.69889259 (25.96860827), SSIM 0.70807749 (0.75941638)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00244396 (0.00238629), PSNR 26.11906052 (26.24375596), SSIM 0.77736330 (0.77009760)
# Finished training epoch 64
# Validate: MSE 0.00260702 (0.00241136), PSNR 25.83856010 (26.24034975), SSIM 0.71055877 (0.77228735)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00298199 (0.00238758), PSNR 25.25494003 (26.24058476), SSIM 0.74437726 (0.76987261)
# Finished training epoch 65
# Validate: MSE 0.00257844 (0.00236733), PSNR 25.88642311 (26.31299774), SSIM 0.71300268 (0.76816223)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00218013 (0.00239656), PSNR 26.61518478 (26.22322271), SSIM 0.76339793 (0.76960463)
# Finished training epoch 66
# Validate: MSE 0.00277155 (0.00238714), PSNR 25.57276535 (26.27758481), SSIM 0.70907563 (0.76225902)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00255103 (0.00238549), PSNR 25.93284416 (26.24816647), SSIM 0.76250535 (0.76970162)
# Finished training epoch 67
# Validate: MSE 0.00274493 (0.00239371), PSNR 25.61468697 (26.27167395), SSIM 0.71355152 (0.77415593)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00235317 (0.00238110), PSNR 26.28345680 (26.25501594), SSIM 0.77455443 (0.77041910)
# Finished training epoch 68
# Validate: MSE 0.00312749 (0.00251992), PSNR 25.04803467 (26.06037397), SSIM 0.70639729 (0.77326709)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00263377 (0.00238604), PSNR 25.79421806 (26.24487035), SSIM 0.74173719 (0.76939676)
# Finished training epoch 69
# Validate: MSE 0.00269733 (0.00236595), PSNR 25.69065857 (26.31752251), SSIM 0.70249307 (0.76475317)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00207604 (0.00238304), PSNR 26.82764053 (26.25016671), SSIM 0.78085524 (0.77000639)
# Finished training epoch 70
# Validate: MSE 0.00267792 (0.00241972), PSNR 25.72202492 (26.22669694), SSIM 0.71199584 (0.77275302)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00222411 (0.00237409), PSNR 26.52844620 (26.26845832), SSIM 0.78441417 (0.77007237)
# Finished training epoch 71
# Validate: MSE 0.00277143 (0.00235274), PSNR 25.57296562 (26.34195080), SSIM 0.71100199 (0.77178349)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00190960 (0.00238679), PSNR 27.19057465 (26.24544243), SSIM 0.80211562 (0.76934171)
# Finished training epoch 72
# Validate: MSE 0.00291275 (0.00238552), PSNR 25.35696983 (26.28450792), SSIM 0.70747113 (0.77409971)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00258224 (0.00239974), PSNR 25.88002396 (26.22079932), SSIM 0.76987010 (0.76906105)
# Finished training epoch 73
# Validate: MSE 0.00288931 (0.00240265), PSNR 25.39205170 (26.25941425), SSIM 0.71303755 (0.77374798)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00240560 (0.00238134), PSNR 26.18777084 (26.25499586), SSIM 0.75301117 (0.77014308)
# Finished training epoch 74
# Validate: MSE 0.00259261 (0.00241357), PSNR 25.86261940 (26.22897885), SSIM 0.71064347 (0.76878685)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00221897 (0.00238414), PSNR 26.53848076 (26.24803508), SSIM 0.77827454 (0.76956571)
# Finished training epoch 75
# Validate: MSE 0.00278932 (0.00238929), PSNR 25.54500771 (26.28279230), SSIM 0.70503771 (0.76886748)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00270529 (0.00237719), PSNR 25.67786407 (26.26262401), SSIM 0.75880623 (0.77023578)
# Finished training epoch 76
# Validate: MSE 0.00265219 (0.00237551), PSNR 25.76395798 (26.29771525), SSIM 0.70773292 (0.76858744)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00262746 (0.00238001), PSNR 25.80464554 (26.26100722), SSIM 0.76228535 (0.76986677)
# Finished training epoch 77
# Validate: MSE 0.00271766 (0.00251809), PSNR 25.65805435 (26.04870469), SSIM 0.70850241 (0.75990389)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00339627 (0.00237239), PSNR 24.68997192 (26.27105778), SSIM 0.74712098 (0.76996899)
# Finished training epoch 78
# Validate: MSE 0.00284956 (0.00256184), PSNR 25.45221519 (25.99296368), SSIM 0.70428419 (0.76794353)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00219374 (0.00236446), PSNR 26.58813667 (26.28561103), SSIM 0.76471829 (0.77032323)
# Finished training epoch 79
# Validate: MSE 0.00266574 (0.00239831), PSNR 25.74181747 (26.25899340), SSIM 0.71402383 (0.77129638)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00242023 (0.00236471), PSNR 26.16142845 (26.28544761), SSIM 0.79007405 (0.77089082)
# Finished training epoch 80
# Validate: MSE 0.00263200 (0.00270920), PSNR 25.79714012 (25.78128058), SSIM 0.70757234 (0.76455307)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00253146 (0.00236753), PSNR 25.96629143 (26.27844084), SSIM 0.77159595 (0.76981921)
# Finished training epoch 81
# Validate: MSE 0.00266169 (0.00233315), PSNR 25.74843025 (26.38341648), SSIM 0.71493590 (0.77218599)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00262121 (0.00236000), PSNR 25.81497955 (26.29812531), SSIM 0.75943315 (0.77031995)
# Finished training epoch 82
# Validate: MSE 0.00264823 (0.00231676), PSNR 25.77044106 (26.41283249), SSIM 0.71415424 (0.76874862)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00237773 (0.00236985), PSNR 26.23836899 (26.27441743), SSIM 0.76494151 (0.76986390)
# Finished training epoch 83
# Validate: MSE 0.00297525 (0.00251089), PSNR 25.26476860 (26.05723381), SSIM 0.70126164 (0.75710884)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00232136 (0.00235743), PSNR 26.34257889 (26.30013545), SSIM 0.77097505 (0.77074398)
# Finished training epoch 84
# Validate: MSE 0.00279754 (0.00230679), PSNR 25.53223038 (26.43410960), SSIM 0.71023196 (0.77375766)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00207546 (0.00237833), PSNR 26.82886124 (26.25832503), SSIM 0.77787238 (0.76884620)
# Finished training epoch 85
# Validate: MSE 0.00282245 (0.00234626), PSNR 25.49373817 (26.35344528), SSIM 0.71175253 (0.77208801)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00271642 (0.00235282), PSNR 25.66002655 (26.30810517), SSIM 0.78742915 (0.77083720)
# Finished training epoch 86
# Validate: MSE 0.00281418 (0.00235689), PSNR 25.50648499 (26.33796143), SSIM 0.70914018 (0.77323130)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00192498 (0.00235610), PSNR 27.15573502 (26.29973727), SSIM 0.77108818 (0.77042207)
# Finished training epoch 87
# Validate: MSE 0.00270126 (0.00236181), PSNR 25.68432808 (26.32831834), SSIM 0.70080179 (0.76423876)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00241594 (0.00235741), PSNR 26.16913033 (26.29652452), SSIM 0.77815074 (0.77021277)
# Finished training epoch 88
# Validate: MSE 0.00270830 (0.00233405), PSNR 25.67302895 (26.38086024), SSIM 0.71074468 (0.77305193)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00221488 (0.00235702), PSNR 26.54650497 (26.30203643), SSIM 0.75656313 (0.77016393)
# Finished training epoch 89
# Validate: MSE 0.00274011 (0.00237851), PSNR 25.62231636 (26.29566472), SSIM 0.70231295 (0.76840734)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00239345 (0.00234741), PSNR 26.20974922 (26.31698970), SSIM 0.76771927 (0.77073931)
# Finished training epoch 90
# Validate: MSE 0.00274135 (0.00255364), PSNR 25.62035179 (26.01323426), SSIM 0.71107000 (0.76819631)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00221961 (0.00234429), PSNR 26.53723526 (26.32201871), SSIM 0.78800195 (0.77097430)
# Finished training epoch 91
# Validate: MSE 0.00273414 (0.00241470), PSNR 25.63179779 (26.24281407), SSIM 0.70777953 (0.77221652)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00267876 (0.00235040), PSNR 25.72065544 (26.30939517), SSIM 0.76592779 (0.77076823)
# Finished training epoch 92
# Validate: MSE 0.00273876 (0.00242906), PSNR 25.62445450 (26.21598028), SSIM 0.71330684 (0.76888692)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00189850 (0.00235467), PSNR 27.21588898 (26.30326355), SSIM 0.80768168 (0.77001901)
# Finished training epoch 93
# Validate: MSE 0.00287796 (0.00236797), PSNR 25.40914536 (26.32572819), SSIM 0.71184200 (0.77309854)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00212631 (0.00233967), PSNR 26.72372627 (26.33290585), SSIM 0.78545791 (0.77116605)
# Finished training epoch 94
# Validate: MSE 0.00309292 (0.00283060), PSNR 25.09631348 (25.56518235), SSIM 0.70620120 (0.76502200)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00268096 (0.00235390), PSNR 25.71710205 (26.30681075), SSIM 0.74016446 (0.77006026)
# Finished training epoch 95
# Validate: MSE 0.00265232 (0.00273149), PSNR 25.76374054 (25.70838309), SSIM 0.70775139 (0.76367493)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00225940 (0.00234990), PSNR 26.46006775 (26.31135222), SSIM 0.78451586 (0.77022519)
# Finished training epoch 96
# Validate: MSE 0.00257838 (0.00229019), PSNR 25.88652802 (26.46154052), SSIM 0.71264082 (0.77180842)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00338283 (0.00235889), PSNR 24.70719910 (26.29745357), SSIM 0.76090014 (0.77004470)
# Finished training epoch 97
# Validate: MSE 0.00259834 (0.00242641), PSNR 25.85303688 (26.20991647), SSIM 0.70983958 (0.77065739)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00289897 (0.00234905), PSNR 25.37755585 (26.31101417), SSIM 0.79121220 (0.77012170)
# Finished training epoch 98
# Validate: MSE 0.00300713 (0.00252823), PSNR 25.21847153 (26.04174697), SSIM 0.70705324 (0.77111829)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00251716 (0.00234829), PSNR 25.99089622 (26.31699099), SSIM 0.74957949 (0.77050071)
# Finished training epoch 99
# Validate: MSE 0.00279504 (0.00235741), PSNR 25.53611946 (26.34127681), SSIM 0.71125495 (0.77242711)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00221661 (0.00234678), PSNR 26.54311752 (26.31833523), SSIM 0.76649505 (0.77046642)
# Finished training epoch 100
# Validate: MSE 0.00279682 (0.00244743), PSNR 25.53335381 (26.16811428), SSIM 0.70375830 (0.76876759)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00265518 (0.00235567), PSNR 25.75906563 (26.30387526), SSIM 0.77554619 (0.77045167)
# Finished training epoch 101
# Validate: MSE 0.00277114 (0.00233763), PSNR 25.57340813 (26.37602021), SSIM 0.70904154 (0.77474943)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00280081 (0.00233273), PSNR 25.52716255 (26.34264581), SSIM 0.77180040 (0.77100140)
# Finished training epoch 102
# Validate: MSE 0.00270527 (0.00247489), PSNR 25.67788887 (26.14334949), SSIM 0.71246016 (0.77342149)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00259740 (0.00233458), PSNR 25.85460663 (26.33930827), SSIM 0.78316367 (0.77093814)
# Finished training epoch 103
# Validate: MSE 0.00289635 (0.00244528), PSNR 25.38149261 (26.18837784), SSIM 0.71402681 (0.77103001)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00261575 (0.00234834), PSNR 25.82403564 (26.31606614), SSIM 0.78434944 (0.77023668)
# Finished training epoch 104
# Validate: MSE 0.00273439 (0.00235655), PSNR 25.63139534 (26.33541997), SSIM 0.71470344 (0.77301343)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00183524 (0.00235758), PSNR 27.36307144 (26.29600516), SSIM 0.78074324 (0.76973590)
# Finished training epoch 105
# Validate: MSE 0.00258485 (0.00234045), PSNR 25.87564468 (26.36826168), SSIM 0.70758265 (0.76878097)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00181063 (0.00233864), PSNR 27.42169952 (26.33353652), SSIM 0.80273616 (0.77061564)
# Finished training epoch 106
# Validate: MSE 0.00273639 (0.00237476), PSNR 25.62821198 (26.30685570), SSIM 0.71302891 (0.77120640)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00308835 (0.00234037), PSNR 25.10273170 (26.32917051), SSIM 0.74176311 (0.77045286)
# Finished training epoch 107
# Validate: MSE 0.00253476 (0.00256066), PSNR 25.96063042 (25.98501230), SSIM 0.71179771 (0.76663639)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00252868 (0.00234841), PSNR 25.97105408 (26.31242493), SSIM 0.76268137 (0.77005779)
# Finished training epoch 108
# Validate: MSE 0.00268926 (0.00242372), PSNR 25.70367813 (26.21684300), SSIM 0.70628119 (0.76164672)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00236851 (0.00234232), PSNR 26.25525475 (26.32531497), SSIM 0.76443440 (0.77013217)
# Finished training epoch 109
# Validate: MSE 0.00282550 (0.00240322), PSNR 25.48904610 (26.25450467), SSIM 0.70972919 (0.76782941)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00233060 (0.00233615), PSNR 26.32531357 (26.33487713), SSIM 0.78803062 (0.77046171)
# Finished training epoch 110
# Validate: MSE 0.00301013 (0.00236615), PSNR 25.21413994 (26.32656758), SSIM 0.70490694 (0.76892790)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00248086 (0.00233748), PSNR 26.05397797 (26.33594053), SSIM 0.75691724 (0.77122404)
# Finished training epoch 111
# Validate: MSE 0.00262351 (0.00238078), PSNR 25.81116867 (26.28550024), SSIM 0.70993125 (0.77108463)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00252478 (0.00233879), PSNR 25.97775841 (26.33237326), SSIM 0.78017175 (0.77020805)
# Finished training epoch 112
# Validate: MSE 0.00297015 (0.00239021), PSNR 25.27221107 (26.28149374), SSIM 0.71274209 (0.77603868)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00229434 (0.00233584), PSNR 26.39341354 (26.33719745), SSIM 0.76087630 (0.77089630)
# Finished training epoch 113
# Validate: MSE 0.00270330 (0.00231490), PSNR 25.68105507 (26.41316488), SSIM 0.71466506 (0.77292852)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00221709 (0.00234321), PSNR 26.54216385 (26.32607522), SSIM 0.78522784 (0.77020837)
# Finished training epoch 114
# Validate: MSE 0.00274504 (0.00240363), PSNR 25.61451721 (26.25473970), SSIM 0.70781565 (0.77377656)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00189011 (0.00232376), PSNR 27.23511887 (26.36073362), SSIM 0.76780289 (0.77114473)
# Finished training epoch 115
# Validate: MSE 0.00266697 (0.00236598), PSNR 25.73981857 (26.32160038), SSIM 0.70900273 (0.76820019)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00200034 (0.00232545), PSNR 26.98895645 (26.35840367), SSIM 0.77387154 (0.77116319)
# Finished training epoch 116
# Validate: MSE 0.00277211 (0.00237608), PSNR 25.57189941 (26.30426609), SSIM 0.70989788 (0.76713645)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00214955 (0.00234611), PSNR 26.67652512 (26.31905489), SSIM 0.78918093 (0.76937179)
# Finished training epoch 117
# Validate: MSE 0.00279637 (0.00244105), PSNR 25.53405190 (26.19115700), SSIM 0.71154916 (0.77348539)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00227650 (0.00232410), PSNR 26.42731476 (26.36234410), SSIM 0.77658570 (0.77092812)
# Finished training epoch 118
# Validate: MSE 0.00277438 (0.00230090), PSNR 25.56833649 (26.44120253), SSIM 0.71025622 (0.76996106)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00272559 (0.00232419), PSNR 25.64539909 (26.36081006), SSIM 0.76544875 (0.77086930)
# Finished training epoch 119
# Validate: MSE 0.00286070 (0.00233598), PSNR 25.43527794 (26.37558351), SSIM 0.70562339 (0.76838078)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00239552 (0.00234651), PSNR 26.20599937 (26.32096286), SSIM 0.77570152 (0.76960516)
# Finished training epoch 120
# Validate: MSE 0.00263769 (0.00228224), PSNR 25.78776169 (26.47597580), SSIM 0.71252406 (0.77353357)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00218987 (0.00232246), PSNR 26.59581375 (26.36280286), SSIM 0.76066780 (0.77138335)
# Finished training epoch 121
# Validate: MSE 0.00252467 (0.00240055), PSNR 25.97795296 (26.24593606), SSIM 0.71339041 (0.76472734)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00206372 (0.00233662), PSNR 26.85349083 (26.33713269), SSIM 0.76561594 (0.77018680)
# Finished training epoch 122
# Validate: MSE 0.00305283 (0.00248239), PSNR 25.15297127 (26.11473941), SSIM 0.70794034 (0.76461683)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00254855 (0.00235072), PSNR 25.93707275 (26.31248685), SSIM 0.74865848 (0.76930563)
# Finished training epoch 123
# Validate: MSE 0.00268977 (0.00244162), PSNR 25.70284081 (26.16753114), SSIM 0.69399244 (0.75534593)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00194008 (0.00234473), PSNR 27.12179375 (26.32300870), SSIM 0.78364438 (0.76966066)
# Finished training epoch 124
# Validate: MSE 0.00266922 (0.00230708), PSNR 25.73615646 (26.42798661), SSIM 0.71071851 (0.77027889)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00231059 (0.00233176), PSNR 26.36276245 (26.34800693), SSIM 0.78433359 (0.77059990)
# Finished training epoch 125
# Validate: MSE 0.00282164 (0.00239954), PSNR 25.49497986 (26.26615051), SSIM 0.70969200 (0.76869476)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00239199 (0.00233173), PSNR 26.21240807 (26.34748922), SSIM 0.78677320 (0.77009209)
# Finished training epoch 126
# Validate: MSE 0.00268564 (0.00235366), PSNR 25.70952034 (26.34515481), SSIM 0.70966876 (0.77253536)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00232097 (0.00232195), PSNR 26.34329987 (26.36526623), SSIM 0.76377064 (0.77050730)
# Finished training epoch 127
# Validate: MSE 0.00252967 (0.00232922), PSNR 25.96935654 (26.38767626), SSIM 0.71072006 (0.77151468)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00208400 (0.00231919), PSNR 26.81102562 (26.36873827), SSIM 0.77174050 (0.77106308)
# Finished training epoch 128
# Validate: MSE 0.00269083 (0.00237822), PSNR 25.70113945 (26.29932817), SSIM 0.71584451 (0.77332302)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00243899 (0.00233038), PSNR 26.12789154 (26.34743656), SSIM 0.77239627 (0.77011532)
# Finished training epoch 129
# Validate: MSE 0.00279468 (0.00234840), PSNR 25.53667831 (26.35729924), SSIM 0.71247804 (0.77592304)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00194211 (0.00231982), PSNR 27.11726189 (26.36853343), SSIM 0.78755015 (0.77050228)
# Finished training epoch 130
# Validate: MSE 0.00271476 (0.00240397), PSNR 25.66267967 (26.25642113), SSIM 0.70754731 (0.77433509)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00280257 (0.00232762), PSNR 25.52443504 (26.35260798), SSIM 0.76330405 (0.77038791)
# Finished training epoch 131
# Validate: MSE 0.00281884 (0.00236934), PSNR 25.49928856 (26.31748072), SSIM 0.71115232 (0.77270817)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00225119 (0.00232232), PSNR 26.47588539 (26.36178682), SSIM 0.77409071 (0.77069608)
# Finished training epoch 132
# Validate: MSE 0.00281189 (0.00239812), PSNR 25.51000977 (26.27027881), SSIM 0.70853984 (0.76952999)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00259925 (0.00231973), PSNR 25.85151672 (26.36820762), SSIM 0.75229752 (0.77033759)
# Finished training epoch 133
# Validate: MSE 0.00268578 (0.00232733), PSNR 25.70930290 (26.38563532), SSIM 0.71066815 (0.77187807)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00229165 (0.00231103), PSNR 26.39851761 (26.38423544), SSIM 0.76351750 (0.77142728)
# Finished training epoch 134
# Validate: MSE 0.00278474 (0.00235638), PSNR 25.55215454 (26.33871213), SSIM 0.71033621 (0.77529548)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00250543 (0.00232554), PSNR 26.01117516 (26.36070764), SSIM 0.75295556 (0.77008897)
# Finished training epoch 135
# Validate: MSE 0.00266734 (0.00231707), PSNR 25.73922157 (26.40947680), SSIM 0.70794427 (0.76751039)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00243613 (0.00232250), PSNR 26.13298798 (26.36254791), SSIM 0.77227306 (0.77051492)
# Finished training epoch 136
# Validate: MSE 0.00259342 (0.00239137), PSNR 25.86127281 (26.26678497), SSIM 0.70856023 (0.76645014)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00258209 (0.00232077), PSNR 25.88028717 (26.36413306), SSIM 0.76097870 (0.77074556)
# Finished training epoch 137
# Validate: MSE 0.00268135 (0.00228921), PSNR 25.71646500 (26.46489891), SSIM 0.71226919 (0.77150555)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00228149 (0.00230619), PSNR 26.41780853 (26.39819142), SSIM 0.77641523 (0.77117401)
# Finished training epoch 138
# Validate: MSE 0.00284841 (0.00236250), PSNR 25.45397758 (26.31907810), SSIM 0.69948936 (0.76640419)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00241172 (0.00232895), PSNR 26.17672157 (26.35236079), SSIM 0.77338880 (0.76986862)
# Finished training epoch 139
# Validate: MSE 0.00265342 (0.00235604), PSNR 25.76194191 (26.33269577), SSIM 0.70922172 (0.76491098)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00205602 (0.00233021), PSNR 26.86972046 (26.35220386), SSIM 0.78926313 (0.76950085)
# Finished training epoch 140
# Validate: MSE 0.00277439 (0.00245852), PSNR 25.56832314 (26.16583627), SSIM 0.71179581 (0.76899722)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00224814 (0.00233261), PSNR 26.48175812 (26.34318052), SSIM 0.76248747 (0.76965278)
# Finished training epoch 141
# Validate: MSE 0.00272623 (0.00230224), PSNR 25.64437485 (26.43603171), SSIM 0.71395969 (0.77349935)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00249456 (0.00231513), PSNR 26.03006172 (26.37854857), SSIM 0.76869237 (0.77075420)
# Finished training epoch 142
# Validate: MSE 0.00272354 (0.00241066), PSNR 25.64866257 (26.23745419), SSIM 0.70514679 (0.76872759)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00246510 (0.00232013), PSNR 26.08165932 (26.37090371), SSIM 0.76504165 (0.77041419)
# Finished training epoch 143
# Validate: MSE 0.00276874 (0.00236247), PSNR 25.57718468 (26.33355006), SSIM 0.71035892 (0.77282123)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00249375 (0.00234416), PSNR 26.03147316 (26.32526994), SSIM 0.76385736 (0.76842762)
# Finished training epoch 144
# Validate: MSE 0.00296417 (0.00237205), PSNR 25.28096390 (26.31311495), SSIM 0.70019472 (0.76721418)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00225914 (0.00233179), PSNR 26.46057129 (26.34310841), SSIM 0.77594101 (0.76984469)
# Finished training epoch 145
# Validate: MSE 0.00275328 (0.00231563), PSNR 25.60148811 (26.41432097), SSIM 0.71176434 (0.77074769)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00206841 (0.00231305), PSNR 26.84363747 (26.38194867), SSIM 0.77989149 (0.77059079)
# Finished training epoch 146
# Validate: MSE 0.00256347 (0.00230961), PSNR 25.91171265 (26.42320081), SSIM 0.71212876 (0.77198980)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00276465 (0.00231417), PSNR 25.58360291 (26.38003031), SSIM 0.75467420 (0.77092082)
# Finished training epoch 147
# Validate: MSE 0.00276489 (0.00245087), PSNR 25.58321762 (26.15780204), SSIM 0.70252311 (0.75419875)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00209667 (0.00232693), PSNR 26.78470802 (26.35305877), SSIM 0.78445470 (0.77028722)
# Finished training epoch 148
# Validate: MSE 0.00277968 (0.00229716), PSNR 25.56005096 (26.44959757), SSIM 0.71056503 (0.77614041)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00196644 (0.00231907), PSNR 27.06318665 (26.36927270), SSIM 0.77885562 (0.77044364)
# Finished training epoch 149
# Validate: MSE 0.00275136 (0.00230456), PSNR 25.60452461 (26.43464917), SSIM 0.70565128 (0.76775312)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00220961 (0.00231084), PSNR 26.55684853 (26.38297541), SSIM 0.77425730 (0.77069003)
# Finished training epoch 150
# Validate: MSE 0.00261357 (0.00230134), PSNR 25.82765961 (26.43701046), SSIM 0.71176445 (0.76905190)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00240416 (0.00231717), PSNR 26.19037247 (26.37359680), SSIM 0.75427282 (0.77011840)
# Finished training epoch 151
# Validate: MSE 0.00267210 (0.00231959), PSNR 25.73146820 (26.40534491), SSIM 0.71109962 (0.77472239)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00236534 (0.00231546), PSNR 26.26105881 (26.37510389), SSIM 0.76008409 (0.76989860)
# Finished training epoch 152
# Validate: MSE 0.00278040 (0.00244216), PSNR 25.55893135 (26.17840305), SSIM 0.71346205 (0.76484740)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00245854 (0.00232256), PSNR 26.09322548 (26.36406573), SSIM 0.77007568 (0.76976250)
# Finished training epoch 153
# Validate: MSE 0.00262891 (0.00235265), PSNR 25.80224800 (26.34862105), SSIM 0.71325397 (0.77104038)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00244227 (0.00232013), PSNR 26.12206841 (26.36895802), SSIM 0.78064537 (0.77014355)
# Finished training epoch 154
# Validate: MSE 0.00291531 (0.00231612), PSNR 25.35315514 (26.42107689), SSIM 0.70434660 (0.77140964)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00172752 (0.00229860), PSNR 27.62576866 (26.40697416), SSIM 0.77853167 (0.77135259)
# Finished training epoch 155
# Validate: MSE 0.00256065 (0.00255430), PSNR 25.91650200 (26.00384846), SSIM 0.71173847 (0.76294592)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00222516 (0.00230841), PSNR 26.52639389 (26.38763449), SSIM 0.77638292 (0.77065671)
# Finished training epoch 156
# Validate: MSE 0.00258553 (0.00232459), PSNR 25.87449837 (26.38953936), SSIM 0.70783103 (0.76597582)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00233878 (0.00231223), PSNR 26.31009674 (26.38289537), SSIM 0.77134061 (0.77072947)
# Finished training epoch 157
# Validate: MSE 0.00262510 (0.00231513), PSNR 25.80853844 (26.41023304), SSIM 0.71067846 (0.76901558)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00225384 (0.00231614), PSNR 26.47076988 (26.37432097), SSIM 0.76053441 (0.77048365)
# Finished training epoch 158
# Validate: MSE 0.00282246 (0.00227403), PSNR 25.49372292 (26.49471940), SSIM 0.70870870 (0.77207825)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00205011 (0.00231801), PSNR 26.88222885 (26.37153900), SSIM 0.79617870 (0.76967523)
# Finished training epoch 159
# Validate: MSE 0.00271685 (0.00230546), PSNR 25.65934753 (26.43563789), SSIM 0.71078950 (0.77521648)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00224425 (0.00233233), PSNR 26.48928642 (26.34548652), SSIM 0.77827513 (0.76919528)
# Finished training epoch 160
# Validate: MSE 0.00306218 (0.00246296), PSNR 25.13968658 (26.14598773), SSIM 0.69911766 (0.76189768)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00279927 (0.00230841), PSNR 25.52954674 (26.38992743), SSIM 0.75642371 (0.77084334)
# Finished training epoch 161
# Validate: MSE 0.00270025 (0.00256061), PSNR 25.68596649 (26.00215768), SSIM 0.71198392 (0.77320545)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00182779 (0.00232054), PSNR 27.38074493 (26.36560218), SSIM 0.77629507 (0.76998069)
# Finished training epoch 162
# Validate: MSE 0.00265500 (0.00230067), PSNR 25.75935364 (26.44368779), SSIM 0.71226954 (0.77022309)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00198961 (0.00230908), PSNR 27.01231766 (26.38670593), SSIM 0.76935261 (0.77082444)
# Finished training epoch 163
# Validate: MSE 0.00260072 (0.00228767), PSNR 25.84906197 (26.46276846), SSIM 0.70845735 (0.76666167)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00183036 (0.00230606), PSNR 27.37463760 (26.39325268), SSIM 0.79286563 (0.77105674)
# Finished training epoch 164
# Validate: MSE 0.00325900 (0.00286908), PSNR 24.86915779 (25.50018902), SSIM 0.70441574 (0.76239355)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00214648 (0.00231536), PSNR 26.68273163 (26.37842862), SSIM 0.77218789 (0.77062670)
# Finished training epoch 165
# Validate: MSE 0.00252063 (0.00238858), PSNR 25.98491287 (26.27128707), SSIM 0.70776457 (0.76570633)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00282803 (0.00232377), PSNR 25.48515511 (26.36237561), SSIM 0.74493229 (0.76965451)
# Finished training epoch 166
# Validate: MSE 0.00282543 (0.00236331), PSNR 25.48915482 (26.32499371), SSIM 0.70267469 (0.76748430)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00199294 (0.00230582), PSNR 27.00505066 (26.39545875), SSIM 0.77575004 (0.77074910)
# Finished training epoch 167
# Validate: MSE 0.00289656 (0.00243767), PSNR 25.38117218 (26.19725721), SSIM 0.71127033 (0.76923499)
# Finished validation.
# Starting training epoch 168
# ...
# Finished training epoch 179
# Validate: MSE 0.00265925 (0.00236497), PSNR 25.75241470 (26.32296866), SSIM 0.71376848 (0.76380338)
# Finished validation.
# Starting training epoch 180
# Epoch: 180, MSE 0.00155077 (0.00229616), PSNR 28.09452057 (26.41350774), SSIM 0.79046839 (0.77074254)
# Finished training epoch 180
# Validate: MSE 0.00273082 (0.00240546), PSNR 25.63706589 (26.25712001), SSIM 0.70860034 (0.76947624)
# Finished validation.
# Starting training epoch 181
# Epoch: 181, MSE 0.00221008 (0.00230411), PSNR 26.55591202 (26.39513535), SSIM 0.76969397 (0.77039911)
# Finished training epoch 181
# Validate: MSE 0.00288978 (0.00234289), PSNR 25.39135170 (26.35913493), SSIM 0.70352399 (0.76852851)
# Finished validation.
# Starting training epoch 182
# Epoch: 182, MSE 0.00192289 (0.00231508), PSNR 27.16045952 (26.37504158), SSIM 0.77719289 (0.77009599)
# Finished training epoch 182
# Validate: MSE 0.00259780 (0.00229958), PSNR 25.85394287 (26.43655916), SSIM 0.70938426 (0.76481335)
# Finished validation.
# Starting training epoch 183
# Epoch: 183, MSE 0.00240342 (0.00229174), PSNR 26.19170570 (26.42152433), SSIM 0.79107440 (0.77099550)
# Finished training epoch 183
# Validate: MSE 0.00272244 (0.00233190), PSNR 25.65042305 (26.38612549), SSIM 0.70935714 (0.77128149)
# Finished validation.
# Starting training epoch 184
# Epoch: 184, MSE 0.00263009 (0.00230344), PSNR 25.80030060 (26.39872229), SSIM 0.75531161 (0.77035521)
# Finished training epoch 184
# Validate: MSE 0.00292773 (0.00246113), PSNR 25.33469009 (26.16074422), SSIM 0.70744061 (0.77013049)
# Finished validation.
# Starting training epoch 185
# Epoch: 185, MSE 0.00251960 (0.00231642), PSNR 25.98668480 (26.37360927), SSIM 0.78140730 (0.76951018)
# Finished training epoch 185
# Validate: MSE 0.00267754 (0.00226862), PSNR 25.72264099 (26.50552024), SSIM 0.71764874 (0.77505116)
# Finished validation.
# Starting training epoch 186
# Epoch: 186, MSE 0.00245798 (0.00230028), PSNR 26.09421539 (26.40513854), SSIM 0.75263792 (0.77038147)
# Finished training epoch 186
# Validate: MSE 0.00276213 (0.00230707), PSNR 25.58754921 (26.42879818), SSIM 0.71155381 (0.76793692)
# Finished validation.
# Starting training epoch 187
# Epoch: 187, MSE 0.00221537 (0.00229939), PSNR 26.54553413 (26.40651448), SSIM 0.78815717 (0.77022386)
# Finished training epoch 187
# Validate: MSE 0.00266350 (0.00230576), PSNR 25.74546432 (26.42978078), SSIM 0.71282554 (0.77344629)
# Finished validation.
# Starting training epoch 188
# Epoch: 188, MSE 0.00291402 (0.00229779), PSNR 25.35507774 (26.40762988), SSIM 0.77152735 (0.77105310)
# Finished training epoch 188
# Validate: MSE 0.00282931 (0.00231439), PSNR 25.48318481 (26.41467939), SSIM 0.70655268 (0.76646362)
# Finished validation.
# Starting training epoch 189
# Epoch: 189, MSE 0.00203135 (0.00231184), PSNR 26.92214966 (26.38094018), SSIM 0.77691972 (0.77029609)
# Finished training epoch 189
# Validate: MSE 0.00276469 (0.00231835), PSNR 25.58353615 (26.40701784), SSIM 0.71086037 (0.76746559)
# Finished validation.
# Starting training epoch 190
# Epoch: 190, MSE 0.00249816 (0.00230069), PSNR 26.02380180 (26.40169937), SSIM 0.77821010 (0.77087721)
# Finished training epoch 190
# Validate: MSE 0.00260217 (0.00227365), PSNR 25.84664345 (26.49025797), SSIM 0.71258116 (0.77047566)
# Finished validation.
# Starting training epoch 191
# Epoch: 191, MSE 0.00317020 (0.00232296), PSNR 24.98913383 (26.36398177), SSIM 0.76948106 (0.76869464)
# Finished training epoch 191
# Validate: MSE 0.00296198 (0.00245495), PSNR 25.28418350 (26.16549163), SSIM 0.70850432 (0.76647740)
# Finished validation.
# Starting training epoch 192
# Epoch: 192, MSE 0.00248259 (0.00229919), PSNR 26.05094719 (26.40536857), SSIM 0.78338975 (0.77050527)
# Finished training epoch 192
# Validate: MSE 0.00277598 (0.00230061), PSNR 25.56583214 (26.44597169), SSIM 0.71325374 (0.77442269)
# Finished validation.
# Starting training epoch 193
# Epoch: 193, MSE 0.00180964 (0.00228961), PSNR 27.42407990 (26.42789382), SSIM 0.77759969 (0.77112450)
# Finished training epoch 193
# Validate: MSE 0.00295296 (0.00241603), PSNR 25.29741478 (26.24312162), SSIM 0.70878273 (0.77333852)
# Finished validation.
# Starting training epoch 194
# Epoch: 194, MSE 0.00165172 (0.00229809), PSNR 27.82064056 (26.40681810), SSIM 0.79434675 (0.77025879)
# Finished training epoch 194
# Validate: MSE 0.00280695 (0.00232403), PSNR 25.51765060 (26.40177065), SSIM 0.71056664 (0.77238589)
# Finished validation.
# Starting training epoch 195
# Epoch: 195, MSE 0.00260429 (0.00229592), PSNR 25.84310341 (26.41366986), SSIM 0.78844762 (0.77069911)
# Finished training epoch 195
# Validate: MSE 0.00263328 (0.00237909), PSNR 25.79502487 (26.29215065), SSIM 0.71042281 (0.76555141)
# Finished validation.
# Starting training epoch 196
# Epoch: 196, MSE 0.00213540 (0.00231132), PSNR 26.70521545 (26.38408948), SSIM 0.76386893 (0.77003713)
# Finished training epoch 196
# Validate: MSE 0.00252742 (0.00229462), PSNR 25.97322845 (26.44782909), SSIM 0.71316314 (0.76041451)
# Finished validation.
# Starting training epoch 197
# Epoch: 197, MSE 0.00185595 (0.00230668), PSNR 27.31434441 (26.39255877), SSIM 0.78560925 (0.76987776)
# Finished training epoch 197
# Validate: MSE 0.00283450 (0.00253646), PSNR 25.47524261 (26.03062552), SSIM 0.71047759 (0.76305138)
# Finished validation.
# Starting training epoch 198
# Epoch: 198, MSE 0.00222457 (0.00230980), PSNR 26.52754593 (26.38533039), SSIM 0.77369070 (0.76974337)
# Finished training epoch 198
# Validate: MSE 0.00260444 (0.00228678), PSNR 25.84286118 (26.46404838), SSIM 0.71140116 (0.76905262)
# Finished validation.
# Starting training epoch 199
# Epoch: 199, MSE 0.00233464 (0.00229397), PSNR 26.31780815 (26.41814199), SSIM 0.76598322 (0.77044219)
# Finished training epoch 199
# Validate: MSE 0.00276339 (0.00248639), PSNR 25.58558273 (26.11280944), SSIM 0.70543915 (0.76270982)
# Finished validation.
# Starting training epoch 200
# Epoch: 200, MSE 0.00299189 (0.00230086), PSNR 25.24054527 (26.40382314), SSIM 0.73228103 (0.77053780)
# Finished training epoch 200
# Validate: MSE 0.00285256 (0.00236891), PSNR 25.44765091 (26.31475469), SSIM 0.70414495 (0.76335474)
# Finished validation.
# Starting training epoch 201
# Epoch: 201, MSE 0.00223175 (0.00229367), PSNR 26.51355362 (26.41895734), SSIM 0.77746123 (0.77052848)
# Finished training epoch 201
# Validate: MSE 0.00261960 (0.00246406), PSNR 25.81764984 (26.13608390), SSIM 0.70756400 (0.76500790)
# Finished validation.
# Starting training epoch 202
# Epoch: 202, MSE 0.00253680 (0.00231183), PSNR 25.95713425 (26.38387112), SSIM 0.75119209 (0.77012413)
# Finished training epoch 202
# Validate: MSE 0.00249775 (0.00238809), PSNR 26.02450943 (26.28446204), SSIM 0.71810675 (0.76891435)
# Finished validation.
# Starting training epoch 203
# Epoch: 203, MSE 0.00231244 (0.00228812), PSNR 26.35929871 (26.42408798), SSIM 0.77935112 (0.77061543)
# Finished training epoch 203
# Validate: MSE 0.00273631 (0.00230107), PSNR 25.62834167 (26.44303213), SSIM 0.70967400 (0.77611609)
# Finished validation.
# Starting training epoch 204
# Epoch: 204, MSE 0.00256641 (0.00229811), PSNR 25.90673065 (26.40874200), SSIM 0.73166716 (0.77076499)
# Finished training epoch 204
# Validate: MSE 0.00279154 (0.00230624), PSNR 25.54155731 (26.43574784), SSIM 0.70881546 (0.76951599)
# Finished validation.
# Starting training epoch 205
# Epoch: 205, MSE 0.00193900 (0.00230478), PSNR 27.12421036 (26.39647858), SSIM 0.79393107 (0.77002627)
# Finished training epoch 205
# Validate: MSE 0.00276211 (0.00235421), PSNR 25.58758926 (26.35113726), SSIM 0.71430588 (0.77659227)
# Finished validation.
# Starting training epoch 206
# Epoch: 206, MSE 0.00206075 (0.00229751), PSNR 26.85975647 (26.41172048), SSIM 0.75615668 (0.77013839)
# Finished training epoch 206
# Validate: MSE 0.00276544 (0.00232372), PSNR 25.58235168 (26.39718923), SSIM 0.70691919 (0.77440695)
# Finished validation.
# Starting training epoch 207
# Epoch: 207, MSE 0.00246695 (0.00230444), PSNR 26.07840157 (26.39799952), SSIM 0.78341949 (0.76974782)
# Finished training epoch 207
# Validate: MSE 0.00273827 (0.00248273), PSNR 25.62523460 (26.11919823), SSIM 0.70745909 (0.76638319)
# Finished validation.
# Starting training epoch 208
# Epoch: 208, MSE 0.00298456 (0.00230529), PSNR 25.25119209 (26.39750169), SSIM 0.75160474 (0.76977287)
# Finished training epoch 208
# Validate: MSE 0.00276114 (0.00237437), PSNR 25.58911133 (26.30949666), SSIM 0.70913827 (0.76667237)
# Finished validation.
# Starting training epoch 209
# Epoch: 209, MSE 0.00216714 (0.00229138), PSNR 26.64112473 (26.41905927), SSIM 0.77850366 (0.77052226)
# Finished training epoch 209
# Validate: MSE 0.00286728 (0.00229630), PSNR 25.42530441 (26.45640153), SSIM 0.71190053 (0.77317270)
# Finished validation.
# Starting training epoch 210
# Epoch: 210, MSE 0.00216165 (0.00229392), PSNR 26.65214920 (26.41739692), SSIM 0.77645123 (0.77054530)
# Finished training epoch 210
# Validate: MSE 0.00288547 (0.00247584), PSNR 25.39783287 (26.13687154), SSIM 0.71401626 (0.77137521)
# Finished validation.
# Starting training epoch 211
# Epoch: 211, MSE 0.00224614 (0.00229847), PSNR 26.48562241 (26.40836252), SSIM 0.75859678 (0.77044988)
# Finished training epoch 211
# Validate: MSE 0.00275354 (0.00233602), PSNR 25.60107994 (26.37403663), SSIM 0.69604880 (0.76395401)
# Finished validation.
# Starting training epoch 212
# Epoch: 212, MSE 0.00224133 (0.00230001), PSNR 26.49493408 (26.40700044), SSIM 0.78799438 (0.77045664)
# Finished training epoch 212
# Validate: MSE 0.00259884 (0.00228900), PSNR 25.85220909 (26.45782220), SSIM 0.70942211 (0.76853769)
# Finished validation.
# Starting training epoch 213
# Epoch: 213, MSE 0.00189700 (0.00228996), PSNR 27.21932411 (26.42461285), SSIM 0.77613866 (0.77087742)
# Finished training epoch 213
# Validate: MSE 0.00267755 (0.00246022), PSNR 25.72262001 (26.15859193), SSIM 0.70389825 (0.76835618)
# Finished validation.
# Starting training epoch 214
# Epoch: 214, MSE 0.00188939 (0.00229476), PSNR 27.23678398 (26.41676117), SSIM 0.77134800 (0.77027361)
# Finished training epoch 214
# Validate: MSE 0.00268292 (0.00230185), PSNR 25.71391869 (26.43286683), SSIM 0.71149004 (0.77258437)
# Finished validation.
# Starting training epoch 215
# Epoch: 215, MSE 0.00272013 (0.00229049), PSNR 25.65410423 (26.42408560), SSIM 0.75102001 (0.77068037)
# Finished training epoch 215
# Validate: MSE 0.00290366 (0.00243546), PSNR 25.37054825 (26.20210845), SSIM 0.70051348 (0.76633673)
# Finished validation.
# Starting training epoch 216
# Epoch: 216, MSE 0.00277626 (0.00229118), PSNR 25.56539154 (26.41909111), SSIM 0.74823391 (0.77070938)
# Finished training epoch 216
# Validate: MSE 0.00284915 (0.00232030), PSNR 25.45284653 (26.40910600), SSIM 0.70800394 (0.77281018)
# Finished validation.
# Starting training epoch 217
# Epoch: 217, MSE 0.00224259 (0.00229621), PSNR 26.49250412 (26.41021697), SSIM 0.76628578 (0.77043476)
# Finished training epoch 217
# Validate: MSE 0.00274839 (0.00246077), PSNR 25.60921097 (26.15473839), SSIM 0.71077752 (0.77240840)
# Finished validation.
# Starting training epoch 218
# Epoch: 218, MSE 0.00183086 (0.00231780), PSNR 27.37344170 (26.37175085), SSIM 0.78741974 (0.76893610)
# Finished training epoch 218
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00279272 (0.00229199), PSNR 25.53972626 (26.45894022), SSIM 0.71499741 (0.77053429)
# Finished validation.
# Starting training epoch 219
# Epoch: 219, MSE 0.00188037 (0.00230203), PSNR 27.25757217 (26.39985139), SSIM 0.79891205 (0.77012164)
# Finished training epoch 219
# Validate: MSE 0.00310966 (0.00249185), PSNR 25.07286453 (26.10326673), SSIM 0.71334803 (0.76874077)
# Finished validation.
# Starting training epoch 220
# Epoch: 220, MSE 0.00193522 (0.00228412), PSNR 27.13270569 (26.43387031), SSIM 0.78259051 (0.77069475)
# Finished training epoch 220
# Validate: MSE 0.00268858 (0.00228130), PSNR 25.70476532 (26.47615839), SSIM 0.70923972 (0.77398599)
# Finished validation.
# Starting training epoch 221
# Epoch: 221, MSE 0.00239730 (0.00230266), PSNR 26.20277596 (26.40178096), SSIM 0.77502006 (0.76938998)
# Finished training epoch 221
# Validate: MSE 0.00276957 (0.00233898), PSNR 25.57587242 (26.37475802), SSIM 0.70689201 (0.77024667)
# Finished validation.
# Starting training epoch 222
# Epoch: 222, MSE 0.00206539 (0.00229922), PSNR 26.84998512 (26.40720590), SSIM 0.75971496 (0.77016226)
# Finished training epoch 222
# Validate: MSE 0.00263084 (0.00233530), PSNR 25.79905319 (26.37869941), SSIM 0.70489877 (0.76490993)
# Finished validation.
# Starting training epoch 223
# Epoch: 223, MSE 0.00213880 (0.00230247), PSNR 26.69830513 (26.39968869), SSIM 0.77647436 (0.77008514)
# Finished training epoch 223
# Validate: MSE 0.00269706 (0.00228403), PSNR 25.69108963 (26.47771605), SSIM 0.70866764 (0.77169291)
# Finished validation.
# Starting training epoch 224
# Epoch: 224, MSE 0.00218578 (0.00227971), PSNR 26.60394096 (26.44365688), SSIM 0.78537339 (0.77128466)
# Finished training epoch 224
# Validate: MSE 0.00264806 (0.00227387), PSNR 25.77071571 (26.49517909), SSIM 0.71768188 (0.77681192)
# Finished validation.
# Starting training epoch 225
# Epoch: 225, MSE 0.00222033 (0.00228975), PSNR 26.53582573 (26.42563814), SSIM 0.76431578 (0.77056218)
# Finished training epoch 225
# Validate: MSE 0.00260661 (0.00228076), PSNR 25.83923340 (26.48027451), SSIM 0.71713328 (0.77136463)
# Finished validation.
# Starting training epoch 226
# Epoch: 226, MSE 0.00263970 (0.00229104), PSNR 25.78444672 (26.42308211), SSIM 0.75697029 (0.77046564)
# Finished training epoch 226
# Validate: MSE 0.00264632 (0.00229477), PSNR 25.77357101 (26.45078867), SSIM 0.70696348 (0.76690482)
# Finished validation.
# Starting training epoch 227
# Epoch: 227, MSE 0.00195089 (0.00228043), PSNR 27.09766769 (26.44333514), SSIM 0.78323162 (0.77061532)
# Finished training epoch 227
# Validate: MSE 0.00285540 (0.00230108), PSNR 25.44332314 (26.44418859), SSIM 0.70508325 (0.76847787)
# Finished validation.
# Starting training epoch 228
# Epoch: 228, MSE 0.00235787 (0.00229202), PSNR 26.27479362 (26.42254416), SSIM 0.75895923 (0.77048618)
# Finished training epoch 228
# Validate: MSE 0.00264033 (0.00245675), PSNR 25.78341293 (26.16298105), SSIM 0.70907342 (0.76254715)
# Finished validation.
# Starting training epoch 229
# Epoch: 229, MSE 0.00258381 (0.00229320), PSNR 25.87739944 (26.42033424), SSIM 0.74176764 (0.77020754)
# Finished training epoch 229
# Validate: MSE 0.00249355 (0.00232913), PSNR 26.03181267 (26.38301848), SSIM 0.71271241 (0.76588903)
# Finished validation.
# Starting training epoch 230
# Epoch: 230, MSE 0.00288643 (0.00229105), PSNR 25.39638519 (26.42287081), SSIM 0.77918184 (0.77005058)
# Finished training epoch 230
# Validate: MSE 0.00270618 (0.00231827), PSNR 25.67642593 (26.41072979), SSIM 0.71320164 (0.77244479)
# Finished validation.
# Starting training epoch 231
# Epoch: 231, MSE 0.00256469 (0.00229284), PSNR 25.90965462 (26.42088214), SSIM 0.74970937 (0.77019333)
# Finished training epoch 231
# Validate: MSE 0.00264703 (0.00263879), PSNR 25.77240562 (25.84958011), SSIM 0.70464242 (0.75309832)
# Finished validation.
# Starting training epoch 232
# Epoch: 232, MSE 0.00246494 (0.00228409), PSNR 26.08194160 (26.43693329), SSIM 0.75910723 (0.77034743)
# Finished training epoch 232
# Validate: MSE 0.00298813 (0.00244558), PSNR 25.24600983 (26.19174344), SSIM 0.70223236 (0.77074944)
# Finished validation.
# Starting training epoch 233
# Epoch: 233, MSE 0.00235369 (0.00228611), PSNR 26.28250885 (26.43201115), SSIM 0.75735432 (0.77064785)
# Finished training epoch 233
# Validate: MSE 0.00284908 (0.00253234), PSNR 25.45294762 (26.02945655), SSIM 0.71244234 (0.76280267)
# Finished validation.
# Starting training epoch 234
# Epoch: 234, MSE 0.00219263 (0.00228536), PSNR 26.59035301 (26.43176585), SSIM 0.78113770 (0.77013573)
# Finished training epoch 234
# Validate: MSE 0.00289698 (0.00235623), PSNR 25.38054276 (26.34506607), SSIM 0.70828617 (0.77682910)
# Finished validation.
# Starting training epoch 235
# Epoch: 235, MSE 0.00224056 (0.00229698), PSNR 26.49642372 (26.41195469), SSIM 0.77954501 (0.76924202)
# Finished training epoch 235
# Validate: MSE 0.00263974 (0.00228747), PSNR 25.78439522 (26.46586470), SSIM 0.70975769 (0.77000406)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00253776 (0.00228655), PSNR 25.95550156 (26.46911406), SSIM 0.71470141 (0.76996229)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
