# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-ba81895c2c743102" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ba81895c2c743102");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 64

class Autoencoder(nn.Module):
    def __init__(self, input_size=128):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x)), negative_slope=0.1)
        x = F.interpolate(self.convtrans3(x), scale_factor=scale_factor)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]             640
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3          [-1, 128, 16, 16]          73,856
#        BatchNorm2d-4          [-1, 128, 16, 16]             256
#    ConvTranspose2d-5             [-1, 64, 8, 8]          73,792
#        BatchNorm2d-6             [-1, 64, 8, 8]             128
#    ConvTranspose2d-7           [-1, 32, 16, 16]          18,464
#        BatchNorm2d-8           [-1, 32, 16, 16]              64
#    ConvTranspose2d-9            [-1, 2, 16, 16]             578
# ================================================================
# Total params: 167,906
# Trainable params: 167,906
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.69
# Params size (MB): 0.64
# Estimated Total Size (MB): 2.34
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.00395997 (0.07210925), PSNR 24.02308083 (20.20020934), SSIM 0.49807110 (0.35565215)
# Finished training epoch 0
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 100 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00501600 (0.00447828), PSNR 22.99642754 (23.52445583), SSIM 0.39760792 (0.47833114)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00309138 (0.00405904), PSNR 25.09847260 (23.94357850), SSIM 0.59131271 (0.53415837)
# Finished training epoch 1
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 16 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00385019 (0.00347840), PSNR 24.14517403 (24.62630303), SSIM 0.51230961 (0.58389975)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00289960 (0.00347437), PSNR 25.37662315 (24.61602449), SSIM 0.61944377 (0.60804741)
# Finished training epoch 2
# Validate: MSE 0.00337290 (0.00312337), PSNR 24.71997070 (25.11795999), SSIM 0.56866556 (0.63829048)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00269104 (0.00320652), PSNR 25.70080376 (24.96199064), SSIM 0.66482544 (0.65170853)
# Finished training epoch 3
# Validate: MSE 0.00388769 (0.00326970), PSNR 24.10308075 (24.91045326), SSIM 0.59631449 (0.66599934)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00267871 (0.00314213), PSNR 25.72073555 (25.05128213), SSIM 0.66098118 (0.67827899)
# Finished training epoch 4
# Validate: MSE 0.00330104 (0.00290342), PSNR 24.81348801 (25.43324514), SSIM 0.62230325 (0.69341623)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00292001 (0.00302943), PSNR 25.34615326 (25.21204142), SSIM 0.70921654 (0.69796070)
# Finished training epoch 5
# Validate: MSE 0.00337226 (0.00291223), PSNR 24.72078514 (25.42046476), SSIM 0.64237261 (0.71073493)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00368618 (0.00299228), PSNR 24.33423042 (25.25973664), SSIM 0.69310725 (0.71143490)
# Finished training epoch 6
# Validate: MSE 0.00351033 (0.00302182), PSNR 24.54652214 (25.25450935), SSIM 0.64820206 (0.71835897)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00313652 (0.00293532), PSNR 25.03551102 (25.34671466), SSIM 0.72795767 (0.72182804)
# Finished training epoch 7
# Validate: MSE 0.00308608 (0.00273951), PSNR 25.10592651 (25.68518833), SSIM 0.66004300 (0.72935899)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00271484 (0.00283490), PSNR 25.66255188 (25.49747367), SSIM 0.74874991 (0.73070820)
# Finished training epoch 8
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 163 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00327998 (0.00297949), PSNR 24.84129143 (25.31228501), SSIM 0.66141278 (0.72780231)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.00269933 (0.00276349), PSNR 25.68743896 (25.60534546), SSIM 0.76567888 (0.73822524)
# Finished training epoch 9
# Validate: MSE 0.00285841 (0.00280631), PSNR 25.43875885 (25.58213898), SSIM 0.67584896 (0.74032918)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00273486 (0.00275805), PSNR 25.63064575 (25.62151401), SSIM 0.75195754 (0.74422943)
# Finished training epoch 10
# Validate: MSE 0.00292311 (0.00271189), PSNR 25.34154892 (25.75492724), SSIM 0.68662393 (0.75041824)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00246637 (0.00266259), PSNR 26.07941437 (25.76788906), SSIM 0.74519849 (0.75055592)
# Finished training epoch 11
# Validate: MSE 0.00290970 (0.00258494), PSNR 25.36151314 (25.94286631), SSIM 0.68905759 (0.75525674)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00237463 (0.00261716), PSNR 26.24403572 (25.84518935), SSIM 0.77010566 (0.75498914)
# Finished training epoch 12
# Validate: MSE 0.00299411 (0.00264159), PSNR 25.23731804 (25.84568115), SSIM 0.69249475 (0.75812651)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00245361 (0.00258601), PSNR 26.10194588 (25.89743669), SSIM 0.80182993 (0.75880379)
# Finished training epoch 13
# Validate: MSE 0.00364608 (0.00327757), PSNR 24.38173485 (24.94491539), SSIM 0.68337333 (0.75071432)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00257258 (0.00257088), PSNR 25.89630318 (25.92390188), SSIM 0.76857841 (0.76151239)
# Finished training epoch 14
# Validate: MSE 0.00274500 (0.00302796), PSNR 25.61457253 (25.27506095), SSIM 0.69356507 (0.75754794)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00236329 (0.00253824), PSNR 26.26482201 (25.97675842), SSIM 0.78286684 (0.76395350)
# Finished training epoch 15
# Validate: MSE 0.00314917 (0.00274381), PSNR 25.01804352 (25.69426034), SSIM 0.69828969 (0.76317043)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00232642 (0.00252407), PSNR 26.33312416 (26.00425214), SSIM 0.79030150 (0.76580157)
# Finished training epoch 16
# Validate: MSE 0.00269175 (0.00334670), PSNR 25.69965172 (24.91228004), SSIM 0.69610161 (0.75546099)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00269999 (0.00249380), PSNR 25.68636894 (26.05437875), SSIM 0.77328873 (0.76803827)
# Finished training epoch 17
# Validate: MSE 0.00278866 (0.00305064), PSNR 25.54604530 (25.28157592), SSIM 0.69524181 (0.75719425)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00269154 (0.00250039), PSNR 25.69998550 (26.04139853), SSIM 0.75242949 (0.76922280)
# Finished training epoch 18
# Validate: MSE 0.00282677 (0.00423496), PSNR 25.48709488 (23.87484891), SSIM 0.70113558 (0.75099531)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00282947 (0.00246853), PSNR 25.48295403 (26.10192163), SSIM 0.75470716 (0.77046144)
# Finished training epoch 19
# Validate: MSE 0.00287409 (0.00257781), PSNR 25.41498756 (25.97502914), SSIM 0.70518333 (0.77007713)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00231952 (0.00247083), PSNR 26.34601784 (26.09248356), SSIM 0.78573525 (0.77163491)
# Finished training epoch 20
# Validate: MSE 0.00271996 (0.00346842), PSNR 25.65436554 (24.72307843), SSIM 0.70361137 (0.75899626)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00270694 (0.00245939), PSNR 25.67520905 (26.11422463), SSIM 0.74567443 (0.77268003)
# Finished training epoch 21
# Validate: MSE 0.00303116 (0.00270219), PSNR 25.18390846 (25.77180522), SSIM 0.70538414 (0.77248611)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00256211 (0.00245675), PSNR 25.91402817 (26.11931016), SSIM 0.75955445 (0.77341660)
# Finished training epoch 22
# Validate: MSE 0.00327874 (0.00302773), PSNR 24.84292793 (25.25858008), SSIM 0.70285589 (0.76372858)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00278585 (0.00244466), PSNR 25.55042076 (26.13951598), SSIM 0.79206580 (0.77404333)
# Finished training epoch 23
# Validate: MSE 0.00311676 (0.00254993), PSNR 25.06296539 (26.00005629), SSIM 0.70171839 (0.77426104)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00209513 (0.00243448), PSNR 26.78788757 (26.15743984), SSIM 0.79475033 (0.77461482)
# Finished training epoch 24
# Validate: MSE 0.00270045 (0.00326297), PSNR 25.68563652 (25.00290390), SSIM 0.70456493 (0.76607733)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00276122 (0.00243800), PSNR 25.58897972 (26.15398683), SSIM 0.75526154 (0.77511424)
# Finished training epoch 25
# Validate: MSE 0.00280823 (0.00272173), PSNR 25.51567268 (25.77119248), SSIM 0.71289980 (0.77331428)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00283247 (0.00242147), PSNR 25.47834206 (26.18118715), SSIM 0.77118540 (0.77554885)
# Finished training epoch 26
# Validate: MSE 0.00295574 (0.00408671), PSNR 25.29332924 (24.05488415), SSIM 0.70862412 (0.76129878)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00265160 (0.00241348), PSNR 25.76491737 (26.19586059), SSIM 0.76384163 (0.77612131)
# Finished training epoch 27
# Validate: MSE 0.00316443 (0.00279105), PSNR 24.99704933 (25.62369091), SSIM 0.70605135 (0.77376821)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00273470 (0.00240434), PSNR 25.63090515 (26.21318594), SSIM 0.76275671 (0.77637720)
# Finished training epoch 28
# Validate: MSE 0.00302049 (0.00260069), PSNR 25.19923019 (25.92551008), SSIM 0.70821249 (0.77571586)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00222566 (0.00239401), PSNR 26.52540779 (26.23255514), SSIM 0.77907574 (0.77692918)
# Finished training epoch 29
# Validate: MSE 0.00304776 (0.00264804), PSNR 25.16019058 (25.83831780), SSIM 0.71332586 (0.77351478)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00217973 (0.00237625), PSNR 26.61597443 (26.26434820), SSIM 0.77416784 (0.77727795)
# Finished training epoch 30
# Validate: MSE 0.00495684 (0.00517844), PSNR 23.04794693 (22.95789944), SSIM 0.68735552 (0.74810951)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00248769 (0.00237132), PSNR 26.04203033 (26.27280993), SSIM 0.76041591 (0.77766352)
# Finished training epoch 31
# Validate: MSE 0.00361088 (0.00333795), PSNR 24.42387009 (24.88994357), SSIM 0.70785666 (0.77177393)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00323263 (0.00238603), PSNR 24.90444183 (26.24974305), SSIM 0.76956856 (0.77759474)
# Finished training epoch 32
# Validate: MSE 0.00288555 (0.00248706), PSNR 25.39770889 (26.11408443), SSIM 0.71488273 (0.77912979)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00230956 (0.00236017), PSNR 26.36470795 (26.29192312), SSIM 0.76689488 (0.77791075)
# Finished training epoch 33
# Validate: MSE 0.00264335 (0.00247070), PSNR 25.77845573 (26.15894192), SSIM 0.71722728 (0.77750499)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00209404 (0.00235344), PSNR 26.79015160 (26.30383731), SSIM 0.78908682 (0.77819249)
# Finished training epoch 34
# Validate: MSE 0.00303192 (0.00245317), PSNR 25.18281937 (26.17263338), SSIM 0.71161902 (0.77905067)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00278498 (0.00235460), PSNR 25.55178642 (26.30442370), SSIM 0.74122578 (0.77838643)
# Finished training epoch 35
# Validate: MSE 0.00264785 (0.00306675), PSNR 25.77106476 (25.27663751), SSIM 0.71817786 (0.77257788)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00221156 (0.00234615), PSNR 26.55302238 (26.31813134), SSIM 0.77283871 (0.77855032)
# Finished training epoch 36
# Validate: MSE 0.00286310 (0.00347575), PSNR 25.43162918 (24.76219068), SSIM 0.71743637 (0.76353182)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00250439 (0.00233680), PSNR 26.01297188 (26.33707801), SSIM 0.79053271 (0.77877096)
# Finished training epoch 37
# Validate: MSE 0.00283945 (0.00239235), PSNR 25.46766281 (26.28218061), SSIM 0.71608073 (0.78085757)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00244512 (0.00233674), PSNR 26.11699486 (26.33680025), SSIM 0.77560002 (0.77902908)
# Finished training epoch 38
# Validate: MSE 0.00262169 (0.00275778), PSNR 25.81418610 (25.72322855), SSIM 0.72042394 (0.77622112)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00234243 (0.00233108), PSNR 26.30333328 (26.34457754), SSIM 0.78154355 (0.77923449)
# Finished training epoch 39
# Validate: MSE 0.00284047 (0.00236012), PSNR 25.46609306 (26.33928867), SSIM 0.71370220 (0.77914752)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00251949 (0.00233241), PSNR 25.98686409 (26.34500534), SSIM 0.78894722 (0.77936020)
# Finished training epoch 40
# Validate: MSE 0.00315662 (0.00247656), PSNR 25.00777245 (26.13408976), SSIM 0.71260405 (0.77869310)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00197817 (0.00234598), PSNR 27.03735924 (26.31982561), SSIM 0.78623569 (0.77917809)
# Finished training epoch 41
# Validate: MSE 0.00267472 (0.00287245), PSNR 25.72722435 (25.54289083), SSIM 0.71871513 (0.77504333)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00216956 (0.00232140), PSNR 26.63629150 (26.36790213), SSIM 0.78041142 (0.77961546)
# Finished training epoch 42
# Validate: MSE 0.00364254 (0.00400896), PSNR 24.38595772 (24.03931756), SSIM 0.69970733 (0.75376287)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00213819 (0.00232017), PSNR 26.69953346 (26.36635773), SSIM 0.77455008 (0.77983638)
# Finished training epoch 43
# Validate: MSE 0.00275635 (0.00234466), PSNR 25.59666061 (26.36451301), SSIM 0.71785462 (0.78100290)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00269232 (0.00231549), PSNR 25.69873619 (26.37752808), SSIM 0.78821051 (0.77976661)
# Finished training epoch 44
# Validate: MSE 0.00263852 (0.00235686), PSNR 25.78639030 (26.34574297), SSIM 0.72015494 (0.77863829)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00203739 (0.00230613), PSNR 26.90926933 (26.39483159), SSIM 0.79563224 (0.78015263)
# Finished training epoch 45
# Validate: MSE 0.00273916 (0.00243041), PSNR 25.62382507 (26.21853887), SSIM 0.71624655 (0.77834562)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00202606 (0.00231528), PSNR 26.93348122 (26.37747951), SSIM 0.78969920 (0.77989327)
# Finished training epoch 46
# Validate: MSE 0.00288796 (0.00260255), PSNR 25.39409256 (25.92513675), SSIM 0.71348202 (0.77314904)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00203252 (0.00231054), PSNR 26.91964149 (26.38446342), SSIM 0.78827393 (0.78025488)
# Finished training epoch 47
# Validate: MSE 0.00266460 (0.00235389), PSNR 25.74368286 (26.34543574), SSIM 0.71812487 (0.77773145)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00220142 (0.00230360), PSNR 26.57296371 (26.39923833), SSIM 0.79831362 (0.78013960)
# Finished training epoch 48
# Validate: MSE 0.00276779 (0.00261414), PSNR 25.57867241 (25.93114941), SSIM 0.71841455 (0.77813151)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00240755 (0.00229445), PSNR 26.18424988 (26.41525054), SSIM 0.76425445 (0.78034800)
# Finished training epoch 49
# Validate: MSE 0.00295453 (0.00341476), PSNR 25.29511642 (24.82057729), SSIM 0.71289706 (0.76924500)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00235608 (0.00229800), PSNR 26.27810478 (26.41086127), SSIM 0.77162457 (0.78015263)
# Finished training epoch 50
# Validate: MSE 0.00274992 (0.00269404), PSNR 25.60679245 (25.82270405), SSIM 0.71485609 (0.77587454)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00229134 (0.00229795), PSNR 26.39909554 (26.40968811), SSIM 0.77008307 (0.78032477)
# Finished training epoch 51
# Validate: MSE 0.00265404 (0.00246566), PSNR 25.76092339 (26.16907331), SSIM 0.71729642 (0.77896672)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00201819 (0.00229689), PSNR 26.95038033 (26.41442177), SSIM 0.78609574 (0.78015623)
# Finished training epoch 52
# Validate: MSE 0.00276222 (0.00236657), PSNR 25.58741379 (26.32588769), SSIM 0.71850300 (0.77860760)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00265273 (0.00228809), PSNR 25.76306534 (26.42746701), SSIM 0.77489007 (0.78024136)
# Finished training epoch 53
# Validate: MSE 0.00258843 (0.00257520), PSNR 25.86964226 (25.97720930), SSIM 0.71948600 (0.77699551)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00184524 (0.00228063), PSNR 27.33946228 (26.44347889), SSIM 0.78883457 (0.78042043)
# Finished training epoch 54
# Validate: MSE 0.00261073 (0.00233648), PSNR 25.83238602 (26.37323336), SSIM 0.72007871 (0.77641577)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00261169 (0.00228278), PSNR 25.83078957 (26.43909141), SSIM 0.77128190 (0.78043374)
# Finished training epoch 55
# Validate: MSE 0.00261273 (0.00239513), PSNR 25.82905960 (26.27666111), SSIM 0.71736085 (0.77986484)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00216354 (0.00227555), PSNR 26.64834976 (26.45284947), SSIM 0.77390581 (0.78049343)
# Finished training epoch 56
# Validate: MSE 0.00341370 (0.00282811), PSNR 24.66774750 (25.57076693), SSIM 0.70617366 (0.77488922)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00171272 (0.00226406), PSNR 27.66312981 (26.47352043), SSIM 0.79694164 (0.78083032)
# Finished training epoch 57
# Validate: MSE 0.00250817 (0.00246248), PSNR 26.00642967 (26.16623492), SSIM 0.72386348 (0.77915415)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00215190 (0.00226619), PSNR 26.67177391 (26.47032110), SSIM 0.77160728 (0.78062090)
# Finished training epoch 58
# Validate: MSE 0.00372227 (0.00392815), PSNR 24.29191971 (24.13421295), SSIM 0.71037745 (0.75526783)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00208361 (0.00227244), PSNR 26.81183624 (26.45923022), SSIM 0.79586899 (0.78054984)
# Finished training epoch 59
# Validate: MSE 0.00302650 (0.00237079), PSNR 25.19059372 (26.32016970), SSIM 0.71543080 (0.78174148)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00186623 (0.00226120), PSNR 27.29034424 (26.48277658), SSIM 0.78074944 (0.78068691)
# Finished training epoch 60
# Validate: MSE 0.00282835 (0.00240940), PSNR 25.48465919 (26.25258422), SSIM 0.71899629 (0.77833332)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00213365 (0.00226151), PSNR 26.70876884 (26.47927107), SSIM 0.78819472 (0.78081336)
# Finished training epoch 61
# Validate: MSE 0.00273831 (0.00235853), PSNR 25.62517548 (26.33561381), SSIM 0.71412092 (0.77885751)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00192370 (0.00226568), PSNR 27.15863037 (26.47138191), SSIM 0.80452347 (0.78061478)
# Finished training epoch 62
# Validate: MSE 0.00258704 (0.00243708), PSNR 25.87197495 (26.21471647), SSIM 0.72088426 (0.77758533)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00233919 (0.00224706), PSNR 26.30934906 (26.50706734), SSIM 0.80034465 (0.78096678)
# Finished training epoch 63
# Validate: MSE 0.00284333 (0.00237287), PSNR 25.46173096 (26.32041108), SSIM 0.71210539 (0.77744870)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00231953 (0.00224393), PSNR 26.34600830 (26.51274138), SSIM 0.77755743 (0.78093115)
# Finished training epoch 64
# Validate: MSE 0.00311254 (0.00283772), PSNR 25.06884384 (25.54387722), SSIM 0.70823312 (0.76859804)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00221146 (0.00224503), PSNR 26.55319977 (26.50977545), SSIM 0.77851027 (0.78089311)
# Finished training epoch 65
# Validate: MSE 0.00273391 (0.00264869), PSNR 25.63215446 (25.83448359), SSIM 0.71253443 (0.77169657)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00242926 (0.00224060), PSNR 26.14526367 (26.51791658), SSIM 0.78387868 (0.78096933)
# Finished training epoch 66
# Validate: MSE 0.00259020 (0.00224108), PSNR 25.86667061 (26.55846951), SSIM 0.71997368 (0.77881385)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00186793 (0.00224819), PSNR 27.28638268 (26.50379814), SSIM 0.77550310 (0.78078103)
# Finished training epoch 67
# Validate: MSE 0.00257160 (0.00236637), PSNR 25.89796829 (26.32634559), SSIM 0.72282243 (0.77759883)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00203601 (0.00224142), PSNR 26.91220665 (26.51996267), SSIM 0.81295788 (0.78087375)
# Finished training epoch 68
# Validate: MSE 0.00276450 (0.00287301), PSNR 25.58383942 (25.53063292), SSIM 0.70999098 (0.76835879)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00253793 (0.00223625), PSNR 25.95519638 (26.52721134), SSIM 0.78609091 (0.78100926)
# Finished training epoch 69
# Validate: MSE 0.00323067 (0.00269503), PSNR 24.90707779 (25.77745921), SSIM 0.71068740 (0.77343868)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00241158 (0.00223247), PSNR 26.17697716 (26.53363396), SSIM 0.76937932 (0.78086412)
# Finished training epoch 70
# Validate: MSE 0.00262688 (0.00242124), PSNR 25.80560112 (26.22941648), SSIM 0.72366631 (0.77626724)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00274641 (0.00222755), PSNR 25.61234856 (26.54483004), SSIM 0.76646650 (0.78115500)
# Finished training epoch 71
# Validate: MSE 0.00257116 (0.00253017), PSNR 25.89870644 (26.04597506), SSIM 0.71646130 (0.77277455)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00221905 (0.00223296), PSNR 26.53833771 (26.53432650), SSIM 0.78665197 (0.78087557)
# Finished training epoch 72
# Validate: MSE 0.00262843 (0.00234651), PSNR 25.80303192 (26.35404386), SSIM 0.71889788 (0.77436129)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00167570 (0.00222466), PSNR 27.75803375 (26.54816132), SSIM 0.80132592 (0.78101342)
# Finished training epoch 73
# Validate: MSE 0.00256391 (0.00239833), PSNR 25.91097069 (26.25596002), SSIM 0.72176886 (0.77334057)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00204209 (0.00222207), PSNR 26.89925385 (26.55260724), SSIM 0.76329041 (0.78096510)
# Finished training epoch 74
# Validate: MSE 0.00270447 (0.00255327), PSNR 25.67918015 (26.01008771), SSIM 0.71906787 (0.77302111)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00207979 (0.00221648), PSNR 26.81981277 (26.56786388), SSIM 0.79203629 (0.78102515)
# Finished training epoch 75
# Validate: MSE 0.00287080 (0.00222311), PSNR 25.41996956 (26.59611470), SSIM 0.71795833 (0.78069192)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00225803 (0.00221198), PSNR 26.46269417 (26.57393445), SSIM 0.76773936 (0.78114066)
# Finished training epoch 76
# Validate: MSE 0.00268883 (0.00235537), PSNR 25.70436859 (26.34909137), SSIM 0.71777236 (0.77902151)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00210162 (0.00221179), PSNR 26.77446747 (26.57679775), SSIM 0.79269111 (0.78110364)
# Finished training epoch 77
# Validate: MSE 0.00265727 (0.00247496), PSNR 25.75564957 (26.15156063), SSIM 0.71848911 (0.78111710)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00187477 (0.00221961), PSNR 27.27052307 (26.56108018), SSIM 0.78772354 (0.78071269)
# Finished training epoch 78
# Validate: MSE 0.00262723 (0.00250747), PSNR 25.80502510 (26.07286856), SSIM 0.72329158 (0.77039021)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00216673 (0.00222232), PSNR 26.64195633 (26.55439345), SSIM 0.78028202 (0.78098227)
# Finished training epoch 79
# Validate: MSE 0.00301487 (0.00238211), PSNR 25.20731163 (26.30307953), SSIM 0.71737075 (0.78009247)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00198333 (0.00221140), PSNR 27.02604485 (26.57723767), SSIM 0.78448957 (0.78095805)
# Finished training epoch 80
# Validate: MSE 0.00270420 (0.00236889), PSNR 25.67961502 (26.31395731), SSIM 0.71545184 (0.77521999)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00221350 (0.00220777), PSNR 26.54920197 (26.58410598), SSIM 0.77447718 (0.78099457)
# Finished training epoch 81
# Validate: MSE 0.00256200 (0.00238312), PSNR 25.91420555 (26.29663839), SSIM 0.72133309 (0.77889125)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00206710 (0.00221195), PSNR 26.84638977 (26.57403517), SSIM 0.76778072 (0.78080595)
# Finished training epoch 82
# Validate: MSE 0.00291341 (0.00254316), PSNR 25.35598373 (26.01365959), SSIM 0.71477258 (0.77049121)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00212588 (0.00221955), PSNR 26.72461700 (26.55973380), SSIM 0.79107910 (0.78090261)
# Finished training epoch 83
# Validate: MSE 0.00283953 (0.00236727), PSNR 25.46753311 (26.32414249), SSIM 0.71343350 (0.78217553)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00242762 (0.00219697), PSNR 26.14819145 (26.60369553), SSIM 0.77751970 (0.78115011)
# Finished training epoch 84
# Validate: MSE 0.00278293 (0.00232271), PSNR 25.55498123 (26.41172505), SSIM 0.71879047 (0.78112479)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00199694 (0.00220754), PSNR 26.99633980 (26.58407930), SSIM 0.78652740 (0.78078330)
# Finished training epoch 85
# Validate: MSE 0.00287978 (0.00264904), PSNR 25.40640640 (25.84549847), SSIM 0.71552849 (0.76940151)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00208931 (0.00220530), PSNR 26.79997444 (26.58955685), SSIM 0.77396333 (0.78099319)
# Finished training epoch 86
# Validate: MSE 0.00259746 (0.00238035), PSNR 25.85451508 (26.30805182), SSIM 0.72043735 (0.77874943)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00203325 (0.00220070), PSNR 26.91809654 (26.59579508), SSIM 0.77954388 (0.78097039)
# Finished training epoch 87
# Validate: MSE 0.00342001 (0.00311431), PSNR 24.65972519 (25.16366718), SSIM 0.70492756 (0.76414538)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00274197 (0.00220838), PSNR 25.61937141 (26.58165325), SSIM 0.76237160 (0.78085282)
# Finished training epoch 88
# Validate: MSE 0.00281848 (0.00234821), PSNR 25.49984169 (26.35067104), SSIM 0.71327865 (0.77209215)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00199070 (0.00220842), PSNR 27.00993919 (26.58325731), SSIM 0.78173149 (0.78074131)
# Finished training epoch 89
# Validate: MSE 0.00272567 (0.00245462), PSNR 25.64526939 (26.14680450), SSIM 0.70948547 (0.77384033)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00190446 (0.00219462), PSNR 27.20229149 (26.60986591), SSIM 0.77018982 (0.78109687)
# Finished training epoch 90
# Validate: MSE 0.00264633 (0.00229458), PSNR 25.77355766 (26.46427937), SSIM 0.72383809 (0.78118088)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00260899 (0.00218983), PSNR 25.83526802 (26.61689644), SSIM 0.77932489 (0.78097430)
# Finished training epoch 91
# Validate: MSE 0.00275730 (0.00226548), PSNR 25.59515572 (26.51750003), SSIM 0.72074711 (0.78146815)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00245981 (0.00220082), PSNR 26.09097481 (26.59552200), SSIM 0.78669065 (0.78068809)
# Finished training epoch 92
# Validate: MSE 0.00271723 (0.00245204), PSNR 25.65873337 (26.18322858), SSIM 0.72447467 (0.77828654)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00266774 (0.00219542), PSNR 25.73856354 (26.60653786), SSIM 0.77660477 (0.78110528)
# Finished training epoch 93
# Validate: MSE 0.00254226 (0.00237003), PSNR 25.94779205 (26.32545912), SSIM 0.71990871 (0.77530106)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00179130 (0.00218938), PSNR 27.46830750 (26.61794078), SSIM 0.79041314 (0.78086057)
# Finished training epoch 94
# Validate: MSE 0.00276894 (0.00226705), PSNR 25.57686615 (26.51045594), SSIM 0.71747303 (0.77852748)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00274413 (0.00219099), PSNR 25.61595154 (26.61794999), SSIM 0.78083730 (0.78086350)
# Finished training epoch 95
# Validate: MSE 0.00259564 (0.00269508), PSNR 25.85754585 (25.77126148), SSIM 0.71531057 (0.76886021)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00240842 (0.00218614), PSNR 26.18268204 (26.62702885), SSIM 0.76275748 (0.78094766)
# Finished training epoch 96
# Validate: MSE 0.00264202 (0.00232914), PSNR 25.78063774 (26.39418279), SSIM 0.71661085 (0.77802527)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00188539 (0.00218772), PSNR 27.24598694 (26.62079131), SSIM 0.78186440 (0.78083396)
# Finished training epoch 97
# Validate: MSE 0.00281370 (0.00224893), PSNR 25.50721359 (26.54664755), SSIM 0.71402109 (0.78125090)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00192477 (0.00218750), PSNR 27.15621758 (26.62364008), SSIM 0.79388475 (0.78076656)
# Finished training epoch 98
# Validate: MSE 0.00303160 (0.00296512), PSNR 25.18328476 (25.36263571), SSIM 0.71395183 (0.77011189)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00223055 (0.00217917), PSNR 26.51586914 (26.63991569), SSIM 0.78549105 (0.78094985)
# Finished training epoch 99
# Validate: MSE 0.00260496 (0.00224190), PSNR 25.84198761 (26.55057738), SSIM 0.71832609 (0.77693113)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00206239 (0.00218036), PSNR 26.85628319 (26.64003666), SSIM 0.77704108 (0.78098069)
# Finished training epoch 100
# Validate: MSE 0.00312289 (0.00259669), PSNR 25.05443573 (25.94465460), SSIM 0.71191597 (0.77384095)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00196780 (0.00218664), PSNR 27.06018448 (26.62398222), SSIM 0.78089535 (0.78086407)
# Finished training epoch 101
# Validate: MSE 0.00259736 (0.00227442), PSNR 25.85467339 (26.49650586), SSIM 0.71926886 (0.77945364)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00227925 (0.00217434), PSNR 26.42206955 (26.64844752), SSIM 0.77580762 (0.78084455)
# Finished training epoch 102
# Validate: MSE 0.00255176 (0.00229843), PSNR 25.93160248 (26.44808959), SSIM 0.72153687 (0.77886246)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00173261 (0.00217243), PSNR 27.61299896 (26.65282293), SSIM 0.78320903 (0.78098533)
# Finished training epoch 103
# Validate: MSE 0.00262911 (0.00231801), PSNR 25.80191422 (26.41110870), SSIM 0.71706486 (0.77806758)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00162870 (0.00217963), PSNR 27.88157845 (26.64340081), SSIM 0.79107112 (0.78079685)
# Finished training epoch 104
# Validate: MSE 0.00272726 (0.00246849), PSNR 25.64273262 (26.15529783), SSIM 0.71874678 (0.77619845)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00232777 (0.00217407), PSNR 26.33060455 (26.65157657), SSIM 0.76699525 (0.78086839)
# Finished training epoch 105
# Validate: MSE 0.00263638 (0.00223279), PSNR 25.78991318 (26.57155246), SSIM 0.71505725 (0.77656172)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00210766 (0.00217254), PSNR 26.76199913 (26.65493122), SSIM 0.78727502 (0.78073148)
# Finished training epoch 106
# Validate: MSE 0.00261338 (0.00227523), PSNR 25.82797623 (26.49640430), SSIM 0.71919960 (0.78043113)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00170996 (0.00216865), PSNR 27.67014885 (26.65978889), SSIM 0.79238492 (0.78087272)
# Finished training epoch 107
# Validate: MSE 0.00264807 (0.00223794), PSNR 25.77070236 (26.56053681), SSIM 0.71525860 (0.77675213)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00192756 (0.00216831), PSNR 27.14992714 (26.66267726), SSIM 0.78810465 (0.78079136)
# Finished training epoch 108
# Validate: MSE 0.00298414 (0.00236830), PSNR 25.25180626 (26.33452962), SSIM 0.71080023 (0.77915120)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00204124 (0.00218303), PSNR 26.90105438 (26.63167914), SSIM 0.78257114 (0.78080262)
# Finished training epoch 109
# Validate: MSE 0.00276403 (0.00242216), PSNR 25.58457565 (26.22248571), SSIM 0.71258992 (0.77843297)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00237499 (0.00216782), PSNR 26.24338150 (26.66163432), SSIM 0.76731050 (0.78085193)
# Finished training epoch 110
# Validate: MSE 0.00266462 (0.00222026), PSNR 25.74364281 (26.59895467), SSIM 0.71351320 (0.78010397)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00227029 (0.00216221), PSNR 26.43919563 (26.67237013), SSIM 0.76907682 (0.78078211)
# Finished training epoch 111
# Validate: MSE 0.00245197 (0.00229218), PSNR 26.10483932 (26.45965114), SSIM 0.72428781 (0.77502676)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00229408 (0.00216910), PSNR 26.39391136 (26.66152856), SSIM 0.78415090 (0.78063292)
# Finished training epoch 112
# Validate: MSE 0.00279618 (0.00228214), PSNR 25.53434944 (26.48308794), SSIM 0.70956135 (0.77973359)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00192430 (0.00216837), PSNR 27.15727997 (26.66288048), SSIM 0.80108994 (0.78077481)
# Finished training epoch 113
# Validate: MSE 0.00271676 (0.00224809), PSNR 25.65949440 (26.54598405), SSIM 0.71629834 (0.77960554)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00233004 (0.00216313), PSNR 26.32635498 (26.67134016), SSIM 0.75406682 (0.78071969)
# Finished training epoch 114
# Validate: MSE 0.00260710 (0.00228908), PSNR 25.83841515 (26.46546388), SSIM 0.71792197 (0.77714634)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00247229 (0.00215958), PSNR 26.06901169 (26.68037526), SSIM 0.77105242 (0.78086413)
# Finished training epoch 115
# Validate: MSE 0.00270386 (0.00260711), PSNR 25.68016243 (25.92802852), SSIM 0.71566832 (0.77549583)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00196018 (0.00216082), PSNR 27.07702827 (26.67810850), SSIM 0.78667343 (0.78071289)
# Finished training epoch 116
# Validate: MSE 0.00274213 (0.00237267), PSNR 25.61911201 (26.32219505), SSIM 0.71603376 (0.77595925)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00226047 (0.00215875), PSNR 26.45801163 (26.67982834), SSIM 0.77392286 (0.78066804)
# Finished training epoch 117
# Validate: MSE 0.00268843 (0.00230316), PSNR 25.70501328 (26.44579174), SSIM 0.71851820 (0.77951788)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00223698 (0.00216603), PSNR 26.50337029 (26.66720701), SSIM 0.77372539 (0.78059021)
# Finished training epoch 118
# Validate: MSE 0.00313106 (0.00281358), PSNR 25.04308319 (25.59439796), SSIM 0.71011692 (0.76654332)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00235691 (0.00214872), PSNR 26.27657127 (26.70180781), SSIM 0.76628149 (0.78075243)
# Finished training epoch 119
# Validate: MSE 0.00250893 (0.00245029), PSNR 26.00510597 (26.17090248), SSIM 0.71406233 (0.76860635)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00206831 (0.00215921), PSNR 26.84384155 (26.68054553), SSIM 0.77143842 (0.78053918)
# Finished training epoch 120
# Validate: MSE 0.00283459 (0.00291923), PSNR 25.47509384 (25.42341476), SSIM 0.70471078 (0.76176089)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00171026 (0.00215721), PSNR 27.66938210 (26.68334754), SSIM 0.78349066 (0.78064125)
# Finished training epoch 121
# Validate: MSE 0.00286075 (0.00239766), PSNR 25.43519974 (26.27301229), SSIM 0.71352923 (0.77488605)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00185793 (0.00215380), PSNR 27.30970192 (26.69249278), SSIM 0.78059822 (0.78070869)
# Finished training epoch 122
# Validate: MSE 0.00296760 (0.00272699), PSNR 25.27594948 (25.73188612), SSIM 0.70661044 (0.76550833)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00209526 (0.00215283), PSNR 26.78762245 (26.69275221), SSIM 0.80193424 (0.78065497)
# Finished training epoch 123
# Validate: MSE 0.00282397 (0.00222046), PSNR 25.49139595 (26.59980147), SSIM 0.71379745 (0.77958188)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00207285 (0.00214702), PSNR 26.83432198 (26.70510127), SSIM 0.78364670 (0.78063919)
# Finished training epoch 124
# Validate: MSE 0.00265741 (0.00229314), PSNR 25.75541687 (26.46229402), SSIM 0.71529329 (0.77745153)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00225331 (0.00215289), PSNR 26.47178650 (26.69347428), SSIM 0.76035947 (0.78053825)
# Finished training epoch 125
# Validate: MSE 0.00326146 (0.00326156), PSNR 24.86587715 (24.95116079), SSIM 0.69786823 (0.76065685)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00174617 (0.00215169), PSNR 27.57913971 (26.69618725), SSIM 0.78385067 (0.78063232)
# Finished training epoch 126
# Validate: MSE 0.00259948 (0.00248400), PSNR 25.85113144 (26.12177592), SSIM 0.71668881 (0.77815554)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00234250 (0.00215782), PSNR 26.30319595 (26.68492081), SSIM 0.76624715 (0.78047088)
# Finished training epoch 127
# Validate: MSE 0.00266802 (0.00240432), PSNR 25.73810387 (26.26508292), SSIM 0.71765321 (0.77833571)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00213914 (0.00214430), PSNR 26.69760704 (26.71160600), SSIM 0.76612371 (0.78057959)
# Finished training epoch 128
# Validate: MSE 0.00276589 (0.00274453), PSNR 25.58165359 (25.69355621), SSIM 0.70968771 (0.75955276)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00211948 (0.00214802), PSNR 26.73769569 (26.70264181), SSIM 0.77415633 (0.78048064)
# Finished training epoch 129
# Validate: MSE 0.00277450 (0.00248435), PSNR 25.56815720 (26.11696945), SSIM 0.71690750 (0.77380745)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00172662 (0.00214740), PSNR 27.62801743 (26.70332184), SSIM 0.79682982 (0.78057451)
# Finished training epoch 130
# Validate: MSE 0.00289158 (0.00228778), PSNR 25.38864136 (26.47853296), SSIM 0.70773768 (0.77909665)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00217908 (0.00214811), PSNR 26.61726761 (26.70257119), SSIM 0.77415907 (0.78056183)
# Finished training epoch 131
# Validate: MSE 0.00289257 (0.00266060), PSNR 25.38715935 (25.82261101), SSIM 0.71502614 (0.77055351)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00234073 (0.00214313), PSNR 26.30648804 (26.71376897), SSIM 0.77476275 (0.78043915)
# Finished training epoch 132
# Validate: MSE 0.00259836 (0.00237026), PSNR 25.85300064 (26.32582899), SSIM 0.71877116 (0.77743267)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00236312 (0.00214557), PSNR 26.26513672 (26.70660371), SSIM 0.76195133 (0.78050139)
# Finished training epoch 133
# Validate: MSE 0.00255569 (0.00225926), PSNR 25.92491341 (26.51367888), SSIM 0.71905458 (0.77681383)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00312390 (0.00214154), PSNR 25.05303001 (26.71626293), SSIM 0.76191503 (0.78074778)
# Finished training epoch 134
# Validate: MSE 0.00300657 (0.00241767), PSNR 25.21928978 (26.23710394), SSIM 0.71040475 (0.77251703)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00248475 (0.00214302), PSNR 26.04716682 (26.71614404), SSIM 0.79067123 (0.78050455)
# Finished training epoch 135
# Validate: MSE 0.00280291 (0.00271839), PSNR 25.52390480 (25.73139486), SSIM 0.71741116 (0.76783278)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00207909 (0.00213981), PSNR 26.82126236 (26.71878622), SSIM 0.77118915 (0.78042015)
# Finished training epoch 136
# Validate: MSE 0.00281867 (0.00246853), PSNR 25.49955368 (26.14492275), SSIM 0.70919812 (0.77205387)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00174478 (0.00214171), PSNR 27.58260345 (26.71509499), SSIM 0.78376627 (0.78040350)
# Finished training epoch 137
# Validate: MSE 0.00276203 (0.00239962), PSNR 25.58771133 (26.27057139), SSIM 0.72058463 (0.77576755)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00209778 (0.00213798), PSNR 26.78240585 (26.72334010), SSIM 0.79193068 (0.78057050)
# Finished training epoch 138
# Validate: MSE 0.00301255 (0.00235771), PSNR 25.21066093 (26.33562632), SSIM 0.70954072 (0.77330778)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00219973 (0.00214520), PSNR 26.57631302 (26.70719428), SSIM 0.78525680 (0.78044961)
# Finished training epoch 139
# Validate: MSE 0.00280191 (0.00231789), PSNR 25.52545929 (26.41913671), SSIM 0.71803820 (0.78013170)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00184631 (0.00213876), PSNR 27.33694267 (26.72278514), SSIM 0.78337020 (0.78070113)
# Finished training epoch 140
# Validate: MSE 0.00270660 (0.00234434), PSNR 25.67575264 (26.36320618), SSIM 0.71391648 (0.77088354)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00219421 (0.00213345), PSNR 26.58721542 (26.73299445), SSIM 0.77543336 (0.78028712)
# Finished training epoch 141
# Validate: MSE 0.00276296 (0.00231790), PSNR 25.58625793 (26.41633901), SSIM 0.71539462 (0.77113423)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00205115 (0.00214038), PSNR 26.88002205 (26.72099696), SSIM 0.78915375 (0.78031387)
# Finished training epoch 142
# Validate: MSE 0.00313856 (0.00260526), PSNR 25.03268814 (25.91653587), SSIM 0.70754081 (0.76947200)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00234706 (0.00212627), PSNR 26.29476547 (26.74684384), SSIM 0.77008003 (0.78045382)
# Finished training epoch 143
# Validate: MSE 0.00265568 (0.00222904), PSNR 25.75823402 (26.57826706), SSIM 0.71265405 (0.78130507)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00289576 (0.00213895), PSNR 25.38237572 (26.72212921), SSIM 0.76758850 (0.78031000)
# Finished training epoch 144
# Validate: MSE 0.00252637 (0.00243902), PSNR 25.97502327 (26.21380691), SSIM 0.71863353 (0.77384459)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00227296 (0.00212792), PSNR 26.43408203 (26.73968063), SSIM 0.76888990 (0.78035164)
# Finished training epoch 145
# Validate: MSE 0.00268812 (0.00245560), PSNR 25.70550728 (26.18189871), SSIM 0.71187437 (0.77920538)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00214366 (0.00212602), PSNR 26.68844795 (26.74706828), SSIM 0.80504382 (0.78053044)
# Finished training epoch 146
# Validate: MSE 0.00277220 (0.00227150), PSNR 25.57175064 (26.50101490), SSIM 0.71381772 (0.77470304)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00234103 (0.00213254), PSNR 26.30592728 (26.73373642), SSIM 0.78728712 (0.78011948)
# Finished training epoch 147
# Validate: MSE 0.00256856 (0.00231813), PSNR 25.90309525 (26.41350323), SSIM 0.71456188 (0.77308017)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00172115 (0.00213024), PSNR 27.64181137 (26.73699086), SSIM 0.78830576 (0.78023184)
# Finished training epoch 148
# Validate: MSE 0.00266077 (0.00228804), PSNR 25.74992561 (26.46967178), SSIM 0.71412349 (0.77591764)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00183356 (0.00212641), PSNR 27.36705017 (26.74540819), SSIM 0.79168767 (0.78037406)
# Finished training epoch 149
# Validate: MSE 0.00259559 (0.00227825), PSNR 25.85763741 (26.48727300), SSIM 0.71604747 (0.77610543)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00242195 (0.00213346), PSNR 26.15834808 (26.72936015), SSIM 0.76843041 (0.78012289)
# Finished training epoch 150
# Validate: MSE 0.00326761 (0.00338109), PSNR 24.85769844 (24.84319051), SSIM 0.69191658 (0.75626128)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00186009 (0.00214200), PSNR 27.30465698 (26.71549316), SSIM 0.78065586 (0.78007886)
# Finished training epoch 151
# Validate: MSE 0.00265626 (0.00251386), PSNR 25.75729942 (26.06689908), SSIM 0.71160167 (0.76973001)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00278237 (0.00212679), PSNR 25.55585289 (26.74607356), SSIM 0.76518136 (0.78039168)
# Finished training epoch 152
# Validate: MSE 0.00268277 (0.00257831), PSNR 25.71417046 (25.94841789), SSIM 0.70625895 (0.76802395)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00193456 (0.00212346), PSNR 27.13418579 (26.75327388), SSIM 0.78054780 (0.78012264)
# Finished training epoch 153
# Validate: MSE 0.00266700 (0.00220969), PSNR 25.73977089 (26.61825028), SSIM 0.71515346 (0.77798801)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00217472 (0.00212461), PSNR 26.62595749 (26.74976771), SSIM 0.77852815 (0.78043551)
# Finished training epoch 154
# Validate: MSE 0.00245737 (0.00226573), PSNR 26.09528732 (26.50693461), SSIM 0.71868587 (0.77377457)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00210943 (0.00211806), PSNR 26.75834465 (26.76217862), SSIM 0.78045875 (0.78025860)
# Finished training epoch 155
# Validate: MSE 0.00281086 (0.00228534), PSNR 25.51160622 (26.47580727), SSIM 0.71431506 (0.77952684)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00160238 (0.00212348), PSNR 27.95235634 (26.75265838), SSIM 0.79490650 (0.78016184)
# Finished training epoch 156
# Validate: MSE 0.00252938 (0.00232634), PSNR 25.96986580 (26.39665161), SSIM 0.71505535 (0.76933315)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00201346 (0.00212095), PSNR 26.96057320 (26.75952710), SSIM 0.77176678 (0.78019174)
# Finished training epoch 157
# Validate: MSE 0.00261498 (0.00220897), PSNR 25.82531357 (26.61793859), SSIM 0.71153951 (0.77493642)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00208110 (0.00212597), PSNR 26.81706047 (26.74809620), SSIM 0.77537620 (0.78010127)
# Finished training epoch 158
# Validate: MSE 0.00276874 (0.00229993), PSNR 25.57717705 (26.44749345), SSIM 0.71439123 (0.77438674)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00247653 (0.00211702), PSNR 26.06156540 (26.76563849), SSIM 0.79103971 (0.78006452)
# Finished training epoch 159
# Validate: MSE 0.00241404 (0.00232848), PSNR 26.17255211 (26.38116976), SSIM 0.71495628 (0.77052195)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00211515 (0.00212182), PSNR 26.74659157 (26.75555908), SSIM 0.78704357 (0.78012126)
# Finished training epoch 160
# Validate: MSE 0.00262444 (0.00224453), PSNR 25.80963326 (26.54644471), SSIM 0.71112007 (0.77378457)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00218739 (0.00211696), PSNR 26.60073280 (26.76441418), SSIM 0.76905209 (0.78026329)
# Finished training epoch 161
# Validate: MSE 0.00265630 (0.00228842), PSNR 25.75722313 (26.47068529), SSIM 0.71972799 (0.77506308)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00185618 (0.00211403), PSNR 27.31379700 (26.77282975), SSIM 0.77132380 (0.78019062)
# Finished training epoch 162
# Validate: MSE 0.00255712 (0.00231122), PSNR 25.92248344 (26.42229658), SSIM 0.71393651 (0.77103158)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00198594 (0.00212006), PSNR 27.02034187 (26.75822686), SSIM 0.77185935 (0.78015966)
# Finished training epoch 163
# Validate: MSE 0.00267275 (0.00226635), PSNR 25.73042297 (26.51381211), SSIM 0.72051382 (0.77756575)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00177073 (0.00212379), PSNR 27.51847458 (26.75241994), SSIM 0.80946863 (0.78009940)
# Finished training epoch 164
# Validate: MSE 0.00291002 (0.00245634), PSNR 25.36104393 (26.16483990), SSIM 0.71768820 (0.77220013)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00213329 (0.00212066), PSNR 26.70949173 (26.75766242), SSIM 0.78783655 (0.77995570)
# Finished training epoch 165
# Validate: MSE 0.00281975 (0.00233953), PSNR 25.49788475 (26.37346922), SSIM 0.70717502 (0.77635943)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00216408 (0.00212065), PSNR 26.64727020 (26.75747832), SSIM 0.77566451 (0.77999733)
# Finished training epoch 166
# Validate: MSE 0.00265106 (0.00227415), PSNR 25.76580429 (26.49594286), SSIM 0.71194518 (0.77539283)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00183346 (0.00211185), PSNR 27.36728287 (26.77773885), SSIM 0.79764831 (0.78030955)
# Finished training epoch 167
# Validate: MSE 0.00258570 (0.00221063), PSNR 25.87421036 (26.61270230), SSIM 0.71272236 (0.77296934)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00209788 (0.00211450), PSNR 26.78218269 (26.77051428), SSIM 0.80733269 (0.78019725)
# Finished training epoch 168
# Validate: MSE 0.00282405 (0.00259238), PSNR 25.49126816 (25.94836152), SSIM 0.70870399 (0.77069330)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00167600 (0.00211376), PSNR 27.75725365 (26.77515661), SSIM 0.78264654 (0.78008732)
# Finished training epoch 169
# Validate: MSE 0.00246877 (0.00235696), PSNR 26.07520103 (26.33402645), SSIM 0.71496618 (0.76995100)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00197254 (0.00210821), PSNR 27.04973030 (26.78390913), SSIM 0.81233323 (0.78029916)
# Finished training epoch 170
# Validate: MSE 0.00249836 (0.00232836), PSNR 26.02345467 (26.39546724), SSIM 0.71377575 (0.77211869)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00204940 (0.00211096), PSNR 26.88372421 (26.77968807), SSIM 0.77755916 (0.77988118)
# Finished training epoch 171
# Validate: MSE 0.00281926 (0.00235729), PSNR 25.49864960 (26.34281129), SSIM 0.70962727 (0.77186397)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00181902 (0.00211847), PSNR 27.40161705 (26.76376825), SSIM 0.80008525 (0.78007815)
# Finished training epoch 172
# Validate: MSE 0.00257061 (0.00232206), PSNR 25.89963913 (26.39749724), SSIM 0.71338797 (0.77136955)
# Finished validation.
# Starting training epoch 173
# Epoch: 173, MSE 0.00209497 (0.00211096), PSNR 26.78822136 (26.77716816), SSIM 0.76602608 (0.78002205)
# Finished training epoch 173
# Validate: MSE 0.00263758 (0.00241847), PSNR 25.78794289 (26.23445163), SSIM 0.71638399 (0.77066395)
# Finished validation.
# Starting training epoch 174
# Epoch: 174, MSE 0.00219235 (0.00211416), PSNR 26.59089088 (26.77058563), SSIM 0.78329468 (0.77998288)
# Finished training epoch 174
# Validate: MSE 0.00271788 (0.00228897), PSNR 25.65770340 (26.46990657), SSIM 0.71479112 (0.77684758)
# Finished validation.
# Starting training epoch 175
# Epoch: 175, MSE 0.00224099 (0.00210413), PSNR 26.49559784 (26.79005156), SSIM 0.78737175 (0.78007707)
# Finished training epoch 175
# Validate: MSE 0.00290496 (0.00252338), PSNR 25.36859894 (26.06038339), SSIM 0.71019185 (0.77206444)
# Finished validation.
# Starting training epoch 176
# Epoch: 176, MSE 0.00218937 (0.00211377), PSNR 26.59680557 (26.76970731), SSIM 0.78215975 (0.77997976)
# Finished training epoch 176
# Validate: MSE 0.00254191 (0.00236609), PSNR 25.94838905 (26.31791588), SSIM 0.71776211 (0.77537583)
# Finished validation.
# Starting training epoch 177
# Epoch: 177, MSE 0.00217163 (0.00210795), PSNR 26.63213348 (26.78367256), SSIM 0.78502339 (0.78012020)
# Finished training epoch 177
# Validate: MSE 0.00277676 (0.00234084), PSNR 25.56461716 (26.37552524), SSIM 0.71575058 (0.77365813)
# Finished validation.
# Starting training epoch 178
# Epoch: 178, MSE 0.00212380 (0.00210720), PSNR 26.72886658 (26.78539690), SSIM 0.77590096 (0.77990302)
# Finished training epoch 178
# Validate: MSE 0.00263094 (0.00230516), PSNR 25.79888344 (26.43187545), SSIM 0.72308719 (0.77501060)
# Finished validation.
# Starting training epoch 179
# Epoch: 179, MSE 0.00245830 (0.00211419), PSNR 26.09364891 (26.77259578), SSIM 0.73913592 (0.77985515)
# Finished training epoch 179
# Validate: MSE 0.00266456 (0.00229988), PSNR 25.74374771 (26.44297679), SSIM 0.71485865 (0.77400809)
# Finished validation.
# Starting training epoch 180
# Epoch: 180, MSE 0.00167373 (0.00209905), PSNR 27.76313972 (26.80359846), SSIM 0.80240363 (0.78004181)
# Finished training epoch 180
# Validate: MSE 0.00270670 (0.00233650), PSNR 25.67559052 (26.38607316), SSIM 0.71405077 (0.77664859)
# Finished validation.
# Starting training epoch 181
# Epoch: 181, MSE 0.00241405 (0.00210585), PSNR 26.17253494 (26.78854253), SSIM 0.77460182 (0.77998879)
# Finished training epoch 181
# Validate: MSE 0.00270038 (0.00227644), PSNR 25.68575096 (26.48783724), SSIM 0.70944595 (0.77355309)
# Finished validation.
# Starting training epoch 182
# Epoch: 182, MSE 0.00190591 (0.00210364), PSNR 27.19898415 (26.79140859), SSIM 0.78410208 (0.77986291)
# Finished training epoch 182
# Validate: MSE 0.00256672 (0.00229800), PSNR 25.90621948 (26.44452415), SSIM 0.71199381 (0.77214552)
# Finished validation.
# Starting training epoch 183
# Epoch: 183, MSE 0.00192357 (0.00211791), PSNR 27.15891457 (26.76158232), SSIM 0.77505881 (0.77977946)
# Finished training epoch 183
# Validate: MSE 0.00260156 (0.00238570), PSNR 25.84765816 (26.28885108), SSIM 0.71712673 (0.77082327)
# Finished validation.
# Starting training epoch 184
# Epoch: 184, MSE 0.00200692 (0.00210340), PSNR 26.97470665 (26.79038373), SSIM 0.77854747 (0.77978703)
# Finished training epoch 184
# Validate: MSE 0.00279131 (0.00226880), PSNR 25.54191971 (26.50442330), SSIM 0.71256363 (0.77298103)
# Finished validation.
# Starting training epoch 185
# Epoch: 185, MSE 0.00233914 (0.00210257), PSNR 26.30944443 (26.79679224), SSIM 0.76448810 (0.77989186)
# Finished training epoch 185
# Validate: MSE 0.00280690 (0.00250776), PSNR 25.51772499 (26.08394193), SSIM 0.71398783 (0.77052776)
# Finished validation.
# Starting training epoch 186
# Epoch: 186, MSE 0.00187201 (0.00209848), PSNR 27.27690697 (26.80648719), SSIM 0.79116660 (0.78001188)
# Finished training epoch 186
# Validate: MSE 0.00287809 (0.00282548), PSNR 25.40894890 (25.58742256), SSIM 0.70287061 (0.75865709)
# Finished validation.
# Starting training epoch 187
# Epoch: 187, MSE 0.00217208 (0.00211021), PSNR 26.63123322 (26.77823200), SSIM 0.77131355 (0.77972474)
# Finished training epoch 187
# Validate: MSE 0.00280929 (0.00244100), PSNR 25.51403427 (26.19836664), SSIM 0.71029592 (0.77298358)
# Finished validation.
# Starting training epoch 188
# Epoch: 188, MSE 0.00182863 (0.00209721), PSNR 27.37873077 (26.80433343), SSIM 0.79653537 (0.78002954)
# Finished training epoch 188
# Validate: MSE 0.00277699 (0.00223602), PSNR 25.56426048 (26.56500318), SSIM 0.70921886 (0.77448267)
# Finished validation.
# Starting training epoch 189
# Epoch: 189, MSE 0.00200568 (0.00209878), PSNR 26.97739029 (26.80230600), SSIM 0.76627284 (0.77974143)
# Finished training epoch 189
# Validate: MSE 0.00279298 (0.00230590), PSNR 25.53932762 (26.43758451), SSIM 0.70920247 (0.77371221)
# Finished validation.
# Starting training epoch 190
# Epoch: 190, MSE 0.00165112 (0.00210567), PSNR 27.82221031 (26.78845883), SSIM 0.80311143 (0.77977097)
# Finished training epoch 190
# Validate: MSE 0.00251534 (0.00221996), PSNR 25.99402428 (26.59568924), SSIM 0.71823192 (0.77328405)
# Finished validation.
# Starting training epoch 191
# Epoch: 191, MSE 0.00187803 (0.00210992), PSNR 27.26297569 (26.78174304), SSIM 0.79693300 (0.77963750)
# Finished training epoch 191
# Validate: MSE 0.00269356 (0.00245264), PSNR 25.69673538 (26.17541683), SSIM 0.70989650 (0.76973939)
# Finished validation.
# Starting training epoch 192
# Epoch: 192, MSE 0.00252597 (0.00209287), PSNR 25.97571945 (26.81314281), SSIM 0.77091742 (0.78002165)
# Finished training epoch 192
# Validate: MSE 0.00268776 (0.00224949), PSNR 25.70609283 (26.54024257), SSIM 0.71221173 (0.77406286)
# Finished validation.
# Starting training epoch 193
# Epoch: 193, MSE 0.00234619 (0.00208474), PSNR 26.29637337 (26.83172514), SSIM 0.77626193 (0.77996401)
# Finished training epoch 193
# Validate: MSE 0.00255591 (0.00222505), PSNR 25.92454529 (26.58202021), SSIM 0.71171290 (0.77316185)
# Finished validation.
# Starting training epoch 194
# Epoch: 194, MSE 0.00223547 (0.00209758), PSNR 26.50630188 (26.80547640), SSIM 0.78368926 (0.77988362)
# Finished training epoch 194
# Validate: MSE 0.00284429 (0.00268872), PSNR 25.46025848 (25.80373190), SSIM 0.70973802 (0.77009955)
# Finished validation.
# Starting training epoch 195
# Epoch: 195, MSE 0.00156735 (0.00210365), PSNR 28.04833412 (26.79463650), SSIM 0.78355598 (0.77964169)
# Finished training epoch 195
# Validate: MSE 0.00276207 (0.00244907), PSNR 25.58764458 (26.17935930), SSIM 0.71254939 (0.77294935)
# Finished validation.
# Starting training epoch 196
# Epoch: 196, MSE 0.00191076 (0.00209847), PSNR 27.18794441 (26.80190474), SSIM 0.78005183 (0.77980587)
# Finished training epoch 196
# Validate: MSE 0.00257481 (0.00243760), PSNR 25.89254189 (26.19062863), SSIM 0.71295232 (0.76799210)
# Finished validation.
# Starting training epoch 197
# Epoch: 197, MSE 0.00191313 (0.00209163), PSNR 27.18256569 (26.81696834), SSIM 0.77658617 (0.77981131)
# Finished training epoch 197
# Validate: MSE 0.00277262 (0.00230844), PSNR 25.57109261 (26.43547442), SSIM 0.71978325 (0.77667487)
# Finished validation.
# Starting training epoch 198
# Epoch: 198, MSE 0.00167286 (0.00208665), PSNR 27.76539040 (26.82855128), SSIM 0.78809965 (0.77988291)
# Finished training epoch 198
# Validate: MSE 0.00302654 (0.00242187), PSNR 25.19053841 (26.23498416), SSIM 0.71143198 (0.77540142)
# Finished validation.
# Starting training epoch 199
# Epoch: 199, MSE 0.00221892 (0.00209625), PSNR 26.53859138 (26.80662340), SSIM 0.78768158 (0.77978052)
# Finished training epoch 199
# Validate: MSE 0.00268317 (0.00240265), PSNR 25.71351624 (26.26309463), SSIM 0.71504140 (0.77485931)
# Finished validation.
# Starting training epoch 200
# Epoch: 200, MSE 0.00188964 (0.00209859), PSNR 27.23620605 (26.80252220), SSIM 0.79140663 (0.77968037)
# Finished training epoch 200
# Validate: MSE 0.00304490 (0.00225099), PSNR 25.16427231 (26.54178303), SSIM 0.71094590 (0.77804539)
# Finished validation.
# Starting training epoch 201
# Epoch: 201, MSE 0.00249316 (0.00208993), PSNR 26.03248978 (26.82185459), SSIM 0.78065801 (0.77980310)
# Finished training epoch 201
# Validate: MSE 0.00256233 (0.00224382), PSNR 25.91365051 (26.55063135), SSIM 0.71361542 (0.77338068)
# Finished validation.
# Starting training epoch 202
# Epoch: 202, MSE 0.00206079 (0.00209128), PSNR 26.85967064 (26.81559962), SSIM 0.78127670 (0.77969946)
# Finished training epoch 202
# Validate: MSE 0.00250568 (0.00237908), PSNR 26.01073456 (26.30084340), SSIM 0.71311945 (0.77329643)
# Finished validation.
# Starting training epoch 203
# Epoch: 203, MSE 0.00212130 (0.00209113), PSNR 26.73398018 (26.81642234), SSIM 0.77766800 (0.77980979)
# Finished training epoch 203
# Validate: MSE 0.00264474 (0.00222873), PSNR 25.77617073 (26.57975782), SSIM 0.70869064 (0.77112738)
# Finished validation.
# Starting training epoch 204
# Epoch: 204, MSE 0.00190909 (0.00209095), PSNR 27.19173813 (26.81868916), SSIM 0.77489853 (0.77968488)
# Finished training epoch 204
# Validate: MSE 0.00279891 (0.00223978), PSNR 25.53010750 (26.56424903), SSIM 0.71621406 (0.77713045)
# Finished validation.
# Starting training epoch 205
# Epoch: 205, MSE 0.00192022 (0.00208699), PSNR 27.16648865 (26.82630011), SSIM 0.77779400 (0.77986881)
# Finished training epoch 205
# Validate: MSE 0.00275596 (0.00234926), PSNR 25.59726143 (26.35582227), SSIM 0.70387721 (0.77002892)
# Finished validation.
# Starting training epoch 206
# Epoch: 206, MSE 0.00209285 (0.00209043), PSNR 26.79261398 (26.82102639), SSIM 0.78079301 (0.77974796)
# Finished training epoch 206
# Validate: MSE 0.00282127 (0.00228744), PSNR 25.49554634 (26.47472334), SSIM 0.71159673 (0.77202590)
# Finished validation.
# Starting training epoch 207
# Epoch: 207, MSE 0.00229999 (0.00208590), PSNR 26.38273621 (26.82908498), SSIM 0.77905691 (0.77955544)
# Finished training epoch 207
# Validate: MSE 0.00257919 (0.00231392), PSNR 25.88517189 (26.41912553), SSIM 0.71349919 (0.77266913)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00257919 (0.00231392), PSNR 25.88517189 (26.41912558), SSIM 0.71349913 (0.77266914)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
