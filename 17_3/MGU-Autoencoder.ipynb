# %%
# For plotting
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# For conversion
from skimage.color import lab2rgb, rgb2lab, rgb2gray
from skimage import io
# For everything
import torch
import torch.nn as nn
import torch.nn.functional as F
# For our model
import torchvision
import torchvision.models as models
from torchvision import datasets, transforms
from torchmetrics import MeanSquaredError, PeakSignalNoiseRatio, StructuralSimilarityIndexMeasure
from PIL import Image
# For utilities
import os, shutil, time

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs
# Out:
#       <iframe id="tensorboard-frame-e332860b3e330abb" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e332860b3e330abb");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# colab i kaggle jeszcze nie testowane
colab = False
kaggle = False
test_number = '12_2'

# %%
color_imgs = 'outputs/color/'
gray_imgs = 'outputs/gray/'
checkpoints = 'checkpoints'
if colab:
    from google.colab import drive
    drive.mount('/content/drive')
    dataset = '/content/drive/MyDrive/MGU/cifar10/'
    
    color_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{color_imgs}'
    gray_imgs = f'/content/drive/MyDrive/MGU/{test_number}/{gray_imgs}'
    checkpoints = f'/content/drive/MyDrive/MGU/{test_number}/{checkpoints}'
elif kaggle:
    dataset = '/kaggle/input/cifar10/'
    
    color_imgs = f'{test_number}/{color_imgs}'
    gray_imgs = f'{test_number}/{gray_imgs}'
    checkpoints = f'{test_number}/{checkpoints}'
else:
    dataset = '../../datasets/cifar10/'

# %%
# Make folders and set parameters
os.makedirs(color_imgs, exist_ok=True)
os.makedirs(gray_imgs, exist_ok=True)
os.makedirs(checkpoints, exist_ok=True)
save_images = True
best_losses = [1e10, 1e10, 1e10]
best_epoch = -1
patience = 50
epochs = 500
batch_size = 128
SIZE = 32

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

# %%
# Check if GPU is available
use_gpu = torch.cuda.is_available()
print(use_gpu)
# Out:
# True

# %%
class LabImageFolder(torch.utils.data.Dataset):
    def __init__(self, paths, split='train'):
        if split == 'train':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC),
                transforms.RandomCrop(SIZE),
                transforms.RandomHorizontalFlip(),  
            ])
        elif split == 'val':
            self.transforms = transforms.Compose([
                transforms.Resize((SIZE, SIZE), transforms.InterpolationMode.BICUBIC), 
                transforms.RandomCrop(SIZE), 
            ])
            
        self.split = split
        self.size = SIZE
        self.paths = [os.path.join(paths, file) for file in os.listdir(paths) if os.path.isfile(
            os.path.join(paths, file))]
        
        
    def __getitem__(self, index):
        img = Image.open(self.paths[index]).convert("RGB")
        img_original = self.transforms(img)
        img_original = np.asarray(img_original)
        img_lab = rgb2lab(img_original)
        img_lab = (img_lab + 128) / 255
        img_ab = img_lab[:, :, 1:3]
        img_ab = torch.from_numpy(img_ab.transpose((2, 0, 1))).float()
        img_gray = rgb2gray(img_original)
        img_gray = torch.from_numpy(img_gray).unsqueeze(0).float()
        return img_gray, img_ab
    
    def __len__(self):
        return len(self.paths)

# %%
# Training
train_imagefolder = LabImageFolder(dataset + 'train')
train_loader = torch.utils.data.DataLoader(train_imagefolder, batch_size=batch_size, shuffle=True)
# Validation 
val_imagefolder = LabImageFolder(dataset + 'val' , 'val')
val_loader = torch.utils.data.DataLoader(val_imagefolder, batch_size=batch_size, shuffle=False)

# %%
kernel_size=3
stride_en=1
stride_de=1
padding=1
scale_factor=2
padding_mode='zeros'
channels_base = 256

class Autoencoder(nn.Module):
    def __init__(self, input_size=128):
        super(Autoencoder, self).__init__()

        self.conv1 = nn.Conv2d(1, channels_base, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)
        self.conv2 = nn.Conv2d(channels_base, channels_base * 2, kernel_size=kernel_size, stride=stride_en, padding=padding, padding_mode=padding_mode)

        self.convtrans1 = nn.ConvTranspose2d(channels_base * 2, channels_base, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans2 = nn.ConvTranspose2d(channels_base, channels_base // 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)
        self.convtrans3 = nn.ConvTranspose2d(channels_base // 2, 2, kernel_size=kernel_size, stride=stride_de, padding=padding, padding_mode=padding_mode)

        self.batchnorm1 = nn.BatchNorm2d(channels_base)
        self.batchnorm2 = nn.BatchNorm2d(channels_base * 2)
        self.batchnorm3 = nn.BatchNorm2d(channels_base)
        self.batchnorm4 = nn.BatchNorm2d(channels_base // 2)
        
    def forward(self, input):
        # encoder
        x = F.leaky_relu(self.batchnorm1(self.conv1(input)), negative_slope=0.1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)), negative_slope=0.1)
        x = F.avg_pool2d(x, kernel_size=3, stride=2, padding=1)
        
        # decoder
        x = F.leaky_relu(self.batchnorm3(self.convtrans1(x)), negative_slope=0.1)
        x = F.interpolate(x, scale_factor=scale_factor)
        x = F.leaky_relu(self.batchnorm4(self.convtrans2(x)), negative_slope=0.1)
        x = F.interpolate(self.convtrans3(x), scale_factor=scale_factor)

        return x

# %%
model = Autoencoder()

# %%
criterion = [MeanSquaredError(), PeakSignalNoiseRatio(data_range=1.0), StructuralSimilarityIndexMeasure(data_range=1.0)]

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

# %%
# # Move model and loss function to GPU
if use_gpu: 
    criterion = [criterion[0].to("cuda"), criterion[1].to("cuda"), criterion[2].to("cuda")]
    model = model.cuda()

# %%
if use_gpu: 
    from torchsummary import summary
    summary(model, (1, SIZE, SIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 32, 32]           2,560
#        BatchNorm2d-2          [-1, 256, 32, 32]             512
#             Conv2d-3          [-1, 512, 16, 16]       1,180,160
#        BatchNorm2d-4          [-1, 512, 16, 16]           1,024
#    ConvTranspose2d-5            [-1, 256, 8, 8]       1,179,904
#        BatchNorm2d-6            [-1, 256, 8, 8]             512
#    ConvTranspose2d-7          [-1, 128, 16, 16]         295,040
#        BatchNorm2d-8          [-1, 128, 16, 16]             256
#    ConvTranspose2d-9            [-1, 2, 16, 16]           2,306
# ================================================================
# Total params: 2,662,274
# Trainable params: 2,662,274
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 6.75
# Params size (MB): 10.16
# Estimated Total Size (MB): 16.91
# ----------------------------------------------------------------

# %%
class AverageMeter(object):
    '''A handy class from the PyTorch ImageNet tutorial''' 
    def __init__(self):
        self.reset()
    def reset(self):
        self.val, self.avg, self.sum, self.count = 0, 0, 0, 0
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def to_rgb(grayscale_input, ab_input, save_path=None, save_name=None):
    '''Show/save rgb image from grayscale and ab channels
       Input save_path in the form {'grayscale': '/path/', 'colorized': '/path/'}'''
    plt.clf() # clear matplotlib 
    color_image = torch.cat((grayscale_input, ab_input), 0).numpy() # combine channels
    color_image = color_image.transpose((1, 2, 0))  # rescale for matplotlib
    color_image[:, :, 0:1] = color_image[:, :, 0:1] * 100
    color_image[:, :, 1:3] = color_image[:, :, 1:3] * 255 - 128   
    color_image = lab2rgb(color_image.astype(np.float64))
    grayscale_input = grayscale_input.squeeze().numpy()
    if save_path is not None and save_name is not None: 
        plt.imsave(arr=grayscale_input, fname='{}{}'.format(save_path['grayscale'], save_name), cmap='gray')
        plt.imsave(arr=color_image, fname='{}{}'.format(save_path['colorized'], save_name))

# %%
def validate(val_loader, model, criterion, save_images, epoch):
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]

    model.eval()
    already_saved_images = False
    for gray, ab in val_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()

        # Run model and record loss
        output_ab = model(gray) # throw away class predictions
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))

        # Save images to file
        if save_images and not already_saved_images:
            already_saved_images = True
            for j in range(min(len(output_ab), 10)): # save at most 5 images
                save_path = {'grayscale': gray_imgs, 'colorized': color_imgs}
                save_name = 'img-{}-epoch-{}.jpg'.format(j, epoch)
                to_rgb(gray[j].cpu(), ab_input=output_ab[j].detach().cpu(), save_path=save_path, save_name=save_name)

    print(f'Validate: MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print('Finished validation.')
    if epoch >= 0:
        writer.add_scalar("MSE/test", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/test", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/test", _loss[2].avg, epoch)
    return _loss[0].avg, _loss[1].avg, _loss[2].avg

# %%
def train(train_loader, model, criterion, optimizer, epoch):
    print(f'Starting training epoch {epoch}')
    _loss = [AverageMeter(), AverageMeter(), AverageMeter()]
    
    model.train()

    for gray, ab in train_loader:
        if use_gpu: 
            gray, ab = gray.cuda(), ab.cuda()
            
        optimizer.zero_grad()

        output_ab = model(gray) 
        loss = [criterion[0](output_ab, ab), criterion[1](output_ab, ab), criterion[2](output_ab, ab)]
        
        loss[0].backward()
        optimizer.step()
        
        _loss[0].update(loss[0].item(), gray.size(0))
        _loss[1].update(loss[1].item(), gray.size(0))
        _loss[2].update(loss[2].item(), gray.size(0))
        
    print(f'Epoch: {epoch}, MSE {_loss[0].val:.8f} ({_loss[0].avg:.8f}), PSNR {_loss[1].val:.8f} ({_loss[1].avg:.8f}), SSIM {_loss[2].val:.8f} ({_loss[2].avg:.8f})')

    print(f'Finished training epoch {epoch}')
    if epoch >= 0:
        writer.add_scalar("MSE/train", _loss[0].avg, epoch)
        writer.add_scalar("PSNR/train", _loss[1].avg, epoch)
        writer.add_scalar("SSIM/train", _loss[2].avg, epoch)

# %%
# Train model
for epoch in range(epochs):
    # Train for one epoch, then validate
    train(train_loader, model, criterion, optimizer, epoch)
    with torch.no_grad():
        losses = validate(val_loader, model, criterion, save_images, epoch)
    # Save checkpoint and replace old best model if current model is better
    if losses[0] < best_losses[0]:
        best_losses[0] = losses[0]
        best_epoch = epoch
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}.pth')
    if losses[1] < best_losses[1]:
        best_losses[1] = losses[1]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-PSNRLoss-{losses[1]:.8f}.pth')
    if losses[2] < best_losses[2]:
        best_losses[2] = losses[2]
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-SSIMLoss-{losses[2]:.8f}.pth')
    
    if epoch - best_epoch >= patience and epoch >= 100:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-MSELoss-{losses[0]:.8f}-early_stop.pth')
        break
    
    if epoch == epochs - 1:
        torch.save(model.state_dict(), f'{checkpoints}/epoch-{epoch}-last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')
# Out:
# Starting training epoch 0
# Epoch: 0, MSE 0.01403700 (1.10604152), PSNR 18.52725601 (13.45730746), SSIM 0.25151959 (0.16115290)
# Finished training epoch 0
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 8 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 5 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 13 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 12 pixels
#   return func(*args, **kwargs)
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 166 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.01299332 (0.01219544), PSNR 18.86279869 (19.16979901), SSIM 0.20267975 (0.27511389)
# Finished validation.
# Starting training epoch 1
# Epoch: 1, MSE 0.00638667 (0.00863926), PSNR 21.94725609 (20.71664290), SSIM 0.40723848 (0.34501353)
# Finished training epoch 1
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 34 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00705020 (0.00621563), PSNR 21.51798820 (22.08946611), SSIM 0.30919349 (0.40057519)
# Finished validation.
# Starting training epoch 2
# Epoch: 2, MSE 0.00486796 (0.00575800), PSNR 23.12652588 (22.42987719), SSIM 0.47686148 (0.43843427)
# Finished training epoch 2
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 21 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00583069 (0.00559902), PSNR 22.34279823 (22.57581513), SSIM 0.37776470 (0.46822066)
# Finished validation.
# Starting training epoch 3
# Epoch: 3, MSE 0.00433237 (0.00474015), PSNR 23.63274765 (23.26658913), SSIM 0.53503323 (0.49857273)
# Finished training epoch 3
# Validate: MSE 0.00550643 (0.00487058), PSNR 22.59129715 (23.15691014), SSIM 0.42187586 (0.51986861)
# Finished validation.
# Starting training epoch 4
# Epoch: 4, MSE 0.00395494 (0.00434421), PSNR 24.02859497 (23.65808513), SSIM 0.59011328 (0.54000273)
# Finished training epoch 4
# Validate: MSE 0.00575043 (0.00582091), PSNR 22.40299988 (22.48346262), SSIM 0.44516003 (0.53823552)
# Finished validation.
# Starting training epoch 5
# Epoch: 5, MSE 0.00459446 (0.00497631), PSNR 23.37765884 (23.20637043), SSIM 0.59345829 (0.56314319)
# Finished training epoch 5
# Validate: MSE 0.00689051 (0.00752965), PSNR 21.61748695 (21.42993427), SSIM 0.45940948 (0.54983176)
# Finished validation.
# Starting training epoch 6
# Epoch: 6, MSE 0.00437830 (0.00567923), PSNR 23.58693886 (22.83902609), SSIM 0.58408666 (0.58098195)
# Finished training epoch 6
# Validate: MSE 0.00372131 (0.00342201), PSNR 24.29303932 (24.70761327), SSIM 0.52610099 (0.61802108)
# Finished validation.
# Starting training epoch 7
# Epoch: 7, MSE 0.00574999 (0.00575244), PSNR 22.40332985 (22.87575197), SSIM 0.59275645 (0.59978985)
# Finished training epoch 7
# Validate: MSE 0.00637064 (0.00681021), PSNR 21.95816994 (21.72671132), SSIM 0.50218451 (0.59296664)
# Finished validation.
# Starting training epoch 8
# Epoch: 8, MSE 0.00354038 (0.00628738), PSNR 24.50949860 (22.55859814), SSIM 0.62928098 (0.60967622)
# Finished training epoch 8
# Validate: MSE 0.00385622 (0.00365110), PSNR 24.13837814 (24.44621093), SSIM 0.55587363 (0.64283940)
# Finished validation.
# Starting training epoch 9
# Epoch: 9, MSE 0.01512919 (0.00613743), PSNR 18.20184326 (22.64932408), SSIM 0.52246332 (0.62033480)
# Finished training epoch 9
# Validate: MSE 0.00575854 (0.00670226), PSNR 22.39687538 (21.87865114), SSIM 0.52621710 (0.60820413)
# Finished validation.
# Starting training epoch 10
# Epoch: 10, MSE 0.00436380 (0.00569305), PSNR 23.60134888 (22.85389347), SSIM 0.67407495 (0.63253129)
# Finished training epoch 10
# Validate: MSE 0.00564727 (0.00555472), PSNR 22.48161125 (22.64369421), SSIM 0.54849350 (0.63227958)
# Finished validation.
# Starting training epoch 11
# Epoch: 11, MSE 0.00448977 (0.00526946), PSNR 23.47775459 (23.14708326), SSIM 0.67742997 (0.64380558)
# Finished training epoch 11
# Validate: MSE 0.00329698 (0.00287976), PSNR 24.81884003 (25.46140717), SSIM 0.59736335 (0.68486406)
# Finished validation.
# Starting training epoch 12
# Epoch: 12, MSE 0.00343466 (0.00534996), PSNR 24.64115715 (23.08913910), SSIM 0.66813123 (0.64760578)
# Finished training epoch 12
# /home/konrad/.local/lib/python3.10/site-packages/skimage/_shared/utils.py:394: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   return func(*args, **kwargs)
# Validate: MSE 0.00430464 (0.00424570), PSNR 23.66062927 (23.83279915), SSIM 0.57066810 (0.65928069)
# Finished validation.
# Starting training epoch 13
# Epoch: 13, MSE 0.00468285 (0.00514263), PSNR 23.29489326 (23.16980596), SSIM 0.62744683 (0.65307865)
# Finished training epoch 13
# Validate: MSE 0.00451306 (0.00464948), PSNR 23.45528793 (23.41726406), SSIM 0.57446420 (0.66249702)
# Finished validation.
# Starting training epoch 14
# Epoch: 14, MSE 0.00502409 (0.00506608), PSNR 22.98942757 (23.32739623), SSIM 0.63140601 (0.66034466)
# Finished training epoch 14
# Validate: MSE 0.00527541 (0.00629407), PSNR 22.77744102 (22.17141524), SSIM 0.55878580 (0.64116774)
# Finished validation.
# Starting training epoch 15
# Epoch: 15, MSE 0.00239081 (0.00433925), PSNR 26.21455193 (23.91964270), SSIM 0.70529079 (0.67297887)
# Finished training epoch 15
# Validate: MSE 0.00360616 (0.00324129), PSNR 24.42955208 (24.94248177), SSIM 0.61235571 (0.69638186)
# Finished validation.
# Starting training epoch 16
# Epoch: 16, MSE 0.00273315 (0.00418642), PSNR 25.63335800 (24.02070550), SSIM 0.71796507 (0.67896512)
# Finished training epoch 16
# Validate: MSE 0.00352619 (0.00329467), PSNR 24.52693939 (24.87389652), SSIM 0.61108220 (0.69551646)
# Finished validation.
# Starting training epoch 17
# Epoch: 17, MSE 0.00260761 (0.00375573), PSNR 25.83756638 (24.41103682), SSIM 0.69957447 (0.69106294)
# Finished training epoch 17
# Validate: MSE 0.00291287 (0.00302879), PSNR 25.35678291 (25.27888726), SSIM 0.63226461 (0.71486056)
# Finished validation.
# Starting training epoch 18
# Epoch: 18, MSE 0.00284320 (0.00386092), PSNR 25.46192360 (24.28265231), SSIM 0.71666706 (0.69202597)
# Finished training epoch 18
# Validate: MSE 0.00311236 (0.00275035), PSNR 25.06909752 (25.66128482), SSIM 0.64358687 (0.71945610)
# Finished validation.
# Starting training epoch 19
# Epoch: 19, MSE 0.00302552 (0.00344035), PSNR 25.19199753 (24.72699120), SSIM 0.70873177 (0.70567553)
# Finished training epoch 19
# Validate: MSE 0.00357857 (0.00353447), PSNR 24.46290970 (24.62098677), SSIM 0.63440782 (0.71128228)
# Finished validation.
# Starting training epoch 20
# Epoch: 20, MSE 0.00197187 (0.00327928), PSNR 27.05121803 (24.94992940), SSIM 0.76552463 (0.71557150)
# Finished training epoch 20
# Validate: MSE 0.00283337 (0.00271162), PSNR 25.47697067 (25.75288559), SSIM 0.66476643 (0.73903554)
# Finished validation.
# Starting training epoch 21
# Epoch: 21, MSE 0.00286200 (0.00314908), PSNR 25.43330765 (25.08304255), SSIM 0.72906208 (0.72292021)
# Finished training epoch 21
# Validate: MSE 0.00338623 (0.00298069), PSNR 24.70283890 (25.31951351), SSIM 0.65877789 (0.73605804)
# Finished validation.
# Starting training epoch 22
# Epoch: 22, MSE 0.00277832 (0.00307032), PSNR 25.56217575 (25.20236204), SSIM 0.73474044 (0.72933690)
# Finished training epoch 22
# Validate: MSE 0.00313834 (0.00313562), PSNR 25.03300095 (25.11963950), SSIM 0.65676451 (0.73069078)
# Finished validation.
# Starting training epoch 23
# Epoch: 23, MSE 0.00317829 (0.00293493), PSNR 24.97806549 (25.36688063), SSIM 0.72402704 (0.73602104)
# Finished training epoch 23
# Validate: MSE 0.00328646 (0.00288969), PSNR 24.83271980 (25.44465926), SSIM 0.66884112 (0.74176486)
# Finished validation.
# Starting training epoch 24
# Epoch: 24, MSE 0.00296009 (0.00287000), PSNR 25.28695488 (25.46315178), SSIM 0.74747074 (0.74180453)
# Finished training epoch 24
# Validate: MSE 0.00332088 (0.00300713), PSNR 24.78746223 (25.28995003), SSIM 0.67115390 (0.74147909)
# Finished validation.
# Starting training epoch 25
# Epoch: 25, MSE 0.00236289 (0.00280476), PSNR 26.26555634 (25.55756760), SSIM 0.76429641 (0.74629090)
# Finished training epoch 25
# Validate: MSE 0.00316910 (0.00330934), PSNR 24.99063301 (24.91583045), SSIM 0.66697943 (0.73494478)
# Finished validation.
# Starting training epoch 26
# Epoch: 26, MSE 0.00250796 (0.00273539), PSNR 26.00679398 (25.66217055), SSIM 0.74890757 (0.75059972)
# Finished training epoch 26
# Validate: MSE 0.00666389 (0.00725313), PSNR 21.76271820 (21.46977250), SSIM 0.63787091 (0.69377660)
# Finished validation.
# Starting training epoch 27
# Epoch: 27, MSE 0.00308831 (0.00267902), PSNR 25.10278320 (25.74949081), SSIM 0.74575794 (0.75513525)
# Finished training epoch 27
# Validate: MSE 0.00290776 (0.00262524), PSNR 25.36441803 (25.88374684), SSIM 0.69364989 (0.76218985)
# Finished validation.
# Starting training epoch 28
# Epoch: 28, MSE 0.00250208 (0.00265456), PSNR 26.01698685 (25.79137059), SSIM 0.75012535 (0.75854614)
# Finished training epoch 28
# Validate: MSE 0.00275375 (0.00288380), PSNR 25.60075378 (25.51269138), SSIM 0.69441098 (0.75819476)
# Finished validation.
# Starting training epoch 29
# Epoch: 29, MSE 0.00222399 (0.00263667), PSNR 26.52867889 (25.81315099), SSIM 0.76791310 (0.76130470)
# Finished training epoch 29
# Validate: MSE 0.00331332 (0.00266981), PSNR 24.79736519 (25.80389837), SSIM 0.69642735 (0.76519845)
# Finished validation.
# Starting training epoch 30
# Epoch: 30, MSE 0.00259723 (0.00259637), PSNR 25.85489655 (25.88098931), SSIM 0.75954777 (0.76409939)
# Finished training epoch 30
# Validate: MSE 0.00301784 (0.00319310), PSNR 25.20303345 (25.10876428), SSIM 0.69521427 (0.76096917)
# Finished validation.
# Starting training epoch 31
# Epoch: 31, MSE 0.00206404 (0.00256657), PSNR 26.85281372 (25.93021045), SSIM 0.76146382 (0.76691714)
# Finished training epoch 31
# Validate: MSE 0.00275172 (0.00312326), PSNR 25.60395050 (25.19133090), SSIM 0.69854450 (0.75742265)
# Finished validation.
# Starting training epoch 32
# Epoch: 32, MSE 0.00212370 (0.00255709), PSNR 26.72907448 (25.94950581), SSIM 0.77876002 (0.76827496)
# Finished training epoch 32
# Validate: MSE 0.00295229 (0.00255202), PSNR 25.29841423 (26.00472436), SSIM 0.70097947 (0.76951794)
# Finished validation.
# Starting training epoch 33
# Epoch: 33, MSE 0.00255173 (0.00250526), PSNR 25.93165398 (26.03355479), SSIM 0.77722430 (0.77076536)
# Finished training epoch 33
# Validate: MSE 0.00284781 (0.00352720), PSNR 25.45489120 (24.71522895), SSIM 0.69771230 (0.75937723)
# Finished validation.
# Starting training epoch 34
# Epoch: 34, MSE 0.00272111 (0.00251083), PSNR 25.65253639 (26.02415378), SSIM 0.74679440 (0.77180760)
# Finished training epoch 34
# Validate: MSE 0.00290756 (0.00340788), PSNR 25.36471558 (24.83459385), SSIM 0.70015019 (0.76246255)
# Finished validation.
# Starting training epoch 35
# Epoch: 35, MSE 0.00216809 (0.00250780), PSNR 26.63923264 (26.03029564), SSIM 0.77256262 (0.77280738)
# Finished training epoch 35
# Validate: MSE 0.00332084 (0.00273367), PSNR 24.78751945 (25.70749353), SSIM 0.70441645 (0.77020165)
# Finished validation.
# Starting training epoch 36
# Epoch: 36, MSE 0.00258711 (0.00246080), PSNR 25.87184906 (26.11341941), SSIM 0.77428043 (0.77430374)
# Finished training epoch 36
# Validate: MSE 0.00283052 (0.00254959), PSNR 25.48134422 (26.01877132), SSIM 0.70963192 (0.77478880)
# Finished validation.
# Starting training epoch 37
# Epoch: 37, MSE 0.00270076 (0.00245452), PSNR 25.68514442 (26.12401169), SSIM 0.76029432 (0.77497966)
# Finished training epoch 37
# Validate: MSE 0.00287879 (0.00249162), PSNR 25.40789223 (26.10327843), SSIM 0.70855367 (0.77634032)
# Finished validation.
# Starting training epoch 38
# Epoch: 38, MSE 0.00255671 (0.00243441), PSNR 25.92319107 (26.15975778), SSIM 0.75972056 (0.77574185)
# Finished training epoch 38
# Validate: MSE 0.00276500 (0.00262996), PSNR 25.58304977 (25.89940178), SSIM 0.71046066 (0.77269685)
# Finished validation.
# Starting training epoch 39
# Epoch: 39, MSE 0.00255571 (0.00241595), PSNR 25.92489052 (26.19226251), SSIM 0.78966266 (0.77643438)
# Finished training epoch 39
# Validate: MSE 0.00308758 (0.00317306), PSNR 25.10381889 (25.13178466), SSIM 0.70806813 (0.76535635)
# Finished validation.
# Starting training epoch 40
# Epoch: 40, MSE 0.00217833 (0.00238767), PSNR 26.61876869 (26.24109665), SSIM 0.77613831 (0.77740441)
# Finished training epoch 40
# Validate: MSE 0.00310051 (0.00291241), PSNR 25.08566284 (25.45253142), SSIM 0.70559978 (0.76844101)
# Finished validation.
# Starting training epoch 41
# Epoch: 41, MSE 0.00238819 (0.00239613), PSNR 26.21931458 (26.22964672), SSIM 0.77660596 (0.77756255)
# Finished training epoch 41
# Validate: MSE 0.00275161 (0.00300712), PSNR 25.60413551 (25.36974335), SSIM 0.71139157 (0.77166704)
# Finished validation.
# Starting training epoch 42
# Epoch: 42, MSE 0.00212060 (0.00236363), PSNR 26.73541260 (26.28668710), SSIM 0.78564328 (0.77842592)
# Finished training epoch 42
# Validate: MSE 0.00294292 (0.00249846), PSNR 25.31221962 (26.10013888), SSIM 0.71045989 (0.77806440)
# Finished validation.
# Starting training epoch 43
# Epoch: 43, MSE 0.00234330 (0.00236362), PSNR 26.30171585 (26.28605596), SSIM 0.78631914 (0.77849882)
# Finished training epoch 43
# Validate: MSE 0.00285498 (0.00280611), PSNR 25.44396400 (25.62436049), SSIM 0.71333897 (0.77099556)
# Finished validation.
# Starting training epoch 44
# Epoch: 44, MSE 0.00244112 (0.00236866), PSNR 26.12411118 (26.27758950), SSIM 0.78689259 (0.77862889)
# Finished training epoch 44
# Validate: MSE 0.00276272 (0.00256298), PSNR 25.58663559 (25.98084699), SSIM 0.71664178 (0.77943189)
# Finished validation.
# Starting training epoch 45
# Epoch: 45, MSE 0.00194610 (0.00236732), PSNR 27.10833740 (26.27993754), SSIM 0.77793759 (0.77890254)
# Finished training epoch 45
# Validate: MSE 0.00308168 (0.00369695), PSNR 25.11212349 (24.51479241), SSIM 0.70731997 (0.76281651)
# Finished validation.
# Starting training epoch 46
# Epoch: 46, MSE 0.00183423 (0.00235940), PSNR 27.36545563 (26.29739212), SSIM 0.82602823 (0.77901616)
# Finished training epoch 46
# Validate: MSE 0.00276215 (0.00251109), PSNR 25.58752632 (26.07586292), SSIM 0.71279335 (0.77591070)
# Finished validation.
# Starting training epoch 47
# Epoch: 47, MSE 0.00195465 (0.00234483), PSNR 27.08930016 (26.32451020), SSIM 0.78891236 (0.77946897)
# Finished training epoch 47
# Validate: MSE 0.00372644 (0.00438988), PSNR 24.28706360 (23.65473960), SSIM 0.70364535 (0.75250365)
# Finished validation.
# Starting training epoch 48
# Epoch: 48, MSE 0.00247769 (0.00235836), PSNR 26.05953598 (26.29690083), SSIM 0.77228749 (0.77937918)
# Finished training epoch 48
# Validate: MSE 0.00282342 (0.00278222), PSNR 25.49223900 (25.67905887), SSIM 0.71553218 (0.77825270)
# Finished validation.
# Starting training epoch 49
# Epoch: 49, MSE 0.00264196 (0.00234302), PSNR 25.78073502 (26.32769088), SSIM 0.76874703 (0.77977238)
# Finished training epoch 49
# Validate: MSE 0.00320835 (0.00309757), PSNR 24.93717766 (25.16720227), SSIM 0.70061511 (0.76215379)
# Finished validation.
# Starting training epoch 50
# Epoch: 50, MSE 0.00225321 (0.00233302), PSNR 26.47198105 (26.34293471), SSIM 0.79249144 (0.77997560)
# Finished training epoch 50
# Validate: MSE 0.00277134 (0.00249345), PSNR 25.57310677 (26.11611079), SSIM 0.71878409 (0.77637126)
# Finished validation.
# Starting training epoch 51
# Epoch: 51, MSE 0.00255049 (0.00232694), PSNR 25.93376541 (26.35481548), SSIM 0.76555586 (0.78017659)
# Finished training epoch 51
# Validate: MSE 0.00260363 (0.00243354), PSNR 25.84420586 (26.21705727), SSIM 0.71870625 (0.78049546)
# Finished validation.
# Starting training epoch 52
# Epoch: 52, MSE 0.00258174 (0.00231252), PSNR 25.88086891 (26.38120771), SSIM 0.77587903 (0.78067816)
# Finished training epoch 52
# Validate: MSE 0.00276125 (0.00279816), PSNR 25.58893967 (25.64095236), SSIM 0.71364892 (0.76586891)
# Finished validation.
# Starting training epoch 53
# Epoch: 53, MSE 0.00292403 (0.00231945), PSNR 25.34018517 (26.37020075), SSIM 0.77418017 (0.78058497)
# Finished training epoch 53
# Validate: MSE 0.00267948 (0.00237573), PSNR 25.71948433 (26.30063750), SSIM 0.71559823 (0.77553555)
# Finished validation.
# Starting training epoch 54
# Epoch: 54, MSE 0.00208293 (0.00231539), PSNR 26.81325912 (26.37828008), SSIM 0.80235738 (0.78063491)
# Finished training epoch 54
# Validate: MSE 0.00299876 (0.00246313), PSNR 25.23058701 (26.15967060), SSIM 0.71346223 (0.77769560)
# Finished validation.
# Starting training epoch 55
# Epoch: 55, MSE 0.00293420 (0.00232422), PSNR 25.32509422 (26.36163173), SSIM 0.76356781 (0.78066675)
# Finished training epoch 55
# Validate: MSE 0.00281821 (0.00268372), PSNR 25.50027084 (25.77088547), SSIM 0.71795166 (0.77556974)
# Finished validation.
# Starting training epoch 56
# Epoch: 56, MSE 0.00272806 (0.00231016), PSNR 25.64146233 (26.38573352), SSIM 0.76204962 (0.78096381)
# Finished training epoch 56
# Validate: MSE 0.00252312 (0.00232477), PSNR 25.98061943 (26.40152434), SSIM 0.72378796 (0.78130531)
# Finished validation.
# Starting training epoch 57
# Epoch: 57, MSE 0.00244469 (0.00230053), PSNR 26.11775780 (26.40421376), SSIM 0.76894790 (0.78114067)
# Finished training epoch 57
# Validate: MSE 0.00250949 (0.00278343), PSNR 26.00414848 (25.64191933), SSIM 0.72142231 (0.77697124)
# Finished validation.
# Starting training epoch 58
# Epoch: 58, MSE 0.00205273 (0.00230866), PSNR 26.87668991 (26.39019178), SSIM 0.79212505 (0.78120717)
# Finished training epoch 58
# Validate: MSE 0.00296238 (0.00327337), PSNR 25.28359604 (25.01691642), SSIM 0.70951813 (0.76471225)
# Finished validation.
# Starting training epoch 59
# Epoch: 59, MSE 0.00216000 (0.00229553), PSNR 26.65545273 (26.41595487), SSIM 0.78724009 (0.78119289)
# Finished training epoch 59
# Validate: MSE 0.00309396 (0.00270979), PSNR 25.09485435 (25.74862760), SSIM 0.71302134 (0.77511886)
# Finished validation.
# Starting training epoch 60
# Epoch: 60, MSE 0.00212102 (0.00228741), PSNR 26.73454666 (26.43338852), SSIM 0.79324275 (0.78149986)
# Finished training epoch 60
# Validate: MSE 0.00270651 (0.00259535), PSNR 25.67590714 (25.94490120), SSIM 0.71769297 (0.77245049)
# Finished validation.
# Starting training epoch 61
# Epoch: 61, MSE 0.00264736 (0.00229182), PSNR 25.77186584 (26.42412826), SSIM 0.77223951 (0.78150327)
# Finished training epoch 61
# Validate: MSE 0.00248240 (0.00242403), PSNR 26.05128860 (26.22105577), SSIM 0.71967161 (0.77580544)
# Finished validation.
# Starting training epoch 62
# Epoch: 62, MSE 0.00268037 (0.00228506), PSNR 25.71805191 (26.43327356), SSIM 0.76968563 (0.78166263)
# Finished training epoch 62
# Validate: MSE 0.00258921 (0.00241390), PSNR 25.86832047 (26.24171492), SSIM 0.71932566 (0.78121659)
# Finished validation.
# Starting training epoch 63
# Epoch: 63, MSE 0.00179748 (0.00227899), PSNR 27.45335197 (26.44952907), SSIM 0.81003779 (0.78177705)
# Finished training epoch 63
# Validate: MSE 0.00333378 (0.00265458), PSNR 24.77062416 (25.83462807), SSIM 0.71238428 (0.77384573)
# Finished validation.
# Starting training epoch 64
# Epoch: 64, MSE 0.00222633 (0.00227866), PSNR 26.52411270 (26.44801029), SSIM 0.78853530 (0.78171261)
# Finished training epoch 64
# Validate: MSE 0.00247952 (0.00256460), PSNR 26.05632401 (25.99375154), SSIM 0.72139955 (0.78037473)
# Finished validation.
# Starting training epoch 65
# Epoch: 65, MSE 0.00241110 (0.00226124), PSNR 26.17785454 (26.48203169), SSIM 0.78293484 (0.78202733)
# Finished training epoch 65
# Validate: MSE 0.00292217 (0.00248286), PSNR 25.34294128 (26.11021438), SSIM 0.71310878 (0.77490495)
# Finished validation.
# Starting training epoch 66
# Epoch: 66, MSE 0.00281968 (0.00225329), PSNR 25.49800873 (26.49716763), SSIM 0.78715402 (0.78217138)
# Finished training epoch 66
# Validate: MSE 0.00261274 (0.00241477), PSNR 25.82904243 (26.24266121), SSIM 0.71979803 (0.78211000)
# Finished validation.
# Starting training epoch 67
# Epoch: 67, MSE 0.00281299 (0.00227323), PSNR 25.50832176 (26.45617764), SSIM 0.73854256 (0.78177246)
# Finished training epoch 67
# Validate: MSE 0.00274367 (0.00228384), PSNR 25.61668205 (26.47809633), SSIM 0.71825713 (0.78461257)
# Finished validation.
# Starting training epoch 68
# Epoch: 68, MSE 0.00212239 (0.00224072), PSNR 26.73174858 (26.51866771), SSIM 0.79971611 (0.78233214)
# Finished training epoch 68
# Validate: MSE 0.00251735 (0.00233717), PSNR 25.99055481 (26.36794014), SSIM 0.71508360 (0.77814521)
# Finished validation.
# Starting training epoch 69
# Epoch: 69, MSE 0.00186174 (0.00225167), PSNR 27.30079842 (26.49640335), SSIM 0.79372770 (0.78241037)
# Finished training epoch 69
# Validate: MSE 0.00269133 (0.00244341), PSNR 25.70032692 (26.20851044), SSIM 0.71808445 (0.77724672)
# Finished validation.
# Starting training epoch 70
# Epoch: 70, MSE 0.00245241 (0.00224632), PSNR 26.10406876 (26.50928586), SSIM 0.77011919 (0.78224859)
# Finished training epoch 70
# Validate: MSE 0.00289754 (0.00307660), PSNR 25.37970924 (25.27587231), SSIM 0.71399891 (0.76796124)
# Finished validation.
# Starting training epoch 71
# Epoch: 71, MSE 0.00266893 (0.00223993), PSNR 25.73662376 (26.52178457), SSIM 0.77744955 (0.78248201)
# Finished training epoch 71
# Validate: MSE 0.00274070 (0.00241290), PSNR 25.62138939 (26.25155443), SSIM 0.71876180 (0.78155247)
# Finished validation.
# Starting training epoch 72
# Epoch: 72, MSE 0.00255318 (0.00224309), PSNR 25.92918205 (26.51556672), SSIM 0.76693571 (0.78219518)
# Finished training epoch 72
# Validate: MSE 0.00266173 (0.00240140), PSNR 25.74836159 (26.24902934), SSIM 0.71600777 (0.77553653)
# Finished validation.
# Starting training epoch 73
# Epoch: 73, MSE 0.00205699 (0.00222874), PSNR 26.86767960 (26.54532503), SSIM 0.77208233 (0.78254075)
# Finished training epoch 73
# Validate: MSE 0.00269836 (0.00258027), PSNR 25.68899536 (25.98589485), SSIM 0.72150981 (0.77965741)
# Finished validation.
# Starting training epoch 74
# Epoch: 74, MSE 0.00238356 (0.00222777), PSNR 26.22773552 (26.54492237), SSIM 0.78238124 (0.78254921)
# Finished training epoch 74
# Validate: MSE 0.00280192 (0.00244416), PSNR 25.52543449 (26.18706679), SSIM 0.71742052 (0.77755220)
# Finished validation.
# Starting training epoch 75
# Epoch: 75, MSE 0.00287452 (0.00223320), PSNR 25.41434479 (26.53727113), SSIM 0.75718009 (0.78257837)
# Finished training epoch 75
# Validate: MSE 0.00266335 (0.00274213), PSNR 25.74571419 (25.74121021), SSIM 0.71286047 (0.77329797)
# Finished validation.
# Starting training epoch 76
# Epoch: 76, MSE 0.00197471 (0.00221749), PSNR 27.04496002 (26.56380104), SSIM 0.78250754 (0.78268516)
# Finished training epoch 76
# Validate: MSE 0.00267891 (0.00248083), PSNR 25.72041512 (26.14248594), SSIM 0.72131163 (0.78015037)
# Finished validation.
# Starting training epoch 77
# Epoch: 77, MSE 0.00261589 (0.00219501), PSNR 25.82379913 (26.60634647), SSIM 0.76614296 (0.78301158)
# Finished training epoch 77
# Validate: MSE 0.00257946 (0.00276200), PSNR 25.88471413 (25.67369040), SSIM 0.71846515 (0.77608127)
# Finished validation.
# Starting training epoch 78
# Epoch: 78, MSE 0.00227035 (0.00221460), PSNR 26.43907356 (26.57047358), SSIM 0.79021090 (0.78260439)
# Finished training epoch 78
# Validate: MSE 0.00283168 (0.00278497), PSNR 25.47955322 (25.63595571), SSIM 0.71933007 (0.77265813)
# Finished validation.
# Starting training epoch 79
# Epoch: 79, MSE 0.00258393 (0.00220305), PSNR 25.87718964 (26.59430898), SSIM 0.76016051 (0.78273102)
# Finished training epoch 79
# Validate: MSE 0.00264742 (0.00230039), PSNR 25.77177429 (26.44524802), SSIM 0.71850884 (0.78194157)
# Finished validation.
# Starting training epoch 80
# Epoch: 80, MSE 0.00176420 (0.00219572), PSNR 27.53453064 (26.60739964), SSIM 0.78831542 (0.78290088)
# Finished training epoch 80
# Validate: MSE 0.00264576 (0.00221509), PSNR 25.77449036 (26.60730764), SSIM 0.71653605 (0.78272076)
# Finished validation.
# Starting training epoch 81
# Epoch: 81, MSE 0.00240575 (0.00220876), PSNR 26.18749809 (26.57970460), SSIM 0.79289752 (0.78276991)
# Finished training epoch 81
# Validate: MSE 0.00276363 (0.00241581), PSNR 25.58520126 (26.23628000), SSIM 0.72085172 (0.78350937)
# Finished validation.
# Starting training epoch 82
# Epoch: 82, MSE 0.00255858 (0.00218973), PSNR 25.92001534 (26.62113818), SSIM 0.78461635 (0.78284564)
# Finished training epoch 82
# Validate: MSE 0.00409258 (0.00434105), PSNR 23.88003159 (23.70659660), SSIM 0.69310492 (0.75463182)
# Finished validation.
# Starting training epoch 83
# Epoch: 83, MSE 0.00212363 (0.00218058), PSNR 26.72921371 (26.63755234), SSIM 0.79697621 (0.78295506)
# Finished training epoch 83
# Validate: MSE 0.00300620 (0.00361870), PSNR 25.21982193 (24.58219622), SSIM 0.71123183 (0.76589546)
# Finished validation.
# Starting training epoch 84
# Epoch: 84, MSE 0.00262924 (0.00218833), PSNR 25.80170059 (26.62242880), SSIM 0.77712363 (0.78290032)
# Finished training epoch 84
# Validate: MSE 0.00284203 (0.00232404), PSNR 25.46370888 (26.41119823), SSIM 0.71284318 (0.78211712)
# Finished validation.
# Starting training epoch 85
# Epoch: 85, MSE 0.00237029 (0.00217636), PSNR 26.25197601 (26.64511973), SSIM 0.77650511 (0.78292300)
# Finished training epoch 85
# Validate: MSE 0.00257405 (0.00231078), PSNR 25.89383507 (26.42705094), SSIM 0.72638834 (0.77879849)
# Finished validation.
# Starting training epoch 86
# Epoch: 86, MSE 0.00218164 (0.00217199), PSNR 26.61216927 (26.65706982), SSIM 0.79972953 (0.78317544)
# Finished training epoch 86
# Validate: MSE 0.00297487 (0.00287565), PSNR 25.26531601 (25.51835663), SSIM 0.71407843 (0.77240047)
# Finished validation.
# Starting training epoch 87
# Epoch: 87, MSE 0.00199223 (0.00217082), PSNR 27.00660515 (26.65926512), SSIM 0.78549439 (0.78301552)
# Finished training epoch 87
# Validate: MSE 0.00296134 (0.00302674), PSNR 25.28511047 (25.27450408), SSIM 0.71455717 (0.76862813)
# Finished validation.
# Starting training epoch 88
# Epoch: 88, MSE 0.00244077 (0.00216975), PSNR 26.12472916 (26.65805718), SSIM 0.78089136 (0.78294383)
# Finished training epoch 88
# Validate: MSE 0.00259904 (0.00232236), PSNR 25.85187340 (26.40589847), SSIM 0.72378612 (0.77744160)
# Finished validation.
# Starting training epoch 89
# Epoch: 89, MSE 0.00241352 (0.00217619), PSNR 26.17349815 (26.64602920), SSIM 0.75452632 (0.78297127)
# Finished training epoch 89
# Validate: MSE 0.00265068 (0.00226905), PSNR 25.76642609 (26.50565670), SSIM 0.71797037 (0.77907027)
# Finished validation.
# Starting training epoch 90
# Epoch: 90, MSE 0.00232497 (0.00215723), PSNR 26.33583260 (26.68713461), SSIM 0.78150123 (0.78307135)
# Finished training epoch 90
# Validate: MSE 0.00283235 (0.00265583), PSNR 25.47852707 (25.84475871), SSIM 0.72100180 (0.77125989)
# Finished validation.
# Starting training epoch 91
# Epoch: 91, MSE 0.00215001 (0.00215573), PSNR 26.67558670 (26.68600645), SSIM 0.77453464 (0.78300073)
# Finished training epoch 91
# Validate: MSE 0.00291452 (0.00293617), PSNR 25.35433006 (25.40347667), SSIM 0.71898532 (0.76724128)
# Finished validation.
# Starting training epoch 92
# Epoch: 92, MSE 0.00203359 (0.00214793), PSNR 26.91736603 (26.70367033), SSIM 0.78190583 (0.78316012)
# Finished training epoch 92
# Validate: MSE 0.00296665 (0.00259167), PSNR 25.27734184 (25.94195971), SSIM 0.71329790 (0.77393143)
# Finished validation.
# Starting training epoch 93
# Epoch: 93, MSE 0.00220433 (0.00214804), PSNR 26.56723022 (26.70398167), SSIM 0.76333463 (0.78309561)
# Finished training epoch 93
# Validate: MSE 0.00250583 (0.00230526), PSNR 26.01048660 (26.43357969), SSIM 0.72033203 (0.77622821)
# Finished validation.
# Starting training epoch 94
# Epoch: 94, MSE 0.00247903 (0.00214585), PSNR 26.05717659 (26.70557908), SSIM 0.77034032 (0.78298171)
# Finished training epoch 94
# Validate: MSE 0.00275577 (0.00277060), PSNR 25.59756279 (25.68273918), SSIM 0.72083223 (0.77307552)
# Finished validation.
# Starting training epoch 95
# Epoch: 95, MSE 0.00251598 (0.00215732), PSNR 25.99292946 (26.68369294), SSIM 0.77688396 (0.78282802)
# Finished training epoch 95
# Validate: MSE 0.00244127 (0.00229448), PSNR 26.12383842 (26.44861884), SSIM 0.72352290 (0.77436325)
# Finished validation.
# Starting training epoch 96
# Epoch: 96, MSE 0.00182951 (0.00214553), PSNR 27.37664223 (26.70977633), SSIM 0.79094899 (0.78302761)
# Finished training epoch 96
# Validate: MSE 0.00243374 (0.00224980), PSNR 26.13726234 (26.53828915), SSIM 0.72932404 (0.77971700)
# Finished validation.
# Starting training epoch 97
# Epoch: 97, MSE 0.00225374 (0.00212993), PSNR 26.47096252 (26.73994291), SSIM 0.77771568 (0.78331954)
# Finished training epoch 97
# Validate: MSE 0.00251068 (0.00232825), PSNR 26.00208473 (26.38572055), SSIM 0.71724868 (0.78093798)
# Finished validation.
# Starting training epoch 98
# Epoch: 98, MSE 0.00198160 (0.00214181), PSNR 27.02983856 (26.71438355), SSIM 0.79879743 (0.78304577)
# Finished training epoch 98
# Validate: MSE 0.00268983 (0.00232053), PSNR 25.70275497 (26.40841191), SSIM 0.72082067 (0.77877298)
# Finished validation.
# Starting training epoch 99
# Epoch: 99, MSE 0.00242679 (0.00211483), PSNR 26.14967918 (26.76785425), SSIM 0.78757888 (0.78301858)
# Finished training epoch 99
# Validate: MSE 0.00271044 (0.00292657), PSNR 25.66959953 (25.48989260), SSIM 0.70795870 (0.76425319)
# Finished validation.
# Starting training epoch 100
# Epoch: 100, MSE 0.00255063 (0.00211634), PSNR 25.93352890 (26.76516185), SSIM 0.77479255 (0.78317520)
# Finished training epoch 100
# Validate: MSE 0.00324855 (0.00266634), PSNR 24.88310814 (25.83312147), SSIM 0.70982623 (0.77592185)
# Finished validation.
# Starting training epoch 101
# Epoch: 101, MSE 0.00222738 (0.00211765), PSNR 26.52204704 (26.76390179), SSIM 0.77119684 (0.78303692)
# Finished training epoch 101
# Validate: MSE 0.00267389 (0.00231242), PSNR 25.72855759 (26.42540615), SSIM 0.72404158 (0.77852734)
# Finished validation.
# Starting training epoch 102
# Epoch: 102, MSE 0.00213565 (0.00212041), PSNR 26.70469666 (26.75667693), SSIM 0.78602880 (0.78289510)
# Finished training epoch 102
# Validate: MSE 0.00315013 (0.00247961), PSNR 25.01670837 (26.13041531), SSIM 0.71552718 (0.77642312)
# Finished validation.
# Starting training epoch 103
# Epoch: 103, MSE 0.00281350 (0.00211153), PSNR 25.50753593 (26.77691934), SSIM 0.76455700 (0.78312237)
# Finished training epoch 103
# Validate: MSE 0.00256008 (0.00242409), PSNR 25.91745758 (26.22137594), SSIM 0.71764195 (0.77846082)
# Finished validation.
# Starting training epoch 104
# Epoch: 104, MSE 0.00212555 (0.00211269), PSNR 26.72527695 (26.77561047), SSIM 0.77240580 (0.78303348)
# Finished training epoch 104
# Validate: MSE 0.00272138 (0.00228068), PSNR 25.65210152 (26.47537342), SSIM 0.72003520 (0.77484576)
# Finished validation.
# Starting training epoch 105
# Epoch: 105, MSE 0.00185847 (0.00209742), PSNR 27.30844307 (26.80615264), SSIM 0.79587346 (0.78282235)
# Finished training epoch 105
# Validate: MSE 0.00276972 (0.00232731), PSNR 25.57564163 (26.39920384), SSIM 0.71613395 (0.77529388)
# Finished validation.
# Starting training epoch 106
# Epoch: 106, MSE 0.00218642 (0.00210013), PSNR 26.60266113 (26.79988211), SSIM 0.78015870 (0.78300749)
# Finished training epoch 106
# Validate: MSE 0.00287368 (0.00241859), PSNR 25.41561508 (26.24028054), SSIM 0.71769774 (0.77572687)
# Finished validation.
# Starting training epoch 107
# Epoch: 107, MSE 0.00187293 (0.00209245), PSNR 27.27477837 (26.81683466), SSIM 0.80042946 (0.78296472)
# Finished training epoch 107
# Validate: MSE 0.00266807 (0.00234203), PSNR 25.73801994 (26.36949970), SSIM 0.71240926 (0.77550884)
# Finished validation.
# Starting training epoch 108
# Epoch: 108, MSE 0.00246242 (0.00209983), PSNR 26.08638191 (26.80148053), SSIM 0.78228700 (0.78278665)
# Finished training epoch 108
# Validate: MSE 0.00264108 (0.00227235), PSNR 25.78217697 (26.50006100), SSIM 0.72441918 (0.77967958)
# Finished validation.
# Starting training epoch 109
# Epoch: 109, MSE 0.00198632 (0.00210696), PSNR 27.01951599 (26.78567971), SSIM 0.77575272 (0.78267768)
# Finished training epoch 109
# Validate: MSE 0.00270996 (0.00284608), PSNR 25.67037392 (25.56406527), SSIM 0.70996988 (0.76476505)
# Finished validation.
# Starting training epoch 110
# Epoch: 110, MSE 0.00250328 (0.00208654), PSNR 26.01490974 (26.82910302), SSIM 0.75958323 (0.78282220)
# Finished training epoch 110
# Validate: MSE 0.00299643 (0.00280861), PSNR 25.23395348 (25.60540772), SSIM 0.71524590 (0.76398712)
# Finished validation.
# Starting training epoch 111
# Epoch: 111, MSE 0.00218748 (0.00208423), PSNR 26.60055161 (26.83360943), SSIM 0.77129346 (0.78295263)
# Finished training epoch 111
# Validate: MSE 0.00248309 (0.00224279), PSNR 26.05007744 (26.55426784), SSIM 0.72468340 (0.77929421)
# Finished validation.
# Starting training epoch 112
# Epoch: 112, MSE 0.00167776 (0.00208011), PSNR 27.75269318 (26.84181654), SSIM 0.79566318 (0.78281277)
# Finished training epoch 112
# Validate: MSE 0.00274834 (0.00233176), PSNR 25.60929108 (26.38725470), SSIM 0.71953321 (0.77666729)
# Finished validation.
# Starting training epoch 113
# Epoch: 113, MSE 0.00196578 (0.00207415), PSNR 27.06464195 (26.85108380), SSIM 0.77456701 (0.78290288)
# Finished training epoch 113
# Validate: MSE 0.00253940 (0.00224136), PSNR 25.95268250 (26.55559922), SSIM 0.71972346 (0.77428511)
# Finished validation.
# Starting training epoch 114
# Epoch: 114, MSE 0.00191889 (0.00206783), PSNR 27.16949081 (26.86875727), SSIM 0.78318751 (0.78285446)
# Finished training epoch 114
# Validate: MSE 0.00285252 (0.00240341), PSNR 25.44771194 (26.26170645), SSIM 0.71183139 (0.77319352)
# Finished validation.
# Starting training epoch 115
# Epoch: 115, MSE 0.00231247 (0.00207512), PSNR 26.35923958 (26.85044674), SSIM 0.78470987 (0.78274270)
# Finished training epoch 115
# Validate: MSE 0.00268197 (0.00251429), PSNR 25.71546173 (26.06753622), SSIM 0.72032952 (0.77226275)
# Finished validation.
# Starting training epoch 116
# Epoch: 116, MSE 0.00189235 (0.00207924), PSNR 27.22997475 (26.84311549), SSIM 0.78961110 (0.78245699)
# Finished training epoch 116
# Validate: MSE 0.00262951 (0.00232907), PSNR 25.80125618 (26.38073123), SSIM 0.72225171 (0.77218846)
# Finished validation.
# Starting training epoch 117
# Epoch: 117, MSE 0.00167210 (0.00206754), PSNR 27.76737976 (26.86697546), SSIM 0.79435205 (0.78254569)
# Finished training epoch 117
# Validate: MSE 0.00249711 (0.00231401), PSNR 26.02562904 (26.41722545), SSIM 0.72026533 (0.77208067)
# Finished validation.
# Starting training epoch 118
# Epoch: 118, MSE 0.00190657 (0.00204803), PSNR 27.19747734 (26.90741611), SSIM 0.79288125 (0.78280543)
# Finished training epoch 118
# Validate: MSE 0.00263918 (0.00251416), PSNR 25.78531456 (26.06067872), SSIM 0.71573830 (0.77235922)
# Finished validation.
# Starting training epoch 119
# Epoch: 119, MSE 0.00198134 (0.00204342), PSNR 27.03039932 (26.91395187), SSIM 0.76707232 (0.78280670)
# Finished training epoch 119
# Validate: MSE 0.00269956 (0.00231531), PSNR 25.68707466 (26.42098357), SSIM 0.71205091 (0.77166881)
# Finished validation.
# Starting training epoch 120
# Epoch: 120, MSE 0.00226843 (0.00205946), PSNR 26.44273758 (26.88569268), SSIM 0.77876413 (0.78238675)
# Finished training epoch 120
# Validate: MSE 0.00262186 (0.00238779), PSNR 25.81390190 (26.27618259), SSIM 0.72781843 (0.77154781)
# Finished validation.
# Starting training epoch 121
# Epoch: 121, MSE 0.00265393 (0.00204799), PSNR 25.76110077 (26.90960797), SSIM 0.77662253 (0.78277377)
# Finished training epoch 121
# Validate: MSE 0.00274737 (0.00245802), PSNR 25.61083031 (26.15468844), SSIM 0.72325355 (0.76923808)
# Finished validation.
# Starting training epoch 122
# Epoch: 122, MSE 0.00165698 (0.00205071), PSNR 27.80683136 (26.90370204), SSIM 0.79060644 (0.78244505)
# Finished training epoch 122
# Validate: MSE 0.00232469 (0.00221488), PSNR 26.33635330 (26.60364388), SSIM 0.72663367 (0.77522350)
# Finished validation.
# Starting training epoch 123
# Epoch: 123, MSE 0.00238323 (0.00203814), PSNR 26.22834206 (26.92881002), SSIM 0.78015727 (0.78258441)
# Finished training epoch 123
# Validate: MSE 0.00259378 (0.00225316), PSNR 25.86066246 (26.53265902), SSIM 0.72044569 (0.77337625)
# Finished validation.
# Starting training epoch 124
# Epoch: 124, MSE 0.00183169 (0.00202784), PSNR 27.37148857 (26.95159047), SSIM 0.78696477 (0.78248017)
# Finished training epoch 124
# Validate: MSE 0.00273573 (0.00249877), PSNR 25.62926674 (26.09696530), SSIM 0.71802789 (0.77005652)
# Finished validation.
# Starting training epoch 125
# Epoch: 125, MSE 0.00190462 (0.00203019), PSNR 27.20192146 (26.94392332), SSIM 0.77842867 (0.78240667)
# Finished training epoch 125
# Validate: MSE 0.00262701 (0.00224481), PSNR 25.80538368 (26.54797475), SSIM 0.71482497 (0.77566780)
# Finished validation.
# Starting training epoch 126
# Epoch: 126, MSE 0.00171233 (0.00204234), PSNR 27.66411781 (26.92119670), SSIM 0.78904128 (0.78217128)
# Finished training epoch 126
# Validate: MSE 0.00268226 (0.00254413), PSNR 25.71498489 (26.01237130), SSIM 0.72092271 (0.76839574)
# Finished validation.
# Starting training epoch 127
# Epoch: 127, MSE 0.00193793 (0.00203414), PSNR 27.12660980 (26.94018954), SSIM 0.78746271 (0.78244605)
# Finished training epoch 127
# Validate: MSE 0.00275573 (0.00255586), PSNR 25.59763527 (25.99100802), SSIM 0.71938944 (0.77097109)
# Finished validation.
# Starting training epoch 128
# Epoch: 128, MSE 0.00201923 (0.00201524), PSNR 26.94813728 (26.97845724), SSIM 0.79612905 (0.78240981)
# Finished training epoch 128
# Validate: MSE 0.00276535 (0.00236439), PSNR 25.58250237 (26.32114914), SSIM 0.71611190 (0.76679860)
# Finished validation.
# Starting training epoch 129
# Epoch: 129, MSE 0.00194303 (0.00200041), PSNR 27.11520767 (27.00782551), SSIM 0.78151393 (0.78259385)
# Finished training epoch 129
# Validate: MSE 0.00302821 (0.00247297), PSNR 25.18814278 (26.13458330), SSIM 0.71062392 (0.77157879)
# Finished validation.
# Starting training epoch 130
# Epoch: 130, MSE 0.00217633 (0.00201836), PSNR 26.62275887 (26.97208181), SSIM 0.76204813 (0.78213906)
# Finished training epoch 130
# Validate: MSE 0.00276617 (0.00234949), PSNR 25.58121109 (26.35604940), SSIM 0.71519601 (0.77147461)
# Finished validation.
# Starting training epoch 131
# Epoch: 131, MSE 0.00232553 (0.00200134), PSNR 26.33477974 (27.00679490), SSIM 0.76660144 (0.78222133)
# Finished training epoch 131
# Validate: MSE 0.00254994 (0.00255422), PSNR 25.93470192 (26.00164543), SSIM 0.71380424 (0.76909657)
# Finished validation.
# Starting training epoch 132
# Epoch: 132, MSE 0.00200828 (0.00201843), PSNR 26.97176552 (26.97108126), SSIM 0.78243315 (0.78220208)
# Finished training epoch 132
# Validate: MSE 0.00244369 (0.00228061), PSNR 26.11953545 (26.47062492), SSIM 0.71949476 (0.77088816)
# Finished validation.
# Starting training epoch 133
# Epoch: 133, MSE 0.00200382 (0.00200676), PSNR 26.98140144 (26.99708574), SSIM 0.77584708 (0.78223384)
# Finished training epoch 133
# Validate: MSE 0.00249378 (0.00231218), PSNR 26.03141785 (26.42287705), SSIM 0.72519898 (0.77112905)
# Finished validation.
# Starting training epoch 134
# Epoch: 134, MSE 0.00192218 (0.00199780), PSNR 27.16205025 (27.01659740), SSIM 0.77656806 (0.78207760)
# Finished training epoch 134
# Validate: MSE 0.00273002 (0.00230033), PSNR 25.63834190 (26.44675025), SSIM 0.71176392 (0.77371619)
# Finished validation.
# Starting training epoch 135
# Epoch: 135, MSE 0.00224262 (0.00199823), PSNR 26.49244690 (27.01564144), SSIM 0.78203720 (0.78223235)
# Finished training epoch 135
# Validate: MSE 0.00264042 (0.00230656), PSNR 25.78326988 (26.43273719), SSIM 0.71300340 (0.77149899)
# Finished validation.
# Starting training epoch 136
# Epoch: 136, MSE 0.00224067 (0.00199561), PSNR 26.49622726 (27.02075293), SSIM 0.76658404 (0.78218454)
# Finished training epoch 136
# Validate: MSE 0.00260198 (0.00239778), PSNR 25.84695625 (26.26944534), SSIM 0.70925319 (0.76872904)
# Finished validation.
# Starting training epoch 137
# Epoch: 137, MSE 0.00192794 (0.00199104), PSNR 27.14905357 (27.03027384), SSIM 0.77766526 (0.78234372)
# Finished training epoch 137
# Validate: MSE 0.00271895 (0.00230726), PSNR 25.65599251 (26.42769253), SSIM 0.71196991 (0.77083976)
# Finished validation.
# Starting training epoch 138
# Epoch: 138, MSE 0.00266299 (0.00197821), PSNR 25.74630165 (27.05839769), SSIM 0.78462684 (0.78214320)
# Finished training epoch 138
# Validate: MSE 0.00286477 (0.00280798), PSNR 25.42910385 (25.65712233), SSIM 0.70221752 (0.75907984)
# Finished validation.
# Starting training epoch 139
# Epoch: 139, MSE 0.00195384 (0.00198551), PSNR 27.09110832 (27.04383862), SSIM 0.76806843 (0.78196309)
# Finished training epoch 139
# Validate: MSE 0.00266124 (0.00238305), PSNR 25.74915695 (26.29099567), SSIM 0.71105349 (0.77006384)
# Finished validation.
# Starting training epoch 140
# Epoch: 140, MSE 0.00190914 (0.00198205), PSNR 27.19161606 (27.05136792), SSIM 0.77571309 (0.78208362)
# Finished training epoch 140
# Validate: MSE 0.00273122 (0.00233977), PSNR 25.63642883 (26.37402686), SSIM 0.71256840 (0.76506290)
# Finished validation.
# Starting training epoch 141
# Epoch: 141, MSE 0.00194647 (0.00197175), PSNR 27.10751343 (27.07099220), SSIM 0.79233605 (0.78192181)
# Finished training epoch 141
# Validate: MSE 0.00280339 (0.00242920), PSNR 25.52315903 (26.20393220), SSIM 0.71160597 (0.76582819)
# Finished validation.
# Starting training epoch 142
# Epoch: 142, MSE 0.00196253 (0.00197037), PSNR 27.07182693 (27.07778923), SSIM 0.78148401 (0.78198280)
# Finished training epoch 142
# Validate: MSE 0.00269441 (0.00286691), PSNR 25.69536781 (25.52128295), SSIM 0.71029854 (0.75913074)
# Finished validation.
# Starting training epoch 143
# Epoch: 143, MSE 0.00188662 (0.00196483), PSNR 27.24314499 (27.09007165), SSIM 0.76187915 (0.78182926)
# Finished training epoch 143
# Validate: MSE 0.00285555 (0.00220744), PSNR 25.44309807 (26.62571567), SSIM 0.71776295 (0.77580672)
# Finished validation.
# Starting training epoch 144
# Epoch: 144, MSE 0.00216737 (0.00196241), PSNR 26.64066887 (27.09152518), SSIM 0.78767627 (0.78201097)
# Finished training epoch 144
# Validate: MSE 0.00271413 (0.00226019), PSNR 25.66369247 (26.52001161), SSIM 0.71268934 (0.77034162)
# Finished validation.
# Starting training epoch 145
# Epoch: 145, MSE 0.00261749 (0.00195551), PSNR 25.82114601 (27.11140143), SSIM 0.76042402 (0.78205545)
# Finished training epoch 145
# Validate: MSE 0.00275472 (0.00306141), PSNR 25.59923172 (25.24868968), SSIM 0.70774555 (0.75245916)
# Finished validation.
# Starting training epoch 146
# Epoch: 146, MSE 0.00191851 (0.00196007), PSNR 27.17035866 (27.09902916), SSIM 0.77703613 (0.78188748)
# Finished training epoch 146
# Validate: MSE 0.00274247 (0.00228810), PSNR 25.61858749 (26.47004174), SSIM 0.71528113 (0.77206092)
# Finished validation.
# Starting training epoch 147
# Epoch: 147, MSE 0.00217106 (0.00196605), PSNR 26.63327980 (27.08664842), SSIM 0.78115439 (0.78143666)
# Finished training epoch 147
# Validate: MSE 0.00294571 (0.00236569), PSNR 25.30809784 (26.33085404), SSIM 0.70186067 (0.76900790)
# Finished validation.
# Starting training epoch 148
# Epoch: 148, MSE 0.00167477 (0.00193353), PSNR 27.76044464 (27.15558570), SSIM 0.79046744 (0.78200648)
# Finished training epoch 148
# Validate: MSE 0.00287061 (0.00266722), PSNR 25.42025948 (25.81523343), SSIM 0.71445727 (0.76494967)
# Finished validation.
# Starting training epoch 149
# Epoch: 149, MSE 0.00179551 (0.00194514), PSNR 27.45811081 (27.13512366), SSIM 0.79205847 (0.78169633)
# Finished training epoch 149
# Validate: MSE 0.00298595 (0.00243256), PSNR 25.24917603 (26.20636943), SSIM 0.70533574 (0.76744319)
# Finished validation.
# Starting training epoch 150
# Epoch: 150, MSE 0.00181780 (0.00193053), PSNR 27.40453529 (27.16294217), SSIM 0.78953773 (0.78185275)
# Finished training epoch 150
# Validate: MSE 0.00287598 (0.00236189), PSNR 25.41213989 (26.33209832), SSIM 0.71517295 (0.77159637)
# Finished validation.
# Starting training epoch 151
# Epoch: 151, MSE 0.00191604 (0.00193741), PSNR 27.17595100 (27.14769920), SSIM 0.78361332 (0.78182420)
# Finished training epoch 151
# Validate: MSE 0.00279885 (0.00277993), PSNR 25.53020096 (25.67651776), SSIM 0.69439906 (0.75809013)
# Finished validation.
# Starting training epoch 152
# Epoch: 152, MSE 0.00168583 (0.00196385), PSNR 27.73186111 (27.09160092), SSIM 0.79264402 (0.78124771)
# Finished training epoch 152
# Validate: MSE 0.00253719 (0.00243059), PSNR 25.95646095 (26.20232658), SSIM 0.71787506 (0.76673327)
# Finished validation.
# Starting training epoch 153
# Epoch: 153, MSE 0.00215546 (0.00192476), PSNR 26.66459274 (27.17428560), SSIM 0.76543212 (0.78181911)
# Finished training epoch 153
# Validate: MSE 0.00281220 (0.00223983), PSNR 25.50953102 (26.55944494), SSIM 0.70570195 (0.76948064)
# Finished validation.
# Starting training epoch 154
# Epoch: 154, MSE 0.00188964 (0.00191636), PSNR 27.23620033 (27.19659260), SSIM 0.76888865 (0.78182690)
# Finished training epoch 154
# Validate: MSE 0.00267537 (0.00237561), PSNR 25.72615814 (26.31755082), SSIM 0.71698153 (0.76821673)
# Finished validation.
# Starting training epoch 155
# Epoch: 155, MSE 0.00181298 (0.00192215), PSNR 27.41607475 (27.18448003), SSIM 0.78640449 (0.78170326)
# Finished training epoch 155
# Validate: MSE 0.00271969 (0.00218994), PSNR 25.65481186 (26.65527255), SSIM 0.71450186 (0.77196034)
# Finished validation.
# Starting training epoch 156
# Epoch: 156, MSE 0.00178939 (0.00191583), PSNR 27.47294426 (27.19726733), SSIM 0.78548741 (0.78165578)
# Finished training epoch 156
# Validate: MSE 0.00327128 (0.00302674), PSNR 24.85281754 (25.29147020), SSIM 0.70096201 (0.75365814)
# Finished validation.
# Starting training epoch 157
# Epoch: 157, MSE 0.00172397 (0.00195019), PSNR 27.63470840 (27.12347806), SSIM 0.79216307 (0.78145723)
# Finished training epoch 157
# Validate: MSE 0.00292004 (0.00236531), PSNR 25.34611130 (26.32632509), SSIM 0.71474051 (0.77115865)
# Finished validation.
# Starting training epoch 158
# Epoch: 158, MSE 0.00218414 (0.00191093), PSNR 26.60719109 (27.21044812), SSIM 0.77458489 (0.78168431)
# Finished training epoch 158
# Validate: MSE 0.00269032 (0.00265766), PSNR 25.70195389 (25.84218016), SSIM 0.71344405 (0.76597684)
# Finished validation.
# Starting training epoch 159
# Epoch: 159, MSE 0.00176221 (0.00191085), PSNR 27.53941345 (27.20746204), SSIM 0.78165662 (0.78167713)
# Finished training epoch 159
# Validate: MSE 0.00283799 (0.00249285), PSNR 25.46989632 (26.10458059), SSIM 0.71609741 (0.76316031)
# Finished validation.
# Starting training epoch 160
# Epoch: 160, MSE 0.00138682 (0.00191111), PSNR 28.57980537 (27.20666680), SSIM 0.79770523 (0.78163838)
# Finished training epoch 160
# Validate: MSE 0.00284376 (0.00235065), PSNR 25.46106911 (26.34983791), SSIM 0.70809710 (0.76615613)
# Finished validation.
# Starting training epoch 161
# Epoch: 161, MSE 0.00180212 (0.00189341), PSNR 27.44216728 (27.24510092), SSIM 0.77133387 (0.78175547)
# Finished training epoch 161
# Validate: MSE 0.00256616 (0.00246275), PSNR 25.90716553 (26.13174468), SSIM 0.70543724 (0.76583651)
# Finished validation.
# Starting training epoch 162
# Epoch: 162, MSE 0.00230615 (0.00189825), PSNR 26.37112617 (27.23727981), SSIM 0.75957263 (0.78160853)
# Finished training epoch 162
# Validate: MSE 0.00260065 (0.00227776), PSNR 25.84918213 (26.48146028), SSIM 0.71317405 (0.76297945)
# Finished validation.
# Starting training epoch 163
# Epoch: 163, MSE 0.00156064 (0.00189945), PSNR 28.06698227 (27.23436867), SSIM 0.78908968 (0.78162139)
# Finished training epoch 163
# Validate: MSE 0.00300086 (0.00273927), PSNR 25.22754669 (25.70497955), SSIM 0.70109117 (0.75365598)
# Finished validation.
# Starting training epoch 164
# Epoch: 164, MSE 0.00188296 (0.00189202), PSNR 27.25158310 (27.25181412), SSIM 0.76831013 (0.78158006)
# Finished training epoch 164
# Validate: MSE 0.00250807 (0.00238145), PSNR 26.00661087 (26.28090714), SSIM 0.70979190 (0.76118318)
# Finished validation.
# Starting training epoch 165
# Epoch: 165, MSE 0.00159044 (0.00190017), PSNR 27.98482704 (27.23383959), SSIM 0.79117388 (0.78142234)
# Finished training epoch 165
# Validate: MSE 0.00269008 (0.00227103), PSNR 25.70235062 (26.48675035), SSIM 0.70928866 (0.76663021)
# Finished validation.
# Starting training epoch 166
# Epoch: 166, MSE 0.00202080 (0.00187305), PSNR 26.94475555 (27.29513784), SSIM 0.78025776 (0.78168566)
# Finished training epoch 166
# Validate: MSE 0.00278230 (0.00248191), PSNR 25.55595398 (26.11546777), SSIM 0.70810735 (0.76466889)
# Finished validation.
# Starting training epoch 167
# Epoch: 167, MSE 0.00215920 (0.00187289), PSNR 26.65707970 (27.29466908), SSIM 0.76191801 (0.78156297)
# Finished training epoch 167
# Validate: MSE 0.00298270 (0.00226032), PSNR 25.25390434 (26.51957085), SSIM 0.70583022 (0.77383066)
# Finished validation.
# Starting training epoch 168
# Epoch: 168, MSE 0.00202520 (0.00189403), PSNR 26.93531990 (27.24685051), SSIM 0.76645678 (0.78113683)
# Finished training epoch 168
# Validate: MSE 0.00293730 (0.00277454), PSNR 25.32051086 (25.67541663), SSIM 0.70391214 (0.75943191)
# Finished validation.
# Starting training epoch 169
# Epoch: 169, MSE 0.00174621 (0.00186149), PSNR 27.57902908 (27.32182795), SSIM 0.78552037 (0.78165315)
# Finished training epoch 169
# Validate: MSE 0.00281152 (0.00229986), PSNR 25.51058578 (26.44625842), SSIM 0.71204036 (0.77022619)
# Finished validation.
# Starting training epoch 170
# Epoch: 170, MSE 0.00170786 (0.00188186), PSNR 27.67548752 (27.27451677), SSIM 0.78845131 (0.78121336)
# Finished training epoch 170
# Validate: MSE 0.00291159 (0.00235450), PSNR 25.35870361 (26.33750852), SSIM 0.70260447 (0.75889756)
# Finished validation.
# Starting training epoch 171
# Epoch: 171, MSE 0.00195523 (0.00187035), PSNR 27.08801842 (27.30078739), SSIM 0.77734315 (0.78158468)
# Finished training epoch 171
# Validate: MSE 0.00306639 (0.00250408), PSNR 25.13372040 (26.08757694), SSIM 0.68524826 (0.75987688)
# Finished validation.
# Starting training epoch 172
# Epoch: 172, MSE 0.00173541 (0.00185939), PSNR 27.60597229 (27.32565972), SSIM 0.79112524 (0.78139363)
# Finished training epoch 172
# Validate: MSE 0.00260198 (0.00241429), PSNR 25.84696007 (26.23958980), SSIM 0.70817393 (0.76613383)
# Finished validation.
# Starting training epoch 173
# Epoch: 173, MSE 0.00199505 (0.00185762), PSNR 27.00046349 (27.33046653), SSIM 0.77327377 (0.78150262)
# Finished training epoch 173
# Validate: MSE 0.00308386 (0.00231849), PSNR 25.10905266 (26.41079990), SSIM 0.70185935 (0.76859916)
# Finished validation.
# Starting training epoch 174
# Epoch: 174, MSE 0.00190405 (0.00185179), PSNR 27.20322609 (27.34178381), SSIM 0.78689921 (0.78126137)
# Finished training epoch 174
# Validate: MSE 0.00279524 (0.00251820), PSNR 25.53580856 (26.05954506), SSIM 0.71351802 (0.76590819)
# Finished validation.
# Starting training epoch 175
# Epoch: 175, MSE 0.00170688 (0.00185993), PSNR 27.67798042 (27.32610543), SSIM 0.79914916 (0.78128293)
# Finished training epoch 175
# Validate: MSE 0.00278867 (0.00239878), PSNR 25.54602814 (26.27009120), SSIM 0.70961559 (0.76670801)
# Finished validation.
# Starting training epoch 176
# Epoch: 176, MSE 0.00186559 (0.00184116), PSNR 27.29183769 (27.36584095), SSIM 0.76868421 (0.78158030)
# Finished training epoch 176
# Validate: MSE 0.00273714 (0.00233241), PSNR 25.62702751 (26.37787060), SSIM 0.70068705 (0.76343761)
# Finished validation.
# Starting training epoch 177
# Epoch: 177, MSE 0.00188594 (0.00184762), PSNR 27.24472809 (27.35168528), SSIM 0.78826702 (0.78118062)
# Finished training epoch 177
# Validate: MSE 0.00275911 (0.00237447), PSNR 25.59231377 (26.30414621), SSIM 0.71196288 (0.76036792)
# Finished validation.
# Starting training epoch 178
# Epoch: 178, MSE 0.00219085 (0.00183762), PSNR 26.59387779 (27.37693795), SSIM 0.76526833 (0.78130978)
# Finished training epoch 178
# Validate: MSE 0.00287177 (0.00271038), PSNR 25.41850471 (25.75234109), SSIM 0.69566345 (0.75171487)
# Finished validation.
# Starting training epoch 179
# Epoch: 179, MSE 0.00218224 (0.00183893), PSNR 26.61096764 (27.37448971), SSIM 0.76017177 (0.78113903)
# Finished training epoch 179
# Validate: MSE 0.00282651 (0.00231709), PSNR 25.48749161 (26.40255408), SSIM 0.70320743 (0.75956980)
# Finished validation.
# Starting training epoch 180
# Epoch: 180, MSE 0.00218719 (0.00184215), PSNR 26.60114288 (27.36718837), SSIM 0.75280416 (0.78114541)
# Finished training epoch 180
# Validate: MSE 0.00266703 (0.00240464), PSNR 25.73972321 (26.25063417), SSIM 0.70404869 (0.76492096)
# Finished validation.
# Starting training epoch 181
# Epoch: 181, MSE 0.00162368 (0.00183028), PSNR 27.89499092 (27.39295867), SSIM 0.78761518 (0.78142626)
# Finished training epoch 181
# Validate: MSE 0.00294241 (0.00234388), PSNR 25.31296730 (26.35723232), SSIM 0.69930238 (0.75769388)
# Finished validation.
# Starting training epoch 182
# Epoch: 182, MSE 0.00183371 (0.00184212), PSNR 27.36668587 (27.36574292), SSIM 0.77800149 (0.78113785)
# Finished training epoch 182
# Validate: MSE 0.00277162 (0.00230069), PSNR 25.57265663 (26.43631972), SSIM 0.70247281 (0.76209394)
# Finished validation.
# Starting training epoch 183
# Epoch: 183, MSE 0.00203054 (0.00182222), PSNR 26.92388916 (27.41461921), SSIM 0.77376765 (0.78133502)
# Finished training epoch 183
# Validate: MSE 0.00298185 (0.00234502), PSNR 25.25514412 (26.36192593), SSIM 0.70590138 (0.76725759)
# Finished validation.
# Starting training epoch 184
# Epoch: 184, MSE 0.00191019 (0.00182170), PSNR 27.18922424 (27.41401377), SSIM 0.77237803 (0.78132244)
# Finished training epoch 184
# Validate: MSE 0.00288521 (0.00226727), PSNR 25.39822578 (26.50128247), SSIM 0.70421892 (0.76922738)
# Finished validation.
# Starting training epoch 185
# Epoch: 185, MSE 0.00202096 (0.00181677), PSNR 26.94441032 (27.42590185), SSIM 0.75586861 (0.78149382)
# Finished training epoch 185
# Validate: MSE 0.00277146 (0.00232500), PSNR 25.57292175 (26.39311589), SSIM 0.70336342 (0.76028742)
# Finished validation.
# Starting training epoch 186
# Epoch: 186, MSE 0.00183705 (0.00181362), PSNR 27.35878372 (27.43241611), SSIM 0.77039558 (0.78125476)
# Finished training epoch 186
# Validate: MSE 0.00317853 (0.00238636), PSNR 24.97772980 (26.27552767), SSIM 0.70003575 (0.76496039)
# Finished validation.
# Starting training epoch 187
# Epoch: 187, MSE 0.00147923 (0.00183559), PSNR 28.29962730 (27.38076815), SSIM 0.79855990 (0.78106259)
# Finished training epoch 187
# Validate: MSE 0.00277052 (0.00239760), PSNR 25.57439041 (26.25770267), SSIM 0.70659578 (0.75621016)
# Finished validation.
# Starting training epoch 188
# Epoch: 188, MSE 0.00183026 (0.00180036), PSNR 27.37487411 (27.46555351), SSIM 0.77704322 (0.78164995)
# Finished training epoch 188
# Validate: MSE 0.00259412 (0.00230110), PSNR 25.86009979 (26.43785162), SSIM 0.71919131 (0.76866708)
# Finished validation.
# Starting training epoch 189
# Epoch: 189, MSE 0.00211883 (0.00179156), PSNR 26.73902893 (27.48448904), SSIM 0.75649107 (0.78146692)
# Finished training epoch 189
# Validate: MSE 0.00288043 (0.00238890), PSNR 25.40542793 (26.27012888), SSIM 0.70430994 (0.75604174)
# Finished validation.
# Starting training epoch 190
# Epoch: 190, MSE 0.00303706 (0.00181549), PSNR 25.17546082 (27.43118212), SSIM 0.76192725 (0.78112413)
# Finished training epoch 190
# Validate: MSE 0.00270010 (0.00231273), PSNR 25.68619919 (26.41578976), SSIM 0.69602746 (0.76603053)
# Finished validation.
# Starting training epoch 191
# Epoch: 191, MSE 0.00183773 (0.00181660), PSNR 27.35719109 (27.42534922), SSIM 0.77788228 (0.78109417)
# Finished training epoch 191
# Validate: MSE 0.00311663 (0.00248235), PSNR 25.06314087 (26.11803687), SSIM 0.69687200 (0.76009504)
# Finished validation.
# Starting training epoch 192
# Epoch: 192, MSE 0.00162699 (0.00180183), PSNR 27.88615227 (27.46035644), SSIM 0.78394830 (0.78101321)
# Finished training epoch 192
# Validate: MSE 0.00278837 (0.00238315), PSNR 25.54649353 (26.28521685), SSIM 0.69094640 (0.76144506)
# Finished validation.
# Starting training epoch 193
# Epoch: 193, MSE 0.00184486 (0.00179570), PSNR 27.34036446 (27.47501983), SSIM 0.78821409 (0.78132550)
# Finished training epoch 193
# Validate: MSE 0.00366073 (0.00289240), PSNR 24.36431694 (25.45067295), SSIM 0.69759631 (0.76054877)
# Finished validation.
# Starting training epoch 194
# Epoch: 194, MSE 0.00208884 (0.00179895), PSNR 26.80095673 (27.47004719), SSIM 0.78238904 (0.78118910)
# Finished training epoch 194
# Validate: MSE 0.00282504 (0.00229307), PSNR 25.48974800 (26.44735388), SSIM 0.69674689 (0.75603055)
# Finished validation.
# Starting training epoch 195
# Epoch: 195, MSE 0.00180437 (0.00177943), PSNR 27.43673325 (27.51613396), SSIM 0.78722811 (0.78125553)
# Finished training epoch 195
# Validate: MSE 0.00298647 (0.00228959), PSNR 25.24841499 (26.46066592), SSIM 0.69697750 (0.76353946)
# Finished validation.
# Starting training epoch 196
# Epoch: 196, MSE 0.00171485 (0.00177629), PSNR 27.65774727 (27.52278287), SSIM 0.77010280 (0.78142562)
# Finished training epoch 196
# Validate: MSE 0.00283586 (0.00288159), PSNR 25.47314644 (25.49523352), SSIM 0.71391940 (0.75821820)
# Finished validation.
# Starting training epoch 197
# Epoch: 197, MSE 0.00175911 (0.00178328), PSNR 27.54706192 (27.50591202), SSIM 0.76234502 (0.78127658)
# Finished training epoch 197
# Validate: MSE 0.00308997 (0.00242683), PSNR 25.10046005 (26.19929489), SSIM 0.68499327 (0.75395899)
# Finished validation.
# Starting training epoch 198
# Epoch: 198, MSE 0.00189667 (0.00177683), PSNR 27.22007942 (27.52169123), SSIM 0.76798588 (0.78115605)
# Finished training epoch 198
# Validate: MSE 0.00285546 (0.00247625), PSNR 25.44324493 (26.10875846), SSIM 0.69453144 (0.74718508)
# Finished validation.
# Starting training epoch 199
# Epoch: 199, MSE 0.00133664 (0.00178342), PSNR 28.73986816 (27.50585464), SSIM 0.79599166 (0.78120129)
# Finished training epoch 199
# Validate: MSE 0.00281546 (0.00230339), PSNR 25.50450897 (26.43382360), SSIM 0.69571745 (0.76570304)
# Finished validation.
# Starting training epoch 200
# Epoch: 200, MSE 0.00151383 (0.00177528), PSNR 28.19924164 (27.52503938), SSIM 0.79422551 (0.78125738)
# Finished training epoch 200
# Validate: MSE 0.00313901 (0.00227684), PSNR 25.03207397 (26.47950845), SSIM 0.69302058 (0.76442031)
# Finished validation.
# Starting training epoch 201
# Epoch: 201, MSE 0.00183809 (0.00177016), PSNR 27.35633278 (27.53797881), SSIM 0.77189243 (0.78128500)
# Finished training epoch 201
# Validate: MSE 0.00288012 (0.00237933), PSNR 25.40589523 (26.29267866), SSIM 0.69748878 (0.76066486)
# Finished validation.
# Starting training epoch 202
# Epoch: 202, MSE 0.00167228 (0.00178367), PSNR 27.76690292 (27.50319226), SSIM 0.77008402 (0.78120937)
# Finished training epoch 202
# Validate: MSE 0.00280328 (0.00235233), PSNR 25.52333641 (26.33539718), SSIM 0.69910061 (0.75357139)
# Finished validation.
# Starting training epoch 203
# Epoch: 203, MSE 0.00156429 (0.00176729), PSNR 28.05682945 (27.54465915), SSIM 0.78781974 (0.78118771)
# Finished training epoch 203
# Validate: MSE 0.00283810 (0.00239787), PSNR 25.46972847 (26.25604544), SSIM 0.69253939 (0.75870458)
# Finished validation.
# Starting training epoch 204
# Epoch: 204, MSE 0.00162110 (0.00176055), PSNR 27.90189743 (27.56327254), SSIM 0.78291512 (0.78126810)
# Finished training epoch 204
# Validate: MSE 0.00271885 (0.00243175), PSNR 25.65615082 (26.19664359), SSIM 0.70333862 (0.76150292)
# Finished validation.
# Starting training epoch 205
# Epoch: 205, MSE 0.00135846 (0.00177163), PSNR 28.66952896 (27.53350161), SSIM 0.79499120 (0.78116051)
# Finished training epoch 205
# Validate: MSE 0.00301909 (0.00241591), PSNR 25.20123863 (26.23248492), SSIM 0.68872851 (0.75954100)
# Finished validation.

# %%
torch.save(model.state_dict(), f'{checkpoints}/last-{losses[0]:.8f}-{losses[1]:.8f}-{losses[2]:.8f}.pth')

# %%
# Validate
save_images = True
with torch.no_grad():
    validate(val_loader, model, criterion, save_images, -1)
# Out:
# Validate: MSE 0.00301909 (0.00241591), PSNR 25.20123863 (26.23248492), SSIM 0.68872857 (0.75954099)
# Finished validation.

# %%
# # Show images 
# image_pairs = []

# for i in range(10):
#     image_pairs.append((f'{color_imgs}img-{i}-epoch-{best_epoch}.jpg', f'{gray_imgs}img-{i}-epoch-{best_epoch}.jpg'))
    
# for c, g in image_pairs:
#   color = mpimg.imread(c)
#   gray  = mpimg.imread(g)
#   f, axarr = plt.subplots(1, 2)
#   f.set_size_inches(15, 15)
#   axarr[0].imshow(gray, cmap='gray')
#   axarr[1].imshow(color)
#   axarr[0].axis('off'), axarr[1].axis('off')
#   plt.show()
